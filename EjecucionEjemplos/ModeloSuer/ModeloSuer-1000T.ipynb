# %% [markdown]
# # Modelo de programación lineal Süer et. al.

# %%
import pandas as pd

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x1.5x1

# %%
datafile="2x1000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-06-11
# Using license file C:\Users\elPatan03\gurobi.lic
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xe4e0bb0e
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 999.0000000
# Sparsify removed 985836 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 367 rows and 0 columns
# Presolve time: 2.56s
# Presolved: 2633 rows, 2196 columns, 13198 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 2.62 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990000000000e+02, best bound 9.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x1.5x2

# %%
datafile="2x1000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xe0ea3b41
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 998.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 355 rows and 0 columns
# Presolve time: 2.91s
# Presolved: 2645 rows, 2196 columns, 13324 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 9.990000e+02, 816 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  999.00000    0    6  998.00000  999.00000  0.10%     -    2s
#      0     0  999.00000    0   12  998.00000  999.00000  0.10%     -    3s
#      0     0  998.00000    0   12  998.00000  998.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 3
#
# Explored 1 nodes (907 simplex iterations) in 3.05 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.980000000000e+02, best bound 9.980000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x1.5x3

# %%
datafile="2x1000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x2e784b6e
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1000.0000000
# Sparsify removed 987622 nonzeros (98%)
# Presolve added 0 rows and 198 columns
# Presolve removed 378 rows and 0 columns
# Presolve time: 2.44s
# Presolved: 2622 rows, 2198 columns, 13376 nonzeros
# Variable types: 196 continuous, 2002 integer (2000 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 2.50 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x1.5x4

# %%
datafile="2x1000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x094fc2af
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1000.0000000
# Sparsify removed 987144 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 352 rows and 0 columns
# Presolve time: 3.00s
# Presolved: 2648 rows, 2196 columns, 13630 nonzeros
# Variable types: 196 continuous, 2000 integer (2000 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 3.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x1.5x5

# %%
datafile="2x1000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x4950f6a8
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 998.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 325 rows and 0 columns
# Presolve time: 2.53s
# Presolved: 2675 rows, 2196 columns, 13544 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 9.990000e+02, 826 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  999.00000    0    4  998.00000  999.00000  0.10%     -    2s
# H    0     0                     999.0000000  999.00000  0.00%     -    2s
#      0     0  999.00000    0    4  999.00000  999.00000  0.00%     -    2s
#
# Explored 1 nodes (906 simplex iterations) in 2.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 999 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990000000000e+02, best bound 9.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2x1

# %%
datafile="2x1000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x4d4cffe1
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 984.0000000
# Sparsify removed 987540 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 194 rows and 0 columns
# Presolve time: 2.43s
# Presolved: 2806 rows, 2196 columns, 14502 nonzeros
# Variable types: 196 continuous, 2000 integer (2000 binary)
#
# Root relaxation: objective 9.881901e+02, 913 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  988.19013    0   25  984.00000  988.19013  0.43%     -    2s
# H    0     0                     987.0000000  988.19013  0.12%     -    2s
#      0     0  988.17240    0   34  987.00000  988.17240  0.12%     -    2s
#      0     0  988.17240    0   30  987.00000  988.17240  0.12%     -    2s
#      0     0  988.15379    0   23  987.00000  988.15379  0.12%     -    2s
#      0     0  988.15379    0   21  987.00000  988.15379  0.12%     -    2s
# H    0     0                     988.0000000  988.15379  0.02%     -    2s
#
# Cutting planes:
#   Gomory: 8
#   MIR: 21
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (1039 simplex iterations) in 2.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 988 987 984
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.880000000000e+02, best bound 9.880000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2x2

# %%
datafile="2x1000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x829583cb
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 969.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 158 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2842 rows, 2194 columns, 14372 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 9.751155e+02, 979 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  975.11555    0   57  969.00000  975.11555  0.63%     -    2s
# H    0     0                     970.0000000  975.11555  0.53%     -    2s
# H    0     0                     972.0000000  975.11555  0.32%     -    2s
#      0     0  974.84124    0   45  972.00000  974.84124  0.29%     -    2s
# H    0     0                     973.0000000  974.84124  0.19%     -    2s
# H    0     0                     974.0000000  974.84124  0.09%     -    2s
#      0     0  974.84056    0   41  974.00000  974.84056  0.09%     -    2s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 1
#   Implied bound: 5
#   MIR: 13
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (1403 simplex iterations) in 2.70 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 974 973 972 ... 969
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.740000000000e+02, best bound 9.740000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2x3

# %%
datafile="2x1000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x18e6cd37
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 980.0000000
# Sparsify removed 983842 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 212 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2788 rows, 2194 columns, 14232 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 9.841986e+02, 921 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  984.19860    0   26  980.00000  984.19860  0.43%     -    2s
# H    0     0                     982.0000000  984.19860  0.22%     -    2s
#      0     0  984.07441    0   25  982.00000  984.07441  0.21%     -    2s
# H    0     0                     983.0000000  984.07441  0.11%     -    2s
#      0     0  984.07358    0   33  983.00000  984.07358  0.11%     -    2s
#      0     0  984.07358    0   33  983.00000  984.07358  0.11%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 13
#   StrongCG: 1
#   RLT: 1
#
# Explored 1 nodes (1102 simplex iterations) in 2.70 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 983 982 980
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.830000000000e+02, best bound 9.830000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2x4

# %%
datafile="2x1000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x2d0c3338
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 985.0000000
# Sparsify removed 981882 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 163 rows and 0 columns
# Presolve time: 2.50s
# Presolved: 2837 rows, 2192 columns, 14376 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 9.870697e+02, 943 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  987.06972    0   46  985.00000  987.06972  0.21%     -    2s
#      0     0  986.95589    0   49  985.00000  986.95589  0.20%     -    2s
# H    0     0                     986.0000000  986.95589  0.10%     -    2s
#      0     0  986.95360    0   43  986.00000  986.95360  0.10%     -    2s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 1
#   MIR: 16
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (1451 simplex iterations) in 2.73 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 986 985
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.860000000000e+02, best bound 9.860000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2x5

# %%
datafile="2x1000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x9db50252
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 975.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 163 rows and 0 columns
# Presolve time: 2.89s
# Presolved: 2837 rows, 2196 columns, 14438 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 9.796528e+02, 937 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  979.65280    0   30  975.00000  979.65280  0.48%     -    2s
# H    0     0                     976.0000000  979.65280  0.37%     -    2s
# H    0     0                     977.0000000  979.65280  0.27%     -    3s
#      0     0  979.61434    0   37  977.00000  979.61434  0.27%     -    3s
# H    0     0                     978.0000000  979.61434  0.17%     -    3s
# H    0     0                     979.0000000  979.61434  0.06%     -    3s
#      0     0  979.60120    0   27  979.00000  979.60120  0.06%     -    3s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 1
#   MIR: 14
#   GUB cover: 3
#   RLT: 1
#
# Explored 1 nodes (1079 simplex iterations) in 3.12 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 979 978 977 ... 975
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.790000000000e+02, best bound 9.790000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2.5x1

# %%
datafile="2x1000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x861dda3d
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 863.0000000
# Sparsify removed 981872 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 101 rows and 0 columns
# Presolve time: 2.87s
# Presolved: 2899 rows, 2192 columns, 14828 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 8.831707e+02, 1439 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  883.17073    0   22  863.00000  883.17073  2.34%     -    2s
# H    0     0                     881.0000000  883.17073  0.25%     -    2s
#      0     0  882.95388    0   27  881.00000  882.95388  0.22%     -    3s
# H    0     0                     882.0000000  882.95388  0.11%     -    3s
#      0     0  882.95388    0   27  882.00000  882.95388  0.11%     -    3s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   MIR: 9
#
# Explored 1 nodes (1561 simplex iterations) in 3.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 882 881 863
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.820000000000e+02, best bound 8.820000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2.5x2

# %%
datafile="2x1000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x981c2de9
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 858.0000000
# Sparsify removed 983842 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 96 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2904 rows, 2194 columns, 14870 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 8.830715e+02, 1220 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  883.07154    0   82  858.00000  883.07154  2.92%     -    2s
# H    0     0                     880.0000000  883.07154  0.35%     -    2s
#      0     0  882.91530    0   67  880.00000  882.91530  0.33%     -    2s
# H    0     0                     881.0000000  882.91530  0.22%     -    2s
# H    0     0                     882.0000000  882.91530  0.10%     -    2s
#      0     0  882.91530    0   67  882.00000  882.91530  0.10%     -    2s
#
# Cutting planes:
#   Gomory: 7
#   Implied bound: 4
#   MIR: 30
#   StrongCG: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (1720 simplex iterations) in 2.74 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 882 881 880 858
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.820000000000e+02, best bound 8.820000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2.5x3

# %%
datafile="2x1000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x143b493a
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 860.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 100 rows and 0 columns
# Presolve time: 2.46s
# Presolved: 2900 rows, 2194 columns, 14852 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 8.851615e+02, 1284 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  885.16148    0   19  860.00000  885.16148  2.93%     -    2s
# H    0     0                     883.0000000  885.16148  0.24%     -    2s
#      0     0  885.04524    0   30  883.00000  885.04524  0.23%     -    2s
# H    0     0                     884.0000000  885.04524  0.12%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   Implied bound: 1
#   MIR: 11
#   Relax-and-lift: 1
#
# Explored 1 nodes (1389 simplex iterations) in 2.68 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 884 883 860
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.840000000000e+02, best bound 8.840000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2.5x4

# %%
datafile="2x1000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x90219caa
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 861.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 104 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2896 rows, 2194 columns, 14740 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 8.847405e+02, 1334 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  884.74046    0   37  861.00000  884.74046  2.76%     -    2s
# H    0     0                     882.0000000  884.74046  0.31%     -    2s
# H    0     0                     883.0000000  884.74046  0.20%     -    2s
#      0     0  884.66379    0   38  883.00000  884.66379  0.19%     -    2s
#      0     0  884.60325    0   40  883.00000  884.60325  0.18%     -    2s
#      0     0  884.60325    0   40  883.00000  884.60325  0.18%     -    2s
#      0     0  884.60325    0   34  883.00000  884.60325  0.18%     -    2s
# H    0     0                     884.0000000  884.60325  0.07%     -    2s
#      0     0  884.60325    0   34  884.00000  884.60325  0.07%     -    2s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 1
#   MIR: 14
#
# Explored 1 nodes (1655 simplex iterations) in 2.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 884 883 882 861
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.840000000000e+02, best bound 8.840000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x2.5x5

# %%
datafile="2x1000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xbe018c60
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 861.0000000
# Sparsify removed 979902 nonzeros (98%)
# Presolve added 0 rows and 190 columns
# Presolve removed 140 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2860 rows, 2190 columns, 14608 nonzeros
# Variable types: 198 continuous, 1992 integer (1992 binary)
#
# Root relaxation: objective 8.869767e+02, 1286 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  886.97668    0   48  861.00000  886.97668  3.02%     -    2s
# H    0     0                     883.0000000  886.97668  0.45%     -    2s
# H    0     0                     885.0000000  886.97668  0.22%     -    2s
#      0     0  886.89994    0   65  885.00000  886.89994  0.21%     -    2s
# H    0     0                     886.0000000  886.89994  0.10%     -    2s
#      0     0  886.84531    0   59  886.00000  886.84531  0.10%     -    2s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 3
#   MIR: 18
#
# Explored 1 nodes (1547 simplex iterations) in 2.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 886 885 883 861
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.860000000000e+02, best bound 8.860000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3x1

# %%
datafile="2x1000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xa9314083
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 773.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 74 rows and 0 columns
# Presolve time: 2.51s
# Presolved: 2926 rows, 2194 columns, 14912 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 8.024420e+02, 1265 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  802.44195    0   78  773.00000  802.44195  3.81%     -    2s
# H    0     0                     797.0000000  802.44195  0.68%     -    2s
# H    0     0                     799.0000000  802.44195  0.43%     -    2s
#      0     0  802.33937    0   82  799.00000  802.33937  0.42%     -    2s
# H    0     0                     801.0000000  802.33937  0.17%     -    2s
#      0     0  802.21070    0   80  801.00000  802.21070  0.15%     -    2s
#      0     0  802.21070    0   80  801.00000  802.21070  0.15%     -    2s
#      0     0  802.15865    0   68  801.00000  802.15865  0.14%     -    2s
#      0     0  802.15677    0   63  801.00000  802.15677  0.14%     -    2s
#      0     0  802.15677    0   69  801.00000  802.15677  0.14%     -    2s
#      0     0  802.14735    0   65  801.00000  802.14735  0.14%     -    2s
#      0     0  802.14735    0   61  801.00000  802.14735  0.14%     -    2s
#      0     0  802.14735    0   67  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   73  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   35  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   31  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   30  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   34  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   33  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   45  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   40  801.00000  802.14735  0.14%     -    3s
#      0     0  802.14735    0   38  801.00000  802.14735  0.14%     -    3s
#      0     2  802.14735    0   38  801.00000  802.14735  0.14%     -    3s
#   1277  1065  802.12164    8   38  801.00000  802.14735  0.14%   2.8    5s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 6
#   Clique: 1
#   MIR: 20
#   Flow cover: 38
#   RLT: 7
#
# Explored 1281 nodes (8260 simplex iterations) in 6.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 801 799 797 773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.010000000000e+02, best bound 8.010000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3x2

# %%
datafile="2x1000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x7225bc1f
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 764.0000000
# Sparsify removed 981882 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 67 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2933 rows, 2192 columns, 14934 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 8.030494e+02, 1525 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  803.04938    0   65  764.00000  803.04938  5.11%     -    2s
# H    0     0                     801.0000000  803.04938  0.26%     -    2s
#      0     0  802.95628    0   61  801.00000  802.95628  0.24%     -    2s
#      0     0  802.95628    0   61  801.00000  802.95628  0.24%     -    2s
#      0     0  802.63720    0   47  801.00000  802.63720  0.20%     -    2s
#      0     0  802.63719    0   47  801.00000  802.63719  0.20%     -    2s
# H    0     0                     802.0000000  802.63719  0.08%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 3
#   Implied bound: 2
#   MIR: 58
#   StrongCG: 3
#   RLT: 1
#
# Explored 1 nodes (2027 simplex iterations) in 2.89 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 802 801 764
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.020000000000e+02, best bound 8.020000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3x3

# %%
datafile="2x1000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x514d2dc6
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 772.0000000
# Sparsify removed 979902 nonzeros (98%)
# Presolve added 0 rows and 190 columns
# Presolve removed 66 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2934 rows, 2190 columns, 14960 nonzeros
# Variable types: 198 continuous, 1992 integer (1992 binary)
#
# Root relaxation: objective 8.066637e+02, 1400 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.66373    0   36  772.00000  806.66373  4.49%     -    2s
# H    0     0                     805.0000000  806.66373  0.21%     -    2s
#      0     0  806.58657    0   24  805.00000  806.58657  0.20%     -    2s
#      0     0  806.45351    0   18  805.00000  806.45351  0.18%     -    2s
#      0     0  806.43204    0   21  805.00000  806.43204  0.18%     -    2s
#      0     0  806.43204    0    9  805.00000  806.43204  0.18%     -    2s
# H    0     0                     806.0000000  806.43204  0.05%     -    2s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 3
#   MIR: 22
#
# Explored 1 nodes (1678 simplex iterations) in 2.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 806 805 772
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.060000000000e+02, best bound 8.060000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3x4

# %%
datafile="2x1000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xd4cdbd2b
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 773.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 61 rows and 0 columns
# Presolve time: 3.31s
# Presolved: 2939 rows, 2196 columns, 14884 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 8.062300e+02, 1346 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.23004    0   46  773.00000  806.23004  4.30%     -    3s
# H    0     0                     804.0000000  806.23004  0.28%     -    3s
#      0     0  806.22684    0   63  804.00000  806.22684  0.28%     -    3s
# H    0     0                     806.0000000  806.22684  0.03%     -    3s
#      0     0  806.22684    0   63  806.00000  806.22684  0.03%     -    3s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   MIR: 15
#
# Explored 1 nodes (1829 simplex iterations) in 3.56 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 806 804 773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.060000000000e+02, best bound 8.060000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3x5

# %%
datafile="2x1000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x32a158e3
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 767.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 67 rows and 0 columns
# Presolve time: 2.53s
# Presolved: 2933 rows, 2196 columns, 14970 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 8.031831e+02, 1510 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  803.18314    0   89  767.00000  803.18314  4.72%     -    2s
# H    0     0                     799.0000000  803.18314  0.52%     -    2s
# H    0     0                     801.0000000  803.18314  0.27%     -    2s
#      0     0  803.12886    0   94  801.00000  803.12886  0.27%     -    2s
# H    0     0                     802.0000000  803.12886  0.14%     -    2s
#      0     0  803.12780    0   96  802.00000  803.12780  0.14%     -    2s
#      0     0  803.12188    0   95  802.00000  803.12188  0.14%     -    2s
#      0     0  803.12187    0   95  802.00000  803.12187  0.14%     -    2s
#      0     0  803.06525    0   60  802.00000  803.06525  0.13%     -    2s
#      0     0  803.06525    0   59  802.00000  803.06525  0.13%     -    2s
#      0     0  803.06525    0   71  802.00000  803.06525  0.13%     -    2s
#      0     0  803.06525    0   66  802.00000  803.06525  0.13%     -    2s
#      0     0  803.06509    0   32  802.00000  803.06509  0.13%     -    3s
#      0     0  803.06503    0   45  802.00000  803.06503  0.13%     -    3s
#      0     0  803.06503    0   61  802.00000  803.06503  0.13%     -    3s
#      0     0  803.06339    0   64  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   64  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   68  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   66  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   70  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   37  802.00000  803.06339  0.13%     -    3s
#      0     0  803.06339    0   25  802.00000  803.06339  0.13%     -    3s
#      0     0  803.03742    0   17  802.00000  803.03742  0.13%     -    3s
#      0     0  803.00281    0   21  802.00000  803.00281  0.13%     -    3s
#      0     0  802.99934    0   19  802.00000  802.99934  0.12%     -    3s
#      0     0  802.99934    0   20  802.00000  802.99934  0.12%     -    3s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 8
#   MIR: 36
#   RLT: 6
#
# Explored 1 nodes (3889 simplex iterations) in 3.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 802 801 799 767
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.020000000000e+02, best bound 8.020000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3.5x1

# %%
datafile="2x1000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xdc32eb90
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 705.0000000
# Sparsify removed 979890 nonzeros (98%)
# Presolve added 0 rows and 190 columns
# Presolve removed 66 rows and 0 columns
# Presolve time: 2.48s
# Presolved: 2934 rows, 2190 columns, 14936 nonzeros
# Variable types: 198 continuous, 1992 integer (1992 binary)
#
# Root relaxation: objective 7.449069e+02, 1469 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  744.90687    0   55  705.00000  744.90687  5.66%     -    2s
# H    0     0                     742.0000000  744.90687  0.39%     -    2s
# H    0     0                     743.0000000  744.90687  0.26%     -    2s
#      0     0  744.86870    0   42  743.00000  744.86870  0.25%     -    2s
#      0     0  744.85317    0   31  743.00000  744.85317  0.25%     -    2s
#      0     0  744.84339    0   29  743.00000  744.84339  0.25%     -    2s
#      0     0  744.81272    0   33  743.00000  744.81272  0.24%     -    2s
# H    0     0                     744.0000000  744.81272  0.11%     -    2s
#      0     0  744.00000    0   24  744.00000  744.00000  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 10
#   Implied bound: 1
#   MIR: 17
#   StrongCG: 1
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (1886 simplex iterations) in 2.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 744 743 742 705
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.440000000000e+02, best bound 7.440000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3.5x2

# %%
datafile="2x1000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xc86f9225
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 701.0000000
# Sparsify removed 975942 nonzeros (98%)
# Presolve added 0 rows and 186 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 2.46s
# Presolved: 2942 rows, 2186 columns, 14974 nonzeros
# Variable types: 198 continuous, 1988 integer (1988 binary)
#
# Root relaxation: objective 7.449724e+02, 1531 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  744.97236    0   29  701.00000  744.97236  6.27%     -    2s
# H    0     0                     744.0000000  744.97236  0.13%     -    2s
#      0     0  744.97236    0   29  744.00000  744.97236  0.13%     -    2s
#
# Explored 1 nodes (1770 simplex iterations) in 2.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 744 701
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.440000000000e+02, best bound 7.440000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3.5x3

# %%
datafile="2x1000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x52782f77
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 705.0000000
# Sparsify removed 981882 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 43 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2957 rows, 2192 columns, 15032 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 7.431688e+02, 1455 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  743.16885    0   54  705.00000  743.16885  5.41%     -    2s
# H    0     0                     741.0000000  743.16885  0.29%     -    2s
# H    0     0                     742.0000000  743.16885  0.16%     -    2s
#      0     0  743.14271    0   62  742.00000  743.14271  0.15%     -    2s
#      0     0  743.01728    0   62  742.00000  743.01728  0.14%     -    2s
#      0     0  743.01728    0   62  742.00000  743.01728  0.14%     -    2s
#
# Cutting planes:
#   Gomory: 23
#   Cover: 3
#   Implied bound: 4
#   MIR: 69
#   RLT: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (1692 simplex iterations) in 2.74 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 742 741 705
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.420000000000e+02, best bound 7.420000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3.5x4

# %%
datafile="2x1000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x4791d99c
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 702.0000000
# Sparsify removed 983826 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 36 rows and 0 columns
# Presolve time: 2.88s
# Presolved: 2964 rows, 2194 columns, 15080 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 7.416683e+02, 1516 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  741.66833    0   84  702.00000  741.66833  5.65%     -    3s
# H    0     0                     740.0000000  741.66833  0.23%     -    3s
#      0     0  741.58813    0   73  740.00000  741.58813  0.21%     -    3s
#      0     0  741.58248    0   63  740.00000  741.58248  0.21%     -    3s
#      0     0  741.58248    0   69  740.00000  741.58248  0.21%     -    3s
#      0     0  741.56989    0   66  740.00000  741.56989  0.21%     -    3s
#      0     0  741.53760    0   70  740.00000  741.53760  0.21%     -    3s
#      0     0  741.53347    0   73  740.00000  741.53347  0.21%     -    3s
#      0     0  741.53313    0   70  740.00000  741.53313  0.21%     -    3s
#      0     0  741.53313    0   70  740.00000  741.53313  0.21%     -    3s
#      0     0  741.53313    0   59  740.00000  741.53313  0.21%     -    3s
#      0     0  741.53313    0   64  740.00000  741.53313  0.21%     -    3s
#      0     0  741.53297    0   55  740.00000  741.53297  0.21%     -    3s
#      0     0  741.53297    0   65  740.00000  741.53297  0.21%     -    3s
#      0     0  741.53297    0   61  740.00000  741.53297  0.21%     -    3s
# H    0     0                     741.0000000  741.53297  0.07%     -    3s
#      0     0  741.00000    0   57  741.00000  741.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 6
#   Implied bound: 1
#   MIR: 54
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (2198 simplex iterations) in 3.56 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 741 740 702
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.410000000000e+02, best bound 7.410000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x3.5x5

# %%
datafile="2x1000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xa14a51cb
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 698.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 70 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2930 rows, 2194 columns, 14944 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 7.372741e+02, 1509 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  737.27406    0   48  698.00000  737.27406  5.63%     -    2s
# H    0     0                     736.0000000  737.27406  0.17%     -    2s
#      0     0  737.19574    0   76  736.00000  737.19574  0.16%     -    2s
#      0     0  737.19031    0   76  736.00000  737.19031  0.16%     -    2s
#      0     0  737.17180    0   53  736.00000  737.17180  0.16%     -    2s
#      0     0  737.13406    0   40  736.00000  737.13406  0.15%     -    2s
#      0     0  737.13288    0   43  736.00000  737.13288  0.15%     -    2s
#      0     0  737.13288    0   41  736.00000  737.13288  0.15%     -    2s
#      0     0  737.13288    0   27  736.00000  737.13288  0.15%     -    2s
#      0     0  737.12988    0   27  736.00000  737.12988  0.15%     -    2s
#      0     0  737.12988    0   25  736.00000  737.12988  0.15%     -    2s
#      0     0  737.12988    0   31  736.00000  737.12988  0.15%     -    2s
#      0     0  737.12988    0   39  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   41  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   43  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   29  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   32  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   31  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   31  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   24  736.00000  737.12988  0.15%     -    3s
#      0     0  737.12988    0   31  736.00000  737.12988  0.15%     -    3s
# H    0     0                     737.0000000  737.12988  0.02%     -    3s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 28
#   StrongCG: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (2201 simplex iterations) in 3.37 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 737 736 698
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.370000000000e+02, best bound 7.370000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4x1

# %%
datafile="2x1000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x978fd8b2
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 646.0000000
# Sparsify removed 983854 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 48 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2952 rows, 2194 columns, 15028 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 6.929594e+02, 1528 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  692.95935    0   51  646.00000  692.95935  7.27%     -    2s
# H    0     0                     689.0000000  692.95935  0.57%     -    2s
#      0     0  692.95383    0   53  689.00000  692.95383  0.57%     -    2s
# H    0     0                     691.0000000  692.95383  0.28%     -    2s
# H    0     0                     692.0000000  692.95383  0.14%     -    2s
#      0     0  692.95383    0   53  692.00000  692.95383  0.14%     -    2s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 2
#   MIR: 25
#   Relax-and-lift: 1
#
# Explored 1 nodes (1940 simplex iterations) in 2.73 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 692 691 689 646
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.920000000000e+02, best bound 6.920000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4x2

# %%
datafile="2x1000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x158bc717
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 646.0000000
# Sparsify removed 975942 nonzeros (98%)
# Presolve added 0 rows and 186 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2942 rows, 2186 columns, 14960 nonzeros
# Variable types: 198 continuous, 1988 integer (1988 binary)
#
# Root relaxation: objective 6.878692e+02, 1569 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  687.86919    0   50  646.00000  687.86919  6.48%     -    2s
# H    0     0                     685.0000000  687.86919  0.42%     -    2s
#      0     0  687.78396    0   50  685.00000  687.78396  0.41%     -    2s
# H    0     0                     687.0000000  687.78396  0.11%     -    2s
#      0     0  687.78396    0   50  687.00000  687.78396  0.11%     -    2s
#
# Cutting planes:
#   Gomory: 7
#   Implied bound: 2
#   MIR: 18
#   RLT: 2
#
# Explored 1 nodes (1715 simplex iterations) in 2.71 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 687 685 646
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.870000000000e+02, best bound 6.870000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4x3

# %%
datafile="2x1000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x73c9221e
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 641.0000000
# Sparsify removed 979902 nonzeros (98%)
# Presolve added 0 rows and 190 columns
# Presolve removed 52 rows and 0 columns
# Presolve time: 2.46s
# Presolved: 2948 rows, 2190 columns, 15010 nonzeros
# Variable types: 198 continuous, 1992 integer (1992 binary)
#
# Root relaxation: objective 6.888758e+02, 1570 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  688.87576    0   43  641.00000  688.87576  7.47%     -    2s
# H    0     0                     687.0000000  688.87576  0.27%     -    2s
#      0     0  688.65025    0   39  687.00000  688.65025  0.24%     -    2s
#      0     0  688.44707    0   32  687.00000  688.44707  0.21%     -    2s
#      0     0  688.44707    0   33  687.00000  688.44707  0.21%     -    2s
#      0     0  688.43751    0   41  687.00000  688.43751  0.21%     -    2s
# H    0     0                     688.0000000  688.43751  0.06%     -    2s
#      0     0  688.00000    0   41  688.00000  688.00000  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 19
#   StrongCG: 1
#
# Explored 1 nodes (1781 simplex iterations) in 2.79 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 688 687 641
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.880000000000e+02, best bound 6.880000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4x4

# %%
datafile="2x1000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x2b781801
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 651.0000000
# Sparsify removed 985754 nonzeros (98%)
# Presolve added 0 rows and 198 columns
# Presolve removed 53 rows and 0 columns
# Presolve time: 2.48s
# Presolved: 2947 rows, 2198 columns, 15112 nonzeros
# Variable types: 200 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 6.880496e+02, 1555 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  688.04956    0   90  651.00000  688.04956  5.69%     -    2s
# H    0     0                     685.0000000  688.04956  0.45%     -    2s
#      0     0  687.94699    0   85  685.00000  687.94699  0.43%     -    2s
#      0     0  687.79559    0   76  685.00000  687.79559  0.41%     -    2s
#      0     0  687.79559    0   72  685.00000  687.79559  0.41%     -    2s
#      0     0  687.74980    0   54  685.00000  687.74980  0.40%     -    2s
# H    0     0                     686.0000000  687.74980  0.26%     -    2s
#      0     0  687.74646    0   45  686.00000  687.74646  0.25%     -    2s
#      0     0  687.74581    0   48  686.00000  687.74581  0.25%     -    2s
#      0     0  687.74536    0   48  686.00000  687.74536  0.25%     -    2s
#      0     0  687.74536    0   48  686.00000  687.74536  0.25%     -    2s
# H    0     0                     687.0000000  687.74536  0.11%     -    2s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 3
#   MIR: 49
#   StrongCG: 1
#   Mod-K: 2
#   RLT: 2
#
# Explored 1 nodes (2342 simplex iterations) in 2.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 687 686 685 651
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.870000000000e+02, best bound 6.870000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4x5

# %%
datafile="2x1000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xfa783978
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 648.0000000
# Sparsify removed 981882 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 43 rows and 0 columns
# Presolve time: 2.50s
# Presolved: 2957 rows, 2192 columns, 15032 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 6.943925e+02, 1592 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  694.39245    0   63  648.00000  694.39245  7.16%     -    2s
# H    0     0                     692.0000000  694.39245  0.35%     -    2s
#      0     0  694.36230    0   59  692.00000  694.36230  0.34%     -    2s
# H    0     0                     693.0000000  694.36230  0.20%     -    2s
#      0     0  694.32712    0   61  693.00000  694.32712  0.19%     -    2s
#      0     0  694.32692    0   65  693.00000  694.32692  0.19%     -    2s
#      0     0  694.32692    0   67  693.00000  694.32692  0.19%     -    2s
#      0     0  694.28696    0   54  693.00000  694.28696  0.19%     -    2s
#      0     0  694.25651    0   58  693.00000  694.25651  0.18%     -    2s
#      0     0  694.25651    0   54  693.00000  694.25651  0.18%     -    2s
#      0     0  694.19124    0   50  693.00000  694.19124  0.17%     -    2s
#      0     0  694.19124    0   43  693.00000  694.19124  0.17%     -    2s
#      0     0  694.19124    0   47  693.00000  694.19124  0.17%     -    3s
# H    0     0                     694.0000000  694.19124  0.03%     -    3s
#      0     0  694.00000    0   46  694.00000  694.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 13
#   Implied bound: 1
#   MIR: 38
#
# Explored 1 nodes (2019 simplex iterations) in 3.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 694 693 692 648
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.940000000000e+02, best bound 6.940000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4.5x1

# %%
datafile="2x1000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x9a8cda22
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 601.0000000
# Sparsify removed 985842 nonzeros (98%)
# Presolve added 0 rows and 196 columns
# Presolve removed 33 rows and 0 columns
# Presolve time: 2.49s
# Presolved: 2967 rows, 2196 columns, 15086 nonzeros
# Variable types: 198 continuous, 1998 integer (1998 binary)
#
# Root relaxation: objective 6.484589e+02, 1788 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  648.45894    0   39  601.00000  648.45894  7.90%     -    2s
# H    0     0                     645.0000000  648.45894  0.54%     -    2s
# H    0     0                     647.0000000  648.45894  0.23%     -    2s
#      0     0  648.43015    0   37  647.00000  648.43015  0.22%     -    2s
#      0     0  648.31079    0   28  647.00000  648.31079  0.20%     -    2s
#      0     0  648.30469    0   11  647.00000  648.30469  0.20%     -    2s
# H    0     0                     648.0000000  648.30469  0.05%     -    2s
#      0     0  648.30469    0   11  648.00000  648.30469  0.05%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 3
#   MIR: 8
#   RLT: 1
#
# Explored 1 nodes (2036 simplex iterations) in 2.81 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 648 647 645 601
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.480000000000e+02, best bound 6.480000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4.5x2

# %%
datafile="2x1000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x3990448f
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 605.0000000
# Sparsify removed 983862 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 24 rows and 0 columns
# Presolve time: 2.47s
# Presolved: 2976 rows, 2194 columns, 15090 nonzeros
# Variable types: 198 continuous, 1996 integer (1996 binary)
#
# Root relaxation: objective 6.477342e+02, 1902 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  647.73421    0   51  605.00000  647.73421  7.06%     -    2s
# H    0     0                     645.0000000  647.73421  0.42%     -    2s
# H    0     0                     646.0000000  647.73421  0.27%     -    2s
#      0     0  647.58073    0   50  646.00000  647.58073  0.24%     -    2s
# H    0     0                     647.0000000  647.58073  0.09%     -    2s
#      0     0  647.58073    0   50  647.00000  647.58073  0.09%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 15
#   RLT: 3
#
# Explored 1 nodes (2078 simplex iterations) in 2.73 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 647 646 645 605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.470000000000e+02, best bound 6.470000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4.5x3

# %%
datafile="2x1000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x67d01085
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 606.0000000
# Sparsify removed 981818 nonzeros (98%)
# Presolve added 0 rows and 192 columns
# Presolve removed 29 rows and 0 columns
# Presolve time: 2.87s
# Presolved: 2971 rows, 2192 columns, 15144 nonzeros
# Variable types: 198 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 6.492880e+02, 1578 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  649.28799    0   69  606.00000  649.28799  7.14%     -    3s
# H    0     0                     647.0000000  649.28799  0.35%     -    3s
# H    0     0                     648.0000000  649.28799  0.20%     -    3s
#      0     0  649.06537    0   81  648.00000  649.06537  0.16%     -    3s
#      0     0 infeasible    0       648.00000  648.00000  0.00%     -    3s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 1
#   Implied bound: 6
#   Clique: 2
#   MIR: 27
#   RLT: 1
#
# Explored 1 nodes (2010 simplex iterations) in 3.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 648 647 606
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.480000000000e+02, best bound 6.480000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4.5x4

# %%
datafile="2x1000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x3224f752
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 606.0000000
# Sparsify removed 977922 nonzeros (98%)
# Presolve added 0 rows and 188 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 2.88s
# Presolved: 2959 rows, 2188 columns, 15028 nonzeros
# Variable types: 198 continuous, 1990 integer (1990 binary)
#
# Root relaxation: objective 6.514156e+02, 1498 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  651.41557    0   29  606.00000  651.41557  7.49%     -    3s
# H    0     0                     649.0000000  651.41557  0.37%     -    3s
#      0     0  651.38448    0   34  649.00000  651.38448  0.37%     -    3s
# H    0     0                     650.0000000  651.38448  0.21%     -    3s
#      0     0  651.38303    0   30  650.00000  651.38303  0.21%     -    3s
#      0     0  651.27418    0   24  650.00000  651.27418  0.20%     -    3s
#      0     0  651.27418    0   24  650.00000  651.27418  0.20%     -    3s
#      0     0  651.27319    0   14  650.00000  651.27319  0.20%     -    3s
#      0     0  651.27319    0   14  650.00000  651.27319  0.20%     -    3s
#      0     0  651.27319    0   18  650.00000  651.27319  0.20%     -    3s
#      0     0  651.27319    0   18  650.00000  651.27319  0.20%     -    3s
#      0     0  651.27319    0    8  650.00000  651.27319  0.20%     -    3s
# H    0     0                     651.0000000  651.27319  0.04%     -    3s
#      0     0  651.27319    0    8  651.00000  651.27319  0.04%     -    3s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 1
#   MIR: 12
#   StrongCG: 2
#
# Explored 1 nodes (1769 simplex iterations) in 3.44 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 651 650 649 606
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.510000000000e+02, best bound 6.510000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x4.5x5

# %%
datafile="2x1000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x4d6071d2
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 603.0000000
# Sparsify removed 979890 nonzeros (98%)
# Presolve added 0 rows and 190 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 2.48s
# Presolved: 2962 rows, 2190 columns, 15012 nonzeros
# Variable types: 198 continuous, 1992 integer (1992 binary)
#
# Root relaxation: objective 6.468925e+02, 1869 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  646.89249    0   42  603.00000  646.89249  7.28%     -    2s
# H    0     0                     645.0000000  646.89249  0.29%     -    2s
#      0     0  646.78927    0   31  645.00000  646.78927  0.28%     -    2s
#      0     0  646.78927    0   33  645.00000  646.78927  0.28%     -    2s
#      0     0  646.67018    0   31  645.00000  646.67018  0.26%     -    2s
# H    0     0                     646.0000000  646.67018  0.10%     -    2s
#      0     0  646.67018    0   31  646.00000  646.67018  0.10%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   Implied bound: 1
#   MIR: 26
#   StrongCG: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (2113 simplex iterations) in 2.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 646 645 603
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.460000000000e+02, best bound 6.460000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x5x1

# %%
datafile="2x1000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0xc2050be5
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 566.0000000
# Sparsify removed 977844 nonzeros (98%)
# Presolve added 0 rows and 186 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 2.95s
# Presolved: 2959 rows, 2186 columns, 15104 nonzeros
# Variable types: 196 continuous, 1990 integer (1990 binary)
#
# Root relaxation: objective 6.113759e+02, 1690 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  611.37594    0   42  566.00000  611.37594  8.02%     -    3s
# H    0     0                     610.0000000  611.37594  0.23%     -    3s
#      0     0  611.35611    0   47  610.00000  611.35611  0.22%     -    3s
#      0     0  611.31269    0   38  610.00000  611.31269  0.22%     -    3s
#      0     0  611.30564    0   36  610.00000  611.30564  0.21%     -    3s
#      0     0  611.28110    0   32  610.00000  611.28110  0.21%     -    3s
#      0     0  611.28110    0   32  610.00000  611.28110  0.21%     -    3s
#      0     0  611.28110    0   30  610.00000  611.28110  0.21%     -    3s
# H    0     0                     611.0000000  611.28110  0.05%     -    3s
#      0     0  611.28110    0   30  611.00000  611.28110  0.05%     -    3s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   MIR: 23
#   StrongCG: 3
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (1933 simplex iterations) in 3.40 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 611 610 566
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.110000000000e+02, best bound 6.110000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x5x2

# %%
datafile="2x1000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x4091c9c4
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 560.0000000
# Sparsify removed 964116 nonzeros (98%)
# Presolve added 0 rows and 172 columns
# Presolve removed 60 rows and 0 columns
# Presolve time: 2.45s
# Presolved: 2940 rows, 2172 columns, 14936 nonzeros
# Variable types: 196 continuous, 1976 integer (1976 binary)
#
# Root relaxation: objective 6.042989e+02, 1643 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  604.29894    0   14  560.00000  604.29894  7.91%     -    2s
# H    0     0                     603.0000000  604.29894  0.22%     -    2s
#      0     0  604.12774    0   12  603.00000  604.12774  0.19%     -    2s
#      0     0     cutoff    0       603.00000  603.00000  0.00%     -    2s
#
# Explored 1 nodes (2883 simplex iterations) in 2.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 603 560
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.030000000000e+02, best bound 6.030000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x5x3

# %%
datafile="2x1000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x6269b2e6
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 569.0000000
# Sparsify removed 975888 nonzeros (98%)
# Presolve added 0 rows and 184 columns
# Presolve removed 30 rows and 0 columns
# Presolve time: 2.88s
# Presolved: 2970 rows, 2184 columns, 15100 nonzeros
# Variable types: 196 continuous, 1988 integer (1988 binary)
#
# Root relaxation: objective 6.159728e+02, 1639 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  615.97283    0   32  569.00000  615.97283  8.26%     -    3s
# H    0     0                     613.0000000  615.97283  0.48%     -    3s
# H    0     0                     614.0000000  615.97283  0.32%     -    3s
# H    0     0                     615.0000000  615.97283  0.16%     -    3s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 8
#   Implied bound: 1
#   MIR: 34
#   GUB cover: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (1714 simplex iterations) in 3.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 615 614 613 569
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.150000000000e+02, best bound 6.150000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x5x4

# %%
datafile="2x1000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x2fb3fda3
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 569.0000000
# Sparsify removed 981844 nonzeros (98%)
# Presolve added 0 rows and 194 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 2.46s
# Presolved: 2963 rows, 2194 columns, 15088 nonzeros
# Variable types: 200 continuous, 1994 integer (1994 binary)
#
# Root relaxation: objective 6.121136e+02, 1747 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  612.11358    0   66  569.00000  612.11358  7.58%     -    2s
# H    0     0                     610.0000000  612.11358  0.35%     -    2s
#      0     0  612.04813    0   60  610.00000  612.04813  0.34%     -    2s
#      0     0  611.99837    0   55  610.00000  611.99837  0.33%     -    2s
#      0     0  611.99837    0   55  610.00000  611.99837  0.33%     -    2s
#      0     0  611.98978    0   49  610.00000  611.98978  0.33%     -    2s
# H    0     0                     611.0000000  611.98978  0.16%     -    2s
#      0     0  611.00000    0   53  611.00000  611.00000  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 2
#   Implied bound: 2
#   MIR: 32
#   StrongCG: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (2251 simplex iterations) in 2.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 611 610 569
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.110000000000e+02, best bound 6.110000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x1000x5x5

# %%
datafile="2x1000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 3000 rows, 2000 columns and 1003000 nonzeros
# Model fingerprint: 0x6b91d7fe
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 557.0000000
# Sparsify removed 975926 nonzeros (98%)
# Presolve added 0 rows and 186 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 2.87s
# Presolved: 2962 rows, 2186 columns, 15026 nonzeros
# Variable types: 198 continuous, 1988 integer (1988 binary)
#
# Root relaxation: objective 6.041227e+02, 1736 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  604.12275    0   47  557.00000  604.12275  8.46%     -    2s
# H    0     0                     602.0000000  604.12275  0.35%     -    3s
#      0     0  604.11616    0   66  602.00000  604.11616  0.35%     -    3s
# H    0     0                     603.0000000  604.11616  0.19%     -    3s
#      0     0  604.09402    0   64  603.00000  604.09402  0.18%     -    3s
#      0     0  604.09391    0   60  603.00000  604.09391  0.18%     -    3s
#      0     0  604.00648    0   35  603.00000  604.00648  0.17%     -    3s
#
# Cutting planes:
#   Gomory: 27
#   Cover: 3
#   Implied bound: 1
#   MIR: 78
#   StrongCG: 3
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (2023 simplex iterations) in 3.20 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 603 602 557
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.030000000000e+02, best bound 6.030000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x1.5x1

# %%
datafile="3x1000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x68e1e2a8
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1000.0000000
# Sparsify removed 1417908 nonzeros (94%)
# Presolve added 0 rows and 236 columns
# Presolve removed 135 rows and 0 columns
# Presolve time: 4.30s
# Presolved: 3865 rows, 3236 columns, 86007 nonzeros
# Variable types: 236 continuous, 3000 integer (3000 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 4.40 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x1.5x2

# %%
datafile="3x1000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x73d33497
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1000.0000000
# Sparsify removed 1415215 nonzeros (94%)
# Presolve added 0 rows and 235 columns
# Presolve removed 96 rows and 0 columns
# Presolve time: 4.30s
# Presolved: 3904 rows, 3235 columns, 88940 nonzeros
# Variable types: 235 continuous, 3000 integer (3000 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 4.40 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x1.5x3

# %%
datafile="3x1000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x286b575e
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 998.0000000
# Sparsify removed 1418591 nonzeros (95%)
# Presolve added 0 rows and 233 columns
# Presolve removed 200 rows and 0 columns
# Presolve time: 3.75s
# Presolved: 3800 rows, 3233 columns, 79084 nonzeros
# Variable types: 239 continuous, 2994 integer (2994 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 3.85 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.980000000000e+02, best bound 9.980000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x1.5x4

# %%
datafile="3x1000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x0353eadf
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 999.0000000
# Sparsify removed 1424625 nonzeros (95%)
# Presolve added 0 rows and 237 columns
# Presolve removed 151 rows and 0 columns
# Presolve time: 3.76s
# Presolved: 3849 rows, 3237 columns, 76227 nonzeros
# Variable types: 240 continuous, 2997 integer (2997 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 3.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990000000000e+02, best bound 9.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x1.5x5

# %%
datafile="3x1000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x3227f613
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 999.0000000
# Sparsify removed 1417449 nonzeros (94%)
# Presolve added 0 rows and 234 columns
# Presolve removed 124 rows and 0 columns
# Presolve time: 3.73s
# Presolved: 3876 rows, 3234 columns, 83547 nonzeros
# Variable types: 237 continuous, 2997 integer (2997 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 3.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990000000000e+02, best bound 9.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2x1

# %%
datafile="3x1000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xeee753f7
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 998.0000000
# Sparsify removed 1420575 nonzeros (94%)
# Presolve added 0 rows and 237 columns
# Presolve removed 99 rows and 0 columns
# Presolve time: 4.94s
# Presolved: 3901 rows, 3237 columns, 83571 nonzeros
# Variable types: 237 continuous, 3000 integer (3000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+03   2.416769e+04   0.000000e+00      5s
#     1422    9.9996790e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 9.999679e+02, 1422 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  999.96790    0   55  998.00000  999.96790  0.20%     -    5s
#      0     0  999.96790    0   54  998.00000  999.96790  0.20%     -    5s
#      0     0  999.93307    0   51  998.00000  999.93307  0.19%     -    5s
#      0     0  999.90137    0   50  998.00000  999.90137  0.19%     -    5s
#      0     0  999.90137    0   38  998.00000  999.90137  0.19%     -    5s
#      0     0  999.90137    0   40  998.00000  999.90137  0.19%     -    5s
#      0     0  999.90137    0   32  998.00000  999.90137  0.19%     -    6s
#      0     0  999.90137    0   36  998.00000  999.90137  0.19%     -    6s
# H    0     0                     999.0000000  999.90137  0.09%     -    6s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 103
#   StrongCG: 1
#
# Explored 1 nodes (4541 simplex iterations) in 6.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 999 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990000000000e+02, best bound 9.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2x2

# %%
datafile="3x1000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x7331250b
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 989.0000000
# Sparsify removed 1422117 nonzeros (95%)
# Presolve added 0 rows and 236 columns
# Presolve removed 91 rows and 0 columns
# Presolve time: 3.74s
# Presolved: 3909 rows, 3236 columns, 79146 nonzeros
# Variable types: 239 continuous, 2997 integer (2997 binary)
#
# Root relaxation: objective 9.923219e+02, 1496 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  992.32190    0   40  989.00000  992.32190  0.34%     -    3s
# H    0     0                     990.0000000  992.32190  0.23%     -    4s
#      0     0  992.15780    0   44  990.00000  992.15780  0.22%     -    4s
# H    0     0                     991.0000000  992.15780  0.12%     -    4s
#      0     0  992.13595    0   45  991.00000  992.13595  0.11%     -    4s
#      0     0  992.13592    0   40  991.00000  992.13592  0.11%     -    4s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 5
#   Implied bound: 3
#   MIR: 59
#   StrongCG: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (3144 simplex iterations) in 4.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 991 990 989
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.910000000000e+02, best bound 9.910000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2x3

# %%
datafile="3x1000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x1b38786e
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 979.0000000
# Sparsify removed 1415215 nonzeros (94%)
# Presolve added 0 rows and 235 columns
# Presolve removed 48 rows and 0 columns
# Presolve time: 4.31s
# Presolved: 3952 rows, 3235 columns, 89132 nonzeros
# Variable types: 235 continuous, 3000 integer (3000 binary)
#
# Root relaxation: objective 9.859738e+02, 1531 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  985.97382    0   91  979.00000  985.97382  0.71%     -    4s
# H    0     0                     982.0000000  985.97382  0.40%     -    4s
# H    0     0                     983.0000000  985.97382  0.30%     -    4s
# H    0     0                     984.0000000  985.97382  0.20%     -    4s
#      0     0  985.66880    0   97  984.00000  985.66880  0.17%     -    4s
#      0     0  985.66880    0   90  984.00000  985.66880  0.17%     -    4s
#      0     0  985.66880    0   87  984.00000  985.66880  0.17%     -    5s
#      0     0  985.66880    0   71  984.00000  985.66880  0.17%     -    5s
#      0     0  985.66880    0   73  984.00000  985.66880  0.17%     -    5s
# H    0     0                     985.0000000  985.66880  0.07%     -    5s
#
# Cutting planes:
#   Gomory: 38
#   Cover: 5
#   Implied bound: 1
#   MIR: 98
#   StrongCG: 1
#   RLT: 4
#   Relax-and-lift: 4
#
# Explored 1 nodes (2702 simplex iterations) in 5.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 985 984 983 ... 979
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.850000000000e+02, best bound 9.850000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2x4

# %%
datafile="3x1000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xc4122d21
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 977.0000000
# Sparsify removed 1424262 nonzeros (95%)
# Presolve added 0 rows and 234 columns
# Presolve removed 87 rows and 0 columns
# Presolve time: 3.74s
# Presolved: 3913 rows, 3234 columns, 71010 nonzeros
# Variable types: 243 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 9.825989e+02, 1539 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  982.59889    0   76  977.00000  982.59889  0.57%     -    3s
# H    0     0                     979.0000000  982.59889  0.37%     -    4s
#      0     0  982.47612    0   61  979.00000  982.47612  0.36%     -    4s
# H    0     0                     980.0000000  982.47612  0.25%     -    4s
# H    0     0                     981.0000000  982.47612  0.15%     -    4s
#      0     0  982.15496    0   52  981.00000  982.15496  0.12%     -    4s
#      0     0  982.15496    0   54  981.00000  982.15496  0.12%     -    4s
#      0     0  982.11734    0   33  981.00000  982.11734  0.11%     -    4s
#      0     0  982.11734    0   37  981.00000  982.11734  0.11%     -    4s
#      0     0  982.11024    0   50  981.00000  982.11024  0.11%     -    4s
#      0     0  982.11024    0   53  981.00000  982.11024  0.11%     -    4s
#      0     0  982.10845    0   44  981.00000  982.10845  0.11%     -    4s
#      0     0  982.10731    0   43  981.00000  982.10731  0.11%     -    4s
#      0     0  982.10314    0   42  981.00000  982.10314  0.11%     -    4s
#      0     0  982.10144    0   41  981.00000  982.10144  0.11%     -    4s
#      0     0  982.10103    0   41  981.00000  982.10103  0.11%     -    4s
#      0     0  982.06316    0   35  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   27  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   30  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   35  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   38  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   36  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   18  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   22  981.00000  982.06316  0.11%     -    5s
#      0     0  982.06316    0   15  981.00000  982.06316  0.11%     -    6s
#      0     0  982.06316    0   25  981.00000  982.06316  0.11%     -    6s
#      0     0  982.06316    0   15  981.00000  982.06316  0.11%     -    6s
#      0     0  982.06316    0   20  981.00000  982.06316  0.11%     -    6s
#      0     0  982.06316    0   16  981.00000  982.06316  0.11%     -    6s
#      0     0  982.06316    0   15  981.00000  982.06316  0.11%     -    6s
#      0     2  982.06316    0   14  981.00000  982.06316  0.11%     -    7s
#   1963  1765  982.02762   95   38  981.00000  982.05898  0.11%   4.3   10s
#   1981  1777  982.00000   81   16  981.00000  982.00000  0.10%   4.2   15s
#   1998  1789  982.00000   27   16  981.00000  982.00000  0.10%  10.0   20s
# H 2407  2180                     982.0000001  982.00000  0.00%  14.7   23s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 1
#   MIR: 1
#   Flow cover: 7
#
# Explored 2642 nodes (45205 simplex iterations) in 23.84 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 982 981 980 ... 977
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.820000000445e+02, best bound 9.820000000445e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2x5

# %%
datafile="3x1000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x44621eb9
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 994.0000000
# Sparsify removed 1418591 nonzeros (95%)
# Presolve added 0 rows and 233 columns
# Presolve removed 77 rows and 0 columns
# Presolve time: 3.76s
# Presolved: 3923 rows, 3233 columns, 79723 nonzeros
# Variable types: 239 continuous, 2994 integer (2994 binary)
#
# Root relaxation: objective 9.959841e+02, 1392 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  995.98410    0   25  994.00000  995.98410  0.20%     -    3s
#      0     0  995.90489    0   23  994.00000  995.90489  0.19%     -    4s
# H    0     0                     995.0000000  995.90489  0.09%     -    4s
#      0     0  995.90489    0   23  995.00000  995.90489  0.09%     -    4s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   MIR: 7
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (2751 simplex iterations) in 4.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 995 994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.950000000000e+02, best bound 9.950000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2.5x1

# %%
datafile="3x1000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xa5466dac
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 871.0000000
# Sparsify removed 1420019 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 72 rows and 0 columns
# Presolve time: 4.39s
# Presolved: 3928 rows, 3232 columns, 75325 nonzeros
# Variable types: 241 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 8.907358e+02, 2014 iterations, 0.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  890.73584    0   57  871.00000  890.73584  2.27%     -    4s
# H    0     0                     888.0000000  890.73584  0.31%     -    4s
# H    0     0                     889.0000000  890.73584  0.20%     -    4s
# H    0     0                     890.0000000  890.73584  0.08%     -    4s
#
# Cutting planes:
#   Gomory: 26
#   Implied bound: 3
#   MIR: 56
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (3186 simplex iterations) in 4.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 890 889 888 871
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.900000000000e+02, best bound 8.900000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2.5x2

# %%
datafile="3x1000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x8534bcd8
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 863.0000000
# Sparsify removed 1425307 nonzeros (95%)
# Presolve added 0 rows and 233 columns
# Presolve removed 79 rows and 0 columns
# Presolve time: 3.75s
# Presolved: 3921 rows, 3233 columns, 67013 nonzeros
# Variable types: 245 continuous, 2988 integer (2988 binary)
#
# Root relaxation: objective 8.871272e+02, 1931 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  887.12718    0  130  863.00000  887.12718  2.80%     -    4s
# H    0     0                     884.0000000  887.12718  0.35%     -    4s
# H    0     0                     885.0000000  887.12718  0.24%     -    4s
# H    0     0                     886.0000000  887.12718  0.13%     -    4s
#      0     0  887.10699    0  129  886.00000  887.10699  0.12%     -    4s
#      0     0  887.08063    0  119  886.00000  887.08063  0.12%     -    4s
#      0     0  887.08048    0  123  886.00000  887.08048  0.12%     -    4s
#      0     0  887.08048    0  130  886.00000  887.08048  0.12%     -    4s
#      0     0  887.07444    0  116  886.00000  887.07444  0.12%     -    4s
#      0     0  887.05735    0  112  886.00000  887.05735  0.12%     -    4s
#      0     0  887.05699    0  106  886.00000  887.05699  0.12%     -    4s
#      0     0  887.05694    0  109  886.00000  887.05694  0.12%     -    4s
#      0     0  887.05418    0  108  886.00000  887.05418  0.12%     -    4s
#      0     0  887.02063    0  103  886.00000  887.02063  0.12%     -    5s
#      0     0  887.01957    0   88  886.00000  887.01957  0.12%     -    5s
#      0     0  887.01951    0   88  886.00000  887.01951  0.12%     -    5s
#      0     0     cutoff    0       886.00000  886.00000  0.00%     -    5s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 7
#   Implied bound: 2
#   MIR: 111
#   StrongCG: 1
#   RLT: 3
#
# Explored 1 nodes (6091 simplex iterations) in 5.31 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 886 885 884 863
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.860000000000e+02, best bound 8.860000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2.5x3

# %%
datafile="3x1000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x0d864de7
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 865.0000000
# Sparsify removed 1423056 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 73 rows and 0 columns
# Presolve time: 4.41s
# Presolved: 3927 rows, 3232 columns, 69306 nonzeros
# Variable types: 244 continuous, 2988 integer (2988 binary)
#
# Root relaxation: objective 8.855340e+02, 1911 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  885.53396    0   61  865.00000  885.53396  2.37%     -    4s
# H    0     0                     881.0000000  885.53396  0.51%     -    4s
# H    0     0                     883.0000000  885.53396  0.29%     -    4s
#      0     0  885.37936    0   89  883.00000  885.37936  0.27%     -    4s
# H    0     0                     884.0000000  885.37936  0.16%     -    5s
#      0     0  885.37932    0   92  884.00000  885.37932  0.16%     -    5s
#      0     0  885.35550    0   60  884.00000  885.35550  0.15%     -    5s
#      0     0  885.35549    0   68  884.00000  885.35549  0.15%     -    5s
#      0     0  885.35536    0   72  884.00000  885.35536  0.15%     -    5s
#      0     0  885.35458    0   57  884.00000  885.35458  0.15%     -    5s
#      0     0  885.35458    0   56  884.00000  885.35458  0.15%     -    5s
# H    0     0                     885.0000000  885.35458  0.04%     -    5s
#
# Cutting planes:
#   Gomory: 8
#   Implied bound: 1
#   MIR: 107
#   StrongCG: 2
#
# Explored 1 nodes (3475 simplex iterations) in 5.85 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 885 884 883 ... 865
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.850000000000e+02, best bound 8.850000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2.5x4

# %%
datafile="3x1000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xed6eb51c
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 869.0000000
# Sparsify removed 1424262 nonzeros (95%)
# Presolve added 0 rows and 234 columns
# Presolve removed 48 rows and 0 columns
# Presolve time: 3.76s
# Presolved: 3952 rows, 3234 columns, 71151 nonzeros
# Variable types: 243 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 8.871031e+02, 1827 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  887.10313    0  159  869.00000  887.10313  2.08%     -    4s
# H    0     0                     883.0000000  887.10313  0.46%     -    4s
# H    0     0                     884.0000000  887.10313  0.35%     -    4s
# H    0     0                     885.0000000  887.10313  0.24%     -    4s
#      0     0  886.87055    0  166  885.00000  886.87055  0.21%     -    4s
#      0     0  886.65532    0  173  885.00000  886.65532  0.19%     -    4s
#      0     0  886.65305    0  162  885.00000  886.65305  0.19%     -    4s
#      0     0  886.65268    0  171  885.00000  886.65268  0.19%     -    4s
#      0     0  886.62505    0  118  885.00000  886.62505  0.18%     -    4s
#      0     0  886.62363    0  118  885.00000  886.62363  0.18%     -    4s
#      0     0  886.62346    0  118  885.00000  886.62346  0.18%     -    4s
#      0     0  886.62342    0  121  885.00000  886.62342  0.18%     -    4s
#      0     0  886.62136    0  118  885.00000  886.62136  0.18%     -    4s
#      0     0  886.62093    0  102  885.00000  886.62093  0.18%     -    5s
#      0     0  886.62019    0  102  885.00000  886.62019  0.18%     -    5s
#      0     0  886.62016    0  104  885.00000  886.62016  0.18%     -    5s
#      0     0  886.62005    0   98  885.00000  886.62005  0.18%     -    5s
# H    0     0                     886.0000000  886.62005  0.07%     -    5s
#      0     0  886.03784    0  103  886.00000  886.03784  0.00%     -    5s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 8
#   MIR: 73
#   StrongCG: 1
#   RLT: 1
#
# Explored 1 nodes (5550 simplex iterations) in 5.37 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 886 885 884 ... 869
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.860000000000e+02, best bound 8.860000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x2.5x5

# %%
datafile="3x1000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x768fe1e0
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 868.0000000
# Sparsify removed 1418591 nonzeros (95%)
# Presolve added 0 rows and 233 columns
# Presolve removed 62 rows and 0 columns
# Presolve time: 3.73s
# Presolved: 3938 rows, 3233 columns, 79741 nonzeros
# Variable types: 239 continuous, 2994 integer (2994 binary)
#
# Root relaxation: objective 8.891195e+02, 1932 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  889.11951    0   65  868.00000  889.11951  2.43%     -    4s
# H    0     0                     885.0000000  889.11951  0.47%     -    4s
# H    0     0                     887.0000000  889.11951  0.24%     -    4s
#      0     0  888.81836    0   69  887.00000  888.81836  0.21%     -    4s
# H    0     0                     888.0000000  888.81836  0.09%     -    4s
#      0     0  888.81836    0   69  888.00000  888.81836  0.09%     -    4s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 2
#   Implied bound: 1
#   MIR: 16
#   RLT: 3
#
# Explored 1 nodes (3632 simplex iterations) in 4.35 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 888 887 885 868
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.880000000000e+02, best bound 8.880000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3x1

# %%
datafile="3x1000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x0eb2f123
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 781.0000000
# Sparsify removed 1424094 nonzeros (96%)
# Presolve added 0 rows and 231 columns
# Presolve removed 62 rows and 0 columns
# Presolve time: 4.37s
# Presolved: 3938 rows, 3231 columns, 65313 nonzeros
# Variable types: 246 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 8.069996e+02, 2169 iterations, 0.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.99957    0  155  781.00000  806.99957  3.33%     -    4s
# H    0     0                     802.0000000  806.99957  0.62%     -    4s
# H    0     0                     804.0000000  806.99957  0.37%     -    4s
#      0     0  806.97863    0  167  804.00000  806.97863  0.37%     -    4s
# H    0     0                     805.0000000  806.97863  0.25%     -    5s
#      0     0  806.81171    0  154  805.00000  806.81171  0.23%     -    5s
#      0     0  806.81171    0  156  805.00000  806.81171  0.23%     -    5s
# H    0     0                     806.0000000  806.81171  0.10%     -    5s
#
# Cutting planes:
#   Gomory: 65
#   Cover: 5
#   Implied bound: 1
#   Clique: 1
#   MIR: 131
#   StrongCG: 3
#   RLT: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (4769 simplex iterations) in 5.28 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 806 805 804 ... 781
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.060000000000e+02, best bound 8.060000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3x2

# %%
datafile="3x1000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x089b404b
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 779.0000000
# Sparsify removed 1420019 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 45 rows and 0 columns
# Presolve time: 3.73s
# Presolved: 3955 rows, 3232 columns, 75394 nonzeros
# Variable types: 241 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 8.064405e+02, 2334 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.44053    0   69  779.00000  806.44053  3.52%     -    4s
# H    0     0                     805.0000000  806.44053  0.18%     -    4s
#      0     0  806.43079    0   65  805.00000  806.43079  0.18%     -    4s
#      0     0  806.41510    0   61  805.00000  806.41510  0.18%     -    4s
#      0     0  806.41510    0   59  805.00000  806.41510  0.18%     -    4s
#      0     0  806.41468    0   69  805.00000  806.41468  0.18%     -    4s
#      0     0  806.34467    0   66  805.00000  806.34467  0.17%     -    4s
#      0     0  806.34444    0   68  805.00000  806.34444  0.17%     -    4s
#      0     0  806.34444    0   67  805.00000  806.34444  0.17%     -    4s
#      0     0  806.34379    0   58  805.00000  806.34379  0.17%     -    5s
#      0     0  806.34359    0   59  805.00000  806.34359  0.17%     -    5s
#      0     0  806.34359    0   51  805.00000  806.34359  0.17%     -    5s
#      0     0  806.33980    0   47  805.00000  806.33980  0.17%     -    5s
#      0     0  806.33980    0   48  805.00000  806.33980  0.17%     -    5s
#      0     0  806.33967    0   50  805.00000  806.33967  0.17%     -    5s
#      0     0  806.33967    0   50  805.00000  806.33967  0.17%     -    5s
#      0     0  806.33800    0   51  805.00000  806.33800  0.17%     -    5s
#      0     0  806.33416    0   55  805.00000  806.33416  0.17%     -    5s
#      0     0  806.32529    0   61  805.00000  806.32529  0.16%     -    5s
#      0     0  806.32529    0   64  805.00000  806.32529  0.16%     -    5s
#      0     0  806.32529    0   61  805.00000  806.32529  0.16%     -    5s
#      0     0  806.32529    0   56  805.00000  806.32529  0.16%     -    5s
# H    0     0                     806.0000000  806.32529  0.04%     -    6s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 84
#
# Explored 1 nodes (4252 simplex iterations) in 6.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 806 805 779
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.060000000000e+02, best bound 8.060000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3x3

# %%
datafile="3x1000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x8afea439
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 773.0000000
# Sparsify removed 1423056 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 5.02s
# Presolved: 3963 rows, 3232 columns, 69387 nonzeros
# Variable types: 244 continuous, 2988 integer (2988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9600000e+02   2.171723e+04   0.000000e+00      5s
#     2097    8.0561473e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.056147e+02, 2097 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  805.61473    0  141  773.00000  805.61473  4.22%     -    5s
# H    0     0                     801.0000000  805.61473  0.58%     -    5s
# H    0     0                     803.0000000  805.61473  0.33%     -    5s
#      0     0  805.41988    0  130  803.00000  805.41988  0.30%     -    5s
# H    0     0                     804.0000000  805.41988  0.18%     -    5s
#      0     0  805.36424    0  117  804.00000  805.36424  0.17%     -    5s
#      0     0  805.36424    0  112  804.00000  805.36424  0.17%     -    5s
#      0     0  805.16096    0   89  804.00000  805.16096  0.14%     -    5s
#      0     0  805.16085    0   86  804.00000  805.16085  0.14%     -    5s
#      0     0  805.15703    0   82  804.00000  805.15703  0.14%     -    6s
#      0     0  805.15703    0   82  804.00000  805.15703  0.14%     -    6s
#      0     0  805.15703    0   90  804.00000  805.15703  0.14%     -    6s
#      0     0  805.15703    0   87  804.00000  805.15703  0.14%     -    6s
#      0     0  805.15687    0   59  804.00000  805.15687  0.14%     -    6s
#      0     0  805.15670    0   63  804.00000  805.15670  0.14%     -    6s
#      0     0  805.15670    0   63  804.00000  805.15670  0.14%     -    6s
#      0     0  805.15445    0   76  804.00000  805.15445  0.14%     -    7s
#      0     0  805.15437    0   88  804.00000  805.15437  0.14%     -    7s
#      0     0  805.15412    0   71  804.00000  805.15412  0.14%     -    7s
#      0     0  805.15412    0   77  804.00000  805.15412  0.14%     -    7s
#      0     0  805.15412    0   83  804.00000  805.15412  0.14%     -    7s
#      0     0  805.15412    0   56  804.00000  805.15412  0.14%     -    7s
#      0     2  805.15412    0   56  804.00000  805.15412  0.14%     -    7s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 9
#   Implied bound: 2
#   MIR: 97
#   GUB cover: 2
#
# Explored 154 nodes (11164 simplex iterations) in 8.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 804 803 801 773
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.040000000000e+02, best bound 8.040000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3x4

# %%
datafile="3x1000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x92bb6f94
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 769.0000000
# Sparsify removed 1433809 nonzeros (96%)
# Presolve removed 41 rows and 2722 columns (presolve time = 5s) ...
# Presolve added 0 rows and 236 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 5.09s
# Presolved: 3959 rows, 3236 columns, 55649 nonzeros
# Variable types: 251 continuous, 2985 integer (2985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   1.590596e+04   0.000000e+00      5s
#     3203    8.0285452e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.028545e+02, 3203 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  802.85452    0   94  769.00000  802.85452  4.40%     -    5s
# H    0     0                     799.0000000  802.85452  0.48%     -    5s
# H    0     0                     800.0000000  802.85452  0.36%     -    5s
#      0     0  802.46780    0   91  800.00000  802.46780  0.31%     -    5s
# H    0     0                     801.0000000  802.46780  0.18%     -    5s
#      0     0  802.46171    0   84  801.00000  802.46171  0.18%     -    5s
#      0     0  802.46171    0   85  801.00000  802.46171  0.18%     -    5s
#      0     0  802.22806    0   73  801.00000  802.22806  0.15%     -    5s
#      0     0  802.22806    0   82  801.00000  802.22806  0.15%     -    6s
#      0     0  802.20570    0   77  801.00000  802.20570  0.15%     -    6s
#      0     0  802.20548    0   65  801.00000  802.20548  0.15%     -    6s
#      0     0  802.20533    0   73  801.00000  802.20533  0.15%     -    6s
#      0     0  802.20533    0   77  801.00000  802.20533  0.15%     -    6s
#      0     0  802.17862    0   73  801.00000  802.17862  0.15%     -    6s
#      0     0  802.17862    0   81  801.00000  802.17862  0.15%     -    6s
#      0     0  802.17784    0   63  801.00000  802.17784  0.15%     -    6s
#      0     0  802.17784    0   48  801.00000  802.17784  0.15%     -    6s
#      0     0  802.17784    0   68  801.00000  802.17784  0.15%     -    6s
#      0     0  802.17784    0   58  801.00000  802.17784  0.15%     -    6s
#      0     0  802.15800    0   59  801.00000  802.15800  0.14%     -    7s
#      0     0  802.15800    0   54  801.00000  802.15800  0.14%     -    7s
#      0     0  802.09899    0   54  801.00000  802.09899  0.14%     -    7s
#      0     0  802.09899    0   49  801.00000  802.09899  0.14%     -    7s
#      0     0  802.09899    0   65  801.00000  802.09899  0.14%     -    7s
#      0     0  802.09899    0   66  801.00000  802.09899  0.14%     -    7s
#      0     0  802.09899    0   58  801.00000  802.09899  0.14%     -    7s
#      0     0  802.09899    0   58  801.00000  802.09899  0.14%     -    7s
#      0     2  802.09899    0   55  801.00000  802.09899  0.14%     -    7s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 11
#   MIR: 67
#   StrongCG: 6
#   GUB cover: 2
#   RLT: 1
#
# Explored 11 nodes (7199 simplex iterations) in 8.00 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 801 800 799 769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.010000000000e+02, best bound 8.010000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3x5

# %%
datafile="3x1000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x8626806a
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 770.0000000
# Sparsify removed 1434710 nonzeros (96%)
# Presolve added 0 rows and 242 columns
# Presolve removed 66 rows and 0 columns
# Presolve time: 3.76s
# Presolved: 3934 rows, 3242 columns, 60649 nonzeros
# Variable types: 251 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 8.069323e+02, 2888 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.93228    0   46  770.00000  806.93228  4.80%     -    4s
# H    0     0                     805.0000000  806.93228  0.24%     -    4s
#      0     0  806.84181    0   50  805.00000  806.84181  0.23%     -    4s
# H    0     0                     806.0000000  806.84181  0.10%     -    4s
#      0     0  806.84181    0   50  806.00000  806.84181  0.10%     -    4s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 6
#   Implied bound: 1
#   MIR: 9
#   StrongCG: 6
#   GUB cover: 2
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (3900 simplex iterations) in 4.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 806 805 770
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.060000000000e+02, best bound 8.060000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3.5x1

# %%
datafile="3x1000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x0de63e2d
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 701.0000000
# Sparsify removed 1422117 nonzeros (95%)
# Presolve added 0 rows and 236 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 3.73s
# Presolved: 3975 rows, 3236 columns, 79332 nonzeros
# Variable types: 239 continuous, 2997 integer (2997 binary)
#
# Root relaxation: objective 7.370387e+02, 2065 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  737.03872    0  130  701.00000  737.03872  5.14%     -    4s
# H    0     0                     733.0000000  737.03872  0.55%     -    4s
# H    0     0                     734.0000000  737.03872  0.41%     -    4s
# H    0     0                     735.0000000  737.03872  0.28%     -    4s
#      0     0  736.86399    0  133  735.00000  736.86399  0.25%     -    4s
# H    0     0                     736.0000000  736.86399  0.12%     -    4s
#      0     0  736.86399    0  133  736.00000  736.86399  0.12%     -    4s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 5
#   Implied bound: 1
#   MIR: 47
#   StrongCG: 12
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (4187 simplex iterations) in 4.45 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 736 735 734 ... 701
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.360000000000e+02, best bound 7.360000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3.5x2

# %%
datafile="3x1000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x9696eb78
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 711.0000000
# Sparsify removed 1426212 nonzeros (96%)
# Presolve added 0 rows and 232 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 3.78s
# Presolved: 3965 rows, 3232 columns, 63279 nonzeros
# Variable types: 247 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 7.449560e+02, 3071 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  744.95596    0   93  711.00000  744.95596  4.78%     -    4s
# H    0     0                     741.0000000  744.95596  0.53%     -    4s
# H    0     0                     743.0000000  744.95596  0.26%     -    4s
#      0     0  744.87624    0   77  743.00000  744.87624  0.25%     -    4s
# H    0     0                     744.0000000  744.87624  0.12%     -    4s
#      0     0  744.87624    0   77  744.00000  744.87624  0.12%     -    4s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 1
#   Implied bound: 2
#   MIR: 21
#   RLT: 1
#
# Explored 1 nodes (5340 simplex iterations) in 4.46 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 744 743 741 711
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.440000000000e+02, best bound 7.440000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3.5x3

# %%
datafile="3x1000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x85a65d97
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 707.0000000
# Sparsify removed 1437642 nonzeros (97%)
# Presolve added 0 rows and 236 columns
# Presolve removed 53 rows and 0 columns
# Presolve time: 3.83s
# Presolved: 3947 rows, 3236 columns, 42876 nonzeros
# Variable types: 260 continuous, 2976 integer (2976 binary)
#
# Root relaxation: objective 7.431976e+02, 2906 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  743.19758    0   52  707.00000  743.19758  5.12%     -    4s
# H    0     0                     739.0000000  743.19758  0.57%     -    4s
# H    0     0                     741.0000000  743.19758  0.30%     -    4s
#      0     0  742.49700    0   51  741.00000  742.49700  0.20%     -    4s
# H    0     0                     742.0000000  742.49700  0.07%     -    4s
#      0     0  742.49700    0   51  742.00000  742.49700  0.07%     -    4s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 3
#   MIR: 14
#
# Explored 1 nodes (3922 simplex iterations) in 4.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 742 741 739 707
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.420000000000e+02, best bound 7.420000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3.5x4

# %%
datafile="3x1000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xa679983c
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 695.0000000
# Sparsify removed 1420019 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 33 rows and 0 columns
# Presolve time: 3.72s
# Presolved: 3967 rows, 3232 columns, 75439 nonzeros
# Variable types: 241 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 7.351504e+02, 2266 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  735.15037    0  109  695.00000  735.15037  5.78%     -    4s
# H    0     0                     732.0000000  735.15037  0.43%     -    4s
# H    0     0                     733.0000000  735.15037  0.29%     -    4s
# H    0     0                     734.0000000  735.15037  0.16%     -    4s
#      0     0  735.13918    0  105  734.00000  735.13918  0.16%     -    4s
#      0     0  735.09463    0   95  734.00000  735.09463  0.15%     -    4s
#      0     0  735.07272    0   97  734.00000  735.07272  0.15%     -    4s
#      0     0  735.04344    0   94  734.00000  735.04344  0.14%     -    4s
#      0     0  735.04344    0   90  734.00000  735.04344  0.14%     -    4s
#      0     0  735.04261    0   89  734.00000  735.04261  0.14%     -    4s
#      0     0  735.04261    0   84  734.00000  735.04261  0.14%     -    4s
#      0     0  735.04258    0   82  734.00000  735.04258  0.14%     -    4s
#      0     0  735.04258    0   83  734.00000  735.04258  0.14%     -    5s
#      0     0  735.04246    0   90  734.00000  735.04246  0.14%     -    5s
#      0     0  735.03955    0   86  734.00000  735.03955  0.14%     -    5s
#      0     0  735.03928    0   86  734.00000  735.03928  0.14%     -    5s
#      0     0  735.03927    0   85  734.00000  735.03927  0.14%     -    5s
#      0     0  735.03680    0   81  734.00000  735.03680  0.14%     -    5s
#      0     0  735.03680    0   87  734.00000  735.03680  0.14%     -    5s
#      0     0  735.03678    0   95  734.00000  735.03678  0.14%     -    5s
#      0     0  735.03678    0   84  734.00000  735.03678  0.14%     -    5s
#      0     0  735.03677    0   76  734.00000  735.03677  0.14%     -    5s
#      0     0  735.03677    0   80  734.00000  735.03677  0.14%     -    5s
#      0     0  735.03623    0   72  734.00000  735.03623  0.14%     -    6s
#      0     0  735.02980    0   79  734.00000  735.02980  0.14%     -    6s
#      0     0  735.02961    0   82  734.00000  735.02961  0.14%     -    6s
#      0     0  735.02961    0   75  734.00000  735.02961  0.14%     -    6s
#      0     0  735.02961    0   58  734.00000  735.02961  0.14%     -    6s
#      0     0  735.02961    0   94  734.00000  735.02961  0.14%     -    6s
#      0     0  735.02961    0   92  734.00000  735.02961  0.14%     -    6s
#      0     0  735.02961    0   86  734.00000  735.02961  0.14%     -    6s
#      0     0  735.01826    0   81  734.00000  735.01826  0.14%     -    6s
#      0     0  735.01826    0   80  734.00000  735.01826  0.14%     -    6s
#      0     0  735.01783    0   79  734.00000  735.01783  0.14%     -    7s
#      0     0  735.01783    0   92  734.00000  735.01783  0.14%     -    7s
#      0     0  735.01775    0   75  734.00000  735.01775  0.14%     -    7s
#      0     0  735.01775    0   81  734.00000  735.01775  0.14%     -    7s
#      0     0  735.01752    0   80  734.00000  735.01752  0.14%     -    7s
#      0     0  735.01751    0   83  734.00000  735.01751  0.14%     -    7s
#      0     0  735.01743    0   67  734.00000  735.01743  0.14%     -    7s
#      0     0  735.01743    0   65  734.00000  735.01743  0.14%     -    7s
#      0     0  735.01743    0   67  734.00000  735.01743  0.14%     -    7s
#      0     0  735.01743    0   51  734.00000  735.01743  0.14%     -    7s
#      0     2  735.01743    0   44  734.00000  735.01743  0.14%     -    7s
#
# Cutting planes:
#   Gomory: 16
#   Implied bound: 2
#   MIR: 96
#   StrongCG: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 3092 nodes (22476 simplex iterations) in 9.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 734 733 732 695
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.340000000000e+02, best bound 7.340000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x3.5x5

# %%
datafile="3x1000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xb9ef1f38
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 703.0000000
# Sparsify removed 1420019 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 57 rows and 0 columns
# Presolve time: 4.38s
# Presolved: 3943 rows, 3232 columns, 75301 nonzeros
# Variable types: 241 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 7.436472e+02, 2273 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  743.64720    0   38  703.00000  743.64720  5.78%     -    4s
# H    0     0                     741.0000000  743.64720  0.36%     -    4s
# H    0     0                     742.0000000  743.64720  0.22%     -    4s
#      0     0  743.29306    0   28  742.00000  743.29306  0.17%     -    4s
# H    0     0                     743.0000000  743.29306  0.04%     -    5s
#
# Cutting planes:
#   Gomory: 25
#   MIR: 30
#   StrongCG: 2
#
# Explored 1 nodes (3969 simplex iterations) in 5.17 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 743 742 741 703
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.430000000000e+02, best bound 7.430000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4x1

# %%
datafile="3x1000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x8c94e227
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 658.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 5s) ...
# Sparsify removed 1430420 nonzeros (96%)
# Presolve added 0 rows and 232 columns
# Presolve removed 43 rows and 0 columns
# Presolve time: 5.12s
# Presolved: 3957 rows, 3232 columns, 53080 nonzeros
# Variable types: 253 continuous, 2979 integer (2979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9300000e+02   1.568085e+04   0.000000e+00      5s
#     2967    6.9177683e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 6.917768e+02, 2967 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  691.77683    0  153  658.00000  691.77683  5.13%     -    5s
# H    0     0                     686.0000000  691.77683  0.84%     -    5s
# H    0     0                     689.0000000  691.77683  0.40%     -    5s
# H    0     0                     690.0000000  691.77683  0.26%     -    5s
#      0     0  691.15671    0  147  690.00000  691.15671  0.17%     -    5s
#      0     0  691.14971    0  125  690.00000  691.14971  0.17%     -    5s
#      0     0  691.14942    0  129  690.00000  691.14942  0.17%     -    5s
#      0     0  691.14942    0  133  690.00000  691.14942  0.17%     -    5s
#      0     0  691.11796    0  107  690.00000  691.11796  0.16%     -    5s
#      0     0  691.11792    0  101  690.00000  691.11792  0.16%     -    6s
#      0     0  691.11730    0   87  690.00000  691.11730  0.16%     -    6s
#      0     0  691.11730    0   88  690.00000  691.11730  0.16%     -    6s
#      0     0  691.11237    0   98  690.00000  691.11237  0.16%     -    6s
#      0     0  691.11229    0   91  690.00000  691.11229  0.16%     -    6s
#      0     0  691.11164    0   70  690.00000  691.11164  0.16%     -    6s
#      0     0  691.11164    0  106  690.00000  691.11164  0.16%     -    6s
#      0     0  691.11164    0  114  690.00000  691.11164  0.16%     -    7s
#      0     0  691.11164    0  100  690.00000  691.11164  0.16%     -    7s
#      0     0  691.11156    0  101  690.00000  691.11156  0.16%     -    7s
#      0     0  691.10943    0   92  690.00000  691.10943  0.16%     -    7s
#      0     0  691.10878    0   83  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10878    0   83  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10878    0   86  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10878    0   83  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10878    0   82  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10878    0   83  690.00000  691.10878  0.16%     -    7s
#      0     0  691.10516    0   59  690.00000  691.10516  0.16%     -    7s
#      0     0  691.10516    0   56  690.00000  691.10516  0.16%     -    7s
#      0     0  691.10251    0   60  690.00000  691.10251  0.16%     -    7s
#      0     0  691.10251    0   56  690.00000  691.10251  0.16%     -    7s
#      0     0  691.10251    0   64  690.00000  691.10251  0.16%     -    7s
#      0     0  691.10251    0   66  690.00000  691.10251  0.16%     -    7s
#      0     0  691.10251    0   39  690.00000  691.10251  0.16%     -    7s
#      0     0  691.10251    0   39  690.00000  691.10251  0.16%     -    8s
#      0     0  691.10251    0   54  690.00000  691.10251  0.16%     -    8s
#      0     0  691.10251    0   57  690.00000  691.10251  0.16%     -    8s
#      0     0  691.10251    0   41  690.00000  691.10251  0.16%     -    8s
#      0     0  691.10251    0   41  690.00000  691.10251  0.16%     -    8s
#      0     2  691.10251    0   37  690.00000  691.10251  0.16%     -    8s
#   1452  1084  691.02525    8   70  690.00000  691.08075  0.16%   7.5   10s
#   1754  1677  691.00928   35   31  690.00000  691.03983  0.15%  18.8   15s
# H 7977  1179                     691.0000000  691.03854  0.01%   8.6   17s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 7
#   MIR: 13
#   StrongCG: 8
#   Flow cover: 15
#   GUB cover: 3
#
# Explored 8282 nodes (76998 simplex iterations) in 17.90 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 691 690 689 ... 658
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.910000000000e+02, best bound 6.910000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4x2

# %%
datafile="3x1000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xd35f2a19
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 654.0000000
# Sparsify removed 1439409 nonzeros (97%)
# Presolve added 0 rows and 237 columns
# Presolve removed 63 rows and 0 columns
# Presolve time: 3.79s
# Presolved: 3937 rows, 3237 columns, 38085 nonzeros
# Variable types: 264 continuous, 2973 integer (2973 binary)
#
# Root relaxation: objective 6.894220e+02, 3050 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  689.42197    0   67  654.00000  689.42197  5.42%     -    4s
# H    0     0                     687.0000000  689.42197  0.35%     -    4s
#      0     0  689.08809    0   80  687.00000  689.08809  0.30%     -    4s
# H    0     0                     688.0000000  689.08809  0.16%     -    4s
#      0     0  689.08556    0   81  688.00000  689.08556  0.16%     -    4s
#      0     0  689.08556    0   79  688.00000  689.08556  0.16%     -    4s
#      0     0  689.07701    0   71  688.00000  689.07701  0.16%     -    4s
#      0     0  689.06841    0   57  688.00000  689.06841  0.16%     -    4s
#      0     0  689.06841    0   57  688.00000  689.06841  0.16%     -    4s
#      0     0  689.05770    0   43  688.00000  689.05770  0.15%     -    4s
#      0     0  689.05770    0   61  688.00000  689.05770  0.15%     -    4s
#      0     0  689.05171    0   72  688.00000  689.05171  0.15%     -    5s
#      0     0  689.04875    0   74  688.00000  689.04875  0.15%     -    5s
#      0     0  689.04760    0   74  688.00000  689.04760  0.15%     -    5s
#      0     0  689.01478    0   70  688.00000  689.01478  0.15%     -    5s
#      0     0  689.01409    0   63  688.00000  689.01409  0.15%     -    5s
#      0     0  689.01409    0   67  688.00000  689.01409  0.15%     -    5s
#      0     0  689.01403    0   69  688.00000  689.01403  0.15%     -    5s
#      0     0  689.01403    0   72  688.00000  689.01403  0.15%     -    5s
#      0     0  689.01098    0   70  688.00000  689.01098  0.15%     -    5s
#
# Cutting planes:
#   Gomory: 12
#   MIR: 32
#
# Explored 1 nodes (10617 simplex iterations) in 5.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 688 687 654
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.880000000000e+02, best bound 6.880000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4x3

# %%
datafile="3x1000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x061b05f4
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 651.0000000
# Sparsify removed 1431693 nonzeros (95%)
# Presolve added 0 rows and 240 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 3.77s
# Presolved: 3960 rows, 3240 columns, 69714 nonzeros
# Variable types: 243 continuous, 2997 integer (2997 binary)
#
# Root relaxation: objective 6.910747e+02, 2258 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  691.07473    0   92  651.00000  691.07473  6.16%     -    4s
# H    0     0                     686.0000000  691.07473  0.74%     -    4s
# H    0     0                     689.0000000  691.07473  0.30%     -    4s
#      0     0  691.00435    0   70  689.00000  691.00435  0.29%     -    4s
# H    0     0                     690.0000000  691.00435  0.15%     -    4s
#      0     0     cutoff    0       690.00000  690.00000  0.00%     -    4s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 1
#   Implied bound: 1
#   MIR: 19
#   RLT: 1
#
# Explored 1 nodes (3810 simplex iterations) in 4.45 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 690 689 686 651
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.900000000000e+02, best bound 6.900000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4x4

# %%
datafile="3x1000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x00a5e7f7
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 653.0000000
# Sparsify removed 1422117 nonzeros (95%)
# Presolve added 0 rows and 236 columns
# Presolve removed 30 rows and 0 columns
# Presolve time: 3.74s
# Presolved: 3970 rows, 3236 columns, 79322 nonzeros
# Variable types: 239 continuous, 2997 integer (2997 binary)
#
# Root relaxation: objective 6.927435e+02, 2353 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  692.74345    0   88  653.00000  692.74345  6.09%     -    4s
# H    0     0                     690.0000000  692.74345  0.40%     -    4s
# H    0     0                     691.0000000  692.74345  0.25%     -    4s
#      0     0  692.73070    0   80  691.00000  692.73070  0.25%     -    4s
# H    0     0                     692.0000000  692.73070  0.11%     -    4s
#      0     0  692.73070    0   80  692.00000  692.73070  0.11%     -    4s
#
# Cutting planes:
#   Gomory: 16
#   MIR: 15
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (3432 simplex iterations) in 4.39 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 692 691 690 653
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.920000000000e+02, best bound 6.920000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4x5

# %%
datafile="3x1000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xc201cf62
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 657.0000000
# Sparsify removed 1435713 nonzeros (96%)
# Presolve added 0 rows and 237 columns
# Presolve removed 53 rows and 0 columns
# Presolve time: 4.43s
# Presolved: 3947 rows, 3237 columns, 53733 nonzeros
# Variable types: 252 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 6.950732e+02, 2755 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  695.07316    0  103  657.00000  695.07316  5.80%     -    4s
# H    0     0                     692.0000000  695.07316  0.44%     -    4s
# H    0     0                     693.0000005  695.07316  0.30%     -    4s
#      0     0  695.00693    0  104  693.00000  695.00693  0.29%     -    4s
# H    0     0                     694.0000000  695.00693  0.15%     -    5s
#      0     0     cutoff    0       694.00000  694.00000  0.00%     -    5s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 9
#   MIR: 65
#   StrongCG: 19
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (4826 simplex iterations) in 5.03 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 694 693 692 657
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.940000000000e+02, best bound 6.940000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4.5x1

# %%
datafile="3x1000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x6b07abbe
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 610.0000000
# Sparsify removed 1431879 nonzeros (96%)
# Presolve added 0 rows and 235 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 3.80s
# Presolved: 3953 rows, 3235 columns, 57582 nonzeros
# Variable types: 250 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 6.438089e+02, 3397 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  643.80891    0   91  610.00000  643.80891  5.54%     -    4s
# H    0     0                     640.0000000  643.80891  0.60%     -    4s
# H    0     0                     642.0000000  643.80891  0.28%     -    4s
#      0     0  643.75583    0   90  642.00000  643.75583  0.27%     -    4s
# H    0     0                     643.0000001  643.75583  0.12%     -    4s
#      0     0  643.75583    0   90  643.00000  643.75583  0.12%     -    4s
#
# Cutting planes:
#   Gomory: 10
#   Implied bound: 1
#   MIR: 30
#   RLT: 1
#
# Explored 1 nodes (5283 simplex iterations) in 4.46 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 643 642 640 610
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.430000000562e+02, best bound 6.430000000562e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4.5x2

# %%
datafile="3x1000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x484e8621
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 617.0000000
# Sparsify removed 1423056 nonzeros (95%)
# Presolve added 0 rows and 232 columns
# Presolve removed 34 rows and 0 columns
# Presolve time: 3.75s
# Presolved: 3966 rows, 3232 columns, 69405 nonzeros
# Variable types: 244 continuous, 2988 integer (2988 binary)
#
# Root relaxation: objective 6.527665e+02, 2478 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  652.76652    0   80  617.00000  652.76652  5.80%     -    4s
# H    0     0                     650.0000000  652.76652  0.43%     -    4s
# H    0     0                     651.0000000  652.76652  0.27%     -    4s
#      0     0  652.73157    0   79  651.00000  652.73157  0.27%     -    4s
# H    0     0                     652.0000000  652.73157  0.11%     -    4s
#      0     0  652.00000    0   77  652.00000  652.00000  0.00%     -    4s
#
# Cutting planes:
#   Gomory: 13
#   Implied bound: 1
#   MIR: 45
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (3581 simplex iterations) in 4.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 652 651 650 617
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.520000000000e+02, best bound 6.520000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4.5x3

# %%
datafile="3x1000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xb54a5e60
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 608.0000000
# Sparsify removed 1435338 nonzeros (96%)
# Presolve added 0 rows and 240 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 3.81s
# Presolved: 3959 rows, 3240 columns, 54123 nonzeros
# Variable types: 255 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 6.414583e+02, 3423 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  641.45831    0   63  608.00000  641.45831  5.50%     -    4s
# H    0     0                     638.0000000  641.45831  0.54%     -    4s
# H    0     0                     640.0000000  641.45831  0.23%     -    4s
#      0     0  641.44939    0   78  640.00000  641.44939  0.23%     -    4s
# H    0     0                     641.0000000  641.44939  0.07%     -    4s
#      0     0  641.42944    0   64  641.00000  641.42944  0.07%     -    4s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 4
#   Implied bound: 1
#   MIR: 27
#   StrongCG: 4
#
# Explored 1 nodes (4951 simplex iterations) in 4.49 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 641 640 638 608
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.410000000000e+02, best bound 6.410000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4.5x4

# %%
datafile="3x1000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xe070b1c9
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 626.0000000
# Sparsify removed 1433767 nonzeros (96%)
# Presolve added 0 rows and 235 columns
# Presolve removed 39 rows and 0 columns
# Presolve time: 4.41s
# Presolved: 3961 rows, 3235 columns, 52727 nonzeros
# Variable types: 253 continuous, 2982 integer (2982 binary)
#
# Root relaxation: objective 6.596862e+02, 3566 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  659.68623    0  104  626.00000  659.68623  5.38%     -    4s
# H    0     0                     654.0000000  659.68623  0.87%     -    4s
# H    0     0                     657.0000000  659.68623  0.41%     -    4s
# H    0     0                     658.0000000  659.68623  0.26%     -    4s
#      0     0  659.60934    0   99  658.00000  659.60934  0.24%     -    4s
#      0     0  659.56162    0   94  658.00000  659.56162  0.24%     -    5s
#      0     0  659.56087    0   98  658.00000  659.56087  0.24%     -    5s
#      0     0  659.56087    0   98  658.00000  659.56087  0.24%     -    5s
#      0     0  659.45043    0   76  658.00000  659.45043  0.22%     -    5s
#      0     0  659.44918    0   75  658.00000  659.44918  0.22%     -    5s
#      0     0  659.44819    0   73  658.00000  659.44819  0.22%     -    5s
#      0     0  659.44819    0   73  658.00000  659.44819  0.22%     -    5s
#      0     0  659.20006    0   57  658.00000  659.20006  0.18%     -    5s
#      0     0  659.20006    0   56  658.00000  659.20006  0.18%     -    5s
#      0     0  659.20006    0   56  658.00000  659.20006  0.18%     -    5s
#      0     0  659.20006    0   58  658.00000  659.20006  0.18%     -    5s
#      0     0  659.20006    0   39  658.00000  659.20006  0.18%     -    6s
#      0     0  659.18992    0   44  658.00000  659.18992  0.18%     -    6s
#      0     0  659.18152    0   50  658.00000  659.18152  0.18%     -    6s
#      0     0  659.18152    0   48  658.00000  659.18152  0.18%     -    6s
#      0     0  659.14017    0   56  658.00000  659.14017  0.17%     -    6s
#      0     0  659.13981    0   61  658.00000  659.13981  0.17%     -    6s
#      0     0  659.13981    0   58  658.00000  659.13981  0.17%     -    6s
#      0     0  659.13767    0   48  658.00000  659.13767  0.17%     -    6s
#      0     0  659.13767    0   82  658.00000  659.13767  0.17%     -    6s
#      0     0  659.13767    0   53  658.00000  659.13767  0.17%     -    7s
#      0     0  659.13767    0   54  658.00000  659.13767  0.17%     -    7s
#      0     0  659.13767    0   54  658.00000  659.13767  0.17%     -    7s
#      0     0  659.10139    0   40  658.00000  659.10139  0.17%     -    7s
#      0     0  659.10139    0   41  658.00000  659.10139  0.17%     -    7s
#      0     0  659.09967    0   46  658.00000  659.09967  0.17%     -    7s
#      0     0  659.08701    0   47  658.00000  659.08701  0.17%     -    7s
#      0     0  659.08336    0   51  658.00000  659.08336  0.16%     -    7s
#      0     0     cutoff    0       658.00000  658.00000  0.00%     -    7s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 1
#   MIR: 66
#   StrongCG: 2
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (12062 simplex iterations) in 7.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 658 657 654 626
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.580000000000e+02, best bound 6.580000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x4.5x5

# %%
datafile="3x1000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xfe671615
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 610.0000000
# Sparsify removed 1449279 nonzeros (98%)
# Presolve added 0 rows and 252 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 4.43s
# Presolved: 3942 rows, 3252 columns, 34194 nonzeros
# Variable types: 273 continuous, 2979 integer (2979 binary)
#
# Root relaxation: objective 6.476190e+02, 3259 iterations, 0.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  647.61903    0  102  610.00000  647.61903  6.17%     -    4s
# H    0     0                     643.0000000  647.61903  0.72%     -    4s
# H    0     0                     646.0000000  647.61903  0.25%     -    4s
#      0     0  647.61694    0  111  646.00000  647.61694  0.25%     -    4s
# H    0     0                     647.0000000  647.61694  0.10%     -    4s
#      0     0  647.61628    0  116  647.00000  647.61628  0.10%     -    4s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 4
#   Implied bound: 3
#   MIR: 45
#   StrongCG: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (5269 simplex iterations) in 4.95 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 647 646 643 610
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.470000000000e+02, best bound 6.470000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x5x1

# %%
datafile="3x1000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x88facad9
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 574.0000000
# Sparsify removed 1435295 nonzeros (97%)
# Presolve added 0 rows and 235 columns
# Presolve removed 34 rows and 0 columns
# Presolve time: 3.81s
# Presolved: 3966 rows, 3235 columns, 48238 nonzeros
# Variable types: 256 continuous, 2979 integer (2979 binary)
#
# Root relaxation: objective 6.035405e+02, 3026 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  603.54045    0   81  574.00000  603.54045  5.15%     -    4s
# H    0     0                     599.0000000  603.54045  0.76%     -    4s
# H    0     0                     601.0000000  603.54045  0.42%     -    4s
#      0     0  603.44287    0   72  601.00000  603.44287  0.41%     -    4s
# H    0     0                     602.0000000  603.44287  0.24%     -    4s
#      0     0  603.36439    0   71  602.00000  603.36439  0.23%     -    4s
#      0     0  603.36439    0   72  602.00000  603.36439  0.23%     -    4s
#      0     0  603.33758    0   57  602.00000  603.33758  0.22%     -    4s
#      0     0  603.24238    0   58  602.00000  603.24238  0.21%     -    4s
#      0     0  603.24178    0   60  602.00000  603.24178  0.21%     -    4s
#      0     0  603.17891    0   49  602.00000  603.17891  0.20%     -    4s
#      0     0  603.17817    0   55  602.00000  603.17817  0.20%     -    4s
#      0     0  603.16343    0   45  602.00000  603.16343  0.19%     -    4s
#      0     0  603.16343    0   84  602.00000  603.16343  0.19%     -    5s
#      0     0  603.16343    0   69  602.00000  603.16343  0.19%     -    5s
#      0     0  603.09859    0   60  602.00000  603.09859  0.18%     -    5s
#      0     0  603.07919    0   64  602.00000  603.07919  0.18%     -    5s
#      0     0  603.07861    0   64  602.00000  603.07861  0.18%     -    5s
#      0     0     cutoff    0       602.00000  602.00000  0.00%     -    5s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 8
#   Implied bound: 3
#   MIR: 79
#   StrongCG: 3
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (10075 simplex iterations) in 5.49 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 602 601 599 574
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.020000000000e+02, best bound 6.020000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x5x2

# %%
datafile="3x1000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xb51c52a8
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 592.0000000
# Sparsify removed 1426520 nonzeros (95%)
# Presolve added 0 rows and 235 columns
# Presolve removed 30 rows and 0 columns
# Presolve time: 4.39s
# Presolved: 3970 rows, 3235 columns, 68938 nonzeros
# Variable types: 244 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 6.211065e+02, 2343 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  621.10650    0  100  592.00000  621.10650  4.92%     -    4s
# H    0     0                     617.0000000  621.10650  0.67%     -    4s
# H    0     0                     618.0000000  621.10650  0.50%     -    4s
# H    0     0                     619.0000000  621.10650  0.34%     -    4s
#      0     0  621.08329    0  110  619.00000  621.08329  0.34%     -    4s
# H    0     0                     620.0000000  621.08329  0.17%     -    5s
#      0     0  621.05501    0  111  620.00000  621.05501  0.17%     -    5s
#      0     0  621.01597    0   57  620.00000  621.01597  0.16%     -    5s
#      0     0     cutoff    0       620.00000  620.00000  0.00%     -    5s
#
# Explored 1 nodes (6714 simplex iterations) in 5.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 620 619 618 ... 592
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.200000000000e+02, best bound 6.200000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x5x3

# %%
datafile="3x1000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x95ce1247
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 569.0000000
# Sparsify removed 1435554 nonzeros (97%)
# Presolve added 0 rows and 236 columns
# Presolve removed 36 rows and 0 columns
# Presolve time: 4.42s
# Presolved: 3964 rows, 3236 columns, 50931 nonzeros
# Variable types: 254 continuous, 2982 integer (2982 binary)
#
# Root relaxation: objective 6.093291e+02, 3290 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  609.32909    0  110  569.00000  609.32909  7.09%     -    4s
# H    0     0                     605.0000000  609.32909  0.72%     -    4s
# H    0     0                     606.0000000  609.32909  0.55%     -    4s
# H    0     0                     607.0000000  609.32909  0.38%     -    4s
#      0     0  609.18569    0  118  607.00000  609.18569  0.36%     -    4s
# H    0     0                     608.0000000  609.18569  0.20%     -    5s
#      0     0  609.15481    0  125  608.00000  609.15481  0.19%     -    5s
#
# Cutting planes:
#   Gomory: 64
#   Cover: 6
#   Implied bound: 6
#   MIR: 182
#   StrongCG: 4
#   GUB cover: 2
#   Mod-K: 1
#   RLT: 10
#   Relax-and-lift: 3
#
# Explored 1 nodes (4540 simplex iterations) in 5.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 608 607 606 ... 569
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.080000000000e+02, best bound 6.080000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x5x4

# %%
datafile="3x1000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0xf09d7a37
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 580.0000000
# Sparsify removed 1437159 nonzeros (96%)
# Presolve added 0 rows and 240 columns
# Presolve removed 27 rows and 0 columns
# Presolve time: 3.79s
# Presolved: 3973 rows, 3240 columns, 58314 nonzeros
# Variable types: 249 continuous, 2991 integer (2991 binary)
#
# Root relaxation: objective 6.116377e+02, 3062 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  611.63774    0  210  580.00000  611.63774  5.45%     -    4s
# H    0     0                     605.0000000  611.63774  1.10%     -    4s
# H    0     0                     609.0000000  611.63774  0.43%     -    4s
#      0     0  611.53724    0  194  609.00000  611.53724  0.42%     -    4s
#      0     0  611.36032    0  192  609.00000  611.36032  0.39%     -    4s
#      0     0  611.35940    0  186  609.00000  611.35940  0.39%     -    4s
#      0     0  611.35940    0  186  609.00000  611.35940  0.39%     -    4s
#      0     0  611.33587    0  150  609.00000  611.33587  0.38%     -    4s
#      0     0  611.24743    0  135  609.00000  611.24743  0.37%     -    4s
#      0     0  611.24224    0  135  609.00000  611.24224  0.37%     -    4s
#      0     0  611.24224    0  143  609.00000  611.24224  0.37%     -    4s
# H    0     0                     610.0000000  611.24224  0.20%     -    4s
#      0     0  611.21060    0   77  610.00000  611.21060  0.20%     -    4s
#      0     0  611.21060    0  151  610.00000  611.21060  0.20%     -    5s
#      0     0  611.21060    0  143  610.00000  611.21060  0.20%     -    5s
#      0     0  611.21060    0  107  610.00000  611.21060  0.20%     -    5s
#      0     0  611.20081    0  103  610.00000  611.20081  0.20%     -    5s
#      0     0  611.19601    0  118  610.00000  611.19601  0.20%     -    5s
#      0     0  611.19320    0  109  610.00000  611.19320  0.20%     -    5s
#      0     0  611.18913    0  111  610.00000  611.18913  0.19%     -    5s
#      0     0  611.18913    0  108  610.00000  611.18913  0.19%     -    5s
#      0     0  611.18597    0  134  610.00000  611.18597  0.19%     -    5s
#      0     0  611.18594    0  121  610.00000  611.18594  0.19%     -    5s
#      0     0  611.18571    0  123  610.00000  611.18571  0.19%     -    6s
#      0     0  611.18545    0  116  610.00000  611.18545  0.19%     -    6s
#      0     0  611.18545    0  115  610.00000  611.18545  0.19%     -    6s
#      0     0  611.18545    0  112  610.00000  611.18545  0.19%     -    6s
#      0     0  611.18545    0  111  610.00000  611.18545  0.19%     -    6s
#      0     0  611.18544    0  117  610.00000  611.18544  0.19%     -    6s
#      0     0  611.18463    0  127  610.00000  611.18463  0.19%     -    6s
#      0     0  611.18463    0  124  610.00000  611.18463  0.19%     -    6s
#      0     0  611.18444    0  115  610.00000  611.18444  0.19%     -    6s
#      0     0  611.18444    0   82  610.00000  611.18444  0.19%     -    6s
#      0     2  611.18444    0   79  610.00000  611.18444  0.19%     -    6s
#   2555  1038  610.99963   10  125  610.00000  611.07079  0.18%  11.4   10s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 7
#   MIR: 45
#   Flow cover: 41
#   GUB cover: 1
#   Zero half: 1
#
# Explored 2644 nodes (56360 simplex iterations) in 12.01 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 610 609 605 580
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.100000000000e+02, best bound 6.100000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x1000x5x5

# %%
datafile="3x1000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 4000 rows, 3000 columns and 1504500 nonzeros
# Model fingerprint: 0x50ecab9c
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 577.0000000
# Sparsify removed 1433718 nonzeros (97%)
# Presolve added 0 rows and 232 columns
# Presolve removed 49 rows and 0 columns
# Presolve time: 4.42s
# Presolved: 3951 rows, 3232 columns, 40869 nonzeros
# Variable types: 262 continuous, 2970 integer (2970 binary)
#
# Root relaxation: objective 6.159892e+02, 3243 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  615.98921    0  115  577.00000  615.98921  6.76%     -    4s
# H    0     0                     613.0000000  615.98921  0.49%     -    4s
# H    0     0                     614.0000000  615.98921  0.32%     -    4s
#      0     0  615.93870    0  117  614.00000  615.93870  0.32%     -    4s
#      0     0  615.93691    0  121  614.00000  615.93691  0.32%     -    4s
#      0     0  615.93572    0  116  614.00000  615.93572  0.32%     -    4s
#      0     0  615.93572    0  117  614.00000  615.93572  0.32%     -    4s
#      0     0  615.93513    0  108  614.00000  615.93513  0.32%     -    5s
#      0     0  615.91063    0  110  614.00000  615.91063  0.31%     -    5s
#      0     0  615.89671    0  109  614.00000  615.89671  0.31%     -    5s
#      0     0  615.89671    0  123  614.00000  615.89671  0.31%     -    5s
#      0     0  615.89592    0  109  614.00000  615.89592  0.31%     -    5s
#      0     0  615.89415    0  111  614.00000  615.89415  0.31%     -    5s
#      0     0  615.89406    0  115  614.00000  615.89406  0.31%     -    5s
#      0     0  615.89191    0  112  614.00000  615.89191  0.31%     -    5s
#      0     0  615.83841    0  112  614.00000  615.83841  0.30%     -    5s
#      0     0  615.83798    0   97  614.00000  615.83798  0.30%     -    5s
#      0     0  615.83798    0  105  614.00000  615.83798  0.30%     -    5s
#      0     0  615.83798    0   97  614.00000  615.83798  0.30%     -    5s
# H    0     0                     615.0000000  615.83798  0.14%     -    5s
#      0     0  615.83798    0  102  615.00000  615.83798  0.14%     -    5s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 8
#   MIR: 64
#   GUB cover: 1
#
# Explored 1 nodes (6172 simplex iterations) in 5.89 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 615 614 613 577
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.150000000000e+02, best bound 6.150000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x1.5x1

# %%
datafile="4x1000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x71ad4fa7
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1000.0000000
# Sparsify removed 1829383 nonzeros (91%)
# Presolve added 0 rows and 289 columns
# Presolve removed 76 rows and 0 columns
# Presolve time: 4.95s
# Presolved: 4924 rows, 4289 columns, 176365 nonzeros
# Variable types: 289 continuous, 4000 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+03   3.659259e+04   0.000000e+00      5s
#
# Root relaxation: cutoff, 0 iterations, 0.01 seconds
#
# Explored 0 nodes (0 simplex iterations) in 5.11 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x1.5x2

# %%
datafile="4x1000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x1147bef8
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 996.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Sparsify removed 1834904 nonzeros (92%)
# Presolve added 0 rows and 280 columns
# Presolve removed 124 rows and 0 columns
# Presolve time: 6.00s
# Presolved: 4876 rows, 4280 columns, 154712 nonzeros
# Variable types: 296 continuous, 3984 integer (3984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9600000e+02   3.370564e+04   0.000000e+00      6s
#
# Root relaxation: cutoff, 0 iterations, 0.01 seconds
#
# Explored 0 nodes (0 simplex iterations) in 6.14 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.960000000000e+02, best bound 9.960000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x1.5x3

# %%
datafile="4x1000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xcfa2dc45
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 998.0000000
# Sparsify removed 1830548 nonzeros (92%)
# Presolve removed 58 rows and 3672 columns (presolve time = 5s) ...
# Presolve added 0 rows and 284 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 5.09s
# Presolved: 4942 rows, 4284 columns, 167336 nonzeros
# Variable types: 292 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9800000e+02   3.668522e+04   0.000000e+00      5s
#
# Root relaxation: cutoff, 0 iterations, 0.01 seconds
#
# Explored 0 nodes (0 simplex iterations) in 5.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.980000000000e+02, best bound 9.980000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x1.5x4

# %%
datafile="4x1000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x2a8e4a45
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 998.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 5s) ...
# Sparsify removed 1830548 nonzeros (92%)
# Presolve added 0 rows and 284 columns
# Presolve removed 118 rows and 0 columns
# Presolve time: 6.03s
# Presolved: 4882 rows, 4284 columns, 167072 nonzeros
# Variable types: 292 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9800000e+02   3.646515e+04   0.000000e+00      6s
#
# Root relaxation: cutoff, 0 iterations, 0.01 seconds
#
# Explored 0 nodes (0 simplex iterations) in 6.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.980000000000e+02, best bound 9.980000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x1.5x5

# %%
datafile="4x1000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xbc2fa96f
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 997.0000000
# Sparsify removed 1836295 nonzeros (92%)
# Presolve removed 59 rows and 3669 columns (presolve time = 5s) ...
# Presolve added 0 rows and 283 columns
# Presolve removed 59 rows and 0 columns
# Presolve time: 5.10s
# Presolved: 4941 rows, 4283 columns, 157597 nonzeros
# Variable types: 295 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9700000e+02   3.301114e+04   0.000000e+00      5s
#
# Root relaxation: cutoff, 0 iterations, 0.01 seconds
#
# Explored 0 nodes (0 simplex iterations) in 5.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.970000000000e+02, best bound 9.970000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2x1

# %%
datafile="4x1000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x0250d5f1
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 990.0000000
# Presolve removed 37 rows and 20 columns (presolve time = 5s) ...
# Sparsify removed 1840203 nonzeros (93%)
# Presolve added 0 rows and 279 columns
# Presolve removed 80 rows and 0 columns
# Presolve time: 6.03s
# Presolved: 4920 rows, 4279 columns, 145663 nonzeros
# Variable types: 299 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.166333e+04   0.000000e+00      6s
#     2096    9.9183036e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 9.918304e+02, 2096 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  991.83036    0   62  990.00000  991.83036  0.18%     -    6s
#      0     0  991.80766    0   80  990.00000  991.80766  0.18%     -    6s
#      0     0  991.79067    0   74  990.00000  991.79067  0.18%     -    6s
#      0     0  991.79067    0   76  990.00000  991.79067  0.18%     -    6s
#      0     0  991.72056    0   46  990.00000  991.72056  0.17%     -    7s
#      0     0  991.71729    0   46  990.00000  991.71729  0.17%     -    7s
#      0     0  991.69933    0   50  990.00000  991.69933  0.17%     -    7s
#      0     0  991.69315    0   50  990.00000  991.69315  0.17%     -    7s
#      0     0  991.69092    0   56  990.00000  991.69092  0.17%     -    7s
#      0     0  991.69092    0   52  990.00000  991.69092  0.17%     -    7s
#      0     0  991.64633    0   57  990.00000  991.64633  0.17%     -    7s
#      0     0  991.62541    0   52  990.00000  991.62541  0.16%     -    7s
#      0     0  991.62541    0   53  990.00000  991.62541  0.16%     -    7s
#      0     0  991.43454    0   34  990.00000  991.43454  0.14%     -    7s
#      0     0  991.43454    0   39  990.00000  991.43454  0.14%     -    8s
#      0     0  991.35962    0   49  990.00000  991.35962  0.14%     -    8s
#      0     0  991.35962    0   47  990.00000  991.35962  0.14%     -    8s
#      0     0  991.30884    0   51  990.00000  991.30884  0.13%     -    8s
#      0     0  991.30884    0   41  990.00000  991.30884  0.13%     -    8s
#      0     0  991.30884    0   36  990.00000  991.30884  0.13%     -    8s
#      0     0  991.30884    0   34  990.00000  991.30884  0.13%     -    9s
# H    0     0                     991.0000000  991.30884  0.03%     -    9s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 7
#   Implied bound: 1
#   MIR: 65
#   StrongCG: 2
#   GUB cover: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (7240 simplex iterations) in 9.21 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 991 990
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.910000000000e+02, best bound 9.910000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2x2

# %%
datafile="4x1000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x818bcdfb
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 980.0000000
# Sparsify removed 1832746 nonzeros (92%)
# Presolve removed 99 rows and 3670 columns (presolve time = 5s) ...
# Presolve added 0 rows and 282 columns
# Presolve removed 99 rows and 0 columns
# Presolve time: 5.11s
# Presolved: 4901 rows, 4282 columns, 161010 nonzeros
# Variable types: 294 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9700000e+02   3.927619e+04   0.000000e+00      5s
#     2010    9.8472557e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 9.847256e+02, 2010 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  984.72557    0  122  980.00000  984.72557  0.48%     -    5s
# H    0     0                     981.0000000  984.72557  0.38%     -    5s
#      0     0  984.57562    0  132  981.00000  984.57562  0.36%     -    5s
# H    0     0                     982.0000000  984.57562  0.26%     -    6s
#      0     0  984.53236    0  128  982.00000  984.53236  0.26%     -    6s
#      0     0  984.49928    0  123  982.00000  984.49928  0.25%     -    6s
#      0     0  984.45258    0  117  982.00000  984.45258  0.25%     -    6s
# H    0     0                     983.0000000  984.45258  0.15%     -    6s
#      0     0  984.41697    0  107  983.00000  984.41697  0.14%     -    6s
#      0     0  984.40052    0   96  983.00000  984.40052  0.14%     -    6s
#      0     0  984.36601    0   88  983.00000  984.36601  0.14%     -    6s
#      0     0  984.32335    0   87  983.00000  984.32335  0.13%     -    6s
#      0     0  984.32335    0   85  983.00000  984.32335  0.13%     -    7s
#      0     0  984.24617    0   70  983.00000  984.24617  0.13%     -    7s
#      0     0  984.24617    0   65  983.00000  984.24617  0.13%     -    7s
#      0     0  984.24617    0   74  983.00000  984.24617  0.13%     -    7s
#      0     0  984.24617    0   77  983.00000  984.24617  0.13%     -    7s
#      0     0  984.17462    0   58  983.00000  984.17462  0.12%     -    8s
#      0     0  984.17462    0   55  983.00000  984.17462  0.12%     -    8s
#      0     0  984.17462    0   74  983.00000  984.17462  0.12%     -    8s
#      0     0  984.17462    0   71  983.00000  984.17462  0.12%     -    8s
#      0     0  984.17462    0   50  983.00000  984.17462  0.12%     -    9s
#      0     0  984.17462    0   55  983.00000  984.17462  0.12%     -    9s
#      0     0  984.17462    0   48  983.00000  984.17462  0.12%     -    9s
#      0     0  984.17462    0   56  983.00000  984.17462  0.12%     -   10s
#      0     0  984.17462    0   57  983.00000  984.17462  0.12%     -   10s
#      0     0  984.17462    0   75  983.00000  984.17462  0.12%     -   10s
#      0     0  984.17462    0   51  983.00000  984.17462  0.12%     -   11s
#      0     0  984.17462    0   50  983.00000  984.17462  0.12%     -   11s
#      0     2  984.17462    0   46  983.00000  984.17462  0.12%     -   12s
#   1564  1858  984.00215  175   51  983.00000  984.14277  0.12%   6.9   15s
#   3530  3166  984.01299  123   72  983.00000  984.13983  0.12%   6.1   20s
#   3539  3172  984.01664  183   57  983.00000  984.13466  0.12%   6.1   25s
#   3547  3177  984.01299   80   44  983.00000  984.11567  0.11%   6.1   30s
#   3557  3184  984.05429   46   37  983.00000  984.05429  0.11%   6.1   35s
#   3564  3189  984.05429   50   37  983.00000  984.05429  0.11%   6.1   40s
#   3571  3193  984.04267  151   20  983.00000  984.05429  0.11%   6.1   45s
#   3607  3224  984.04782   19   21  983.00000  984.05372  0.11%  16.9   50s
#   5696  4689  984.00566   52   33  983.00000  984.05327  0.11%  13.3   55s
#   9922  6795  984.00000  109   28  983.00000  984.05327  0.11%  10.4   60s
#  12752  8362  984.00000  367   27  983.00000  984.05327  0.11%   9.7   65s
#  17467 11777  984.05304   40   29  983.00000  984.05327  0.11%   8.9   70s
#  22365 15863  984.05327   53   25  983.00000  984.05327  0.11%   8.5   75s
#  25906 17973  983.99968  220   50  983.00000  984.05327  0.11%   8.1   80s
#  25925 17986  984.00000  101   46  983.00000  984.05327  0.11%   8.1   85s
#  26419 18658  984.03864   66   39  983.00000  984.05327  0.11%   8.1   90s
#  28162 20184  983.99903  184   20  983.00000  984.05327  0.11%   8.0   96s
#  31231 21124  983.99903  316   30  983.00000  984.05327  0.11%   8.1  100s
#  33997 23331  984.00000  158   35  983.00000  984.05327  0.11%   8.1  105s
#  36473 24278  984.00000  196   39  983.00000  984.05327  0.11%   8.1  110s
# H38672 12922                     984.0000000  984.05327  0.01%   8.1  127s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 4
#   MIR: 14
#   StrongCG: 2
#   Flow cover: 27
#
# Explored 38672 nodes (351209 simplex iterations) in 128.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 984 983 982 ... 980
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.840000000000e+02, best bound 9.840000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2x3

# %%
datafile="4x1000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xe84a9923
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 988.0000000
# Sparsify removed 1854168 nonzeros (93%)
# Presolve added 0 rows and 288 columns
# Presolve removed 55 rows and 0 columns
# Presolve time: 5.12s
# Presolved: 4945 rows, 4288 columns, 139744 nonzeros
# Variable types: 300 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9700000e+02   3.296870e+04   0.000000e+00      5s
#     2057    9.9101716e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 9.910172e+02, 2057 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  991.01716    0  104  988.00000  991.01716  0.31%     -    5s
#      0     0  990.93269    0  137  988.00000  990.93269  0.30%     -    5s
#      0     0  990.92634    0  128  988.00000  990.92634  0.30%     -    6s
#      0     0  990.92487    0  128  988.00000  990.92487  0.30%     -    6s
#      0     0  990.78254    0   83  988.00000  990.78254  0.28%     -    6s
#      0     0  990.72924    0   77  988.00000  990.72924  0.28%     -    6s
#      0     0  990.72924    0   72  988.00000  990.72924  0.28%     -    6s
#      0     0  990.70817    0   70  988.00000  990.70817  0.27%     -    6s
#      0     0  990.69877    0   74  988.00000  990.69877  0.27%     -    6s
#      0     0  990.69877    0   78  988.00000  990.69877  0.27%     -    6s
#      0     0  990.68578    0   75  988.00000  990.68578  0.27%     -    6s
#      0     0  990.68451    0   61  988.00000  990.68451  0.27%     -    6s
#      0     0  990.66765    0   82  988.00000  990.66765  0.27%     -    6s
#      0     0  990.65317    0   91  988.00000  990.65317  0.27%     -    6s
#      0     0  990.60794    0   82  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   84  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   69  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   62  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   67  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   62  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   56  988.00000  990.60794  0.26%     -    7s
#      0     0  990.60794    0   59  988.00000  990.60794  0.26%     -    7s
# H    0     0                     989.0000000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   61  989.00000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   56  989.00000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   48  989.00000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   53  989.00000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   40  989.00000  990.60794  0.16%     -    8s
#      0     0  990.60794    0   47  989.00000  990.60794  0.16%     -    9s
#      0     0  990.60794    0   51  989.00000  990.60794  0.16%     -    9s
#      0     0  990.60794    0   47  989.00000  990.60794  0.16%     -    9s
#      0     2  990.60794    0   38  989.00000  990.60794  0.16%     -    9s
#      9    14  990.60794    4   58  989.00000  990.60794  0.16%   171   10s
#   1679  1488  990.35196   49   47  989.00000  990.60794  0.16%   8.8   15s
#   1687  1493  990.44755   30   45  989.00000  990.44755  0.15%   8.8   20s
#   1696  1499  990.24009   90   26  989.00000  990.33102  0.13%   8.7   25s
#   1706  1507  990.00000  106   60  989.00000  990.33102  0.13%  22.3   30s
#   1716  1514  990.33102   34   42  989.00000  990.33102  0.13%  22.1   35s
#   1724  1519  990.33102  105   31  989.00000  990.33102  0.13%  22.0   40s
#   2687  2880  990.27849  102   52  989.00000  990.32767  0.13%  27.1   45s
#   7867  5910  990.00000  161   25  989.00000  990.32767  0.13%  14.7   50s
# H11564   343                     990.0000000  990.32767  0.03%  12.5   54s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 7
#   MIR: 14
#   StrongCG: 4
#   Flow cover: 10
#   RLT: 1
#
# Explored 11567 nodes (159600 simplex iterations) in 54.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 990 989 988
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.900000000000e+02, best bound 9.900000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2x4

# %%
datafile="4x1000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x54698692
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 997.0000000
# Presolve removed 13 rows and 4 columns (presolve time = 5s) ...
# Sparsify removed 1835516 nonzeros (92%)
# Presolve added 0 rows and 288 columns
# Presolve removed 53 rows and 0 columns
# Presolve time: 5.19s
# Presolved: 4947 rows, 4288 columns, 166372 nonzeros
# Variable types: 292 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9900000e+02   4.184327e+04   0.000000e+00      5s
#     2091    9.9900000e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 9.990000e+02, 2091 iterations, 0.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  999.00000    0  105  997.00000  999.00000  0.20%     -    5s
#      0     0  998.83964    0  135  997.00000  998.83964  0.18%     -    6s
#      0     0  998.82183    0  129  997.00000  998.82183  0.18%     -    6s
#      0     0  998.00000    0   61  997.00000  998.00000  0.10%     -    6s
#      0     0  998.00000    0   64  997.00000  998.00000  0.10%     -    6s
#      0     0  998.00000    0   60  997.00000  998.00000  0.10%     -    6s
#      0     0  998.00000    0   52  997.00000  998.00000  0.10%     -    7s
#      0     0  998.00000    0   24  997.00000  998.00000  0.10%     -    7s
#      0     0  998.00000    0   26  997.00000  998.00000  0.10%     -    7s
#      0     0  998.00000    0   33  997.00000  998.00000  0.10%     -    7s
#      0     0  998.00000    0   30  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   30  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   34  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   26  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   25  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   25  997.00000  998.00000  0.10%     -    8s
#      0     0  998.00000    0   22  997.00000  998.00000  0.10%     -    8s
#      0     2  998.00000    0   22  997.00000  998.00000  0.10%     -    9s
#      2     3  998.00000    1   22  997.00000  998.00000  0.10%   594   10s
# H    3     3                     998.0000000  998.00000  0.00%   396   11s
#
# Explored 3 nodes (24173 simplex iterations) in 11.39 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 998 997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.980000000000e+02, best bound 9.980000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2x5

# %%
datafile="4x1000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xa2389c51
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 983.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Sparsify removed 1836822 nonzeros (92%)
# Presolve added 0 rows and 278 columns
# Presolve removed 57 rows and 0 columns
# Presolve time: 5.27s
# Presolved: 4943 rows, 4278 columns, 149130 nonzeros
# Variable types: 298 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.261071e+04   0.000000e+00      5s
#     1936    9.8562715e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 9.856272e+02, 1936 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  985.62715    0  137  983.00000  985.62715  0.27%     -    5s
#      0     0  985.50231    0  163  983.00000  985.50231  0.25%     -    6s
#      0     0  985.46406    0  156  983.00000  985.46406  0.25%     -    6s
#      0     0  985.46381    0  154  983.00000  985.46381  0.25%     -    6s
#      0     0  985.46380    0  160  983.00000  985.46380  0.25%     -    6s
#      0     0  985.41834    0  124  983.00000  985.41834  0.25%     -    6s
#      0     0  985.38284    0  121  983.00000  985.38284  0.24%     -    6s
#      0     0  985.38226    0  121  983.00000  985.38226  0.24%     -    6s
#      0     0  985.38226    0  125  983.00000  985.38226  0.24%     -    6s
#      0     0  985.26266    0  126  983.00000  985.26266  0.23%     -    6s
#      0     0  985.24939    0  133  983.00000  985.24939  0.23%     -    7s
#      0     0  985.24885    0  119  983.00000  985.24885  0.23%     -    7s
#      0     0  985.24885    0  122  983.00000  985.24885  0.23%     -    7s
#      0     0  985.15683    0  131  983.00000  985.15683  0.22%     -    7s
#      0     0  985.15683    0  126  983.00000  985.15683  0.22%     -    7s
#      0     0  985.12220    0  125  983.00000  985.12220  0.22%     -    7s
#      0     0  985.12212    0  118  983.00000  985.12212  0.22%     -    7s
#      0     0  985.12012    0  105  983.00000  985.12012  0.22%     -    8s
#      0     0  985.11902    0  119  983.00000  985.11902  0.22%     -    8s
#      0     0  985.11886    0  119  983.00000  985.11886  0.22%     -    8s
#      0     0  985.11886    0  126  983.00000  985.11886  0.22%     -    8s
# H    0     0                     984.0000000  985.11886  0.11%     -    8s
#      0     0  985.11819    0  128  984.00000  985.11819  0.11%     -    8s
#      0     0  985.11685    0  117  984.00000  985.11685  0.11%     -    8s
#      0     0  985.11685    0  107  984.00000  985.11685  0.11%     -    8s
#      0     0  985.11685    0   98  984.00000  985.11685  0.11%     -    8s
#      0     0  985.11685    0  102  984.00000  985.11685  0.11%     -    9s
#      0     0  985.11685    0  108  984.00000  985.11685  0.11%     -    9s
#      0     0  985.11685    0  101  984.00000  985.11685  0.11%     -    9s
#      0     0  985.11685    0   70  984.00000  985.11685  0.11%     -    9s
#      0     0  985.11685    0   83  984.00000  985.11685  0.11%     -   10s
#      0     0  985.11685    0   64  984.00000  985.11685  0.11%     -   10s
#      0     0  985.11685    0   54  984.00000  985.11685  0.11%     -   10s
#      0     2  985.11685    0   54  984.00000  985.11685  0.11%     -   11s
#   1354  1177  985.02455   42   54  984.00000  985.10454  0.11%  10.4   15s
#   1370  1188  985.02295   26   48  984.00000  985.02295  0.10%  10.3   20s
#   1388  1201  985.02295   15   37  984.00000  985.02295  0.10%  30.0   25s
#   1411  1216  985.02082   15   29  984.00000  985.02082  0.10%  29.5   30s
#   3531  2589  985.01211   51   37  984.00000  985.01369  0.10%  22.3   35s
#  10111  5923  985.00409   76   40  984.00000  985.01283  0.10%  12.3   40s
#  13387  7603  985.00260   60   51  984.00000  985.01259  0.10%  11.7   45s
#  17635 10616  985.00616   65   37  984.00000  985.01165  0.10%  11.3   50s
#  22418 13171  985.00446   73   38  984.00000  985.01156  0.10%  10.8   56s
#  25690 14420  985.00407   98   54  984.00000  985.01154  0.10%  10.5   69s
#  25692 14421  985.00303  109  134  984.00000  985.01154  0.10%  10.5   70s
#  25701 14427  985.00500   72   61  984.00000  985.01154  0.10%  10.5   75s
#  25708 14432  985.00000   54   29  984.00000  985.00000  0.10%  10.5   80s
#  25716 14437  985.00000   62   20  984.00000  985.00000  0.10%  10.5   85s
#  25726 14445  985.00000   57   51  984.00000  985.00000  0.10%  11.5   90s
#  25733 14450  985.00000   52   16  984.00000  985.00000  0.10%  11.5   95s
#  25739 14454  985.00000   75   16  984.00000  985.00000  0.10%  11.5  100s
#  26826 15327  985.00000  128   17  984.00000  985.00000  0.10%  12.3  105s
#  28910 16544  985.00000  331    5  984.00000  985.00000  0.10%  11.7  110s
#  31509 18728  985.00000  325    8  984.00000  985.00000  0.10%  11.4  115s
#  35874 20780  985.00000  518   13  984.00000  985.00000  0.10%  10.9  120s
# *38202 10927             765     985.0000000  985.00000  0.00%  10.7  123s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 11
#   MIR: 29
#   StrongCG: 3
#   Flow cover: 51
#   GUB cover: 1
#   Inf proof: 1
#   RLT: 1
#
# Explored 39021 nodes (439436 simplex iterations) in 123.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 985 984 983
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.850000000000e+02, best bound 9.850000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2.5x1

# %%
datafile="4x1000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x85a33b91
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 869.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1850656 nonzeros (93%)
# Presolve added 0 rows and 280 columns
# Presolve removed 70 rows and 0 columns
# Presolve time: 6.08s
# Presolved: 4930 rows, 4280 columns, 131264 nonzeros
# Variable types: 304 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.209851e+04   0.000000e+00      6s
#     2565    8.8772072e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 8.877207e+02, 2565 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  887.72072    0  107  869.00000  887.72072  2.15%     -    6s
# H    0     0                     884.0000000  887.72072  0.42%     -    6s
# H    0     0                     885.0000000  887.72072  0.31%     -    6s
#      0     0  887.70991    0   96  885.00000  887.70991  0.31%     -    6s
# H    0     0                     886.0000000  887.70991  0.19%     -    7s
#      0     0  887.66549    0   93  886.00000  887.66549  0.19%     -    7s
#      0     0  887.66484    0   90  886.00000  887.66484  0.19%     -    7s
#      0     0  887.66398    0   85  886.00000  887.66398  0.19%     -    7s
#      0     0  887.66398    0   86  886.00000  887.66398  0.19%     -    7s
#      0     0  887.66387    0   95  886.00000  887.66387  0.19%     -    7s
#      0     0  887.63561    0   90  886.00000  887.63561  0.18%     -    7s
#      0     0  887.63351    0   88  886.00000  887.63351  0.18%     -    7s
#      0     0  887.63351    0   90  886.00000  887.63351  0.18%     -    7s
#      0     0  887.63321    0   94  886.00000  887.63321  0.18%     -    8s
#      0     0  887.63321    0   85  886.00000  887.63321  0.18%     -    8s
#      0     0  887.63312    0   87  886.00000  887.63312  0.18%     -    8s
#      0     0  887.63218    0   84  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   83  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   70  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   77  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   90  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   81  886.00000  887.63218  0.18%     -    9s
#      0     0  887.63218    0   57  886.00000  887.63218  0.18%     -   10s
#      0     0  887.63218    0   66  886.00000  887.63218  0.18%     -   10s
#      0     0  887.63218    0   69  886.00000  887.63218  0.18%     -   10s
#      0     0  887.63218    0   69  886.00000  887.63218  0.18%     -   10s
#      0     0  887.63218    0   66  886.00000  887.63218  0.18%     -   11s
#      0     0  887.63218    0   64  886.00000  887.63218  0.18%     -   11s
#      0     2  887.63218    0   59  886.00000  887.63218  0.18%     -   11s
# H   84    87                     887.0000001  887.63218  0.07%  26.6   12s
#
# Cutting planes:
#   Gomory: 22
#   Cover: 1
#   MIR: 180
#   StrongCG: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 88 nodes (11809 simplex iterations) in 12.95 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 887 886 885 ... 869
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.870000001046e+02, best bound 8.870000001046e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2.5x2

# %%
datafile="4x1000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xad832973
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 871.0000000
# Sparsify removed 1843586 nonzeros (92%)
# Presolve added 0 rows and 290 columns
# Presolve removed 49 rows and 0 columns
# Presolve time: 5.09s
# Presolved: 4951 rows, 4290 columns, 158322 nonzeros
# Variable types: 294 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9900000e+02   3.643836e+04   0.000000e+00      5s
#     2791    8.9000332e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.900033e+02, 2791 iterations, 0.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  890.00332    0  180  871.00000  890.00332  2.18%     -    5s
# H    0     0                     882.0000000  890.00332  0.91%     -    5s
# H    0     0                     886.0000000  890.00332  0.45%     -    5s
# H    0     0                     887.0000000  890.00332  0.34%     -    6s
#      0     0  889.97504    0  166  887.00000  889.97504  0.34%     -    6s
# H    0     0                     888.0000000  889.97504  0.22%     -    6s
#      0     0  889.48333    0  136  888.00000  889.48333  0.17%     -    6s
#      0     0  889.48069    0  131  888.00000  889.48069  0.17%     -    6s
#      0     0  889.48069    0  136  888.00000  889.48069  0.17%     -    6s
#      0     0  889.46337    0  141  888.00000  889.46337  0.16%     -    6s
#      0     0  889.46337    0  117  888.00000  889.46337  0.16%     -    6s
#      0     0  889.46337    0  117  888.00000  889.46337  0.16%     -    7s
#      0     0  889.46337    0  111  888.00000  889.46337  0.16%     -    7s
#      0     0  889.46337    0  102  888.00000  889.46337  0.16%     -    7s
#      0     0  889.46337    0   95  888.00000  889.46337  0.16%     -    7s
#      0     0  889.46337    0   88  888.00000  889.46337  0.16%     -    7s
#      0     0  889.45748    0   64  888.00000  889.45748  0.16%     -    8s
#      0     0  889.45613    0   88  888.00000  889.45613  0.16%     -    8s
#      0     0  889.45613    0   94  888.00000  889.45613  0.16%     -    8s
#      0     0  889.45613    0   93  888.00000  889.45613  0.16%     -    8s
#      0     0  889.42902    0   93  888.00000  889.42902  0.16%     -    9s
#      0     0  889.42902    0   86  888.00000  889.42902  0.16%     -    9s
#      0     0  889.42902    0  103  888.00000  889.42902  0.16%     -    9s
#      0     0  889.42902    0  101  888.00000  889.42902  0.16%     -    9s
#      0     0  889.42902    0  110  888.00000  889.42902  0.16%     -    9s
#      0     0  889.41722    0  111  888.00000  889.41722  0.16%     -    9s
#      0     0  889.41722    0  106  888.00000  889.41722  0.16%     -   10s
#      0     0  889.37383    0   85  888.00000  889.37383  0.15%     -   10s
#      0     0  889.37347    0   79  888.00000  889.37347  0.15%     -   10s
#      0     0  889.37347    0   81  888.00000  889.37347  0.15%     -   10s
#      0     0  889.36999    0  104  888.00000  889.36999  0.15%     -   11s
#      0     0  889.36959    0   92  888.00000  889.36959  0.15%     -   11s
#      0     0  889.36959    0  103  888.00000  889.36959  0.15%     -   11s
#      0     0  889.36648    0  108  888.00000  889.36648  0.15%     -   11s
#      0     0  889.35780    0  100  888.00000  889.35780  0.15%     -   11s
#      0     0  889.35780    0   95  888.00000  889.35780  0.15%     -   11s
#      0     0  889.35780    0   88  888.00000  889.35780  0.15%     -   11s
#      0     0  889.35780    0   90  888.00000  889.35780  0.15%     -   11s
#      0     0  889.35780    0  101  888.00000  889.35780  0.15%     -   12s
#      0     0  889.35780    0   92  888.00000  889.35780  0.15%     -   12s
#      0     0  889.35740    0   71  888.00000  889.35740  0.15%     -   13s
#      0     0  889.35740    0   88  888.00000  889.35740  0.15%     -   13s
#      0     0  889.35317    0   82  888.00000  889.35317  0.15%     -   13s
#      0     0  889.35317    0   84  888.00000  889.35317  0.15%     -   13s
#      0     0  889.35317    0   94  888.00000  889.35317  0.15%     -   13s
#      0     0  889.35317    0   92  888.00000  889.35317  0.15%     -   14s
#      0     0  889.35317    0   96  888.00000  889.35317  0.15%     -   14s
#      0     0  889.35317    0   75  888.00000  889.35317  0.15%     -   14s
#      0     2  889.35317    0   67  888.00000  889.35317  0.15%     -   15s
# H  148   266                     889.0000000  889.35317  0.04%  20.4   17s
#
# Cutting planes:
#   Gomory: 8
#   Implied bound: 4
#   MIR: 191
#   StrongCG: 1
#
# Explored 265 nodes (23836 simplex iterations) in 17.11 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 889 888 887 ... 871
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.890000000000e+02, best bound 8.890000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2.5x3

# %%
datafile="4x1000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x1d54a5ec
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 861.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Sparsify removed 1854822 nonzeros (93%)
# Presolve added 0 rows and 286 columns
# Presolve removed 66 rows and 0 columns
# Presolve time: 5.15s
# Presolved: 4934 rows, 4286 columns, 135094 nonzeros
# Variable types: 302 continuous, 3984 integer (3984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9600000e+02   3.384839e+04   0.000000e+00      5s
#     2927    8.8228231e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.822823e+02, 2927 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  882.28231    0  154  861.00000  882.28231  2.47%     -    5s
# H    0     0                     874.0000000  882.28231  0.95%     -    5s
# H    0     0                     878.0000000  882.28231  0.49%     -    5s
# H    0     0                     879.0000000  882.28231  0.37%     -    6s
#      0     0  882.27027    0  165  879.00000  882.27027  0.37%     -    6s
#      0     0  881.89558    0  165  879.00000  881.89558  0.33%     -    6s
# H    0     0                     880.0000000  881.89558  0.22%     -    6s
#      0     0  881.89484    0  164  880.00000  881.89484  0.22%     -    6s
#      0     0  881.89409    0  165  880.00000  881.89409  0.22%     -    6s
#      0     0  881.89345    0  166  880.00000  881.89345  0.22%     -    6s
#      0     0  881.89345    0  167  880.00000  881.89345  0.22%     -    6s
#      0     0  881.88216    0  138  880.00000  881.88216  0.21%     -    6s
#      0     0  881.87651    0  147  880.00000  881.87651  0.21%     -    6s
#      0     0  881.83153    0  125  880.00000  881.83153  0.21%     -    7s
#      0     0  881.83153    0  115  880.00000  881.83153  0.21%     -    7s
#      0     0  881.83153    0  121  880.00000  881.83153  0.21%     -    7s
#      0     0  881.83153    0  108  880.00000  881.83153  0.21%     -    7s
#      0     0  881.82522    0  137  880.00000  881.82522  0.21%     -    7s
#      0     0  881.82487    0  126  880.00000  881.82487  0.21%     -    8s
#      0     0  881.82338    0  120  880.00000  881.82338  0.21%     -    8s
#      0     0  881.82338    0  125  880.00000  881.82338  0.21%     -    8s
#      0     0  881.80933    0  121  880.00000  881.80933  0.21%     -    8s
#      0     0  881.80932    0  123  880.00000  881.80932  0.21%     -    8s
#      0     0  881.80530    0  105  880.00000  881.80530  0.21%     -    8s
#      0     0  881.77822    0  138  880.00000  881.77822  0.20%     -    9s
#      0     0  881.77711    0  128  880.00000  881.77711  0.20%     -    9s
#      0     0  881.77711    0  133  880.00000  881.77711  0.20%     -    9s
#      0     0  881.58241    0  136  880.00000  881.58241  0.18%     -    9s
#      0     0  881.57958    0  141  880.00000  881.57958  0.18%     -    9s
#      0     0  881.57900    0  140  880.00000  881.57900  0.18%     -    9s
#      0     0  881.57868    0  138  880.00000  881.57868  0.18%     -   10s
#      0     0  881.57863    0  141  880.00000  881.57863  0.18%     -   10s
#      0     0  881.45602    0  128  880.00000  881.45602  0.17%     -   10s
#      0     0  881.45400    0  136  880.00000  881.45400  0.17%     -   10s
#      0     0  881.45391    0  117  880.00000  881.45391  0.17%     -   10s
#      0     0  881.45317    0  118  880.00000  881.45317  0.17%     -   10s
#      0     0  881.45317    0  131  880.00000  881.45317  0.17%     -   10s
#      0     0  881.45168    0  128  880.00000  881.45168  0.16%     -   10s
#      0     0  881.45168    0  103  880.00000  881.45168  0.16%     -   11s
# H    0     0                     881.0000000  881.45168  0.05%     -   11s
#      0     0  881.45168    0  103  881.00000  881.45168  0.05%     -   11s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 20
#   Implied bound: 1
#   MIR: 77
#   StrongCG: 18
#   RLT: 4
#
# Explored 1 nodes (12460 simplex iterations) in 11.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 881 880 879 ... 861
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.810000000000e+02, best bound 8.810000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2.5x4

# %%
datafile="4x1000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x60e3bd6a
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 861.0000000
# Sparsify removed 1840203 nonzeros (93%)
# Presolve removed 60 rows and 3665 columns (presolve time = 5s) ...
# Presolve added 0 rows and 279 columns
# Presolve removed 60 rows and 0 columns
# Presolve time: 5.13s
# Presolved: 4940 rows, 4279 columns, 145732 nonzeros
# Variable types: 299 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.677042e+04   0.000000e+00      5s
#     2641    8.8458079e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.845808e+02, 2641 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  884.58079    0  284  861.00000  884.58079  2.74%     -    5s
# H    0     0                     875.0000000  884.58079  1.09%     -    5s
# H    0     0                     878.0000000  884.58079  0.75%     -    5s
# H    0     0                     880.0000000  884.58079  0.52%     -    6s
#      0     0  884.47013    0  311  880.00000  884.47013  0.51%     -    6s
# H    0     0                     882.0000000  884.47013  0.28%     -    6s
#      0     0  884.35291    0  281  882.00000  884.35291  0.27%     -    6s
#      0     0  884.24884    0  274  882.00000  884.24884  0.25%     -    6s
#      0     0  884.24792    0  273  882.00000  884.24792  0.25%     -    6s
#      0     0  884.24791    0  273  882.00000  884.24791  0.25%     -    6s
#      0     0  884.23163    0  246  882.00000  884.23163  0.25%     -    6s
#      0     0  883.87714    0  199  882.00000  883.87714  0.21%     -    7s
#      0     0  883.87552    0  199  882.00000  883.87552  0.21%     -    7s
#      0     0  883.87552    0  192  882.00000  883.87552  0.21%     -    7s
#      0     0  883.87414    0  221  882.00000  883.87414  0.21%     -    7s
#      0     0  883.87374    0  188  882.00000  883.87374  0.21%     -    7s
#      0     0  883.87374    0  177  882.00000  883.87374  0.21%     -    7s
#      0     0  883.87347    0  212  882.00000  883.87347  0.21%     -    8s
#      0     0  883.87304    0  190  882.00000  883.87304  0.21%     -    8s
#      0     0  883.87304    0  177  882.00000  883.87304  0.21%     -    8s
#      0     0  883.86420    0  203  882.00000  883.86420  0.21%     -    8s
#      0     0  883.86388    0  195  882.00000  883.86388  0.21%     -    8s
#      0     0  883.86359    0  181  882.00000  883.86359  0.21%     -    8s
#      0     0  883.86359    0  180  882.00000  883.86359  0.21%     -    9s
#      0     0  883.80420    0  155  882.00000  883.80420  0.20%     -    9s
#      0     0  883.78020    0  168  882.00000  883.78020  0.20%     -    9s
#      0     0  883.78020    0  166  882.00000  883.78020  0.20%     -    9s
#      0     0  883.69633    0  146  882.00000  883.69633  0.19%     -    9s
#      0     0  883.69633    0  163  882.00000  883.69633  0.19%     -    9s
#      0     0  883.69633    0  163  882.00000  883.69633  0.19%     -   10s
#      0     0  883.69633    0  160  882.00000  883.69633  0.19%     -   10s
#      0     0  883.69630    0  146  882.00000  883.69630  0.19%     -   10s
#      0     0  883.69630    0  159  882.00000  883.69630  0.19%     -   11s
#      0     0  883.69547    0  167  882.00000  883.69547  0.19%     -   11s
#      0     0  883.69547    0  121  882.00000  883.69547  0.19%     -   11s
#      0     2  883.69547    0  121  882.00000  883.69547  0.19%     -   12s
#    207   455  883.68329   23  127  882.00000  883.69513  0.19%  21.7   15s
# H  796   866                     883.0000000  883.69513  0.08%  12.1   16s
#
# Cutting planes:
#   Gomory: 13
#   Implied bound: 3
#   MIR: 301
#   StrongCG: 2
#   RLT: 9
#   Relax-and-lift: 4
#
# Explored 991 nodes (30566 simplex iterations) in 16.88 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 883 882 880 ... 861
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.830000000000e+02, best bound 8.830000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x2.5x5

# %%
datafile="4x1000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x1f97619d
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 867.0000000
# Presolve removed 47 rows and 28 columns (presolve time = 5s) ...
# Sparsify removed 1845860 nonzeros (93%)
# Presolve added 0 rows and 276 columns
# Presolve removed 71 rows and 0 columns
# Presolve time: 5.15s
# Presolved: 4929 rows, 4276 columns, 132104 nonzeros
# Variable types: 304 continuous, 3972 integer (3972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9300000e+02   3.286103e+04   0.000000e+00      5s
#     3149    8.8626568e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.862657e+02, 3149 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  886.26568    0  309  867.00000  886.26568  2.22%     -    5s
# H    0     0                     882.0000000  886.26568  0.48%     -    5s
# H    0     0                     883.0000000  886.26568  0.37%     -    5s
#      0     0  886.26328    0  331  883.00000  886.26328  0.37%     -    6s
# H    0     0                     884.0000000  886.26328  0.26%     -    6s
#      0     0  885.80927    0  321  884.00000  885.80927  0.20%     -    6s
#      0     0  885.80686    0  323  884.00000  885.80686  0.20%     -    6s
#      0     0  885.80674    0  327  884.00000  885.80674  0.20%     -    6s
#      0     0  885.77371    0  243  884.00000  885.77371  0.20%     -    6s
#      0     0  885.70709    0  204  884.00000  885.70709  0.19%     -    6s
#      0     0  885.68475    0  216  884.00000  885.68475  0.19%     -    6s
#      0     0  885.68208    0  211  884.00000  885.68208  0.19%     -    6s
#      0     0  885.68201    0  210  884.00000  885.68201  0.19%     -    6s
#      0     0  885.46115    0  220  884.00000  885.46115  0.17%     -    7s
#      0     0  885.46097    0  193  884.00000  885.46097  0.17%     -    7s
#      0     0  885.46097    0  191  884.00000  885.46097  0.17%     -    7s
#      0     0  885.40660    0  194  884.00000  885.40660  0.16%     -    7s
#      0     0  885.34151    0  163  884.00000  885.34151  0.15%     -    7s
#      0     0  885.34151    0  177  884.00000  885.34151  0.15%     -    8s
#      0     0  885.34013    0  188  884.00000  885.34013  0.15%     -    8s
#      0     0  885.33972    0  187  884.00000  885.33972  0.15%     -    8s
#      0     0  885.33938    0  187  884.00000  885.33938  0.15%     -    8s
#      0     0  885.33928    0  189  884.00000  885.33928  0.15%     -    8s
#      0     0  885.33721    0  181  884.00000  885.33721  0.15%     -    8s
#      0     0  885.33721    0  177  884.00000  885.33721  0.15%     -    9s
#      0     0  885.33560    0  200  884.00000  885.33560  0.15%     -    9s
#      0     0  885.33496    0  181  884.00000  885.33496  0.15%     -    9s
#      0     0  885.33439    0  166  884.00000  885.33439  0.15%     -    9s
#      0     0  885.33439    0  177  884.00000  885.33439  0.15%     -    9s
#      0     0  885.33382    0  169  884.00000  885.33382  0.15%     -    9s
#      0     0  885.33376    0  159  884.00000  885.33376  0.15%     -    9s
#      0     0  885.33376    0  169  884.00000  885.33376  0.15%     -   10s
#      0     0  885.33376    0  131  884.00000  885.33376  0.15%     -   10s
#      0     2  885.33376    0  122  884.00000  885.33376  0.15%     -   11s
# H  279   369                     885.0000000  885.33369  0.04%  25.4   13s
#
# Cutting planes:
#   Gomory: 25
#   Cover: 3
#   Implied bound: 8
#   MIR: 242
#   StrongCG: 3
#   RLT: 4
#   Relax-and-lift: 3
#
# Explored 368 nodes (23351 simplex iterations) in 13.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 885 884 883 ... 867
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.850000000000e+02, best bound 8.850000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3x1

# %%
datafile="4x1000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xfbce23de
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 775.0000000
# Presolve removed 58 rows and 40 columns (presolve time = 5s) ...
# Sparsify removed 1850879 nonzeros (94%)
# Presolve added 0 rows and 271 columns
# Presolve removed 74 rows and 0 columns
# Presolve time: 6.03s
# Presolved: 4926 rows, 4271 columns, 115209 nonzeros
# Variable types: 311 continuous, 3960 integer (3960 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9000000e+02   3.004180e+04   0.000000e+00      6s
#     2897    8.0475168e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 8.047517e+02, 2897 iterations, 0.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  804.75168    0  123  775.00000  804.75168  3.84%     -    6s
# H    0     0                     797.0000000  804.75168  0.97%     -    6s
# H    0     0                     801.0000000  804.75168  0.47%     -    6s
# H    0     0                     802.0000000  804.75168  0.34%     -    6s
# H    0     0                     803.0000000  804.75168  0.22%     -    6s
#      0     0  804.71947    0  110  803.00000  804.71947  0.21%     -    6s
#      0     0  804.65170    0  124  803.00000  804.65170  0.21%     -    7s
#      0     0  804.65131    0  124  803.00000  804.65131  0.21%     -    7s
#      0     0  804.65128    0  125  803.00000  804.65128  0.21%     -    7s
#      0     0  804.60596    0   87  803.00000  804.60596  0.20%     -    7s
#      0     0  804.39540    0   84  803.00000  804.39540  0.17%     -    7s
#      0     0  804.39540    0   81  803.00000  804.39540  0.17%     -    7s
#      0     0  804.27552    0   66  803.00000  804.27552  0.16%     -    7s
#      0     0  804.27252    0   68  803.00000  804.27252  0.16%     -    8s
#      0     0  804.27206    0   71  803.00000  804.27206  0.16%     -    8s
#      0     0  804.27206    0   71  803.00000  804.27206  0.16%     -    8s
#      0     0  804.26167    0   68  803.00000  804.26167  0.16%     -    8s
#      0     0  804.25160    0   64  803.00000  804.25160  0.16%     -    8s
#      0     0  804.25014    0   69  803.00000  804.25014  0.16%     -    8s
#      0     0  804.25014    0   69  803.00000  804.25014  0.16%     -    8s
#      0     0  804.22097    0   64  803.00000  804.22097  0.15%     -    8s
#      0     0  804.22097    0   62  803.00000  804.22097  0.15%     -    9s
#      0     0  804.22097    0   61  803.00000  804.22097  0.15%     -    9s
#      0     0  804.22097    0   67  803.00000  804.22097  0.15%     -    9s
#      0     0  804.22097    0   47  803.00000  804.22097  0.15%     -    9s
#      0     0  804.22097    0   54  803.00000  804.22097  0.15%     -   10s
#      0     0  804.22097    0   53  803.00000  804.22097  0.15%     -   10s
#      0     0  804.22097    0   48  803.00000  804.22097  0.15%     -   10s
#      0     0  804.22097    0   53  803.00000  804.22097  0.15%     -   11s
#      0     0  804.22097    0   53  803.00000  804.22097  0.15%     -   11s
#      0     2  804.22097    0   53  803.00000  804.22097  0.15%     -   12s
# H  217   417                     804.0000000  804.22097  0.03%  16.6   13s
#
# Cutting planes:
#   Gomory: 17
#   MIR: 104
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 429 nodes (17770 simplex iterations) in 13.29 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 804 803 802 ... 775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.040000000000e+02, best bound 8.040000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3x2

# %%
datafile="4x1000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x122e867f
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 769.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1850656 nonzeros (93%)
# Presolve added 0 rows and 280 columns
# Presolve removed 62 rows and 0 columns
# Presolve time: 5.16s
# Presolved: 4938 rows, 4280 columns, 131308 nonzeros
# Variable types: 304 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.786937e+04   0.000000e+00      5s
#     2970    8.0068047e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.006805e+02, 2970 iterations, 0.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  800.68047    0  153  769.00000  800.68047  4.12%     -    5s
# H    0     0                     795.0000000  800.68047  0.71%     -    5s
# H    0     0                     798.0000000  800.68047  0.34%     -    5s
#      0     0  800.66813    0  159  798.00000  800.66813  0.33%     -    6s
# H    0     0                     799.0000000  800.66813  0.21%     -    6s
#      0     0  800.35608    0  160  799.00000  800.35608  0.17%     -    6s
#      0     0  800.14227    0  109  799.00000  800.14227  0.14%     -    6s
#      0     0  800.05936    0  109  799.00000  800.05936  0.13%     -    6s
#      0     0  800.04789    0  107  799.00000  800.04789  0.13%     -    6s
#      0     0  800.04656    0  103  799.00000  800.04656  0.13%     -    6s
#      0     0  800.04595    0   98  799.00000  800.04595  0.13%     -    6s
#      0     0  800.03959    0   92  799.00000  800.03959  0.13%     -    6s
#      0     0  800.03959    0   92  799.00000  800.03959  0.13%     -    6s
#      0     0     cutoff    0       799.00000  799.00000  0.00%     -    6s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 5
#   Implied bound: 1
#   MIR: 183
#   StrongCG: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (7213 simplex iterations) in 7.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 799 798 795 769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.990000000000e+02, best bound 7.990000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3x3

# %%
datafile="4x1000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xf5339f1b
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 769.0000000
# Presolve removed 25 rows and 20 columns (presolve time = 5s) ...
# Sparsify removed 1843556 nonzeros (93%)
# Presolve added 0 rows and 280 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 5.17s
# Presolved: 4959 rows, 4280 columns, 142444 nonzeros
# Variable types: 300 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.727365e+04   0.000000e+00      5s
#     3037    8.0100756e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 8.010076e+02, 3037 iterations, 0.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  801.00756    0  130  769.00000  801.00756  4.16%     -    5s
# H    0     0                     796.0000000  801.00756  0.63%     -    5s
# H    0     0                     797.0000000  801.00756  0.50%     -    5s
# H    0     0                     798.0000000  801.00756  0.38%     -    6s
#      0     0  800.98305    0  126  798.00000  800.98305  0.37%     -    6s
# H    0     0                     799.0000000  800.98305  0.25%     -    6s
#      0     0  800.89906    0  129  799.00000  800.89906  0.24%     -    6s
#      0     0  800.88944    0  130  799.00000  800.88944  0.24%     -    6s
#      0     0  800.88944    0  126  799.00000  800.88944  0.24%     -    6s
#      0     0  800.54714    0   78  799.00000  800.54714  0.19%     -    6s
#      0     0  800.54033    0   82  799.00000  800.54033  0.19%     -    6s
#      0     0  800.54030    0   75  799.00000  800.54030  0.19%     -    6s
#      0     0  800.41618    0   66  799.00000  800.41618  0.18%     -    7s
#      0     0  800.41565    0   73  799.00000  800.41565  0.18%     -    7s
#      0     0  800.41512    0   73  799.00000  800.41512  0.18%     -    7s
#      0     0  800.41512    0   73  799.00000  800.41512  0.18%     -    7s
#      0     0  800.35534    0   78  799.00000  800.35534  0.17%     -    7s
#      0     0  800.35531    0   75  799.00000  800.35531  0.17%     -    7s
#      0     0  800.28367    0   77  799.00000  800.28367  0.16%     -    8s
#      0     0  800.28319    0   73  799.00000  800.28319  0.16%     -    8s
#      0     0  800.28319    0   69  799.00000  800.28319  0.16%     -    8s
#      0     0  800.28319    0   62  799.00000  800.28319  0.16%     -    8s
#      0     0  800.28319    0   63  799.00000  800.28319  0.16%     -    8s
#      0     0  800.28319    0   66  799.00000  800.28319  0.16%     -    9s
#      0     0  800.28319    0   68  799.00000  800.28319  0.16%     -    9s
#      0     0  800.28195    0   39  799.00000  800.28195  0.16%     -    9s
#      0     0  800.28195    0   40  799.00000  800.28195  0.16%     -    9s
#      0     0  800.28195    0   54  799.00000  800.28195  0.16%     -   10s
#      0     0  800.28195    0   49  799.00000  800.28195  0.16%     -   10s
#      0     0  800.28195    0   49  799.00000  800.28195  0.16%     -   10s
#      0     0  800.28195    0   47  799.00000  800.28195  0.16%     -   10s
#      0     2  800.28195    0   46  799.00000  800.28195  0.16%     -   11s
#    977   977  800.01345  103   31  799.00000  800.28195  0.16%   6.8   15s
#   3326  3112  800.01164   93   47  799.00000  800.28195  0.16%   6.0   20s
#   3332  3116  800.14605  332   37  799.00000  800.27373  0.16%   6.0   25s
#   3337  3119  800.15126   76   44  799.00000  800.22980  0.15%   6.0   30s
#   3345  3125  800.05316   63   38  799.00000  800.18164  0.15%   6.0   35s
#   3355  3131  800.06744  263   35  799.00000  800.16598  0.15%   6.0   40s
#   3370  3141  800.06744  136   51  799.00000  800.15328  0.14%   5.9   45s
#   3386  3153  800.14952   62  121  799.00000  800.14952  0.14%  20.8   50s
#   3395  3159  800.02464   80   45  799.00000  800.14491  0.14%  20.8   55s
#   3405  3166  800.06744  105   35  799.00000  800.13081  0.14%  20.7   60s
#   3414  3172  800.00766  234   37  799.00000  800.12380  0.14%  20.7   65s
#   3423  3178  800.00766  167   21  799.00000  800.10073  0.14%  20.6   70s
#   3435  3187  800.00525  140   57  799.00000  800.10073  0.14%  28.8   75s
#   3442  3192  800.00766  253   51  799.00000  800.10073  0.14%  28.8   80s
#   3451  3198  800.10073  359   32  799.00000  800.10073  0.14%  28.7   85s
# H 3936  3501                     800.0000000  800.10073  0.01%  32.3   89s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 7
#   MIR: 29
#   StrongCG: 6
#   Flow cover: 19
#   GUB cover: 2
#   Zero half: 1
#   RLT: 2
#
# Explored 4076 nodes (138736 simplex iterations) in 89.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 800 799 798 ... 769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+02, best bound 8.000000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3x4

# %%
datafile="4x1000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x7e9e77d3
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 780.0000000
# Presolve removed 48 rows and 32 columns (presolve time = 5s) ...
# Sparsify removed 1855347 nonzeros (94%)
# Presolve added 0 rows and 277 columns
# Presolve removed 64 rows and 0 columns
# Presolve time: 6.09s
# Presolved: 4936 rows, 4277 columns, 118653 nonzeros
# Variable types: 309 continuous, 3968 integer (3968 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9200000e+02   2.588652e+04   0.000000e+00      6s
#     2912    8.0688191e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 8.068819e+02, 2912 iterations, 0.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  806.88191    0   91  780.00000  806.88191  3.45%     -    6s
# H    0     0                     802.0000000  806.88191  0.61%     -    6s
# H    0     0                     803.0000000  806.88191  0.48%     -    6s
#      0     0  806.49227    0  104  803.00000  806.49227  0.43%     -    6s
# H    0     0                     804.0000000  806.49227  0.31%     -    6s
# H    0     0                     805.0000000  806.49227  0.19%     -    7s
#      0     0  806.33263    0  104  805.00000  806.33263  0.17%     -    7s
#      0     0  806.33263    0  103  805.00000  806.33263  0.17%     -    7s
#      0     0  806.33263    0   76  805.00000  806.33263  0.17%     -    7s
#      0     0  806.33003    0   74  805.00000  806.33003  0.17%     -    7s
#      0     0  806.32998    0   75  805.00000  806.32998  0.17%     -    7s
#      0     0  806.12456    0   74  805.00000  806.12456  0.14%     -    8s
#      0     0  806.12455    0   76  805.00000  806.12455  0.14%     -    8s
#      0     0  806.11847    0   67  805.00000  806.11847  0.14%     -    8s
#      0     0  806.11613    0   65  805.00000  806.11613  0.14%     -    8s
#      0     0  806.11556    0   56  805.00000  806.11556  0.14%     -    8s
#      0     0  806.11529    0   67  805.00000  806.11529  0.14%     -    8s
#      0     0  806.11529    0   68  805.00000  806.11529  0.14%     -    8s
#      0     0  806.09531    0   63  805.00000  806.09531  0.14%     -    8s
#      0     0  806.09152    0   74  805.00000  806.09152  0.14%     -    9s
#      0     0  806.09152    0   76  805.00000  806.09152  0.14%     -    9s
#      0     0  806.04647    0   55  805.00000  806.04647  0.13%     -    9s
#      0     0  806.04330    0   55  805.00000  806.04330  0.13%     -    9s
#      0     0  806.04330    0   59  805.00000  806.04330  0.13%     -    9s
#      0     0  806.00914    0   58  805.00000  806.00914  0.13%     -    9s
#      0     0  806.00914    0   67  805.00000  806.00914  0.13%     -    9s
#      0     0  806.00914    0   67  805.00000  806.00914  0.13%     -    9s
#      0     0  806.00914    0   59  805.00000  806.00914  0.13%     -    9s
#      0     0  806.00914    0   53  805.00000  806.00914  0.13%     -   10s
#      0     0  806.00914    0   55  805.00000  806.00914  0.13%     -   10s
#      0     0  806.00732    0   55  805.00000  806.00732  0.13%     -   10s
#      0     0  806.00732    0   55  805.00000  806.00732  0.13%     -   10s
#      0     0  806.00732    0   86  805.00000  806.00732  0.13%     -   11s
#      0     0  806.00732    0  101  805.00000  806.00732  0.13%     -   11s
#      0     0  806.00732    0   84  805.00000  806.00732  0.13%     -   11s
#      0     0     cutoff    0       805.00000  805.00000  0.00%     -   11s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 3
#   Implied bound: 1
#   MIR: 40
#   StrongCG: 3
#   GUB cover: 4
#   RLT: 3
#   Relax-and-lift: 2
#
# Explored 1 nodes (16198 simplex iterations) in 11.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 805 804 803 ... 780
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+02, best bound 8.050000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3x5

# %%
datafile="4x1000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x44a8983a
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 776.0000000
# Presolve removed 47 rows and 28 columns (presolve time = 5s) ...
# Sparsify removed 1842657 nonzeros (93%)
# Presolve added 0 rows and 275 columns
# Presolve removed 91 rows and 0 columns
# Presolve time: 6.08s
# Presolved: 4909 rows, 4275 columns, 135255 nonzeros
# Variable types: 303 continuous, 3972 integer (3972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9300000e+02   3.516328e+04   0.000000e+00      6s
#     2965    8.0474639e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 8.047464e+02, 2965 iterations, 0.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  804.74639    0  111  776.00000  804.74639  3.70%     -    6s
# H    0     0                     800.0000000  804.74639  0.59%     -    6s
# H    0     0                     802.0000000  804.74639  0.34%     -    6s
#      0     0  804.74247    0  134  802.00000  804.74247  0.34%     -    6s
# H    0     0                     803.0000000  804.74247  0.22%     -    7s
#      0     0  804.48143    0  118  803.00000  804.48143  0.18%     -    7s
#      0     0  804.48141    0  121  803.00000  804.48141  0.18%     -    7s
#      0     0  804.47443    0  117  803.00000  804.47443  0.18%     -    7s
#      0     0  804.36928    0   84  803.00000  804.36928  0.17%     -    7s
#      0     0  804.36928    0   85  803.00000  804.36928  0.17%     -    7s
#      0     0  804.18755    0   96  803.00000  804.18755  0.15%     -    8s
#      0     0  804.18751    0   90  803.00000  804.18751  0.15%     -    8s
#      0     0  804.18025    0   91  803.00000  804.18025  0.15%     -    8s
#      0     0  804.16865    0   92  803.00000  804.16865  0.15%     -    8s
#      0     0  804.16865    0   90  803.00000  804.16865  0.15%     -    8s
#      0     0  804.16865    0   88  803.00000  804.16865  0.15%     -    8s
#      0     0  804.16865    0   91  803.00000  804.16865  0.15%     -    9s
#      0     0  804.16824    0   83  803.00000  804.16824  0.15%     -    9s
#      0     0  804.16824    0   95  803.00000  804.16824  0.15%     -    9s
#      0     0  804.16820    0   83  803.00000  804.16820  0.15%     -    9s
#      0     0  804.16820    0   81  803.00000  804.16820  0.15%     -    9s
#      0     0  804.16820    0   72  803.00000  804.16820  0.15%     -   10s
# H    0     0                     804.0000000  804.16820  0.02%     -   10s
#      0     0  804.16820    0   81  804.00000  804.16820  0.02%     -   10s
#
# Cutting planes:
#   Gomory: 13
#   MIR: 80
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (7976 simplex iterations) in 10.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 804 803 802 ... 776
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.040000000000e+02, best bound 8.040000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3.5x1

# %%
datafile="4x1000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xae6b9d52
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 719.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Sparsify removed 1865847 nonzeros (94%)
# Presolve added 0 rows and 297 columns
# Presolve removed 36 rows and 0 columns
# Presolve time: 5.18s
# Presolved: 4964 rows, 4297 columns, 124129 nonzeros
# Variable types: 313 continuous, 3984 integer (3984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9600000e+02   3.240924e+04   0.000000e+00      5s
#     3288    7.4313072e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 7.431307e+02, 3288 iterations, 0.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  743.13072    0  170  719.00000  743.13072  3.36%     -    5s
# H    0     0                     739.0000000  743.13072  0.56%     -    5s
# H    0     0                     740.0000000  743.13072  0.42%     -    5s
#      0     0  743.01780    0  146  740.00000  743.01780  0.41%     -    6s
# H    0     0                     741.0000000  743.01780  0.27%     -    6s
#      0     0  742.64050    0  130  741.00000  742.64050  0.22%     -    6s
#      0     0  742.61874    0  103  741.00000  742.61874  0.22%     -    6s
#      0     0  742.61571    0  111  741.00000  742.61571  0.22%     -    6s
#      0     0  742.61510    0  104  741.00000  742.61510  0.22%     -    6s
#      0     0  742.61510    0  104  741.00000  742.61510  0.22%     -    6s
#      0     0  742.61054    0   90  741.00000  742.61054  0.22%     -    6s
#      0     0  742.52749    0   78  741.00000  742.52749  0.21%     -    7s
#      0     0  742.52250    0   77  741.00000  742.52250  0.21%     -    7s
#      0     0  742.52250    0   73  741.00000  742.52250  0.21%     -    7s
#      0     0  742.44210    0   67  741.00000  742.44210  0.19%     -    7s
#      0     0  742.33034    0   66  741.00000  742.33034  0.18%     -    7s
#      0     0  742.33034    0   69  741.00000  742.33034  0.18%     -    7s
#      0     0  742.33034    0   68  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   73  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   89  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   77  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   58  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   83  741.00000  742.33034  0.18%     -    8s
#      0     0  742.33034    0   64  741.00000  742.33034  0.18%     -    9s
#      0     0  742.33034    0   68  741.00000  742.33034  0.18%     -    9s
#      0     0  742.33034    0   53  741.00000  742.33034  0.18%     -   10s
#      0     0  742.33012    0   62  741.00000  742.33012  0.18%     -   10s
#      0     0  742.33012    0   79  741.00000  742.33012  0.18%     -   10s
#      0     0  742.32904    0   60  741.00000  742.32904  0.18%     -   10s
#      0     0  742.32904    0   60  741.00000  742.32904  0.18%     -   10s
#      0     2  742.32904    0   58  741.00000  742.32904  0.18%     -   11s
#    873  1350  742.09770  104   90  741.00000  742.32875  0.18%  14.7   15s
# H 1540   493                     742.0000000  742.32875  0.04%  11.3   15s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 27
#   Implied bound: 3
#   MIR: 261
#   StrongCG: 12
#   RLT: 5
#
# Explored 1567 nodes (32141 simplex iterations) in 15.74 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 742 741 740 ... 719
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.420000000000e+02, best bound 7.420000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3.5x2

# %%
datafile="4x1000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x60b95883
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 712.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 5s) ...
# Sparsify removed 1848935 nonzeros (93%)
# Presolve added 0 rows and 277 columns
# Presolve removed 43 rows and 0 columns
# Presolve time: 5.18s
# Presolved: 4957 rows, 4277 columns, 129105 nonzeros
# Variable types: 305 continuous, 3972 integer (3972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9300000e+02   3.262751e+04   0.000000e+00      5s
#     3305    7.4055831e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 7.405583e+02, 3305 iterations, 0.20 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  740.55831    0   80  712.00000  740.55831  4.01%     -    5s
# H    0     0                     738.0000000  740.55831  0.35%     -    5s
#      0     0  740.53411    0   62  738.00000  740.53411  0.34%     -    6s
# H    0     0                     739.0000000  740.53411  0.21%     -    6s
#      0     0  740.50071    0   65  739.00000  740.50071  0.20%     -    6s
#      0     0  740.24813    0   65  739.00000  740.24813  0.17%     -    6s
#      0     0  740.24813    0   69  739.00000  740.24813  0.17%     -    6s
#      0     0  740.24813    0   54  739.00000  740.24813  0.17%     -    6s
#      0     0  740.24813    0   53  739.00000  740.24813  0.17%     -    6s
#      0     0  740.24171    0   41  739.00000  740.24171  0.17%     -    7s
#      0     0  740.24171    0   49  739.00000  740.24171  0.17%     -    7s
#      0     0  740.24171    0   45  739.00000  740.24171  0.17%     -    7s
#      0     0  740.24171    0   48  739.00000  740.24171  0.17%     -    7s
#      0     0  740.20075    0   41  739.00000  740.20075  0.16%     -    8s
#      0     0  740.20075    0   43  739.00000  740.20075  0.16%     -    8s
#      0     0  740.20011    0   47  739.00000  740.20011  0.16%     -    8s
#      0     0  740.20011    0   47  739.00000  740.20011  0.16%     -    8s
#      0     0  740.20011    0   51  739.00000  740.20011  0.16%     -    9s
#      0     0  740.20011    0   48  739.00000  740.20011  0.16%     -    9s
#      0     0  740.18366    0   45  739.00000  740.18366  0.16%     -    9s
#      0     0  740.18366    0   41  739.00000  740.18366  0.16%     -    9s
#      0     0  740.15735    0   51  739.00000  740.15735  0.16%     -    9s
#      0     0  740.15639    0   51  739.00000  740.15639  0.16%     -    9s
#      0     0  740.15550    0   49  739.00000  740.15550  0.16%     -   10s
#      0     0  740.15550    0   42  739.00000  740.15550  0.16%     -   10s
#      0     0  740.15492    0   42  739.00000  740.15492  0.16%     -   10s
#      0     0  740.15492    0   42  739.00000  740.15492  0.16%     -   10s
#      0     0  740.14346    0   38  739.00000  740.14346  0.15%     -   10s
#      0     0  740.14346    0   35  739.00000  740.14346  0.15%     -   10s
#      0     0  740.14346    0   42  739.00000  740.14346  0.15%     -   11s
#      0     0  740.14346    0   41  739.00000  740.14346  0.15%     -   11s
#      0     0  740.12974    0   30  739.00000  740.12974  0.15%     -   11s
#      0     0  740.11926    0   34  739.00000  740.11926  0.15%     -   11s
#      0     0  740.06483    0   33  739.00000  740.06483  0.14%     -   11s
#      0     0  740.06483    0   36  739.00000  740.06483  0.14%     -   11s
#      0     0  740.03207    0   39  739.00000  740.03207  0.14%     -   11s
#      0     0  740.03207    0   39  739.00000  740.03207  0.14%     -   11s
#      0     0  740.00713    0   35  739.00000  740.00713  0.14%     -   12s
#      0     0  740.00713    0   60  739.00000  740.00713  0.14%     -   12s
#      0     0  740.00713    0   53  739.00000  740.00713  0.14%     -   13s
#      0     0  740.00713    0   53  739.00000  740.00713  0.14%     -   13s
#      0     0  740.00713    0   54  739.00000  740.00713  0.14%     -   13s
#      0     0  740.00713    0   43  739.00000  740.00713  0.14%     -   13s
#      0     0  740.00713    0   46  739.00000  740.00713  0.14%     -   13s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 2
#   Implied bound: 1
#   MIR: 86
#   GUB cover: 2
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (17413 simplex iterations) in 13.30 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 739 738 712
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.390000000000e+02, best bound 7.390000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3.5x3

# %%
datafile="4x1000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x40c6a518
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 715.0000000
# Presolve removed 52 rows and 32 columns (presolve time = 5s) ...
# Sparsify removed 1861117 nonzeros (94%)
# Presolve added 0 rows and 279 columns
# Presolve removed 60 rows and 0 columns
# Presolve time: 5.18s
# Presolved: 4940 rows, 4279 columns, 112919 nonzeros
# Variable types: 311 continuous, 3968 integer (3968 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9200000e+02   2.755090e+04   0.000000e+00      5s
#     3033    7.4530870e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 7.453087e+02, 3033 iterations, 0.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  745.30870    0  176  715.00000  745.30870  4.24%     -    5s
# H    0     0                     741.0000000  745.30870  0.58%     -    5s
# H    0     0                     742.0000000  745.30870  0.45%     -    5s
# H    0     0                     743.0000000  745.30870  0.31%     -    6s
#      0     0  745.30764    0  208  743.00000  745.30764  0.31%     -    6s
#      0     0  745.29656    0  193  743.00000  745.29656  0.31%     -    6s
#      0     0  745.28006    0  187  743.00000  745.28006  0.31%     -    6s
# H    0     0                     744.0000000  745.28006  0.17%     -    6s
#      0     0  745.11922    0  168  744.00000  745.11922  0.15%     -    6s
#      0     0  745.11747    0  166  744.00000  745.11747  0.15%     -    6s
#      0     0  745.11658    0  168  744.00000  745.11658  0.15%     -    6s
#      0     0  745.11645    0  167  744.00000  745.11645  0.15%     -    6s
#      0     0  745.11645    0  169  744.00000  745.11645  0.15%     -    6s
#      0     0  745.10654    0  156  744.00000  745.10654  0.15%     -    6s
#      0     0  745.09936    0  145  744.00000  745.09936  0.15%     -    7s
#      0     0  745.09924    0  142  744.00000  745.09924  0.15%     -    7s
#      0     0  745.09914    0  143  744.00000  745.09914  0.15%     -    7s
#      0     0  745.09061    0  124  744.00000  745.09061  0.15%     -    7s
#      0     0  745.08793    0  122  744.00000  745.08793  0.15%     -    7s
#      0     0  745.08793    0  118  744.00000  745.08793  0.15%     -    7s
#      0     0  745.03405    0  110  744.00000  745.03405  0.14%     -    7s
#      0     0  745.03405    0  103  744.00000  745.03405  0.14%     -    7s
#      0     0  745.03375    0  109  744.00000  745.03375  0.14%     -    8s
#      0     0  745.03255    0  103  744.00000  745.03255  0.14%     -    8s
#      0     0  745.03255    0   99  744.00000  745.03255  0.14%     -    8s
#      0     0  745.03255    0  119  744.00000  745.03255  0.14%     -    8s
#      0     0  745.03255    0  172  744.00000  745.03255  0.14%     -    9s
#      0     0  745.03255    0  133  744.00000  745.03255  0.14%     -    9s
#      0     0  745.03255    0  124  744.00000  745.03255  0.14%     -    9s
#      0     0  745.03255    0  128  744.00000  745.03255  0.14%     -    9s
#      0     0     cutoff    0       744.00000  744.00000  0.00%     -    9s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 2
#   MIR: 45
#   StrongCG: 1
#   RLT: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (19378 simplex iterations) in 9.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 744 743 742 ... 715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.440000000000e+02, best bound 7.440000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3.5x4

# %%
datafile="4x1000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x4ad9a0c6
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 715.0000000
# Presolve removed 52 rows and 32 columns (presolve time = 5s) ...
# Sparsify removed 1846354 nonzeros (94%)
# Presolve added 0 rows and 274 columns
# Presolve removed 64 rows and 0 columns
# Presolve time: 6.04s
# Presolved: 4936 rows, 4274 columns, 127670 nonzeros
# Variable types: 306 continuous, 3968 integer (3968 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9200000e+02   3.340834e+04   0.000000e+00      6s
#     3339    7.4198988e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 7.419899e+02, 3339 iterations, 0.19 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  741.98988    0  250  715.00000  741.98988  3.77%     -    6s
# H    0     0                     734.0000000  741.98988  1.09%     -    6s
# H    0     0                     737.0000000  741.98988  0.68%     -    6s
# H    0     0                     738.0000000  741.98988  0.54%     -    6s
# H    0     0                     739.0000000  741.98988  0.40%     -    6s
#      0     0  741.94549    0  230  739.00000  741.94549  0.40%     -    6s
# H    0     0                     740.0000000  741.94549  0.26%     -    7s
#      0     0  741.82935    0  199  740.00000  741.82935  0.25%     -    7s
#      0     0  741.80744    0  185  740.00000  741.80744  0.24%     -    7s
#      0     0  741.73080    0  185  740.00000  741.73080  0.23%     -    7s
#      0     0  741.72907    0  193  740.00000  741.72907  0.23%     -    7s
#      0     0  741.72864    0  186  740.00000  741.72864  0.23%     -    7s
#      0     0  741.72864    0  192  740.00000  741.72864  0.23%     -    7s
#      0     0  741.71342    0  174  740.00000  741.71342  0.23%     -    7s
#      0     0  741.69213    0  150  740.00000  741.69213  0.23%     -    8s
#      0     0  741.68692    0  151  740.00000  741.68692  0.23%     -    8s
#      0     0  741.68692    0  147  740.00000  741.68692  0.23%     -    8s
#      0     0  741.66804    0  168  740.00000  741.66804  0.23%     -    8s
#      0     0  741.66804    0  157  740.00000  741.66804  0.23%     -    8s
#      0     0  741.65236    0  152  740.00000  741.65236  0.22%     -    9s
#      0     0  741.62407    0  148  740.00000  741.62407  0.22%     -    9s
#      0     0  741.62407    0  153  740.00000  741.62407  0.22%     -    9s
#      0     0  741.56548    0  142  740.00000  741.56548  0.21%     -    9s
#      0     0  741.56548    0  129  740.00000  741.56548  0.21%     -    9s
#      0     0  741.56539    0  145  740.00000  741.56539  0.21%     -    9s
#      0     0  741.56539    0  136  740.00000  741.56539  0.21%     -    9s
#      0     0  741.56539    0  143  740.00000  741.56539  0.21%     -   10s
#      0     0  741.56518    0  127  740.00000  741.56518  0.21%     -   10s
#      0     0  741.56518    0  151  740.00000  741.56518  0.21%     -   10s
#      0     0  741.56424    0  149  740.00000  741.56424  0.21%     -   10s
#      0     0  741.56424    0  114  740.00000  741.56424  0.21%     -   11s
#      0     2  741.56424    0  114  740.00000  741.56424  0.21%     -   12s
# H   92   120                     741.0000000  741.56410  0.08%  44.5   12s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 4
#   Implied bound: 13
#   MIR: 271
#   RLT: 6
#   Relax-and-lift: 6
#
# Explored 119 nodes (18057 simplex iterations) in 12.67 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 7: 741 740 739 ... 715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.410000000000e+02, best bound 7.410000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x3.5x5

# %%
datafile="4x1000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x84ace976
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 709.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1847475 nonzeros (93%)
# Presolve added 0 rows and 279 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 5.15s
# Presolved: 4942 rows, 4279 columns, 134493 nonzeros
# Variable types: 303 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.399520e+04   0.000000e+00      5s
#     3143    7.4200326e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 7.420033e+02, 3143 iterations, 0.19 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  742.00326    0   87  709.00000  742.00326  4.65%     -    5s
# H    0     0                     737.0000000  742.00326  0.68%     -    5s
# H    0     0                     739.0000000  742.00326  0.41%     -    5s
# H    0     0                     740.0000000  742.00326  0.27%     -    6s
#      0     0  742.00197    0   97  740.00000  742.00197  0.27%     -    6s
# H    0     0                     741.0000000  742.00197  0.14%     -    6s
#      0     0     cutoff    0       741.00000  741.00000  0.00%     -    6s
#
# Cutting planes:
#   Gomory: 22
#   Implied bound: 2
#   MIR: 36
#
# Explored 1 nodes (7280 simplex iterations) in 6.37 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 741 740 739 ... 709
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.410000000000e+02, best bound 7.410000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4x1

# %%
datafile="4x1000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x9faf8141
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 651.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1877294 nonzeros (95%)
# Presolve added 0 rows and 298 columns
# Presolve removed 54 rows and 0 columns
# Presolve time: 6.08s
# Presolved: 4946 rows, 4298 columns, 104686 nonzeros
# Variable types: 322 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   2.887551e+04   0.000000e+00      6s
#     3333    6.8249502e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.824950e+02, 3333 iterations, 0.17 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  682.49502    0  234  651.00000  682.49502  4.84%     -    6s
# H    0     0                     675.0000000  682.49502  1.11%     -    6s
# H    0     0                     676.0000000  682.49502  0.96%     -    6s
# H    0     0                     677.0000000  682.49502  0.81%     -    6s
# H    0     0                     678.0000000  682.49502  0.66%     -    6s
#      0     0  682.43882    0  255  678.00000  682.43882  0.65%     -    6s
# H    0     0                     679.0000000  682.43882  0.51%     -    7s
# H    0     0                     680.0000000  682.43882  0.36%     -    7s
#      0     0  682.10743    0  245  680.00000  682.10743  0.31%     -    7s
#      0     0  682.10679    0  241  680.00000  682.10679  0.31%     -    7s
#      0     0  682.10666    0  244  680.00000  682.10666  0.31%     -    7s
#      0     0  682.10666    0  245  680.00000  682.10666  0.31%     -    7s
#      0     0  682.06336    0  214  680.00000  682.06336  0.30%     -    7s
#      0     0  681.92906    0  212  680.00000  681.92906  0.28%     -    7s
#      0     0  681.92555    0  206  680.00000  681.92555  0.28%     -    7s
#      0     0  681.92539    0  200  680.00000  681.92539  0.28%     -    7s
#      0     0  681.92537    0  198  680.00000  681.92537  0.28%     -    7s
#      0     0  681.82834    0  218  680.00000  681.82834  0.27%     -    8s
#      0     0  681.82426    0  178  680.00000  681.82426  0.27%     -    8s
#      0     0  681.82404    0  183  680.00000  681.82404  0.27%     -    8s
#      0     0  681.82404    0  171  680.00000  681.82404  0.27%     -    8s
#      0     0  681.81463    0  176  680.00000  681.81463  0.27%     -    8s
#      0     0  681.81457    0  179  680.00000  681.81457  0.27%     -    8s
#      0     0  681.81444    0  184  680.00000  681.81444  0.27%     -    9s
#      0     0  681.81285    0  172  680.00000  681.81285  0.27%     -    9s
#      0     0  681.81285    0  156  680.00000  681.81285  0.27%     -    9s
#      0     0  681.81155    0  165  680.00000  681.81155  0.27%     -    9s
#      0     0  681.80737    0  164  680.00000  681.80737  0.27%     -    9s
#      0     0  681.80369    0  167  680.00000  681.80369  0.27%     -    9s
#      0     0  681.80368    0  178  680.00000  681.80368  0.27%     -    9s
#      0     0  681.77836    0  172  680.00000  681.77836  0.26%     -    9s
#      0     0  681.77806    0  166  680.00000  681.77806  0.26%     -   10s
#      0     0  681.77806    0  168  680.00000  681.77806  0.26%     -   10s
#      0     0  681.77801    0  177  680.00000  681.77801  0.26%     -   10s
#      0     0  681.77641    0  182  680.00000  681.77641  0.26%     -   10s
#      0     0  681.77625    0  172  680.00000  681.77625  0.26%     -   10s
#      0     0  681.77622    0  177  680.00000  681.77622  0.26%     -   10s
#      0     0  681.77517    0  167  680.00000  681.77517  0.26%     -   10s
#      0     0  681.77085    0  167  680.00000  681.77085  0.26%     -   10s
#      0     0  681.77054    0  178  680.00000  681.77054  0.26%     -   10s
#      0     0  681.77053    0  176  680.00000  681.77053  0.26%     -   10s
#      0     0  681.76977    0  182  680.00000  681.76977  0.26%     -   11s
#      0     0  681.74180    0  181  680.00000  681.74180  0.26%     -   11s
#      0     0  681.74180    0  168  680.00000  681.74180  0.26%     -   11s
#      0     0  681.74104    0  162  680.00000  681.74104  0.26%     -   11s
#      0     0  681.73985    0  154  680.00000  681.73985  0.26%     -   11s
#      0     0  681.73909    0  167  680.00000  681.73909  0.26%     -   11s
#      0     0  681.73892    0  172  680.00000  681.73892  0.26%     -   11s
#      0     0  681.73884    0  168  680.00000  681.73884  0.26%     -   11s
#      0     0  681.73630    0  156  680.00000  681.73630  0.26%     -   12s
#      0     0  681.73591    0  152  680.00000  681.73591  0.26%     -   12s
#      0     0  681.73590    0  151  680.00000  681.73590  0.26%     -   12s
#      0     0  681.73538    0  154  680.00000  681.73538  0.26%     -   12s
#      0     0  681.73528    0  155  680.00000  681.73528  0.26%     -   12s
#      0     0  681.73478    0  152  680.00000  681.73478  0.26%     -   12s
#      0     0  681.73478    0  128  680.00000  681.73478  0.26%     -   12s
#      0     2  681.73478    0  128  680.00000  681.73478  0.26%     -   13s
#     85    92  681.59564    9  139  680.00000  681.73262  0.25%  71.4   15s
#   2946  3340  681.09577  321   64  680.00000  681.73175  0.25%  10.0   20s
#   4867  4607  681.03570  369  226  680.00000  681.73175  0.25%   9.5   25s
#   4874  4612  681.03570  369  109  680.00000  681.63425  0.24%   9.5   30s
#   4881  4617  681.44218  156  144  680.00000  681.62862  0.24%   9.5   35s
#   4892  4624  681.50225   84   67  680.00000  681.60221  0.24%   9.5   40s
#   4903  4631  681.54861  157  112  680.00000  681.59538  0.23%   9.5   45s
#   4912  4638  681.03606  333   94  680.00000  681.59538  0.23%  18.7   50s
#   4919  4643  681.22181  140  117  680.00000  681.59533  0.23%  18.7   55s
#   4927  4648  681.12142  313  122  680.00000  681.57345  0.23%  18.7   60s
#   4933  4652  681.02902  536  135  680.00000  681.57345  0.23%  18.7   65s
#   4942  4659  681.57345   19   99  680.00000  681.57345  0.23%  24.9   70s
#   4950  4665  681.57345   28  116  680.00000  681.57345  0.23%  24.9   75s
#   4958  4670  681.34809  187  103  680.00000  681.57343  0.23%  24.8   80s
#   5063  4785  681.54449   52  122  680.00000  681.54683  0.23%  30.6   85s
#   6552  6751  681.49532  164   70  680.00000  681.54683  0.23%  27.3   90s
#   9761  8191  681.29737  380   53  680.00000  681.54683  0.23%  21.9   95s
#  12720 10702  681.17596  675   42  680.00000  681.54681  0.23%  20.1  101s
#  14354 10673  681.49472  102  133  680.00000  681.54681  0.23%  19.3  106s
#  17297 13407  681.36538   76  112  680.00000  681.54681  0.23%  17.9  110s
#  22370 17981  681.29053  266   58  680.00000  681.54681  0.23%  15.8  115s
#  26378 20211  681.11134  203  128  680.00000  681.54681  0.23%  14.6  140s
#  26384 20215  681.24327  712  151  680.00000  681.54681  0.23%  14.6  145s
#  26389 20218  681.22016  496  107  680.00000  681.51334  0.22%  14.6  150s
#  26394 20222  681.14777  691   81  680.00000  681.47588  0.22%  14.6  156s
#  26397 20224  681.24770  101   93  680.00000  681.47584  0.22%  14.6  160s
#  26401 20226  681.00000  912   98  680.00000  681.47584  0.22%  14.6  165s
#  26406 20230  681.25633  382   90  680.00000  681.47584  0.22%  14.6  171s
#  26410 20232  681.19061  820   84  680.00000  681.47584  0.22%  14.6  178s
#  26441 20260  681.46508   60   79  680.00000  681.46596  0.22%  15.9  180s
#  26878 21456  681.31747   84   95  680.00000  681.46595  0.22%  16.2  187s
#  28307 21676  681.30308  204   60  680.00000  681.46595  0.22%  16.2  191s
# H28351 19130                     681.0000000  681.46595  0.07%  16.3  191s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 15
#   MIR: 55
#   StrongCG: 3
#   Flow cover: 86
#   GUB cover: 4
#   Zero half: 1
#   Relax-and-lift: 1
#
# Explored 28496 nodes (479267 simplex iterations) in 191.89 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 8: 681 680 679 ... 651
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.810000000000e+02, best bound 6.810000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4x2

# %%
datafile="4x1000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x4421c3ec
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 654.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1862848 nonzeros (94%)
# Presolve added 0 rows and 292 columns
# Presolve removed 50 rows and 0 columns
# Presolve time: 5.40s
# Presolved: 4950 rows, 4292 columns, 119148 nonzeros
# Variable types: 316 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.224310e+04   0.000000e+00      6s
#     3160    6.8759637e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.875964e+02, 3160 iterations, 0.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  687.59637    0  119  654.00000  687.59637  5.14%     -    5s
# H    0     0                     685.0000000  687.59637  0.38%     -    5s
#      0     0  687.55324    0  100  685.00000  687.55324  0.37%     -    6s
# H    0     0                     686.0000000  687.55324  0.23%     -    6s
#      0     0  687.53302    0   95  686.00000  687.53302  0.22%     -    6s
#      0     0  687.45088    0   88  686.00000  687.45088  0.21%     -    7s
#      0     0  687.36968    0   88  686.00000  687.36968  0.20%     -    7s
#      0     0  687.36866    0   93  686.00000  687.36866  0.20%     -    7s
#      0     0  687.36848    0   93  686.00000  687.36848  0.20%     -    7s
#      0     0  687.36848    0   91  686.00000  687.36848  0.20%     -    7s
#      0     0  687.27988    0   69  686.00000  687.27988  0.19%     -    7s
#      0     0  687.22881    0   68  686.00000  687.22881  0.18%     -    7s
#      0     0  687.22109    0   78  686.00000  687.22109  0.18%     -    7s
#      0     0  687.22109    0   78  686.00000  687.22109  0.18%     -    7s
#      0     0  687.18106    0   74  686.00000  687.18106  0.17%     -    7s
#      0     0  687.17216    0   67  686.00000  687.17216  0.17%     -    8s
#      0     0  687.16934    0   67  686.00000  687.16934  0.17%     -    8s
#      0     0  687.16807    0   61  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   64  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   56  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   58  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   64  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   58  686.00000  687.16807  0.17%     -    8s
#      0     0  687.16807    0   57  686.00000  687.16807  0.17%     -    9s
#      0     0  687.16807    0   53  686.00000  687.16807  0.17%     -    9s
#      0     0  687.16804    0   56  686.00000  687.16804  0.17%     -    9s
#      0     0  687.16741    0   60  686.00000  687.16741  0.17%     -    9s
#      0     0  687.16741    0   57  686.00000  687.16741  0.17%     -    9s
#      0     0  687.16741    0   47  686.00000  687.16741  0.17%     -   10s
#      0     0  687.16741    0  107  686.00000  687.16741  0.17%     -   11s
#      0     0  687.16741    0  103  686.00000  687.16741  0.17%     -   11s
#      0     0  687.16741    0   83  686.00000  687.16741  0.17%     -   11s
#      0     0  687.16021    0   79  686.00000  687.16021  0.17%     -   11s
#      0     0  687.16018    0   74  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   73  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   72  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   80  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   79  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   53  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   52  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   61  686.00000  687.16018  0.17%     -   12s
#      0     0  687.16018    0   61  686.00000  687.16018  0.17%     -   13s
#      0     2  687.16018    0   61  686.00000  687.16018  0.17%     -   13s
#    164   541  687.10295   33   39  686.00000  687.13450  0.17%  22.1   15s
#   1546  1362  687.05593   89   43  686.00000  687.06527  0.16%   9.6   20s
#   1598  1404  687.06527   15   32  686.00000  687.06527  0.16%  22.0   25s
#   3550  3058  687.00000  206   40  686.00000  687.06527  0.16%  14.2   30s
#   6096  4867  687.00000  410   34  686.00000  687.06527  0.16%  14.9   35s
#   8567  7547  687.00000  624   37  686.00000  687.06527  0.16%  15.0   40s
#  12533 10061  687.00000  536   47  686.00000  687.06527  0.16%  12.6   45s
#  12552 10074  687.00000  996   24  686.00000  687.06527  0.16%  12.6   50s
#  12927 11036  687.06526   39   29  686.00000  687.06526  0.16%  13.7   57s
#  15307 12377  687.00000  247   32  686.00000  687.06526  0.16%  12.4   60s
#  17458 13217  687.00000  428   35  686.00000  687.06526  0.16%  12.7   65s
# H17683  8232                     687.0000000  687.06526  0.01%  12.7   66s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 3
#   MIR: 13
#   StrongCG: 5
#   Flow cover: 14
#   Relax-and-lift: 1
#
# Explored 17697 nodes (234221 simplex iterations) in 66.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 687 686 685 654
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.870000000000e+02, best bound 6.870000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4x3

# %%
datafile="4x1000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x9b0ea1f0
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 656.0000000
# Presolve removed 25 rows and 20 columns (presolve time = 5s) ...
# Sparsify removed 1849978 nonzeros (93%)
# Presolve added 0 rows and 282 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 5.15s
# Presolved: 4963 rows, 4282 columns, 136058 nonzeros
# Variable types: 302 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.582420e+04   0.000000e+00      5s
#     3226    6.8921212e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 6.892121e+02, 3226 iterations, 0.19 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  689.21212    0  196  656.00000  689.21212  5.06%     -    5s
# H    0     0                     682.0000000  689.21212  1.06%     -    5s
# H    0     0                     684.0000000  689.21212  0.76%     -    5s
# H    0     0                     685.0000000  689.21212  0.61%     -    5s
#      0     0  689.15387    0  206  685.00000  689.15387  0.61%     -    6s
# H    0     0                     686.0000000  689.15387  0.46%     -    6s
# H    0     0                     687.0000000  689.15387  0.31%     -    6s
#      0     0  689.06614    0  206  687.00000  689.06614  0.30%     -    6s
#      0     0  688.84945    0  179  687.00000  688.84945  0.27%     -    6s
#      0     0  688.57068    0  166  687.00000  688.57068  0.23%     -    6s
#      0     0  688.56774    0  162  687.00000  688.56774  0.23%     -    6s
#      0     0  688.56766    0  162  687.00000  688.56766  0.23%     -    6s
#      0     0  688.54140    0  151  687.00000  688.54140  0.22%     -    7s
#      0     0  688.51770    0  144  687.00000  688.51770  0.22%     -    7s
#      0     0  688.51741    0  139  687.00000  688.51741  0.22%     -    7s
#      0     0  688.51741    0  150  687.00000  688.51741  0.22%     -    7s
#      0     0  688.50437    0  154  687.00000  688.50437  0.22%     -    7s
#      0     0  688.47910    0  148  687.00000  688.47910  0.22%     -    8s
#      0     0  688.47893    0  142  687.00000  688.47893  0.22%     -    8s
#      0     0  688.47854    0  140  687.00000  688.47854  0.22%     -    8s
#      0     0  688.47853    0  152  687.00000  688.47853  0.22%     -    8s
#      0     0  688.47265    0  144  687.00000  688.47265  0.21%     -    8s
#      0     0  688.47265    0  152  687.00000  688.47265  0.21%     -    8s
#      0     0  688.46852    0  130  687.00000  688.46852  0.21%     -    8s
#      0     0  688.46838    0  134  687.00000  688.46838  0.21%     -    9s
#      0     0  688.46154    0  136  687.00000  688.46154  0.21%     -    9s
#      0     0  688.46154    0  138  687.00000  688.46154  0.21%     -    9s
#      0     0  688.46078    0  137  687.00000  688.46078  0.21%     -    9s
#      0     0  688.46078    0  131  687.00000  688.46078  0.21%     -   10s
#      0     0  688.45716    0  140  687.00000  688.45716  0.21%     -   10s
#      0     0  688.45716    0  129  687.00000  688.45716  0.21%     -   10s
#      0     0  688.45697    0  129  687.00000  688.45697  0.21%     -   10s
#      0     0  688.45691    0  129  687.00000  688.45691  0.21%     -   11s
#      0     0  688.45249    0  122  687.00000  688.45249  0.21%     -   11s
#      0     0  688.45249    0  137  687.00000  688.45249  0.21%     -   11s
#      0     0  688.45249    0  130  687.00000  688.45249  0.21%     -   11s
#      0     0  688.45249    0  128  687.00000  688.45249  0.21%     -   11s
#      0     0  688.45249    0  126  687.00000  688.45249  0.21%     -   12s
#      0     0  688.45249    0   94  687.00000  688.45249  0.21%     -   12s
#      0     2  688.45249    0   94  687.00000  688.45249  0.21%     -   13s
#     88    95  688.43273   11  114  687.00000  688.45249  0.21%  46.5   15s
#   2290  2861  688.27945   91   74  687.00000  688.45249  0.21%  10.2   20s
#   4944  4690  688.12742  316  175  687.00000  688.45249  0.21%   7.9   26s
#   4949  4694  688.35348   65  101  687.00000  688.41696  0.21%   7.9   30s
#   4954  4697  688.37703   20  104  687.00000  688.37703  0.20%   7.8   35s
#   4958  4700  688.35011   45   86  687.00000  688.35011  0.20%   7.8   40s
#   4971  4708  688.20839  148   74  687.00000  688.21901  0.18%   7.8   46s
#   4980  4715  688.21720  103  188  687.00000  688.21851  0.18%  15.4   50s
#   4985  4719  688.09425  181  120  687.00000  688.21851  0.18%  15.4   55s
#   4991  4723  688.21830   35   63  687.00000  688.21830  0.18%  15.3   60s
#   5002  4731  688.21830   13   94  687.00000  688.21830  0.18%  20.1   65s
#   5008  4735  688.21830  113   69  687.00000  688.21830  0.18%  20.1   70s
#   5013  4738  688.21830   64   60  687.00000  688.21830  0.18%  20.1   75s
#   5019  4742  688.21665   53   65  687.00000  688.21665  0.18%  20.0   80s
#   5028  4750  688.11730  154   94  687.00000  688.21664  0.18%  25.1   85s
#   5035  4755  688.19239  235   86  687.00000  688.21664  0.18%  25.0   90s
#   5041  4759  688.21664   34   80  687.00000  688.21664  0.18%  25.0   96s
#   5046  4762  688.11030  104  111  687.00000  688.21664  0.18%  25.0  100s
#   5052  4769  688.21664   46   89  687.00000  688.21664  0.18%  29.7  105s
#   5804  5691  688.15356  103   71  687.00000  688.21026  0.18%  27.9  111s
#   7920  7158  688.15938  219   84  687.00000  688.21026  0.18%  25.1  115s
#  10069  8556  688.04373  360   50  687.00000  688.21026  0.18%  21.9  120s
#  13464  9372  688.20639   75   53  687.00000  688.21026  0.18%  18.5  125s
#  13470 14721  688.20639   76   54  687.00000  688.21026  0.18%  18.5  133s
#  19476 14155  688.16670   71   75  687.00000  688.21026  0.18%  15.4  135s
#  24648 18738  688.15598  516   53  687.00000  688.21026  0.18%  13.5  140s
#  27094 19832  688.05984  302   94  687.00000  688.21026  0.18%  13.0  164s
#  27096 19833  688.19687  101  188  687.00000  688.21026  0.18%  13.0  165s
#  27101 19837  688.00851  374   85  687.00000  688.21026  0.18%  13.0  171s
#  27105 19839  688.12203  120   94  687.00000  688.21026  0.18%  13.0  176s
#  27108 19841  688.11596  225   86  687.00000  688.21026  0.18%  13.0  181s
#  27111 19843  688.07889  317  104  687.00000  688.21026  0.18%  13.0  186s
#  27114 19845  688.18125  152  121  687.00000  688.21026  0.18%  13.0  191s
#  27118 19848  688.16975  149   83  687.00000  688.21026  0.18%  13.0  195s
#  27122 19851  688.04980  615  110  687.00000  688.21026  0.18%  13.0  200s
#  27127 19854  688.12720  217   71  687.00000  688.21026  0.18%  13.0  205s
#  27131 19857  688.12159  240   83  687.00000  688.21026  0.18%  13.0  210s
#  27136 19860  688.18621   84  111  687.00000  688.21026  0.18%  13.0  215s
#  27141 19863  688.10878  254  104  687.00000  688.21026  0.18%  12.9  220s
#  27147 19867  688.15622  180   90  687.00000  688.21026  0.18%  12.9  225s
#  27153 19871  688.17619   93   92  687.00000  688.21026  0.18%  12.9  231s
#  27157 19874  688.06232  149  100  687.00000  688.21026  0.18%  12.9  235s
#  27163 19878  688.14124  200   98  687.00000  688.21026  0.18%  12.9  240s
#  27167 19881  688.05619  272  108  687.00000  688.21026  0.18%  12.9  245s
#  27172 19884  688.05211  139  107  687.00000  688.21026  0.18%  12.9  250s
#  27182 19898  688.21026   57  122  687.00000  688.21026  0.18%  14.9  255s
#  27480 20894  688.20443   79   92  687.00000  688.21026  0.18%  15.2  262s
#  28564 21151  688.20610  120   71  687.00000  688.21026  0.18%  15.7  265s
#  29431 22233  688.20055  161  106  687.00000  688.21026  0.18%  16.7  271s
#  30960 23622  688.19746  188  101  687.00000  688.21026  0.18%  17.3  275s
#  33409 24870  688.19124  240   95  687.00000  688.21026  0.18%  17.8  280s
#  37783 27324  688.15061  353   63  687.00000  688.21026  0.18%  17.4  286s
#  40178 29723  688.14772  421   56  687.00000  688.21026  0.18%  17.2  291s
#  45081 30755  688.02434  547   93  687.00000  688.21026  0.18%  16.7  295s
#  47575 32555  688.00000  664   70  687.00000  688.21026  0.18%  17.2  300s
#  49755 33561  688.00000  933   29  687.00000  688.21026  0.18%  17.1  306s
#  53348 37079  688.20241   82   83  687.00000  688.21026  0.18%  16.8  312s
#  56577 37964  688.18057  107   46  687.00000  688.21026  0.18%  16.5  315s
#  61703 40739  688.19424  157   56  687.00000  688.21026  0.18%  15.9  320s
#  66380 44300  688.19038  138   64  687.00000  688.21026  0.18%  15.8  327s
#  71378 45667  688.19931   77   83  687.00000  688.21026  0.18%  15.4  331s
#  73455 47366  688.18439  137   82  687.00000  688.21026  0.18%  15.7  335s
#  75763 48248  688.00163  224   80  687.00000  688.21026  0.18%  15.7  340s
#  79184 51400  688.19744   76   63  687.00000  688.21026  0.18%  15.5  345s
#  84071 54471  688.01872  145   82  687.00000  688.21026  0.18%  15.4  350s
#  89979 58022  688.18781  196   44  687.00000  688.21026  0.18%  14.8  355s
#  94261 62019  688.12776  694   55  687.00000  688.21026  0.18%  14.4  360s
#  96702 64009  688.18984  101   83  687.00000  688.21026  0.18%  14.4  365s
#  100668 67788  688.19032  124   79  687.00000  688.21026  0.18%  14.6  370s
#  103327 70380  688.18818  138   43  687.00000  688.21026  0.18%  15.0  375s
#  105734 72835  688.18515  105  110  687.00000  688.21026  0.18%  15.2  380s
#  110127 76799  688.06595  122   72  687.00000  688.21026  0.18%  15.2  385s
#  112206 77645  688.00000  240   35  687.00000  688.21026  0.18%  15.2  391s
#  115133 81222  688.00000 1004   38  687.00000  688.21026  0.18%  15.2  395s
#  118358 84553  688.20821   66   88  687.00000  688.21026  0.18%  15.2  400s
#  124069 89357  688.08215   97   76  687.00000  688.21026  0.18%  14.9  405s
#  129541 93846  688.19700   88   54  687.00000  688.21026  0.18%  14.7  410s
#  134486 98223  688.12869  187   73  687.00000  688.21026  0.18%  14.4  415s
#  140393 103333  688.12180  186   37  687.00000  688.21026  0.18%  14.1  420s
#  143038 105252  688.15895   90   93  687.00000  688.21026  0.18%  14.1  425s
#  143044 110758  688.19439   91   91  687.00000  688.21026  0.18%  14.1  431s
#  152047 114443  688.18859  115   75  687.00000  688.21026  0.18%  14.0  435s
#  157011 118761  688.15662  154   87  687.00000  688.21026  0.18%  13.9  440s
#  161688 122703  688.08294  130   90  687.00000  688.21026  0.18%  14.0  445s
#  164994 125763  688.13483  172   74  687.00000  688.21026  0.18%  14.1  450s
#  168701 128716  688.21026   88   49  687.00000  688.21026  0.18%  14.1  456s
#  170595 129710  688.19598  109   46  687.00000  688.21026  0.18%  14.2  460s
#  173990 133437  688.00000  653   27  687.00000  688.21026  0.18%  14.3  465s
#  178388 137229  688.16646   88   76  687.00000  688.21026  0.18%  14.4  470s
#  181873 140043  688.17758  120   97  687.00000  688.21026  0.18%  14.5  476s
#  185258 143758  688.00000  240   60  687.00000  688.21026  0.18%  14.6  481s
#  189338 146305  688.19711  103   60  687.00000  688.21026  0.18%  14.7  487s
#  189443 146982  688.19711  105   65  687.00000  688.21026  0.18%  14.7  490s
#  193604 150790  688.19189  124   95  687.00000  688.21026  0.18%  14.8  496s
#  194592 156087  688.19407  104   55  687.00000  688.21026  0.18%  14.8  506s
#  203250 159106  688.16616  116   67  687.00000  688.21026  0.18%  15.0  510s
#  207850 162539  688.11433  592   39  687.00000  688.21026  0.18%  15.0  516s
#  207856 167798  688.11433  593   39  687.00000  688.21026  0.18%  15.0  524s
#  213862 169188  688.04406  163   93  687.00000  688.21026  0.18%  15.1  526s
#  218363 172310  688.10462  183   56  687.00000  688.21026  0.18%  15.1  530s
#  221956 175130     cutoff  249       687.00000  688.21026  0.18%  15.1  535s
#  224607 177595  688.17063  228   72  687.00000  688.21026  0.18%  15.3  540s
#  226455 179316  688.13891  128   70  687.00000  688.21026  0.18%  15.4  545s
#  230538 182818  688.20821   93   56  687.00000  688.21026  0.18%  15.5  550s
#  232629 183812  688.21026  100   59  687.00000  688.21026  0.18%  15.5  555s
#  234173 187080  688.16747  356   43  687.00000  688.21026  0.18%  15.5  560s
#  239172 190123  688.09599  141   64  687.00000  688.21026  0.18%  15.6  565s
#  241204 192002  688.03263  222   53  687.00000  688.21026  0.18%  15.7  570s
#  244467 194906  687.99956 1051   36  687.00000  688.21026  0.18%  15.8  575s
#  248287 198091  688.18468  167   91  687.00000  688.21026  0.18%  15.8  580s
#  251428 201176  688.17322  239   89  687.00000  688.21026  0.18%  16.0  585s
#  255259 204175  688.17949  205   95  687.00000  688.21026  0.18%  16.1  590s
#  257550 206501  688.19403  130   74  687.00000  688.21026  0.18%  16.2  596s
#  261306 209502  688.17851  124   54  687.00000  688.21026  0.18%  16.2  600s
#  264963 212495  688.17047  250   78  687.00000  688.21026  0.18%  16.3  605s
#  268166 215512  688.18134  196   88  687.00000  688.21026  0.18%  16.4  610s
#  272598 219411  688.21026   92   55  687.00000  688.21026  0.18%  16.4  615s
#  275247 221055  688.18091  197   72  687.00000  688.21026  0.18%  16.4  620s
#  277759 223575  688.18816  158   86  687.00000  688.21026  0.18%  16.6  625s
#  280589 226217  688.16620  154   76  687.00000  688.21026  0.18%  16.6  630s
#  282471 227651  688.01277  183   71  687.00000  688.21026  0.18%  16.6  636s
#  285402 229822  688.18612  157   78  687.00000  688.21026  0.18%  16.7  640s
#  288231 231673  688.19861  120   53  687.00000  688.21026  0.18%  16.8  645s
#  291110 235164  688.20821  107   46  687.00000  688.21026  0.18%  16.9  651s
#  294356 237821  688.20821  109   46  687.00000  688.21026  0.18%  16.9  655s
#  297751 241019  688.18703  143  104  687.00000  688.21026  0.18%  17.0  661s
#  300969 243077  688.09072  164   70  687.00000  688.21026  0.18%  17.0  665s
#  304243 245951  688.19182  139   88  687.00000  688.21026  0.18%  17.1  670s
#  306754 248169  688.00124  288   62  687.00000  688.21026  0.18%  17.1  676s
#  310531 251460  688.19348  136   74  687.00000  688.21026  0.18%  17.2  681s
#  313409 253629  688.17994  219   75  687.00000  688.21026  0.18%  17.2  685s
#  316532 256154     cutoff  117       687.00000  688.21026  0.18%  17.3  690s
#  320238 259292  688.01139  374   64  687.00000  688.21026  0.18%  17.3  695s
#  323000 261418  688.18966  156   72  687.00000  688.21026  0.18%  17.4  701s
#  325589 263487  688.17048  250   55  687.00000  688.21026  0.18%  17.4  706s
#  327600 265039  688.17724  232   79  687.00000  688.21026  0.18%  17.6  710s
#  330332 267560  688.17645  239   77  687.00000  688.21026  0.18%  17.7  715s
#  333561 269510  688.17817  210   84  687.00000  688.21026  0.18%  17.7  721s
#  334925 271683  688.18161  180   69  687.00000  688.21026  0.18%  17.7  725s
#  338328 273371  688.18824  157   73  687.00000  688.21026  0.18%  17.8  730s
#  341616 276750  688.18959  150   99  687.00000  688.21026  0.18%  17.9  736s
#  344275 279337  688.10204  135   46  687.00000  688.21026  0.18%  17.9  740s
#  348338 282079  688.08508  153   88  687.00000  688.21026  0.18%  18.0  746s
#  350887 284237  688.16844  266   60  687.00000  688.21026  0.18%  18.0  750s
#  353367 285602  688.14967  120   93  687.00000  688.21026  0.18%  18.1  755s
#  356613 288449  687.99998  891   38  687.00000  688.21026  0.18%  18.1  761s
#  359332 290706  688.11612  124   92  687.00000  688.21026  0.18%  18.2  765s
#  362529 293369  688.17724  228   68  687.00000  688.21026  0.18%  18.2  770s
#  365378 295421  688.17914  125   64  687.00000  688.21026  0.18%  18.3  775s
#  367747 296612  688.17896  230   73  687.00000  688.21026  0.18%  18.4  780s
#  369591 299101  688.00923  351   60  687.00000  688.21026  0.18%  18.5  785s
#  372684 301593  688.18026  256   52  687.00000  688.21026  0.18%  18.5  790s
#  375650 303368  688.10937  142   57  687.00000  688.21026  0.18%  18.5  795s
#  376507 307963  688.15620  134   64  687.00000  688.21026  0.18%  18.5  808s
#  382513 307956 infeasible  124       687.00000  688.21026  0.18%  18.6  811s
#  384500 309854  688.02240  132   70  687.00000  688.21026  0.18%  18.6  815s
#  387811 311937  688.20219  128   57  687.00000  688.21026  0.18%  18.7  821s
#  390092 313879     cutoff  123       687.00000  688.21026  0.18%  18.8  826s
#  393740 316038  688.17177  152   64  687.00000  688.21026  0.18%  18.8  831s
#  395425 317329  688.01167  144   85  687.00000  688.21026  0.18%  18.9  836s
#  398306 319115  688.16484  154   75  687.00000  688.21026  0.18%  18.9  840s
#  401606 321189  688.20004  135   54  687.00000  688.21026  0.18%  19.0  845s
#  404081 323259  688.17392  246   59  687.00000  688.21026  0.18%  19.0  850s
#  407831 325276  688.11284  128   96  687.00000  688.21026  0.18%  19.1  855s
#  410829 326905  688.05958  121  107  687.00000  688.21026  0.18%  19.2  862s
#  411845 328019  688.14080  121   84  687.00000  688.21026  0.18%  19.2  865s
#  414561 330206  688.19702  149   45  687.00000  688.21026  0.18%  19.2  870s
#  417634 332352  688.16509  146   88  687.00000  688.21026  0.18%  19.3  876s
#  420773 334283  688.17032  134   60  687.00000  688.21026  0.18%  19.3  880s
#  422911 335771  688.00214  114   94  687.00000  688.21026  0.18%  19.3  885s
#  425364 337474  688.09673  129  107  687.00000  688.21026  0.18%  19.4  890s
#  427597 338982     cutoff  132       687.00000  688.21026  0.18%  19.5  896s
#  429076 340128  688.08937  181   84  687.00000  688.21026  0.18%  19.5  900s
#  429843 341170  688.18169  238   45  687.00000  688.21026  0.18%  19.5  906s
#  432095 342498  688.21026  120   53  687.00000  688.21026  0.18%  19.6  910s
#  434997 344603  688.18966  162   77  687.00000  688.21026  0.18%  19.6  915s
#  436802 345700     cutoff  280       687.00000  688.21026  0.18%  19.6  920s
#  439758 347379  688.14347  126   67  687.00000  688.21026  0.18%  19.7  926s
#  441547 348054  688.19984  134   55  687.00000  688.21026  0.18%  19.7  930s
#  444133 350048  688.01917  128   68  687.00000  688.21026  0.18%  19.8  935s
#  446386 351284  688.09877  196   68  687.00000  688.21026  0.18%  19.8  940s
#  448818 353084  688.03584  291   47  687.00000  688.21026  0.18%  19.9  948s
#  449433 353857  688.02240  124   95  687.00000  688.21026  0.18%  19.9  950s
#  452429 355176  688.20322  127   63  687.00000  688.21026  0.18%  20.0  956s
#  454266 356067     cutoff  222       687.00000  688.21026  0.18%  20.0  960s
#  456850 357419     cutoff  165       687.00000  688.21026  0.18%  20.1  965s
#  459288 358681  688.17020  252   52  687.00000  688.21026  0.18%  20.2  970s
#  460955 359124     cutoff  122       687.00000  688.21026  0.18%  20.2  975s
#  462453 360443  688.21026  123   53  687.00000  688.21026  0.18%  20.3  980s
#  465026 361886  688.18349  186   93  687.00000  688.21026  0.18%  20.4  985s
#  467742 363482  688.18256  191  102  687.00000  688.21026  0.18%  20.4  991s
#  468752 363486  688.18263  185   80  687.00000  688.21026  0.18%  20.5  995s
#  469891 364963  688.17011  271   75  687.00000  688.21026  0.18%  20.5 1002s
#  471886 365998  688.09089  123  120  687.00000  688.21026  0.18%  20.5 1006s
#  473851 367284  688.01091  143   71  687.00000  688.21026  0.18%  20.6 1010s
#  476541 368362  688.02339  127   76  687.00000  688.21026  0.18%  20.7 1015s
#  479128 370060  688.19403  155   74  687.00000  688.21026  0.18%  20.7 1021s
#  480639 370412  688.14347  131   68  687.00000  688.21026  0.18%  20.8 1025s
#  482800 372134  688.19153  159   75  687.00000  688.21026  0.18%  20.8 1031s
#  484791 372957  688.15865  124   65  687.00000  688.21026  0.18%  20.9 1035s
#  487555 374446  688.12510  131   95  687.00000  688.21026  0.18%  21.0 1041s
#  489305 375206  688.21026  121   51  687.00000  688.21026  0.18%  21.1 1045s
#  491329 376050  688.08514  134   65  687.00000  688.21026  0.18%  21.1 1050s
#  493696 377003  688.11491  134   81  687.00000  688.21026  0.18%  21.2 1057s
#  495338 377865  688.00482  145   57  687.00000  688.21026  0.18%  21.2 1061s
#  497140 378495  688.16294  245   98  687.00000  688.21026  0.18%  21.3 1065s
#  499850 379682  688.18351  158   82  687.00000  688.21026  0.18%  21.3 1071s
#  501672 380488  688.07169  130   97  687.00000  688.21026  0.18%  21.4 1077s
#  503456 381627  688.00482  153   44  687.00000  688.21026  0.18%  21.4 1081s
#  505711 382579 infeasible  137       687.00000  688.21026  0.18%  21.5 1086s
#  507837 383469  688.00575  147   48  687.00000  688.21026  0.18%  21.5 1090s
#  509808 384280  688.11611  131   80  687.00000  688.21026  0.18%  21.5 1095s
#  512408 385366  688.00399  146   50  687.00000  688.21026  0.18%  21.6 1101s
#  513248 385366     cutoff  127       687.00000  688.21026  0.18%  21.7 1106s
#  513391 385748  688.06287  135  119  687.00000  688.21026  0.18%  21.7 1111s
#  515085 386416  688.19476  126   58  687.00000  688.21026  0.18%  21.7 1115s
#  516815 387056  688.02338  131  101  687.00000  688.21026  0.18%  21.8 1120s
#  518433 387753  688.01857  148   60  687.00000  688.21026  0.18%  21.8 1125s
#  520996 389001  688.00284  155   49  687.00000  688.21026  0.18%  21.9 1132s
#  521415 389651 infeasible  130       687.00000  688.21026  0.18%  21.9 1135s
#  523686 390682  688.14347  130   55  687.00000  688.21026  0.18%  22.0 1140s
#  525744 391570  688.04831  130   78  687.00000  688.21026  0.18%  22.0 1145s
#  527852 392625  688.00214  118   93  687.00000  688.21026  0.18%  22.1 1150s
#  531285 394691 infeasible  130       687.00000  688.21026  0.18%  22.1 1157s
#  533064 395416     cutoff  130       687.00000  688.21026  0.18%  22.2 1161s
#  534008 395747  688.16885  133   78  687.00000  688.21026  0.18%  22.2 1165s
#  535926 396869  688.12382  128   64  687.00000  688.21026  0.18%  22.3 1170s
#  538396 398709  688.15828  131   85  687.00000  688.21026  0.18%  22.3 1175s
#  540637 399660  688.01167  136   61  687.00000  688.21026  0.18%  22.3 1180s
#  543159 400814  688.05134  129   77  687.00000  688.21026  0.18%  22.3 1186s
#  545143 401430  688.18380  163   83  687.00000  688.21026  0.18%  22.4 1191s
#  545152 404697  688.13616  163   69  687.00000  688.21026  0.18%  22.4 1206s
#  552585 406296  688.14010  153   95  687.00000  688.21026  0.18%  22.5 1212s
#  555028 407434  688.00065  157   81  687.00000  688.21026  0.18%  22.6 1216s
#  556988 407869  688.15224  128   67  687.00000  688.21026  0.18%  22.6 1221s
#  558136 408691  688.00214  130   96  687.00000  688.21026  0.18%  22.6 1225s
#  559479 410059  688.21026  121   50  687.00000  688.21026  0.18%  22.6 1230s
#  562654 411648  688.16817  244   82  687.00000  688.21026  0.18%  22.7 1236s
#  564314 412248  688.14173  170   94  687.00000  688.21026  0.18%  22.7 1244s
#  564391 412737  688.08273  170  104  687.00000  688.21026  0.18%  22.7 1246s
#  566638 413651  688.08563  176   77  687.00000  688.21026  0.18%  22.7 1252s
#  567401 414433  688.17171  216   84  687.00000  688.21026  0.18%  22.8 1255s
#  568878 415355  688.16097  279   72  687.00000  688.21026  0.18%  22.8 1260s
#  571313 416414  688.16991  128   61  687.00000  688.21026  0.18%  22.8 1265s
#  572950 417097  688.19949  131   52  687.00000  688.21026  0.18%  22.9 1271s
#  574620 418329  688.00575  155   53  687.00000  688.21026  0.18%  22.9 1276s
#  576989 419469  688.14962  127   88  687.00000  688.21026  0.18%  23.0 1282s
#  578336 419852  688.00351  147   52  687.00000  688.21026  0.18%  23.0 1287s
#  580296 420695  688.02475  124   70  687.00000  688.21026  0.18%  23.0 1292s
#  582276 421332  688.00214  131   92  687.00000  688.21026  0.18%  23.1 1297s
#  584020 421878  688.19094  128   57  687.00000  688.21026  0.18%  23.1 1302s
#  585642 423024  688.21026  106   62  687.00000  688.21026  0.18%  23.1 1306s
#  587566 423957  688.01933  141   92  687.00000  688.21026  0.18%  23.2 1311s
#  588779 425004  688.04626  127  101  687.00000  688.21026  0.18%  23.2 1317s
#  590977 425857  688.10906  133   66  687.00000  688.21026  0.18%  23.2 1322s
#  592906 426649  688.01519  158   77  687.00000  688.21026  0.18%  23.2 1326s
#  594563 427391  688.21026  122   57  687.00000  688.21026  0.18%  23.3 1331s
#  596528 428090  688.12894  120   70  687.00000  688.21026  0.18%  23.3 1336s
#  598179 428833  688.01474  128   86  687.00000  688.21026  0.18%  23.4 1342s
#  598732 429277  688.17527  120   89  687.00000  688.21026  0.18%  23.4 1345s
#  601028 430208  688.01474  136   51  687.00000  688.21026  0.18%  23.4 1351s
#  603030 431141  688.21026  122   49  687.00000  688.21026  0.18%  23.5 1356s
#  604936 431993  688.14298  128   82  687.00000  688.21026  0.18%  23.5 1361s
#  606768 432835 infeasible  131       687.00000  688.21026  0.18%  23.6 1366s
#  608803 434017     cutoff  122       687.00000  688.21026  0.18%  23.6 1372s
#  610118 434019  688.20247  139   73  687.00000  688.21026  0.18%  23.7 1376s
#  610125 436758  688.20241  140   66  687.00000  688.21026  0.18%  23.7 1393s
#  616131 437913  688.19462  126   59  687.00000  688.21026  0.18%  23.8 1398s
#  617593 438472  688.18302  129   67  687.00000  688.21026  0.18%  23.8 1400s
#  619561 439210  688.13321  123   78  687.00000  688.21026  0.18%  23.8 1405s
#  620429 439250  688.19368  120   67  687.00000  688.21026  0.18%  23.8 1412s
#  620550 439385  688.16117  121   77  687.00000  688.21026  0.18%  23.8 1415s
#  621764 440228  688.12955  124   70  687.00000  688.21026  0.18%  23.9 1420s
#  623391 440879  688.19189  124   70  687.00000  688.21026  0.18%  23.9 1425s
#  626159 441967  688.01167  137   51  687.00000  688.21026  0.18%  24.0 1432s
#  627002 442375  688.00575  142  124  687.00000  688.21026  0.18%  24.0 1435s
#  628840 442819  688.00351  147   50  687.00000  688.21026  0.18%  24.1 1440s
#  629988 443501  688.20701  125   60  687.00000  688.21026  0.18%  24.1 1446s
#  631773 444170  688.01933  132   68  687.00000  688.21026  0.18%  24.2 1451s
#  633635 445229     cutoff  125       687.00000  688.21026  0.18%  24.2 1457s
#  634944 445898 infeasible  133       687.00000  688.21026  0.18%  24.2 1460s
#  636723 446306  688.21026  128   56  687.00000  688.21026  0.18%  24.3 1465s
#  638304 447124  688.18834  129   62  687.00000  688.21026  0.18%  24.3 1472s
#  639211 447429  688.14243  126   68  687.00000  688.21026  0.18%  24.3 1475s
#  641058 448117     cutoff  123       687.00000  688.21026  0.18%  24.4 1480s
#  643222 449149  688.17539  126   53  687.00000  688.21026  0.18%  24.4 1487s
#  644178 449721     cutoff  122       687.00000  688.21026  0.18%  24.5 1490s
#  645626 450246  688.07937  127  111  687.00000  688.21026  0.18%  24.5 1496s
#  647825 451217  688.21026  124   64  687.00000  688.21026  0.18%  24.5 1502s
#  648709 451627  688.01859  137   80  687.00000  688.21026  0.18%  24.5 1505s
#  650531 452659  688.17315  118  117  687.00000  688.21026  0.18%  24.6 1510s
#  653207 453692 infeasible  128       687.00000  688.21026  0.18%  24.6 1517s
#  654831 454526  688.20471  124   54  687.00000  688.21026  0.18%  24.6 1521s
#  655867 455039  688.02240  127  106  687.00000  688.21026  0.18%  24.7 1527s
#  657866 456073     cutoff  130       687.00000  688.21026  0.18%  24.7 1532s
#  659657 456927  688.17883  177   83  687.00000  688.21026  0.18%  24.7 1537s
#  661208 457535  688.19093  125   74  687.00000  688.21026  0.18%  24.8 1541s
#  662643 458262  688.21026  125   48  687.00000  688.21026  0.18%  24.8 1547s
#  663585 458588  688.00047  149   58  687.00000  688.21026  0.18%  24.8 1550s
#  665564 458963     cutoff  127       687.00000  688.21026  0.18%  24.9 1556s
#  666314 459525  688.01167  136   57  687.00000  688.21026  0.18%  24.9 1563s
#  667299 459751  688.20566  126   63  687.00000  688.21026  0.18%  25.0 1569s
#  668033 460157  688.20252  128   61  687.00000  688.21026  0.18%  25.0 1573s
#  669198 460575  688.06867  127   98  687.00000  688.21026  0.18%  25.0 1577s
#  670459 460816  688.20555  129   47  687.00000  688.21026  0.18%  25.0 1580s
#  672223 461256  688.00399  157   44  687.00000  688.21026  0.18%  25.1 1586s
#  672804 461617  688.06798  130  105  687.00000  688.21026  0.18%  25.1 1590s
#  674765 462451  688.16568  265   76  687.00000  688.21026  0.18%  25.2 1595s
#  676230 463284  688.13321  132   67  687.00000  688.21026  0.18%  25.2 1600s
#  677795 464350  688.15985  200  114  687.00000  688.21026  0.18%  25.3 1606s
#  679997 466555  688.17883  185   83  687.00000  688.21026  0.18%  25.3 1613s
#  681623 466987  688.16515  429   43  687.00000  688.21026  0.18%  25.3 1616s
#  683533 468316     cutoff  131       687.00000  688.21026  0.18%  25.3 1621s
#  685025 468998     cutoff  129       687.00000  688.21026  0.18%  25.3 1626s
#  686464 469445  688.07268  129   74  687.00000  688.21026  0.18%  25.4 1630s
#  687900 470148  688.10226  181   94  687.00000  688.21026  0.18%  25.4 1635s
#  688741 470153  688.16866  176   75  687.00000  688.21026  0.18%  25.4 1642s
#  688747 470310  688.15148  177   69  687.00000  688.21026  0.18%  25.4 1645s
#  690405 471377  688.14347  125   95  687.00000  688.21026  0.18%  25.4 1652s
#  691304 471739  688.20412  128   61  687.00000  688.21026  0.18%  25.4 1655s
#  693441 473156     cutoff  137       687.00000  688.21026  0.18%  25.5 1661s
#  694382 474171     cutoff  133       687.00000  688.21026  0.18%  25.5 1665s
#  696682 474992  688.15551  126   61  687.00000  688.21026  0.18%  25.5 1671s
#  697723 475380  688.21016  119   66  687.00000  688.21026  0.18%  25.6 1677s
#  698603 475720  688.20947  117   64  687.00000  688.21026  0.18%  25.6 1680s
#  700476 476419  688.05412  125  100  687.00000  688.21026  0.18%  25.6 1685s
#  701900 477079  688.01474  135  109  687.00000  688.21026  0.18%  25.7 1691s
#  704005 477928  688.19235  124   65  687.00000  688.21026  0.18%  25.7 1697s
#  705042 478225  688.03539  121   73  687.00000  688.21026  0.18%  25.7 1700s
# H706704   432                     688.0000000  688.21026  0.03%  25.8 1707s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 2060
#   Implied bound: 6
#   MIR: 258
#   StrongCG: 18
#   Flow cover: 305
#   Inf proof: 4
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 706908 nodes (18228028 simplex iterations) in 1708.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 7: 688 687 686 ... 656
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.880000000000e+02, best bound 6.880000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4x4

# %%
datafile="4x1000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x713fff9f
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 656.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1856782 nonzeros (94%)
# Presolve added 0 rows and 282 columns
# Presolve removed 54 rows and 0 columns
# Presolve time: 6.22s
# Presolved: 4946 rows, 4282 columns, 125190 nonzeros
# Variable types: 306 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.274921e+04   0.000000e+00      6s
#     3496    6.8629731e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.862973e+02, 3496 iterations, 0.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  686.29731    0  210  656.00000  686.29731  4.62%     -    6s
# H    0     0                     679.0000000  686.29731  1.07%     -    6s
# H    0     0                     683.0000000  686.29731  0.48%     -    6s
# H    0     0                     684.0000000  686.29731  0.34%     -    7s
#      0     0  686.29417    0  249  684.00000  686.29417  0.34%     -    7s
#      0     0  686.27890    0  242  684.00000  686.27890  0.33%     -    7s
#      0     0  686.27849    0  238  684.00000  686.27849  0.33%     -    7s
#      0     0  686.27843    0  238  684.00000  686.27843  0.33%     -    7s
#      0     0  686.25457    0  224  684.00000  686.25457  0.33%     -    7s
#      0     0  686.15867    0  200  684.00000  686.15867  0.32%     -    7s
#      0     0  686.15450    0  207  684.00000  686.15450  0.31%     -    7s
#      0     0  686.15417    0  209  684.00000  686.15417  0.31%     -    7s
#      0     0  686.15417    0  207  684.00000  686.15417  0.31%     -    7s
#      0     0  686.12448    0  177  684.00000  686.12448  0.31%     -    8s
#      0     0  686.07715    0  192  684.00000  686.07715  0.30%     -    8s
#      0     0  686.07712    0  188  684.00000  686.07712  0.30%     -    8s
#      0     0  686.02949    0  187  684.00000  686.02949  0.30%     -    8s
#      0     0  686.02681    0  174  684.00000  686.02681  0.30%     -    8s
#      0     0  686.02660    0  155  684.00000  686.02660  0.30%     -    9s
#      0     0  686.02660    0  158  684.00000  686.02660  0.30%     -    9s
#      0     0  686.02360    0  151  684.00000  686.02360  0.30%     -    9s
#      0     0  686.02131    0  147  684.00000  686.02131  0.30%     -    9s
#      0     0  686.02099    0  150  684.00000  686.02099  0.30%     -    9s
#      0     0  686.02087    0  152  684.00000  686.02087  0.30%     -    9s
#      0     0  686.02087    0  151  684.00000  686.02087  0.30%     -    9s
#      0     0  686.01887    0  151  684.00000  686.01887  0.30%     -   10s
#      0     0  686.01830    0  156  684.00000  686.01830  0.30%     -   10s
#      0     0  686.01830    0  144  684.00000  686.01830  0.30%     -   10s
#      0     0  686.01768    0  138  684.00000  686.01768  0.29%     -   10s
#      0     0  686.01687    0  148  684.00000  686.01687  0.29%     -   10s
#      0     0  686.01687    0  142  684.00000  686.01687  0.29%     -   10s
#      0     0  686.01354    0  149  684.00000  686.01354  0.29%     -   10s
#      0     0  686.01311    0  152  684.00000  686.01311  0.29%     -   11s
#      0     0  686.01308    0  150  684.00000  686.01308  0.29%     -   11s
#      0     0  686.01074    0  159  684.00000  686.01074  0.29%     -   11s
#      0     0  686.01047    0  165  684.00000  686.01047  0.29%     -   11s
#      0     0  686.01047    0  152  684.00000  686.01047  0.29%     -   11s
# H    0     0                     685.0000000  686.01047  0.15%     -   12s
#      0     0  686.00971    0  159  685.00000  686.00971  0.15%     -   12s
#      0     0  686.00886    0  168  685.00000  686.00886  0.15%     -   12s
#      0     0 infeasible    0       685.00000  685.00000  0.00%     -   12s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 6
#   Implied bound: 3
#   MIR: 219
#   StrongCG: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (13457 simplex iterations) in 12.30 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 685 684 683 ... 656
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.850000000000e+02, best bound 6.850000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4x5

# %%
datafile="4x1000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xc8d66b13
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 659.0000000
# Presolve removed 19 rows and 12 columns (presolve time = 5s) ...
# Sparsify removed 1846574 nonzeros (93%)
# Presolve added 0 rows and 286 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 6.27s
# Presolved: 4965 rows, 4286 columns, 147390 nonzeros
# Variable types: 298 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9700000e+02   3.684595e+04   0.000000e+00      6s
#     3060    6.9209989e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.920999e+02, 3060 iterations, 0.19 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  692.09989    0  106  659.00000  692.09989  5.02%     -    6s
# H    0     0                     688.0000000  692.09989  0.60%     -    6s
# H    0     0                     689.0000000  692.09989  0.45%     -    6s
# H    0     0                     690.0000000  692.09989  0.30%     -    7s
#      0     0  692.07984    0  129  690.00000  692.07984  0.30%     -    7s
#      0     0  691.85057    0  111  690.00000  691.85057  0.27%     -    7s
#      0     0  691.58223    0  113  690.00000  691.58223  0.23%     -    7s
#      0     0  691.57797    0  104  690.00000  691.57797  0.23%     -    7s
#      0     0  691.57797    0   96  690.00000  691.57797  0.23%     -    8s
# H    0     0                     691.0000000  691.57797  0.08%     -    8s
#
# Cutting planes:
#   Gomory: 25
#   Cover: 11
#   Implied bound: 1
#   MIR: 148
#   StrongCG: 3
#   RLT: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (5562 simplex iterations) in 8.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 691 690 689 ... 659
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.910000000000e+02, best bound 6.910000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4.5x1

# %%
datafile="4x1000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x1b3f72b2
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 611.0000000
# Presolve removed 63 rows and 44 columns (presolve time = 5s) ...
# Sparsify removed 1866269 nonzeros (95%)
# Presolve added 0 rows and 275 columns
# Presolve removed 63 rows and 0 columns
# Presolve time: 6.12s
# Presolved: 4937 rows, 4275 columns, 95879 nonzeros
# Variable types: 319 continuous, 3956 integer (3956 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8900000e+02   2.516376e+04   0.000000e+00      6s
#     3319    6.4326453e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.432645e+02, 3319 iterations, 0.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  643.26453    0  141  611.00000  643.26453  5.28%     -    6s
# H    0     0                     638.0000000  643.26453  0.83%     -    6s
# H    0     0                     640.0000000  643.26453  0.51%     -    6s
# H    0     0                     641.0000000  643.26453  0.35%     -    6s
#      0     0  643.24338    0  132  641.00000  643.24338  0.35%     -    6s
#      0     0  643.08696    0  135  641.00000  643.08696  0.33%     -    7s
#      0     0  643.07077    0  121  641.00000  643.07077  0.32%     -    7s
#      0     0  643.01246    0  121  641.00000  643.01246  0.31%     -    7s
#      0     0  643.01246    0  105  641.00000  643.01246  0.31%     -    7s
# H    0     0                     642.0000000  643.01246  0.16%     -    7s
#      0     0  643.01246    0  116  642.00000  643.01246  0.16%     -    7s
#      0     0  643.01246    0  117  642.00000  643.01246  0.16%     -    8s
#      0     0     cutoff    0       642.00000  642.00000  0.00%     -    8s
#
# Cutting planes:
#   Gomory: 43
#   Cover: 3
#   Implied bound: 1
#   MIR: 110
#   StrongCG: 2
#   RLT: 7
#   Relax-and-lift: 2
#
# Explored 1 nodes (15417 simplex iterations) in 8.44 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 642 641 640 ... 611
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.420000000000e+02, best bound 6.420000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4.5x2

# %%
datafile="4x1000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xc63c1b96
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 605.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Sparsify removed 1846781 nonzeros (93%)
# Presolve added 0 rows and 281 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 6.03s
# Presolved: 4963 rows, 4281 columns, 139215 nonzeros
# Variable types: 301 continuous, 3980 integer (3980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9500000e+02   3.702006e+04   0.000000e+00      6s
#     3272    6.3823663e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.382366e+02, 3272 iterations, 0.23 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  638.23663    0  185  605.00000  638.23663  5.49%     -    6s
# H    0     0                     635.0000000  638.23663  0.51%     -    6s
#      0     0  638.20658    0  192  635.00000  638.20658  0.50%     -    7s
# H    0     0                     637.0000000  638.20658  0.19%     -    7s
#      0     0  638.11106    0  178  637.00000  638.11106  0.17%     -    7s
#      0     0  638.11022    0  183  637.00000  638.11022  0.17%     -    7s
#      0     0     cutoff    0       637.00000  637.00000  0.00%     -    8s
#
# Explored 1 nodes (11687 simplex iterations) in 8.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 637 635 605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.370000000000e+02, best bound 6.370000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4.5x3

# %%
datafile="4x1000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xfaf7d208
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 615.0000000
# Presolve removed 57 rows and 36 columns (presolve time = 5s) ...
# Sparsify removed 1866613 nonzeros (95%)
# Presolve added 0 rows and 279 columns
# Presolve removed 69 rows and 0 columns
# Presolve time: 7.05s
# Presolved: 4931 rows, 4279 columns, 103423 nonzeros
# Variable types: 315 continuous, 3964 integer (3964 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9100000e+02   2.720057e+04   0.000000e+00      7s
#     3407    6.5308267e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.530827e+02, 3407 iterations, 0.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  653.08267    0  130  615.00000  653.08267  6.19%     -    7s
# H    0     0                     648.0000000  653.08267  0.78%     -    7s
# H    0     0                     650.0000000  653.08267  0.47%     -    7s
# H    0     0                     651.0000000  653.08267  0.32%     -    7s
#      0     0  653.07561    0  121  651.00000  653.07561  0.32%     -    7s
# H    0     0                     652.0000000  653.07561  0.16%     -    8s
#      0     0  653.07018    0  123  652.00000  653.07018  0.16%     -    8s
#      0     0  653.06447    0   87  652.00000  653.06447  0.16%     -    8s
#      0     0  653.01432    0  116  652.00000  653.01432  0.16%     -    8s
#      0     0  653.00477    0  109  652.00000  653.00477  0.15%     -    9s
#      0     0  653.00030    0   72  652.00000  653.00030  0.15%     -    9s
#      0     0  653.00030    0   72  652.00000  653.00030  0.15%     -    9s
#      0     0  653.00030    0   87  652.00000  653.00030  0.15%     -    9s
#      0     0  653.00030    0   88  652.00000  653.00030  0.15%     -    9s
#      0     0     cutoff    0       652.00000  652.00000  0.00%     -    9s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 4
#   MIR: 135
#   StrongCG: 2
#   GUB cover: 2
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (14221 simplex iterations) in 9.49 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 652 651 650 ... 615
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.520000000000e+02, best bound 6.520000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4.5x4

# %%
datafile="4x1000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x6c4bccee
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 630.0000000
# Presolve removed 47 rows and 28 columns (presolve time = 5s) ...
# Sparsify removed 1865879 nonzeros (94%)
# Presolve added 0 rows and 291 columns
# Presolve removed 59 rows and 0 columns
# Presolve time: 5.17s
# Presolved: 4941 rows, 4291 columns, 112121 nonzeros
# Variable types: 319 continuous, 3972 integer (3972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9300000e+02   2.800786e+04   0.000000e+00      5s
#     3454    6.5860817e+02   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 6.586082e+02, 3454 iterations, 0.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  658.60817    0  244  630.00000  658.60817  4.54%     -    5s
# H    0     0                     652.0000000  658.60817  1.01%     -    5s
# H    0     0                     655.0000000  658.60817  0.55%     -    5s
#      0     0  658.54658    0  241  655.00000  658.54658  0.54%     -    6s
# H    0     0                     656.0000000  658.54658  0.39%     -    6s
#      0     0  658.54580    0  253  656.00000  658.54580  0.39%     -    6s
# H    0     0                     657.0000000  658.54580  0.24%     -    6s
#      0     0  658.54356    0  221  657.00000  658.54356  0.23%     -    6s
#      0     0  658.48214    0  210  657.00000  658.48214  0.23%     -    6s
#      0     0  658.48214    0  199  657.00000  658.48214  0.23%     -    6s
#      0     0  658.48180    0  188  657.00000  658.48180  0.23%     -    6s
#      0     0  658.42709    0  168  657.00000  658.42709  0.22%     -    7s
#      0     0  658.42343    0  171  657.00000  658.42343  0.22%     -    7s
#      0     0  658.42343    0  159  657.00000  658.42343  0.22%     -    7s
#      0     0  658.42307    0  188  657.00000  658.42307  0.22%     -    7s
#      0     0  658.42307    0  176  657.00000  658.42307  0.22%     -    7s
#      0     0  658.42307    0  177  657.00000  658.42307  0.22%     -    7s
#      0     0  658.38030    0  181  657.00000  658.38030  0.21%     -    7s
#      0     0  658.38030    0  172  657.00000  658.38030  0.21%     -    7s
#      0     0  658.38030    0  166  657.00000  658.38030  0.21%     -    8s
#      0     0  658.38030    0  173  657.00000  658.38030  0.21%     -    8s
#      0     0  658.38030    0  194  657.00000  658.38030  0.21%     -    8s
#      0     0  658.32386    0  204  657.00000  658.32386  0.20%     -    8s
#      0     0  658.32101    0  198  657.00000  658.32101  0.20%     -    8s
#      0     0  658.32093    0  188  657.00000  658.32093  0.20%     -    8s
#      0     0  658.32093    0  160  657.00000  658.32093  0.20%     -    9s
#      0     0  658.30904    0  192  657.00000  658.30904  0.20%     -    9s
#      0     0  658.30904    0  206  657.00000  658.30904  0.20%     -    9s
#      0     0  658.29215    0  213  657.00000  658.29215  0.20%     -    9s
#      0     0  658.29185    0  206  657.00000  658.29185  0.20%     -    9s
#      0     0  658.29144    0  218  657.00000  658.29144  0.20%     -   10s
#      0     0  658.29122    0  213  657.00000  658.29122  0.20%     -   10s
#      0     0  658.29121    0  212  657.00000  658.29121  0.20%     -   10s
#      0     0  658.29121    0  207  657.00000  658.29121  0.20%     -   10s
#      0     0  658.28651    0  213  657.00000  658.28651  0.20%     -   10s
#      0     0  658.28545    0  221  657.00000  658.28545  0.20%     -   10s
#      0     0  658.28507    0  213  657.00000  658.28507  0.20%     -   10s
#      0     0  658.28506    0  226  657.00000  658.28506  0.20%     -   10s
#      0     0  658.28506    0  223  657.00000  658.28506  0.20%     -   10s
#      0     0  658.28310    0  215  657.00000  658.28310  0.20%     -   10s
#      0     0  658.28310    0  211  657.00000  658.28310  0.20%     -   10s
#      0     0  658.28310    0  194  657.00000  658.28310  0.20%     -   10s
#      0     0  658.28149    0  193  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  183  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  177  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  178  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  193  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  154  657.00000  658.28149  0.20%     -   11s
#      0     0  658.28149    0  218  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  182  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  169  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  180  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  192  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  186  657.00000  658.28149  0.20%     -   13s
#      0     0  658.28149    0  181  657.00000  658.28149  0.20%     -   13s
#      0     0  658.27947    0  175  657.00000  658.27947  0.19%     -   13s
#      0     0  658.27908    0  174  657.00000  658.27908  0.19%     -   13s
#      0     0  658.27908    0  175  657.00000  658.27908  0.19%     -   13s
#      0     0  658.27888    0  183  657.00000  658.27888  0.19%     -   13s
#      0     0  658.27821    0  183  657.00000  658.27821  0.19%     -   13s
#      0     0  658.27821    0  180  657.00000  658.27821  0.19%     -   13s
#      0     0  658.27821    0  199  657.00000  658.27821  0.19%     -   14s
#      0     0  658.27812    0  191  657.00000  658.27812  0.19%     -   14s
#      0     0  658.27812    0  180  657.00000  658.27812  0.19%     -   14s
#      0     0  658.27808    0  175  657.00000  658.27808  0.19%     -   14s
#      0     0  658.27808    0  192  657.00000  658.27808  0.19%     -   14s
#      0     0  658.27808    0  178  657.00000  658.27808  0.19%     -   14s
#      0     2  658.27808    0  175  657.00000  658.27808  0.19%     -   15s
#   1855  1623  658.14343   12  212  657.00000  658.19036  0.18%  11.7   20s
#   1874  1636  658.11859  137   93  657.00000  658.19036  0.18%  11.6   25s
#   1889  1651  658.16022   17   86  657.00000  658.17898  0.18%  24.7   30s
#   5139  3868  658.05539  237   81  657.00000  658.16022  0.18%  18.6   35s
#   9645  7096  658.00586   38  116  657.00000  658.15370  0.18%  14.9   40s
#  14216 11020  658.00042   91  116  657.00000  658.15367  0.18%  14.9   45s
#  19005 14724  658.04678   68  106  657.00000  658.15367  0.18%  14.7   50s
#  24033 18959  658.15367   29  127  657.00000  658.15367  0.18%  14.6   55s
#  26450 19849  658.01986   61  216  657.00000  658.15367  0.18%  14.4   60s
#  26465 19859  658.03650   94   99  657.00000  658.15367  0.18%  14.4   65s
#  27011 20575  658.14676   69   91  657.00000  658.15367  0.18%  15.1   70s
#  29212 22003  658.11767  329   73  657.00000  658.15367  0.18%  15.8   75s
#  34798 26015  658.10173  226   95  657.00000  658.15367  0.18%  15.6   80s
#  40192 27476  658.00171  285  154  657.00000  658.15367  0.18%  15.0   99s
#  40194 27477  658.08578  202  220  657.00000  658.15367  0.18%  15.0  100s
#  40211 27489  658.11586   83  132  657.00000  658.15367  0.18%  15.0  106s
#  40220 27495  658.04674  147  131  657.00000  658.15367  0.18%  15.0  111s
#  40227 27499  658.07881  161  113  657.00000  658.15367  0.18%  15.0  115s
#  40232 27503  658.00434  314  156  657.00000  658.15367  0.18%  15.0  120s
#  40237 27506  658.14052   70  132  657.00000  658.15367  0.18%  15.0  125s
#  40528 28405  658.14068   68  107  657.00000  658.15367  0.18%  15.9  130s
#  44373 30447  658.02909  158  134  657.00000  658.15367  0.18%  15.9  135s
#  47386 31822 infeasible   78       657.00000  658.15367  0.18%  15.8  140s
#  53313 35316  657.99935  343   89  657.00000  658.15349  0.18%  15.7  146s
#  58159 36936  658.07833   85  117  657.00000  658.15349  0.18%  15.6  150s
#  62633 38540  658.14128   68  129  657.00000  658.15349  0.18%  15.7  155s
#  64800 38879  658.06810  174   97  657.00000  658.15349  0.18%  15.9  161s
#  65825 39324  658.06528  120  154  657.00000  658.15349  0.18%  15.9  165s
#  65841 39335  658.07302  105  118  657.00000  658.15349  0.18%  15.9  170s
#  65846 39338  658.00000  339  136  657.00000  658.15349  0.18%  15.9  175s
#  65850 39341  658.08463  169  169  657.00000  658.15349  0.18%  15.9  180s
#  66010 39648  658.15132   70  109  657.00000  658.15349  0.18%  16.3  185s
#  68031 41196  658.08063  207   80  657.00000  658.15349  0.18%  16.5  191s
#  70912 42996  658.03614  292  113  657.00000  658.15349  0.18%  16.6  195s
#  74926 45006  658.01758  376  130  657.00000  658.15131  0.18%  16.6  200s
#  77944 45779  658.09331   99  108  657.00000  658.14887  0.17%  16.7  205s
#  83513 48865  658.00360  452   85  657.00000  658.14887  0.17%  16.7  210s
#  88838 51431  657.99982  250   68  657.00000  658.14887  0.17%  16.9  215s
#  93496 53433  658.14481   73  139  657.00000  658.14887  0.17%  17.2  220s
#  96019 54819  658.10429   87  137  657.00000  658.14887  0.17%  17.4  225s
#  101753 57058  658.14812   75  126  657.00000  658.14887  0.17%  17.6  230s
#  105538 58343  658.02118   87  137  657.00000  658.14887  0.17%  17.9  235s
#  110418 61090  658.14482   82  120  657.00000  658.14887  0.17%  18.1  240s
#  116488 62613  658.08667   85  103  657.00000  658.14887  0.17%  18.2  245s
#  120414 64296  658.02449   81  119  657.00000  658.14887  0.17%  18.5  250s
#  124838 66286     cutoff   85       657.00000  658.14887  0.17%  18.8  255s
#  129167 67868  658.14703   77  142  657.00000  658.14887  0.17%  18.8  260s
#  133806 69375  658.00137  666   40  657.00000  658.14887  0.17%  19.0  267s
#  136228 70655  658.14133   77  140  657.00000  658.14887  0.17%  19.0  270s
#  140386 72499  658.00791   77  122  657.00000  658.14887  0.17%  19.2  275s
#  143932 73860  658.04126  106   96  657.00000  658.14887  0.17%  19.4  280s
#  149130 75789  658.00868   99  100  657.00000  658.14887  0.17%  19.5  285s
#  151884 76676  658.05285   94   99  657.00000  658.14887  0.17%  19.6  290s
#  155258 78528 infeasible   85       657.00000  658.14887  0.17%  19.8  295s
#  159736 80166  658.08474   99  100  657.00000  658.14887  0.17%  19.9  300s
#  164377 82801  658.01297  137   94  657.00000  658.14887  0.17%  20.0  305s
#  168750 84072  658.07882  173  105  657.00000  658.14887  0.17%  20.1  311s
#  170279 85701     cutoff  212       657.00000  658.14887  0.17%  20.3  315s
#  174533 86946  658.01915   96  116  657.00000  658.14887  0.17%  20.3  320s
#  179374 88502  658.07259   82  107  657.00000  658.14887  0.17%  20.4  325s
#  182424 90130     cutoff   80       657.00000  658.14887  0.17%  20.6  330s
#  187753 93201  658.02095   85  116  657.00000  658.14887  0.17%  20.6  335s
#  192354 97068  658.14695   73  149  657.00000  658.14887  0.17%  20.7  341s
#  195920 99576  658.13958   82  122  657.00000  658.14887  0.17%  20.9  346s
#  199478 101578  658.00189  708   58  657.00000  658.14887  0.17%  20.9  351s
#  201893 104266  658.14887   71  162  657.00000  658.14887  0.17%  21.0  355s
#  206912 107113  658.14552   73  152  657.00000  658.14887  0.17%  21.1  361s
#  208448 107690  658.14654   78  149  657.00000  658.14887  0.17%  21.2  370s
#  211775 111171  658.14203   74  124  657.00000  658.14887  0.17%  21.3  376s
#  215349 113710  658.00000  174   77  657.00000  658.14887  0.17%  21.4  380s
#  218579 116047  657.99980  138   86  657.00000  658.14887  0.17%  21.5  385s
#  220768 117817  658.00025  160  114  657.00000  658.14887  0.17%  21.5  391s
#  224006 119632  658.03754  143   97  657.00000  658.14887  0.17%  21.7  395s
#  227316 121930  658.01966  140   66  657.00000  658.14887  0.17%  21.9  401s
#  230854 124714  658.14084   81  181  657.00000  658.14887  0.17%  22.1  405s
#  233802 126655  658.04109  104  105  657.00000  658.14887  0.17%  22.2  410s
#  237567 129111  658.13849   76  142  657.00000  658.14887  0.17%  22.3  415s
#  241919 132185  658.14672   76  172  657.00000  658.14887  0.17%  22.4  420s
#  245046 134140  658.08726   82  146  657.00000  658.14887  0.17%  22.6  425s
#  248281 135969  658.08770   72  125  657.00000  658.14887  0.17%  22.7  432s
#  249693 137620  658.08458   82  134  657.00000  658.14887  0.17%  22.8  435s
#  254108 140719  658.00791   82  127  657.00000  658.14887  0.17%  22.8  440s
#  257367 142689  658.13875   76  154  657.00000  658.14887  0.17%  23.0  446s
#  258455 143419  658.08726   87  131  657.00000  658.14887  0.17%  23.1  450s
#  261664 146501  658.04339  107  113  657.00000  658.14887  0.17%  23.1  455s
#  266184 149055  658.04236   96  109  657.00000  658.14887  0.17%  23.1  460s
#  269130 151019  658.09710   81  123  657.00000  658.14887  0.17%  23.2  465s
#  272888 153800  658.07482  103  135  657.00000  658.14887  0.17%  23.3  470s
#  276433 156504  658.14887   76  115  657.00000  658.14887  0.17%  23.4  475s
#  278574 157857  658.14381   78  141  657.00000  658.14887  0.17%  23.4  480s
#  282016 160029  658.14363   79  173  657.00000  658.14887  0.17%  23.5  485s
#  284294 162063  658.08770   74  129  657.00000  658.14887  0.17%  23.6  490s
#  288361 164462  658.03015   87  148  657.00000  658.14887  0.17%  23.7  495s
#  291938 167186  658.12641   77  133  657.00000  658.14887  0.17%  23.8  500s
#  296051 170286  658.13683   80  146  657.00000  658.14887  0.17%  23.8  505s
#  299820 173306  658.00761  107  121  657.00000  658.14887  0.17%  23.7  510s
#  301782 174740  658.12595   82  135  657.00000  658.14887  0.17%  23.8  515s
#  305272 177869  658.14174   74  157  657.00000  658.14887  0.17%  23.9  521s
#  309735 181213  658.07664  114  107  657.00000  658.14887  0.17%  23.7  525s
#  313028 183168  658.14366   69  159  657.00000  658.14887  0.17%  23.8  530s
#  316499 185803  658.14887   66  133  657.00000  658.14887  0.17%  23.9  535s
#  320526 188652  658.00000  917   35  657.00000  658.14887  0.17%  23.9  540s
#  323099 190602  658.09710   77  114  657.00000  658.14887  0.17%  24.0  545s
#  327217 194337  658.01419  175   69  657.00000  658.14887  0.17%  23.9  551s
#  331788 197333  658.08770   88  116  657.00000  658.14887  0.17%  23.8  555s
#  335093 199552  658.08770   78  116  657.00000  658.14887  0.17%  23.9  560s
#  337216 200705  658.02954  154   72  657.00000  658.14887  0.17%  23.9  566s
#  339571 202714  658.08770   69  124  657.00000  658.14887  0.17%  24.0  571s
#  342709 204454  658.13875   72  135  657.00000  658.14887  0.17%  24.1  576s
#  345403 206715  658.02087   79  130  657.00000  658.14887  0.17%  24.2  581s
#  348035 208307  658.14887   70  139  657.00000  658.14887  0.17%  24.2  585s
#  350517 210237  658.09710   80  123  657.00000  658.14887  0.17%  24.3  590s
#  353911 212542  658.06966  129  117  657.00000  658.14887  0.17%  24.4  595s
#  358753 215596  658.00848   81  110  657.00000  658.14887  0.17%  24.4  600s
#  362017 218295  658.02979  100  100  657.00000  658.14887  0.17%  24.5  606s
#  363667 218728  658.13829   81  132  657.00000  658.14887  0.17%  24.5  610s
#  366409 221364  658.05972   76  127  657.00000  658.14887  0.17%  24.5  616s
#  369676 223685  658.01404  371   44  657.00000  658.14887  0.17%  24.6  620s
#  372549 225819  658.12533   74  143  657.00000  658.14887  0.17%  24.6  625s
#  375513 228577  658.14835   72  161  657.00000  658.14887  0.17%  24.7  630s
#  379997 231203  658.14887   68  150  657.00000  658.14887  0.17%  24.6  635s
#  383707 234634     cutoff   71       657.00000  658.14887  0.17%  24.6  640s
#  388306 238155     cutoff   81       657.00000  658.14887  0.17%  24.5  645s
#  391839 241195  658.00637   85  152  657.00000  658.14887  0.17%  24.6  651s
#  394647 242581  658.14690   70  140  657.00000  658.14887  0.17%  24.6  655s
#  398351 245171  658.01606   98  112  657.00000  658.14887  0.17%  24.7  660s
#  401209 247992     cutoff  129       657.00000  658.14887  0.17%  24.7  665s
#  404431 249278  657.99976  209   43  657.00000  658.14887  0.17%  24.6  670s
#  407665 252159  658.00025  172   95  657.00000  658.14887  0.17%  24.6  675s
#  410109 253885  658.14551   78  150  657.00000  658.14887  0.17%  24.7  680s
#  413390 255971  658.14530   75  184  657.00000  658.14887  0.17%  24.8  686s
#  415781 257887  658.14832   75  166  657.00000  658.14887  0.17%  24.8  690s
#  419460 260264  658.11649   81  154  657.00000  658.14887  0.17%  24.9  696s
#  421734 261737  658.08726   88  128  657.00000  658.14887  0.17%  24.9  700s
#  424330 263653  658.14644   78  162  657.00000  658.14887  0.17%  25.0  705s
#  428308 266346  658.01419   86  126  657.00000  658.14887  0.17%  25.0  711s
#  430972 268214  658.09710   84  147  657.00000  658.14887  0.17%  25.0  715s
#  434321 270596  658.01706  189   79  657.00000  658.14887  0.17%  25.1  721s
#  437101 272329  658.14337   79  158  657.00000  658.14887  0.17%  25.1  725s
#  440044 274250  658.14731   81  175  657.00000  658.14887  0.17%  25.2  730s
#  443215 276590  658.05845   98  121  657.00000  658.14887  0.17%  25.2  738s
#  444059 277067  658.09710   89  143  657.00000  658.14887  0.17%  25.2  740s
#  447004 279140  658.14887   79  140  657.00000  658.14887  0.17%  25.2  745s
#  450969 282011  658.03830   88  126  657.00000  658.14887  0.17%  25.3  751s
#  453876 283832  658.03932  133   73  657.00000  658.14887  0.17%  25.3  756s
#  455874 284913  658.14887   77  135  657.00000  658.14887  0.17%  25.3  760s
#  458834 287654  658.02654  106  133  657.00000  658.14887  0.17%  25.3  766s
#  462090 289450  658.01807   97  147  657.00000  658.14887  0.17%  25.3  770s
#  464745 291277  658.00766  113   99  657.00000  658.14887  0.17%  25.4  775s
#  468406 293826  658.07284  103  139  657.00000  658.14887  0.17%  25.4  780s
#  471839 296369  658.14161   79  173  657.00000  658.14887  0.17%  25.4  785s
#  475529 298975  658.00285  283   82  657.00000  658.14887  0.17%  25.4  790s
#  478601 301145  658.00009  206   53  657.00000  658.14887  0.17%  25.4  795s
#  481239 302882  658.01779   88  128  657.00000  658.14887  0.17%  25.4  800s
#  484356 305329  658.14254   77  161  657.00000  658.14887  0.17%  25.5  805s
#  486724 306806  658.13310   88  145  657.00000  658.14887  0.17%  25.5  810s
#  489447 308899  658.14532   81  163  657.00000  658.14887  0.17%  25.5  815s
#  493004 311629  658.06720   88  142  657.00000  658.14887  0.17%  25.5  820s
#  494946 312741  658.14855   79  160  657.00000  658.14887  0.17%  25.5  825s
#  498795 316005  658.00000  413   46  657.00000  658.14887  0.17%  25.5  830s
#  502901 319246  658.07846   90  126  657.00000  658.14887  0.17%  25.4  835s
#  505767 321106  658.09710   93  133  657.00000  658.14887  0.17%  25.4  840s
#  509113 323432  658.00640  142   97  657.00000  658.14887  0.17%  25.4  845s
#  512794 325868  658.14799   77  166  657.00000  658.14887  0.17%  25.5  851s
#  515717 328172  658.13967   75  163  657.00000  658.14887  0.17%  25.4  855s
#  520070 330916  658.14742   77  171  657.00000  658.14887  0.17%  25.4  861s
#  522668 332221  658.08214   92  133  657.00000  658.14885  0.17%  25.4  873s
#  522711 332565  658.07581   93  127  657.00000  658.14884  0.17%  25.4  875s
#  525017 334399  658.13906   83  149  657.00000  658.14882  0.17%  25.4  880s
#  527965 336438  658.00766  143  121  657.00000  658.14881  0.17%  25.4  885s
#  529465 336813  658.14880   72  180  657.00000  658.14880  0.17%  25.5  890s
#  530826 338402  658.06077   78  143  657.00000  658.14880  0.17%  25.5  895s
#  533997 340339 infeasible   99       657.00000  658.14880  0.17%  25.6  901s
#  535634 341405  658.00364   91  114  657.00000  658.14880  0.17%  25.6  905s
#  538230 343330  658.14785   75  163  657.00000  658.14880  0.17%  25.7  911s
#  541034 345079  658.14450   76  167  657.00000  658.14880  0.17%  25.7  916s
#  543066 346439  658.14354   77  161  657.00000  658.14880  0.17%  25.8  920s
#  545596 348432  658.13989   79  169  657.00000  658.14880  0.17%  25.8  926s
#  548199 350166  658.10578   82  130  657.00000  658.14880  0.17%  25.8  930s
#  551211 352061  658.08411   85  140  657.00000  658.14880  0.17%  25.8  935s
#  554046 353884  658.14873   70  174  657.00000  658.14880  0.17%  25.9  940s
#  556647 355435     cutoff  106       657.00000  658.14880  0.17%  25.9  945s
#  559092 357213  658.01359   89  151  657.00000  658.14880  0.17%  25.9  951s
#  561176 358715  658.14880   72  152  657.00000  658.14880  0.17%  26.0  955s
#  564368 360956  658.11321   81  142  657.00000  658.14880  0.17%  26.0  961s
#  566723 362215     cutoff   96       657.00000  658.14880  0.17%  26.0  965s
#  569536 363831  658.14880   72  159  657.00000  658.14880  0.17%  26.0  970s
#  570269 363975  658.14043   69  128  657.00000  658.14880  0.17%  26.1  977s
#  570425 365067  658.09710   70  133  657.00000  658.14880  0.17%  26.1  980s
#  573288 366590  658.02193   94  153  657.00000  658.14880  0.17%  26.1  986s
#  575695 368163  658.14880   69  161  657.00000  658.14880  0.17%  26.2  991s
#  578302 370075  658.13294   81  149  657.00000  658.14880  0.17%  26.2  996s
#  580742 371584  658.09377   88  129  657.00000  658.14880  0.17%  26.2 1000s
#  583948 373561  658.08746   86  130  657.00000  658.14880  0.17%  26.2 1006s
#  586357 375073  658.14880   72  153  657.00000  658.14880  0.17%  26.2 1010s
#  588628 376694  658.03066   87  119  657.00000  658.14880  0.17%  26.2 1015s
#  591656 378843  658.06199   74  128  657.00000  658.14878  0.17%  26.2 1021s
#  594786 380758  658.00236  153   52  657.00000  658.14877  0.17%  26.2 1026s
#  596696 382082  658.04236  114   93  657.00000  658.14876  0.17%  26.2 1030s
#  600468 384983  658.02200   85  153  657.00000  658.14875  0.17%  26.2 1036s
#  603622 386773 infeasible  102       657.00000  658.14874  0.17%  26.2 1040s
#  606921 388742  658.09710  105  114  657.00000  658.14873  0.17%  26.1 1045s
#  609329 390685  658.09585   70  134  657.00000  658.14873  0.17%  26.2 1050s
#  612133 392694  658.08445   73  138  657.00000  658.14873  0.17%  26.2 1056s
#  613643 393822  658.14873   69  182  657.00000  658.14873  0.17%  26.2 1060s
#  615604 395189  658.08619   69  172  657.00000  658.14873  0.17%  26.2 1067s
#  616631 396167  658.08574   78  160  657.00000  658.14873  0.17%  26.3 1070s
#  619416 398427  658.02618  137   59  657.00000  658.14873  0.17%  26.2 1075s
#  622953 400302  658.14418   71  184  657.00000  658.14873  0.17%  26.2 1080s
#  626780 403300  658.09585   80  167  657.00000  658.14873  0.17%  26.2 1085s
#  630225 405062  658.09971   77  125  657.00000  658.14872  0.17%  26.2 1091s
#  632737 406781  658.01338  184   79  657.00000  658.14871  0.17%  26.2 1095s
#  635372 408803  658.04236   94   83  657.00000  658.14870  0.17%  26.2 1100s
#  638046 410229  658.14402   79  163  657.00000  658.14869  0.17%  26.2 1105s
#  640658 412128  658.04236   99   79  657.00000  658.14868  0.17%  26.2 1110s
#  643221 413968  658.06779   81  116  657.00000  658.14867  0.17%  26.2 1115s
#  646259 415627  658.01281   90  116  657.00000  658.14866  0.17%  26.2 1120s
#  648754 417565  658.12807   83  126  657.00000  658.14865  0.17%  26.2 1125s
#  652098 420262  658.00016  192   78  657.00000  658.14864  0.17%  26.1 1131s
#  654924 422115  658.09710   83  133  657.00000  658.14864  0.17%  26.1 1135s
#  657884 424134  658.13518   80  137  657.00000  658.14863  0.17%  26.1 1140s
#  660794 426284  658.00180  136  103  657.00000  658.14862  0.17%  26.1 1145s
#  663993 428421  658.08123   73  117  657.00000  658.14861  0.17%  26.0 1150s
#  666952 430034  658.00153  184   59  657.00000  658.14860  0.17%  26.0 1155s
#  668249 430481  658.01832   86  105  657.00000  658.14859  0.17%  26.0 1160s
#  670431 432457     cutoff  298       657.00000  658.14859  0.17%  26.0 1165s
#  673367 434315     cutoff   73       657.00000  658.14857  0.17%  26.0 1170s
#  676070 436324  658.00025  148   78  657.00000  658.14857  0.17%  26.0 1175s
#  678889 437966  658.14396   77  149  657.00000  658.14856  0.17%  26.0 1180s
#  681493 439750  658.13621   78  151  657.00000  658.14855  0.17%  26.0 1185s
#  683338 440941  658.08617   73  140  657.00000  658.14855  0.17%  26.0 1190s
#  685280 442621  658.00685  194   69  657.00000  658.14855  0.17%  26.1 1195s
#  687520 444124  658.13590   76  231  657.00000  658.14855  0.17%  26.1 1200s
#  689942 445943  658.12852   75  148  657.00000  658.14855  0.17%  26.2 1206s
#  692343 447431  658.13607   72  152  657.00000  658.14855  0.17%  26.2 1210s
#  695310 449685  658.14801   73  160  657.00000  658.14855  0.17%  26.2 1216s
#  697928 450918  658.14851   73  183  657.00000  658.14855  0.17%  26.2 1223s
#  698777 451815  658.13985   69  175  657.00000  658.14855  0.17%  26.2 1226s
#  700673 453698  658.05080  173   81  657.00000  658.14855  0.17%  26.3 1231s
#  703389 455544  658.14669   74  183  657.00000  658.14855  0.17%  26.3 1237s
#  705392 456705  658.14009   82  165  657.00000  658.14855  0.17%  26.3 1240s
#  708198 459000  658.01295  141  107  657.00000  658.14855  0.17%  26.3 1247s
#  710306 460453  658.14696   74  171  657.00000  658.14855  0.17%  26.3 1250s
#  711914 461710  658.14780   69  167  657.00000  658.14855  0.17%  26.3 1255s
#  715834 464647  658.03533   81  149  657.00000  658.14855  0.17%  26.3 1261s
#  718018 466268  658.14022   73  150  657.00000  658.14855  0.17%  26.3 1265s
#  720976 468819  657.99980  237   61  657.00000  658.14855  0.17%  26.3 1270s
#  724174 470624  658.09971   74  122  657.00000  658.14854  0.17%  26.3 1275s
#  727223 472523  657.99980  154   70  657.00000  658.14853  0.17%  26.3 1281s
#  729558 474758  658.08765  117  104  657.00000  658.14852  0.17%  26.3 1286s
#  733173 477181  658.04076  112   91  657.00000  658.14852  0.17%  26.2 1291s
#  735163 478800  658.13548   79  142  657.00000  658.14852  0.17%  26.2 1295s
#  738398 481266  658.07063  174  104  657.00000  658.14851  0.17%  26.2 1300s
#  741280 482774  658.00893  103  105  657.00000  658.14850  0.17%  26.2 1306s
#  742891 483470  658.00030  146   95  657.00000  658.14850  0.17%  26.2 1310s
#  745035 485637  658.13078   83  135  657.00000  658.14849  0.17%  26.1 1315s
#  747801 487687  658.08366   81  139  657.00000  658.14848  0.17%  26.1 1321s
#  750289 489288  658.02318  109  104  657.00000  658.14848  0.17%  26.1 1326s
#  752266 490395  658.14791   72  168  657.00000  658.14847  0.17%  26.1 1330s
#  754772 491760  658.00893   89  101  657.00000  658.14846  0.17%  26.1 1335s
#  756844 493252  658.14846   71  165  657.00000  658.14846  0.17%  26.2 1341s
#  758852 494887  658.09550   79  129  657.00000  658.14846  0.17%  26.2 1346s
#  760588 495890  657.99980  188   79  657.00000  658.14846  0.17%  26.2 1350s
#  762975 497308  658.14339   77  185  657.00000  658.14846  0.17%  26.3 1355s
#  763526 497674  658.09303   83  141  657.00000  658.14846  0.17%  26.3 1360s
#  765535 499572  658.00078   85  170  657.00000  658.14846  0.17%  26.3 1366s
#  766770 500750  658.06953  196   78  657.00000  658.14846  0.17%  26.3 1370s
#  769471 502021  658.01281  176   73  657.00000  658.14846  0.17%  26.3 1375s
#  772971 504507  658.09303   77  146  657.00000  658.14846  0.17%  26.3 1381s
#  774834 505684  658.14003   68  177  657.00000  658.14846  0.17%  26.4 1385s
#  777170 507476  658.07106   82  137  657.00000  658.14846  0.17%  26.4 1391s
#  780016 509360  658.00595  114   84  657.00000  658.14846  0.17%  26.4 1397s
#  782155 510276  658.14105   70  174  657.00000  658.14846  0.17%  26.4 1400s
#  784308 511815  658.08540   83  151  657.00000  658.14845  0.17%  26.4 1406s
#  786270 513168  658.14675   75  178  657.00000  658.14844  0.17%  26.4 1410s
#  789149 515187     cutoff   98       657.00000  658.14843  0.17%  26.4 1416s
#  791223 516374  658.08411   90  137  657.00000  658.14843  0.17%  26.4 1420s
#  793914 518287  658.08965   88  129  657.00000  658.14842  0.17%  26.4 1425s
#  796421 519504  658.13531   76  168  657.00000  658.14841  0.17%  26.4 1433s
#  796495 520057  658.12833   77  163  657.00000  658.14841  0.17%  26.4 1435s
#  799296 522435  658.09583   83  147  657.00000  658.14840  0.17%  26.4 1442s
#  800778 523095  658.13189   77  142  657.00000  658.14840  0.17%  26.3 1445s
#  803134 524516  658.05286   89  113  657.00000  658.14839  0.17%  26.3 1450s
#  805687 525925  658.08617   73  150  657.00000  658.14838  0.17%  26.3 1455s
#  808195 527817  658.13590   74  165  657.00000  658.14838  0.17%  26.3 1461s
#  810391 529352  658.08619   77  134  657.00000  658.14837  0.17%  26.3 1465s
#  813423 531277  658.09710   86  131  657.00000  658.14836  0.17%  26.3 1471s
#  815217 532342  658.14648   81  167  657.00000  658.14836  0.17%  26.3 1475s
#  817755 534277     cutoff   91       657.00000  658.14835  0.17%  26.3 1480s
#  821265 536245  658.00761  106   78  657.00000  658.14834  0.17%  26.3 1485s
#  823741 537682  658.01517   83  150  657.00000  658.14834  0.17%  26.3 1490s
#  826040 539438  658.14422   76  180  657.00000  658.14833  0.17%  26.2 1496s
#  827956 540720  657.99956   84  154  657.00000  658.14833  0.17%  26.2 1500s
#  830492 542510  658.09585   85  136  657.00000  658.14832  0.17%  26.3 1506s
#  832320 543629  658.03910  133   67  657.00000  658.14832  0.17%  26.2 1510s
#  834777 545301  658.14717   64  175  657.00000  658.14831  0.17%  26.3 1516s
#  836569 546252  658.04381   83  117  657.00000  658.14831  0.17%  26.3 1520s
#  838607 547832  658.01188   86  128  657.00000  658.14830  0.17%  26.3 1526s
#  840202 549033  658.12665   79  139  657.00000  658.14829  0.17%  26.3 1530s
#  842403 550278  658.14369   73  185  657.00000  658.14828  0.17%  26.3 1535s
#  844304 551388  658.06692  154   72  657.00000  658.14828  0.17%  26.3 1541s
#  845230 552373  658.14773   70  167  657.00000  658.14827  0.17%  26.3 1545s
#  847120 553785  658.08332   91  116  657.00000  658.14827  0.17%  26.3 1550s
#  850290 555669  658.00766  112   93  657.00000  658.14826  0.17%  26.3 1556s
#  852082 556932  658.04236  122  102  657.00000  658.14825  0.17%  26.3 1560s
#  853805 558243  658.09327   92  134  657.00000  658.14825  0.17%  26.3 1566s
#  855752 559073  658.08707   73  135  657.00000  658.14824  0.17%  26.3 1570s
#  857506 560265  658.08905   80  140  657.00000  658.14824  0.17%  26.3 1576s
#  858769 561110  658.12219   72  167  657.00000  658.14824  0.17%  26.4 1580s
#  860364 562713  658.09599   85  115  657.00000  658.14824  0.17%  26.4 1586s
#  861679 562717  658.00336  194   71  657.00000  658.14824  0.17%  26.4 1601s
#  862775 564138  658.01730  111   91  657.00000  658.14824  0.17%  26.4 1607s
#  864835 565673  658.09710   83  122  657.00000  658.14823  0.17%  26.4 1611s
#  866991 566782  658.01236   90  116  657.00000  658.14823  0.17%  26.4 1615s
#  869302 568183  658.01212   94  111  657.00000  658.14822  0.17%  26.4 1621s
#  870006 568560  658.08411   82  142  657.00000  658.14822  0.17%  26.4 1626s
#  871428 569865  658.08868   78  127  657.00000  658.14821  0.17%  26.4 1631s
#  873649 571002  658.13247   76  157  657.00000  658.14820  0.17%  26.4 1636s
#  875469 572181  658.00868  100  104  657.00000  658.14820  0.17%  26.4 1640s
#  878089 573793  658.13435   79  165  657.00000  658.14819  0.17%  26.4 1647s
#  880078 575064  658.14783   66  192  657.00000  658.14818  0.17%  26.4 1651s
#  881992 576381  658.14474   76  169  657.00000  658.14817  0.17%  26.4 1656s
#  883777 577605  658.14093   76  147  657.00000  658.14817  0.17%  26.4 1660s
#  885825 578804  658.01124   85  156  657.00000  658.14816  0.17%  26.4 1665s
#  887577 579980  658.09377   79  131  657.00000  658.14815  0.17%  26.4 1670s
#  889506 581399     cutoff   79       657.00000  658.14815  0.17%  26.4 1675s
#  892486 583286  658.14502   84  167  657.00000  658.14814  0.17%  26.4 1682s
#  894457 584442  658.08649   80  128  657.00000  658.14814  0.17%  26.4 1686s
#  896472 586131  658.08189   94  116  657.00000  658.14814  0.17%  26.3 1690s
#  898505 588159  658.00791   78  131  657.00000  658.14814  0.17%  26.3 1695s
#  901178 590140  658.08411   83  130  657.00000  658.14813  0.17%  26.3 1700s
#  902904 590575  658.03230  136   77  657.00000  658.14813  0.17%  26.3 1705s
#  903850 592092  658.08493   72  138  657.00000  658.14813  0.17%  26.3 1710s
#  906763 593846  658.00761  101   95  657.00000  658.14812  0.17%  26.3 1715s
#  908826 595595  658.08630  138   93  657.00000  658.14811  0.17%  26.3 1721s
#  910834 597050  658.13519   63  175  657.00000  658.14811  0.17%  26.2 1725s
#  913514 598654  658.00010  161  124  657.00000  658.14810  0.17%  26.2 1731s
#  915304 600040  658.14253   77  154  657.00000  658.14810  0.17%  26.2 1736s
#  916980 600797  658.14641   76  151  657.00000  658.14809  0.17%  26.2 1740s
#  918761 602284  658.14655   77  151  657.00000  658.14809  0.17%  26.2 1745s
#  920853 603550  658.02200   74  130  657.00000  658.14808  0.17%  26.2 1750s
#  922953 605013  658.09710   82  123  657.00000  658.14808  0.17%  26.2 1755s
#  924934 606108  658.08377   87  140  657.00000  658.14807  0.17%  26.2 1760s
#  926669 607966  658.00382  195  119  657.00000  658.14807  0.17%  26.2 1765s
#  929316 609754  658.00761  120  102  657.00000  658.14807  0.17%  26.2 1770s
#  931328 611238  658.08746   75  134  657.00000  658.14806  0.17%  26.2 1775s
#  934684 613843  658.14369   80  156  657.00000  658.14806  0.17%  26.1 1781s
#  936892 615272  658.05286   83   94  657.00000  658.14805  0.17%  26.1 1786s
#  938247 615643     cutoff  120       657.00000  658.14804  0.17%  26.1 1793s
#  938390 616111 infeasible   84       657.00000  658.14804  0.17%  26.1 1795s
#  940869 617880  658.08304   94  130  657.00000  658.14804  0.17%  26.1 1801s
#  942705 619185  658.01648  100  114  657.00000  658.14804  0.17%  26.1 1806s
#  944524 620497  658.00470  174   66  657.00000  658.14803  0.17%  26.1 1810s
#  946134 621495  658.04642   82  120  657.00000  658.14803  0.17%  26.1 1815s
#  948924 623207  658.12652   85  134  657.00000  658.14802  0.17%  26.1 1822s
#  950641 624625  658.09082   76  111  657.00000  658.14801  0.17%  26.1 1826s
#  952696 625910  658.13973   74  155  657.00000  658.14801  0.17%  26.1 1832s
#  954265 626719  658.14121   77  221  657.00000  658.14800  0.17%  26.1 1836s
#  955638 627748  658.07546  104  168  657.00000  658.14800  0.17%  26.1 1841s
#  956845 629515  658.14283   70  177  657.00000  658.14799  0.17%  26.2 1849s
#  957873 629515     cutoff   83       657.00000  658.14799  0.17%  26.2 1850s
#  960483 631062  658.07567   85  147  657.00000  658.14798  0.17%  26.2 1856s
#  962883 633389  658.01074  174   52  657.00000  658.14798  0.17%  26.1 1862s
#  964548 634366  658.00326  262   62  657.00000  658.14798  0.17%  26.1 1865s
#  966665 635378  658.09710   86  143  657.00000  658.14797  0.17%  26.1 1870s
#  968600 636675  658.14518   76  166  657.00000  658.14796  0.17%  26.1 1875s
#  970100 637834  658.08538   80  138  657.00000  658.14796  0.17%  26.1 1880s
#  972408 639139  658.14396   76  173  657.00000  658.14796  0.17%  26.1 1885s
#  974233 640571  658.03504  185   68  657.00000  658.14795  0.17%  26.1 1890s
#  976200 641445  658.13922   76  154  657.00000  658.14795  0.17%  26.1 1898s
#  976401 642100  658.13264   77  134  657.00000  658.14795  0.17%  26.1 1901s
#  978132 643016  658.01122   69  149  657.00000  658.14794  0.17%  26.1 1905s
#  979958 644617  658.00761  103  108  657.00000  658.14794  0.17%  26.1 1911s
#  981971 645867  658.09710   83  113  657.00000  658.14793  0.17%  26.1 1916s
#  983602 646954  658.04964   94  125  657.00000  658.14792  0.17%  26.1 1922s
#  985407 648069  658.14561   77  150  657.00000  658.14792  0.17%  26.1 1927s
#  986371 649250  658.08765  106  111  657.00000  658.14792  0.17%  26.1 1930s
#  988897 650748  658.06389   81  137  657.00000  658.14791  0.17%  26.1 1936s
#  990327 651587  658.05286   89  101  657.00000  658.14791  0.17%  26.1 1940s
#  992054 652914  658.12714   78  169  657.00000  658.14791  0.17%  26.1 1946s
#  993523 653758  658.00605  101  122  657.00000  658.14791  0.17%  26.1 1950s
#  995227 654962  658.08512   73  218  657.00000  658.14791  0.17%  26.2 1957s
#  996697 656482  658.14736   67  172  657.00000  658.14791  0.17%  26.2 1963s
#  998145 657075  658.09277   81  162  657.00000  658.14791  0.17%  26.2 1966s
#  998996 657763  658.07771   93  122  657.00000  658.14791  0.17%  26.2 1970s
#  1000969 658835  658.09477   75  146  657.00000  658.14791  0.17%  26.2 1976s
#  1002531 659610  658.07358   96  157  657.00000  658.14791  0.17%  26.2 1985s
#  1003855 661912  658.09477   79  182  657.00000  658.14791  0.17%  26.2 1993s
#  1005611 663386  658.08192   84  150  657.00000  658.14791  0.17%  26.2 1998s
#  1007524 663691  658.10202   75  171  657.00000  658.14791  0.17%  26.2 2000s
#  1009288 665861  658.08512   82  149  657.00000  658.14791  0.17%  26.2 2008s
#  1010885 666590  658.00000  559   32  657.00000  658.14791  0.17%  26.2 2010s
#  1012689 668061     cutoff   81       657.00000  658.14791  0.17%  26.2 2017s
#  1013669 668951  658.00180  128   86  657.00000  658.14791  0.17%  26.2 2020s
#  1015826 670671  658.00141  182  119  657.00000  658.14791  0.17%  26.2 2026s
#  1017926 671886  658.13941   76  151  657.00000  658.14790  0.17%  26.2 2032s
#  1018759 672780  658.12319   83  145  657.00000  658.14790  0.17%  26.2 2035s
#  1020874 673780 infeasible   95       657.00000  658.14789  0.17%  26.2 2041s
#  1021634 674922  658.09252   85  134  657.00000  658.14789  0.17%  26.2 2045s
#  1024114 676098  658.00572  115  106  657.00000  658.14789  0.17%  26.2 2050s
#  1025546 676957  658.08074   86  139  657.00000  658.14788  0.17%  26.2 2055s
#  1027308 678396  658.09710   73  129  657.00000  658.14788  0.17%  26.2 2061s
#  1029036 679270  658.14245   75  143  657.00000  658.14787  0.17%  26.2 2066s
#  1030543 680416  658.00795  122  107  657.00000  658.14787  0.17%  26.2 2072s
#  1032135 681025  658.14645   66  175  657.00000  658.14786  0.17%  26.2 2075s
#  1033059 681695  658.14719   69  174  657.00000  658.14786  0.17%  26.2 2080s
#  1033941 682512  658.00615   87  119  657.00000  658.14786  0.17%  26.2 2085s
#  1035674 683310  658.08726   93  131  657.00000  658.14786  0.17%  26.2 2092s
#  1035964 683920  658.08726   93  130  657.00000  658.14786  0.17%  26.2 2096s
#  1036942 684537  658.09710   92  125  657.00000  658.14785  0.17%  26.2 2100s
#  1038905 685610  658.14644   65  184  657.00000  658.14785  0.17%  26.2 2106s
#  1039666 686529  658.14562   76  153  657.00000  658.14785  0.17%  26.2 2110s
#  1041470 687703  658.09585   80  133  657.00000  658.14784  0.17%  26.2 2117s
#  1042674 688467  658.02200   79  129  657.00000  658.14784  0.17%  26.2 2120s
#  1044793 689690  658.13966   77  145  657.00000  658.14783  0.17%  26.2 2128s
#  1045779 690267  658.14020   84  164  657.00000  658.14783  0.17%  26.2 2131s
#  1047010 691643  658.13242   69  193  657.00000  658.14783  0.17%  26.3 2138s
#  1048443 692334  658.14348   67  190  657.00000  658.14783  0.17%  26.3 2141s
#  1049818 692948  658.14501   65  193  657.00000  658.14783  0.17%  26.3 2145s
#  1051197 694897  658.04255   98  109  657.00000  658.14783  0.17%  26.3 2152s
#  1052790 695778  658.14572   68  188  657.00000  658.14783  0.17%  26.3 2156s
#  1054710 696564  658.00325  190   47  657.00000  658.14783  0.17%  26.3 2160s
#  1055921 697691  658.13932   66  188  657.00000  658.14783  0.17%  26.3 2168s
#  1056247 699038  658.14255   68  197  657.00000  658.14783  0.17%  26.3 2172s
#  1057936 699720  658.08493   85  144  657.00000  658.14783  0.17%  26.3 2176s
#  1059597 700582  658.08509   76  140  657.00000  658.14783  0.17%  26.3 2181s
#  1060193 701323  658.13764   66  174  657.00000  658.14783  0.17%  26.3 2185s
#  1062164 702477  658.01508   77  157  657.00000  658.14783  0.17%  26.3 2191s
#  1063013 703442  658.14316   71  184  657.00000  658.14783  0.17%  26.3 2196s
#  1065037 704579  658.00761  115   89  657.00000  658.14783  0.17%  26.3 2202s
#  1065802 705376  658.14411   70  182  657.00000  658.14783  0.17%  26.3 2207s
#  1066960 705980  658.09474   78  159  657.00000  658.14783  0.17%  26.3 2210s
#  1069009 707414  657.99978  136   78  657.00000  658.14783  0.17%  26.3 2218s
#  1069959 708338  658.08464   75  166  657.00000  658.14783  0.17%  26.3 2222s
#  1071211 709080  658.02561  159   47  657.00000  658.14783  0.17%  26.3 2225s
#  1073367 710395  658.08726   78  137  657.00000  658.14783  0.17%  26.3 2232s
#  1074680 711502  658.00470  143   72  657.00000  658.14782  0.17%  26.3 2238s
#  1075665 712041  658.09710   92  125  657.00000  658.14782  0.17%  26.3 2241s
#  1077107 713138  658.08840   79  142  657.00000  658.14782  0.17%  26.3 2247s
#  1078091 713792     cutoff   99       657.00000  658.14782  0.17%  26.3 2251s
#  1079785 714992  658.14587   72  168  657.00000  658.14782  0.17%  26.3 2257s
#  1080681 715413  658.14759   69  160  657.00000  658.14782  0.17%  26.3 2260s
#  1082227 716471  658.14427   79  159  657.00000  658.14781  0.17%  26.3 2267s
#  1082983 717206  658.12982   77  144  657.00000  658.14781  0.17%  26.3 2271s
#  1084932 718316  658.09471   80  130  657.00000  658.14781  0.17%  26.3 2277s
#  1085478 719195  658.14662   72  183  657.00000  658.14781  0.17%  26.3 2281s
#  1086686 719771  658.00893   92  113  657.00000  658.14781  0.17%  26.3 2285s
#  1087668 720630  658.00868   94  103  657.00000  658.14780  0.17%  26.3 2290s
#  1090076 721326  658.13884   76  177  657.00000  658.14780  0.17%  26.3 2301s
#  1090083 721996  658.12756   75  172  657.00000  658.14779  0.17%  26.3 2305s
#  1091952 723748  658.13717   79  171  657.00000  658.14779  0.17%  26.3 2314s
#  1093360 724657     cutoff  118       657.00000  658.14779  0.17%  26.3 2318s
#  1094563 725334  658.00085  123   78  657.00000  658.14779  0.17%  26.3 2322s
#  1095425 725986  658.00780   96  122  657.00000  658.14778  0.17%  26.3 2326s
#  1097332 727285  658.01801   85  130  657.00000  658.14778  0.17%  26.3 2333s
#  1098395 727796  658.09710   74  127  657.00000  658.14778  0.17%  26.3 2337s
#  1099180 728454  658.09474   75  150  657.00000  658.14778  0.17%  26.3 2341s
#  1100852 729229     cutoff   80       657.00000  658.14777  0.17%  26.3 2347s
#  1101930 730266  658.14741   71  192  657.00000  658.14777  0.17%  26.4 2353s
#  1102686 730960  658.09322   87  134  657.00000  658.14777  0.17%  26.4 2357s
#  1103602 731529  658.00414   92  141  657.00000  658.14777  0.17%  26.4 2361s
#  1105332 732556  658.09393   84  142  657.00000  658.14777  0.17%  26.4 2368s
#  1106125 732931  658.04252   86   98  657.00000  658.14777  0.17%  26.4 2371s
#  1106841 733668  658.14217   80  174  657.00000  658.14777  0.17%  26.4 2376s
#  1108723 734271  658.14777   77  173  657.00000  658.14777  0.17%  26.4 2380s
#  1109865 735572     cutoff   84       657.00000  658.14777  0.17%  26.4 2388s
#  1110792 736385  658.14343   78  173  657.00000  658.14777  0.17%  26.4 2392s
#  1112022 736838  658.00672  120  113  657.00000  658.14777  0.17%  26.5 2396s
#  1112717 737518  658.08427   78  144  657.00000  658.14777  0.17%  26.5 2400s
#  1114193 738246  658.09393   73  150  657.00000  658.14777  0.17%  26.5 2406s
#  1114792 738811  658.08475   90  132  657.00000  658.14777  0.17%  26.5 2410s
#  1116494 739839  658.14722   69  188  657.00000  658.14777  0.17%  26.5 2417s
#  1117279 740338  658.08427   83  141  657.00000  658.14777  0.17%  26.5 2421s
#  1118062 740929  658.14519   73  175  657.00000  658.14777  0.17%  26.5 2425s
#  1119056 741586  658.13161   71  150  657.00000  658.14777  0.17%  26.5 2430s
#  1121014 742908  658.07048   79  136  657.00000  658.14777  0.17%  26.6 2439s
#  1122004 743646  658.14628   71  175  657.00000  658.14777  0.17%  26.6 2443s
#  1123036 744492  658.09869   77  138  657.00000  658.14777  0.17%  26.6 2448s
#  1124308 745070     cutoff   84       657.00000  658.14777  0.17%  26.6 2453s
#  1125129 745528  658.08938   83  147  657.00000  658.14777  0.17%  26.6 2456s
#  1125799 746519  658.14513   66  178  657.00000  658.14777  0.17%  26.6 2461s
#  1127021 747185     cutoff   95       657.00000  658.14777  0.17%  26.6 2465s
#  1128876 748296  658.09869   78  139  657.00000  658.14777  0.17%  26.6 2471s
#  1130022 749054  658.08979   77  129  657.00000  658.14777  0.17%  26.6 2477s
#  1130591 749363  658.09411   74  123  657.00000  658.14777  0.17%  26.6 2480s
#  1131582 750105  658.08400   80  136  657.00000  658.14777  0.17%  26.6 2486s
#  1132123 750696  658.14433   67  162  657.00000  658.14777  0.17%  26.7 2490s
#  1133042 751277  658.08445   74  154  657.00000  658.14777  0.17%  26.7 2500s
#  1133917 752303  658.14093   67  152  657.00000  658.14777  0.17%  26.7 2506s
#  1135232 753145  658.14752   70  163  657.00000  658.14777  0.17%  26.7 2511s
#  1136295 754319  658.13819   69  143  657.00000  658.14777  0.17%  26.7 2517s
#  1137727 755040  658.13707   71  159  657.00000  658.14777  0.17%  26.7 2521s
#  1138610 755669  658.14777   68  155  657.00000  658.14777  0.17%  26.7 2525s
#  1140190 756953  658.04076  109   74  657.00000  658.14777  0.17%  26.7 2532s
#  1141088 757620  658.14777   67  144  657.00000  658.14777  0.17%  26.7 2536s
#  1141982 758262  658.00795   99   91  657.00000  658.14777  0.17%  26.7 2540s
#  1143689 759578  658.14634   74  171  657.00000  658.14777  0.17%  26.7 2548s
#  1144653 760126  658.00382   93   96  657.00000  658.14777  0.17%  26.7 2552s
#  1145562 760643  658.14601   74  158  657.00000  658.14777  0.17%  26.7 2555s
#  1147110 761825  658.00795   88   99  657.00000  658.14777  0.17%  26.7 2563s
#  1147989 762302  658.14777   68  159  657.00000  658.14777  0.17%  26.7 2566s
#  1148766 762841  658.14069   72  158  657.00000  658.14777  0.17%  26.7 2570s
#  1150106 764175  658.14125   73  153  657.00000  658.14777  0.17%  26.7 2579s
#  1151465 764531  658.03660  112  101  657.00000  658.14777  0.17%  26.7 2583s
#  1152064 765158  658.06105   88  138  657.00000  658.14777  0.17%  26.7 2588s
#  1153337 765834  658.13911   75  179  657.00000  658.14776  0.17%  26.7 2592s
#  1154352 766367  658.08505   78  131  657.00000  658.14776  0.17%  26.7 2596s
#  1155217 766912  658.09393   84  148  657.00000  658.14776  0.17%  26.7 2600s
#  1156773 767593  658.00795  109  122  657.00000  658.14775  0.17%  26.7 2605s
#  1157472 768539  658.08048  108  133  657.00000  658.14775  0.17%  26.7 2611s
#  1158390 769372  658.02200   83  141  657.00000  658.14775  0.17%  26.7 2616s
#  1159542 770164  658.09082   75  129  657.00000  658.14775  0.17%  26.7 2621s
#  1160694 770868  658.00401  105  101  657.00000  658.14775  0.17%  26.7 2626s
#  1161809 771598  658.08493   77  138  657.00000  658.14774  0.17%  26.7 2631s
#  1163651 772603  658.14741   66  181  657.00000  658.14774  0.17%  26.7 2637s
#  1164259 772912  658.10128   78  168  657.00000  658.14774  0.17%  26.7 2640s
#  1164707 773784  658.09710   86  139  657.00000  658.14774  0.17%  26.7 2646s
#  1165905 774295  658.12574   74  181  657.00000  658.14774  0.17%  26.7 2650s
#  1166684 774909  658.14773   66  171  657.00000  658.14773  0.17%  26.8 2655s
#  1167631 775732  658.13157   71  153  657.00000  658.14773  0.17%  26.8 2660s
#  1168912 776260  658.14454   70  183  657.00000  658.14773  0.17%  26.8 2665s
#  1169705 776341  658.14584   76  176  657.00000  658.14773  0.17%  26.8 2672s
#  1169841 777036  658.14363   77  172  657.00000  658.14773  0.17%  26.8 2677s
#  1170859 777872  658.09295   91  141  657.00000  658.14773  0.17%  26.8 2682s
#  1172042 778557  658.13055   79  160  657.00000  658.14773  0.17%  26.8 2687s
#  1173039 779248  658.08067   88  142  657.00000  658.14773  0.17%  26.8 2692s
#  1174072 780502  658.12334   70  141  657.00000  658.14773  0.17%  26.8 2699s
#  1175635 781511  658.00189  373   58  657.00000  658.14773  0.17%  26.8 2705s
#  1177684 782566  658.14564   69  172  657.00000  658.14773  0.17%  26.8 2714s
#  1178813 782868  658.08411   75  144  657.00000  658.14773  0.17%  26.8 2718s
#  1179347 783615  658.14773   66  166  657.00000  658.14773  0.17%  26.8 2723s
#  1180331 785113  658.12029   77  144  657.00000  658.14773  0.17%  26.8 2730s
#  1182396 785740  658.07882   90  137  657.00000  658.14773  0.17%  26.8 2735s
#  1183921 787251  658.14754   68  169  657.00000  658.14773  0.17%  26.8 2743s
#  1184930 788111  658.14450   74  163  657.00000  658.14773  0.17%  26.8 2748s
#  1185961 788782  658.14702   72  163  657.00000  658.14773  0.17%  26.8 2752s
#  1186747 789651  658.13963   78  169  657.00000  658.14773  0.17%  26.8 2757s
#  1187824 790362  658.01096   94  109  657.00000  658.14773  0.17%  26.8 2761s
#  1188759 790942  658.13816   78  149  657.00000  658.14773  0.17%  26.8 2766s
#  1190120 791920  658.08976   80  142  657.00000  658.14773  0.17%  26.8 2775s
#  1191194 792590  658.13741   70  177  657.00000  658.14773  0.17%  26.8 2780s
#  1192201 793766  658.00113  195   50  657.00000  658.14773  0.17%  26.8 2786s
#  1193649 794436  658.14525   74  169  657.00000  658.14773  0.17%  26.8 2790s
#  1195397 795271  658.00109   80  140  657.00000  658.14773  0.17%  26.8 2798s
#  1196052 795766  658.14400   72  172  657.00000  658.14773  0.17%  26.8 2801s
#  1196803 796204  658.09865   74  131  657.00000  658.14773  0.17%  26.8 2805s
#  1198266 797255  658.14533   75  171  657.00000  658.14773  0.17%  26.8 2813s
#  1199072 797992     cutoff   90       657.00000  658.14773  0.17%  26.8 2818s
#  1200151 798681  658.00761  101   89  657.00000  658.14773  0.17%  26.8 2823s
#  1201136 799187  658.14773   70  165  657.00000  658.14773  0.17%  26.9 2827s
#  1201927 800183  658.08411   89  130  657.00000  658.14773  0.17%  26.9 2833s
#  1203290 800540  658.08411   77  149  657.00000  658.14773  0.17%  26.9 2836s
#  1203801 801383  658.14680   69  181  657.00000  658.14773  0.17%  26.9 2842s
#  1204998 801917     cutoff   80       657.00000  658.14773  0.17%  26.9 2846s
#  1205796 802835  658.04236  139   69  657.00000  658.14773  0.17%  26.9 2852s
#  1207136 803684  658.14773   68  172  657.00000  658.14773  0.17%  26.9 2858s
#  1208341 804038  658.14007   73  171  657.00000  658.14773  0.17%  26.9 2862s
#  1208988 804534  658.14773   61  186  657.00000  658.14773  0.17%  26.9 2866s
#  1209781 805292  658.14696   72  164  657.00000  658.14773  0.17%  26.9 2871s
#  1210897 805983  658.11900   75  167  657.00000  658.14773  0.17%  26.9 2876s
#  1211891 806627     cutoff   72       657.00000  658.14773  0.17%  26.9 2881s
#  1212813 807253     cutoff   89       657.00000  658.14773  0.17%  26.9 2886s
#  1213806 807428  658.14158   79  165  657.00000  658.14773  0.17%  26.9 2893s
#  1214040 807811  658.13928   80  147  657.00000  658.14773  0.17%  26.9 2897s
#  1214714 808506     cutoff  103       657.00000  658.14773  0.17%  26.9 2902s
#  1215725 809155  658.14090   72  154  657.00000  658.14773  0.17%  26.9 2907s
#  1216715 809566  658.14317   69  184  657.00000  658.14773  0.17%  26.9 2911s
#  1217341 810257  658.05698   77  111  657.00000  658.14773  0.17%  26.9 2916s
#  1218369 810685  658.13424   78  151  657.00000  658.14773  0.17%  26.9 2920s
#  1219057 811432  658.04236  105   96  657.00000  658.14773  0.17%  26.9 2926s
#  1220118 812108  658.08411   85  130  657.00000  658.14773  0.17%  26.9 2932s
#  1221174 812668  658.13120   76  169  657.00000  658.14773  0.17%  26.9 2937s
#  1222083 813144  658.02066  106   91  657.00000  658.14773  0.17%  26.9 2943s
#  1222973 813332  658.14178   75  170  657.00000  658.14773  0.17%  26.9 2950s
#  1223315 814026  658.13823   76  170  657.00000  658.14773  0.17%  26.9 2957s
#  1224559 814868  657.99980  171   76  657.00000  658.14773  0.17%  26.9 2963s
#  1225806 815683  658.08534  107  121  657.00000  658.14773  0.17%  26.9 2970s
#  1227009 816488  658.00439  136   89  657.00000  658.14773  0.17%  26.9 2976s
#  1228224 817243  658.00606   77  160  657.00000  658.14773  0.17%  26.9 2983s
#  1229296 817728  658.14509   72  187  657.00000  658.14772  0.17%  26.9 2988s
#  1229984 818509  658.09869   70  116  657.00000  658.14772  0.17%  26.9 2994s
#  1231088 819012  658.14197   78  176  657.00000  658.14772  0.17%  26.9 2998s
#  1231937 819610  658.14245   77  165  657.00000  658.14772  0.17%  26.9 3004s
#  1232887 820312  658.08770   76  125  657.00000  658.14772  0.17%  26.9 3010s
#  1233931 821207  658.14386   82  167  657.00000  658.14772  0.17%  26.9 3016s
#  1235056 821912  658.12313   76  162  657.00000  658.14771  0.17%  26.9 3021s
#  1236063 822444  658.08445   85  126  657.00000  658.14771  0.17%  26.9 3026s
#  1236991 823066  658.09471   80  142  657.00000  658.14771  0.17%  26.9 3031s
#  1238019 823509  658.07799   83  127  657.00000  658.14771  0.17%  26.9 3036s
#  1238758 824209  658.14335   70  184  657.00000  658.14770  0.17%  26.9 3041s
#  1239852 825263  658.04252   96  119  657.00000  658.14770  0.17%  26.9 3048s
#  1241198 825644  658.11529   80  155  657.00000  658.14770  0.17%  26.9 3052s
#  1241891 826190  658.13189   77  141  657.00000  658.14770  0.17%  26.9 3056s
#  1242633 826741  658.00795   97   92  657.00000  658.14770  0.17%  26.9 3061s
#  1243476 827683  658.14595   77  178  657.00000  658.14769  0.17%  26.9 3068s
#  1244808 828290  658.02271  128   74  657.00000  658.14769  0.17%  26.9 3073s
#  1245763 828477  658.14628   68  175  657.00000  658.14769  0.17%  26.9 3075s
#  1246715 829529  658.14628   69  187  657.00000  658.14769  0.17%  26.9 3084s
#  1247597 830194  658.00848   95  109  657.00000  658.14769  0.17%  26.9 3090s
#  1248658 830657  658.13074   81  152  657.00000  658.14769  0.17%  26.9 3095s
#  1249462 831057  658.09287   82  141  657.00000  658.14768  0.17%  26.9 3100s
#  1250178 831841     cutoff  105       657.00000  658.14768  0.17%  26.9 3106s
#  1251181 832458  658.14768   66  169  657.00000  658.14768  0.17%  26.9 3111s
#  1251987 832515  658.00470  152   66  657.00000  658.14768  0.17%  26.9 3120s
#  1252074 833133  658.00470  153   66  657.00000  658.14768  0.17%  26.9 3125s
#  1252937 833780  658.14768   67  165  657.00000  658.14768  0.17%  26.9 3130s
#  1253819 834238  658.08538   81  145  657.00000  658.14768  0.17%  26.9 3135s
#  1255062 835093  658.14486   70  175  657.00000  658.14768  0.17%  26.9 3144s
#  1255893 835864  658.08799   87  122  657.00000  658.14768  0.17%  27.0 3151s
#  1257055 836456     cutoff   68       657.00000  658.14768  0.17%  27.0 3158s
#  1258036 837020  658.08493   77  143  657.00000  658.14768  0.17%  27.0 3164s
#  1258920 838184  658.08366   82  141  657.00000  658.14768  0.17%  27.0 3173s
#  1260611 839316  658.05252   95  142  657.00000  658.14768  0.17%  27.0 3181s
#  1262123 839717  658.14087   78  217  657.00000  658.14767  0.17%  27.0 3185s
#  1262745 840397  658.13492   76  161  657.00000  658.14767  0.17%  27.0 3191s
#  1263916 841197  658.09751   73  119  657.00000  658.14767  0.17%  27.0 3197s
#  1265044 841908  658.00000  234   70  657.00000  658.14767  0.17%  27.0 3203s
#  1266092 842530  658.02620   97  131  657.00000  658.14767  0.17%  27.0 3208s
#  1267076 843289  658.12448   78  136  657.00000  658.14766  0.17%  27.0 3214s
#  1268146 843642  658.14502   71  179  657.00000  658.14766  0.17%  27.0 3218s
#  1268668 844139  658.00203   87  112  657.00000  658.14766  0.17%  27.0 3222s
#  1269457 844843  658.00761  142  105  657.00000  658.14766  0.17%  27.0 3227s
#  1270391 845322  658.13328   79  137  657.00000  658.14766  0.17%  27.0 3232s
#  1271200 845822  658.14740   73  172  657.00000  658.14766  0.17%  27.0 3236s
#  1271912 846249  658.14766   69  152  657.00000  658.14766  0.17%  27.0 3240s
#  1273152 846915  658.06280   82  131  657.00000  658.14766  0.17%  27.0 3247s
#  1273589 847361  658.13622   74  167  657.00000  658.14766  0.17%  27.0 3251s
#  1274328 848102     cutoff   88       657.00000  658.14766  0.17%  27.0 3257s
#  1275343 848738  658.07813   95  115  657.00000  658.14766  0.17%  27.0 3262s
#  1276232 849350  658.14735   71  178  657.00000  658.14766  0.17%  27.0 3267s
#  1277076 849816  657.99985  202   84  657.00000  658.14766  0.17%  27.0 3272s
#  1277889 850303  658.08474   82  157  657.00000  658.14766  0.17%  27.0 3277s
#  1278665 850917  658.08518   76  140  657.00000  658.14766  0.17%  27.0 3282s
#  1279504 851446  658.01481   86  101  657.00000  658.14766  0.17%  27.0 3288s
#  1280295 851845  658.14283   74  173  657.00000  658.14766  0.17%  27.0 3292s
#  1280910 852641  658.00588   89  110  657.00000  658.14766  0.17%  27.0 3298s
#  1282108 853161  657.99970   77  121  657.00000  658.14766  0.17%  27.0 3303s
#  1282881 854054  658.14632   74  171  657.00000  658.14766  0.17%  27.0 3309s
#  1284073 855228  658.03945  128   59  657.00000  658.14766  0.17%  27.0 3316s
#  1285622 856077  658.00119  167   70  657.00000  658.14766  0.17%  27.0 3322s
#  1286765 856459  658.08437   88  156  657.00000  658.14765  0.17%  27.0 3327s
#  1287442 857010  658.10362   71  173  657.00000  658.14765  0.17%  27.0 3332s
#  1288294 857566  658.08791   83  125  657.00000  658.14765  0.17%  27.0 3337s
#  1289224 857876  658.13621   73  151  657.00000  658.14765  0.17%  27.0 3340s
#  1290159 858612  658.05877   87  144  657.00000  658.14765  0.17%  27.0 3347s
#  1290839 858945  658.07799   89  109  657.00000  658.14765  0.17%  27.0 3351s
#  1291445 859660  658.08292   80  129  657.00000  658.14765  0.17%  27.0 3356s
#  1292445 860293  658.14691   69  174  657.00000  658.14765  0.17%  27.0 3361s
#  1293274 861091     cutoff  110       657.00000  658.14765  0.17%  27.0 3373s
#  1294253 861819 infeasible   99       657.00000  658.14765  0.17%  27.0 3380s
#  1295382 862366  658.13252   79  151  657.00000  658.14765  0.17%  27.0 3385s
#  1296184 862992  658.00629   99  123  657.00000  658.14765  0.17%  27.0 3391s
#  1297109 863498  658.08505   74  112  657.00000  658.14765  0.17%  27.0 3397s
#  1297835 864228  658.14675   78  175  657.00000  658.14765  0.17%  27.1 3403s
#  1298850 864817     cutoff   75       657.00000  658.14765  0.17%  27.1 3410s
#  1299754 865514  658.09471   77  140  657.00000  658.14765  0.17%  27.1 3417s
#  1300724 866244  658.14686   67  174  657.00000  658.14765  0.17%  27.1 3423s
#  1301873 867083  658.08505   74  107  657.00000  658.14765  0.17%  27.1 3430s
#  1302978 868049  658.03020  167   62  657.00000  658.14765  0.17%  27.1 3437s
#  1304252 868715  658.08967   80  141  657.00000  658.14765  0.17%  27.1 3444s
#  1305315 869296  658.00078   90  136  657.00000  658.14765  0.17%  27.1 3450s
#  1306339 869468     cutoff   80       657.00000  658.14764  0.17%  27.1 3456s
#  1306620 871036  658.08493   84  135  657.00000  658.14764  0.17%  27.1 3471s
#  1308918 871770  658.14553   69  167  657.00000  658.14764  0.17%  27.1 3478s
#  1309921 872351  658.14764   65  172  657.00000  658.14764  0.17%  27.1 3483s
#  1310707 872934  658.07797   76  150  657.00000  658.14764  0.17%  27.1 3489s
#  1311586 873496  658.12708   66  137  657.00000  658.14764  0.17%  27.1 3495s
#  1312379 874344  658.00579  127  109  657.00000  658.14764  0.17%  27.1 3503s
#  1313599 874939  658.14664   75  164  657.00000  658.14764  0.17%  27.1 3510s
#  1314548 875771  658.14623   70  175  657.00000  658.14764  0.17%  27.1 3518s
#  1315800 876755  658.01003   87  126  657.00000  658.14764  0.17%  27.1 3525s
#  1317204 877489  658.08445   78  136  657.00000  658.14764  0.17%  27.1 3533s
#  1318269 878195  658.11653   75  142  657.00000  658.14764  0.17%  27.2 3539s
#  1319234 878277  658.01469   87  125  657.00000  658.14764  0.17%  27.2 3544s
#  1319378 882156  658.02456   87  158  657.00000  658.14764  0.17%  27.2 3573s
#  1324670 882781  658.14236   72  170  657.00000  658.14764  0.17%  27.2 3580s
#  1325535 883587  658.03690   88  119  657.00000  658.14764  0.17%  27.2 3587s
#  1326629 884352  658.13987   70  149  657.00000  658.14764  0.17%  27.2 3593s
#  1327704 885113  658.10107   77  104  657.00000  658.14764  0.17%  27.2 3600s
#
# Cutting planes:
#   Gomory: 100
#   Cover: 3655
#   Implied bound: 20
#   Clique: 2
#   MIR: 507
#   StrongCG: 54
#   Flow cover: 726
#   Inf proof: 50
#   Zero half: 3
#   RLT: 26
#   Relax-and-lift: 12
#
# Explored 1328824 nodes (36139105 simplex iterations) in 3600.54 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 657 656 655 ... 630
#
# Time limit reached
# Best objective 6.570000000000e+02, best bound 6.580000000000e+02, gap 0.1522%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x4.5x5

# %%
datafile="4x1000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x17f88a9f
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 616.0000000
# Presolve removed 46 rows and 40 columns (presolve time = 5s) ...
# Sparsify removed 1869066 nonzeros (95%)
# Presolve added 0 rows and 282 columns
# Presolve removed 54 rows and 0 columns
# Presolve time: 6.35s
# Presolved: 4946 rows, 4282 columns, 97114 nonzeros
# Variable types: 322 continuous, 3960 integer (3960 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9000000e+02   2.492458e+04   0.000000e+00      6s
#     3220    6.4535313e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.453531e+02, 3220 iterations, 0.20 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  645.35313    0  104  616.00000  645.35313  4.77%     -    6s
# H    0     0                     640.0000000  645.35313  0.84%     -    6s
# H    0     0                     643.0000000  645.35313  0.37%     -    6s
#      0     0  645.32119    0   99  643.00000  645.32119  0.36%     -    7s
# H    0     0                     644.0000000  645.32119  0.21%     -    7s
#      0     0  645.30411    0   98  644.00000  645.30411  0.20%     -    7s
#      0     0  645.29481    0  117  644.00000  645.29481  0.20%     -    7s
#      0     0  645.17549    0  107  644.00000  645.17549  0.18%     -    7s
#      0     0  645.17525    0  105  644.00000  645.17525  0.18%     -    7s
#      0     0  645.17525    0  105  644.00000  645.17525  0.18%     -    7s
#      0     0  645.13920    0   82  644.00000  645.13920  0.18%     -    8s
#      0     0  645.13920    0   83  644.00000  645.13920  0.18%     -    8s
#      0     0  645.12363    0   78  644.00000  645.12363  0.17%     -    8s
#      0     0  645.12363    0  113  644.00000  645.12363  0.17%     -    9s
#      0     0  645.12363    0  118  644.00000  645.12363  0.17%     -    9s
#      0     0  645.11866    0   93  644.00000  645.11866  0.17%     -    9s
#      0     0  645.11564    0   93  644.00000  645.11564  0.17%     -    9s
#      0     0  645.11564    0   93  644.00000  645.11564  0.17%     -    9s
#      0     0  645.02561    0   77  644.00000  645.02561  0.16%     -    9s
#      0     0     cutoff    0       644.00000  644.00000  0.00%     -   10s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 3
#   Implied bound: 1
#   MIR: 51
#   StrongCG: 2
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (13543 simplex iterations) in 10.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 644 643 640 616
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.440000000000e+02, best bound 6.440000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x5x1

# %%
datafile="4x1000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x67c18dbe
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 588.0000000
# Presolve removed 73 rows and 52 columns (presolve time = 5s) ...
# Sparsify removed 1878213 nonzeros (96%)
# Presolve added 0 rows and 277 columns
# Presolve removed 77 rows and 0 columns
# Presolve time: 6.33s
# Presolved: 4923 rows, 4277 columns, 76015 nonzeros
# Variable types: 329 continuous, 3948 integer (3948 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8700000e+02   1.811943e+04   0.000000e+00      6s
#     5358    6.1928396e+02   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.192840e+02, 5358 iterations, 0.25 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  619.28396    0  181  588.00000  619.28396  5.32%     -    6s
# H    0     0                     613.0000000  619.28396  1.03%     -    6s
# H    0     0                     615.0000000  619.28396  0.70%     -    6s
# H    0     0                     616.0000000  619.28396  0.53%     -    6s
#      0     0  619.26307    0  177  616.00000  619.26307  0.53%     -    7s
# H    0     0                     617.0000000  619.26307  0.37%     -    7s
#      0     0  619.21287    0  159  617.00000  619.21287  0.36%     -    7s
#      0     0  619.18474    0  161  617.00000  619.18474  0.35%     -    7s
#      0     0  618.92527    0  141  617.00000  618.92527  0.31%     -    7s
#      0     0  618.92518    0  139  617.00000  618.92518  0.31%     -    7s
# H    0     0                     618.0000000  618.92518  0.15%     -    7s
#
# Cutting planes:
#   Gomory: 31
#   Implied bound: 1
#   MIR: 234
#   RLT: 3
#
# Explored 1 nodes (7697 simplex iterations) in 8.00 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 618 617 616 ... 588
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.180000000000e+02, best bound 6.180000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x5x2

# %%
datafile="4x1000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x4c16e901
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 578.0000000
# Presolve removed 48 rows and 32 columns (presolve time = 5s) ...
# Sparsify removed 1858266 nonzeros (94%)
# Presolve added 0 rows and 278 columns
# Presolve removed 48 rows and 0 columns
# Presolve time: 5.32s
# Presolved: 4952 rows, 4278 columns, 115802 nonzeros
# Variable types: 310 continuous, 3968 integer (3968 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9200000e+02   3.282344e+04   0.000000e+00      5s
#     3227    6.0920662e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.092066e+02, 3227 iterations, 0.25 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  609.20662    0  106  578.00000  609.20662  5.40%     -    5s
# H    0     0                     605.0000000  609.20662  0.70%     -    5s
# H    0     0                     606.0000000  609.20662  0.53%     -    6s
#      0     0  609.17998    0  107  606.00000  609.17998  0.52%     -    6s
# H    0     0                     607.0000000  609.17998  0.36%     -    6s
#      0     0  609.05225    0  111  607.00000  609.05225  0.34%     -    6s
#      0     0  608.95422    0   85  607.00000  608.95422  0.32%     -    7s
#      0     0  608.87854    0   66  607.00000  608.87854  0.31%     -    7s
#      0     0  608.76380    0   70  607.00000  608.76380  0.29%     -    7s
#      0     0  608.75618    0   65  607.00000  608.75618  0.29%     -    7s
#      0     0  608.75618    0   68  607.00000  608.75618  0.29%     -    7s
#      0     0  608.39848    0   56  607.00000  608.39848  0.23%     -    7s
#      0     0  608.38905    0   48  607.00000  608.38905  0.23%     -    7s
#      0     0  608.38905    0   46  607.00000  608.38905  0.23%     -    7s
#      0     0  608.32729    0   45  607.00000  608.32729  0.22%     -    7s
#      0     0  608.32729    0   46  607.00000  608.32729  0.22%     -    8s
#      0     0  608.29809    0   53  607.00000  608.29809  0.21%     -    8s
#      0     0  608.29598    0   56  607.00000  608.29598  0.21%     -    8s
#      0     0  608.29440    0   51  607.00000  608.29440  0.21%     -    8s
#      0     0  608.29440    0   49  607.00000  608.29440  0.21%     -    8s
#      0     0  608.22979    0   52  607.00000  608.22979  0.20%     -    8s
#      0     0  608.22979    0   51  607.00000  608.22979  0.20%     -    8s
#      0     0  608.20847    0   43  607.00000  608.20847  0.20%     -    8s
#      0     0  608.20847    0   53  607.00000  608.20847  0.20%     -    8s
#      0     0  608.20748    0   44  607.00000  608.20748  0.20%     -    9s
#      0     0  608.20748    0   94  607.00000  608.20748  0.20%     -    9s
#      0     0  608.20748    0   53  607.00000  608.20748  0.20%     -    9s
#      0     0  608.20729    0   50  607.00000  608.20729  0.20%     -   10s
#      0     0  608.20729    0   51  607.00000  608.20729  0.20%     -   10s
#      0     0  608.20729    0   51  607.00000  608.20729  0.20%     -   10s
#      0     0  608.20717    0   53  607.00000  608.20717  0.20%     -   10s
#      0     0  608.20717    0   55  607.00000  608.20717  0.20%     -   10s
#      0     0  608.20717    0   53  607.00000  608.20717  0.20%     -   10s
#      0     0  608.20717    0   48  607.00000  608.20717  0.20%     -   10s
#      0     0  608.20614    0   52  607.00000  608.20614  0.20%     -   10s
#      0     0  608.20614    0   50  607.00000  608.20614  0.20%     -   10s
#      0     0  608.20614    0   52  607.00000  608.20614  0.20%     -   10s
#      0     0  608.20614    0   39  607.00000  608.20614  0.20%     -   10s
#      0     2  608.20614    0   34  607.00000  608.20614  0.20%     -   11s
#   1287  1100  608.05565    9   34  607.00000  608.13760  0.19%   5.3   15s
#   1318  1122  608.01489   97   44  607.00000  608.08380  0.18%  10.3   20s
#   2027  1424  608.00000   86   24  607.00000  608.07996  0.18%  16.6   25s
# H 3017   871                     608.0000000  608.07996  0.01%  15.5   27s
#
# Cutting planes:
#   Gomory: 13
#   MIR: 25
#   Flow cover: 38
#
# Explored 3020 nodes (59434 simplex iterations) in 27.21 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 608 607 606 ... 578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.080000000000e+02, best bound 6.080000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x5x3

# %%
datafile="4x1000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x2292cc05
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 576.0000000
# Presolve removed 26 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1871997 nonzeros (94%)
# Presolve added 0 rows and 287 columns
# Presolve removed 26 rows and 0 columns
# Presolve time: 5.43s
# Presolved: 4974 rows, 4287 columns, 110107 nonzeros
# Variable types: 311 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   3.028269e+04   0.000000e+00      6s
#     3258    6.1164514e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.116451e+02, 3258 iterations, 0.23 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  611.64514    0  130  576.00000  611.64514  6.19%     -    6s
# H    0     0                     607.0000000  611.64514  0.77%     -    6s
# H    0     0                     608.0000000  611.64514  0.60%     -    6s
# H    0     0                     609.0000000  611.64514  0.43%     -    6s
#      0     0  611.57442    0  150  609.00000  611.57442  0.42%     -    6s
#      0     0  611.46121    0  136  609.00000  611.46121  0.40%     -    6s
#      0     0  611.33263    0  107  609.00000  611.33263  0.38%     -    6s
#      0     0  611.23855    0   97  609.00000  611.23855  0.37%     -    7s
#      0     0  611.15959    0   97  609.00000  611.15959  0.35%     -    7s
#      0     0  611.12347    0   98  609.00000  611.12347  0.35%     -    7s
#      0     0  611.08615    0   87  609.00000  611.08615  0.34%     -    7s
#      0     0  611.08609    0   90  609.00000  611.08609  0.34%     -    7s
# H    0     0                     610.0000000  611.08609  0.18%     -    7s
#      0     0     cutoff    0       610.00000  610.00000  0.00%     -    7s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 5
#   Implied bound: 3
#   MIR: 139
#   StrongCG: 9
#   GUB cover: 5
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (6235 simplex iterations) in 7.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 610 609 608 ... 576
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.100000000000e+02, best bound 6.100000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x5x4

# %%
datafile="4x1000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0xfbf822cc
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 573.0000000
# Presolve removed 50 rows and 40 columns (presolve time = 5s) ...
# Sparsify removed 1863884 nonzeros (95%)
# Presolve added 0 rows and 276 columns
# Presolve removed 58 rows and 0 columns
# Presolve time: 5.36s
# Presolved: 4942 rows, 4276 columns, 102240 nonzeros
# Variable types: 316 continuous, 3960 integer (3960 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9000000e+02   2.756401e+04   0.000000e+00      5s
#     3202    6.0387698e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.038770e+02, 3202 iterations, 0.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  603.87698    0   73  573.00000  603.87698  5.39%     -    5s
# H    0     0                     600.0000000  603.87698  0.65%     -    5s
# H    0     0                     601.0000000  603.87698  0.48%     -    5s
# H    0     0                     602.0000000  603.87698  0.31%     -    6s
#      0     0  603.86909    0   88  602.00000  603.86909  0.31%     -    6s
#      0     0  603.81238    0   90  602.00000  603.81238  0.30%     -    6s
#      0     0  603.79416    0   66  602.00000  603.79416  0.30%     -    7s
#      0     0  603.76938    0   67  602.00000  603.76938  0.29%     -    7s
#      0     0  603.76938    0   69  602.00000  603.76938  0.29%     -    7s
#      0     0  603.76938    0   55  602.00000  603.76938  0.29%     -    7s
#      0     0  603.76924    0   62  602.00000  603.76924  0.29%     -    7s
#      0     0  603.76901    0   69  602.00000  603.76901  0.29%     -    7s
#      0     0  603.76901    0   70  602.00000  603.76901  0.29%     -    8s
#      0     0  603.76901    0   70  602.00000  603.76901  0.29%     -    8s
#      0     0  603.76901    0   70  602.00000  603.76901  0.29%     -    8s
#      0     0  603.76901    0   62  602.00000  603.76901  0.29%     -    8s
#      0     0  603.76855    0   72  602.00000  603.76855  0.29%     -    9s
# H    0     0                     603.0000000  603.76855  0.13%     -    9s
#      0     0  603.76855    0   72  603.00000  603.76855  0.13%     -    9s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 11
#   MIR: 53
#   StrongCG: 2
#   GUB cover: 4
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (7826 simplex iterations) in 9.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 603 602 601 ... 573
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.030000000000e+02, best bound 6.030000000000e+02, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x1000x5x5

# %%
datafile="4x1000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 1000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 5000 rows, 4000 columns and 2006000 nonzeros
# Model fingerprint: 0x40f827d2
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 583.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Sparsify removed 1869174 nonzeros (94%)
# Presolve added 0 rows and 286 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 5.27s
# Presolved: 4962 rows, 4286 columns, 112850 nonzeros
# Variable types: 310 continuous, 3976 integer (3976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9400000e+02   2.932008e+04   0.000000e+00      5s
#     3349    6.1527928e+02   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 6.152793e+02, 3349 iterations, 0.22 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  615.27928    0  151  583.00000  615.27928  5.54%     -    5s
# H    0     0                     610.0000000  615.27928  0.87%     -    5s
# H    0     0                     611.0000000  615.27928  0.70%     -    5s
# H    0     0                     612.0000000  615.27928  0.54%     -    5s
# H    0     0                     613.0000000  615.27928  0.37%     -    6s
#      0     0  615.27612    0  142  613.00000  615.27612  0.37%     -    6s
#      0     0  615.12428    0  135  613.00000  615.12428  0.35%     -    6s
#      0     0  615.12278    0  134  613.00000  615.12278  0.35%     -    6s
#      0     0  614.94627    0  121  613.00000  614.94627  0.32%     -    6s
# H    0     0                     614.0000000  614.94627  0.15%     -    7s
#      0     0  614.94421    0  126  614.00000  614.94421  0.15%     -    7s
#
# Cutting planes:
#   Gomory: 38
#   Implied bound: 1
#   MIR: 104
#   StrongCG: 2
#
# Explored 1 nodes (7829 simplex iterations) in 7.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 614 613 612 ... 583
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.140000000000e+02, best bound 6.140000000000e+02, gap 0.0000%

# %% [markdown]
# # Modelo de programación lineal Süer et. al.

# %%
import pandas as pd

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x1.5x1

# %%
datafile="2x2000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-06-11
# Using license file C:\Users\elPatan03\gurobi.lic
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xeb20b13a
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2000.0000000
# Presolve removed 24 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 10s) ...
# Sparsify removed 1440596 nonzeros (36%)
# Presolve added 0 rows and 80 columns
# Presolve removed 166 rows and 0 columns
# Presolve time: 12.23s
# Presolved: 5834 rows, 4080 columns, 2564394 nonzeros
# Variable types: 76 continuous, 4004 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   5.571725e+05   0.000000e+00     13s
#
# Root relaxation: cutoff, 0 iterations, 0.16 seconds
#
# Explored 0 nodes (0 simplex iterations) in 13.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+03, best bound 2.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x1.5x2

# %%
datafile="2x2000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xfc2e3322
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 21 rows and 2 columns (presolve time = 6s) ...
# Presolve removed 21 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1392098 nonzeros (35%)
# Presolve added 0 rows and 74 columns
# Presolve removed 207 rows and 0 columns
# Presolve time: 12.22s
# Presolved: 5793 rows, 4074 columns, 2608588 nonzeros
# Variable types: 76 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   5.742599e+05   0.000000e+00     13s
#      546    1.9987099e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.998710e+03, 546 iterations, 0.49 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1998.70992    0   11 1997.00000 1998.70992  0.09%     -   14s
# H    0     0                    1998.0000000 1998.70992  0.04%     -   14s
#      0     0 1998.70992    0   11 1998.00000 1998.70992  0.04%     -   14s
#
# Explored 1 nodes (634 simplex iterations) in 14.71 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1998 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x1.5x3

# %%
datafile="2x2000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xcf266667
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1995.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1368684 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 151 rows and 0 columns
# Presolve time: 12.09s
# Presolved: 5849 rows, 4070 columns, 2624588 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   5.877829e+05   0.000000e+00     13s
#      541    1.9961903e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.996190e+03, 541 iterations, 0.50 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1996.00000    0    8 1995.00000 1996.00000  0.05%     -   14s
#      0     0 1996.00000    0    8 1995.00000 1996.00000  0.05%     -   15s
#      0     0 1996.00000    0   10 1995.00000 1996.00000  0.05%     -   18s
#      0     0 1996.00000    0   10 1995.00000 1996.00000  0.05%     -   18s
#      0     0 1996.00000    0    8 1995.00000 1996.00000  0.05%     -   20s
#      0     0 1996.00000    0    6 1995.00000 1996.00000  0.05%     -   22s
#      0     0 1996.00000    0   10 1995.00000 1996.00000  0.05%     -   23s
#      0     0 1996.00000    0   10 1995.00000 1996.00000  0.05%     -   25s
#      0     0 1996.00000    0    4 1995.00000 1996.00000  0.05%     -   25s
#      0     0 1996.00000    0    4 1995.00000 1996.00000  0.05%     -   27s
#      0     0 1996.00000    0   16 1995.00000 1996.00000  0.05%     -   27s
#      0     0 1996.00000    0   14 1995.00000 1996.00000  0.05%     -   29s
#      0     0 1996.00000    0   14 1995.00000 1996.00000  0.05%     -   30s
#      0     2 1996.00000    0   14 1995.00000 1996.00000  0.05%     -   32s
#      2     3 1996.00000    1   14 1995.00000 1996.00000  0.05%   0.5   53s
#
# Explored 3 nodes (2986 simplex iterations) in 56.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.995000000000e+03, best bound 1.995000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x1.5x4

# %%
datafile="2x2000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x7a0b5334
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 25 rows and 6 columns (presolve time = 5s) ...
# Sparsify removed 1378302 nonzeros (35%)
# Presolve removed 113 rows and 3906 columns (presolve time = 10s) ...
# Presolve added 0 rows and 70 columns
# Presolve removed 113 rows and 0 columns
# Presolve time: 10.29s
# Presolved: 5887 rows, 4070 columns, 2615220 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   5.694177e+05   0.000000e+00     11s
#
# Root relaxation: cutoff, 0 iterations, 0.16 seconds
#
# Explored 0 nodes (0 simplex iterations) in 11.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.997000000000e+03, best bound 1.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x1.5x5

# %%
datafile="2x2000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x6a81dbd6
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1999.0000000
# Presolve removed 37 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 37 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1421307 nonzeros (36%)
# Presolve added 0 rows and 75 columns
# Presolve removed 129 rows and 0 columns
# Presolve time: 10.44s
# Presolved: 5871 rows, 4075 columns, 2579869 nonzeros
# Variable types: 77 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   5.709803e+05   0.000000e+00     11s
#
# Root relaxation: cutoff, 0 iterations, 0.16 seconds
#
# Explored 0 nodes (0 simplex iterations) in 11.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.999000000000e+03, best bound 1.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2x1

# %%
datafile="2x2000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xc81d44df
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1962.0000000
# Presolve removed 15 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1368684 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 71 rows and 0 columns
# Presolve time: 12.24s
# Presolved: 5929 rows, 4070 columns, 2625044 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   8.244954e+05   0.000000e+00     13s
#      774    1.9676006e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.967601e+03, 774 iterations, 0.52 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1967.60061    0   44 1962.00000 1967.60061  0.29%     -   14s
# H    0     0                    1966.0000000 1967.60061  0.08%     -   14s
#      0     0 1967.56174    0   48 1966.00000 1967.56174  0.08%     -   16s
# H    0     0                    1967.0000000 1967.56174  0.03%     -   17s
#      0     0 1967.56174    0   48 1967.00000 1967.56174  0.03%     -   17s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   MIR: 10
#   GUB cover: 1
#
# Explored 1 nodes (1085 simplex iterations) in 17.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1967 1966 1962
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.967000000000e+03, best bound 1.967000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2x2

# %%
datafile="2x2000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xcec997ea
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1974.0000000
# Presolve removed 9 rows and 2 columns (presolve time = 5s) ...
# Sparsify removed 1354025 nonzeros (34%)
# Presolve removed 61 rows and 3907 columns (presolve time = 10s) ...
# Presolve added 0 rows and 73 columns
# Presolve removed 61 rows and 0 columns
# Presolve time: 10.35s
# Presolved: 5939 rows, 4073 columns, 2647657 nonzeros
# Variable types: 75 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   8.003727e+05   0.000000e+00     11s
#      640    1.9793823e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.979382e+03, 640 iterations, 0.45 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1979.38228    0   40 1974.00000 1979.38228  0.27%     -   13s
# H    0     0                    1976.0000000 1979.38228  0.17%     -   13s
# H    0     0                    1977.0000000 1979.38228  0.12%     -   13s
#      0     0 1979.29187    0   51 1977.00000 1979.29187  0.12%     -   15s
# H    0     0                    1978.0000000 1979.29187  0.07%     -   15s
# H    0     0                    1979.0000000 1979.29187  0.01%     -   15s
#      0     0 1979.29187    0   51 1979.00000 1979.29187  0.01%     -   15s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 4
#   Implied bound: 1
#   MIR: 21
#   RLT: 1
#
# Explored 1 nodes (882 simplex iterations) in 15.90 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1979 1978 1977 ... 1974
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.979000000000e+03, best bound 1.979000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2x3

# %%
datafile="2x2000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x8e7ec9e4
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1976.0000000
# Presolve removed 21 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 21 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1383036 nonzeros (35%)
# Presolve added 0 rows and 74 columns
# Presolve removed 67 rows and 0 columns
# Presolve time: 10.46s
# Presolved: 5933 rows, 4074 columns, 2618710 nonzeros
# Variable types: 76 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   8.550951e+05   0.000000e+00     11s
#      645    1.9813891e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.981389e+03, 645 iterations, 0.46 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1981.38911    0   20 1976.00000 1981.38911  0.27%     -   12s
# H    0     0                    1980.0000000 1981.38911  0.07%     -   13s
#      0     0     cutoff    0      1980.00000 1980.00000  0.00%     -   14s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 7
#   RLT: 2
#
# Explored 1 nodes (724 simplex iterations) in 14.81 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1980 1976
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.980000000000e+03, best bound 1.980000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2x4

# %%
datafile="2x2000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x25469e4a
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1951.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 6s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1354025 nonzeros (34%)
# Presolve added 0 rows and 73 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 12.09s
# Presolved: 5965 rows, 4073 columns, 2647853 nonzeros
# Variable types: 75 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   8.593922e+05   0.000000e+00     13s
#      755    1.9593607e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.959361e+03, 755 iterations, 0.51 seconds
# Total elapsed time = 15.18s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1959.36073    0   46 1951.00000 1959.36073  0.43%     -   15s
# H    0     0                    1957.0000000 1959.36073  0.12%     -   15s
#      0     0 1959.35769    0   50 1957.00000 1959.35769  0.12%     -   17s
# H    0     0                    1959.0000000 1959.35769  0.02%     -   18s
#      0     0 1959.35769    0   50 1959.00000 1959.35769  0.02%     -   18s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   MIR: 8
#
# Explored 1 nodes (1287 simplex iterations) in 18.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1959 1957 1951
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.959000000000e+03, best bound 1.959000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2x5

# %%
datafile="2x2000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xf9433719
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 1981.0000000
# Presolve removed 8 rows and 0 columns (presolve time = 5s) ...
# Sparsify removed 1380600 nonzeros (34%)
# Presolve removed 44 rows and 3906 columns (presolve time = 10s) ...
# Presolve added 0 rows and 76 columns
# Presolve removed 44 rows and 0 columns
# Presolve time: 10.29s
# Presolved: 5956 rows, 4076 columns, 2625266 nonzeros
# Variable types: 76 continuous, 4000 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   8.635044e+05   0.000000e+00     11s
#      620    1.9852630e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.985263e+03, 620 iterations, 0.47 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1985.26300    0   58 1981.00000 1985.26300  0.22%     -   13s
# H    0     0                    1982.0000000 1985.26300  0.16%     -   13s
# H    0     0                    1984.0000000 1985.26300  0.06%     -   13s
#      0     0 1985.23010    0   53 1984.00000 1985.23010  0.06%     -   15s
#      0     0 1985.19460    0   49 1984.00000 1985.19460  0.06%     -   16s
#      0     0 1985.18911    0   50 1984.00000 1985.18911  0.06%     -   18s
#      0     0 1985.09700    0   32 1984.00000 1985.09700  0.06%     -   19s
#      0     0 1985.09700    0   32 1984.00000 1985.09700  0.06%     -   20s
#      0     0 1985.04601    0   40 1984.00000 1985.04601  0.05%     -   21s
# H    0     0                    1985.0000000 1985.04601  0.00%     -   22s
#      0     0 1985.04601    0   40 1985.00000 1985.04601  0.00%     -   22s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 15
#
# Explored 1 nodes (892 simplex iterations) in 22.65 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1985 1984 1982 1981
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.985000000000e+03, best bound 1.985000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2.5x1

# %%
datafile="2x2000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x411095ba
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1725.0000000
# Presolve removed 10 rows and 0 columns (presolve time = 5s) ...
# Sparsify removed 1354775 nonzeros (34%)
# Presolve removed 44 rows and 3907 columns (presolve time = 10s) ...
# Presolve added 0 rows and 75 columns
# Presolve removed 44 rows and 0 columns
# Presolve time: 10.23s
# Presolved: 5956 rows, 4075 columns, 2651093 nonzeros
# Variable types: 75 continuous, 4000 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   1.038132e+06   0.000000e+00     11s
#     1350    1.7765936e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.776594e+03, 1350 iterations, 0.81 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1776.59359    0   67 1725.00000 1776.59359  2.99%     -   13s
# H    0     0                    1775.0000000 1776.59359  0.09%     -   13s
#      0     0 1776.57577    0   52 1775.00000 1776.57577  0.09%     -   15s
# H    0     0                    1776.0000000 1776.57577  0.03%     -   16s
#      0     0 1776.57577    0   52 1776.00000 1776.57577  0.03%     -   16s
#
# Cutting planes:
#   Gomory: 13
#   MIR: 7
#   StrongCG: 1
#
# Explored 1 nodes (1521 simplex iterations) in 16.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1776 1775 1725
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.776000000000e+03, best bound 1.776000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2.5x2

# %%
datafile="2x2000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xac711847
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1723.0000000
# Presolve removed 11 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 11 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1354025 nonzeros (34%)
# Presolve added 0 rows and 73 columns
# Presolve removed 49 rows and 0 columns
# Presolve time: 10.47s
# Presolved: 5951 rows, 4073 columns, 2647842 nonzeros
# Variable types: 75 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.020858e+06   0.000000e+00     11s
#     1183    1.7771546e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.777155e+03, 1183 iterations, 0.84 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1777.15459    0   22 1723.00000 1777.15459  3.14%     -   13s
# H    0     0                    1773.0000000 1777.15459  0.23%     -   13s
# H    0     0                    1776.0000000 1777.15459  0.07%     -   13s
#      0     0     cutoff    0      1776.00000 1776.00000  0.00%     -   15s
#
# Cutting planes:
#   Gomory: 5
#   Implied bound: 1
#   MIR: 22
#
# Explored 1 nodes (1252 simplex iterations) in 15.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1776 1773 1723
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.776000000000e+03, best bound 1.776000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2.5x3

# %%
datafile="2x2000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xbd044438
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1715.0000000
# Presolve removed 16 rows and 4 columns (presolve time = 5s) ...
# Sparsify removed 1369444 nonzeros (34%)
# Presolve removed 42 rows and 3906 columns (presolve time = 10s) ...
# Presolve added 0 rows and 72 columns
# Presolve removed 42 rows and 0 columns
# Presolve time: 10.18s
# Presolved: 5958 rows, 4072 columns, 2628454 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.053101e+06   0.000000e+00     11s
#     1020    1.7735425e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.773542e+03, 1020 iterations, 0.73 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1773.54247    0   73 1715.00000 1773.54247  3.41%     -   13s
# H    0     0                    1771.0000000 1773.54247  0.14%     -   14s
#      0     0 1773.50355    0   64 1771.00000 1773.50355  0.14%     -   15s
# H    0     0                    1772.0000000 1773.50355  0.08%     -   16s
# H    0     0                    1773.0000000 1773.50355  0.03%     -   16s
#      0     0 1773.50355    0   64 1773.00000 1773.50355  0.03%     -   16s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   Implied bound: 1
#   MIR: 23
#
# Explored 1 nodes (1380 simplex iterations) in 16.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1773 1772 1771 1715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.773000000000e+03, best bound 1.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2.5x4

# %%
datafile="2x2000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-06-11
# Using license file C:\Users\elPatan03\gurobi.lic
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xd16a3aea
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1734.0000000
# Presolve removed 11 rows and 2 columns (presolve time = 6s) ...
# Presolve removed 11 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1354025 nonzeros (34%)
# Presolve added 0 rows and 73 columns
# Presolve removed 14 rows and 0 columns
# Presolve time: 12.64s
# Presolved: 5986 rows, 4073 columns, 2647941 nonzeros
# Variable types: 75 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.026598e+06   0.000000e+00     14s
#     1108    1.7795030e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.779503e+03, 1108 iterations, 0.78 seconds
# Total elapsed time = 15.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1779.50299    0   33 1734.00000 1779.50299  2.62%     -   16s
# H    0     0                    1778.0000000 1779.50299  0.08%     -   16s
#      0     0 1779.47007    0   29 1778.00000 1779.47007  0.08%     -   18s
# H    0     0                    1779.0000000 1779.47007  0.03%     -   19s
#      0     0 1779.47007    0   29 1779.00000 1779.47007  0.03%     -   19s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 3
#   RLT: 1
#
# Explored 1 nodes (1697 simplex iterations) in 19.45 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1779 1778 1734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.779000000000e+03, best bound 1.779000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x2.5x5

# %%
datafile="2x2000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x6ed2d3b5
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1722.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1369444 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 54 rows and 0 columns
# Presolve time: 10.88s
# Presolved: 5946 rows, 4072 columns, 2628412 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.063370e+06   0.000000e+00     12s
#     1167    1.7694111e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.769411e+03, 1167 iterations, 0.76 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1769.41110    0   42 1722.00000 1769.41110  2.75%     -   14s
# H    0     0                    1768.0000000 1769.41110  0.08%     -   14s
#      0     0 1769.28058    0   50 1768.00000 1769.28058  0.07%     -   16s
# H    0     0                    1769.0000000 1769.28058  0.02%     -   17s
#      0     0 1769.28058    0   50 1769.00000 1769.28058  0.02%     -   17s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 2
#   MIR: 16
#   RLT: 2
#
# Explored 1 nodes (1753 simplex iterations) in 17.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1769 1768 1722
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.769000000000e+03, best bound 1.769000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3x1

# %%
datafile="2x2000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x011a55ef
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1547.0000000
# Presolve removed 20 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 10s) ...
# Sparsify removed 1367924 nonzeros (34%)
# Presolve added 0 rows and 68 columns
# Presolve removed 36 rows and 0 columns
# Presolve time: 10.96s
# Presolved: 5964 rows, 4068 columns, 2622008 nonzeros
# Variable types: 76 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.161886e+06   0.000000e+00     12s
#     1731    1.6176648e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.617665e+03, 1731 iterations, 0.80 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1617.66484    0   49 1547.00000 1617.66484  4.57%     -   13s
# H    0     0                    1616.0000000 1617.66484  0.10%     -   13s
#      0     0 1617.66296    0   61 1616.00000 1617.66296  0.10%     -   16s
# H    0     0                    1617.0000000 1617.66296  0.04%     -   16s
#      0     0 1617.66296    0   61 1617.00000 1617.66296  0.04%     -   16s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 10
#   StrongCG: 1
#
# Explored 1 nodes (2182 simplex iterations) in 16.89 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1617 1616 1547
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.617000000000e+03, best bound 1.617000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3x2

# %%
datafile="2x2000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x9bbdac1d
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1541.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1375100 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 10.58s
# Presolved: 5965 rows, 4070 columns, 2618832 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.166855e+06   0.000000e+00     11s
#     1604    1.6152280e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.615228e+03, 1604 iterations, 2.13 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1615.22805    0   29 1541.00000 1615.22805  4.82%     -   14s
# H    0     0                    1612.0000000 1615.22805  0.20%     -   14s
# H    0     0                    1613.0000000 1615.22805  0.14%     -   14s
# H    0     0                    1614.0000000 1615.22805  0.08%     -   15s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 1
#   MIR: 36
#
# Explored 1 nodes (1631 simplex iterations) in 16.38 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1614 1613 1612 1541
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.614000000000e+03, best bound 1.614000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3x3

# %%
datafile="2x2000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x317f77a8
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1533.0000000
# Presolve removed 6 rows and 0 columns (presolve time = 5s) ...
# Sparsify removed 1358001 nonzeros (34%)
# Presolve removed 26 rows and 3907 columns (presolve time = 10s) ...
# Presolve added 0 rows and 75 columns
# Presolve removed 26 rows and 0 columns
# Presolve time: 10.35s
# Presolved: 5974 rows, 4075 columns, 2647911 nonzeros
# Variable types: 75 continuous, 4000 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   1.184121e+06   0.000000e+00     11s
#     1444    1.6074351e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.607435e+03, 1444 iterations, 0.95 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1607.43513    0   66 1533.00000 1607.43513  4.86%     -   13s
# H    0     0                    1606.0000000 1607.43513  0.09%     -   14s
#      0     0 1607.40387    0   52 1606.00000 1607.40387  0.09%     -   16s
# H    0     0                    1607.0000000 1607.40387  0.03%     -   16s
#      0     0 1607.40387    0   52 1607.00000 1607.40387  0.03%     -   16s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 9
#
# Explored 1 nodes (1611 simplex iterations) in 16.99 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1607 1606 1533
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.607000000000e+03, best bound 1.607000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3x4

# %%
datafile="2x2000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xf1998d36
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1538.0000000
# Presolve removed 5 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1383030 nonzeros (35%)
# Presolve added 0 rows and 76 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 10.57s
# Presolved: 5975 rows, 4076 columns, 2618912 nonzeros
# Variable types: 78 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.113412e+06   0.000000e+00     11s
#     1288    1.6152171e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.615217e+03, 1288 iterations, 0.95 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1615.21714    0   56 1538.00000 1615.21714  5.02%     -   13s
# H    0     0                    1614.0000000 1615.21714  0.08%     -   13s
#      0     0 1615.11610    0   55 1614.00000 1615.11610  0.07%     -   16s
#      0     0 1615.11610    0   55 1614.00000 1615.11610  0.07%     -   16s
#      0     0 1615.09368    0   45 1614.00000 1615.09368  0.07%     -   19s
#      0     0 1615.07840    0   33 1614.00000 1615.07840  0.07%     -   20s
#      0     0 1615.07840    0   31 1614.00000 1615.07840  0.07%     -   20s
#      0     0 1615.07698    0   39 1614.00000 1615.07698  0.07%     -   22s
#      0     0 1615.07587    0   40 1614.00000 1615.07587  0.07%     -   23s
#      0     0 1615.07357    0   39 1614.00000 1615.07357  0.07%     -   24s
#      0     0 1615.07152    0   39 1614.00000 1615.07152  0.07%     -   24s
#      0     0 1615.04183    0   31 1614.00000 1615.04183  0.06%     -   26s
#      0     0 1615.04183    0   35 1614.00000 1615.04183  0.06%     -   27s
#      0     0 1615.04183    0   41 1614.00000 1615.04183  0.06%     -   29s
#      0     0 1615.04183    0   43 1614.00000 1615.04183  0.06%     -   30s
#      0     0 1615.04183    0   27 1614.00000 1615.04183  0.06%     -   32s
#      0     0 1615.04175    0   33 1614.00000 1615.04175  0.06%     -   33s
#      0     0 1615.04157    0   32 1614.00000 1615.04157  0.06%     -   35s
#      0     0 1615.03304    0   36 1614.00000 1615.03304  0.06%     -   36s
#      0     0     cutoff    0      1614.00000 1614.00000  0.00%     -   36s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 1
#   MIR: 17
#
# Explored 1 nodes (1930 simplex iterations) in 37.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1614 1538
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.614000000000e+03, best bound 1.614000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3x5

# %%
datafile="2x2000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xdcac3f4d
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1543.0000000
# Presolve removed 22 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 10s) ...
# Sparsify removed 1367924 nonzeros (34%)
# Presolve added 0 rows and 68 columns
# Presolve removed 44 rows and 0 columns
# Presolve time: 10.68s
# Presolved: 5956 rows, 4068 columns, 2621996 nonzeros
# Variable types: 76 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.186957e+06   0.000000e+00     12s
#     1298    1.6130803e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.613080e+03, 1298 iterations, 0.90 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1613.08032    0   76 1543.00000 1613.08032  4.54%     -   14s
# H    0     0                    1611.0000000 1613.08032  0.13%     -   14s
# H    0     0                    1612.0000000 1613.08032  0.07%     -   14s
#      0     0 1613.02307    0   73 1612.00000 1613.02307  0.06%     -   16s
#      0     0 1613.02307    0   69 1612.00000 1613.02307  0.06%     -   17s
#      0     0 1613.01434    0   83 1612.00000 1613.01434  0.06%     -   19s
#      0     0 1613.00302    0   86 1612.00000 1613.00302  0.06%     -   20s
#      0     0 1613.00150    0   79 1612.00000 1613.00150  0.06%     -   20s
#      0     0 1613.00150    0   79 1612.00000 1613.00150  0.06%     -   21s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 4
#   Implied bound: 3
#   MIR: 44
#   StrongCG: 2
#   GUB cover: 1
#
# Explored 1 nodes (1612 simplex iterations) in 22.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1612 1611 1543
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.612000000000e+03, best bound 1.612000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3.5x1

# %%
datafile="2x2000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x3ddebe38
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1400.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1372656 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 22 rows and 0 columns
# Presolve time: 10.68s
# Presolved: 5978 rows, 4072 columns, 2625298 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.213335e+06   0.000000e+00     12s
#     1547    1.4811837e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.481184e+03, 1547 iterations, 2.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1481.18370    0   67 1400.00000 1481.18370  5.80%     -   14s
# H    0     0                    1480.0000000 1481.18370  0.08%     -   14s
#      0     0     cutoff    0      1480.00000 1480.00000  0.00%     -   16s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 1
#   MIR: 27
#   StrongCG: 2
#   RLT: 2
#
# Explored 1 nodes (1736 simplex iterations) in 16.44 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1480 1400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.480000000000e+03, best bound 1.480000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3.5x2

# %%
datafile="2x2000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x493bfe1a
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1397.0000000
# Presolve removed 15 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1371894 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 10.74s
# Presolved: 5975 rows, 4070 columns, 2622068 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.238984e+06   0.000000e+00     12s
#     1363    1.4784744e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.478474e+03, 1363 iterations, 0.90 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1478.47443    0   46 1397.00000 1478.47443  5.83%     -   13s
# H    0     0                    1477.0000000 1478.47443  0.10%     -   13s
# H    0     0                    1478.0000000 1478.47443  0.03%     -   13s
#      0     0 1478.47443    0   46 1478.00000 1478.47443  0.03%     -   13s
#
# Explored 1 nodes (1461 simplex iterations) in 14.03 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1478 1477 1397
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.478000000000e+03, best bound 1.478000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3.5x3

# %%
datafile="2x2000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x6a0625f8
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1405.0000000
# Presolve removed 30 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 30 rows and 8 columns (presolve time = 10s) ...
# Sparsify removed 1371110 nonzeros (34%)
# Presolve added 0 rows and 68 columns
# Presolve removed 48 rows and 0 columns
# Presolve time: 10.77s
# Presolved: 5952 rows, 4068 columns, 2618746 nonzeros
# Variable types: 76 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.185639e+06   0.000000e+00     12s
#     1420    1.4861021e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.486102e+03, 1420 iterations, 2.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1486.10206    0   31 1405.00000 1486.10206  5.77%     -   14s
# H    0     0                    1483.0000000 1486.10206  0.21%     -   14s
# H    0     0                    1485.0000000 1486.10206  0.07%     -   15s
#      0     0 1486.08201    0   29 1485.00000 1486.08201  0.07%     -   16s
#      0     0 1486.08201    0   27 1485.00000 1486.08201  0.07%     -   17s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 15
#
# Explored 1 nodes (1461 simplex iterations) in 18.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1485 1483 1405
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.485000000000e+03, best bound 1.485000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3.5x4

# %%
datafile="2x2000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x67170a16
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1399.0000000
# Presolve removed 19 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 19 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1368684 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 31 rows and 0 columns
# Presolve time: 12.53s
# Presolved: 5969 rows, 4070 columns, 2625242 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.240740e+06   0.000000e+00     13s
#     1562    1.4856849e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.485685e+03, 1562 iterations, 0.80 seconds
# Total elapsed time = 15.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1485.68485    0   97 1399.00000 1485.68485  6.20%     -   15s
# H    0     0                    1484.0000000 1485.68485  0.11%     -   15s
#      0     0 1485.29958    0   81 1484.00000 1485.29958  0.09%     -   18s
#      0     0 1485.29440    0   77 1484.00000 1485.29440  0.09%     -   20s
#      0     0 1485.29248    0   77 1484.00000 1485.29248  0.09%     -   21s
#      0     0 1485.29248    0   77 1484.00000 1485.29248  0.09%     -   21s
#      0     0 1485.28855    0   69 1484.00000 1485.28855  0.09%     -   24s
#      0     0 1485.28855    0   61 1484.00000 1485.28855  0.09%     -   24s
#      0     0 1485.28568    0   76 1484.00000 1485.28568  0.09%     -   27s
#      0     0 1485.28568    0   66 1484.00000 1485.28568  0.09%     -   27s
#      0     0 1485.28482    0   62 1484.00000 1485.28482  0.09%     -   30s
# H    0     0                    1485.0000000 1485.28482  0.02%     -   30s
#      0     0 1485.28482    0   62 1485.00000 1485.28482  0.02%     -   30s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 33
#
# Explored 1 nodes (2353 simplex iterations) in 30.84 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1485 1484 1399
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.485000000000e+03, best bound 1.485000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x3.5x5

# %%
datafile="2x2000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x0d30a0d6
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1399.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1373396 nonzeros (34%)
# Presolve added 0 rows and 74 columns
# Presolve removed 23 rows and 0 columns
# Presolve time: 10.73s
# Presolved: 5977 rows, 4074 columns, 2628548 nonzeros
# Variable types: 76 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.264155e+06   0.000000e+00     12s
#     1689    1.4769043e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.476904e+03, 1689 iterations, 2.26 seconds
# Total elapsed time = 15.08s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1476.90426    0   35 1399.00000 1476.90426  5.57%     -   15s
# H    0     0                    1475.0000000 1476.90426  0.13%     -   15s
#      0     0 1476.89209    0   40 1475.00000 1476.89209  0.13%     -   17s
# H    0     0                    1476.0000000 1476.89209  0.06%     -   18s
#      0     0 1476.89209    0   40 1476.00000 1476.89209  0.06%     -   18s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 4
#   MIR: 6
#   StrongCG: 3
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (1761 simplex iterations) in 18.22 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1476 1475 1399
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.476000000000e+03, best bound 1.476000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4x1

# %%
datafile="2x2000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xd9a99177
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1284.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 10s) ...
# Sparsify removed 1380600 nonzeros (34%)
# Presolve added 0 rows and 76 columns
# Presolve removed 8 rows and 0 columns
# Presolve time: 10.53s
# Presolved: 5992 rows, 4076 columns, 2625382 nonzeros
# Variable types: 76 continuous, 4000 integer (4000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   1.300618e+06   0.000000e+00     11s
#     1428    1.3819118e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.381912e+03, 1428 iterations, 0.96 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1381.91176    0   66 1284.00000 1381.91176  7.63%     -   13s
# H    0     0                    1380.0000000 1381.91176  0.14%     -   13s
#      0     0 1381.86533    0   71 1380.00000 1381.86533  0.14%     -   15s
# H    0     0                    1381.0000000 1381.86533  0.06%     -   16s
#      0     0 1381.86533    0   71 1381.00000 1381.86533  0.06%     -   16s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   Implied bound: 1
#   MIR: 23
#   StrongCG: 4
#   GUB cover: 2
#
# Explored 1 nodes (1658 simplex iterations) in 16.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1381 1380 1284
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.381000000000e+03, best bound 1.381000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4x2

# %%
datafile="2x2000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x718a21dc
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1293.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 6s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 10s) ...
# Sparsify removed 1367164 nonzeros (34%)
# Presolve added 0 rows and 66 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 12.28s
# Presolved: 5965 rows, 4066 columns, 2618800 nonzeros
# Variable types: 76 continuous, 3990 integer (3990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.288135e+06   0.000000e+00     13s
#     1604    1.3830773e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.383077e+03, 1604 iterations, 1.06 seconds
# Total elapsed time = 15.35s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1383.07728    0   72 1293.00000 1383.07728  6.97%     -   15s
# H    0     0                    1381.0000000 1383.07728  0.15%     -   16s
#      0     0 1382.90374    0   55 1381.00000 1382.90374  0.14%     -   17s
# H    0     0                    1382.0000000 1382.90374  0.07%     -   19s
#      0     0 1382.90374    0   55 1382.00000 1382.90374  0.07%     -   19s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 1
#   Implied bound: 1
#   MIR: 13
#
# Explored 1 nodes (1940 simplex iterations) in 19.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1382 1381 1293
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.382000000000e+03, best bound 1.382000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4x3

# %%
datafile="2x2000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x21c4e9c7
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1291.0000000
# Presolve removed 17 rows and 10 columns (presolve time = 6s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 10s) ...
# Sparsify removed 1405541 nonzeros (35%)
# Presolve added 0 rows and 69 columns
# Presolve removed 21 rows and 0 columns
# Presolve time: 12.40s
# Presolved: 5979 rows, 4069 columns, 2580459 nonzeros
# Variable types: 79 continuous, 3990 integer (3990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.283833e+06   0.000000e+00     13s
#     1727    1.3735667e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.373567e+03, 1727 iterations, 0.77 seconds
# Total elapsed time = 15.31s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1373.56673    0   93 1291.00000 1373.56673  6.40%     -   15s
# H    0     0                    1371.0000000 1373.56673  0.19%     -   16s
#      0     0 1373.53924    0  100 1371.00000 1373.53924  0.19%     -   17s
# H    0     0                    1372.0000000 1373.53924  0.11%     -   19s
#      0     0 1373.53700    0   95 1372.00000 1373.53700  0.11%     -   19s
#      0     0 1373.47563    0   94 1372.00000 1373.47563  0.11%     -   20s
#      0     0 1373.43225    0   84 1372.00000 1373.43225  0.10%     -   22s
#      0     0 1373.43062    0   85 1372.00000 1373.43062  0.10%     -   23s
#      0     0 1373.43035    0   87 1372.00000 1373.43035  0.10%     -   23s
#      0     0 1373.43027    0   87 1372.00000 1373.43027  0.10%     -   24s
#      0     0 1373.41613    0   73 1372.00000 1373.41613  0.10%     -   26s
# H    0     0                    1373.0000000 1373.41613  0.03%     -   26s
#      0     0 1373.41613    0   73 1373.00000 1373.41613  0.03%     -   26s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 1
#   MIR: 29
#   StrongCG: 1
#   GUB cover: 3
#
# Explored 1 nodes (2304 simplex iterations) in 26.97 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1373 1372 1371 1291
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.373000000000e+03, best bound 1.373000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4x4

# %%
datafile="2x2000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x590cbeda
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1286.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1368684 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 10.83s
# Presolved: 5975 rows, 4070 columns, 2625280 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.293698e+06   0.000000e+00     12s
#     2130    1.3742514e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.374251e+03, 2130 iterations, 0.93 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1374.25141    0   51 1286.00000 1374.25141  6.86%     -   13s
# H    0     0                    1373.0000000 1374.25141  0.09%     -   14s
#      0     0 1374.22872    0   45 1373.00000 1374.22872  0.09%     -   16s
# H    0     0                    1374.0000000 1374.22872  0.02%     -   17s
#      0     0 1374.22872    0   45 1374.00000 1374.22872  0.02%     -   17s
#
# Cutting planes:
#   Gomory: 11
#   MIR: 9
#   StrongCG: 1
#
# Explored 1 nodes (2249 simplex iterations) in 17.04 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1374 1373 1286
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.374000000000e+03, best bound 1.374000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4x5

# %%
datafile="2x2000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x3adf3208
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1292.0000000
# Presolve removed 15 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 10s) ...
# Sparsify removed 1368684 nonzeros (34%)
# Presolve added 0 rows and 70 columns
# Presolve removed 21 rows and 0 columns
# Presolve time: 12.37s
# Presolved: 5979 rows, 4070 columns, 2625286 nonzeros
# Variable types: 76 continuous, 3994 integer (3994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.264384e+06   0.000000e+00     13s
#     1998    1.3830532e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.383053e+03, 1998 iterations, 0.80 seconds
# Total elapsed time = 15.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1383.05324    0   35 1292.00000 1383.05324  7.05%     -   15s
# H    0     0                    1382.0000000 1383.05324  0.08%     -   15s
#      0     0     cutoff    0      1382.00000 1382.00000  0.00%     -   16s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 22
#   RLT: 1
#
# Explored 1 nodes (2436 simplex iterations) in 16.99 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1382 1292
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.382000000000e+03, best bound 1.382000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4.5x1

# %%
datafile="2x2000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x750559f8
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1205.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1372656 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 28 rows and 0 columns
# Presolve time: 12.52s
# Presolved: 5972 rows, 4072 columns, 2625288 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.323867e+06   0.000000e+00     13s
#     2245    1.3007562e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.300756e+03, 2245 iterations, 1.01 seconds
# Total elapsed time = 15.14s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1300.75617    0   62 1205.00000 1300.75617  7.95%     -   16s
# H    0     0                    1300.0000000 1300.75617  0.06%     -   16s
#      0     0 1300.75617    0   62 1300.00000 1300.75617  0.06%     -   16s
#
# Explored 1 nodes (2506 simplex iterations) in 16.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1300 1205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+03, best bound 1.300000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4.5x2

# %%
datafile="2x2000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xcebd9c65
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1217.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1369444 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 18 rows and 0 columns
# Presolve time: 10.73s
# Presolved: 5982 rows, 4072 columns, 2628524 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.305581e+06   0.000000e+00     12s
#     2047    1.3066999e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.306700e+03, 2047 iterations, 0.75 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1306.69992    0   49 1217.00000 1306.69992  7.37%     -   13s
# H    0     0                    1305.0000000 1306.69992  0.13%     -   13s
#      0     0 1306.55728    0   57 1305.00000 1306.55728  0.12%     -   15s
# H    0     0                    1306.0000000 1306.55728  0.04%     -   16s
#      0     0 1306.55728    0   57 1306.00000 1306.55728  0.04%     -   16s
#
# Cutting planes:
#   Gomory: 12
#   MIR: 5
#
# Explored 1 nodes (2190 simplex iterations) in 16.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1306 1305 1217
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.306000000000e+03, best bound 1.306000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4.5x3

# %%
datafile="2x2000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x4d2b0e1b
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1214.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1369444 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 22 rows and 0 columns
# Presolve time: 10.71s
# Presolved: 5978 rows, 4072 columns, 2628514 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.375344e+06   0.000000e+00     12s
#     2617    1.2981414e+03   0.000000e+00   0.000000e+00     15s
#
# Root relaxation: objective 1.298141e+03, 2617 iterations, 3.28 seconds
# Total elapsed time = 15.31s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1298.14137    0   60 1214.00000 1298.14137  6.93%     -   16s
# H    0     0                    1297.0000000 1298.14137  0.09%     -   16s
#      0     0     cutoff    0      1297.00000 1297.00000  0.00%     -   17s
#
# Cutting planes:
#   Gomory: 21
#   MIR: 40
#
# Explored 1 nodes (2891 simplex iterations) in 17.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1297 1214
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.297000000000e+03, best bound 1.297000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4.5x4

# %%
datafile="2x2000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xd3d46c00
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1197.0000000
# Presolve removed 18 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 12 columns (presolve time = 10s) ...
# Sparsify removed 1398387 nonzeros (35%)
# Presolve added 0 rows and 65 columns
# Presolve removed 24 rows and 0 columns
# Presolve time: 10.72s
# Presolved: 5976 rows, 4065 columns, 2583619 nonzeros
# Variable types: 77 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.323958e+06   0.000000e+00     12s
#     2001    1.2920305e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.292030e+03, 2001 iterations, 2.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1292.03049    0   78 1197.00000 1292.03049  7.94%     -   14s
# H    0     0                    1283.0000000 1292.03049  0.70%     -   14s
# H    0     0                    1289.0000000 1292.03049  0.24%     -   15s
# H    0     0                    1290.0000000 1292.03049  0.16%     -   15s
#      0     0 1291.94331    0   73 1290.00000 1291.94331  0.15%     -   17s
# H    0     0                    1291.0000000 1291.94331  0.07%     -   17s
#      0     0 1291.94331    0   73 1291.00000 1291.94331  0.07%     -   17s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 1
#   MIR: 11
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (2198 simplex iterations) in 17.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1291 1290 1289 ... 1197
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.291000000000e+03, best bound 1.291000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x4.5x5

# %%
datafile="2x2000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x89efb410
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1195.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Sparsify removed 1354025 nonzeros (34%)
# Presolve added 0 rows and 73 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 10.55s
# Presolved: 5975 rows, 4073 columns, 2647915 nonzeros
# Variable types: 75 continuous, 3998 integer (3998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.346675e+06   0.000000e+00     11s
#     2520    1.2879078e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.287908e+03, 2520 iterations, 1.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1287.90783    0   54 1195.00000 1287.90783  7.77%     -   13s
# H    0     0                    1287.0000000 1287.90783  0.07%     -   13s
#      0     0 1287.90783    0   54 1287.00000 1287.90783  0.07%     -   13s
#
# Explored 1 nodes (2763 simplex iterations) in 13.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1287 1195
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.287000000000e+03, best bound 1.287000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x5x1

# %%
datafile="2x2000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xff5b588c
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1149.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Sparsify removed 1375864 nonzeros (34%)
# Presolve added 0 rows and 72 columns
# Presolve removed 18 rows and 0 columns
# Presolve time: 10.63s
# Presolved: 5982 rows, 4072 columns, 2622104 nonzeros
# Variable types: 76 continuous, 3996 integer (3996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.332842e+06   0.000000e+00     12s
#     2391    1.2388587e+03   0.000000e+00   0.000000e+00     12s
#
# Root relaxation: objective 1.238859e+03, 2391 iterations, 1.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1238.85868    0   35 1149.00000 1238.85868  7.82%     -   13s
# H    0     0                    1236.0000000 1238.85868  0.23%     -   13s
# H    0     0                    1237.0000000 1238.85868  0.15%     -   13s
#      0     0 1238.81548    0   34 1237.00000 1238.81548  0.15%     -   15s
# H    0     0                    1238.0000000 1238.81548  0.07%     -   15s
#      0     0 1238.81548    0   34 1238.00000 1238.81548  0.07%     -   15s
#
# Cutting planes:
#   Gomory: 5
#   Implied bound: 1
#   MIR: 4
#
# Explored 1 nodes (2466 simplex iterations) in 16.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1238 1237 1236 1149
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.238000000000e+03, best bound 1.238000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x5x2

# %%
datafile="2x2000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x17119678
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1141.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 10s) ...
# Sparsify removed 1387158 nonzeros (35%)
# Presolve added 0 rows and 70 columns
# Presolve removed 20 rows and 0 columns
# Presolve time: 10.87s
# Presolved: 5980 rows, 4070 columns, 2602834 nonzeros
# Variable types: 78 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.387996e+06   0.000000e+00     12s
#     2111    1.2189334e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.218933e+03, 2111 iterations, 1.95 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1218.93337    0   71 1141.00000 1218.93337  6.83%     -   15s
# H    0     0                    1216.0000000 1218.93337  0.24%     -   15s
# H    0     0                    1217.0000000 1218.93337  0.16%     -   15s
#      0     0 1218.83402    0   83 1217.00000 1218.83402  0.15%     -   17s
# H    0     0                    1218.0000000 1218.83402  0.07%     -   18s
#      0     0 1218.83402    0   83 1218.00000 1218.83402  0.07%     -   18s
#
# Cutting planes:
#   Gomory: 13
#   MIR: 10
#   StrongCG: 2
#
# Explored 1 nodes (2366 simplex iterations) in 18.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1218 1217 1216 1141
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.218000000000e+03, best bound 1.218000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x5x3

# %%
datafile="2x2000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x793ad566
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1128.0000000
# Presolve removed 20 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 10s) ...
# Sparsify removed 1369608 nonzeros (34%)
# Presolve added 0 rows and 64 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 12.39s
# Presolved: 5960 rows, 4064 columns, 2612358 nonzeros
# Variable types: 76 continuous, 3988 integer (3988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.383321e+06   0.000000e+00     13s
#     1865    1.2180298e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 1.218030e+03, 1865 iterations, 0.83 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1218.02983    0   51 1128.00000 1218.02983  7.98%     -   14s
# H    0     0                    1209.0000000 1218.02983  0.75%     -   15s
# H    0     0                    1217.0000000 1218.02983  0.08%     -   15s
#      0     0     cutoff    0      1217.00000 1217.00000  0.00%     -   16s
#
# Cutting planes:
#   Gomory: 11
#   Implied bound: 2
#   MIR: 50
#   StrongCG: 1
#   GUB cover: 1
#   RLT: 6
#   Relax-and-lift: 2
#
# Explored 1 nodes (2032 simplex iterations) in 16.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1217 1209 1128
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.217000000000e+03, best bound 1.217000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x5x4

# %%
datafile="2x2000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0xf3ac7c95
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1125.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 6s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 10s) ...
# Sparsify removed 1367164 nonzeros (34%)
# Presolve added 0 rows and 66 columns
# Presolve removed 27 rows and 0 columns
# Presolve time: 14.84s
# Presolved: 5973 rows, 4066 columns, 2618810 nonzeros
# Variable types: 76 continuous, 3990 integer (3990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.406345e+06   0.000000e+00     16s
#     2275    1.2179393e+03   0.000000e+00   0.000000e+00     17s
#
# Root relaxation: objective 1.217939e+03, 2275 iterations, 0.97 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1217.93932    0   61 1125.00000 1217.93932  8.26%     -   17s
# H    0     0                    1217.0000000 1217.93932  0.08%     -   17s
#      0     0 1217.93932    0   61 1217.00000 1217.93932  0.08%     -   17s
#
# Explored 1 nodes (2340 simplex iterations) in 17.98 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1217 1125
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.217000000000e+03, best bound 1.217000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x2000x5x5

# %%
datafile="2x2000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 6000 rows, 4000 columns and 4006000 nonzeros
# Model fingerprint: 0x31ce975e
# Variable types: 0 continuous, 4000 integer (4000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1147.0000000
# Presolve removed 16 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 10s) ...
# Sparsify removed 1367924 nonzeros (34%)
# Presolve added 0 rows and 68 columns
# Presolve removed 28 rows and 0 columns
# Presolve time: 11.12s
# Presolved: 5972 rows, 4068 columns, 2622040 nonzeros
# Variable types: 76 continuous, 3992 integer (3992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.360386e+06   0.000000e+00     12s
#     2132    1.2267818e+03   0.000000e+00   0.000000e+00     13s
#
# Root relaxation: objective 1.226782e+03, 2132 iterations, 0.87 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1226.78183    0   62 1147.00000 1226.78183  6.96%     -   13s
# H    0     0                    1226.0000000 1226.78183  0.06%     -   13s
#      0     0 1226.78183    0   62 1226.00000 1226.78183  0.06%     -   13s
#
# Explored 1 nodes (2183 simplex iterations) in 14.00 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1226 1147
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.226000000000e+03, best bound 1.226000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x1.5x1

# %%
datafile="3x2000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x4a791121
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 17 rows and 6 columns (presolve time = 8s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1924114 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 129 rows and 0 columns
# Presolve time: 17.37s
# Presolved: 7871 rows, 6100 columns, 4072352 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.007009e+06   0.000000e+00     19s
#     1053    1.9980000e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.998000e+03, 1053 iterations, 0.77 seconds
# Total elapsed time = 20.26s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1998.0000000 1998.00000  0.00%     -   20s
#
# Explored 0 nodes (2553 simplex iterations) in 20.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1998 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x1.5x2

# %%
datafile="3x2000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x9d8b2970
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 1998.0000000
# Presolve removed 10 rows and 3 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 15s) ...
# Sparsify removed 1925174 nonzeros (32%)
# Presolve added 0 rows and 103 columns
# Presolve removed 55 rows and 0 columns
# Presolve time: 16.56s
# Presolved: 7945 rows, 6103 columns, 4077640 nonzeros
# Variable types: 106 continuous, 5997 integer (5997 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   9.563035e+05   0.000000e+00     18s
#      939    1.9990000e+03   0.000000e+00   0.000000e+00     18s
#
# Root relaxation: objective 1.999000e+03, 939 iterations, 0.65 seconds
# Total elapsed time = 20.06s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1999.00000    0    7 1998.00000 1999.00000  0.05%     -   21s
#      0     0 1999.00000    0   15 1998.00000 1999.00000  0.05%     -   23s
#      0     0 1999.00000    0   16 1998.00000 1999.00000  0.05%     -   24s
#      0     0 1999.00000    0    4 1998.00000 1999.00000  0.05%     -   29s
#      0     0 1999.00000    0    7 1998.00000 1999.00000  0.05%     -   33s
#      0     0 1999.00000    0   13 1998.00000 1999.00000  0.05%     -   34s
#      0     0 1999.00000    0    8 1998.00000 1999.00000  0.05%     -   38s
#      0     0 1999.00000    0   10 1998.00000 1999.00000  0.05%     -   39s
#      0     0 1999.00000    0   14 1998.00000 1999.00000  0.05%     -   41s
#      0     0 1999.00000    0   14 1998.00000 1999.00000  0.05%     -   42s
#      0     0 1999.00000    0   10 1998.00000 1999.00000  0.05%     -   45s
#      0     0 1999.00000    0   10 1998.00000 1999.00000  0.05%     -   47s
#      0     2 1999.00000    0   10 1998.00000 1999.00000  0.05%     -   51s
#      2     3 1999.00000    1   10 1998.00000 1999.00000  0.05%  19.0   82s
#      4     4 1999.00000    1    7 1998.00000 1999.00000  0.05%   9.5   88s
#      5     5 1999.00000    1    6 1998.00000 1999.00000  0.05%   7.6   91s
#      7     6 1999.00000    1   16 1998.00000 1999.00000  0.05%   5.4   97s
#      9     8 1999.00000    1   17 1998.00000 1999.00000  0.05%   4.2  101s
#     11     9 1999.00000    1   13 1998.00000 1999.00000  0.05%   3.5  106s
#     13    10 1999.00000    1   14 1998.00000 1999.00000  0.05%   2.9  110s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 7
#   MIR: 10
#   Flow cover: 15
#   GUB cover: 3
#   Inf proof: 2
#   Relax-and-lift: 1
#
# Explored 13 nodes (15974 simplex iterations) in 112.33 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x1.5x3

# %%
datafile="3x2000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x97454442
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 1998.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1933904 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 65 rows and 0 columns
# Presolve time: 16.36s
# Presolved: 7935 rows, 6100 columns, 4062841 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   9.668427e+05   0.000000e+00     18s
#
# Root relaxation: cutoff, 0 iterations, 0.26 seconds
#
# Explored 0 nodes (0 simplex iterations) in 17.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x1.5x4

# %%
datafile="3x2000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xc73de1d5
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 1998.0000000
# Presolve removed 38 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 38 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 38 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1969721 nonzeros (33%)
# Presolve added 0 rows and 101 columns
# Presolve removed 116 rows and 0 columns
# Presolve time: 16.54s
# Presolved: 7884 rows, 6101 columns, 4026844 nonzeros
# Variable types: 107 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   9.913115e+05   0.000000e+00     18s
#
# Root relaxation: cutoff, 0 iterations, 0.26 seconds
#
# Explored 0 nodes (0 simplex iterations) in 18.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x1.5x5

# %%
datafile="3x2000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xfb9fffb2
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 24 rows and 9 columns (presolve time = 8s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 15s) ...
# Sparsify removed 1927949 nonzeros (32%)
# Presolve added 0 rows and 97 columns
# Presolve removed 82 rows and 0 columns
# Presolve time: 17.12s
# Presolved: 7918 rows, 6097 columns, 4062815 nonzeros
# Variable types: 106 continuous, 5991 integer (5991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   9.929808e+05   0.000000e+00     19s
#
# Root relaxation: cutoff, 0 iterations, 0.26 seconds
#
# Explored 0 nodes (0 simplex iterations) in 18.67 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.997000000000e+03, best bound 1.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2x1

# %%
datafile="3x2000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x4896b686
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1990.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 7s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 15s) ...
# Sparsify removed 1923054 nonzeros (32%)
# Presolve added 0 rows and 97 columns
# Presolve removed 45 rows and 0 columns
# Presolve time: 16.65s
# Presolved: 7955 rows, 6097 columns, 4067868 nonzeros
# Variable types: 106 continuous, 5991 integer (5991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.123900e+06   0.000000e+00     18s
#     1045    1.9925679e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.992568e+03, 1045 iterations, 0.76 seconds
# Total elapsed time = 20.89s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1992.56794    0   87 1990.00000 1992.56794  0.13%     -   23s
#      0     0 1992.48698    0  112 1990.00000 1992.48698  0.12%     -   26s
#      0     0 1992.46734    0  108 1990.00000 1992.46734  0.12%     -   28s
#      0     0 1992.46722    0  109 1990.00000 1992.46722  0.12%     -   29s
#      0     0 1992.17293    0   74 1990.00000 1992.17293  0.11%     -   32s
# H    0     0                    1991.0000000 1992.17293  0.06%     -   33s
#      0     0 1992.17155    0   69 1991.00000 1992.17155  0.06%     -   33s
#      0     0 1992.17153    0   76 1991.00000 1992.17153  0.06%     -   34s
#      0     0 1992.15245    0   77 1991.00000 1992.15245  0.06%     -   37s
#      0     0 1992.15245    0   86 1991.00000 1992.15245  0.06%     -   38s
#      0     0 1992.15137    0   78 1991.00000 1992.15137  0.06%     -   41s
#      0     0 1992.15130    0   79 1991.00000 1992.15130  0.06%     -   43s
#      0     0 1992.15079    0   68 1991.00000 1992.15079  0.06%     -   46s
#      0     0 1992.15079    0   60 1991.00000 1992.15079  0.06%     -   48s
#      0     0 1992.15079    0   55 1991.00000 1992.15079  0.06%     -   50s
#      0     0 1992.15073    0   55 1991.00000 1992.15073  0.06%     -   52s
#      0     0 1992.15031    0   49 1991.00000 1992.15031  0.06%     -   57s
#      0     0 1992.15008    0   48 1991.00000 1992.15008  0.06%     -   59s
#      0     0 1992.15008    0   48 1991.00000 1992.15008  0.06%     -   59s
#      0     0 1992.14984    0   52 1991.00000 1992.14984  0.06%     -   62s
#      0     0 1992.14984    0   55 1991.00000 1992.14984  0.06%     -   64s
#      0     0 1992.13724    0   45 1991.00000 1992.13724  0.06%     -   67s
#      0     0 1992.12332    0   47 1991.00000 1992.12332  0.06%     -   69s
#      0     0 1992.12332    0   49 1991.00000 1992.12332  0.06%     -   69s
#      0     0 1992.11228    0   51 1991.00000 1992.11228  0.06%     -   72s
#      0     0 1992.11228    0   45 1991.00000 1992.11228  0.06%     -   73s
#      0     0 1992.11228    0   39 1991.00000 1992.11228  0.06%     -   76s
#      0     0 1992.11228    0   47 1991.00000 1992.11228  0.06%     -   78s
#      0     0 1992.04868    0   40 1991.00000 1992.04868  0.05%     -   82s
#      0     0 1992.04868    0   42 1991.00000 1992.04868  0.05%     -   83s
#      0     0 1992.04868    0   34 1991.00000 1992.04868  0.05%     -   86s
#      0     0 1992.04868    0   40 1991.00000 1992.04868  0.05%     -   88s
#      0     0 1992.04868    0   39 1991.00000 1992.04868  0.05%     -   92s
#      0     0 1992.04868    0   47 1991.00000 1992.04868  0.05%     -   93s
#      0     0 1992.04868    0   39 1991.00000 1992.04868  0.05%     -   97s
#      0     0 1992.04868    0   50 1991.00000 1992.04868  0.05%     -   99s
#      0     0 1992.04868    0   29 1991.00000 1992.04868  0.05%     -  103s
#      0     0 1992.04868    0   31 1991.00000 1992.04868  0.05%     -  105s
#      0     0 1992.04868    0   23 1991.00000 1992.04868  0.05%     -  109s
#      0     0 1992.04868    0   35 1991.00000 1992.04868  0.05%     -  110s
#      0     0 1992.04868    0   29 1991.00000 1992.04868  0.05%     -  116s
#      0     0 1992.04868    0   29 1991.00000 1992.04868  0.05%     -  118s
#      0     2 1992.04868    0   22 1991.00000 1992.04868  0.05%     -  126s
#     19    26 1992.04868    4   28 1991.00000 1992.04868  0.05%   226  130s
# H   33    36                    1992.0000000 1992.04868  0.00%   132  132s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 5
#   MIR: 27
#   StrongCG: 1
#   RLT: 1
#
# Explored 37 nodes (27571 simplex iterations) in 132.79 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1992 1991 1990
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.992000000000e+03, best bound 1.992000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2x2

# %%
datafile="3x2000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x25a57113
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1985.0000000
# Presolve removed 24 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 15s) ...
# Sparsify removed 1923054 nonzeros (32%)
# Presolve added 0 rows and 97 columns
# Presolve removed 54 rows and 0 columns
# Presolve time: 19.25s
# Presolved: 7946 rows, 6097 columns, 4067826 nonzeros
# Variable types: 106 continuous, 5991 integer (5991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.137561e+06   0.000000e+00     21s
#     1051    1.9892578e+03   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.989258e+03, 1051 iterations, 0.88 seconds
# Total elapsed time = 25.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1989.25776    0   54 1985.00000 1989.25776  0.21%     -   25s
# H    0     0                    1987.0000000 1989.25776  0.11%     -   26s
# H    0     0                    1988.0000000 1989.25776  0.06%     -   26s
#      0     0 1989.10716    0   50 1988.00000 1989.10716  0.06%     -   30s
#      0     0 1989.10716    0   54 1988.00000 1989.10716  0.06%     -   32s
#
# Cutting planes:
#   Gomory: 27
#   Implied bound: 2
#   MIR: 70
#   StrongCG: 1
#
# Explored 1 nodes (5864 simplex iterations) in 35.57 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1988 1987 1985
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.988000000000e+03, best bound 1.988000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2x3

# %%
datafile="3x2000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x1f55881f
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1976.0000000
# Presolve removed 27 rows and 18 columns (presolve time = 7s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 15s) ...
# Sparsify removed 1936203 nonzeros (32%)
# Presolve added 0 rows and 89 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 16.32s
# Presolved: 7965 rows, 6089 columns, 4036793 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.156182e+06   0.000000e+00     18s
#     1066    1.9811019e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.981102e+03, 1066 iterations, 0.91 seconds
# Total elapsed time = 20.91s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1981.10188    0  107 1976.00000 1981.10188  0.26%     -   21s
# H    0     0                    1978.0000000 1981.10188  0.16%     -   22s
#      0     0 1981.09025    0   88 1978.00000 1981.09025  0.16%     -   25s
# H    0     0                    1980.0000000 1981.09025  0.06%     -   27s
#      0     0 1981.09025    0   93 1980.00000 1981.09025  0.06%     -   28s
#      0     0 1981.06708    0   73 1980.00000 1981.06708  0.05%     -   31s
#      0     0 1981.06708    0   75 1980.00000 1981.06708  0.05%     -   33s
#      0     0     cutoff    0      1980.00000 1980.00000  0.00%     -   36s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 8
#   Implied bound: 1
#   MIR: 84
#   StrongCG: 1
#   RLT: 1
#
# Explored 1 nodes (4891 simplex iterations) in 36.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1980 1978 1976
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.980000000000e+03, best bound 1.980000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2x4

# %%
datafile="3x2000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x008502ed
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1994.0000000
# Presolve removed 19 rows and 3 columns (presolve time = 7s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 15s) ...
# Sparsify removed 1925174 nonzeros (32%)
# Presolve added 0 rows and 103 columns
# Presolve removed 52 rows and 0 columns
# Presolve time: 16.41s
# Presolved: 7948 rows, 6103 columns, 4077664 nonzeros
# Variable types: 106 continuous, 5997 integer (5997 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.174466e+06   0.000000e+00     18s
#     1012    1.9966921e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.996692e+03, 1012 iterations, 0.86 seconds
# Total elapsed time = 20.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1996.69208    0   44 1994.00000 1996.69208  0.14%     -   20s
# H    0     0                    1995.0000000 1996.69208  0.08%     -   21s
#      0     0 1996.45377    0   46 1995.00000 1996.45377  0.07%     -   24s
# H    0     0                    1996.0000000 1996.45377  0.02%     -   25s
#      0     0 1996.45377    0   46 1996.00000 1996.45377  0.02%     -   25s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 3
#   MIR: 20
#   StrongCG: 1
#
# Explored 1 nodes (4272 simplex iterations) in 25.48 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1996 1995 1994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.996000000000e+03, best bound 1.996000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2x5

# %%
datafile="3x2000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xe34cf172
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1972.0000000
# Presolve removed 16 rows and 3 columns (presolve time = 7s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 15s) ...
# Sparsify removed 1925174 nonzeros (32%)
# Presolve added 0 rows and 103 columns
# Presolve removed 55 rows and 0 columns
# Presolve time: 16.14s
# Presolved: 7945 rows, 6103 columns, 4077676 nonzeros
# Variable types: 106 continuous, 5997 integer (5997 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.200531e+06   0.000000e+00     18s
#     1178    1.9781411e+03   0.000000e+00   0.000000e+00     18s
#
# Root relaxation: objective 1.978141e+03, 1178 iterations, 0.96 seconds
# Total elapsed time = 20.05s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1978.14106    0   80 1972.00000 1978.14106  0.31%     -   20s
# H    0     0                    1976.0000000 1978.14106  0.11%     -   20s
#      0     0 1978.10281    0   67 1976.00000 1978.10281  0.11%     -   23s
# H    0     0                    1977.0000000 1978.10281  0.06%     -   25s
#      0     0 1978.10281    0   65 1977.00000 1978.10281  0.06%     -   25s
#      0     0 1978.10281    0   48 1977.00000 1978.10281  0.06%     -   28s
#      0     0 1978.10281    0   57 1977.00000 1978.10281  0.06%     -   30s
#      0     0 1978.06025    0   61 1977.00000 1978.06025  0.05%     -   35s
#      0     0 1978.05859    0   55 1977.00000 1978.05859  0.05%     -   36s
#      0     0 1978.05859    0   55 1977.00000 1978.05859  0.05%     -   37s
#      0     0 1978.05692    0   65 1977.00000 1978.05692  0.05%     -   40s
#      0     0 1978.05692    0   70 1977.00000 1978.05692  0.05%     -   41s
#      0     0     cutoff    0      1977.00000 1977.00000  0.00%     -   43s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 2
#   MIR: 154
#   StrongCG: 1
#
# Explored 1 nodes (5956 simplex iterations) in 43.69 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1977 1976 1972
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.977000000000e+03, best bound 1.977000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2.5x1

# %%
datafile="3x2000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x9bfeb5a7
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1736.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 25s) ...
# Sparsify removed 1949177 nonzeros (33%)
# Presolve removed 21 rows and 5866 columns (presolve time = 30s) ...
# Presolve added 0 rows and 98 columns
# Presolve removed 21 rows and 0 columns
# Presolve time: 30.17s
# Presolved: 7979 rows, 6098 columns, 4041808 nonzeros
# Variable types: 107 continuous, 5991 integer (5991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.262742e+06   0.000000e+00     34s
#      453    1.7818168e+03   1.181256e+05   0.000000e+00     36s
#     1627    1.7755423e+03   0.000000e+00   0.000000e+00     37s
#
# Root relaxation: objective 1.775542e+03, 1627 iterations, 3.73 seconds
# Total elapsed time = 41.52s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1775.54233    0  177 1736.00000 1775.54233  2.28%     -   43s
# H    0     0                    1760.0000000 1775.54233  0.88%     -   44s
# H    0     0                    1767.0000000 1775.54233  0.48%     -   44s
# H    0     0                    1771.0000000 1775.54233  0.26%     -   45s
#      0     0 1775.52167    0  156 1771.00000 1775.52167  0.26%     -   52s
# H    0     0                    1772.0000000 1775.52167  0.20%     -   53s
# H    0     0                    1774.0000000 1775.52167  0.09%     -   54s
#      0     0 1775.52041    0  163 1774.00000 1775.52041  0.09%     -   54s
#      0     0 1775.52041    0  163 1774.00000 1775.52041  0.09%     -   55s
#      0     0 1775.36439    0  123 1774.00000 1775.36439  0.08%     -   62s
#      0     0 1775.33038    0  118 1774.00000 1775.33038  0.07%     -   65s
#      0     0 1775.33038    0  116 1774.00000 1775.33038  0.07%     -   67s
#      0     0 1775.32961    0  103 1774.00000 1775.32961  0.07%     -   72s
#      0     0 1775.32961    0  104 1774.00000 1775.32961  0.07%     -   75s
#      0     0 1775.32770    0   91 1774.00000 1775.32770  0.07%     -   83s
#      0     0 1775.32770    0   90 1774.00000 1775.32770  0.07%     -   86s
#      0     0 1775.32770    0   87 1774.00000 1775.32770  0.07%     -   89s
# H    0     0                    1775.0000000 1775.32770  0.02%     -   93s
#      0     0 1775.32770    0   87 1775.00000 1775.32770  0.02%     -   93s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 10
#   MIR: 29
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (5989 simplex iterations) in 93.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 7: 1775 1774 1772 ... 1736
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.775000000000e+03, best bound 1.775000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2.5x2

# %%
datafile="3x2000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xcb263e6d
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1733.0000000
# Presolve removed 10 rows and 3 columns (presolve time = 6s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 15s) ...
# Sparsify removed 1930075 nonzeros (32%)
# Presolve added 0 rows and 103 columns
# Presolve removed 22 rows and 0 columns
# Presolve time: 19.16s
# Presolved: 7978 rows, 6103 columns, 4072868 nonzeros
# Variable types: 106 continuous, 5997 integer (5997 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.303226e+06   0.000000e+00     21s
#     1632    1.7738511e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.773851e+03, 1632 iterations, 1.69 seconds
# Total elapsed time = 25.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1773.85110    0  231 1733.00000 1773.85110  2.36%     -   26s
# H    0     0                    1759.0000000 1773.85110  0.84%     -   26s
# H    0     0                    1769.0000000 1773.85110  0.27%     -   26s
# H    0     0                    1771.0000000 1773.85110  0.16%     -   27s
#      0     0 1773.71829    0  226 1771.00000 1773.71829  0.15%     -   30s
# H    0     0                    1772.0000000 1773.71829  0.10%     -   33s
#      0     0 1773.48810    0  218 1772.00000 1773.48810  0.08%     -   34s
#      0     0 1773.48760    0  218 1772.00000 1773.48760  0.08%     -   35s
#      0     0 1773.48601    0  211 1772.00000 1773.48601  0.08%     -   36s
#      0     0 1773.48582    0  210 1772.00000 1773.48582  0.08%     -   37s
#      0     0 1773.33618    0  156 1772.00000 1773.33618  0.08%     -   40s
#      0     0 1773.32685    0  136 1772.00000 1773.32685  0.07%     -   42s
#      0     0 1773.32685    0  137 1772.00000 1773.32685  0.07%     -   43s
#      0     0 1773.32685    0  128 1772.00000 1773.32685  0.07%     -   46s
#      0     0 1773.32685    0  133 1772.00000 1773.32685  0.07%     -   47s
#      0     0 1773.32685    0  143 1772.00000 1773.32685  0.07%     -   50s
#      0     0 1773.32685    0  152 1772.00000 1773.32685  0.07%     -   52s
#      0     0 1773.30167    0   96 1772.00000 1773.30167  0.07%     -   57s
#      0     0 1773.26421    0  109 1772.00000 1773.26421  0.07%     -   59s
#      0     0 1773.26421    0  109 1772.00000 1773.26421  0.07%     -   60s
#      0     0 1773.26421    0  106 1772.00000 1773.26421  0.07%     -   63s
#      0     0 1773.21156    0  111 1772.00000 1773.21156  0.07%     -   65s
#      0     0 1773.21156    0  114 1772.00000 1773.21156  0.07%     -   66s
#      0     0 1773.21156    0  113 1772.00000 1773.21156  0.07%     -   69s
#      0     0 1773.21156    0  126 1772.00000 1773.21156  0.07%     -   70s
#      0     0 1773.21156    0  118 1772.00000 1773.21156  0.07%     -   72s
#      0     0 1773.21156    0  111 1772.00000 1773.21156  0.07%     -   73s
#      0     0 1773.21156    0   85 1772.00000 1773.21156  0.07%     -   80s
#      0     0 1773.21156    0   97 1772.00000 1773.21156  0.07%     -   81s
#      0     0 1773.21156    0   97 1772.00000 1773.21156  0.07%     -   87s
#      0     0 1773.21156    0  105 1772.00000 1773.21156  0.07%     -   88s
#      0     0 1773.21156    0   76 1772.00000 1773.21156  0.07%     -   95s
#      0     0 1773.21156    0   87 1772.00000 1773.21156  0.07%     -   98s
#      0     0 1773.21156    0   97 1772.00000 1773.21156  0.07%     -  102s
#      0     0 1773.21156    0   97 1772.00000 1773.21156  0.07%     -  104s
#      0     2 1773.21156    0   76 1772.00000 1773.21156  0.07%     -  112s
#      7    14 1773.21156    3   86 1772.00000 1773.21156  0.07%   251  116s
# H   31    36                    1773.0000000 1773.21156  0.01%  93.3  121s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 5
#   MIR: 150
#   StrongCG: 6
#
# Explored 37 nodes (21821 simplex iterations) in 121.75 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1773 1772 1771 ... 1733
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.773000000000e+03, best bound 1.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2.5x3

# %%
datafile="3x2000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x97d11041
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1731.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 8s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1924114 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 26 rows and 0 columns
# Presolve time: 18.73s
# Presolved: 7974 rows, 6100 columns, 4072844 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.267372e+06   0.000000e+00     20s
#     1570    1.7756287e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.775629e+03, 1570 iterations, 2.06 seconds
# Total elapsed time = 25.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1775.62868    0  230 1731.00000 1775.62868  2.58%     -   26s
# H    0     0                    1768.0000000 1775.62868  0.43%     -   26s
# H    0     0                    1772.0000000 1775.62868  0.20%     -   26s
# H    0     0                    1773.0000000 1775.62868  0.15%     -   27s
#      0     0 1775.60358    0  224 1773.00000 1775.60358  0.15%     -   31s
# H    0     0                    1774.0000000 1775.60358  0.09%     -   33s
#      0     0 1775.40539    0  231 1774.00000 1775.40539  0.08%     -   34s
#      0     0 1775.36754    0  224 1774.00000 1775.36754  0.08%     -   35s
#      0     0 1775.36731    0  220 1774.00000 1775.36731  0.08%     -   36s
#      0     0 1775.36731    0  222 1774.00000 1775.36731  0.08%     -   37s
#      0     0 1775.34903    0  166 1774.00000 1775.34903  0.08%     -   41s
#      0     0 1775.34652    0  148 1774.00000 1775.34652  0.08%     -   43s
#      0     0 1775.30015    0  149 1774.00000 1775.30015  0.07%     -   44s
#      0     0 1775.26869    0  142 1774.00000 1775.26869  0.07%     -   45s
#      0     0 1775.26869    0  147 1774.00000 1775.26869  0.07%     -   46s
#      0     0 1775.03662    0  140 1774.00000 1775.03662  0.06%     -   50s
#      0     0 1775.03652    0  134 1774.00000 1775.03652  0.06%     -   52s
#      0     0     cutoff    0      1774.00000 1774.00000  0.00%     -   56s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 1
#   Implied bound: 1
#   MIR: 206
#   StrongCG: 2
#   RLT: 2
#
# Explored 1 nodes (5017 simplex iterations) in 56.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1774 1773 1772 ... 1731
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.774000000000e+03, best bound 1.774000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2.5x4

# %%
datafile="3x2000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x95a78ae1
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1733.0000000
# Presolve removed 27 rows and 18 columns (presolve time = 8s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 15s) ...
# Sparsify removed 1945949 nonzeros (33%)
# Presolve added 0 rows and 89 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 18.72s
# Presolved: 7962 rows, 6089 columns, 4027050 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.240063e+06   0.000000e+00     20s
#     1556    1.7765090e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.776509e+03, 1556 iterations, 1.78 seconds
# Total elapsed time = 25.35s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1776.50896    0  125 1733.00000 1776.50896  2.51%     -   26s
# H    0     0                    1772.0000000 1776.50896  0.25%     -   26s
# H    0     0                    1773.0000000 1776.50896  0.20%     -   26s
#      0     0 1776.50196    0  121 1773.00000 1776.50196  0.20%     -   30s
# H    0     0                    1775.0000000 1776.50196  0.08%     -   32s
#      0     0 1776.49831    0  124 1775.00000 1776.49831  0.08%     -   33s
#      0     0 1776.49831    0  126 1775.00000 1776.49831  0.08%     -   33s
#      0     0 1776.25574    0  103 1775.00000 1776.25574  0.07%     -   37s
#      0     0 1776.25574    0   99 1775.00000 1776.25574  0.07%     -   38s
#      0     0 1776.09580    0   95 1775.00000 1776.09580  0.06%     -   41s
#      0     0 1776.09580    0   92 1775.00000 1776.09580  0.06%     -   43s
#      0     0 1776.09580    0   93 1775.00000 1776.09580  0.06%     -   46s
#      0     0 1776.09580    0   93 1775.00000 1776.09580  0.06%     -   47s
#      0     0 1776.09580    0   62 1775.00000 1776.09580  0.06%     -   54s
#      0     0 1776.09580    0   60 1775.00000 1776.09580  0.06%     -   55s
#      0     0 1776.09580    0   60 1775.00000 1776.09580  0.06%     -   63s
#      0     0 1776.09580    0   68 1775.00000 1776.09580  0.06%     -   64s
#      0     0 1776.09580    0   60 1775.00000 1776.09580  0.06%     -   68s
#      0     0 1776.09580    0   66 1775.00000 1776.09580  0.06%     -   70s
#      0     0 1776.09515    0   71 1775.00000 1776.09515  0.06%     -   75s
#      0     0 1776.09515    0   75 1775.00000 1776.09515  0.06%     -   76s
#      0     0 1776.09515    0   79 1775.00000 1776.09515  0.06%     -   79s
#      0     0 1776.09515    0   62 1775.00000 1776.09515  0.06%     -   82s
#      0     2 1776.09515    0   57 1775.00000 1776.09515  0.06%     -   90s
#     31    37 1776.09515    7   67 1775.00000 1776.09515  0.06%  28.9   98s
#     49    71 1776.09444    9   69 1775.00000 1776.09515  0.06%  21.1  100s
#     81   160 1776.09444   12   70 1775.00000 1776.09515  0.06%  16.3  106s
#    177   241 1776.08323   23   58 1775.00000 1776.09515  0.06%  10.5  117s
#    271   547 1776.07993   28   60 1775.00000 1776.09515  0.06%   8.8  131s
#    583   953 1776.07700   75   42 1775.00000 1776.09515  0.06%   6.3  148s
#   1014   997 1776.01583   84   52 1775.00000 1776.09515  0.06%   5.0  166s
#   1092  1397 1776.01583   85   52 1775.00000 1776.09515  0.06%   5.0  183s
#   1561  1908 1776.07404   59   58 1775.00000 1776.09515  0.06%   4.5  201s
#   2171  2302 1776.00962  107   44 1775.00000 1776.09515  0.06%   4.3  216s
#   2649  2303 1776.08652   18   62 1775.00000 1776.09515  0.06%   4.2  283s
#   2651  2304 1775.99936  265  109 1775.00000 1776.09515  0.06%   4.2  298s
#   2652  2305 1776.06704  158   75 1775.00000 1776.09515  0.06%   4.1  312s
#   2654  2306 1776.02275   60   76 1775.00000 1776.02275  0.06%   4.1  318s
#   2655  2307 1776.00814  151   54 1775.00000 1776.01914  0.06%   4.1  327s
#   2656  2308 1776.01914   64   62 1775.00000 1776.01914  0.06%   4.1  331s
#   2657  2308 1776.01072  122   64 1775.00000 1776.01708  0.06%   4.1  339s
#   2658  2309 1776.01444   53   50 1775.00000 1776.01444  0.06%   4.1  340s
#   2660  2310 1776.01444   24   44 1775.00000 1776.01444  0.06%   4.1  355s
#   2661  2311 1776.01444   16   60 1775.00000 1776.01444  0.06%   4.1  362s
#   2662  2312 1775.99998  260   36 1775.00000 1776.01444  0.06%   4.1  376s
#   2663  2312 1776.01444   54   44 1775.00000 1776.01444  0.06%   4.1  385s
#   2664  2313 1776.01444   43   41 1775.00000 1776.01444  0.06%   4.1  399s
#   2665  2314 1775.99998  226   39 1775.00000 1776.01444  0.06%   4.1  408s
#   2666  2314 1776.01444   37   31 1775.00000 1776.01444  0.06%   4.1  419s
#   2667  2315 1776.00070  189   33 1775.00000 1776.01444  0.06%   4.1  423s
#   2668  2316 1776.01444   89   30 1775.00000 1776.01444  0.06%   4.1  432s
#   2669  2316 1776.01444   41   30 1775.00000 1776.01444  0.06%   4.1  441s
#   2670  2317 1776.00070  243   36 1775.00000 1776.01444  0.06%   4.1  452s
#   2671  2318 1775.99996  274   47 1775.00000 1776.01444  0.06%   4.1  460s
#   2672  2318 1776.01444   74   35 1775.00000 1776.01444  0.06%   4.1  470s
#   2675  2322 1776.01444  118   62 1775.00000 1776.01444  0.06%  14.2  564s
#   2677  2323 1776.01444   36   75 1775.00000 1776.01444  0.06%  14.1  565s
#
# Cutting planes:
#   Gomory: 34
#   Cover: 5
#   MIR: 24
#   StrongCG: 4
#   Flow cover: 58
#   GUB cover: 4
#   Zero half: 1
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 2682 nodes (63366 simplex iterations) in 566.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1775 1773 1772 1733
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.775000000000e+03, best bound 1.775000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x2.5x5

# %%
datafile="3x2000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x0d04ecb2
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1724.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1924114 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 53 rows and 0 columns
# Presolve time: 16.15s
# Presolved: 7947 rows, 6100 columns, 4072751 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.316268e+06   0.000000e+00     18s
#     1396    1.7728869e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.772887e+03, 1396 iterations, 1.41 seconds
# Total elapsed time = 20.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1772.88692    0   66 1724.00000 1772.88692  2.84%     -   23s
# H    0     0                    1771.0000000 1772.88692  0.11%     -   24s
#      0     0 1772.85459    0   61 1771.00000 1772.85459  0.10%     -   27s
# H    0     0                    1772.0000000 1772.85459  0.05%     -   30s
#      0     0 1772.85459    0   61 1772.00000 1772.85459  0.05%     -   30s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 2
#   MIR: 13
#   StrongCG: 5
#
# Explored 1 nodes (5082 simplex iterations) in 30.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1772 1771 1724
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.772000000000e+03, best bound 1.772000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3x1

# %%
datafile="3x2000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xd117c478
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1543.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1933904 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 29 rows and 0 columns
# Presolve time: 18.98s
# Presolved: 7971 rows, 6100 columns, 4063051 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.374895e+06   0.000000e+00     21s
#     1608    1.6104540e+03   0.000000e+00   0.000000e+00     23s
#
# Root relaxation: objective 1.610454e+03, 1608 iterations, 2.32 seconds
# Total elapsed time = 25.45s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1610.45404    0   88 1543.00000 1610.45404  4.37%     -   26s
# H    0     0                    1607.0000000 1610.45404  0.21%     -   26s
# H    0     0                    1608.0000000 1610.45404  0.15%     -   27s
#      0     0 1610.44652    0   80 1608.00000 1610.44652  0.15%     -   29s
# H    0     0                    1609.0000000 1610.44652  0.09%     -   32s
#      0     0 1610.43465    0   86 1609.00000 1610.43465  0.09%     -   32s
#      0     0 1610.43465    0   86 1609.00000 1610.43465  0.09%     -   33s
#      0     0 1610.33514    0   66 1609.00000 1610.33514  0.08%     -   36s
#      0     0 1610.26154    0   58 1609.00000 1610.26154  0.08%     -   37s
#      0     0 1610.26154    0   58 1609.00000 1610.26154  0.08%     -   38s
#      0     0 1610.26154    0   52 1609.00000 1610.26154  0.08%     -   41s
# H    0     0                    1610.0000000 1610.26154  0.02%     -   42s
#      0     0 1610.26154    0   52 1610.00000 1610.26154  0.02%     -   42s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 3
#   MIR: 24
#   StrongCG: 4
#
# Explored 1 nodes (6300 simplex iterations) in 43.04 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1610 1609 1608 ... 1543
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.610000000000e+03, best bound 1.610000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3x2

# %%
datafile="3x2000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xc1fd9635
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1550.0000000
# Presolve removed 35 rows and 15 columns (presolve time = 7s) ...
# Presolve removed 35 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 35 rows and 15 columns (presolve time = 15s) ...
# Sparsify removed 1937273 nonzeros (32%)
# Presolve added 0 rows and 92 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 16.04s
# Presolved: 7962 rows, 6092 columns, 4041688 nonzeros
# Variable types: 107 continuous, 5985 integer (5985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.355501e+06   0.000000e+00     18s
#     1866    1.6557157e+03   2.081704e+05   0.000000e+00     20s
#     2955    1.6156642e+03   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.615664e+03, 2955 iterations, 4.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1615.66416    0   54 1550.00000 1615.66416  4.24%     -   24s
# H    0     0                    1613.0000000 1615.66416  0.17%     -   24s
#      0     0 1615.56636    0   43 1613.00000 1615.56636  0.16%     -   28s
# H    0     0                    1615.0000000 1615.56636  0.04%     -   29s
#      0     0 1615.56636    0   43 1615.00000 1615.56636  0.04%     -   29s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   MIR: 9
#
# Explored 1 nodes (4367 simplex iterations) in 29.29 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1615 1613 1550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.615000000000e+03, best bound 1.615000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3x3

# %%
datafile="3x2000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x024812ce
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1555.0000000
# Presolve removed 36 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 36 rows and 18 columns (presolve time = 11s) ...
# Presolve removed 36 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 36 rows and 18 columns (presolve time = 20s) ...
# Sparsify removed 1950813 nonzeros (33%)
# Presolve added 0 rows and 89 columns
# Presolve removed 51 rows and 0 columns
# Presolve time: 23.83s
# Presolved: 7949 rows, 6089 columns, 4022115 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.368582e+06   0.000000e+00     26s
#     2673    1.6155479e+03   0.000000e+00   0.000000e+00     29s
#
# Root relaxation: objective 1.615548e+03, 2673 iterations, 3.58 seconds
# Total elapsed time = 30.12s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1615.54791    0  116 1555.00000 1615.54791  3.89%     -   32s
# H    0     0                    1612.0000000 1615.54791  0.22%     -   33s
# H    0     0                    1613.0000000 1615.54791  0.16%     -   33s
#      0     0 1615.47201    0  123 1613.00000 1615.47201  0.15%     -   37s
# H    0     0                    1614.0000000 1615.47201  0.09%     -   39s
#      0     0 1615.42636    0  114 1614.00000 1615.42636  0.09%     -   40s
#      0     0 1615.37628    0  114 1614.00000 1615.37628  0.09%     -   41s
#      0     0 1615.37628    0  116 1614.00000 1615.37628  0.09%     -   41s
#      0     0 1615.08670    0  101 1614.00000 1615.08670  0.07%     -   45s
#      0     0 1615.08458    0   79 1614.00000 1615.08458  0.07%     -   46s
#      0     0 1615.08458    0   77 1614.00000 1615.08458  0.07%     -   47s
#      0     0 1615.08458    0   76 1614.00000 1615.08458  0.07%     -   50s
#      0     0 1615.08458    0   75 1614.00000 1615.08458  0.07%     -   51s
#      0     0 1615.08458    0   64 1614.00000 1615.08458  0.07%     -   54s
#      0     0 1615.08458    0   67 1614.00000 1615.08458  0.07%     -   55s
#      0     0 1615.08458    0   58 1614.00000 1615.08458  0.07%     -   59s
#      0     0 1615.08458    0   58 1614.00000 1615.08458  0.07%     -   61s
#      0     0 1615.08458    0   62 1614.00000 1615.08458  0.07%     -   66s
#      0     0 1615.08458    0   60 1614.00000 1615.08458  0.07%     -   67s
#      0     0 1615.08458    0   52 1614.00000 1615.08458  0.07%     -   72s
#      0     0 1615.08456    0   62 1614.00000 1615.08456  0.07%     -   73s
#      0     0 1615.08453    0   52 1614.00000 1615.08453  0.07%     -   78s
#      0     0 1615.08019    0   68 1614.00000 1615.08019  0.07%     -   79s
#      0     0 1615.08019    0   72 1614.00000 1615.08019  0.07%     -   80s
#      0     0 1615.08013    0   78 1614.00000 1615.08013  0.07%     -   82s
#      0     0 1615.08011    0   67 1614.00000 1615.08011  0.07%     -   84s
#      0     0 1615.08000    0   59 1614.00000 1615.08000  0.07%     -   86s
#      0     0 1615.08000    0   66 1614.00000 1615.08000  0.07%     -   88s
#      0     0 1615.08000    0   60 1614.00000 1615.08000  0.07%     -   90s
#      0     0 1615.08000    0   58 1614.00000 1615.08000  0.07%     -   90s
#      0     0 1615.08000    0   58 1614.00000 1615.08000  0.07%     -   94s
#      0     0 1615.08000    0   55 1614.00000 1615.08000  0.07%     -   95s
#      0     0 1615.08000    0   49 1614.00000 1615.08000  0.07%     -   99s
#      0     0 1615.08000    0   52 1614.00000 1615.08000  0.07%     -  101s
#      0     0 1615.08000    0   64 1614.00000 1615.08000  0.07%     -  104s
#      0     0 1615.08000    0   64 1614.00000 1615.08000  0.07%     -  106s
#      0     0 1615.08000    0  117 1614.00000 1615.08000  0.07%     -  121s
#      0     0 1615.08000    0   57 1614.00000 1615.08000  0.07%     -  123s
#      0     0 1615.08000    0   62 1614.00000 1615.08000  0.07%     -  124s
#      0     0 1615.08000    0   62 1614.00000 1615.08000  0.07%     -  125s
#      0     0 1615.02714    0   94 1614.00000 1615.02714  0.06%     -  126s
#      0     0 1615.02701    0   77 1614.00000 1615.02701  0.06%     -  127s
#      0     0 1615.02606    0   70 1614.00000 1615.02606  0.06%     -  129s
#      0     0 1615.02606    0   63 1614.00000 1615.02606  0.06%     -  130s
#      0     0 1615.02606    0   63 1614.00000 1615.02606  0.06%     -  132s
#      0     0 1615.02606    0   66 1614.00000 1615.02606  0.06%     -  132s
#      0     0 1615.02606    0   52 1614.00000 1615.02606  0.06%     -  136s
#      0     0 1615.02606    0   60 1614.00000 1615.02606  0.06%     -  137s
#      0     0 1615.02606    0   50 1614.00000 1615.02606  0.06%     -  140s
#      0     0 1615.02606    0   56 1614.00000 1615.02606  0.06%     -  141s
#      0     0 1615.02588    0   52 1614.00000 1615.02588  0.06%     -  143s
#      0     0 1615.02581    0   50 1614.00000 1615.02581  0.06%     -  145s
#      0     0 1615.02515    0   41 1614.00000 1615.02515  0.06%     -  147s
#      0     0 1615.02515    0   42 1614.00000 1615.02515  0.06%     -  147s
#      0     0 1615.02515    0   37 1614.00000 1615.02515  0.06%     -  149s
#      0     0 1615.02515    0   38 1614.00000 1615.02515  0.06%     -  149s
#      0     0 1615.02515    0   32 1614.00000 1615.02515  0.06%     -  153s
#      0     0 1615.02515    0   44 1614.00000 1615.02515  0.06%     -  154s
#      0     0 1615.02515    0   34 1614.00000 1615.02515  0.06%     -  156s
#      0     0 1615.02515    0   34 1614.00000 1615.02515  0.06%     -  159s
#      0     2 1615.02515    0   34 1614.00000 1615.02515  0.06%     -  163s
#      7    14 1615.02258    3   38 1614.00000 1615.02448  0.06%   162  165s
#     65    77 1615.02150   11   42 1614.00000 1615.02194  0.06%  25.3  170s
#    154   266 1615.01833   22   34 1614.00000 1615.02194  0.06%  14.1  178s
#    331   515 1615.00297   46   28 1614.00000 1615.02194  0.06%   9.2  187s
#    658   739 1615.00055   81   29 1614.00000 1615.02150  0.06%   7.2  198s
#    985  1007 1615.00297   33   26 1614.00000 1615.02150  0.06%   7.0  209s
#   1323  1008 1615.00175   17   64 1614.00000 1615.02150  0.06%   6.6  258s
#   1325  1009 1615.00175   17   98 1614.00000 1615.02150  0.06%   6.5  277s
#   1328  1011 1615.00304   37   72 1614.00000 1615.02150  0.06%   6.5  292s
#   1330  1013 1614.99995   69   61 1614.00000 1615.02150  0.06%   6.5  306s
#   1334  1015 1615.00175   21   55 1614.00000 1615.00704  0.06%   6.5  315s
#   1335  1016 1615.00297   18   41 1614.00000 1615.00704  0.06%   6.5  328s
#   1336  1017 1615.00704   23   47 1614.00000 1615.00704  0.06%   6.5  352s
#   1338  1018 1615.00306   40   50 1614.00000 1615.00704  0.06%   6.5  360s
#   1339  1019 1615.00175   21   44 1614.00000 1615.00704  0.06%   6.5  382s
#   1340  1019 1615.00306   38   55 1614.00000 1615.00704  0.06%   6.5  396s
#   1341  1020 1615.00139   40   52 1614.00000 1615.00704  0.06%   6.5  403s
#   1342  1021 1615.00297   30   48 1614.00000 1615.00704  0.06%   6.5  412s
#   1343  1021 1615.00704   19   37 1614.00000 1615.00704  0.06%   6.5  430s
#   1345  1023 1615.00175   34   40 1614.00000 1615.00704  0.06%   6.4  440s
#   1347  1024 1614.99995   46   42 1614.00000 1615.00704  0.06%   6.4  448s
#   1348  1025 1615.00143   44   41 1614.00000 1615.00704  0.06%   6.4  452s
#   1349  1025 1615.00704   44   41 1614.00000 1615.00704  0.06%   6.4  458s
#   1350  1028 1615.00704   14   37 1614.00000 1615.00704  0.06%  19.1  461s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 1
#   MIR: 7
#   Flow cover: 7
#
# Explored 1369 nodes (56058 simplex iterations) in 462.62 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1614 1613 1612 1555
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.614000000000e+03, best bound 1.614000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3x4

# %%
datafile="3x2000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x39ee37a0
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1555.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Sparsify removed 1924114 nonzeros (32%)
# Presolve added 0 rows and 100 columns
# Presolve removed 35 rows and 0 columns
# Presolve time: 16.69s
# Presolved: 7965 rows, 6100 columns, 4072826 nonzeros
# Variable types: 106 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.366109e+06   0.000000e+00     18s
#     1515    1.6098934e+03   6.386599e+02   0.000000e+00     20s
#     1737    1.6098462e+03   0.000000e+00   0.000000e+00     20s
#
# Root relaxation: objective 1.609846e+03, 1737 iterations, 2.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1609.84622    0  133 1555.00000 1609.84622  3.53%     -   24s
# H    0     0                    1606.0000000 1609.84622  0.24%     -   24s
# H    0     0                    1608.0000000 1609.84622  0.11%     -   25s
# H    0     0                    1609.0000000 1609.84622  0.05%     -   25s
#      0     0 1609.84622    0  133 1609.00000 1609.84622  0.05%     -   25s
#
# Explored 1 nodes (6596 simplex iterations) in 25.46 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1609 1608 1606 1555
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.609000000000e+03, best bound 1.609000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3x5

# %%
datafile="3x2000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x8142d5c9
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1540.0000000
# Presolve removed 27 rows and 18 columns (presolve time = 5s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 14s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 27 rows and 18 columns (presolve time = 30s) ...
# Sparsify removed 1981677 nonzeros (33%)
# Presolve added 0 rows and 90 columns
# Presolve removed 51 rows and 0 columns
# Presolve time: 32.57s
# Presolved: 7949 rows, 6090 columns, 3991281 nonzeros
# Variable types: 108 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.384593e+06   0.000000e+00     35s
#     3183    1.6026701e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: objective 1.602670e+03, 3183 iterations, 4.91 seconds
# Total elapsed time = 40.81s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1602.67010    0  105 1540.00000 1602.67010  4.07%     -   42s
# H    0     0                    1599.0000000 1602.67010  0.23%     -   42s
#      0     0 1602.59554    0  109 1599.00000 1602.59554  0.22%     -   45s
# H    0     0                    1600.0000000 1602.59554  0.16%     -   46s
# H    0     0                    1601.0000000 1602.59554  0.10%     -   47s
#      0     0 1602.28998    0  101 1601.00000 1602.28998  0.08%     -   47s
#      0     0 1602.28682    0   83 1601.00000 1602.28682  0.08%     -   48s
#      0     0 1602.28682    0   90 1601.00000 1602.28682  0.08%     -   49s
#      0     0 1602.22031    0   73 1601.00000 1602.22031  0.08%     -   52s
#      0     0 1602.21253    0   66 1601.00000 1602.21253  0.08%     -   54s
#      0     0 1602.21253    0   70 1601.00000 1602.21253  0.08%     -   55s
#      0     0 1602.19196    0   65 1601.00000 1602.19196  0.07%     -   58s
#      0     0 1602.11129    0   57 1601.00000 1602.11129  0.07%     -   59s
#      0     0 1602.11101    0   66 1601.00000 1602.11101  0.07%     -   60s
#      0     0 1602.11101    0   76 1601.00000 1602.11101  0.07%     -   61s
#      0     0 1602.11101    0   76 1601.00000 1602.11101  0.07%     -   64s
#      0     0 1602.11034    0   78 1601.00000 1602.11034  0.07%     -   65s
#      0     0 1602.10931    0   77 1601.00000 1602.10931  0.07%     -   65s
#      0     0 1602.10924    0   78 1601.00000 1602.10924  0.07%     -   66s
#      0     0 1602.09646    0   65 1601.00000 1602.09646  0.07%     -   69s
#      0     0 1602.09646    0   60 1601.00000 1602.09646  0.07%     -   70s
#      0     0 1602.09646    0   51 1601.00000 1602.09646  0.07%     -   73s
#      0     0 1602.09646    0   49 1601.00000 1602.09646  0.07%     -   74s
#      0     0 1602.09646    0   48 1601.00000 1602.09646  0.07%     -   78s
#      0     0 1602.08783    0   53 1601.00000 1602.08783  0.07%     -   79s
#      0     0 1602.08783    0   60 1601.00000 1602.08783  0.07%     -   80s
#      0     0 1602.06278    0   33 1601.00000 1602.06278  0.07%     -   85s
#      0     0 1602.06278    0   42 1601.00000 1602.06278  0.07%     -   87s
#      0     0 1602.05208    0   35 1601.00000 1602.05208  0.07%     -   89s
#      0     0 1602.05208    0   30 1601.00000 1602.05208  0.07%     -   91s
#      0     0 1602.05208    0   33 1601.00000 1602.05208  0.07%     -   93s
#      0     0 1602.00977    0   32 1601.00000 1602.00977  0.06%     -   94s
#      0     0 1602.00977    0   32 1601.00000 1602.00977  0.06%     -   95s
#      0     0 1602.00977    0   32 1601.00000 1602.00977  0.06%     -   99s
#      0     0 1602.00977    0   34 1601.00000 1602.00977  0.06%     -  100s
#      0     0 1602.00977    0   35 1601.00000 1602.00977  0.06%     -  103s
#      0     0 1602.00977    0   37 1601.00000 1602.00977  0.06%     -  104s
#      0     0 1602.00977    0   20 1601.00000 1602.00977  0.06%     -  107s
#      0     0 1602.00977    0   24 1601.00000 1602.00977  0.06%     -  109s
#      0     0 1602.00977    0   25 1601.00000 1602.00977  0.06%     -  113s
#      0     0 1602.00977    0   37 1601.00000 1602.00977  0.06%     -  114s
#      0     0 1602.00977    0   24 1601.00000 1602.00977  0.06%     -  119s
#      0     0 1602.00977    0   20 1601.00000 1602.00977  0.06%     -  121s
#      0     0 1602.00977    0   81 1601.00000 1602.00977  0.06%     -  135s
#      0     0 1602.00977    0   57 1601.00000 1602.00977  0.06%     -  137s
#      0     0 1602.00977    0   48 1601.00000 1602.00977  0.06%     -  138s
#      0     0 1602.00977    0   46 1601.00000 1602.00977  0.06%     -  138s
#      0     0 1602.00977    0   55 1601.00000 1602.00977  0.06%     -  139s
#      0     0 1602.00977    0   36 1601.00000 1602.00977  0.06%     -  140s
#      0     0 1602.00977    0   45 1601.00000 1602.00977  0.06%     -  141s
#      0     0 1602.00977    0   47 1601.00000 1602.00977  0.06%     -  142s
#      0     0 1602.00977    0   27 1601.00000 1602.00977  0.06%     -  145s
#      0     0 1602.00977    0   42 1601.00000 1602.00977  0.06%     -  146s
#      0     0 1602.00977    0   23 1601.00000 1602.00977  0.06%     -  149s
#      0     0 1602.00977    0   25 1601.00000 1602.00977  0.06%     -  150s
#      0     0 1602.00977    0   29 1601.00000 1602.00977  0.06%     -  152s
#      0     0 1602.00977    0   28 1601.00000 1602.00977  0.06%     -  153s
#      0     0 1602.00977    0   34 1601.00000 1602.00977  0.06%     -  156s
#      0     0 1602.00977    0   41 1601.00000 1602.00977  0.06%     -  157s
#      0     0 1602.00977    0   25 1601.00000 1602.00977  0.06%     -  159s
#      0     0 1602.00977    0   28 1601.00000 1602.00977  0.06%     -  160s
#      0     0 1602.00977    0   28 1601.00000 1602.00977  0.06%     -  162s
#      0     0 1602.00977    0   29 1601.00000 1602.00977  0.06%     -  163s
#      0     0 1602.00977    0   26 1601.00000 1602.00977  0.06%     -  166s
#      0     0 1602.00977    0   26 1601.00000 1602.00977  0.06%     -  167s
#      0     2 1602.00977    0   26 1601.00000 1602.00977  0.06%     -  172s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 10
#   MIR: 23
#   StrongCG: 2
#
# Explored 7 nodes (26020 simplex iterations) in 172.95 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1601 1600 1599 1540
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.601000000000e+03, best bound 1.601000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3.5x1

# %%
datafile="3x2000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x0c181bd6
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1408.0000000
# Presolve removed 33 rows and 18 columns (presolve time = 7s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 15s) ...
# Sparsify removed 1945949 nonzeros (33%)
# Presolve added 0 rows and 89 columns
# Presolve removed 39 rows and 0 columns
# Presolve time: 15.94s
# Presolved: 7961 rows, 6089 columns, 4027039 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.440994e+06   0.000000e+00     17s
#     1947    1.4721852e+03   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 1.472185e+03, 1947 iterations, 2.05 seconds
# Total elapsed time = 20.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1472.18521    0  227 1408.00000 1472.18521  4.56%     -   23s
# H    0     0                    1469.0000000 1472.18521  0.22%     -   24s
#      0     0 1472.17722    0  238 1469.00000 1472.17722  0.22%     -   29s
# H    0     0                    1470.0000000 1472.17722  0.15%     -   29s
# H    0     0                    1471.0000000 1472.17722  0.08%     -   31s
#      0     0 1472.13921    0  241 1471.00000 1472.13921  0.08%     -   31s
#      0     0 1472.09214    0  247 1471.00000 1472.09214  0.07%     -   33s
#      0     0 1472.09209    0  254 1471.00000 1472.09209  0.07%     -   33s
#      0     0 1472.04923    0  206 1471.00000 1472.04923  0.07%     -   38s
#      0     0     cutoff    0      1471.00000 1471.00000  0.00%     -   39s
#
# Cutting planes:
#   Gomory: 27
#   Cover: 2
#   Implied bound: 3
#   MIR: 120
#   StrongCG: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (7679 simplex iterations) in 39.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1471 1470 1469 1408
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.471000000000e+03, best bound 1.471000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3.5x2

# %%
datafile="3x2000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xf8f53bcb
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1431.0000000
# Presolve removed 44 rows and 24 columns (presolve time = 7s) ...
# Presolve removed 44 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 44 rows and 24 columns (presolve time = 15s) ...
# Sparsify removed 1950372 nonzeros (33%)
# Presolve added 0 rows and 84 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 16.41s
# Presolved: 7953 rows, 6084 columns, 4010643 nonzeros
# Variable types: 108 continuous, 5976 integer (5976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9920000e+03   1.380637e+06   0.000000e+00     18s
#     1493    1.4959400e+03   2.794714e+02   0.000000e+00     20s
#     1750    1.4959015e+03   0.000000e+00   0.000000e+00     20s
#
# Root relaxation: objective 1.495902e+03, 1750 iterations, 2.42 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1495.90151    0  100 1431.00000 1495.90151  4.54%     -   25s
# H    0     0                    1493.0000000 1495.90151  0.19%     -   26s
# H    0     0                    1494.0000000 1495.90151  0.13%     -   26s
#      0     0 1495.27540    0  111 1494.00000 1495.27540  0.09%     -   29s
#      0     0 1495.27480    0  111 1494.00000 1495.27480  0.09%     -   32s
#      0     0 1495.27480    0  116 1494.00000 1495.27480  0.09%     -   33s
#      0     0 1495.26242    0   90 1494.00000 1495.26242  0.08%     -   36s
#      0     0 1495.25877    0   85 1494.00000 1495.25877  0.08%     -   38s
#      0     0 1495.25860    0   81 1494.00000 1495.25860  0.08%     -   39s
#      0     0 1495.25737    0   70 1494.00000 1495.25737  0.08%     -   42s
#      0     0 1495.25737    0   76 1494.00000 1495.25737  0.08%     -   44s
#      0     0 1495.25737    0   73 1494.00000 1495.25737  0.08%     -   47s
#      0     0 1495.25737    0   75 1494.00000 1495.25737  0.08%     -   48s
#      0     0 1495.25737    0   64 1494.00000 1495.25737  0.08%     -   52s
#      0     0 1495.25737    0   74 1494.00000 1495.25737  0.08%     -   53s
#      0     0 1495.25737    0   56 1494.00000 1495.25737  0.08%     -   59s
#      0     0 1495.25737    0   58 1494.00000 1495.25737  0.08%     -   60s
#      0     0 1495.21734    0   58 1494.00000 1495.21734  0.08%     -   64s
#      0     0 1495.17552    0   68 1494.00000 1495.17552  0.08%     -   66s
#      0     0 1495.17551    0   79 1494.00000 1495.17551  0.08%     -   67s
#      0     0 1495.08164    0   78 1494.00000 1495.08164  0.07%     -   69s
#      0     0 1495.08164    0   75 1494.00000 1495.08164  0.07%     -   71s
#      0     0 1495.08164    0   68 1494.00000 1495.08164  0.07%     -   72s
#      0     0 1495.08158    0   78 1494.00000 1495.08158  0.07%     -   73s
#      0     0 1495.08108    0   53 1494.00000 1495.08108  0.07%     -   78s
#      0     0 1495.07961    0   64 1494.00000 1495.07961  0.07%     -   80s
#      0     0 1495.07961    0   67 1494.00000 1495.07961  0.07%     -   81s
#      0     0 1495.07961    0   68 1494.00000 1495.07961  0.07%     -   83s
#      0     0 1495.07961    0   75 1494.00000 1495.07961  0.07%     -   84s
#      0     0 1495.07961    0   69 1494.00000 1495.07961  0.07%     -   86s
#      0     0 1495.07961    0   72 1494.00000 1495.07961  0.07%     -   87s
#      0     0 1495.07961    0   43 1494.00000 1495.07961  0.07%     -   92s
#      0     0 1495.07961    0   57 1494.00000 1495.07961  0.07%     -   94s
#      0     0 1495.07961    0   56 1494.00000 1495.07961  0.07%     -   98s
#      0     0 1495.07961    0   52 1494.00000 1495.07961  0.07%     -  100s
#      0     0 1495.07961    0   94 1494.00000 1495.07961  0.07%     -  115s
#      0     0 1495.07961    0   96 1494.00000 1495.07961  0.07%     -  117s
#      0     0 1495.07961    0   94 1494.00000 1495.07961  0.07%     -  118s
#      0     0 1495.07961    0   90 1494.00000 1495.07961  0.07%     -  119s
#      0     0 1495.07961    0   92 1494.00000 1495.07961  0.07%     -  119s
#      0     0 1495.07961    0   80 1494.00000 1495.07961  0.07%     -  120s
#      0     0 1495.07961    0   82 1494.00000 1495.07961  0.07%     -  121s
#      0     0 1495.07961    0   75 1494.00000 1495.07961  0.07%     -  122s
#      0     0 1495.07961    0   70 1494.00000 1495.07961  0.07%     -  123s
#      0     0 1495.07961    0   62 1494.00000 1495.07961  0.07%     -  126s
#      0     0 1495.07961    0   65 1494.00000 1495.07961  0.07%     -  127s
#      0     0 1495.07961    0   58 1494.00000 1495.07961  0.07%     -  130s
#      0     0 1495.07961    0   56 1494.00000 1495.07961  0.07%     -  131s
#      0     0 1495.07961    0   59 1494.00000 1495.07961  0.07%     -  133s
#      0     0 1495.07961    0   61 1494.00000 1495.07961  0.07%     -  134s
#      0     0 1495.07961    0   69 1494.00000 1495.07961  0.07%     -  136s
#      0     0 1495.07961    0   78 1494.00000 1495.07961  0.07%     -  138s
#      0     0 1495.07961    0   58 1494.00000 1495.07961  0.07%     -  141s
#      0     0 1495.07961    0   58 1494.00000 1495.07961  0.07%     -  143s
#      0     2 1495.07961    0   58 1494.00000 1495.07961  0.07%     -  147s
#     25    32 1495.07282    6   66 1494.00000 1495.07282  0.07%  46.9  150s
#    115   207     cutoff   15      1494.00000 1495.05856  0.07%  13.5  158s
#    217   436 1495.01674   22   47 1494.00000 1495.05856  0.07%   9.7  164s
#    447   758 1495.01104   62   35 1494.00000 1495.05856  0.07%   7.2  173s
#    770  1055 1495.01104  127   27 1494.00000 1495.05856  0.07%   6.2  182s
#   1072  1512 1495.00000  184   18 1494.00000 1495.05856  0.07%   5.7  192s
#   1575  1782 1495.00000  271   16 1494.00000 1495.05856  0.07%   5.2  202s
# H 1597   609                    1495.0000000 1495.05856  0.00%   5.1  202s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 67
#
# Explored 1894 nodes (40823 simplex iterations) in 203.00 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1495 1494 1493 ... 1431
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.495000000000e+03, best bound 1.495000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3.5x3

# %%
datafile="3x2000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x9b994190
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1422.0000000
# Presolve removed 32 rows and 15 columns (presolve time = 7s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 15s) ...
# Sparsify removed 1937273 nonzeros (32%)
# Presolve added 0 rows and 92 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 16.87s
# Presolved: 7953 rows, 6092 columns, 4041673 nonzeros
# Variable types: 107 continuous, 5985 integer (5985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.428622e+06   0.000000e+00     18s
#     1169    1.6326812e+03   3.144091e+05   0.000000e+00     20s
#     3750    1.4840139e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.484014e+03, 3750 iterations, 4.32 seconds
# Total elapsed time = 25.17s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1484.01392    0  136 1422.00000 1484.01392  4.36%     -   26s
# H    0     0                    1481.0000000 1484.01392  0.20%     -   26s
# H    0     0                    1482.0000000 1484.01392  0.14%     -   27s
# H    0     0                    1483.0000000 1484.01392  0.07%     -   27s
#
# Cutting planes:
#   Gomory: 20
#   MIR: 81
#
# Explored 1 nodes (4680 simplex iterations) in 29.56 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1483 1482 1481 1422
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.483000000000e+03, best bound 1.483000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3.5x4

# %%
datafile="3x2000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xc406c4f5
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1406.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 7s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 15s) ...
# Sparsify removed 1945949 nonzeros (33%)
# Presolve added 0 rows and 89 columns
# Presolve removed 36 rows and 0 columns
# Presolve time: 16.44s
# Presolved: 7964 rows, 6089 columns, 4027054 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.430196e+06   0.000000e+00     18s
#     1149    1.4799063e+03   1.328520e+04   0.000000e+00     20s
#     1921    1.4788246e+03   0.000000e+00   0.000000e+00     20s
#
# Root relaxation: objective 1.478825e+03, 1921 iterations, 2.66 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1478.82460    0  244 1406.00000 1478.82460  5.18%     -   24s
# H    0     0                    1475.0000000 1478.82460  0.26%     -   24s
# H    0     0                    1477.0000000 1478.82460  0.12%     -   25s
#      0     0 1478.76453    0  173 1477.00000 1478.76453  0.12%     -   29s
# H    0     0                    1478.0000000 1478.76453  0.05%     -   31s
#      0     0 1478.76453    0  173 1478.00000 1478.76453  0.05%     -   31s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 1
#   MIR: 39
#   RLT: 2
#
# Explored 1 nodes (4396 simplex iterations) in 31.31 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1478 1477 1475 1406
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.478000000000e+03, best bound 1.478000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x3.5x5

# %%
datafile="3x2000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x8022d330
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1422.0000000
# Presolve removed 9 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 15s) ...
# Sparsify removed 1926234 nonzeros (32%)
# Presolve added 0 rows and 106 columns
# Presolve removed 16 rows and 0 columns
# Presolve time: 16.14s
# Presolved: 7984 rows, 6106 columns, 4082731 nonzeros
# Variable types: 106 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+03   1.429931e+06   0.000000e+00     18s
#     1157    1.5662721e+03   2.484604e+05   0.000000e+00     20s
#     2101    1.4916981e+03   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.491698e+03, 2101 iterations, 4.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1491.69813    0   51 1422.00000 1491.69813  4.90%     -   25s
# H    0     0                    1491.0000000 1491.69813  0.05%     -   25s
#      0     0 1491.69813    0   51 1491.00000 1491.69813  0.05%     -   25s
#
# Explored 1 nodes (4238 simplex iterations) in 25.84 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1491 1422
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.491000000000e+03, best bound 1.491000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4x1

# %%
datafile="3x2000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xaaae4cab
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1327.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 15s) ...
# Sparsify removed 1980579 nonzeros (33%)
# Presolve added 0 rows and 87 columns
# Presolve removed 34 rows and 0 columns
# Presolve time: 19.71s
# Presolved: 7966 rows, 6087 columns, 3986442 nonzeros
# Variable types: 108 continuous, 5979 integer (5979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.411371e+06   0.000000e+00     21s
#     2518    1.3934101e+03   2.727826e+01   0.000000e+00     25s
#     2569    1.3932826e+03   0.000000e+00   0.000000e+00     25s
#
# Root relaxation: objective 1.393283e+03, 2569 iterations, 4.16 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1393.28256    0   96 1327.00000 1393.28256  4.99%     -   28s
# H    0     0                    1389.0000000 1393.28256  0.31%     -   28s
# H    0     0                    1390.0000000 1393.28256  0.24%     -   28s
# H    0     0                    1391.0000000 1393.28256  0.16%     -   28s
#      0     0 1393.14102    0  105 1391.00000 1393.14102  0.15%     -   31s
# H    0     0                    1392.0000000 1393.14102  0.08%     -   34s
#      0     0 1393.13365    0  109 1392.00000 1393.13365  0.08%     -   34s
#      0     0 1393.13365    0  116 1392.00000 1393.13365  0.08%     -   35s
#
# Cutting planes:
#   Gomory: 34
#   Cover: 4
#   Implied bound: 6
#   MIR: 135
#   StrongCG: 3
#   GUB cover: 2
#   RLT: 2
#
# Explored 1 nodes (5045 simplex iterations) in 37.54 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1392 1391 1390 ... 1327
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.392000000000e+03, best bound 1.392000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4x2

# %%
datafile="3x2000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x06728309
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1321.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 7s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 15s) ...
# Sparsify removed 1970868 nonzeros (33%)
# Presolve added 0 rows and 87 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 16.86s
# Presolved: 7960 rows, 6087 columns, 3996153 nonzeros
# Variable types: 108 continuous, 5979 integer (5979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.434017e+06   0.000000e+00     18s
#     1148    1.5420701e+03   3.317682e+05   0.000000e+00     20s
#     2661    1.3937775e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.393778e+03, 2661 iterations, 3.96 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1393.77752    0  106 1321.00000 1393.77752  5.51%     -   24s
# H    0     0                    1383.0000000 1393.77752  0.78%     -   25s
# H    0     0                    1390.0000008 1393.77752  0.27%     -   25s
# H    0     0                    1391.0000000 1393.77752  0.20%     -   25s
# H    0     0                    1392.0000000 1393.77752  0.13%     -   26s
#      0     0 1393.63709    0   95 1392.00000 1393.63709  0.12%     -   28s
#      0     0 1393.57824    0  104 1392.00000 1393.57824  0.11%     -   32s
#      0     0 1393.56733    0  100 1392.00000 1393.56733  0.11%     -   32s
#      0     0 1393.47454    0  104 1392.00000 1393.47454  0.11%     -   35s
#      0     0 1393.45415    0   81 1392.00000 1393.45415  0.10%     -   37s
#      0     0 1393.45415    0   84 1392.00000 1393.45415  0.10%     -   37s
#      0     0 1393.45038    0   70 1392.00000 1393.45038  0.10%     -   40s
#      0     0 1393.42541    0   71 1392.00000 1393.42541  0.10%     -   41s
#      0     0 1393.42541    0   67 1392.00000 1393.42541  0.10%     -   42s
#      0     0 1393.40986    0   79 1392.00000 1393.40986  0.10%     -   45s
#      0     0 1393.40986    0   75 1392.00000 1393.40986  0.10%     -   47s
#      0     0 1393.40979    0   82 1392.00000 1393.40979  0.10%     -   49s
#      0     0 1393.38603    0   72 1392.00000 1393.38603  0.10%     -   52s
#      0     0 1393.37823    0   75 1392.00000 1393.37823  0.10%     -   53s
#      0     0 1393.37823    0   78 1392.00000 1393.37823  0.10%     -   53s
#      0     0 1393.35937    0   70 1392.00000 1393.35937  0.10%     -   56s
#      0     0 1393.35927    0   73 1392.00000 1393.35927  0.10%     -   57s
#      0     0 1393.27304    0   89 1392.00000 1393.27304  0.09%     -   60s
#      0     0 1393.27260    0   90 1392.00000 1393.27260  0.09%     -   61s
#      0     0 1393.27239    0   87 1392.00000 1393.27239  0.09%     -   61s
#      0     0 1393.27239    0   88 1392.00000 1393.27239  0.09%     -   62s
#      0     0 1393.27165    0  102 1392.00000 1393.27165  0.09%     -   64s
#      0     0 1393.27165    0   87 1392.00000 1393.27165  0.09%     -   65s
#      0     0 1393.26815    0   85 1392.00000 1393.26815  0.09%     -   68s
#      0     0 1393.26813    0   78 1392.00000 1393.26813  0.09%     -   69s
#      0     0 1393.26812    0   87 1392.00000 1393.26812  0.09%     -   71s
#      0     0 1393.26788    0   79 1392.00000 1393.26788  0.09%     -   72s
#      0     0 1393.26723    0   83 1392.00000 1393.26723  0.09%     -   73s
#      0     0 1393.26664    0   88 1392.00000 1393.26664  0.09%     -   74s
#      0     0 1393.26664    0   90 1392.00000 1393.26664  0.09%     -   74s
#      0     0 1393.26356    0   74 1392.00000 1393.26356  0.09%     -   76s
#      0     0 1393.26356    0   73 1392.00000 1393.26356  0.09%     -   77s
#      0     0 1393.26356    0   80 1392.00000 1393.26356  0.09%     -   80s
#      0     0 1393.26356    0   81 1392.00000 1393.26356  0.09%     -   81s
#      0     0 1393.26356    0   65 1392.00000 1393.26356  0.09%     -   84s
#      0     0 1393.26356    0   74 1392.00000 1393.26356  0.09%     -   86s
#      0     0 1393.26356    0   57 1392.00000 1393.26356  0.09%     -   90s
#      0     0 1393.26356    0   64 1392.00000 1393.26356  0.09%     -   92s
#      0     0 1393.26356    0   68 1392.00000 1393.26356  0.09%     -   95s
#      0     0 1393.26356    0   71 1392.00000 1393.26356  0.09%     -   96s
#      0     0 1393.26356    0   61 1392.00000 1393.26356  0.09%     -  100s
#      0     0 1393.26356    0   61 1392.00000 1393.26356  0.09%     -  101s
# H    0     0                    1393.0000000 1393.26356  0.02%     -  103s
#      0     0 1393.26356    0   61 1393.00000 1393.26356  0.02%     -  103s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 35
#   StrongCG: 2
#
# Explored 1 nodes (10399 simplex iterations) in 103.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1393 1392 1391 ... 1321
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.393000000000e+03, best bound 1.393000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4x3

# %%
datafile="3x2000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x09579b52
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1309.0000000
# Presolve removed 49 rows and 30 columns (presolve time = 7s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 10s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 15s) ...
# Sparsify removed 1957914 nonzeros (33%)
# Presolve added 0 rows and 78 columns
# Presolve removed 52 rows and 0 columns
# Presolve time: 16.27s
# Presolved: 7948 rows, 6078 columns, 3991167 nonzeros
# Variable types: 108 continuous, 5970 integer (5970 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9900000e+03   1.416289e+06   0.000000e+00     18s
#     1785    1.3828992e+03   0.000000e+00   0.000000e+00     20s
#
# Root relaxation: objective 1.382899e+03, 1785 iterations, 2.14 seconds
# Total elapsed time = 20.59s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1382.89919    0   87 1309.00000 1382.89919  5.65%     -   23s
# H    0     0                    1380.0000000 1382.89919  0.21%     -   23s
# H    0     0                    1381.0000000 1382.89919  0.14%     -   24s
# H    0     0                    1382.0000000 1382.89919  0.07%     -   24s
#      0     0 1382.89919    0   87 1382.00000 1382.89919  0.07%     -   24s
#
# Explored 1 nodes (4561 simplex iterations) in 24.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1382 1381 1380 1309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.382000000000e+03, best bound 1.382000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4x4

# %%
datafile="3x2000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x48939e06
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1302.0000000
# Presolve removed 36 rows and 18 columns (presolve time = 7s) ...
# Presolve removed 36 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 36 rows and 18 columns (presolve time = 15s) ...
# Sparsify removed 1936203 nonzeros (32%)
# Presolve added 0 rows and 89 columns
# Presolve removed 42 rows and 0 columns
# Presolve time: 16.71s
# Presolved: 7958 rows, 6089 columns, 4036782 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.492254e+06   0.000000e+00     18s
#     1159    1.5018019e+03   2.175007e+05   0.000000e+00     20s
#     2253    1.3754167e+03   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.375417e+03, 2253 iterations, 3.35 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1375.41671    0   95 1302.00000 1375.41671  5.64%     -   24s
# H    0     0                    1372.0000000 1375.41671  0.25%     -   24s
# H    0     0                    1373.0000000 1375.41671  0.18%     -   25s
#      0     0 1375.34510    0   98 1373.00000 1375.34510  0.17%     -   28s
# H    0     0                    1374.0000000 1375.34510  0.10%     -   31s
#      0     0 1375.34459    0   98 1374.00000 1375.34459  0.10%     -   31s
#      0     0 1375.34459    0   97 1374.00000 1375.34459  0.10%     -   32s
#      0     0 1375.31794    0   64 1374.00000 1375.31794  0.10%     -   35s
#      0     0 1375.26587    0   70 1374.00000 1375.26587  0.09%     -   37s
#      0     0 1375.26116    0   66 1374.00000 1375.26116  0.09%     -   38s
#      0     0 1375.26116    0   67 1374.00000 1375.26116  0.09%     -   38s
#      0     0 1375.24504    0   48 1374.00000 1375.24504  0.09%     -   41s
#      0     0 1375.24504    0   47 1374.00000 1375.24504  0.09%     -   43s
#      0     0 1375.08551    0   50 1374.00000 1375.08551  0.08%     -   46s
#      0     0 1375.08287    0   53 1374.00000 1375.08287  0.08%     -   46s
#      0     0 1375.08287    0   50 1374.00000 1375.08287  0.08%     -   47s
#      0     0 1375.08287    0   37 1374.00000 1375.08287  0.08%     -   51s
#      0     0 1375.08287    0   89 1374.00000 1375.08287  0.08%     -   62s
#      0     0 1375.08287    0   49 1374.00000 1375.08287  0.08%     -   64s
#      0     0 1375.08287    0   41 1374.00000 1375.08287  0.08%     -   65s
#      0     0 1375.08287    0   41 1374.00000 1375.08287  0.08%     -   66s
#      0     0 1375.08287    0   43 1374.00000 1375.08287  0.08%     -   66s
#      0     0 1375.08206    0   49 1374.00000 1375.08206  0.08%     -   67s
# H    0     0                    1375.0000000 1375.08206  0.01%     -   67s
#      0     0 1375.08206    0   49 1375.00000 1375.08206  0.01%     -   68s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 16
#
# Explored 1 nodes (10762 simplex iterations) in 68.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1375 1374 1373 ... 1302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.375000000000e+03, best bound 1.375000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4x5

# %%
datafile="3x2000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x4267ae8e
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1308.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 7s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 15s) ...
# Sparsify removed 1923054 nonzeros (32%)
# Presolve added 0 rows and 97 columns
# Presolve removed 27 rows and 0 columns
# Presolve time: 16.63s
# Presolved: 7973 rows, 6097 columns, 4067892 nonzeros
# Variable types: 106 continuous, 5991 integer (5991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.476141e+06   0.000000e+00     18s
#     1170    1.4629232e+03   2.930180e+05   0.000000e+00     20s
#     3242    1.3822052e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 1.382205e+03, 3242 iterations, 4.33 seconds
# Total elapsed time = 25.38s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1382.20522    0  116 1308.00000 1382.20522  5.67%     -   25s
# H    0     0                    1378.0000000 1382.20522  0.31%     -   26s
# H    0     0                    1379.0000000 1382.20522  0.23%     -   26s
#      0     0 1381.95418    0  123 1379.00000 1381.95418  0.21%     -   29s
# H    0     0                    1381.0000000 1381.95418  0.07%     -   31s
#      0     0 1381.95418    0  123 1381.00000 1381.95418  0.07%     -   31s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 1
#   MIR: 21
#   StrongCG: 2
#   GUB cover: 2
#
# Explored 1 nodes (6417 simplex iterations) in 31.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1381 1379 1378 1308
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.381000000000e+03, best bound 1.381000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4.5x1

# %%
datafile="3x2000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x35f478f6
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1219.0000000
# Presolve removed 33 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 30s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 35s) ...
# Sparsify removed 1936203 nonzeros (32%)
# Presolve added 0 rows and 89 columns
# Presolve removed 51 rows and 0 columns
# Presolve time: 37.25s
# Presolved: 7949 rows, 6089 columns, 4036755 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.505907e+06   0.000000e+00     40s
#     1502    1.3412919e+03   1.616999e+05   0.000000e+00     46s
#     3217    1.3054054e+03   1.175622e+05   0.000000e+00     50s
#     3992    1.2952988e+03   0.000000e+00   0.000000e+00     52s
#
# Root relaxation: objective 1.295299e+03, 3992 iterations, 12.30 seconds
# Total elapsed time = 55.76s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1295.29881    0  111 1219.00000 1295.29881  6.26%     -   58s
# H    0     0                    1292.0000000 1295.29881  0.26%     -   59s
# H    0     0                    1293.0000000 1295.29881  0.18%     -   59s
#      0     0 1295.29550    0  110 1293.00000 1295.29550  0.18%     -   66s
# H    0     0                    1294.0000000 1295.29550  0.10%     -   69s
#      0     0 1295.22919    0   97 1294.00000 1295.22919  0.09%     -   71s
#      0     0 1295.21889    0   67 1294.00000 1295.21889  0.09%     -   76s
#      0     0 1295.16472    0   67 1294.00000 1295.16472  0.09%     -   79s
#      0     0 1295.16472    0   69 1294.00000 1295.16472  0.09%     -   81s
#      0     0 1295.16472    0   60 1294.00000 1295.16472  0.09%     -   89s
#      0     0 1295.16472    0  105 1294.00000 1295.16472  0.09%     -  105s
#      0     0 1295.16472    0   64 1294.00000 1295.16472  0.09%     -  107s
#      0     0 1295.16472    0   61 1294.00000 1295.16472  0.09%     -  108s
#      0     0 1295.16472    0   64 1294.00000 1295.16472  0.09%     -  109s
#      0     0 1295.16472    0   68 1294.00000 1295.16472  0.09%     -  109s
#      0     0 1295.16472    0   64 1294.00000 1295.16472  0.09%     -  111s
#      0     0 1295.16472    0   66 1294.00000 1295.16472  0.09%     -  111s
#      0     0 1295.16373    0   62 1294.00000 1295.16373  0.09%     -  113s
#      0     0 1295.16373    0   58 1294.00000 1295.16373  0.09%     -  114s
#      0     0 1295.16373    0   70 1294.00000 1295.16373  0.09%     -  115s
#      0     0 1295.16373    0   70 1294.00000 1295.16373  0.09%     -  116s
#      0     0 1295.16373    0   63 1294.00000 1295.16373  0.09%     -  118s
#      0     0 1295.07907    0   61 1294.00000 1295.07907  0.08%     -  119s
#      0     0 1295.07907    0   59 1294.00000 1295.07907  0.08%     -  120s
#      0     0 1295.07907    0   52 1294.00000 1295.07907  0.08%     -  122s
#      0     0 1295.07907    0   48 1294.00000 1295.07907  0.08%     -  123s
#      0     0     cutoff    0      1294.00000 1294.00000  0.00%     -  124s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 157
#   RLT: 2
#
# Explored 1 nodes (18181 simplex iterations) in 124.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1294 1293 1292 1219
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.294000000000e+03, best bound 1.294000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4.5x2

# %%
datafile="3x2000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x30b34a52
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1228.0000000
# Presolve removed 10 rows and 12 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 12 columns (presolve time = 15s) ...
# Sparsify removed 1952971 nonzeros (33%)
# Presolve added 0 rows and 95 columns
# Presolve removed 16 rows and 0 columns
# Presolve time: 16.56s
# Presolved: 7984 rows, 6095 columns, 4032068 nonzeros
# Variable types: 107 continuous, 5988 integer (5988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.475368e+06   0.000000e+00     18s
#     1735    1.3880853e+03   3.974366e+05   0.000000e+00     20s
#     4596    1.2985064e+03   0.000000e+00   0.000000e+00     23s
#
# Root relaxation: objective 1.298506e+03, 4596 iterations, 5.15 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1298.50636    0  119 1228.00000 1298.50636  5.74%     -   25s
# H    0     0                    1287.0000000 1298.50636  0.89%     -   25s
# H    0     0                    1295.0000000 1298.50636  0.27%     -   25s
# H    0     0                    1296.0000000 1298.50636  0.19%     -   26s
#      0     0 1298.47966    0  149 1296.00000 1298.47966  0.19%     -   28s
# H    0     0                    1297.0000004 1298.47966  0.11%     -   30s
#      0     0 1298.40523    0  141 1297.00000 1298.40523  0.11%     -   31s
#      0     0 1298.40196    0  139 1297.00000 1298.40196  0.11%     -   32s
#      0     0 1298.40196    0  139 1297.00000 1298.40196  0.11%     -   33s
#      0     0 1298.17301    0  104 1297.00000 1298.17301  0.09%     -   36s
#      0     0 1298.15984    0   96 1297.00000 1298.15984  0.09%     -   37s
#      0     0 1298.15849    0   93 1297.00000 1298.15849  0.09%     -   38s
#      0     0 1298.15849    0   94 1297.00000 1298.15849  0.09%     -   39s
#      0     0 1298.15619    0   74 1297.00000 1298.15619  0.09%     -   44s
#      0     0 1298.15619    0  102 1297.00000 1298.15619  0.09%     -   57s
#      0     0 1298.15619    0   76 1297.00000 1298.15619  0.09%     -   59s
#      0     0 1298.09286    0   75 1297.00000 1298.09286  0.08%     -   59s
#      0     0 1298.08901    0   72 1297.00000 1298.08901  0.08%     -   60s
#      0     0 1298.08901    0   70 1297.00000 1298.08901  0.08%     -   60s
#      0     0 1298.08897    0   70 1297.00000 1298.08897  0.08%     -   62s
#      0     0 1298.05081    0   73 1297.00000 1298.05081  0.08%     -   63s
#      0     0 1298.05081    0   69 1297.00000 1298.05081  0.08%     -   63s
#      0     0     cutoff    0      1297.00000 1297.00000  0.00%     -   65s
#
# Cutting planes:
#   Gomory: 9
#   Implied bound: 1
#   MIR: 87
#   StrongCG: 1
#
# Explored 1 nodes (14905 simplex iterations) in 65.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1297 1296 1296 ... 1228
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.297000000309e+03, best bound 1.297000000309e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4.5x3

# %%
datafile="3x2000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x86a49485
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1232.0000000
# Presolve removed 44 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 44 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 44 rows and 24 columns (presolve time = 15s) ...
# Sparsify removed 1964934 nonzeros (33%)
# Presolve added 0 rows and 84 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 19.28s
# Presolved: 7953 rows, 6084 columns, 3996090 nonzeros
# Variable types: 108 continuous, 5976 integer (5976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9920000e+03   1.479213e+06   0.000000e+00     21s
#     2979    1.3022197e+03   0.000000e+00   0.000000e+00     24s
#
# Root relaxation: objective 1.302220e+03, 2979 iterations, 3.29 seconds
# Total elapsed time = 25.60s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1302.21967    0  106 1232.00000 1302.21967  5.70%     -   27s
# H    0     0                    1299.0000000 1302.21967  0.25%     -   27s
# H    0     0                    1300.0000000 1302.21967  0.17%     -   27s
#      0     0 1302.21445    0  133 1300.00000 1302.21445  0.17%     -   30s
# H    0     0                    1301.0000000 1302.21445  0.09%     -   32s
#      0     0     cutoff    0      1301.00000 1301.00000  0.00%     -   33s
#
# Cutting planes:
#   Gomory: 23
#   MIR: 42
#   RLT: 1
#
# Explored 1 nodes (6048 simplex iterations) in 33.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1301 1300 1299 1232
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.301000000000e+03, best bound 1.301000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4.5x4

# %%
datafile="3x2000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x7498d878
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1231.0000000
# Presolve removed 41 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 41 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 41 rows and 24 columns (presolve time = 15s) ...
# Sparsify removed 1979538 nonzeros (33%)
# Presolve added 0 rows and 90 columns
# Presolve removed 50 rows and 0 columns
# Presolve time: 19.53s
# Presolved: 7950 rows, 6090 columns, 3981471 nonzeros
# Variable types: 114 continuous, 5976 integer (5976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9920000e+03   1.416711e+06   0.000000e+00     21s
#     3371    1.3117198e+03   0.000000e+00   0.000000e+00     25s
#
# Root relaxation: objective 1.311720e+03, 3371 iterations, 3.84 seconds
# Total elapsed time = 25.54s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1311.71977    0  183 1231.00000 1311.71977  6.56%     -   27s
# H    0     0                    1306.0000000 1311.71977  0.44%     -   27s
# H    0     0                    1308.0000000 1311.71977  0.28%     -   27s
# H    0     0                    1309.0000000 1311.71977  0.21%     -   28s
#      0     0 1311.67315    0  172 1309.00000 1311.67315  0.20%     -   31s
# H    0     0                    1310.0000000 1311.67315  0.13%     -   34s
#      0     0 1311.51112    0  155 1310.00000 1311.51112  0.12%     -   35s
#      0     0 1311.50863    0  149 1310.00000 1311.50863  0.12%     -   36s
#      0     0 1311.50863    0  148 1310.00000 1311.50863  0.12%     -   37s
#      0     0 1311.46513    0  117 1310.00000 1311.46513  0.11%     -   40s
#      0     0 1311.46120    0  108 1310.00000 1311.46120  0.11%     -   42s
#      0     0 1311.46068    0  107 1310.00000 1311.46068  0.11%     -   43s
#      0     0 1311.45146    0  112 1310.00000 1311.45146  0.11%     -   44s
#      0     0 1311.44784    0  112 1310.00000 1311.44784  0.11%     -   45s
#      0     0 1311.44417    0  117 1310.00000 1311.44417  0.11%     -   49s
#      0     0 1311.37937    0  102 1310.00000 1311.37937  0.11%     -   50s
#      0     0 1311.37937    0  104 1310.00000 1311.37937  0.11%     -   51s
#      0     0 1311.37133    0   89 1310.00000 1311.37133  0.10%     -   54s
#      0     0 1311.37133    0   92 1310.00000 1311.37133  0.10%     -   55s
#      0     0 1311.37133    0   90 1310.00000 1311.37133  0.10%     -   58s
#      0     0 1311.37129    0   99 1310.00000 1311.37129  0.10%     -   59s
#      0     0 1311.36676    0   93 1310.00000 1311.36676  0.10%     -   64s
#      0     0 1311.36619    0   94 1310.00000 1311.36619  0.10%     -   65s
#      0     0 1311.36619    0   93 1310.00000 1311.36619  0.10%     -   66s
#      0     0 1311.36619    0  102 1310.00000 1311.36619  0.10%     -   68s
#      0     0 1311.36132    0  100 1310.00000 1311.36132  0.10%     -   69s
#      0     0 1311.36132    0  105 1310.00000 1311.36132  0.10%     -   70s
#      0     0 1311.36115    0   94 1310.00000 1311.36115  0.10%     -   73s
#      0     0 1311.36106    0   97 1310.00000 1311.36106  0.10%     -   74s
#      0     0 1311.36106    0   97 1310.00000 1311.36106  0.10%     -   76s
#      0     0 1311.35952    0  102 1310.00000 1311.35952  0.10%     -   78s
#      0     0 1311.35952    0   98 1310.00000 1311.35952  0.10%     -   78s
#      0     0 1311.35783    0  102 1310.00000 1311.35783  0.10%     -   82s
#      0     0 1311.35783    0  104 1310.00000 1311.35783  0.10%     -   83s
#      0     0 1311.35393    0   91 1310.00000 1311.35393  0.10%     -   85s
#      0     0 1311.35393    0   93 1310.00000 1311.35393  0.10%     -   86s
#      0     0 1311.35392    0   93 1310.00000 1311.35392  0.10%     -   88s
#      0     0 1311.35387    0   87 1310.00000 1311.35387  0.10%     -   90s
#      0     0 1311.35385    0   95 1310.00000 1311.35385  0.10%     -   92s
#      0     0 1311.35385    0   91 1310.00000 1311.35385  0.10%     -   93s
#      0     0 1311.35385    0   98 1310.00000 1311.35385  0.10%     -   95s
#      0     0 1311.35385    0   74 1310.00000 1311.35385  0.10%     -   99s
#      0     0 1311.35385    0  163 1310.00000 1311.35385  0.10%     -  114s
#      0     0 1311.35385    0  117 1310.00000 1311.35385  0.10%     -  117s
#      0     0 1311.35385    0   96 1310.00000 1311.35385  0.10%     -  119s
#      0     0 1311.35385    0   94 1310.00000 1311.35385  0.10%     -  119s
#      0     0 1311.35385    0  101 1310.00000 1311.35385  0.10%     -  121s
#      0     0 1311.35385    0   94 1310.00000 1311.35385  0.10%     -  122s
#      0     0 1311.35385    0   86 1310.00000 1311.35385  0.10%     -  124s
#      0     0 1311.35385    0   88 1310.00000 1311.35385  0.10%     -  125s
#      0     0 1311.35385    0   78 1310.00000 1311.35385  0.10%     -  130s
#      0     0 1311.35385    0   84 1310.00000 1311.35385  0.10%     -  132s
#      0     0 1311.35385    0   77 1310.00000 1311.35385  0.10%     -  136s
#      0     0 1311.35385    0   85 1310.00000 1311.35385  0.10%     -  139s
#      0     0 1311.35385    0   85 1310.00000 1311.35385  0.10%     -  142s
#      0     0 1311.35385    0   91 1310.00000 1311.35385  0.10%     -  144s
#      0     0 1311.35385    0   93 1310.00000 1311.35385  0.10%     -  147s
#      0     0 1311.35385    0   84 1310.00000 1311.35385  0.10%     -  149s
#      0     0 1311.35385    0   79 1310.00000 1311.35385  0.10%     -  154s
#      0     0 1311.35385    0   78 1310.00000 1311.35385  0.10%     -  155s
#      0     0 1311.35385    0   73 1310.00000 1311.35385  0.10%     -  161s
#      0     0 1311.35385    0   73 1310.00000 1311.35385  0.10%     -  164s
#      0     2 1311.35385    0   72 1310.00000 1311.35385  0.10%     -  174s
#      1     5 1311.35217    1   71 1310.00000 1311.35217  0.10%   397  175s
#     31    33 1311.32050    7   76 1310.00000 1311.32424  0.10%  20.7  180s
#     66    65 1311.31381   11   73 1310.00000 1311.32424  0.10%  12.0  187s
#     73    80 1311.31206   12   71 1310.00000 1311.32424  0.10%  11.2  190s
#     90    86 1311.31152   14   69 1310.00000 1311.32424  0.10%   9.6  231s
#    133   146 1311.29861   18   71 1310.00000 1311.32424  0.10%   7.4  238s
#    173   176 1311.28208   22   69 1310.00000 1311.32424  0.10%   6.3  246s
#    204   234 1311.28156   24   71 1310.00000 1311.32424  0.10%   6.0  251s
#    265   329 1311.13204   32   63 1310.00000 1311.32424  0.10%   5.6  256s
#    360   443 1311.12959   51   76 1310.00000 1311.32424  0.10%   5.2  264s
#    474   561 1311.12552   79   74 1310.00000 1311.32424  0.10%   4.9  270s
#    592   693 1311.12256   97   61 1310.00000 1311.32424  0.10%   4.7  279s
#    724   846 1311.12171  115   65 1310.00000 1311.32424  0.10%   4.5  287s
#    877  1032 1311.12030  137   65 1310.00000 1311.32424  0.10%   4.3  299s
#   1063  1222 1311.11862  164   61 1310.00000 1311.32424  0.10%   4.1  310s
#   1253  1384 1311.11738  190   61 1310.00000 1311.32424  0.10%   4.1  323s
#   1415  1627 1311.11708  211   59 1310.00000 1311.32424  0.10%   4.1  339s
#   1658  1891 1311.11645  242   61 1310.00000 1311.32424  0.10%   4.1  353s
#   1927  2097 1311.11518  270   61 1310.00000 1311.32424  0.10%   4.0  374s
# H 2071   560                    1311.0000000 1311.32424  0.02%   3.9  374s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 61
#
# Explored 2133 nodes (29458 simplex iterations) in 374.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1311 1310 1309 ... 1231
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.311000000000e+03, best bound 1.311000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x4.5x5

# %%
datafile="3x2000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x6055179b
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1231.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 12s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 25s) ...
# Sparsify removed 1936203 nonzeros (32%)
# Presolve added 0 rows and 89 columns
# Presolve removed 30 rows and 0 columns
# Presolve time: 26.18s
# Presolved: 7970 rows, 6089 columns, 4036815 nonzeros
# Variable types: 107 continuous, 5982 integer (5982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.490439e+06   0.000000e+00     28s
#      824    1.5007890e+03   4.108954e+05   0.000000e+00     30s
#     3487    1.2979860e+03   0.000000e+00   0.000000e+00     34s
#
# Root relaxation: objective 1.297986e+03, 3487 iterations, 5.65 seconds
# Total elapsed time = 35.86s
# Total elapsed time = 40.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1297.98604    0  112 1231.00000 1297.98604  5.44%     -   43s
# H    0     0                    1295.0000000 1297.98604  0.23%     -   44s
# H    0     0                    1296.0000000 1297.98604  0.15%     -   44s
#      0     0 1297.97672    0   99 1296.00000 1297.97672  0.15%     -   49s
# H    0     0                    1297.0000000 1297.97672  0.08%     -   52s
#      0     0 1297.97672    0   99 1297.00000 1297.97672  0.08%     -   52s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 1
#   MIR: 22
#   StrongCG: 4
#
# Explored 1 nodes (6578 simplex iterations) in 52.68 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1297 1296 1295 1231
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.297000000000e+03, best bound 1.297000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x5x1

# %%
datafile="3x2000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x5327e9f4
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1152.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 15s) ...
# Sparsify removed 1995159 nonzeros (33%)
# Presolve added 0 rows and 96 columns
# Presolve removed 34 rows and 0 columns
# Presolve time: 19.57s
# Presolved: 7966 rows, 6096 columns, 3971862 nonzeros
# Variable types: 117 continuous, 5979 integer (5979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.496776e+06   0.000000e+00     21s
#     3459    1.2305809e+03   3.175171e+04   0.000000e+00     25s
#     4152    1.2273579e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.227358e+03, 4152 iterations, 4.79 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1227.35786    0  126 1152.00000 1227.35786  6.54%     -   28s
# H    0     0                    1223.0000000 1227.35786  0.36%     -   28s
# H    0     0                    1225.0000000 1227.35786  0.19%     -   28s
#      0     0 1227.34526    0  135 1225.00000 1227.34526  0.19%     -   31s
# H    0     0                    1226.0000000 1227.34526  0.11%     -   32s
#      0     0 1227.10353    0  130 1226.00000 1227.10353  0.09%     -   34s
#      0     0 1227.10267    0  127 1226.00000 1227.10267  0.09%     -   34s
#      0     0 1227.10267    0  126 1226.00000 1227.10267  0.09%     -   35s
#      0     0 1227.07810    0   78 1226.00000 1227.07810  0.09%     -   40s
#      0     0 1227.07810    0  139 1226.00000 1227.07810  0.09%     -   49s
#      0     0 1227.07810    0  104 1226.00000 1227.07810  0.09%     -   50s
#      0     0 1227.07810    0  106 1226.00000 1227.07810  0.09%     -   50s
#      0     0 1227.07810    0  106 1226.00000 1227.07810  0.09%     -   51s
#      0     0 1227.05841    0   89 1226.00000 1227.05841  0.09%     -   52s
#      0     0 1227.05841    0   98 1226.00000 1227.05841  0.09%     -   53s
#      0     0 1227.05841    0   83 1226.00000 1227.05841  0.09%     -   54s
#      0     0 1227.05841    0   87 1226.00000 1227.05841  0.09%     -   55s
#      0     0 1227.05841    0   68 1226.00000 1227.05841  0.09%     -   57s
#      0     0 1227.05841    0   67 1226.00000 1227.05841  0.09%     -   57s
#      0     0 1227.03699    0   66 1226.00000 1227.03699  0.08%     -   60s
#      0     0 1227.01663    0   71 1226.00000 1227.01663  0.08%     -   60s
#      0     0 1227.01663    0   69 1226.00000 1227.01663  0.08%     -   61s
#      0     0     cutoff    0      1226.00000 1226.00000  0.00%     -   62s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 4
#   MIR: 101
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (14288 simplex iterations) in 62.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1226 1225 1223 1152
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.226000000000e+03, best bound 1.226000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x5x2

# %%
datafile="3x2000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x7b28d93a
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1148.0000000
# Presolve removed 23 rows and 15 columns (presolve time = 7s) ...
# Presolve removed 23 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 23 rows and 15 columns (presolve time = 15s) ...
# Sparsify removed 1956753 nonzeros (33%)
# Presolve added 0 rows and 92 columns
# Presolve removed 23 rows and 0 columns
# Presolve time: 17.17s
# Presolved: 7977 rows, 6092 columns, 4022256 nonzeros
# Variable types: 107 continuous, 5985 integer (5985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.542888e+06   0.000000e+00     20s
#      139    1.5618254e+03   6.074403e+05   0.000000e+00     20s
#     3127    1.2185827e+03   0.000000e+00   0.000000e+00     24s
#
# Root relaxation: objective 1.218583e+03, 3127 iterations, 5.15 seconds
# Total elapsed time = 25.19s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1218.58269    0  201 1148.00000 1218.58269  6.15%     -   27s
# H    0     0                    1206.0000000 1218.58269  1.04%     -   28s
# H    0     0                    1213.0000000 1218.58269  0.46%     -   28s
# H    0     0                    1216.0000000 1218.58269  0.21%     -   28s
#      0     0 1218.56295    0  216 1216.00000 1218.56295  0.21%     -   32s
# H    0     0                    1217.0000000 1218.56295  0.13%     -   35s
#      0     0 1218.53104    0  210 1217.00000 1218.53104  0.13%     -   36s
#      0     0 1218.51828    0  197 1217.00000 1218.51828  0.12%     -   37s
#      0     0 1218.51828    0  195 1217.00000 1218.51828  0.12%     -   37s
#      0     0 1218.49136    0  157 1217.00000 1218.49136  0.12%     -   42s
#      0     0 1218.48053    0  152 1217.00000 1218.48053  0.12%     -   43s
#      0     0 1218.47676    0  153 1217.00000 1218.47676  0.12%     -   44s
#      0     0 1218.47608    0  159 1217.00000 1218.47608  0.12%     -   45s
#      0     0 1218.47597    0  160 1217.00000 1218.47597  0.12%     -   46s
#      0     0 1218.45377    0  156 1217.00000 1218.45377  0.12%     -   50s
#      0     0 1218.45228    0  159 1217.00000 1218.45228  0.12%     -   51s
#      0     0 1218.45134    0  146 1217.00000 1218.45134  0.12%     -   52s
#      0     0 1218.45124    0  143 1217.00000 1218.45124  0.12%     -   52s
#      0     0 1218.44940    0  153 1217.00000 1218.44940  0.12%     -   56s
#      0     0 1218.44534    0  156 1217.00000 1218.44534  0.12%     -   58s
#      0     0 1218.44508    0  147 1217.00000 1218.44508  0.12%     -   59s
#      0     0 1218.44500    0  149 1217.00000 1218.44500  0.12%     -   60s
#      0     0 1218.44343    0  146 1217.00000 1218.44343  0.12%     -   63s
#      0     0 1218.44342    0  142 1217.00000 1218.44342  0.12%     -   64s
#      0     0 1218.43973    0  141 1217.00000 1218.43973  0.12%     -   68s
#      0     0 1218.42421    0  149 1217.00000 1218.42421  0.12%     -   69s
#      0     0 1218.42420    0  151 1217.00000 1218.42420  0.12%     -   70s
#      0     0 1218.38601    0  136 1217.00000 1218.38601  0.11%     -   74s
#      0     0 1218.38601    0  143 1217.00000 1218.38601  0.11%     -   75s
#      0     0 1218.38591    0  130 1217.00000 1218.38591  0.11%     -   79s
#      0     0 1218.38591    0  131 1217.00000 1218.38591  0.11%     -   80s
#      0     0 1218.38591    0  133 1217.00000 1218.38591  0.11%     -   82s
#      0     0 1218.38591    0  125 1217.00000 1218.38591  0.11%     -   83s
#      0     0 1218.38591    0  119 1217.00000 1218.38591  0.11%     -   87s
#      0     0 1218.38591    0  110 1217.00000 1218.38591  0.11%     -   88s
#      0     0 1218.38591    0  118 1217.00000 1218.38591  0.11%     -   93s
#      0     0 1218.38591    0  118 1217.00000 1218.38591  0.11%     -   95s
#      0     0 1218.38591    0  196 1217.00000 1218.38591  0.11%     -  110s
#      0     0 1218.38591    0  175 1217.00000 1218.38591  0.11%     -  114s
#      0     0 1218.38591    0  132 1217.00000 1218.38591  0.11%     -  115s
#      0     0 1218.38591    0  133 1217.00000 1218.38591  0.11%     -  116s
#      0     0 1218.38591    0  132 1217.00000 1218.38591  0.11%     -  116s
#      0     0 1218.38195    0  137 1217.00000 1218.38195  0.11%     -  119s
#      0     0 1218.38193    0  141 1217.00000 1218.38193  0.11%     -  120s
#      0     0 1218.38144    0  134 1217.00000 1218.38144  0.11%     -  123s
#      0     0 1218.38120    0  131 1217.00000 1218.38120  0.11%     -  124s
#      0     0 1218.38120    0  126 1217.00000 1218.38120  0.11%     -  125s
#      0     0 1218.37960    0  123 1217.00000 1218.37960  0.11%     -  127s
#      0     0 1218.37960    0  127 1217.00000 1218.37960  0.11%     -  128s
#      0     0 1218.37960    0  118 1217.00000 1218.37960  0.11%     -  130s
#      0     0 1218.37960    0  134 1217.00000 1218.37960  0.11%     -  131s
#      0     0 1218.37960    0  131 1217.00000 1218.37960  0.11%     -  135s
#      0     0 1218.37960    0  132 1217.00000 1218.37960  0.11%     -  136s
#      0     0 1218.37960    0  123 1217.00000 1218.37960  0.11%     -  140s
#      0     0 1218.37960    0  124 1217.00000 1218.37960  0.11%     -  140s
#      0     0 1218.37960    0  117 1217.00000 1218.37960  0.11%     -  144s
#      0     0 1218.37960    0  116 1217.00000 1218.37960  0.11%     -  147s
#      0     2 1218.37960    0  116 1217.00000 1218.37960  0.11%     -  152s
#      7    14 1218.35666    3  132 1217.00000 1218.37779  0.11%  93.9  155s
#     56    70 1218.34372    9  125 1217.00000 1218.37572  0.11%  33.1  160s
#    111   222 1218.34178   17  116 1217.00000 1218.37572  0.11%  19.3  167s
#    236   343 1218.31684   36  112 1217.00000 1218.37572  0.11%  13.0  175s
#    447   410 1218.18094   62  112 1217.00000 1218.37550  0.11%  11.2  183s
#    685   445 1218.04252   17  106 1217.00000 1218.36243  0.11%  10.6  191s
#    960   470 1218.29196    7  126 1217.00000 1218.34803  0.11%  11.7  198s
#   1276   495 1218.03211    6  125 1217.00000 1218.33171  0.11%  12.7  204s
#   1528   486 infeasible    9      1217.00000 1218.27986  0.11%  12.4  212s
#   1752   300 1218.00534   11   96 1217.00000 1218.23255  0.10%  12.4  222s
#   2239   237     cutoff   58      1217.00000 1218.14861  0.09%  12.5  229s
#   2563   377     cutoff   14      1217.00000 1218.04825  0.09%  12.3  238s
#   2997   552 1218.00134   24  108 1217.00000 1218.02683  0.08%  11.8  248s
#   3575   629 1218.00415   20   99 1217.00000 1218.02282  0.08%  11.1  259s
#   4118   651 1218.00320   13   89 1217.00000 1218.01888  0.08%  10.8  268s
#   4560   614 1218.00041   20  105 1217.00000 1218.01644  0.08%  10.6  279s
#   4961   639 1217.99882   15   95 1217.00000 1218.01170  0.08%  10.4  291s
#   5548   586 1218.00756   15  107 1217.00000 1218.00756  0.08%  10.1  302s
#   6176   549 1218.00037   18   90 1217.00000 1218.00529  0.08%   9.7  314s
#   6771   428 1217.99933   17   89 1217.00000 1218.00374  0.08%   9.6  329s
#   7308   358 1218.00170   25   99 1217.00000 1218.00264  0.08%   9.6  342s
#   7947   368 1218.00063   19  105 1217.00000 1218.00063  0.08%   9.5  356s
#   8776   325 1217.99907   21   93 1217.00000 1218.00037  0.08%   9.2  388s
#   9257   198 1218.00004   23   96 1217.00000 1218.00005  0.08%   9.2  401s
#   9767    86 1217.99933   21  101 1217.00000 1217.99959  0.08%   9.0  414s
#  10520     0 1217.99906   24   91 1217.00000 1217.99907  0.08%   8.9  420s
#
# Cutting planes:
#   Gomory: 25
#   Cover: 15
#   Implied bound: 4
#   MIR: 297
#   StrongCG: 2
#   GUB cover: 13
#   Inf proof: 1
#   RLT: 3
#   Relax-and-lift: 5
#
# Explored 10830 nodes (115363 simplex iterations) in 421.01 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1217 1216 1213 ... 1148
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.217000000000e+03, best bound 1.217000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x5x3

# %%
datafile="3x2000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0xb833be95
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1154.0000000
# Presolve removed 44 rows and 33 columns (presolve time = 7s) ...
# Presolve removed 44 rows and 33 columns (presolve time = 10s) ...
# Presolve removed 44 rows and 33 columns (presolve time = 15s) ...
# Sparsify removed 2032526 nonzeros (34%)
# Presolve added 0 rows and 86 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 16.20s
# Presolved: 7953 rows, 6086 columns, 3910615 nonzeros
# Variable types: 119 continuous, 5967 integer (5967 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9890000e+03   1.500577e+06   0.000000e+00     18s
#     1880    1.2890534e+03   9.981288e+04   0.000000e+00     20s
#     3737    1.2257778e+03   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.225778e+03, 3737 iterations, 3.92 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1225.77775    0  223 1154.00000 1225.77775  6.22%     -   24s
# H    0     0                    1222.0000000 1225.77775  0.31%     -   24s
# H    0     0                    1223.0000000 1225.77775  0.23%     -   25s
# H    0     0                    1224.0000000 1225.77775  0.15%     -   25s
#      0     0 1225.76155    0  207 1224.00000 1225.76155  0.14%     -   29s
#      0     0 1225.74776    0  204 1224.00000 1225.74776  0.14%     -   32s
#      0     0 1225.73822    0  200 1224.00000 1225.73822  0.14%     -   33s
#      0     0 1225.73822    0  204 1224.00000 1225.73822  0.14%     -   34s
#      0     0 1225.73051    0  194 1224.00000 1225.73051  0.14%     -   37s
#      0     0 1225.62654    0  192 1224.00000 1225.62654  0.13%     -   38s
#      0     0 1225.62649    0  193 1224.00000 1225.62649  0.13%     -   39s
#      0     0 1225.62617    0  192 1224.00000 1225.62617  0.13%     -   43s
#      0     0 1225.62348    0  170 1224.00000 1225.62348  0.13%     -   46s
#      0     0 1225.61914    0  165 1224.00000 1225.61914  0.13%     -   47s
#      0     0 1225.61914    0  165 1224.00000 1225.61914  0.13%     -   48s
#      0     0 1225.61914    0  153 1224.00000 1225.61914  0.13%     -   51s
#      0     0 1225.61895    0  149 1224.00000 1225.61895  0.13%     -   52s
#      0     0 1225.61820    0  142 1224.00000 1225.61820  0.13%     -   53s
#      0     0 1225.61820    0  147 1224.00000 1225.61820  0.13%     -   54s
#      0     0 1225.61820    0  166 1224.00000 1225.61820  0.13%     -   57s
#      0     0 1225.61820    0  173 1224.00000 1225.61820  0.13%     -   58s
#      0     0 1225.61798    0  173 1224.00000 1225.61798  0.13%     -   61s
#      0     0 1225.61494    0  162 1224.00000 1225.61494  0.13%     -   62s
#      0     0 1225.59611    0  159 1224.00000 1225.59611  0.13%     -   63s
#      0     0 1225.59611    0  157 1224.00000 1225.59611  0.13%     -   64s
#      0     0 1225.59564    0  150 1224.00000 1225.59564  0.13%     -   67s
#      0     0 1225.59563    0  147 1224.00000 1225.59563  0.13%     -   69s
#      0     0 1225.59458    0  142 1224.00000 1225.59458  0.13%     -   72s
#      0     0 1225.59457    0  135 1224.00000 1225.59457  0.13%     -   73s
#      0     0 1225.59406    0  141 1224.00000 1225.59406  0.13%     -   75s
#      0     0 1225.59358    0  139 1224.00000 1225.59358  0.13%     -   76s
#      0     0 1225.59288    0  145 1224.00000 1225.59288  0.13%     -   77s
#      0     0 1225.59287    0  146 1224.00000 1225.59287  0.13%     -   77s
#      0     0 1225.59217    0  140 1224.00000 1225.59217  0.13%     -   81s
#      0     0 1225.59217    0  113 1224.00000 1225.59217  0.13%     -   83s
#      0     2 1225.59217    0  113 1224.00000 1225.59217  0.13%     -   88s
#      3     8 1225.57200    2  102 1224.00000 1225.58979  0.13%   156   90s
#     31    36 1225.25905    5   91 1224.00000 1225.56759  0.13%  40.7   95s
# H   35    36                    1225.0000006 1225.56759  0.05%  37.1   95s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 22
#   MIR: 128
#   StrongCG: 11
#   GUB cover: 1
#   RLT: 1
#
# Explored 38 nodes (11974 simplex iterations) in 95.19 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1225 1224 1223 ... 1154
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.225000000516e+03, best bound 1.225000000516e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x5x4

# %%
datafile="3x2000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x54b96254
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1156.0000000
# Presolve removed 32 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 32 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 32 rows and 24 columns (presolve time = 15s) ...
# Sparsify removed 1960086 nonzeros (33%)
# Presolve added 0 rows and 84 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 19.37s
# Presolved: 7962 rows, 6084 columns, 4000989 nonzeros
# Variable types: 108 continuous, 5976 integer (5976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9920000e+03   1.536073e+06   0.000000e+00     21s
#     3579    1.2249738e+03   6.090215e+04   0.000000e+00     25s
#     4139    1.2209453e+03   0.000000e+00   0.000000e+00     25s
#
# Root relaxation: objective 1.220945e+03, 4139 iterations, 4.74 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1220.94529    0  167 1156.00000 1220.94529  5.62%     -   27s
# H    0     0                    1218.0000000 1220.94529  0.24%     -   28s
# H    0     0                    1219.0000000 1220.94529  0.16%     -   28s
#      0     0 1220.93928    0  189 1219.00000 1220.93928  0.16%     -   32s
# H    0     0                    1220.0000000 1220.93928  0.08%     -   34s
#      0     0 1220.93928    0  189 1220.00000 1220.93928  0.08%     -   34s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 1
#   MIR: 27
#   StrongCG: 1
#   RLT: 2
#
# Explored 1 nodes (6095 simplex iterations) in 34.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1220 1219 1218 1156
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.220000000000e+03, best bound 1.220000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x2000x5x5

# %%
datafile="3x2000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 8000 rows, 6000 columns and 6009000 nonzeros
# Model fingerprint: 0x16f7add9
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1162.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 7s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 15s) ...
# Sparsify removed 1970868 nonzeros (33%)
# Presolve added 0 rows and 87 columns
# Presolve removed 34 rows and 0 columns
# Presolve time: 16.53s
# Presolved: 7966 rows, 6087 columns, 3996162 nonzeros
# Variable types: 108 continuous, 5979 integer (5979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.507722e+06   0.000000e+00     18s
#     1514    1.4323703e+03   3.031853e+04   0.000000e+00     20s
#     4497    1.2383162e+03   0.000000e+00   0.000000e+00     23s
#
# Root relaxation: objective 1.238316e+03, 4497 iterations, 5.29 seconds
# Total elapsed time = 25.24s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1238.31617    0  157 1162.00000 1238.31617  6.57%     -   25s
# H    0     0                    1235.0000000 1238.31617  0.27%     -   26s
#      0     0 1238.01956    0  112 1235.00000 1238.01956  0.24%     -   29s
# H    0     0                    1237.0000000 1238.01956  0.08%     -   31s
#      0     0 1238.01956    0  112 1237.00000 1238.01956  0.08%     -   31s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 18
#
# Explored 1 nodes (6595 simplex iterations) in 31.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1237 1235 1162
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.237000000000e+03, best bound 1.237000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x1.5x1

# %%
datafile="4x2000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x5f3af04b
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1993.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 11s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 15s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 20s) ...
# Sparsify removed 2494768 nonzeros (31%)
# Presolve added 0 rows and 120 columns
# Presolve removed 84 rows and 0 columns
# Presolve time: 23.01s
# Presolved: 9916 rows, 8120 columns, 5485028 nonzeros
# Variable types: 136 continuous, 7984 integer (7984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.158102e+06   0.000000e+00     25s
#     1486    1.9951067e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.995107e+03, 1486 iterations, 1.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1995.10674    0   32 1993.00000 1995.10674  0.11%     -   29s
# H    0     0                    1994.0000000 1995.10674  0.06%     -   29s
#      0     0     cutoff    0      1994.00000 1994.00000  0.00%     -   32s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 16
#   Implied bound: 2
#   MIR: 36
#   StrongCG: 1
#   RLT: 9
#
# Explored 1 nodes (5334 simplex iterations) in 32.96 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1994 1993
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.994000000000e+03, best bound 1.994000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x1.5x2

# %%
datafile="4x2000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xb63f5bdd
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 22 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 2461215 nonzeros (31%)
# Presolve added 0 rows and 127 columns
# Presolve removed 49 rows and 0 columns
# Presolve time: 22.87s
# Presolved: 9951 rows, 8127 columns, 5534696 nonzeros
# Variable types: 135 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.203292e+06   0.000000e+00     25s
#      273    1.9980000e+03   4.477528e+05   0.000000e+00     25s
#     1405    1.9980000e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.998000e+03, 1405 iterations, 1.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1998.00000    0    5 1997.00000 1998.00000  0.05%     -   28s
# H    0     0                    1998.0000000 1998.00000  0.00%     -   28s
#      0     0 1998.00000    0    5 1998.00000 1998.00000  0.00%     -   28s
#
# Explored 1 nodes (3796 simplex iterations) in 28.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1998 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.998000000000e+03, best bound 1.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x1.5x3

# %%
datafile="4x2000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x8d7b9b16
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1997.0000000
# Presolve removed 27 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 20s) ...
# Sparsify removed 2476424 nonzeros (31%)
# Presolve added 0 rows and 124 columns
# Presolve removed 79 rows and 0 columns
# Presolve time: 22.50s
# Presolved: 9921 rows, 8124 columns, 5511396 nonzeros
# Variable types: 136 continuous, 7988 integer (7988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.233251e+06   0.000000e+00     25s
#
# Root relaxation: cutoff, 0 iterations, 0.36 seconds
#
# Explored 0 nodes (0 simplex iterations) in 24.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.997000000000e+03, best bound 1.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x1.5x4

# %%
datafile="4x2000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xc873c829
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1994.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 20s) ...
# Sparsify removed 2472344 nonzeros (31%)
# Presolve added 0 rows and 112 columns
# Presolve removed 74 rows and 0 columns
# Presolve time: 21.95s
# Presolved: 9926 rows, 8112 columns, 5491488 nonzeros
# Variable types: 136 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.178704e+06   0.000000e+00     24s
#
# Root relaxation: cutoff, 0 iterations, 0.36 seconds
#
# Explored 0 nodes (0 simplex iterations) in 24.12 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 1994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.994000000000e+03, best bound 1.994000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x1.5x5

# %%
datafile="4x2000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x1e7d3478
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1995.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 10s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 15s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 20s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 25s) ...
# Sparsify removed 2475064 nonzeros (31%)
# Presolve added 0 rows and 120 columns
# Presolve removed 92 rows and 0 columns
# Presolve time: 27.00s
# Presolved: 9908 rows, 8120 columns, 5504664 nonzeros
# Variable types: 136 continuous, 7984 integer (7984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.224760e+06   0.000000e+00     29s
#     1112    1.9960000e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 1.996000e+03, 1112 iterations, 0.99 seconds
# Total elapsed time = 30.93s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1996.00000    0   11 1995.00000 1996.00000  0.05%     -   33s
# H    0     0                    1996.0000000 1996.00000  0.00%     -   33s
#      0     0 1996.00000    0   11 1996.00000 1996.00000  0.00%     -   33s
#
# Explored 1 nodes (4506 simplex iterations) in 33.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1996 1995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.996000000000e+03, best bound 1.996000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2x1

# %%
datafile="4x2000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x57224dac
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1966.0000000
# Presolve removed 23 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 20s) ...
# Sparsify removed 2502696 nonzeros (31%)
# Presolve added 0 rows and 124 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 22.65s
# Presolved: 9953 rows, 8124 columns, 5485224 nonzeros
# Variable types: 136 continuous, 7988 integer (7988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.328873e+06   0.000000e+00     25s
#      193    1.9970000e+03   4.172135e+05   0.000000e+00     25s
#     1968    1.9737024e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.973702e+03, 1968 iterations, 1.51 seconds
# Total elapsed time = 30.31s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1973.70239    0  176 1966.00000 1973.70239  0.39%     -   31s
# H    0     0                    1970.0000000 1973.70239  0.19%     -   32s
#      0     0 1973.61347    0  162 1970.00000 1973.61347  0.18%     -   36s
# H    0     0                    1971.0000000 1973.61347  0.13%     -   38s
# H    0     0                    1972.0000000 1973.61347  0.08%     -   39s
#      0     0 1973.50103    0  147 1972.00000 1973.50103  0.08%     -   40s
#      0     0 1973.50103    0  145 1972.00000 1973.50103  0.08%     -   41s
#      0     0 1973.46994    0  107 1972.00000 1973.46994  0.07%     -   45s
#      0     0 1973.46994    0   97 1972.00000 1973.46994  0.07%     -   47s
#      0     0 1973.46994    0   99 1972.00000 1973.46994  0.07%     -   51s
# H    0     0                    1973.0000000 1973.46994  0.02%     -   53s
#      0     0 1973.46994    0   99 1973.00000 1973.46994  0.02%     -   53s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 10
#   Implied bound: 1
#   MIR: 53
#   StrongCG: 5
#   RLT: 2
#
# Explored 1 nodes (10184 simplex iterations) in 53.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1973 1972 1971 ... 1966
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.973000000000e+03, best bound 1.973000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2x2

# %%
datafile="4x2000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x91b2b9a6
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1984.0000000
# Presolve removed 13 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 20s) ...
# Sparsify removed 2462565 nonzeros (31%)
# Presolve added 0 rows and 131 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 22.28s
# Presolved: 9963 rows, 8131 columns, 5541355 nonzeros
# Variable types: 135 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.348318e+06   0.000000e+00     25s
#      523    1.9989992e+03   1.071585e+04   0.000000e+00     25s
#     2051    1.9869907e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.986991e+03, 2051 iterations, 1.49 seconds
# Total elapsed time = 30.36s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1986.99070    0  146 1984.00000 1986.99070  0.15%     -   32s
#      0     0 1986.99023    0  175 1984.00000 1986.99023  0.15%     -   38s
#      0     0 1986.99023    0  185 1984.00000 1986.99023  0.15%     -   41s
#      0     0 1986.98930    0  143 1984.00000 1986.98930  0.15%     -   48s
#      0     0 1986.97446    0  131 1984.00000 1986.97446  0.15%     -   50s
#      0     0 1986.97446    0  134 1984.00000 1986.97446  0.15%     -   51s
#      0     0 1986.86013    0  128 1984.00000 1986.86013  0.14%     -   57s
#      0     0 1986.86013    0  122 1984.00000 1986.86013  0.14%     -   59s
#      0     0 1986.85998    0  129 1984.00000 1986.85998  0.14%     -   65s
#      0     0 1986.85682    0  123 1984.00000 1986.85682  0.14%     -   67s
#      0     0 1986.83862    0  114 1984.00000 1986.83862  0.14%     -   68s
#      0     0 1986.83862    0  116 1984.00000 1986.83862  0.14%     -   69s
#      0     0 1986.83378    0  119 1984.00000 1986.83378  0.14%     -   75s
#      0     0 1986.83378    0  113 1984.00000 1986.83378  0.14%     -   78s
#      0     0 1986.83378    0  124 1984.00000 1986.83378  0.14%     -   81s
#      0     0 1986.83378    0  119 1984.00000 1986.83378  0.14%     -   83s
#      0     0 1986.83376    0  109 1984.00000 1986.83376  0.14%     -   92s
# H    0     0                    1985.0000000 1986.83376  0.09%     -   95s
#      0     0 1986.83376    0  103 1985.00000 1986.83376  0.09%     -   96s
#      0     0 1986.83351    0  108 1985.00000 1986.83351  0.09%     -   99s
#      0     0 1986.83341    0  100 1985.00000 1986.83341  0.09%     -  101s
#      0     0 1986.83306    0  101 1985.00000 1986.83306  0.09%     -  106s
#      0     0 1986.83306    0  107 1985.00000 1986.83306  0.09%     -  107s
#      0     0 1986.83306    0  108 1985.00000 1986.83306  0.09%     -  111s
#      0     0 1986.83306    0   96 1985.00000 1986.83306  0.09%     -  116s
#      0     2 1986.83306    0   86 1985.00000 1986.83306  0.09%     -  122s
#      7    14 1986.10800    3   86 1985.00000 1986.83306  0.09%   233  126s
#     19    26 1986.10780    5   91 1985.00000 1986.83306  0.09%   126  131s
# H   31    38                    1986.0000000 1986.83306  0.04%  87.4  138s
#
# Cutting planes:
#   Gomory: 15
#   MIR: 173
#
# Explored 37 nodes (18708 simplex iterations) in 138.39 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1986 1985 1984
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.986000000000e+03, best bound 1.986000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2x3

# %%
datafile="4x2000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x8ef31fdd
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1989.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 2461215 nonzeros (31%)
# Presolve added 0 rows and 127 columns
# Presolve removed 42 rows and 0 columns
# Presolve time: 22.85s
# Presolved: 9958 rows, 8127 columns, 5534697 nonzeros
# Variable types: 135 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.357678e+06   0.000000e+00     25s
#      184    1.9980000e+03   5.019939e+05   0.000000e+00     25s
#     1704    1.9922602e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.992260e+03, 1704 iterations, 1.36 seconds
# Total elapsed time = 31.24s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1992.26021    0  101 1989.00000 1992.26021  0.16%     -   32s
#      0     0 1992.11810    0   66 1989.00000 1992.11810  0.16%     -   37s
#      0     0 1992.02895    0   62 1989.00000 1992.02895  0.15%     -   40s
#      0     0 1992.02895    0   62 1989.00000 1992.02895  0.15%     -   41s
#      0     0 1991.93971    0   54 1989.00000 1991.93971  0.15%     -   45s
# H    0     0                    1990.0000000 1991.93971  0.10%     -   47s
#      0     0 1991.93971    0   53 1990.00000 1991.93971  0.10%     -   47s
#      0     0 1991.93971    0   54 1990.00000 1991.93971  0.10%     -   52s
# H    0     0                    1991.0000000 1991.93971  0.05%     -   54s
#      0     0 1991.93971    0   54 1991.00000 1991.93971  0.05%     -   54s
#
# Cutting planes:
#   Gomory: 8
#   MIR: 21
#   StrongCG: 2
#
# Explored 1 nodes (9356 simplex iterations) in 54.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1991 1990 1989
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.991000000000e+03, best bound 1.991000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2x4

# %%
datafile="4x2000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xf1276fbc
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1988.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 6s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 25s) ...
# Sparsify removed 2461215 nonzeros (31%)
# Presolve added 0 rows and 127 columns
# Presolve removed 42 rows and 0 columns
# Presolve time: 27.24s
# Presolved: 9958 rows, 8127 columns, 5534701 nonzeros
# Variable types: 135 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9980000e+03   1.334887e+06   0.000000e+00     30s
#      175    1.9980000e+03   2.468331e+05   0.000000e+00     30s
#     1881    1.9911015e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.991101e+03, 1881 iterations, 1.39 seconds
# Total elapsed time = 35.87s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1991.10148    0   78 1988.00000 1991.10148  0.16%     -   38s
#      0     0 1991.10148    0   81 1988.00000 1991.10148  0.16%     -   42s
# H    0     0                    1989.0000000 1991.10148  0.11%     -   44s
#      0     0 1990.94471    0   74 1989.00000 1990.94471  0.10%     -   46s
#      0     0 1990.00000    0   20 1989.00000 1990.00000  0.05%     -   54s
#      0     0 1990.00000    0   17 1989.00000 1990.00000  0.05%     -   55s
#      0     0 1990.00000    0   12 1989.00000 1990.00000  0.05%     -   59s
#      0     0 1990.00000    0   12 1989.00000 1990.00000  0.05%     -   63s
#      0     0 1990.00000    0    8 1989.00000 1990.00000  0.05%     -   69s
#      0     0 1990.00000    0    9 1989.00000 1990.00000  0.05%     -   71s
#      0     0 1990.00000    0    6 1989.00000 1990.00000  0.05%     -   77s
# H    0     0                    1990.0000009 1990.00000  0.00%     -   78s
#      0     0 1990.00000    0    6 1990.00000 1990.00000  0.00%     -   78s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#
# Explored 1 nodes (20005 simplex iterations) in 78.22 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1990 1989 1988
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.990000000845e+03, best bound 1.990000000845e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2x5

# %%
datafile="4x2000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x8e329e64
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1974.0000000
# Presolve removed 33 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2473704 nonzeros (31%)
# Presolve added 0 rows and 116 columns
# Presolve removed 69 rows and 0 columns
# Presolve time: 25.99s
# Presolved: 9931 rows, 8116 columns, 5498204 nonzeros
# Variable types: 136 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.370099e+06   0.000000e+00     28s
#     1894    1.9782345e+03   0.000000e+00   0.000000e+00     29s
#
# Root relaxation: objective 1.978234e+03, 1894 iterations, 1.36 seconds
# Total elapsed time = 31.00s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1978.23447    0   77 1974.00000 1978.23447  0.21%     -   34s
# H    0     0                    1976.0000000 1978.23447  0.11%     -   35s
#      0     0 1978.00000    0   84 1976.00000 1978.00000  0.10%     -   39s
#      0     0 1978.00000    0   82 1976.00000 1978.00000  0.10%     -   42s
#      0     0 1978.00000    0   84 1976.00000 1978.00000  0.10%     -   47s
#      0     0 1978.00000    0   80 1976.00000 1978.00000  0.10%     -   48s
#      0     0 1977.73116    0   60 1976.00000 1977.73116  0.09%     -   56s
# H    0     0                    1977.0000009 1977.73116  0.04%     -   58s
#      0     0 1977.73116    0   60 1977.00000 1977.73116  0.04%     -   58s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 1
#   MIR: 17
#   GUB cover: 1
#
# Explored 1 nodes (12554 simplex iterations) in 58.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1977 1976 1974
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.977000000861e+03, best bound 1.977000000861e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2.5x1

# %%
datafile="4x2000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xe3a54bda
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1730.0000000
# Presolve removed 38 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 20s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 25s) ...
# Sparsify removed 2521531 nonzeros (32%)
# Presolve added 0 rows and 113 columns
# Presolve removed 46 rows and 0 columns
# Presolve time: 26.23s
# Presolved: 9954 rows, 8113 columns, 5442473 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.426938e+06   0.000000e+00     28s
#     2106    1.7692050e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 1.769205e+03, 2106 iterations, 2.04 seconds
# Total elapsed time = 32.03s
# Total elapsed time = 36.21s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1769.20496    0  230 1730.00000 1769.20496  2.27%     -   37s
# H    0     0                    1764.0000000 1769.20496  0.30%     -   38s
#      0     0 1769.20240    0  245 1764.00000 1769.20240  0.29%     -   42s
# H    0     0                    1767.0000000 1769.20240  0.12%     -   48s
#      0     0 1769.18583    0  215 1767.00000 1769.18583  0.12%     -   48s
#      0     0 1769.11187    0  196 1767.00000 1769.11187  0.12%     -   50s
#      0     0 1769.11187    0  200 1767.00000 1769.11187  0.12%     -   51s
#      0     0 1768.90411    0  180 1767.00000 1768.90411  0.11%     -   54s
#      0     0 1768.89505    0  182 1767.00000 1768.89505  0.11%     -   56s
#      0     0 1768.88990    0  178 1767.00000 1768.88990  0.11%     -   57s
#      0     0 1768.88990    0  179 1767.00000 1768.88990  0.11%     -   58s
#      0     0 1768.87960    0  181 1767.00000 1768.87960  0.11%     -   63s
#      0     0 1768.71342    0  272 1767.00000 1768.71342  0.10%     -   65s
#      0     0 1768.71341    0  279 1767.00000 1768.71341  0.10%     -   66s
#      0     0 1768.71294    0  238 1767.00000 1768.71294  0.10%     -   71s
#      0     0 1768.71250    0  223 1767.00000 1768.71250  0.10%     -   73s
#      0     0 1768.71238    0  207 1767.00000 1768.71238  0.10%     -   74s
#      0     0 1768.70546    0  188 1767.00000 1768.70546  0.10%     -   79s
#      0     0 1768.60615    0  145 1767.00000 1768.60615  0.09%     -   81s
#      0     0 1768.57769    0  155 1767.00000 1768.57769  0.09%     -   82s
#      0     0 1768.57769    0  154 1767.00000 1768.57769  0.09%     -   83s
#      0     0 1768.56590    0  146 1767.00000 1768.56590  0.09%     -   88s
#      0     0 1768.56590    0  133 1767.00000 1768.56590  0.09%     -   89s
#      0     0 1768.56590    0  138 1767.00000 1768.56590  0.09%     -   93s
#      0     0 1768.54976    0  129 1767.00000 1768.54976  0.09%     -   94s
#      0     0 1768.54963    0  138 1767.00000 1768.54963  0.09%     -   95s
#      0     0 1768.54963    0  272 1767.00000 1768.54963  0.09%     -   98s
#      0     0 1768.54962    0  266 1767.00000 1768.54962  0.09%     -  100s
#      0     0 1768.54958    0  230 1767.00000 1768.54958  0.09%     -  105s
#      0     0 1768.54952    0  240 1767.00000 1768.54952  0.09%     -  107s
#      0     0 1768.54918    0  212 1767.00000 1768.54918  0.09%     -  111s
#      0     0 1768.54879    0  200 1767.00000 1768.54879  0.09%     -  112s
#      0     0 1768.54877    0  204 1767.00000 1768.54877  0.09%     -  113s
#      0     0 1768.54877    0  184 1767.00000 1768.54877  0.09%     -  117s
#      0     0 1768.54874    0  186 1767.00000 1768.54874  0.09%     -  118s
#      0     0 1768.54874    0  174 1767.00000 1768.54874  0.09%     -  122s
#      0     0 1768.54869    0  169 1767.00000 1768.54869  0.09%     -  124s
#      0     0 1768.54865    0  164 1767.00000 1768.54865  0.09%     -  127s
#      0     0 1768.54864    0  154 1767.00000 1768.54864  0.09%     -  129s
#      0     0 1768.54861    0  119 1767.00000 1768.54861  0.09%     -  132s
#      0     0 1768.54861    0  136 1767.00000 1768.54861  0.09%     -  133s
#      0     0 1768.54860    0  134 1767.00000 1768.54860  0.09%     -  137s
#      0     0 1768.54860    0   92 1767.00000 1768.54860  0.09%     -  143s
#      0     2 1768.54860    0   92 1767.00000 1768.54860  0.09%     -  151s
#      7    14 1768.54686    3   92 1767.00000 1768.54853  0.09%   279  155s
#     25    32 1768.50409    5  103 1767.00000 1768.54849  0.09%   118  160s
#     37    46 1768.50409    6  112 1767.00000 1768.54849  0.09%  82.7  165s
#    100   107 1768.50404   10  106 1767.00000 1768.54849  0.09%  36.8  175s
#    106   248 1768.50405   10   96 1767.00000 1768.54849  0.09%  35.6  185s
#    247   254 1768.50305   25   92 1767.00000 1768.54849  0.09%  20.4  202s
# H  248   254                    1768.0000000 1768.54849  0.03%  20.3  202s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 15
#   Implied bound: 2
#   MIR: 169
#   StrongCG: 18
#   RLT: 2
#   Relax-and-lift: 3
#
# Explored 253 nodes (24843 simplex iterations) in 203.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1768 1767 1764 1730
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.768000000000e+03, best bound 1.768000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2.5x2

# %%
datafile="4x2000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xa52fb199
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1736.0000000
# Presolve removed 33 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2480276 nonzeros (31%)
# Presolve added 0 rows and 116 columns
# Presolve removed 45 rows and 0 columns
# Presolve time: 25.99s
# Presolved: 9955 rows, 8116 columns, 5491700 nonzeros
# Variable types: 136 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.429521e+06   0.000000e+00     28s
#     2166    1.7774617e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 1.777462e+03, 2166 iterations, 2.28 seconds
# Total elapsed time = 32.11s
# Total elapsed time = 36.19s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1777.46168    0  122 1736.00000 1777.46168  2.39%     -   36s
# H    0     0                    1773.0000000 1777.46168  0.25%     -   37s
# H    0     0                    1775.0000000 1777.46168  0.14%     -   37s
#      0     0 1777.39620    0  106 1775.00000 1777.39620  0.13%     -   41s
# H    0     0                    1776.0000000 1777.39620  0.08%     -   43s
#      0     0 1777.31170    0   96 1776.00000 1777.31170  0.07%     -   44s
#      0     0 1777.31169    0   96 1776.00000 1777.31169  0.07%     -   45s
#      0     0     cutoff    0      1776.00000 1776.00000  0.00%     -   49s
#
# Cutting planes:
#   Gomory: 37
#   MIR: 69
#   RLT: 1
#
# Explored 1 nodes (9137 simplex iterations) in 49.32 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1776 1775 1773 1736
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.776000000000e+03, best bound 1.776000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2.5x3

# %%
datafile="4x2000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x36ba9f68
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1737.0000000
# Presolve removed 23 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 20s) ...
# Sparsify removed 2509244 nonzeros (31%)
# Presolve added 0 rows and 124 columns
# Presolve removed 27 rows and 0 columns
# Presolve time: 22.30s
# Presolved: 9973 rows, 8124 columns, 5478732 nonzeros
# Variable types: 136 continuous, 7988 integer (7988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.410232e+06   0.000000e+00     24s
#      540    1.7931121e+03   4.249986e+04   0.000000e+00     25s
#     2198    1.7740546e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.774055e+03, 2198 iterations, 1.75 seconds
# Total elapsed time = 31.86s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1774.05460    0  294 1737.00000 1774.05460  2.13%     -   34s
# H    0     0                    1768.0000000 1774.05460  0.34%     -   35s
# H    0     0                    1770.0000000 1774.05460  0.23%     -   35s
#      0     0 1774.05210    0  334 1770.00000 1774.05210  0.23%     -   41s
# H    0     0                    1773.0000000 1774.05210  0.06%     -   46s
#      0     0 1774.03993    0  317 1773.00000 1774.03993  0.06%     -   47s
#      0     0 1774.03412    0  313 1773.00000 1774.03412  0.06%     -   48s
#      0     0 1774.03412    0  311 1773.00000 1774.03412  0.06%     -   49s
#
# Cutting planes:
#   Gomory: 70
#   Cover: 18
#   Implied bound: 4
#   MIR: 302
#   StrongCG: 5
#   Mod-K: 1
#   RLT: 1
#
# Explored 1 nodes (13900 simplex iterations) in 54.20 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1773 1770 1768 1737
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.773000000000e+03, best bound 1.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2.5x4

# %%
datafile="4x2000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x24aa59b7
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1731.0000000
# Presolve removed 13 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 20s) ...
# Sparsify removed 2469163 nonzeros (31%)
# Presolve added 0 rows and 131 columns
# Presolve removed 21 rows and 0 columns
# Presolve time: 21.77s
# Presolved: 9979 rows, 8131 columns, 5534797 nonzeros
# Variable types: 135 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9990000e+03   1.442130e+06   0.000000e+00     24s
#     1026    1.7781382e+03   5.329920e+04   0.000000e+00     25s
#     2332    1.7741325e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.774133e+03, 2332 iterations, 2.07 seconds
# Total elapsed time = 30.45s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1774.13253    0  262 1731.00000 1774.13253  2.49%     -   32s
# H    0     0                    1767.0000000 1774.13253  0.40%     -   32s
# H    0     0                    1771.0000000 1774.13253  0.18%     -   32s
#      0     0 1774.11848    0  304 1771.00000 1774.11848  0.18%     -   37s
# H    0     0                    1772.0000000 1774.11848  0.12%     -   41s
#      0     0 1773.86602    0  291 1772.00000 1773.86602  0.11%     -   42s
#      0     0 1773.73412    0  281 1772.00000 1773.73412  0.10%     -   44s
#      0     0 1773.73249    0  279 1772.00000 1773.73249  0.10%     -   45s
#      0     0 1773.73249    0  280 1772.00000 1773.73249  0.10%     -   46s
#      0     0 1773.72485    0  232 1772.00000 1773.72485  0.10%     -   51s
#      0     0 1773.72416    0  242 1772.00000 1773.72416  0.10%     -   54s
#      0     0 1773.72290    0  238 1772.00000 1773.72290  0.10%     -   55s
#      0     0 1773.72286    0  236 1772.00000 1773.72286  0.10%     -   57s
#      0     0 1773.72139    0  205 1772.00000 1773.72139  0.10%     -   62s
#      0     0 1773.72139    0  197 1772.00000 1773.72139  0.10%     -   63s
#      0     0 1773.71974    0  178 1772.00000 1773.71974  0.10%     -   68s
#      0     0 1773.65227    0  174 1772.00000 1773.65227  0.09%     -   70s
#      0     0 1773.64726    0  184 1772.00000 1773.64726  0.09%     -   72s
#      0     0 1773.64726    0  188 1772.00000 1773.64726  0.09%     -   73s
#      0     0 1773.59514    0  166 1772.00000 1773.59514  0.09%     -   77s
#      0     0 1773.59514    0  151 1772.00000 1773.59514  0.09%     -   79s
#      0     0 1773.59514    0  179 1772.00000 1773.59514  0.09%     -   83s
#      0     0 1773.59514    0  186 1772.00000 1773.59514  0.09%     -   85s
#      0     0 1773.59514    0  185 1772.00000 1773.59514  0.09%     -   91s
# H    0     0                    1773.0000000 1773.59514  0.03%     -   93s
#      0     0 1773.59514    0  185 1773.00000 1773.59514  0.03%     -   93s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 7
#   MIR: 70
#   GUB cover: 2
#   RLT: 3
#
# Explored 1 nodes (16009 simplex iterations) in 93.67 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1773 1772 1771 ... 1731
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.773000000000e+03, best bound 1.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x2.5x5

# %%
datafile="4x2000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x09b46135
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1729.0000000
# Presolve removed 68 rows and 48 columns (presolve time = 5s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 10s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 15s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 20s) ...
# Sparsify removed 2513291 nonzeros (32%)
# Presolve added 0 rows and 91 columns
# Presolve removed 76 rows and 0 columns
# Presolve time: 22.15s
# Presolved: 9924 rows, 8091 columns, 5402893 nonzeros
# Variable types: 139 continuous, 7952 integer (7952 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9880000e+03   1.433200e+06   0.000000e+00     24s
#      639    1.7792434e+03   1.651867e+04   0.000000e+00     25s
#     1879    1.7685639e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.768564e+03, 1879 iterations, 1.90 seconds
# Total elapsed time = 31.21s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1768.56391    0  156 1729.00000 1768.56391  2.29%     -   36s
# H    0     0                    1763.0000000 1768.56391  0.32%     -   36s
# H    0     0                    1765.0000000 1768.56391  0.20%     -   37s
# H    0     0                    1766.0000000 1768.56391  0.15%     -   37s
#      0     0 1768.33336    0  185 1766.00000 1768.33336  0.13%     -   42s
# H    0     0                    1767.0000000 1768.33336  0.08%     -   46s
#      0     0 1768.21550    0  152 1767.00000 1768.21550  0.07%     -   47s
#      0     0 1768.21549    0  146 1767.00000 1768.21549  0.07%     -   48s
#      0     0 1768.19793    0  113 1767.00000 1768.19793  0.07%     -   54s
#      0     0 1768.19611    0  104 1767.00000 1768.19611  0.07%     -   58s
#      0     0 1768.19611    0  106 1767.00000 1768.19611  0.07%     -   60s
#      0     0 1768.19148    0   89 1767.00000 1768.19148  0.07%     -   66s
#      0     0 1768.19148    0   83 1767.00000 1768.19148  0.07%     -   72s
#      0     0 1768.18994    0   75 1767.00000 1768.18994  0.07%     -   78s
#      0     0 1768.18994    0   73 1767.00000 1768.18994  0.07%     -   82s
#      0     0 1768.18653    0   92 1767.00000 1768.18653  0.07%     -   89s
#      0     0 1768.18653    0   82 1767.00000 1768.18653  0.07%     -   91s
#      0     0 1768.07590    0   82 1767.00000 1768.07590  0.06%     -   96s
#      0     0 1768.07590    0   79 1767.00000 1768.07590  0.06%     -   98s
#      0     0     cutoff    0      1767.00000 1767.00000  0.00%     -  102s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 2
#   MIR: 79
#   StrongCG: 3
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (10972 simplex iterations) in 103.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1767 1766 1765 ... 1729
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.767000000000e+03, best bound 1.767000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3x1

# %%
datafile="4x2000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xec4c3b02
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1558.0000000
# Presolve removed 71 rows and 44 columns (presolve time = 9s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 16s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 29s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 30s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 35s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 40s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 45s) ...
# Presolve removed 71 rows and 44 columns (presolve time = 50s) ...
# Sparsify removed 2504830 nonzeros (32%)
# Presolve added 0 rows and 94 columns
# Presolve removed 79 rows and 0 columns
# Presolve time: 54.37s
# Presolved: 9921 rows, 8094 columns, 5419270 nonzeros
# Variable types: 138 continuous, 7956 integer (7956 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9890000e+03   1.452030e+06   0.000000e+00     59s
#      629    1.6288855e+03   2.633185e+05   0.000000e+00     61s
#     2049    1.6069792e+03   0.000000e+00   0.000000e+00     63s
#
# Root relaxation: objective 1.606979e+03, 2049 iterations, 4.58 seconds
# Total elapsed time = 65.83s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1606.97921    0  130 1558.00000 1606.97921  3.14%     -   67s
# H    0     0                    1604.0000000 1606.97921  0.19%     -   68s
# H    0     0                    1605.0000000 1606.97921  0.12%     -   69s
#      0     0 1606.93433    0   94 1605.00000 1606.93433  0.12%     -   72s
# H    0     0                    1606.0000000 1606.93433  0.06%     -   75s
#      0     0 1606.93433    0   94 1606.00000 1606.93433  0.06%     -   75s
#
# Cutting planes:
#   Gomory: 11
#   MIR: 20
#   StrongCG: 1
#
# Explored 1 nodes (5833 simplex iterations) in 75.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1606 1605 1604 1558
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.606000000000e+03, best bound 1.606000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3x2

# %%
datafile="4x2000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x36c415a1
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1555.0000000
# Presolve removed 67 rows and 44 columns (presolve time = 5s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 10s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 15s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 20s) ...
# Sparsify removed 2498302 nonzeros (32%)
# Presolve added 0 rows and 94 columns
# Presolve removed 75 rows and 0 columns
# Presolve time: 21.73s
# Presolved: 9925 rows, 8094 columns, 5425814 nonzeros
# Variable types: 138 continuous, 7956 integer (7956 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9890000e+03   1.480314e+06   0.000000e+00     24s
#     1006    1.6131403e+03   2.618039e+04   0.000000e+00     25s
#     2499    1.6108027e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.610803e+03, 2499 iterations, 2.66 seconds
# Total elapsed time = 30.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1610.80270    0  249 1555.00000 1610.80270  3.59%     -   32s
# H    0     0                    1606.0000000 1610.80270  0.30%     -   32s
# H    0     0                    1608.0000000 1610.80270  0.17%     -   32s
#      0     0 1610.80016    0  249 1608.00000 1610.80016  0.17%     -   37s
# H    0     0                    1609.0000000 1610.80016  0.11%     -   41s
#      0     0 1610.78793    0  228 1609.00000 1610.78793  0.11%     -   42s
#      0     0 1610.78788    0  224 1609.00000 1610.78788  0.11%     -   43s
#      0     0 1610.77589    0  172 1609.00000 1610.77589  0.11%     -   47s
#      0     0 1610.76478    0  150 1609.00000 1610.76478  0.11%     -   49s
#      0     0 1610.76478    0  150 1609.00000 1610.76478  0.11%     -   51s
#      0     0 1610.76143    0  129 1609.00000 1610.76143  0.11%     -   55s
#      0     0 1610.76143    0  143 1609.00000 1610.76143  0.11%     -   57s
#      0     0 1610.76143    0  135 1609.00000 1610.76143  0.11%     -   61s
#      0     0 1610.75759    0  124 1609.00000 1610.75759  0.11%     -   62s
#      0     0 1610.75759    0  117 1609.00000 1610.75759  0.11%     -   64s
#      0     0 1610.75337    0  118 1609.00000 1610.75337  0.11%     -   74s
#      0     0 1610.75292    0  124 1609.00000 1610.75292  0.11%     -   75s
#      0     0 1610.75292    0  126 1609.00000 1610.75292  0.11%     -   76s
#      0     0 1610.75291    0  136 1609.00000 1610.75291  0.11%     -   80s
#      0     0 1610.75113    0  134 1609.00000 1610.75113  0.11%     -   82s
#      0     0 1610.75113    0  133 1609.00000 1610.75113  0.11%     -   83s
#      0     0 1610.75113    0  128 1609.00000 1610.75113  0.11%     -   86s
# H    0     0                    1610.0000000 1610.75113  0.05%     -   88s
#      0     0 1610.75113    0  128 1610.00000 1610.75113  0.05%     -   88s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 1
#   MIR: 115
#   StrongCG: 1
#
# Explored 1 nodes (13572 simplex iterations) in 88.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1610 1609 1608 ... 1555
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.610000000000e+03, best bound 1.610000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3x3

# %%
datafile="4x2000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x0447ba0d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1558.0000000
# Presolve removed 61 rows and 36 columns (presolve time = 5s) ...
# Presolve removed 61 rows and 36 columns (presolve time = 10s) ...
# Presolve removed 61 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 61 rows and 36 columns (presolve time = 20s) ...
# Presolve removed 61 rows and 36 columns (presolve time = 25s) ...
# Sparsify removed 2501062 nonzeros (31%)
# Presolve added 0 rows and 102 columns
# Presolve removed 81 rows and 0 columns
# Presolve time: 27.22s
# Presolved: 9919 rows, 8102 columns, 5438946 nonzeros
# Variable types: 138 continuous, 7964 integer (7964 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9910000e+03   1.470582e+06   0.000000e+00     29s
#      737    1.6515234e+03   1.165739e+05   0.000000e+00     31s
#     2285    1.6115799e+03   0.000000e+00   0.000000e+00     32s
#
# Root relaxation: objective 1.611580e+03, 2285 iterations, 2.95 seconds
# Total elapsed time = 35.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1611.57993    0  210 1558.00000 1611.57993  3.44%     -   38s
# H    0     0                    1607.0000000 1611.57993  0.28%     -   39s
# H    0     0                    1608.0000000 1611.57993  0.22%     -   39s
#      0     0 1611.56200    0  175 1608.00000 1611.56200  0.22%     -   43s
# H    0     0                    1610.0000000 1611.56200  0.10%     -   47s
#      0     0 1611.53755    0  148 1610.00000 1611.53755  0.10%     -   47s
#      0     0 1611.53755    0  147 1610.00000 1611.53755  0.10%     -   49s
#      0     0 1611.52540    0  133 1610.00000 1611.52540  0.09%     -   53s
#      0     0 1611.33454    0  151 1610.00000 1611.33454  0.08%     -   55s
#      0     0 1611.33454    0  158 1610.00000 1611.33454  0.08%     -   56s
#      0     0 1611.33410    0  154 1610.00000 1611.33410  0.08%     -   61s
#      0     0 1611.30366    0  132 1610.00000 1611.30366  0.08%     -   66s
#      0     0 1611.30161    0  126 1610.00000 1611.30161  0.08%     -   67s
#      0     0 1611.30161    0  134 1610.00000 1611.30161  0.08%     -   69s
#      0     0 1611.29422    0  141 1610.00000 1611.29422  0.08%     -   73s
#      0     0 1611.29386    0  153 1610.00000 1611.29386  0.08%     -   75s
#      0     0 1611.29386    0  150 1610.00000 1611.29386  0.08%     -   76s
#      0     0 1611.29386    0  148 1610.00000 1611.29386  0.08%     -   81s
#      0     0 1611.29332    0  125 1610.00000 1611.29332  0.08%     -   82s
#      0     0 1611.29315    0  132 1610.00000 1611.29315  0.08%     -   83s
#      0     0 1611.29303    0  141 1610.00000 1611.29303  0.08%     -   87s
#      0     0 1611.29155    0  136 1610.00000 1611.29155  0.08%     -   89s
#      0     0 1611.28558    0  147 1610.00000 1611.28558  0.08%     -   90s
#      0     0 1611.21794    0  141 1610.00000 1611.21794  0.08%     -   92s
#      0     0 1611.21794    0  144 1610.00000 1611.21794  0.08%     -   93s
#      0     0 1611.21794    0  126 1610.00000 1611.21794  0.08%     -   97s
#      0     0 1611.21794    0  117 1610.00000 1611.21794  0.08%     -   99s
#      0     0 1611.21741    0  127 1610.00000 1611.21741  0.08%     -  102s
#      0     0 1611.21655    0  127 1610.00000 1611.21655  0.08%     -  103s
#      0     0 1611.21631    0  125 1610.00000 1611.21631  0.08%     -  105s
#      0     0 1611.21563    0  133 1610.00000 1611.21563  0.08%     -  106s
#      0     0 1611.21561    0  132 1610.00000 1611.21561  0.08%     -  107s
#      0     0 1611.21554    0  141 1610.00000 1611.21554  0.08%     -  110s
#      0     0 1611.21347    0  134 1610.00000 1611.21347  0.08%     -  112s
#      0     0 1611.21347    0  131 1610.00000 1611.21347  0.08%     -  113s
#      0     0 1611.21347    0  140 1610.00000 1611.21347  0.08%     -  117s
#      0     0 1611.21347    0  109 1610.00000 1611.21347  0.08%     -  124s
#      0     2 1611.21347    0  108 1610.00000 1611.21347  0.08%     -  132s
#      3     8 1611.21175    2  126 1610.00000 1611.21347  0.08%   461  138s
#      7    14 1611.21175    3  113 1610.00000 1611.21194  0.08%   254  140s
#     31    38 1611.21175    5  120 1610.00000 1611.21194  0.08%  90.5  153s
#     46    74 1611.20823    7  116 1610.00000 1611.21194  0.08%  66.5  156s
#     73    90 1611.20823    8  119 1610.00000 1611.21194  0.08%  47.9  163s
#     89   230 1611.07878    8  143 1610.00000 1611.21194  0.08%  42.1  174s
#    229   473 1611.18117   25   94 1610.00000 1611.21194  0.08%  23.9  194s
#    497   703 1611.12841   57  103 1610.00000 1611.21175  0.08%  15.3  219s
#    750  1058 1611.19147   21  112 1610.00000 1611.21175  0.08%  13.2  252s
#   1109  1379 1611.11722   86   77 1610.00000 1611.21175  0.08%  11.0  283s
#   1503  1753 1611.10628  137   79 1610.00000 1611.21175  0.08%  10.1  309s
#   1901  2317 1611.09712  188   74 1610.00000 1611.21175  0.08%   9.6  335s
#   2510  2617 1611.01872  253   57 1610.00000 1611.21175  0.08%   8.7  359s
#   2889  2618 1611.20677   21  109 1610.00000 1611.21175  0.08%   8.6  454s
#   2891  2619 1611.03317   36  167 1610.00000 1611.21175  0.08%   8.6  489s
#   2892  2620 1611.00000  487  135 1610.00000 1611.21175  0.08%   8.6  507s
#   2893  2621 1611.02659  227  147 1610.00000 1611.21175  0.08%   8.6  510s
#   2896  2623 1611.12084   67  145 1610.00000 1611.21175  0.08%   8.6  520s
#   2897  2623 1611.08964  211   99 1610.00000 1611.19782  0.07%   8.6  543s
#   2898  2624 1611.00807   77   87 1610.00000 1611.19256  0.07%   8.6  545s
#   2899  2625 1611.17143  117   89 1610.00000 1611.19256  0.07%   8.6  558s
#   2900  2625 1610.99928  189   71 1610.00000 1611.19256  0.07%   8.6  577s
#   2901  2626 1611.02659  237   82 1610.00000 1611.19256  0.07%   8.6  587s
#   2902  2627 1611.00000  486   71 1610.00000 1611.19256  0.07%   8.6  603s
#   2903  2627 1611.19256   20   73 1610.00000 1611.19256  0.07%   8.6  611s
#   2904  2628 1611.15809  137   75 1610.00000 1611.19256  0.07%   8.6  627s
#   2905  2629 1611.15035  115   75 1610.00000 1611.19256  0.07%   8.6  640s
#   2906  2629 1611.02128  246   68 1610.00000 1611.19256  0.07%   8.6  655s
#   2907  2630 1611.14356  206   78 1610.00000 1611.19256  0.07%   8.5  666s
#   2908  2631 1611.19256   81   69 1610.00000 1611.19256  0.07%   8.5  682s
#   2909  2631 1611.00565   97   70 1610.00000 1611.19256  0.07%   8.5  696s
#   2910  2632 1611.03181  162   68 1610.00000 1611.19256  0.07%   8.5  712s
#   2911  2633 1611.16782   46   67 1610.00000 1611.19256  0.07%   8.5  729s
#   2912  2633 1610.99981  126   64 1610.00000 1611.19256  0.07%   8.5  750s
#   2913  2634 1611.03241  159   89 1610.00000 1611.19256  0.07%   8.5  761s
#   2914  2635 1611.11076  114   73 1610.00000 1611.19256  0.07%   8.5  780s
#   2915  2635 1611.08657  232   66 1610.00000 1611.19256  0.07%   8.5  790s
#   2917  2638 1610.99928  139  109 1610.00000 1611.19256  0.07%  22.7  865s
#   2919  2639 1611.17143  114  195 1610.00000 1611.19256  0.07%  22.7  905s
#   2920  2640 1611.19256    8   95 1610.00000 1611.19256  0.07%  22.7  934s
#   2921  2641 1610.99928  174   92 1610.00000 1611.19256  0.07%  22.7  947s
#   2922  2641 1611.15226   80   99 1610.00000 1611.19256  0.07%  22.7  981s
#   2923  2642 1611.08671   76   97 1610.00000 1611.19256  0.07%  22.7  998s
#   2924  2643 1611.00072  182   93 1610.00000 1611.19256  0.07%  22.7 1048s
#   2925  2643 1611.18749   69   98 1610.00000 1611.19256  0.07%  22.6 1085s
#   2926  2644 1610.99928  146  112 1610.00000 1611.19256  0.07%  22.6 1119s
#   2927  2645 1610.99872  220  105 1610.00000 1611.19256  0.07%  22.6 1143s
#   2928  2645 1611.18943   32   99 1610.00000 1611.19256  0.07%  22.6 1181s
#   2929  2646 1611.01051  158  116 1610.00000 1611.19256  0.07%  22.6 1195s
#   2930  2647 1611.09127   89  102 1610.00000 1611.19256  0.07%  22.6 1219s
#   2931  2647 1611.17143  119   99 1610.00000 1611.19256  0.07%  22.6 1267s
#   2932  2648 1611.03181  170   84 1610.00000 1611.19256  0.07%  22.6 1325s
#   2933  2649 1611.17221  103   92 1610.00000 1611.19256  0.07%  22.6 1353s
#   2934  2649 1611.01778  270   78 1610.00000 1611.19256  0.07%  22.6 1400s
#   2936  2651 1611.11796   80  102 1610.00000 1611.19256  0.07%  22.6 1427s
#   2937  2651 1611.00067  203   95 1610.00000 1611.19256  0.07%  22.6 1462s
#   2938  2652 1611.00000  436   93 1610.00000 1611.19256  0.07%  22.5 1488s
#   2939  2653 1610.99928  184   92 1610.00000 1611.19256  0.07%  22.5 1517s
#   2940  2653 1611.10050  218   93 1610.00000 1611.19256  0.07%  22.5 1534s
#   2941  2654 1611.10050  195   70 1610.00000 1611.19256  0.07%  22.5 1575s
#   2942  2655 1611.01241  107   95 1610.00000 1611.19256  0.07%  22.5 1593s
#   2943  2655 1611.01245  115   79 1610.00000 1611.19256  0.07%  22.5 1622s
#   2944  2656 1611.08420   81   98 1610.00000 1611.19256  0.07%  22.5 1632s
#   2945  2657 1610.99872  204   84 1610.00000 1611.19256  0.07%  22.5 1659s
#   2946  2657 1611.19256   35   89 1610.00000 1611.19256  0.07%  22.5 1676s
#   2947  2658 1611.08796   68   70 1610.00000 1611.19256  0.07%  22.5 1705s
#   2948  2659 1610.99981  126   84 1610.00000 1611.19256  0.07%  22.5 1723s
#   2949  2659 1611.01051  140   73 1610.00000 1611.19256  0.07%  22.5 1748s
#   2950  2660 1611.19256   25   65 1610.00000 1611.19256  0.07%  22.5 1769s
#   2951  2661 1611.00565   94   65 1610.00000 1611.19256  0.07%  22.4 1786s
#   2952  2664 1611.19256   23   65 1610.00000 1611.19256  0.07%  39.4 1792s
#   2954  2668 1611.19256   24   65 1610.00000 1611.19256  0.07%  39.4 1795s
#   2970  2679 1611.15860   26   61 1610.00000 1611.19256  0.07%  39.3 1800s
#   2982  2687 1611.15699   27   61 1610.00000 1611.19256  0.07%  39.2 1813s
#   2988  2693 1611.19256   28   64 1610.00000 1611.19256  0.07%  39.2 1815s
#   3011  2709 1611.15497   29   58 1610.00000 1611.19256  0.07%  39.0 1821s
#   3024  2778 1611.15497   30   55 1610.00000 1611.19256  0.07%  38.9 1829s
#   3098  2866 1611.19256   34   66 1610.00000 1611.19256  0.07%  38.3 1844s
#   3214  3138 1611.19256   39   64 1610.00000 1611.19256  0.07%  37.4 1877s
#   3541  3385 1611.13506   75   68 1610.00000 1611.19256  0.07%  34.8 1916s
#   3998  3290 1611.12620  117   67 1610.00000 1611.19256  0.07%  32.7 2019s
#   4064  3349 1611.06058  122   59 1610.00000 1611.19256  0.07%  32.4 2046s
#   4225  4153 1611.12580  123   68 1610.00000 1611.19256  0.07%  32.3 2125s
#   5273  4291 1611.13506   74   78 1610.00000 1611.17626  0.07%  29.0 2169s
#   5872  4684 1611.00000  252   72 1610.00000 1611.17626  0.07%  29.3 2215s
#   6498  4481 1611.00000  333   69 1610.00000 1611.17626  0.07%  27.6 2257s
#   6504  4974 1611.00000  334   69 1610.00000 1611.17626  0.07%  27.6 2308s
#   7003  5249 1611.00000  390   78 1610.00000 1611.17626  0.07%  26.5 2352s
#   7449  5634 1611.00000  453   71 1610.00000 1611.17626  0.07%  25.8 2403s
#   7991  5962 1611.00000  524   59 1610.00000 1611.17626  0.07%  25.1 2455s
#   8510  6326 1611.00000  613   46 1610.00000 1611.17626  0.07%  24.5 2515s
#   9089  6688 1611.00000  689   46 1610.00000 1611.17626  0.07%  24.0 2577s
#   9679  7107 1611.00000  763   63 1610.00000 1611.17626  0.07%  23.6 2642s
#  10318  7521 1610.99956  876   54 1610.00000 1611.17626  0.07%  23.0 2703s
#  11004  7898 1610.99956  975   54 1610.00000 1611.17626  0.07%  22.2 2766s
#  11751  8623 1611.00670   45   64 1610.00000 1611.17626  0.07%  21.5 2834s
#  12663  9720 1611.11661   42   80 1610.00000 1611.17626  0.07%  20.9 3100s
#  13926  9735 1611.04164  101   53 1610.00000 1611.17626  0.07%  20.1 3132s
#  13943 10511 1611.04164  103   49 1610.00000 1611.17626  0.07%  20.1 3168s
#  14743 11209 1611.01339  270   95 1610.00000 1611.17460  0.07%  19.7 3203s
#  15542 12011 1611.01839   83   77 1610.00000 1611.17460  0.07%  19.5 3237s
#  16430 12663 1610.99841  260   78 1610.00000 1611.17460  0.07%  19.2 3273s
#  17283 13379 1610.99841  346   81 1610.00000 1611.17460  0.07%  18.8 3312s
#  18092 14261 1611.07960  111   99 1610.00000 1611.17460  0.07%  18.5 3353s
#  19071 15090 1611.06803  367   92 1610.00000 1611.17460  0.07%  18.0 3393s
#  20119 16320 1611.00000  546   71 1610.00000 1611.17460  0.07%  17.7 3433s
#  21507 17603 1611.00000  778   48 1610.00000 1611.17460  0.07%  17.3 3471s
#  22806 18713 1611.00000  999   43 1610.00000 1611.17460  0.07%  16.9 3506s
#  23976 19970 1611.00000 1152   55 1610.00000 1611.17190  0.07%  16.9 3541s
#
# Cutting planes:
#   Gomory: 26
#   MIR: 50
#   Flow cover: 76
#
# Explored 25354 nodes (434311 simplex iterations) in 3600.50 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1610 1608 1607 1558
#
# Time limit reached
# Best objective 1.610000000000e+03, best bound 1.611000000000e+03, gap 0.0621%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3x4

# %%
datafile="4x2000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xdae2c2c0
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1559.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 5s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 14s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 15s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 20s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 25s) ...
# Sparsify removed 2493957 nonzeros (31%)
# Presolve added 0 rows and 109 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 26.80s
# Presolved: 9953 rows, 8109 columns, 5462071 nonzeros
# Variable types: 137 continuous, 7972 integer (7972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.472922e+06   0.000000e+00     29s
#      614    1.6526341e+03   3.261053e+04   0.000000e+00     30s
#     2098    1.6137791e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.613779e+03, 2098 iterations, 2.54 seconds
# Total elapsed time = 35.65s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1613.77908    0  176 1559.00000 1613.77908  3.51%     -   36s
# H    0     0                    1609.0000000 1613.77908  0.30%     -   37s
# H    0     0                    1611.0000000 1613.77908  0.17%     -   37s
# H    0     0                    1612.0000000 1613.77908  0.11%     -   38s
#      0     0 1613.76686    0  204 1612.00000 1613.76686  0.11%     -   42s
#      0     0 1613.75565    0  186 1612.00000 1613.75565  0.11%     -   47s
#      0     0 1613.75565    0  184 1612.00000 1613.75565  0.11%     -   47s
#      0     0 1613.70466    0  158 1612.00000 1613.70466  0.11%     -   52s
#      0     0 1613.70466    0  156 1612.00000 1613.70466  0.11%     -   54s
#      0     0 1613.70229    0  147 1612.00000 1613.70229  0.11%     -   59s
#      0     0 1613.70092    0  136 1612.00000 1613.70092  0.11%     -   60s
#      0     0 1613.70092    0  141 1612.00000 1613.70092  0.11%     -   61s
#      0     0 1613.67157    0  155 1612.00000 1613.67157  0.10%     -   65s
#      0     0 1613.64320    0  138 1612.00000 1613.64320  0.10%     -   67s
#      0     0 1613.64320    0  139 1612.00000 1613.64320  0.10%     -   68s
#      0     0 1613.60219    0  125 1612.00000 1613.60219  0.10%     -   72s
# H    0     0                    1613.0000000 1613.60219  0.04%     -   74s
#      0     0 1613.60219    0  125 1613.00000 1613.60219  0.04%     -   74s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 3
#   MIR: 70
#   StrongCG: 5
#   RLT: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (8485 simplex iterations) in 74.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1613 1612 1611 ... 1559
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.613000000000e+03, best bound 1.613000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3x5

# %%
datafile="4x2000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xfe80f2e7
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1549.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 10s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 16s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2509805 nonzeros (31%)
# Presolve added 0 rows and 117 columns
# Presolve removed 37 rows and 0 columns
# Presolve time: 28.45s
# Presolved: 9963 rows, 8117 columns, 5462183 nonzeros
# Variable types: 137 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.463187e+06   0.000000e+00     30s
#     2420    1.6090921e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 1.609092e+03, 2420 iterations, 2.49 seconds
# Total elapsed time = 35.82s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1609.09209    0  251 1549.00000 1609.09209  3.88%     -   39s
# H    0     0                    1604.0000000 1609.09209  0.32%     -   39s
# H    0     0                    1605.0000000 1609.09209  0.25%     -   40s
#      0     0 1609.05834    0  246 1605.00000 1609.05834  0.25%     -   45s
# H    0     0                    1607.0000000 1609.05834  0.13%     -   50s
#      0     0 1608.88136    0  191 1607.00000 1608.88136  0.12%     -   50s
#      0     0 1608.87916    0  193 1607.00000 1608.87916  0.12%     -   51s
#      0     0 1608.86945    0  187 1607.00000 1608.86945  0.12%     -   52s
#      0     0 1608.86937    0  188 1607.00000 1608.86937  0.12%     -   53s
#      0     0 1608.84439    0  168 1607.00000 1608.84439  0.11%     -   58s
#      0     0 1608.62773    0  186 1607.00000 1608.62773  0.10%     -   61s
#      0     0 1608.62422    0  187 1607.00000 1608.62422  0.10%     -   62s
#      0     0 1608.61746    0  180 1607.00000 1608.61746  0.10%     -   64s
#      0     0 1608.61745    0  178 1607.00000 1608.61745  0.10%     -   65s
#      0     0 1608.61732    0  173 1607.00000 1608.61732  0.10%     -   69s
#      0     0 1608.53254    0  178 1607.00000 1608.53254  0.10%     -   72s
#      0     0 1608.53137    0  172 1607.00000 1608.53137  0.10%     -   73s
#      0     0 1608.51850    0  167 1607.00000 1608.51850  0.09%     -   74s
#      0     0 1608.51850    0  166 1607.00000 1608.51850  0.09%     -   76s
#      0     0 1608.50406    0  178 1607.00000 1608.50406  0.09%     -   80s
#      0     0 1608.49592    0  164 1607.00000 1608.49592  0.09%     -   82s
#      0     0 1608.49592    0  172 1607.00000 1608.49592  0.09%     -   84s
#      0     0 1608.48980    0  162 1607.00000 1608.48980  0.09%     -   90s
#      0     0 1608.48913    0  158 1607.00000 1608.48913  0.09%     -   97s
#      0     0 1608.48913    0  159 1607.00000 1608.48913  0.09%     -   99s
#      0     0 1608.48656    0  152 1607.00000 1608.48656  0.09%     -  106s
#      0     0 1608.48639    0  149 1607.00000 1608.48639  0.09%     -  108s
#      0     0 1608.48399    0  146 1607.00000 1608.48399  0.09%     -  113s
#      0     0 1608.48308    0  123 1607.00000 1608.48308  0.09%     -  115s
#      0     0 1608.48308    0  128 1607.00000 1608.48308  0.09%     -  117s
#      0     0 1608.48281    0  128 1607.00000 1608.48281  0.09%     -  122s
#      0     0 1608.48281    0  124 1607.00000 1608.48281  0.09%     -  126s
#      0     0 1608.48168    0  131 1607.00000 1608.48168  0.09%     -  130s
#      0     0 1608.48168    0  126 1607.00000 1608.48168  0.09%     -  132s
#      0     0 1608.48168    0  132 1607.00000 1608.48168  0.09%     -  137s
#      0     0 1608.48168    0   92 1607.00000 1608.48168  0.09%     -  152s
#      0     2 1608.48168    0   92 1607.00000 1608.48168  0.09%     -  166s
#      3     8 1608.48168    2  132 1607.00000 1608.48168  0.09%   514  171s
#      7    14 1608.48155    3  138 1607.00000 1608.48168  0.09%   285  175s
#     19    26 1608.48155    4  134 1607.00000 1608.48168  0.09%   197  184s
#     25    32 1608.48155    5  137 1607.00000 1608.48168  0.09%   175  185s
#     31    38 1608.48155    6  137 1607.00000 1608.48168  0.09%   150  195s
#     44    76 1608.48144    7  137 1607.00000 1608.48168  0.09%   113  203s
#     75   113 1608.48144    9  138 1607.00000 1608.48168  0.09%  74.7  213s
#    112   242 1608.48141   11  142 1607.00000 1608.48168  0.09%  58.3  231s
# H  240   242                    1608.0000000 1608.48168  0.03%  36.1  231s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 11
#   Implied bound: 2
#   MIR: 311
#   StrongCG: 14
#   GUB cover: 1
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 241 nodes (23909 simplex iterations) in 231.89 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1608 1607 1605 ... 1549
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.608000000000e+03, best bound 1.608000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3.5x1

# %%
datafile="4x2000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x1690e5c7
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1419.0000000
# Presolve removed 52 rows and 32 columns (presolve time = 5s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 10s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 20s) ...
# Sparsify removed 2486033 nonzeros (31%)
# Presolve added 0 rows and 105 columns
# Presolve removed 56 rows and 0 columns
# Presolve time: 21.99s
# Presolved: 9944 rows, 8105 columns, 5462003 nonzeros
# Variable types: 137 continuous, 7968 integer (7968 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9920000e+03   1.538781e+06   0.000000e+00     24s
#      612    1.5630672e+03   4.346125e+04   0.000000e+00     25s
#     2354    1.4832453e+03   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 1.483245e+03, 2354 iterations, 2.67 seconds
# Total elapsed time = 30.86s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1483.24527    0  115 1419.00000 1483.24527  4.53%     -   31s
# H    0     0                    1480.0000000 1483.24527  0.22%     -   31s
#      0     0 1482.79577    0  108 1480.00000 1482.79577  0.19%     -   37s
# H    0     0                    1481.0000000 1482.79577  0.12%     -   38s
#      0     0 1482.62326    0   89 1481.00000 1482.62326  0.11%     -   40s
#      0     0 1482.62326    0   89 1481.00000 1482.62326  0.11%     -   41s
#      0     0 1482.48014    0   72 1481.00000 1482.48014  0.10%     -   45s
#      0     0 1482.40587    0   82 1481.00000 1482.40587  0.09%     -   47s
#      0     0 1482.40587    0   78 1481.00000 1482.40587  0.09%     -   48s
#      0     0 1482.14260    0   80 1481.00000 1482.14260  0.08%     -   53s
#      0     0 1482.12661    0   75 1481.00000 1482.12661  0.08%     -   55s
#      0     0 1482.12661    0   78 1481.00000 1482.12661  0.08%     -   56s
#      0     0 1482.12435    0   75 1481.00000 1482.12435  0.08%     -   60s
#      0     0 1482.12435    0   70 1481.00000 1482.12435  0.08%     -   62s
#      0     0 1482.12400    0   67 1481.00000 1482.12400  0.08%     -   66s
#      0     0 1482.12400    0   66 1481.00000 1482.12400  0.08%     -   68s
#      0     0 1482.12391    0   79 1481.00000 1482.12391  0.08%     -   71s
#      0     0 1482.12391    0   75 1481.00000 1482.12391  0.08%     -   72s
#      0     0 1482.12391    0   65 1481.00000 1482.12391  0.08%     -   75s
#      0     0 1482.12391    0   73 1481.00000 1482.12391  0.08%     -   76s
#      0     0 1482.12372    0   67 1481.00000 1482.12372  0.08%     -   82s
#      0     0 1482.12372    0   67 1481.00000 1482.12372  0.08%     -   84s
#      0     0 1482.12310    0   66 1481.00000 1482.12310  0.08%     -   87s
#      0     0 1482.12310    0   66 1481.00000 1482.12310  0.08%     -   88s
#      0     0 1482.12310    0   73 1481.00000 1482.12310  0.08%     -   92s
#      0     0 1482.12310    0   63 1481.00000 1482.12310  0.08%     -   95s
#      0     0 1482.12310    0  100 1481.00000 1482.12310  0.08%     -  115s
#      0     0 1482.12310    0   73 1481.00000 1482.12310  0.08%     -  119s
#      0     0 1482.12310    0   77 1481.00000 1482.12310  0.08%     -  120s
#      0     0 1482.12310    0   68 1481.00000 1482.12310  0.08%     -  122s
#      0     0 1482.12310    0   61 1481.00000 1482.12310  0.08%     -  123s
#      0     0 1482.12310    0   45 1481.00000 1482.12310  0.08%     -  128s
#      0     0 1482.12310    0   58 1481.00000 1482.12310  0.08%     -  129s
#      0     0 1482.12310    0   72 1481.00000 1482.12310  0.08%     -  132s
#      0     0 1482.12310    0   66 1481.00000 1482.12310  0.08%     -  133s
#      0     0 1482.12310    0   54 1481.00000 1482.12310  0.08%     -  138s
#      0     0 1482.12310    0   51 1481.00000 1482.12310  0.08%     -  140s
#      0     0 1482.12310    0   56 1481.00000 1482.12310  0.08%     -  144s
#      0     0 1482.12310    0   59 1481.00000 1482.12310  0.08%     -  145s
#      0     0 1482.12310    0   57 1481.00000 1482.12310  0.08%     -  148s
#      0     0 1482.12310    0   52 1481.00000 1482.12310  0.08%     -  152s
#      0     2 1482.12310    0   50 1481.00000 1482.12310  0.08%     -  160s
#     13    16 1482.06363    4   68 1481.00000 1482.07356  0.07%  64.5  166s
#     46    41 1482.01858    7   66 1481.00000 1482.07356  0.07%  28.7  170s
#     94   130 1482.01849   13   62 1481.00000 1482.07356  0.07%  19.8  176s
#    143   238 1482.01794   21   52 1481.00000 1482.07356  0.07%  17.5  185s
#    251   532 1482.01647   37   52 1481.00000 1482.07356  0.07%  12.6  202s
#    561   817 1482.01252   78   56 1481.00000 1482.07356  0.07%   8.0  224s
#    875   953 1482.00964  114   53 1481.00000 1482.07356  0.07%   6.1  244s
#   1250   954 1482.00660  160   48 1481.00000 1482.07356  0.07%   5.0  263s
#   1623   965 1482.00228  208   47 1481.00000 1482.07347  0.07%   4.4  286s
#   1956  1116 1482.02692   16   76 1481.00000 1482.07347  0.07%   4.3  314s
#   2377  1491 1482.02230   48   47 1481.00000 1482.07347  0.07%   4.1  346s
#   3243  1499 1482.02171  226   45 1481.00000 1482.07347  0.07%   3.6  369s
#   3915  1499 1482.02068  498   45 1481.00000 1482.07347  0.07%   3.2  389s
# H 4293   306                    1482.0000000 1482.07347  0.00%   3.0  410s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 122
#
# Explored 4366 nodes (41752 simplex iterations) in 411.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1482 1481 1480 1419
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.482000000000e+03, best bound 1.482000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3.5x2

# %%
datafile="4x2000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x605bb307
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1422.0000000
# Presolve removed 38 rows and 24 columns (presolve time = 9s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 23s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 25s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 30s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 35s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 40s) ...
# Sparsify removed 2501881 nonzeros (31%)
# Presolve removed 38 rows and 7827 columns (presolve time = 45s) ...
# Presolve added 0 rows and 113 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 45.48s
# Presolved: 9962 rows, 8113 columns, 5462127 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.543214e+06   0.000000e+00     48s
#      623    1.5367998e+03   8.525890e+04   0.000000e+00     50s
#     2787    1.4809353e+03   0.000000e+00   0.000000e+00     52s
#
# Root relaxation: objective 1.480935e+03, 2787 iterations, 4.10 seconds
# Total elapsed time = 57.42s
# Total elapsed time = 61.18s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1480.93527    0  376 1422.00000 1480.93527  4.14%     -   63s
# H    0     0                    1473.0000000 1480.93527  0.54%     -   65s
# H    0     0                    1477.0000000 1480.93527  0.27%     -   65s
# H    0     0                    1478.0000000 1480.93527  0.20%     -   66s
#      0     0 1480.90117    0  315 1478.00000 1480.90117  0.20%     -   75s
# H    0     0                    1479.0000000 1480.90117  0.13%     -   85s
#      0     0 1480.45282    0  294 1479.00000 1480.45282  0.10%     -   87s
#      0     0 1480.45261    0  306 1479.00000 1480.45261  0.10%     -   89s
#      0     0 1480.45197    0  319 1479.00000 1480.45197  0.10%     -   91s
#      0     0 1480.45197    0  323 1479.00000 1480.45197  0.10%     -   94s
#      0     0 1480.43134    0  274 1479.00000 1480.43134  0.10%     -  102s
#      0     0 1480.42561    0  260 1479.00000 1480.42561  0.10%     -  106s
#      0     0 1480.42511    0  257 1479.00000 1480.42511  0.10%     -  108s
#      0     0 1480.42511    0  245 1479.00000 1480.42511  0.10%     -  110s
#      0     0 1480.42014    0  229 1479.00000 1480.42014  0.10%     -  118s
#      0     0 1480.41853    0  222 1479.00000 1480.41853  0.10%     -  120s
#      0     0 1480.41853    0  212 1479.00000 1480.41853  0.10%     -  122s
#      0     0 1480.41847    0  218 1479.00000 1480.41847  0.10%     -  128s
#      0     0 1480.41800    0  216 1479.00000 1480.41800  0.10%     -  130s
#      0     0 1480.41750    0  235 1479.00000 1480.41750  0.10%     -  132s
#      0     0 1480.41715    0  229 1479.00000 1480.41715  0.10%     -  133s
#      0     0 1480.41715    0  227 1479.00000 1480.41715  0.10%     -  134s
#      0     0 1480.27217    0  192 1479.00000 1480.27217  0.09%     -  141s
#      0     0 1480.27217    0  180 1479.00000 1480.27217  0.09%     -  144s
#      0     0 1480.27008    0  183 1479.00000 1480.27008  0.09%     -  152s
#      0     0 1480.26898    0  183 1479.00000 1480.26898  0.09%     -  156s
#      0     0 1480.26898    0  169 1479.00000 1480.26898  0.09%     -  158s
#      0     0 1480.26811    0  176 1479.00000 1480.26811  0.09%     -  164s
#      0     0 1480.26795    0  197 1479.00000 1480.26795  0.09%     -  166s
#      0     0 1480.26795    0  181 1479.00000 1480.26795  0.09%     -  172s
#      0     0 1480.26670    0  191 1479.00000 1480.26670  0.09%     -  175s
#      0     0 1480.26563    0  181 1479.00000 1480.26563  0.09%     -  178s
#      0     0 1480.26563    0  164 1479.00000 1480.26563  0.09%     -  179s
#      0     0 1480.26563    0  161 1479.00000 1480.26563  0.09%     -  185s
#      0     0 1480.26489    0  176 1479.00000 1480.26489  0.09%     -  189s
#      0     0 1480.26487    0  163 1479.00000 1480.26487  0.09%     -  191s
#      0     0 1480.26487    0  167 1479.00000 1480.26487  0.09%     -  199s
#      0     0 1480.26487    0  167 1479.00000 1480.26487  0.09%     -  203s
#      0     2 1480.26487    0  139 1479.00000 1480.26487  0.09%     -  211s
#      7    14 1480.26274    3  166 1479.00000 1480.26443  0.09%   221  215s
#     19    26 1480.26274    5  169 1479.00000 1480.26367  0.09%   146  220s
#     31    38 1480.26274    7  172 1479.00000 1480.26367  0.09%   104  227s
#     37    62 1480.26274    7  166 1479.00000 1480.26367  0.09%  88.9  230s
#     61    98 1480.26120   10  155 1479.00000 1480.26367  0.09%  60.4  235s
#     97   246 1480.25854   18  144 1479.00000 1480.26367  0.09%  44.8  246s
#    245   648 1480.25429   40  135 1479.00000 1480.26367  0.09%  25.6  271s
#    647   951 1480.24070   85   96 1479.00000 1480.26367  0.09%  15.6  294s
#    950  1307 1480.24070  106   95 1479.00000 1480.26367  0.09%  13.3  317s
#   1306  1745 1480.17648  150   68 1479.00000 1480.26367  0.09%  12.0  341s
#   1755  2064 1480.26078   22  151 1479.00000 1480.26367  0.09%  11.2  364s
#   2074  2546 1480.24789   48  112 1479.00000 1480.26367  0.09%  10.7  389s
#   2600  2894 1480.09446  176   69 1479.00000 1480.26367  0.09%  10.1  410s
#   2961  3285 1480.00046  271   51 1479.00000 1480.26367  0.09%  10.0  436s
#   3371  3756 1480.23888   55  108 1479.00000 1480.26367  0.09%  10.2  462s
#   3844  4122 1480.00353  162   80 1479.00000 1480.26367  0.09%  10.1  489s
#   4246  4657 1479.99895  225   81 1479.00000 1480.26367  0.09%   9.8  521s
#   4859  4973 1479.99895  305   76 1479.00000 1480.26367  0.09%   9.5  562s
#   5255  5438 1479.99895  347   72 1479.00000 1480.26367  0.09%   9.3  597s
#   5824  6249 1480.23427   77  136 1479.00000 1480.26367  0.09%   9.2  637s
#   6733  6250 1480.03188  495  167 1479.00000 1480.26367  0.09%   8.9  748s
#   6735  6251 1480.19887  160  275 1479.00000 1480.26367  0.09%   8.9  796s
#   6736  6252 1480.24070  130  200 1479.00000 1480.26367  0.09%   8.9  828s
#   6737  6253 1480.24070  106  195 1479.00000 1480.26367  0.09%   8.9  834s
#   6738  6253 1479.99866  513  172 1479.00000 1480.26367  0.09%   8.9  836s
#   6740  6255 1480.09651  446  168 1479.00000 1480.26367  0.09%   8.9  860s
#   6741  6255 1480.01440  190  159 1479.00000 1480.26367  0.09%   8.9  891s
#   6742  6256 1480.03188  493  139 1479.00000 1480.25027  0.08%   8.9  896s
#   6743  6257 1480.00046  274  145 1479.00000 1480.25014  0.08%   8.9  919s
#   6744  6257 1480.10803  187  109 1479.00000 1480.24737  0.08%   8.9  955s
#   6745  6258 1480.22545   12  126 1479.00000 1480.24737  0.08%   8.9  974s
#   6746  6259 1480.22752   78  120 1479.00000 1480.24726  0.08%   8.9  994s
#   6747  6259 1480.01702  140  114 1479.00000 1480.24636  0.08%   8.9  997s
#   6749  6261 1480.24588   52  129 1479.00000 1480.24588  0.08%   8.9 1015s
#   6750  6261 1480.00891  114  130 1479.00000 1480.24588  0.08%   8.9 1036s
#   6753  6263 1480.00910   97  134 1479.00000 1480.24448  0.08%   8.9 1050s
#   6754  6264 1480.09651  450  135 1479.00000 1480.24448  0.08%   8.9 1068s
#   6755  6265 1480.00140  216  128 1479.00000 1480.24448  0.08%   8.9 1081s
#   6756  6265 1480.24448   27  113 1479.00000 1480.24448  0.08%   8.9 1102s
#   6757  6266 1480.24070  127  112 1479.00000 1480.24448  0.08%   8.9 1111s
#   6758  6267 1480.00487  298   99 1479.00000 1480.24448  0.08%   8.9 1129s
#   6759  6267 1480.24448   17  118 1479.00000 1480.24448  0.08%   8.9 1140s
#   6760  6268 1479.99895  225  103 1479.00000 1480.24448  0.08%   8.9 1156s
#   6761  6269 1480.17081  219  109 1479.00000 1480.24448  0.08%   8.9 1166s
#   6762  6269 1480.23223   83   95 1479.00000 1480.24448  0.08%   8.9 1186s
#   6763  6270 1480.03497  598  111 1479.00000 1480.24448  0.08%   8.9 1201s
#   6764  6271 1480.24448   43   81 1479.00000 1480.24448  0.08%   8.9 1227s
#   6765  6271 1479.99976  123  106 1479.00000 1480.24448  0.08%   8.9 1245s
#   6766  6272 1480.09314  208   97 1479.00000 1480.24448  0.08%   8.9 1269s
#   6767  6273 1480.05168  367   87 1479.00000 1480.24448  0.08%   8.9 1278s
#   6769  6275 1480.22066   85  167 1479.00000 1480.24448  0.08%  15.8 1426s
#   6771  6276 1480.24448   21  254 1479.00000 1480.24448  0.08%  15.8 1470s
#   6772  6277 1480.13534  123  141 1479.00000 1480.24448  0.08%  15.8 1517s
#   6773  6278 1480.23813   50  119 1479.00000 1480.24448  0.08%  15.8 1524s
#   6774  6278 1480.00353  166  127 1479.00000 1480.24448  0.08%  15.8 1525s
#   6775  6279 1480.24070  110  124 1479.00000 1480.24448  0.08%  15.8 1549s
#   6776  6280 1480.00677  275  103 1479.00000 1480.24448  0.08%  15.8 1589s
#   6777  6280 1480.23789   98  107 1479.00000 1480.24430  0.08%  15.8 1591s
#   6778  6281 1480.23874   42  104 1479.00000 1480.24430  0.08%  15.8 1603s
#   6779  6282 1480.03525  590  103 1479.00000 1480.24430  0.08%  15.8 1632s
#   6780  6282 1480.24430   25  115 1479.00000 1480.24430  0.08%  15.8 1653s
#   6781  6283 1480.17636  205  113 1479.00000 1480.24430  0.08%  15.8 1677s
#   6782  6284 1480.01305  669  114 1479.00000 1480.24430  0.08%  15.8 1696s
#   6783  6284 1479.99866  486  114 1479.00000 1480.24430  0.08%  15.8 1728s
#   6784  6285 1480.05846  449  118 1479.00000 1480.24430  0.08%  15.8 1769s
#   6785  6286 1480.15379  132  104 1479.00000 1480.24430  0.08%  15.8 1807s
#   6786  6286 1480.20784  131  108 1479.00000 1480.24430  0.08%  15.8 1830s
#   6787  6287 1480.24025   26  103 1479.00000 1480.24430  0.08%  15.8 1864s
#   6788  6288 1480.23789   95  111 1479.00000 1480.24430  0.08%  15.8 1890s
#   6789  6288 1480.02882  506  103 1479.00000 1480.24430  0.08%  15.8 1920s
#   6790  6289 1480.06656  494  106 1479.00000 1480.24430  0.08%  15.8 1940s
#   6791  6290 1480.23813   61   93 1479.00000 1480.24430  0.08%  15.8 1976s
#   6792  6290 1480.02259  244  113 1479.00000 1480.24430  0.08%  15.8 1999s
#   6793  6291 1480.10490  408  102 1479.00000 1480.24430  0.08%  15.8 2027s
#   6794  6292 1480.24070   87   96 1479.00000 1480.24430  0.08%  15.8 2043s
#   6795  6292 1480.06761  275   96 1479.00000 1480.24430  0.08%  15.8 2101s
#   6796  6296 1480.24430   22   90 1479.00000 1480.24430  0.08%  20.5 2157s
#   6798  6299 1480.24430   23   87 1479.00000 1480.24430  0.08%  20.5 2160s
#   6808  6308 1480.24217   25   90 1479.00000 1480.24217  0.08%  20.6 2166s
#   6826  6320 1480.24010   26   88 1479.00000 1480.24202  0.08%  20.8 2183s
#   6832  6326 1480.24202   27   93 1479.00000 1480.24202  0.08%  20.8 2185s
#   6851  6360 1480.24202   28   89 1479.00000 1480.24202  0.08%  20.7 2195s
#   6880  6445 1480.24202   30   86 1479.00000 1480.24202  0.08%  20.7 2205s
#   6975  6497 1480.24120   38  103 1479.00000 1480.24202  0.08%  20.6 2223s
#   7059  6877 1480.24011   43   92 1479.00000 1480.24202  0.08%  20.5 2251s
#   7467  7154 1480.23604   74   83 1479.00000 1480.24202  0.08%  20.4 2280s
#   7880  7023 1480.23159  104   70 1479.00000 1480.24202  0.08%  20.4 2318s
#   7886  7450 1480.22653  104   72 1479.00000 1480.24202  0.08%  20.4 2344s
#   8315  7699 1480.23120  133   68 1479.00000 1480.24202  0.08%  20.1 2370s
#   8707  8020 1480.20816  164  110 1479.00000 1480.24202  0.08%  20.4 2397s
#   9159  8238 1480.21880  212   55 1479.00000 1480.24202  0.08%  20.2 2424s
#   9528  8677 1480.21394  249   71 1479.00000 1480.24202  0.08%  19.9 2474s
#  10095  8989 1480.21307  303   74 1479.00000 1480.24202  0.08%  19.5 2525s
#  10659  9443 1480.20925  355   61 1479.00000 1480.24202  0.08%  19.1 2563s
#  11332  9752 1480.20434  410   81 1479.00000 1480.24202  0.08%  18.5 2598s
#  11865 10188 1480.20040  444  101 1479.00000 1480.24202  0.08%  17.9 2648s
#  12487 10665 1480.19472  495   88 1479.00000 1480.24202  0.08%  17.5 2700s
#  13178 10441 1480.19134  538   86 1479.00000 1480.24202  0.08%  17.0 3037s
#  13184 12963 1480.19134  539   81 1479.00000 1480.24202  0.08%  17.0 3217s
#  15902 12710 1480.02179  764   79 1479.00000 1480.24202  0.08%  15.5 3269s
#  16689 13665 1480.02179  830   74 1479.00000 1480.24202  0.08%  15.0 3312s
#  18035 14216 1480.02179  922   54 1479.00000 1480.24202  0.08%  14.3 3346s
#  19097 15368 1480.02179 1001   61 1479.00000 1480.24202  0.08%  13.9 3384s
#  20620 16171 1480.02179 1125   54 1479.00000 1480.24202  0.08%  13.4 3420s
#  22014 17307 1480.02179 1209   53 1479.00000 1480.24202  0.08%  12.9 3456s
#  23638 16863 1480.01796 1286   50 1479.00000 1480.24202  0.08%  12.5 3500s
#  23735 18200 1480.01796 1286   47 1479.00000 1480.24202  0.08%  12.4 3531s
#  25123 19468 1480.01796 1350   46 1479.00000 1480.24202  0.08%  12.1 3561s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 3
#   MIR: 35
#   StrongCG: 10
#   Flow cover: 54
#
# Explored 26920 nodes (334907 simplex iterations) in 3600.24 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1479 1478 1477 ... 1422
#
# Time limit reached
# Best objective 1.479000000000e+03, best bound 1.480000000000e+03, gap 0.0676%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3.5x3

# %%
datafile="4x2000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xf24c8d02
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1421.0000000
# Presolve removed 33 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2542527 nonzeros (32%)
# Presolve added 0 rows and 121 columns
# Presolve removed 45 rows and 0 columns
# Presolve time: 26.65s
# Presolved: 9955 rows, 8121 columns, 5429437 nonzeros
# Variable types: 141 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.489899e+06   0.000000e+00     29s
#      640    1.5499762e+03   7.956783e+04   0.000000e+00     30s
#     2470    1.4882150e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.488215e+03, 2470 iterations, 3.00 seconds
# Total elapsed time = 36.44s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1488.21502    0  228 1421.00000 1488.21502  4.73%     -   39s
# H    0     0                    1484.0000000 1488.21502  0.28%     -   39s
# H    0     0                    1485.0000000 1488.21502  0.22%     -   40s
#      0     0 1487.96112    0  179 1485.00000 1487.96112  0.20%     -   45s
# H    0     0                    1486.0000000 1487.96112  0.13%     -   48s
#      0     0 1487.81788    0  172 1486.00000 1487.81788  0.12%     -   49s
#      0     0 1487.81788    0  176 1486.00000 1487.81788  0.12%     -   50s
#      0     0 1487.42162    0  137 1486.00000 1487.42162  0.10%     -   56s
#      0     0 1487.37714    0  131 1486.00000 1487.37714  0.09%     -   59s
#      0     0 1487.37712    0  125 1486.00000 1487.37712  0.09%     -   61s
#      0     0 1487.26786    0  122 1486.00000 1487.26786  0.09%     -   67s
#      0     0 1487.20475    0  111 1486.00000 1487.20475  0.08%     -   69s
#      0     0 1487.19174    0  111 1486.00000 1487.19174  0.08%     -   72s
#      0     0 1487.19174    0  111 1486.00000 1487.19174  0.08%     -   74s
#      0     0     cutoff    0      1486.00000 1486.00000  0.00%     -   79s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 8
#   Implied bound: 2
#   MIR: 264
#   StrongCG: 6
#   GUB cover: 2
#   RLT: 3
#
# Explored 1 nodes (10739 simplex iterations) in 80.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1486 1485 1484 1421
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.486000000000e+03, best bound 1.486000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3.5x4

# %%
datafile="4x2000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xa237ce65
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1424.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 20s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 25s) ...
# Sparsify removed 2541013 nonzeros (32%)
# Presolve added 0 rows and 113 columns
# Presolve removed 46 rows and 0 columns
# Presolve time: 26.28s
# Presolved: 9954 rows, 8113 columns, 5422987 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.515720e+06   0.000000e+00     28s
#     1036    1.4881846e+03   7.320421e+04   0.000000e+00     30s
#     2319    1.4857341e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.485734e+03, 2319 iterations, 2.60 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1485.73414    0  274 1424.00000 1485.73414  4.34%     -   35s
# H    0     0                    1479.0000000 1485.73414  0.46%     -   36s
# H    0     0                    1483.0000000 1485.73414  0.18%     -   36s
# H    0     0                    1484.0000000 1485.73414  0.12%     -   36s
#      0     0 1485.71568    0  242 1484.00000 1485.71568  0.12%     -   43s
#      0     0 1485.71491    0  219 1484.00000 1485.71491  0.12%     -   48s
#      0     0 1485.70935    0  221 1484.00000 1485.70935  0.12%     -   49s
#      0     0 1485.70935    0  219 1484.00000 1485.70935  0.12%     -   50s
#      0     0 1485.69561    0  180 1484.00000 1485.69561  0.11%     -   56s
#      0     0 1485.57748    0  169 1484.00000 1485.57748  0.11%     -   58s
#      0     0 1485.57748    0  172 1484.00000 1485.57748  0.11%     -   59s
#      0     0 1485.57632    0  146 1484.00000 1485.57632  0.11%     -   64s
#      0     0 1485.57632    0  124 1484.00000 1485.57632  0.11%     -   65s
#      0     0 1485.57560    0  115 1484.00000 1485.57560  0.11%     -   70s
#      0     0 1485.57560    0  119 1484.00000 1485.57560  0.11%     -   72s
#      0     0 1485.57560    0  115 1484.00000 1485.57560  0.11%     -   76s
# H    0     0                    1485.0000000 1485.57560  0.04%     -   78s
#      0     0 1485.57560    0  115 1485.00000 1485.57560  0.04%     -   78s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 17
#   MIR: 78
#   StrongCG: 6
#   GUB cover: 2
#   RLT: 2
#
# Explored 1 nodes (10384 simplex iterations) in 78.39 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1485 1484 1483 ... 1424
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.485000000000e+03, best bound 1.485000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x3.5x5

# %%
datafile="4x2000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x3f3696ba
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1429.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 5s) ...
# Presolve removed 32 rows and 16 columns (presolve time = 14s) ...
# Presolve removed 32 rows and 16 columns (presolve time = 15s) ...
# Presolve removed 32 rows and 16 columns (presolve time = 20s) ...
# Presolve removed 32 rows and 16 columns (presolve time = 25s) ...
# Sparsify removed 2481640 nonzeros (31%)
# Presolve added 0 rows and 120 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 26.52s
# Presolved: 9960 rows, 8120 columns, 5498300 nonzeros
# Variable types: 136 continuous, 7984 integer (7984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.490936e+06   0.000000e+00     29s
#      748    1.5401135e+03   6.850088e+04   0.000000e+00     30s
#     2258    1.4897351e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.489735e+03, 2258 iterations, 3.20 seconds
# Total elapsed time = 35.71s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1489.73512    0  152 1429.00000 1489.73512  4.25%     -   36s
# H    0     0                    1487.0000000 1489.73512  0.18%     -   37s
# H    0     0                    1488.0000000 1489.73512  0.12%     -   37s
#      0     0 1489.73512    0  171 1488.00000 1489.73512  0.12%     -   41s
#      0     0 1489.28345    0  155 1488.00000 1489.28345  0.09%     -   47s
#      0     0 1489.28345    0  156 1488.00000 1489.28345  0.09%     -   48s
#      0     0 1489.27573    0   94 1488.00000 1489.27573  0.09%     -   59s
#      0     0 1489.27301    0  122 1488.00000 1489.27301  0.09%     -   63s
#      0     0 1489.27301    0  114 1488.00000 1489.27301  0.09%     -   64s
#      0     0 1489.25381    0   95 1488.00000 1489.25381  0.08%     -   69s
#      0     0 1489.25381    0   88 1488.00000 1489.25381  0.08%     -   70s
#      0     0 1489.24963    0   91 1488.00000 1489.24963  0.08%     -   74s
#      0     0 1489.24963    0   87 1488.00000 1489.24963  0.08%     -   76s
#      0     0 1489.19629    0   88 1488.00000 1489.19629  0.08%     -   80s
#      0     0 1489.19629    0   88 1488.00000 1489.19629  0.08%     -   81s
#      0     0 1489.19629    0   92 1488.00000 1489.19629  0.08%     -   85s
#      0     0 1489.19629    0   96 1488.00000 1489.19629  0.08%     -   86s
#      0     0 1489.19610    0   64 1488.00000 1489.19610  0.08%     -   95s
#      0     0 1489.19540    0   71 1488.00000 1489.19540  0.08%     -   98s
#      0     0 1489.19540    0   72 1488.00000 1489.19540  0.08%     -  100s
#      0     0 1489.19540    0   79 1488.00000 1489.19540  0.08%     -  104s
#      0     0 1489.19302    0   86 1488.00000 1489.19302  0.08%     -  107s
#      0     0 1489.19302    0   83 1488.00000 1489.19302  0.08%     -  108s
#      0     0 1489.19302    0   77 1488.00000 1489.19302  0.08%     -  112s
#      0     0 1489.19293    0   78 1488.00000 1489.19293  0.08%     -  113s
#      0     0 1489.19293    0   91 1488.00000 1489.19293  0.08%     -  116s
#      0     0 1489.19293    0   72 1488.00000 1489.19293  0.08%     -  119s
#      0     2 1489.19293    0   72 1488.00000 1489.19293  0.08%     -  126s
#      7    12 1489.19220    3   81 1488.00000 1489.19220  0.08%   279  130s
#     31    36 1489.19220    6   70 1488.00000 1489.19220  0.08%  82.5  136s
#     68    73 1489.19089   12   68 1488.00000 1489.19220  0.08%  44.0  144s
#     74   131 1489.19089   13   69 1488.00000 1489.19220  0.08%  40.8  150s
#    132   248 1489.17411   23   62 1488.00000 1489.19220  0.08%  27.4  160s
#    249   710 1489.19089   22   65 1488.00000 1489.19220  0.08%  18.1  185s
# H  578   710                    1489.0000000 1489.19220  0.01%  11.8  185s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 1
#   MIR: 166
#
# Explored 741 nodes (26872 simplex iterations) in 185.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1489 1488 1487 1429
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.489000000000e+03, best bound 1.489000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4x1

# %%
datafile="4x2000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xb83cb206
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1333.0000000
# Presolve removed 27 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 20s) ...
# Sparsify removed 2515876 nonzeros (31%)
# Presolve added 0 rows and 128 columns
# Presolve removed 31 rows and 0 columns
# Presolve time: 22.35s
# Presolved: 9969 rows, 8128 columns, 5472088 nonzeros
# Variable types: 140 continuous, 7988 integer (7988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9970000e+03   1.541229e+06   0.000000e+00     24s
#      671    1.5009066e+03   3.833934e+05   0.000000e+00     26s
#     2483    1.3967473e+03   0.000000e+00   0.000000e+00     27s
#
# Root relaxation: objective 1.396747e+03, 2483 iterations, 3.02 seconds
# Total elapsed time = 30.60s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1396.74727    0  144 1333.00000 1396.74727  4.78%     -   31s
# H    0     0                    1389.0000000 1396.74727  0.56%     -   31s
# H    0     0                    1393.0000000 1396.74727  0.27%     -   32s
# H    0     0                    1395.0000000 1396.74727  0.13%     -   32s
#      0     0 1396.72569    0  126 1395.00000 1396.72569  0.12%     -   36s
#      0     0 1396.71166    0  129 1395.00000 1396.71166  0.12%     -   40s
#      0     0 1396.71166    0  131 1395.00000 1396.71166  0.12%     -   41s
#      0     0 1396.69623    0  120 1395.00000 1396.69623  0.12%     -   45s
#      0     0 1396.69544    0  118 1395.00000 1396.69544  0.12%     -   47s
#      0     0 1396.69168    0  124 1395.00000 1396.69168  0.12%     -   48s
#      0     0 1396.69168    0  124 1395.00000 1396.69168  0.12%     -   49s
#      0     0 1396.67127    0  114 1395.00000 1396.67127  0.12%     -   53s
#      0     0 1396.67127    0  106 1395.00000 1396.67127  0.12%     -   54s
#      0     0 1396.67074    0  113 1395.00000 1396.67074  0.12%     -   58s
#      0     0 1396.67068    0  120 1395.00000 1396.67068  0.12%     -   60s
#      0     0 1396.66675    0  118 1395.00000 1396.66675  0.12%     -   63s
#      0     0 1396.66255    0  117 1395.00000 1396.66255  0.12%     -   67s
#      0     0 1396.66055    0  124 1395.00000 1396.66055  0.12%     -   68s
#      0     0 1396.66055    0  114 1395.00000 1396.66055  0.12%     -   69s
#      0     0 1396.60903    0  100 1395.00000 1396.60903  0.12%     -   72s
#      0     0 1396.48145    0  105 1395.00000 1396.48145  0.11%     -   74s
#      0     0 1396.48145    0  103 1395.00000 1396.48145  0.11%     -   75s
#      0     0 1396.45365    0  103 1395.00000 1396.45365  0.10%     -   78s
#      0     0 1396.45286    0  100 1395.00000 1396.45286  0.10%     -   80s
#      0     0 1396.44447    0   98 1395.00000 1396.44447  0.10%     -   81s
#      0     0 1396.44447    0   98 1395.00000 1396.44447  0.10%     -   82s
#      0     0 1396.36647    0   98 1395.00000 1396.36647  0.10%     -   85s
#      0     0 1396.36070    0  104 1395.00000 1396.36070  0.10%     -   88s
#      0     0 1396.36070    0  109 1395.00000 1396.36070  0.10%     -   89s
#      0     0 1396.36070    0  106 1395.00000 1396.36070  0.10%     -   92s
#      0     0 1396.34346    0  103 1395.00000 1396.34346  0.10%     -   94s
#      0     0 1396.34346    0  110 1395.00000 1396.34346  0.10%     -   96s
#      0     0 1396.34346    0  101 1395.00000 1396.34346  0.10%     -   99s
#      0     0 1396.34346    0  104 1395.00000 1396.34346  0.10%     -  101s
#      0     0 1396.34339    0  110 1395.00000 1396.34339  0.10%     -  103s
#      0     0 1396.34326    0  120 1395.00000 1396.34326  0.10%     -  105s
#      0     0 1396.33279    0  107 1395.00000 1396.33279  0.10%     -  109s
#      0     0 1396.33279    0   98 1395.00000 1396.33279  0.10%     -  112s
#      0     0 1396.33279    0   92 1395.00000 1396.33279  0.10%     -  117s
#      0     0 1396.33279    0  107 1395.00000 1396.33279  0.10%     -  119s
#      0     0 1396.33069    0   69 1395.00000 1396.33069  0.10%     -  129s
#      0     0 1396.33069    0   90 1395.00000 1396.33069  0.10%     -  131s
#      0     0 1396.33069    0   89 1395.00000 1396.33069  0.10%     -  134s
#      0     0 1396.33069    0   89 1395.00000 1396.33069  0.10%     -  137s
#      0     0 1396.32974    0   69 1395.00000 1396.32974  0.10%     -  143s
#      0     0 1396.32630    0   94 1395.00000 1396.32630  0.10%     -  146s
#      0     0 1396.32587    0   90 1395.00000 1396.32587  0.10%     -  147s
#      0     0 1396.32587    0   86 1395.00000 1396.32587  0.10%     -  148s
#      0     0 1396.26493    0   76 1395.00000 1396.26493  0.09%     -  152s
#      0     0 1396.26493    0   96 1395.00000 1396.26493  0.09%     -  153s
#      0     0 1396.26493    0   83 1395.00000 1396.26493  0.09%     -  157s
#      0     0 1396.26493    0   90 1395.00000 1396.26493  0.09%     -  159s
#      0     0 1396.26493    0   84 1395.00000 1396.26493  0.09%     -  167s
#      0     0 1396.26493    0   82 1395.00000 1396.26493  0.09%     -  170s
#      0     0 1396.26493    0   73 1395.00000 1396.26493  0.09%     -  177s
#      0     0 1396.26493    0   73 1395.00000 1396.26493  0.09%     -  179s
#      0     2 1396.26493    0   73 1395.00000 1396.26493  0.09%     -  186s
#      9    14 1396.26493    4   83 1395.00000 1396.26493  0.09%   220  191s
#     27    32 1396.26493    6   81 1395.00000 1396.26493  0.09%  93.0  197s
# H   28    32                    1396.0000000 1396.26493  0.02%  89.7  198s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 14
#   Implied bound: 1
#   Clique: 1
#   MIR: 207
#   StrongCG: 5
#
# Explored 33 nodes (27127 simplex iterations) in 198.30 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1396 1395 1393 ... 1333
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.396000000000e+03, best bound 1.396000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4x2

# %%
datafile="4x2000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xe92ae5ce
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1317.0000000
# Presolve removed 38 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 20s) ...
# Sparsify removed 2570502 nonzeros (32%)
# Presolve added 0 rows and 122 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 22.66s
# Presolved: 9960 rows, 8122 columns, 5393514 nonzeros
# Variable types: 146 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.537512e+06   0.000000e+00     25s
#      166    1.6780610e+03   3.039197e+05   0.000000e+00     25s
#     2615    1.3872297e+03   0.000000e+00   0.000000e+00     27s
#
# Root relaxation: objective 1.387230e+03, 2615 iterations, 2.96 seconds
# Total elapsed time = 30.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1387.22968    0  224 1317.00000 1387.22968  5.33%     -   32s
# H    0     0                    1382.0000000 1387.22968  0.38%     -   33s
# H    0     0                    1383.0000000 1387.22968  0.31%     -   33s
# H    0     0                    1384.0000000 1387.22968  0.23%     -   34s
#      0     0 1387.22839    0  240 1384.00000 1387.22839  0.23%     -   39s
# H    0     0                    1385.0000000 1387.22839  0.16%     -   43s
#      0     0 1387.16624    0  198 1385.00000 1387.16624  0.16%     -   44s
#      0     0 1387.09482    0  193 1385.00000 1387.09482  0.15%     -   45s
#      0     0 1387.09482    0  193 1385.00000 1387.09482  0.15%     -   46s
#      0     0 1387.06892    0  167 1385.00000 1387.06892  0.15%     -   51s
#      0     0 1386.99719    0  179 1385.00000 1386.99719  0.14%     -   53s
#      0     0 1386.97660    0  183 1385.00000 1386.97660  0.14%     -   54s
#      0     0 1386.97660    0  185 1385.00000 1386.97660  0.14%     -   55s
#      0     0 1386.76913    0  174 1385.00000 1386.76913  0.13%     -   60s
#      0     0 1386.75688    0  147 1385.00000 1386.75688  0.13%     -   61s
#      0     0 1386.75688    0  158 1385.00000 1386.75688  0.13%     -   62s
#      0     0 1386.75603    0  153 1385.00000 1386.75603  0.13%     -   66s
#      0     0 1386.75584    0  155 1385.00000 1386.75584  0.13%     -   68s
#      0     0 1386.75584    0  159 1385.00000 1386.75584  0.13%     -   69s
#      0     0 1386.75122    0  151 1385.00000 1386.75122  0.13%     -   74s
#      0     0 1386.74330    0  149 1385.00000 1386.74330  0.13%     -   75s
#      0     0 1386.73361    0  156 1385.00000 1386.73361  0.13%     -   78s
#      0     0 1386.70331    0  154 1385.00000 1386.70331  0.12%     -   79s
#      0     0 1386.70331    0  161 1385.00000 1386.70331  0.12%     -   82s
#      0     0 1386.69757    0  154 1385.00000 1386.69757  0.12%     -   88s
#      0     0 1386.66600    0  137 1385.00000 1386.66600  0.12%     -   91s
#      0     0 1386.66600    0  146 1385.00000 1386.66600  0.12%     -   94s
#      0     0 1386.65977    0  124 1385.00000 1386.65977  0.12%     -   99s
#      0     0 1386.65977    0  120 1385.00000 1386.65977  0.12%     -  103s
#      0     0 1386.65977    0  116 1385.00000 1386.65977  0.12%     -  109s
#      0     0 1386.65763    0  127 1385.00000 1386.65763  0.12%     -  112s
#      0     0 1386.65573    0  131 1385.00000 1386.65573  0.12%     -  114s
#      0     0 1386.65543    0  135 1385.00000 1386.65543  0.12%     -  117s
#      0     0 1386.65543    0  139 1385.00000 1386.65543  0.12%     -  119s
#      0     0 1386.65543    0  124 1385.00000 1386.65543  0.12%     -  134s
#      0     0 1386.62421    0  116 1385.00000 1386.62421  0.12%     -  145s
#      0     0 1386.62421    0  122 1385.00000 1386.62421  0.12%     -  147s
#      0     0 1386.62421    0  131 1385.00000 1386.62421  0.12%     -  153s
#      0     0 1386.62421    0  119 1385.00000 1386.62421  0.12%     -  156s
#      0     0 1386.62421    0  133 1385.00000 1386.62421  0.12%     -  164s
#      0     0 1386.62421    0  124 1385.00000 1386.62421  0.12%     -  167s
#      0     0 1386.62421    0  107 1385.00000 1386.62421  0.12%     -  181s
#      0     0 1386.62421    0  104 1385.00000 1386.62421  0.12%     -  185s
#      0     0 1386.62421    0   97 1385.00000 1386.62421  0.12%     -  196s
#      0     0 1386.62421    0  116 1385.00000 1386.62421  0.12%     -  200s
#      0     0 1386.62421    0  108 1385.00000 1386.62421  0.12%     -  211s
#      0     0 1386.62421    0   99 1385.00000 1386.62421  0.12%     -  216s
#      0     2 1386.62421    0   99 1385.00000 1386.62421  0.12%     -  231s
#      3     8 1386.62421    2  117 1385.00000 1386.62421  0.12%   364  235s
#     13    20 1386.61961    4  123 1385.00000 1386.62229  0.12%   165  240s
#     19    26 1386.61961    5  125 1385.00000 1386.62229  0.12%   143  247s
# H   31    38                    1386.0000000 1386.62229  0.04%  98.9  263s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 23
#   MIR: 323
#   StrongCG: 15
#   GUB cover: 6
#   RLT: 1
#
# Explored 37 nodes (25267 simplex iterations) in 263.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1386 1385 1384 ... 1317
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.386000000000e+03, best bound 1.386000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4x3

# %%
datafile="4x2000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xfe84715d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1318.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2509805 nonzeros (31%)
# Presolve added 0 rows and 117 columns
# Presolve removed 29 rows and 0 columns
# Presolve time: 26.91s
# Presolved: 9971 rows, 8117 columns, 5462235 nonzeros
# Variable types: 137 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.551614e+06   0.000000e+00     29s
#      583    1.6444838e+03   6.246105e+05   0.000000e+00     30s
#     3301    1.3789058e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 1.378906e+03, 3301 iterations, 4.54 seconds
# Total elapsed time = 35.60s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1378.90583    0  200 1318.00000 1378.90583  4.62%     -   37s
# H    0     0                    1373.0000000 1378.90583  0.43%     -   38s
# H    0     0                    1376.0000000 1378.90583  0.21%     -   38s
#      0     0 1378.87932    0  189 1376.00000 1378.87932  0.21%     -   42s
# H    0     0                    1377.0000000 1378.87932  0.14%     -   46s
#      0     0 1378.84684    0  185 1377.00000 1378.84684  0.13%     -   47s
#      0     0 1378.84646    0  182 1377.00000 1378.84646  0.13%     -   48s
#      0     0 1378.84551    0  182 1377.00000 1378.84551  0.13%     -   49s
#      0     0 1378.74997    0  131 1377.00000 1378.74997  0.13%     -   53s
#      0     0 1378.70476    0  148 1377.00000 1378.70476  0.12%     -   55s
#      0     0 1378.69982    0  145 1377.00000 1378.69982  0.12%     -   57s
#      0     0 1378.69825    0  148 1377.00000 1378.69825  0.12%     -   58s
#      0     0 1378.69825    0  148 1377.00000 1378.69825  0.12%     -   59s
#      0     0 1378.62630    0  123 1377.00000 1378.62630  0.12%     -   63s
#      0     0 1378.61904    0  128 1377.00000 1378.61904  0.12%     -   65s
#      0     0 1378.61904    0  126 1377.00000 1378.61904  0.12%     -   66s
#      0     0 1378.43922    0  131 1377.00000 1378.43922  0.10%     -   70s
#      0     0 1378.43919    0  123 1377.00000 1378.43919  0.10%     -   72s
#      0     0 1378.43919    0  127 1377.00000 1378.43919  0.10%     -   76s
#      0     0 1378.41841    0  111 1377.00000 1378.41841  0.10%     -   80s
#      0     0 1378.41221    0  119 1377.00000 1378.41221  0.10%     -   82s
#      0     0 1378.40344    0  114 1377.00000 1378.40344  0.10%     -   83s
#      0     0 1378.40344    0  111 1377.00000 1378.40344  0.10%     -   84s
#      0     0 1378.40344    0  133 1377.00000 1378.40344  0.10%     -   88s
#      0     0 1378.37011    0  115 1377.00000 1378.37011  0.10%     -   91s
#      0     0 1378.35750    0  124 1377.00000 1378.35750  0.10%     -   92s
#      0     0 1378.35750    0  123 1377.00000 1378.35750  0.10%     -   93s
#      0     0 1378.32759    0  125 1377.00000 1378.32759  0.10%     -   98s
#      0     0 1378.31736    0  126 1377.00000 1378.31736  0.10%     -   99s
#      0     0 1378.31589    0  114 1377.00000 1378.31589  0.10%     -  101s
#      0     0 1378.30753    0  113 1377.00000 1378.30753  0.09%     -  102s
#      0     0 1378.30753    0  115 1377.00000 1378.30753  0.09%     -  105s
#      0     0 1378.30753    0   99 1377.00000 1378.30753  0.09%     -  107s
#      0     0 1378.30753    0  115 1377.00000 1378.30753  0.09%     -  110s
#      0     0 1378.30753    0  104 1377.00000 1378.30753  0.09%     -  111s
#      0     0 1378.30753    0  105 1377.00000 1378.30753  0.09%     -  117s
#      0     0 1378.30753    0  118 1377.00000 1378.30753  0.09%     -  119s
#      0     0 1378.30753    0   92 1377.00000 1378.30753  0.09%     -  125s
#      0     0 1378.30753    0   98 1377.00000 1378.30753  0.09%     -  127s
#      0     0 1378.30753    0  100 1377.00000 1378.30753  0.09%     -  134s
#      0     0 1378.30753    0   94 1377.00000 1378.30753  0.09%     -  137s
#      0     2 1378.30753    0   89 1377.00000 1378.30753  0.09%     -  145s
#      7    14 1378.30743    3  111 1377.00000 1378.30743  0.09%   238  150s
#     19    26 1378.30743    4  117 1377.00000 1378.30743  0.09%   133  156s
#     31    38 1378.30743    6  111 1377.00000 1378.30743  0.09%  96.0  161s
#     45    97 1378.30743    8  112 1377.00000 1378.30743  0.09%  69.2  165s
#     96   209 1378.30743   12  109 1377.00000 1378.30743  0.09%  40.9  175s
#    208   422 1378.29361   27   88 1377.00000 1378.30743  0.09%  23.9  191s
#    421   824 1378.27554   49   88 1377.00000 1378.30743  0.09%  15.2  217s
#    825  1180 1378.26916   94   97 1377.00000 1378.30743  0.09%  11.1  240s
#   1185  1461 1378.23965  123   94 1377.00000 1378.30743  0.09%   9.8  262s
#   1495  1880 1378.22100  158   95 1377.00000 1378.30743  0.09%   9.2  287s
#   1930  2183 1378.27471   46  110 1377.00000 1378.30743  0.09%   9.5  309s
#   2260  2732 1378.30216   20  115 1377.00000 1378.30743  0.09%   9.4  334s
#   2818  3238 1378.22366  162   66 1377.00000 1378.30743  0.09%   8.8  359s
#   3341  3831 1378.18481  281   44 1377.00000 1378.30743  0.09%   8.4  386s
#   3943  3832 1378.22104  133   94 1377.00000 1378.30743  0.09%   8.1  483s
#   3945  3833 1378.30743    7  147 1377.00000 1378.30743  0.09%   8.0  516s
#   3946  3834 1378.27312   46  140 1377.00000 1378.30743  0.09%   8.0  542s
#   3947  3835 1378.09358  240  117 1377.00000 1378.30743  0.09%   8.0  547s
#   3949  3836 1378.27298   70  118 1377.00000 1378.30541  0.09%   8.0  562s
#   3950  3837 1378.22586  189   73 1377.00000 1378.28360  0.09%   8.0  589s
#   3951  3837 1378.09358  247   63 1377.00000 1378.27441  0.09%   8.0  592s
#   3953  3839 1378.26180   70   82 1377.00000 1378.26828  0.09%   8.0  609s
#   3954  3839 1378.11881  300   67 1377.00000 1378.26190  0.09%   8.0  629s
#   3955  3840 1378.18481  346   69 1377.00000 1378.26190  0.09%   8.0  643s
#   3956  3841 1378.22234  156   63 1377.00000 1378.26190  0.09%   8.0  665s
#   3957  3841 1378.11787  214   64 1377.00000 1378.26190  0.09%   8.0  683s
#   3958  3842 1378.26190  111   61 1377.00000 1378.26190  0.09%   8.0  703s
#   3959  3843 1378.23269  112   70 1377.00000 1378.26190  0.09%   8.0  725s
#   3960  3843 1377.99969  153   60 1377.00000 1378.26190  0.09%   8.0  751s
#   3962  3845 1378.25395   30   64 1377.00000 1378.26126  0.09%   8.0  762s
#   3963  3845 1378.11881  291   54 1377.00000 1378.26126  0.09%   8.0  777s
#   3964  3846 1378.19888  217   65 1377.00000 1378.26126  0.09%   8.0  788s
#   3965  3847 1378.11881  313   61 1377.00000 1378.26126  0.09%   8.0  800s
#   3966  3847 1378.23021  108   70 1377.00000 1378.26126  0.09%   8.0  808s
#   3967  3848 1378.23023  107   70 1377.00000 1378.26126  0.09%   8.0  823s
#   3968  3849 1378.25118  212   84 1377.00000 1378.26126  0.09%   8.0  834s
#   3969  3849 1378.25877   92   81 1377.00000 1378.26126  0.09%   8.0  844s
#   3970  3850 1378.23237  116   70 1377.00000 1378.26126  0.09%   8.0  850s
#   3972  3853 1378.26126   83   94 1377.00000 1378.26126  0.09%  15.3  935s
#   3974  3854 1378.26126   86  160 1377.00000 1378.26126  0.09%  15.3  964s
#   3975  3855 1378.11881  318   84 1377.00000 1378.26126  0.09%  15.3  983s
#   3976  3856 1378.22369  148   71 1377.00000 1378.26126  0.09%  15.3  986s
#   3978  3857 1378.26030   71   77 1377.00000 1378.26030  0.09%  15.3 1000s
#   3979  3858 1378.18481  300   68 1377.00000 1378.26030  0.09%  15.3 1022s
#   3980  3858 1378.03099  147   82 1377.00000 1378.26030  0.09%  15.3 1040s
#   3981  3859 1378.26030   14   68 1377.00000 1378.26030  0.09%  15.3 1061s
#   3982  3860 1378.26030   56   71 1377.00000 1378.26030  0.09%  15.2 1083s
#   3983  3860 1378.22811  167   73 1377.00000 1378.26030  0.09%  15.2 1103s
#   3984  3861 1378.22938  154   78 1377.00000 1378.26030  0.09%  15.2 1121s
#   3985  3862 1378.15083  222   74 1377.00000 1378.26030  0.09%  15.2 1152s
#   3986  3862 1378.23528  149   83 1377.00000 1378.26030  0.09%  15.2 1170s
#   3987  3863 1378.18105  150   65 1377.00000 1378.26030  0.09%  15.2 1201s
#   3988  3864 1378.15324  168   62 1377.00000 1378.26030  0.09%  15.2 1223s
#   3989  3864 1378.21915  123   68 1377.00000 1378.26030  0.09%  15.2 1237s
# H 3989  3670                    1378.0000000 1378.26030  0.02%  15.2 1242s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 7
#   MIR: 46
#   StrongCG: 4
#   Flow cover: 46
#   GUB cover: 4
#   RLT: 2
#
# Explored 3989 nodes (107826 simplex iterations) in 1243.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1378 1377 1376 ... 1318
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.378000000000e+03, best bound 1.378000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4x4

# %%
datafile="4x2000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x745d229d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1316.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 20s) ...
# Sparsify removed 2508407 nonzeros (31%)
# Presolve added 0 rows and 117 columns
# Presolve removed 42 rows and 0 columns
# Presolve time: 22.23s
# Presolved: 9958 rows, 8117 columns, 5455601 nonzeros
# Variable types: 141 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.548533e+06   0.000000e+00     24s
#      679    1.4562274e+03   3.331622e+05   0.000000e+00     26s
#     2322    1.3837497e+03   0.000000e+00   0.000000e+00     27s
#
# Root relaxation: objective 1.383750e+03, 2322 iterations, 2.88 seconds
# Total elapsed time = 31.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1383.74973    0  185 1316.00000 1383.74973  5.15%     -   33s
# H    0     0                    1379.0000000 1383.74973  0.34%     -   34s
#      0     0 1383.47107    0  185 1379.00000 1383.47107  0.32%     -   38s
# H    0     0                    1380.0000000 1383.47107  0.25%     -   39s
# H    0     0                    1381.0000000 1383.47107  0.18%     -   43s
#      0     0 1383.27530    0  156 1381.00000 1383.27530  0.16%     -   43s
#      0     0 1383.27530    0  153 1381.00000 1383.27530  0.16%     -   44s
#      0     0 1383.04915    0  147 1381.00000 1383.04915  0.15%     -   48s
#      0     0 1383.02528    0  144 1381.00000 1383.02528  0.15%     -   50s
#      0     0 1382.98517    0  119 1381.00000 1382.98517  0.14%     -   51s
#      0     0 1382.98516    0  125 1381.00000 1382.98516  0.14%     -   52s
#      0     0 1382.94843    0  131 1381.00000 1382.94843  0.14%     -   56s
#      0     0 1382.91799    0  139 1381.00000 1382.91799  0.14%     -   57s
#      0     0 1382.91680    0  137 1381.00000 1382.91680  0.14%     -   58s
#      0     0 1382.91680    0  135 1381.00000 1382.91680  0.14%     -   59s
#      0     0 1382.89857    0  119 1381.00000 1382.89857  0.14%     -   63s
#      0     0 1382.89834    0  106 1381.00000 1382.89834  0.14%     -   66s
#      0     0 1382.89654    0  116 1381.00000 1382.89654  0.14%     -   67s
#      0     0 1382.89598    0  114 1381.00000 1382.89598  0.14%     -   68s
#      0     0 1382.89598    0  120 1381.00000 1382.89598  0.14%     -   69s
#      0     0 1382.88267    0  106 1381.00000 1382.88267  0.14%     -   72s
#      0     0 1382.87830    0  120 1381.00000 1382.87830  0.14%     -   74s
#      0     0 1382.87830    0  117 1381.00000 1382.87830  0.14%     -   75s
#      0     0 1382.86485    0  128 1381.00000 1382.86485  0.14%     -   79s
#      0     0 1382.86472    0  131 1381.00000 1382.86472  0.14%     -   80s
#      0     0 1382.86003    0  118 1381.00000 1382.86003  0.13%     -   84s
#      0     0 1382.85978    0  119 1381.00000 1382.85978  0.13%     -   87s
#      0     0 1382.85978    0  107 1381.00000 1382.85978  0.13%     -   88s
#      0     0 1382.85977    0  116 1381.00000 1382.85977  0.13%     -   92s
#      0     0 1382.85977    0  120 1381.00000 1382.85977  0.13%     -   94s
#      0     0 1382.85030    0  107 1381.00000 1382.85030  0.13%     -   98s
#      0     0 1382.84456    0  111 1381.00000 1382.84456  0.13%     -  100s
#      0     0 1382.84456    0  111 1381.00000 1382.84456  0.13%     -  102s
#      0     0 1382.82454    0  102 1381.00000 1382.82454  0.13%     -  107s
#      0     0 1382.81445    0  113 1381.00000 1382.81445  0.13%     -  111s
#      0     0 1382.81445    0  109 1381.00000 1382.81445  0.13%     -  112s
#      0     0 1382.77749    0  121 1381.00000 1382.77749  0.13%     -  117s
#      0     0 1382.77069    0  110 1381.00000 1382.77069  0.13%     -  120s
#      0     0 1382.77069    0  106 1381.00000 1382.77069  0.13%     -  123s
#      0     0 1382.71804    0  109 1381.00000 1382.71804  0.12%     -  128s
#      0     0 1382.71804    0   92 1381.00000 1382.71804  0.12%     -  133s
#      0     0 1382.71804    0  109 1381.00000 1382.71804  0.12%     -  138s
#      0     0 1382.71804    0  113 1381.00000 1382.71804  0.12%     -  140s
#      0     0 1382.71804    0   90 1381.00000 1382.71804  0.12%     -  150s
#      0     0 1382.71804    0  102 1381.00000 1382.71804  0.12%     -  153s
#      0     0 1382.71804    0  107 1381.00000 1382.71804  0.12%     -  159s
#      0     0 1382.71804    0  108 1381.00000 1382.71804  0.12%     -  162s
#      0     0 1382.71804    0   87 1381.00000 1382.71804  0.12%     -  169s
#      0     0 1382.71804    0   83 1381.00000 1382.71804  0.12%     -  172s
#      0     2 1382.71804    0   83 1381.00000 1382.71804  0.12%     -  180s
#     13    20 1382.71787    4  110 1381.00000 1382.71804  0.12%   197  185s
# H   31    38                    1382.0000000 1382.71787  0.05%   124  191s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 27
#   Implied bound: 4
#   Clique: 2
#   MIR: 245
#   StrongCG: 12
#   GUB cover: 5
#   RLT: 5
#
# Explored 37 nodes (25502 simplex iterations) in 191.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1382 1381 1380 ... 1316
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.382000000000e+03, best bound 1.382000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4x5

# %%
datafile="4x2000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xd417e147
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1316.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 20s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 25s) ...
# Sparsify removed 2541065 nonzeros (32%)
# Presolve added 0 rows and 113 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 26.06s
# Presolved: 9962 rows, 8113 columns, 5422923 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.547451e+06   0.000000e+00     28s
#     1494    1.5538838e+03   3.864634e+05   0.000000e+00     31s
#     3903    1.3854852e+03   0.000000e+00   0.000000e+00     32s
#
# Root relaxation: objective 1.385485e+03, 3903 iterations, 4.58 seconds
# Total elapsed time = 35.28s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1385.48518    0  170 1316.00000 1385.48518  5.28%     -   37s
# H    0     0                    1382.0000000 1385.48518  0.25%     -   37s
# H    0     0                    1383.0000000 1385.48518  0.18%     -   38s
#      0     0 1385.47805    0  183 1383.00000 1385.47805  0.18%     -   42s
# H    0     0                    1384.0000000 1385.47805  0.11%     -   46s
#      0     0 1385.42857    0  164 1384.00000 1385.42857  0.10%     -   47s
#      0     0 1385.37438    0  166 1384.00000 1385.37438  0.10%     -   48s
#      0     0 1385.37438    0  166 1384.00000 1385.37438  0.10%     -   49s
#      0     0 1385.31565    0  115 1384.00000 1385.31565  0.10%     -   54s
#      0     0 1385.26915    0   96 1384.00000 1385.26915  0.09%     -   56s
#      0     0 1385.26915    0   98 1384.00000 1385.26915  0.09%     -   57s
#      0     0 1385.24903    0   81 1384.00000 1385.24903  0.09%     -   61s
#      0     0 1385.24903    0   80 1384.00000 1385.24903  0.09%     -   63s
#      0     0 1385.24656    0   69 1384.00000 1385.24656  0.09%     -   68s
#      0     0 1385.24656    0   74 1384.00000 1385.24656  0.09%     -   69s
#      0     0 1385.23109    0   76 1384.00000 1385.23109  0.09%     -   73s
#      0     0 1385.23109    0   73 1384.00000 1385.23109  0.09%     -   74s
#      0     0 1385.23109    0   79 1384.00000 1385.23109  0.09%     -   78s
#      0     0 1385.23109    0   75 1384.00000 1385.23109  0.09%     -   79s
#      0     0 1385.23109    0   80 1384.00000 1385.23109  0.09%     -   85s
#      0     0 1385.23109    0   79 1384.00000 1385.23109  0.09%     -   88s
#      0     0 1385.23109    0   72 1384.00000 1385.23109  0.09%     -   94s
#      0     0 1385.23109    0   72 1384.00000 1385.23109  0.09%     -   96s
#      0     0 1385.23109    0   77 1384.00000 1385.23109  0.09%     -  100s
#      0     0 1385.23109    0   85 1384.00000 1385.23109  0.09%     -  102s
#      0     0 1385.23023    0   62 1384.00000 1385.23023  0.09%     -  111s
#      0     0 1385.23023    0   66 1384.00000 1385.23023  0.09%     -  113s
#      0     0 1385.23023    0   80 1384.00000 1385.23023  0.09%     -  116s
#      0     0 1385.23023    0   65 1384.00000 1385.23023  0.09%     -  121s
#      0     0 1385.23023    0  166 1384.00000 1385.23023  0.09%     -  147s
#      0     0 1385.23023    0   92 1384.00000 1385.23023  0.09%     -  150s
#      0     0 1385.23023    0   83 1384.00000 1385.23023  0.09%     -  152s
#      0     0 1385.23023    0   85 1384.00000 1385.23023  0.09%     -  153s
#      0     0 1385.23023    0   85 1384.00000 1385.23023  0.09%     -  153s
#      0     0 1385.22567    0   72 1384.00000 1385.22567  0.09%     -  156s
#      0     0 1385.22567    0   68 1384.00000 1385.22567  0.09%     -  157s
#      0     0 1385.22567    0   66 1384.00000 1385.22567  0.09%     -  160s
#      0     0 1385.22567    0   68 1384.00000 1385.22567  0.09%     -  163s
#      0     0 1385.22567    0   61 1384.00000 1385.22567  0.09%     -  172s
#      0     0 1385.22567    0   65 1384.00000 1385.22567  0.09%     -  176s
#      0     0 1385.22557    0   62 1384.00000 1385.22557  0.09%     -  184s
#      0     0 1385.22247    0   72 1384.00000 1385.22247  0.09%     -  188s
#      0     0 1385.22173    0   71 1384.00000 1385.22173  0.09%     -  189s
#      0     0 1385.22115    0   76 1384.00000 1385.22115  0.09%     -  190s
#      0     0 1385.21937    0   77 1384.00000 1385.21937  0.09%     -  192s
#      0     0 1385.21906    0   79 1384.00000 1385.21906  0.09%     -  195s
#      0     0 1385.21764    0   73 1384.00000 1385.21764  0.09%     -  197s
#      0     0 1385.21698    0   78 1384.00000 1385.21698  0.09%     -  198s
#      0     0 1385.21698    0   80 1384.00000 1385.21698  0.09%     -  200s
#      0     0 1385.21698    0   93 1384.00000 1385.21698  0.09%     -  203s
#      0     0 1385.21698    0   89 1384.00000 1385.21698  0.09%     -  205s
#      0     0 1385.21698    0   71 1384.00000 1385.21698  0.09%     -  208s
#      0     0 1385.21665    0   75 1384.00000 1385.21665  0.09%     -  210s
#      0     0 1385.21665    0   70 1384.00000 1385.21665  0.09%     -  211s
#      0     0 1385.21432    0   79 1384.00000 1385.21432  0.09%     -  218s
#      0     0 1385.21432    0   75 1384.00000 1385.21432  0.09%     -  220s
#      0     0 1385.21432    0   70 1384.00000 1385.21432  0.09%     -  223s
#      0     0 1385.21432    0   67 1384.00000 1385.21432  0.09%     -  234s
#      0     2 1385.21432    0   65 1384.00000 1385.21432  0.09%     -  249s
#      1     5 1385.20315    1   63 1384.00000 1385.20315  0.09%  1398  250s
#     25    24 1385.15523    6   54 1384.00000 1385.16423  0.08%  63.3  255s
#     43    42 1385.12584    9   60 1384.00000 1385.16423  0.08%  42.9  260s
#     74   108 1385.02576   14   38 1384.00000 1385.16423  0.08%  28.1  269s
#    143   156 1385.10960    6   58 1384.00000 1385.16423  0.08%  18.6  277s
#    216   260 1385.03810   22   37 1384.00000 1385.16423  0.08%  14.8  286s
#    375   418 1385.03810   41   41 1384.00000 1385.16423  0.08%  11.6  302s
#    593   792 1385.02452   65   33 1384.00000 1385.16423  0.08%  10.1  323s
#   1006  1061 1385.01712   99   33 1384.00000 1385.16423  0.08%   8.8  362s
#   1283  1062 1385.05902   52   65 1384.00000 1385.16423  0.08%   8.6  501s
#   1285  1063 1385.03341   51  113 1384.00000 1385.16423  0.08%   8.6  529s
#   1286  1064 1385.00000   94   95 1384.00000 1385.16423  0.08%   8.6  534s
#   1287  1065 1385.04033   36   69 1384.00000 1385.16423  0.08%   8.6  536s
#   1290  1067 1385.01635  114   76 1384.00000 1385.16423  0.08%   8.6  541s
#   1292  1068 1385.16423    5   78 1384.00000 1385.16423  0.08%   8.5  548s
#   1293  1069 1385.02340  142   77 1384.00000 1385.16423  0.08%   8.5  550s
#   1295  1070 1385.01203  112   84 1384.00000 1385.16423  0.08%   8.5  560s
#   1296  1071 1385.02340  188   73 1384.00000 1385.16423  0.08%   8.5  570s
#   1297  1071 1385.07537   12   60 1384.00000 1385.16423  0.08%   8.5  575s
#   1299  1073 1385.05902   52   52 1384.00000 1385.16166  0.08%   8.5  581s
#   1300  1073 1385.02340  165   60 1384.00000 1385.16021  0.08%   8.5  585s
#   1302  1075 1385.01050   59   56 1384.00000 1385.14016  0.08%   8.5  597s
#   1304  1076 1385.02376   69   53 1384.00000 1385.14016  0.08%   8.5  606s
#   1306  1077 1385.02414   68   57 1384.00000 1385.14016  0.08%   8.5  612s
#   1307  1078 1385.05902   51   48 1384.00000 1385.14016  0.08%   8.5  620s
#   1308  1079 1385.03089   61   53 1384.00000 1385.14016  0.08%   8.4  629s
#   1309  1079 1385.01050   59   35 1384.00000 1385.14016  0.08%   8.4  648s
#   1310  1080 1385.12917    9   46 1384.00000 1385.14016  0.08%   8.4  653s
#   1311  1081 1385.05802   44   41 1384.00000 1385.14016  0.08%   8.4  669s
#   1312  1081 1385.04559   29   49 1384.00000 1385.14016  0.08%   8.4  678s
#   1313  1082 1385.02340  154   56 1384.00000 1385.14016  0.08%   8.4  691s
#   1314  1083 1385.05757   29   60 1384.00000 1385.14016  0.08%   8.4  704s
#   1315  1083 1385.03089   42   58 1384.00000 1385.14016  0.08%   8.4  730s
#   1316  1084 1385.03089   29   52 1384.00000 1385.14016  0.08%   8.4  739s
#   1317  1085 1385.05757   26   52 1384.00000 1385.14016  0.08%   8.4  747s
#   1318  1088 1385.14016   16   48 1384.00000 1385.14016  0.08%  43.6  758s
#   1320  1091 1385.13967   17   48 1384.00000 1385.13967  0.08%  43.6  760s
#   1336  1102 1385.10086   19   40 1384.00000 1385.10824  0.08%  43.6  765s
#   1401  1190 1385.07440   25   29 1384.00000 1385.10691  0.08%  42.1  772s
#   1466  1249 1385.04667   30   37 1384.00000 1385.10691  0.08%  40.6  781s
#   1565  1375 1385.04658   37   33 1384.00000 1385.10691  0.08%  38.6  799s
#   1733  1592 1385.04347   49   48 1384.00000 1385.10691  0.08%  35.6  822s
#   2091  1728 1385.00370   85   47 1384.00000 1385.10691  0.08%  30.7  838s
#   2521  1818 1385.00370  118   44 1384.00000 1385.10691  0.08%  26.5  851s
#   2845  1971 1385.00000  180   46 1384.00000 1385.10691  0.08%  25.9  865s
#   3150  2012 1385.00000  201   38 1384.00000 1385.10691  0.08%  27.5  879s
#   3296  2279     cutoff  202      1384.00000 1385.10691  0.08%  26.7  893s
#   3651  2571 1385.00000  222   37 1384.00000 1385.10691  0.08%  27.7  911s
#   4114  2778     cutoff  251      1384.00000 1385.10691  0.08%  29.1  928s
#   4506  3077 1385.00000  275   34 1384.00000 1385.10691  0.08%  29.9  947s
#   4982  3426 1385.00000  301   42 1384.00000 1385.10691  0.08%  31.0  969s
#   5398  3886 1385.00000  315   45 1384.00000 1385.10691  0.08%  31.3  989s
#   5819  3886 1385.00015  460   23 1384.00000 1385.10691  0.08%  32.4  990s
#   5914  4330 1385.00000  358   34 1384.00000 1385.10691  0.08%  32.0 1020s
#   6410  4879     cutoff  394      1384.00000 1385.10691  0.08%  33.2 1045s
#   7038  5416     cutoff  431      1384.00000 1385.10691  0.08%  35.2 1071s
#   7657  5908 1385.00000  454   44 1384.00000 1385.10691  0.08%  37.4 1096s
#   8223  6366     cutoff  482      1384.00000 1385.10691  0.08%  39.2 1122s
#   8785  6864 1385.00000  517   42 1384.00000 1385.10691  0.08%  41.5 1147s
#   9356  7346 1385.00000  542   42 1384.00000 1385.10691  0.08%  42.7 1175s
#   9941  7758 1385.00000  572   41 1384.00000 1385.10691  0.08%  44.7 1201s
#  10423  8260 1385.00000  596   42 1384.00000 1385.10691  0.08%  45.7 1227s
#  11025  8784 1385.00000  630   38 1384.00000 1385.10691  0.08%  46.8 1258s
#  11688  9270     cutoff  665      1384.00000 1385.10691  0.08%  48.5 1293s
#  12346  9887     cutoff  699      1384.00000 1385.10691  0.08%  50.4 1327s
#  13120  9888 1385.00000  949   65 1384.00000 1385.10691  0.08%  50.8 1568s
#  13122  9889 1385.00000  428  107 1384.00000 1385.10691  0.08%  50.8 1595s
#  13124  9891 1385.00015  157   59 1384.00000 1385.10691  0.08%  50.7 1607s
#  13125  9891 1385.00000  638  195 1384.00000 1385.10691  0.08%  50.7 1610s
#  13128  9893 1385.00000  873  165 1384.00000 1385.10691  0.08%  50.7 1620s
#  13129  9894 1385.00000  233  123 1384.00000 1385.10691  0.08%  50.7 1626s
#  13130  9895 1385.00000  561  113 1384.00000 1385.10691  0.08%  50.7 1657s
#  13131  9895 1385.00000 1092   89 1384.00000 1385.10691  0.08%  50.7 1660s
#  13133  9897 1385.00000  778   86 1384.00000 1385.10691  0.08%  50.7 1674s
#  13134  9897 1385.00000  673   57 1384.00000 1385.10691  0.08%  50.7 1689s
#  13135  9898 1385.00000  325   68 1384.00000 1385.10691  0.08%  50.7 1695s
#  13136  9899 1385.00015  568   68 1384.00000 1385.10691  0.08%  50.7 1713s
#  13137  9899 1385.00015 1017   85 1384.00000 1385.10691  0.08%  50.7 1717s
#  13138  9900 1385.00000 1074   82 1384.00000 1385.10691  0.08%  50.7 1742s
#  13139  9901 1385.00000  244   71 1384.00000 1385.10691  0.08%  50.7 1746s
#  13140  9901 1385.00000  554   79 1384.00000 1385.10691  0.08%  50.7 1768s
#  13141  9902 1385.00015  151   54 1384.00000 1385.10691  0.08%  50.7 1808s
#  13142  9903 1385.00000  435   54 1384.00000 1385.10691  0.08%  50.7 1828s
#  13143  9903 1385.00015  197   47 1384.00000 1385.10691  0.08%  50.7 1861s
#  13144  9904 1385.00015 1015   52 1384.00000 1385.10691  0.08%  50.7 1876s
#  13145  9905 1385.00015  289   62 1384.00000 1385.10691  0.08%  50.7 1900s
#  13146  9905 1385.00000 1010   61 1384.00000 1385.10691  0.08%  50.7 1912s
#  13147  9906 1385.00000 1067   75 1384.00000 1385.10691  0.08%  50.7 1916s
#  13148  9907 1385.00000  733   55 1384.00000 1385.10691  0.08%  50.7 1930s
#  13150  9911 1385.10691   27   52 1384.00000 1385.10691  0.08%  52.4 1940s
#  13156  9918 1385.10691   29   62 1384.00000 1385.10691  0.08%  52.4 1946s
#  13174  9929 1385.10691   31   61 1384.00000 1385.10691  0.08%  52.3 1950s
#  13203  9950 1385.10691   33   54 1384.00000 1385.10691  0.08%  52.3 1955s
#  13250 10028 1385.08970   36   56 1384.00000 1385.10691  0.08%  52.1 1965s
#  13322 10103 1385.01603   43   38 1384.00000 1385.10691  0.08%  51.9 1977s
#  13447 10161 1385.01401   61   30 1384.00000 1385.10691  0.08%  51.5 1988s
#  13673 10230 1385.01328   94   29 1384.00000 1385.10691  0.08%  50.7 2010s
#  13971 10331 1385.00000  124   29 1384.00000 1385.10691  0.08%  49.8 2035s
#  14207 10259 1385.00000  144   25 1384.00000 1385.10691  0.08%  49.8 2091s
#  14213 10510 1385.00000  144   26 1384.00000 1385.10691  0.08%  49.8 2122s
#  14482 10705 1385.00000  162   38 1384.00000 1385.10691  0.08%  49.5 2149s
#  14821 10966 1385.00000  186   33 1384.00000 1385.10691  0.08%  50.1 2187s
#  15243 11236 1385.00000  220   33 1384.00000 1385.10691  0.08%  50.1 2217s
#  15696 11311 1385.00000  252   32 1384.00000 1385.10691  0.08%  50.2 2262s
#  15948 11739 1385.00000  273   32 1384.00000 1385.10691  0.08%  50.3 2285s
#  16502 12025 1385.00000  304   42 1384.00000 1385.10691  0.08%  50.1 2309s
#  17030 12340 1385.00000  336   37 1384.00000 1385.10691  0.08%  50.2 2331s
#  17575 12570 1385.00000  355   35 1384.00000 1385.10691  0.08%  50.4 2353s
#  18043 12861     cutoff  381      1384.00000 1385.10691  0.08%  50.8 2377s
#  18548 12832 1385.00000  410   34 1384.00000 1385.10691  0.08%  51.2 2393s
#  18709 13451 1385.00000  417   32 1384.00000 1385.10691  0.08%  51.4 2421s
#  19454 13889 1385.00000  450   32 1384.00000 1385.10691  0.08%  51.7 2449s
#  20200 14273 1385.00000  487   33 1384.00000 1385.10691  0.08%  51.8 2477s
#  20934 14755 1385.00000  530   28 1384.00000 1385.10691  0.08%  52.3 2529s
#  21743 15078 1385.00000  571   28 1384.00000 1385.10691  0.08%  52.0 2574s
#  22431 15269 1385.00000  622   29 1384.00000 1385.10691  0.08%  52.4 2623s
#  23089 15855 1384.99965  688   30 1384.00000 1385.10691  0.08%  53.4 2674s
#  24096 16495 1385.00000  132   35 1384.00000 1385.10691  0.08%  53.2 2730s
#  25209 17003 1385.00000  570   37 1384.00000 1385.10691  0.08%  52.4 2785s
#  26194 17628 1385.00000  761   27 1384.00000 1385.10691  0.08%  51.8 3023s
#  27229 18018 1385.00000  975   26 1384.00000 1385.10691  0.08%  50.9 3052s
#  28086 18611 1385.00000 1135   31 1384.00000 1385.10691  0.08%  50.7 3085s
#  29151 19339 1385.00000 1267   29 1384.00000 1385.10691  0.08%  50.3 3118s
#  30377 19824 1385.00000 1408   25 1384.00000 1385.10691  0.08%  49.5 3145s
#  31337 20477 1385.00000 1510   30 1384.00000 1385.10691  0.08%  48.8 3172s
#  32315 21080 1385.00000 1660   30 1384.00000 1385.10691  0.08%  47.8 3199s
#  33303 21680 1385.00000 1795   33 1384.00000 1385.10691  0.08%  47.0 3223s
#  34321 22346 1385.05691   83   42 1384.00000 1385.10691  0.08%  46.2 3248s
#  35411 23133 1385.00000  352   45 1384.00000 1385.10691  0.08%  45.3 3276s
#  36879 23713 1385.00000  475   26 1384.00000 1385.10691  0.08%  44.1 3304s
#  38030 23852 1385.00000  569   31 1384.00000 1385.10691  0.08%  43.3 3349s
#  38594 24853 1385.00000  600   38 1384.00000 1385.10691  0.08%  42.9 3378s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 1
#   MIR: 31
#   StrongCG: 2
#   Flow cover: 24
#
# Explored 39959 nodes (1695780 simplex iterations) in 3600.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1384 1383 1382 1316
#
# Time limit reached
# Best objective 1.384000000000e+03, best bound 1.385000000000e+03, gap 0.0723%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4.5x1

# %%
datafile="4x2000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x285dfb89
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1237.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 6s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 13s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 20s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 20s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 25s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 30s) ...
# Sparsify removed 2543817 nonzeros (32%)
# Presolve added 0 rows and 121 columns
# Presolve removed 33 rows and 0 columns
# Presolve time: 31.94s
# Presolved: 9967 rows, 8121 columns, 5436169 nonzeros
# Variable types: 137 continuous, 7984 integer (7984 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9960000e+03   1.555552e+06   0.000000e+00     35s
#      169    1.9960000e+03   1.159407e+06   0.000000e+00     35s
#     2567    1.2961836e+03   0.000000e+00   0.000000e+00     37s
#
# Root relaxation: objective 1.296184e+03, 2567 iterations, 2.68 seconds
# Total elapsed time = 40.80s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1296.18362    0  194 1237.00000 1296.18362  4.78%     -   41s
# H    0     0                    1293.0000000 1296.18362  0.25%     -   42s
#      0     0 1296.17078    0  197 1293.00000 1296.17078  0.25%     -   48s
# H    0     0                    1294.0000000 1296.17078  0.17%     -   49s
# H    0     0                    1295.0000000 1296.17078  0.09%     -   51s
#      0     0     cutoff    0      1295.00000 1295.00000  0.00%     -   51s
#
# Cutting planes:
#   Gomory: 22
#   MIR: 74
#   RLT: 1
#
# Explored 1 nodes (9500 simplex iterations) in 51.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1295 1294 1293 1237
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.295000000000e+03, best bound 1.295000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4.5x2

# %%
datafile="4x2000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x736ecb28
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1234.0000000
# Presolve removed 46 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 46 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 46 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 46 rows and 24 columns (presolve time = 20s) ...
# Sparsify removed 2508423 nonzeros (31%)
# Presolve added 0 rows and 113 columns
# Presolve removed 50 rows and 0 columns
# Presolve time: 22.81s
# Presolved: 9950 rows, 8113 columns, 5455565 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.537752e+06   0.000000e+00     25s
#      157    1.9940000e+03   1.147718e+06   0.000000e+00     25s
#     2638    1.2957376e+03   0.000000e+00   0.000000e+00     27s
#
# Root relaxation: objective 1.295738e+03, 2638 iterations, 2.58 seconds
# Total elapsed time = 30.17s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1295.73761    0  259 1234.00000 1295.73761  5.00%     -   32s
# H    0     0                    1290.0000000 1295.73761  0.44%     -   32s
# H    0     0                    1293.0000000 1295.73761  0.21%     -   33s
#      0     0 1295.70116    0  240 1293.00000 1295.70116  0.21%     -   40s
#      0     0 1295.34174    0  219 1293.00000 1295.34174  0.18%     -   45s
#      0     0 1295.34004    0  229 1293.00000 1295.34004  0.18%     -   46s
#      0     0 1295.34004    0  230 1293.00000 1295.34004  0.18%     -   47s
#      0     0 1295.29431    0  203 1293.00000 1295.29431  0.18%     -   53s
#      0     0 1295.26570    0  182 1293.00000 1295.26570  0.18%     -   55s
#      0     0 1295.25935    0  164 1293.00000 1295.25935  0.17%     -   56s
#      0     0 1295.25935    0  172 1293.00000 1295.25935  0.17%     -   57s
#      0     0 1295.24619    0  182 1293.00000 1295.24619  0.17%     -   62s
#      0     0 1295.22706    0  183 1293.00000 1295.22706  0.17%     -   63s
#      0     0 1295.22529    0  168 1293.00000 1295.22529  0.17%     -   64s
#      0     0 1295.22529    0  168 1293.00000 1295.22529  0.17%     -   66s
#      0     0 1295.20947    0  149 1293.00000 1295.20947  0.17%     -   71s
#      0     0 1295.20725    0  156 1293.00000 1295.20725  0.17%     -   72s
#      0     0 1295.20710    0  159 1293.00000 1295.20710  0.17%     -   73s
#      0     0 1295.15438    0  159 1293.00000 1295.15438  0.17%     -   78s
#      0     0 1295.14519    0  152 1293.00000 1295.14519  0.17%     -   80s
#      0     0 1295.14202    0  152 1293.00000 1295.14202  0.17%     -   81s
#      0     0 1295.14202    0  153 1293.00000 1295.14202  0.17%     -   82s
#      0     0 1295.14081    0  161 1293.00000 1295.14081  0.17%     -   85s
#      0     0 1295.14081    0  147 1293.00000 1295.14081  0.17%     -   87s
#      0     0 1295.14003    0  157 1293.00000 1295.14003  0.17%     -   91s
#      0     0 1295.13285    0  156 1293.00000 1295.13285  0.16%     -   93s
#      0     0 1295.13285    0  150 1293.00000 1295.13285  0.16%     -   94s
#      0     0 1295.13209    0  147 1293.00000 1295.13209  0.16%     -   98s
#      0     0 1295.13209    0  145 1293.00000 1295.13209  0.16%     -   99s
#      0     0 1295.13209    0  149 1293.00000 1295.13209  0.16%     -  104s
#      0     0 1295.13202    0  151 1293.00000 1295.13202  0.16%     -  105s
#      0     0 1295.13079    0  118 1293.00000 1295.13079  0.16%     -  113s
# H    0     0                    1294.0000000 1295.13079  0.09%     -  114s
#      0     0 1295.13079    0  146 1294.00000 1295.13079  0.09%     -  115s
#      0     0 1295.13071    0  149 1294.00000 1295.13071  0.09%     -  122s
#      0     0 1295.13071    0  270 1294.00000 1295.13071  0.09%     -  141s
#      0     0 1295.13071    0  216 1294.00000 1295.13071  0.09%     -  145s
#      0     0 1295.13071    0  174 1294.00000 1295.13071  0.09%     -  146s
#      0     0 1295.13071    0  184 1294.00000 1295.13071  0.09%     -  147s
#      0     0 1295.13071    0  184 1294.00000 1295.13071  0.09%     -  147s
#      0     0 1295.13071    0  178 1294.00000 1295.13071  0.09%     -  148s
#      0     0 1295.13059    0  182 1294.00000 1295.13059  0.09%     -  150s
#      0     0 1295.12214    0  174 1294.00000 1295.12214  0.09%     -  152s
#      0     0 1295.12208    0  175 1294.00000 1295.12208  0.09%     -  152s
#      0     0 1295.11911    0  150 1294.00000 1295.11911  0.09%     -  155s
#      0     0 1295.11664    0  152 1294.00000 1295.11664  0.09%     -  156s
#      0     0 1295.11664    0  145 1294.00000 1295.11664  0.09%     -  157s
#      0     0 1295.11664    0  150 1294.00000 1295.11664  0.09%     -  159s
#      0     0 1295.10314    0  152 1294.00000 1295.10314  0.09%     -  160s
#      0     0 1295.10314    0  152 1294.00000 1295.10314  0.09%     -  160s
#      0     0 1295.10296    0  155 1294.00000 1295.10296  0.09%     -  162s
#      0     0 1295.08464    0  150 1294.00000 1295.08464  0.08%     -  164s
#      0     0 1295.08066    0  155 1294.00000 1295.08066  0.08%     -  164s
#      0     0 1295.08066    0  154 1294.00000 1295.08066  0.08%     -  165s
#      0     0 1295.08066    0  149 1294.00000 1295.08066  0.08%     -  167s
#      0     0 1295.08066    0  160 1294.00000 1295.08066  0.08%     -  168s
#      0     0 1295.07849    0  154 1294.00000 1295.07849  0.08%     -  170s
#      0     0 1295.07645    0  153 1294.00000 1295.07645  0.08%     -  172s
#      0     0 1295.07645    0  152 1294.00000 1295.07645  0.08%     -  172s
#      0     0 1295.06709    0  159 1294.00000 1295.06709  0.08%     -  174s
#      0     0 1295.06708    0  156 1294.00000 1295.06708  0.08%     -  175s
#      0     0 1295.06568    0  151 1294.00000 1295.06568  0.08%     -  177s
#      0     0 1295.06568    0  150 1294.00000 1295.06568  0.08%     -  179s
#      0     0 1295.06568    0  139 1294.00000 1295.06568  0.08%     -  181s
#      0     0 1295.06559    0  146 1294.00000 1295.06559  0.08%     -  182s
#      0     0 1295.06559    0  125 1294.00000 1295.06559  0.08%     -  184s
#      0     0 1295.06559    0  127 1294.00000 1295.06559  0.08%     -  184s
#      0     0 1295.06559    0  134 1294.00000 1295.06559  0.08%     -  186s
#      0     0 1295.06559    0  124 1294.00000 1295.06559  0.08%     -  187s
#      0     0 1295.06559    0  123 1294.00000 1295.06559  0.08%     -  191s
#      0     0 1295.06559    0  119 1294.00000 1295.06559  0.08%     -  194s
#      0     2 1295.06559    0  117 1294.00000 1295.06559  0.08%     -  201s
#     19    24 1295.05619    5   92 1294.00000 1295.05843  0.08%  63.4  205s
#     43    41 1295.03202    7   83 1294.00000 1295.05843  0.08%  34.7  210s
#    121   215     cutoff   17      1294.00000 1295.05843  0.08%  17.8  218s
#    245   387 1295.01082   35   79 1294.00000 1295.05843  0.08%  11.6  227s
#    477   645 1295.01771   14  121 1294.00000 1295.04893  0.08%   9.6  242s
#    842   926 1294.99911   42  116 1294.00000 1295.04604  0.08%  10.4  254s
#   1303   927 1294.99911   49  149 1294.00000 1295.04142  0.08%  11.8  348s
#   1305   928 1295.01082   39  201 1294.00000 1295.04142  0.08%  11.8  374s
#   1306   929 1295.00041   30  170 1294.00000 1295.04142  0.08%  11.8  378s
#   1308   930 1295.01082   39  127 1294.00000 1295.04142  0.08%  11.8  381s
#   1310   932 1295.00563   27  130 1294.00000 1295.04142  0.08%  11.8  390s
#   1312   933 1294.99989   54  143 1294.00000 1295.04142  0.08%  11.7  407s
#   1314   934 1295.00502   32  127 1294.00000 1295.04142  0.08%  11.7  410s
#   1315   935 1295.00718   17  142 1294.00000 1295.04142  0.08%  11.7  424s
#   1316   936 1295.01157   26  133 1294.00000 1295.04142  0.08%  11.7  426s
#   1318   937 1295.00137   47  108 1294.00000 1295.04142  0.08%  11.7  441s
#   1320   938 1295.00563   31  113 1294.00000 1295.04142  0.08%  11.7  456s
#   1322   940 1295.01154   21   99 1294.00000 1295.04142  0.08%  11.7  472s
#   1323   940 1295.00539   45   96 1294.00000 1295.04142  0.08%  11.6  500s
#   1325   942 1295.02236   22  116 1294.00000 1295.03503  0.08%  11.6  505s
#   1326   942 1295.02236   15  104 1294.00000 1295.03503  0.08%  11.6  515s
#   1327   943 1295.00498   45  101 1294.00000 1295.03503  0.08%  11.6  537s
#   1328   944 1295.01157   23  119 1294.00000 1295.03503  0.08%  11.6  553s
#   1329   944 1295.01835   19  117 1294.00000 1295.03503  0.08%  11.6  555s
#   1331   946 1295.00465   41  103 1294.00000 1295.03359  0.08%  11.6  572s
#   1332   946 1294.99872   38   99 1294.00000 1295.03359  0.08%  11.6  593s
#   1333   947 1295.02209   14   92 1294.00000 1295.03359  0.08%  11.6  606s
#   1335   948 1295.00353   24   99 1294.00000 1295.03359  0.08%  11.5  622s
#   1336   949 1295.01852    8   73 1294.00000 1295.03359  0.08%  11.5  641s
#   1337   950 1295.01996   12   78 1294.00000 1295.03359  0.08%  11.5  650s
#   1338   950 1295.01527   21   85 1294.00000 1295.03359  0.08%  11.5  666s
#   1339   951 1295.00647   42   80 1294.00000 1295.03359  0.08%  11.5  675s
#   1340   952 1295.00465   36   86 1294.00000 1295.03359  0.08%  11.5  697s
#   1341   952 1295.01977   12   96 1294.00000 1295.03359  0.08%  11.5  713s
#   1342   953 1295.00563   26   95 1294.00000 1295.03359  0.08%  11.5  726s
#   1343   954 1295.00795   30   95 1294.00000 1295.03359  0.08%  11.5  730s
#   1344   954 1295.00694   51   95 1294.00000 1295.03359  0.08%  11.5  743s
#   1345   958 1295.03359   15   92 1294.00000 1295.03359  0.08%  40.7  746s
#   1375   968 1295.02175   20   78 1294.00000 1295.02175  0.08%  40.1  751s
#   1427  1026 1295.01497   24   79 1294.00000 1295.02175  0.08%  39.3  755s
#   1475  1086 1295.01494   27   83 1294.00000 1295.02175  0.08%  38.3  760s
#   1576  1164 1295.00875   32   78 1294.00000 1295.02175  0.08%  37.3  768s
#   1747  1423 1295.01866   24   89 1294.00000 1295.01866  0.08%  35.4  784s
#   2291  1389     cutoff   35      1294.00000 1295.01866  0.08%  30.7  795s
#   2606  1510 1295.01138   27   92 1294.00000 1295.01866  0.08%  32.1  810s
#   3139  1467 1295.00794   34   98 1294.00000 1295.01866  0.08%  30.1  821s
#   3416  1600 1295.00794   37   96 1294.00000 1295.01866  0.08%  30.9  842s
#   3916  1586 1295.00649   38   98 1294.00000 1295.01866  0.08%  31.7  862s
#   4202  1680 1295.01425   34  124 1294.00000 1295.01866  0.08%  34.0  890s
#   4604  1878 1295.00810   29   92 1294.00000 1295.01866  0.08%  37.2  921s
#   5094  2160 1295.01380   33  147 1294.00000 1295.01844  0.08%  38.8  951s
#   5678  2407 1295.00748   36  154 1294.00000 1295.01844  0.08%  39.6  976s
#   6259  2620 1295.01719   31   99 1294.00000 1295.01795  0.08%  39.5 1009s
#   6883  2777     cutoff   29      1294.00000 1295.01741  0.08%  39.7 1038s
#   7426  2984 1295.00495   36   93 1294.00000 1295.01695  0.08%  40.0 1072s
#   8148  3206 1295.00650   27   77 1294.00000 1295.01612  0.08%  39.8 1104s
#   8723  3376 1295.00583   36  135 1294.00000 1295.01497  0.08%  41.6 1136s
#   9171  3647 1295.01286   30  102 1294.00000 1295.01497  0.08%  43.6 1171s
#   9740  3908 1295.00368   35  122 1294.00000 1295.01497  0.08%  45.0 1204s
#  10399  4149 1295.00740   33   90 1294.00000 1295.01497  0.08%  46.3 1243s
#  11016  4309 1295.00553   34  120 1294.00000 1295.01494  0.08%  48.5 1282s
#  11586  4326 1295.00837   40  235 1294.00000 1295.01494  0.08%  51.3 1332s
#  11708  4554 1295.00533   41  235 1294.00000 1295.01494  0.08%  51.6 1374s
#  11942  4554 1295.00583   35  137 1294.00000 1295.01494  0.08%  52.3 1375s
#  12469  4987 1295.01055   29  142 1294.00000 1295.01494  0.08%  53.2 1418s
#  13291  5155     cutoff   29      1294.00000 1295.01493  0.08%  53.0 1531s
#  13621  6152 1295.00368   35   89 1294.00000 1295.01493  0.08%  52.9 1595s
#  15712  6702 1295.00368   42  131 1294.00000 1295.01483  0.08%  52.5 1630s
#  17019  7115 1295.00875   36   88 1294.00000 1295.01483  0.08%  51.4 1660s
#  18021  7400 1295.00551   36  111 1294.00000 1295.01480  0.08%  51.5 1687s
#  18826  7787     cutoff   37      1294.00000 1295.01480  0.08%  52.0 1716s
#  19735  8260 1295.00697   32  140 1294.00000 1295.01480  0.08%  52.5 1747s
#  20808  8665     cutoff   38      1294.00000 1295.01480  0.08%  52.7 1776s
#  21749  9065 1295.00368   36  132 1294.00000 1295.01471  0.08%  53.2 1807s
#  22845  9418 1295.00567   38  113 1294.00000 1295.01471  0.08%  52.9 1838s
#  23804  9763 1295.00615   36  103 1294.00000 1295.01459  0.08%  52.7 1868s
#  24866  9927 1295.00697   36  106 1294.00000 1295.01434  0.08%  52.7 1888s
#  25341 10337     cutoff   39      1294.00000 1295.01434  0.08%  52.3 1920s
#  26438 10338 1295.00415   35  149 1294.00000 1295.01433  0.08%  52.2 2306s
#  26440 10339 1295.00172   31  204 1294.00000 1295.01433  0.08%  52.2 2322s
#  26443 10341 1295.00495   32  123 1294.00000 1295.01433  0.08%  52.2 2325s
#  26445 10343 1295.00427   38  109 1294.00000 1295.01433  0.08%  52.2 2330s
#  26447 10344 1295.00509   39   96 1294.00000 1295.01433  0.08%  52.2 2355s
#  26449 10345 1295.00744   42   97 1294.00000 1295.01433  0.08%  52.2 2383s
#  26450 10346 1295.00693   35  107 1294.00000 1295.01433  0.08%  52.2 2408s
#  26451 10347 1295.01051   36  109 1294.00000 1295.01433  0.08%  52.2 2435s
#  26452 10347 1295.00710   35   92 1294.00000 1295.01433  0.08%  52.2 2472s
#  26453 10348 1295.01199   34  101 1294.00000 1295.01433  0.08%  52.2 2487s
#  26454 10349 1295.00615   41  116 1294.00000 1295.01433  0.08%  52.2 2523s
#  26455 10349 1295.00697   31  125 1294.00000 1295.01433  0.08%  52.2 2538s
#  26456 10350 1295.01186   33   98 1294.00000 1295.01433  0.08%  52.1 2558s
#  26457 10351 1295.00875   37   94 1294.00000 1295.01433  0.08%  52.1 2578s
#  26458 10351 1295.00748   40   74 1294.00000 1295.01433  0.08%  52.1 2603s
#  26459 10352 1295.00697   44  108 1294.00000 1295.01433  0.08%  52.1 2617s
#  26460 10353 1295.00613   40   91 1294.00000 1295.01433  0.08%  52.1 2642s
#  26461 10353 1295.01104   36   92 1294.00000 1295.01433  0.08%  52.1 2645s
#  26462 10354 1295.01337   27   85 1294.00000 1295.01433  0.08%  52.1 2662s
#  26464 10355 1295.01366   32   92 1294.00000 1295.01433  0.08%  52.1 2681s
#  26466 10357 1295.00551   39   82 1294.00000 1295.01433  0.08%  52.1 2701s
#  26467 10357 1295.00825   31   66 1294.00000 1295.01433  0.08%  52.1 2723s
#  26468 10358 1295.00368   30   77 1294.00000 1295.01433  0.08%  52.1 2740s
#  26469 10359 1295.00509   37   83 1294.00000 1295.01433  0.08%  52.1 2762s
#  26470 10359 1295.00697   34   96 1294.00000 1295.01433  0.08%  52.1 2779s
#  26471 10360 1295.00414   38  103 1294.00000 1295.01433  0.08%  52.1 2801s
#  26472 10361 1295.00697   36  103 1294.00000 1295.01433  0.08%  52.1 2816s
#  26473 10361 1295.00697   39  103 1294.00000 1295.01433  0.08%  52.1 2823s
#  26474 10365 1295.01433   28   79 1294.00000 1295.01433  0.08%  53.4 2829s
#  26476 10366 1295.01433   29   79 1294.00000 1295.01433  0.08%  53.4 2832s
#  26492 10361 1295.01433   32   88 1294.00000 1295.01433  0.08%  53.4 2835s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 1
#   MIR: 32
#   Flow cover: 43
#
# Explored 26520 nodes (1430212 simplex iterations) in 2838.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1294 1293 1290 1234
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.294000000000e+03, best bound 1.294000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4.5x3

# %%
datafile="4x2000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x68f18354
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1258.0000000
# Presolve removed 45 rows and 36 columns (presolve time = 5s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 20s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 25s) ...
# Sparsify removed 2533710 nonzeros (32%)
# Presolve added 0 rows and 102 columns
# Presolve removed 45 rows and 0 columns
# Presolve time: 26.08s
# Presolved: 9955 rows, 8102 columns, 5406398 nonzeros
# Variable types: 138 continuous, 7964 integer (7964 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9910000e+03   1.521061e+06   0.000000e+00     28s
#     1118    1.5581156e+03   6.799454e+05   0.000000e+00     30s
#     4704    1.3095194e+03   0.000000e+00   0.000000e+00     34s
#
# Root relaxation: objective 1.309519e+03, 4704 iterations, 6.46 seconds
# Total elapsed time = 35.57s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1309.51940    0  122 1258.00000 1309.51940  4.10%     -   39s
# H    0     0                    1306.0000000 1309.51940  0.27%     -   39s
# H    0     0                    1307.0000000 1309.51940  0.19%     -   40s
#      0     0 1309.51658    0  141 1307.00000 1309.51658  0.19%     -   44s
# H    0     0                    1308.0000000 1309.51658  0.12%     -   48s
#      0     0 1309.44469    0  114 1308.00000 1309.44469  0.11%     -   49s
#      0     0 1309.44469    0  116 1308.00000 1309.44469  0.11%     -   50s
#      0     0 1309.28207    0   98 1308.00000 1309.28207  0.10%     -   54s
#      0     0 1309.28162    0   98 1308.00000 1309.28162  0.10%     -   56s
#      0     0 1309.28162    0  100 1308.00000 1309.28162  0.10%     -   57s
#      0     0 1309.28135    0   89 1308.00000 1309.28135  0.10%     -   62s
#      0     0 1309.28135    0   85 1308.00000 1309.28135  0.10%     -   63s
#      0     0 1309.28116    0   84 1308.00000 1309.28116  0.10%     -   67s
#      0     0 1309.28112    0   84 1308.00000 1309.28112  0.10%     -   69s
#      0     0 1309.28101    0   84 1308.00000 1309.28101  0.10%     -   73s
#      0     0 1309.28101    0   92 1308.00000 1309.28101  0.10%     -   75s
#      0     0 1309.28101    0   84 1308.00000 1309.28101  0.10%     -   79s
#      0     0 1309.28101    0   85 1308.00000 1309.28101  0.10%     -   80s
#      0     0 1309.28101    0   75 1308.00000 1309.28101  0.10%     -   86s
#      0     0 1309.28101    0   75 1308.00000 1309.28101  0.10%     -   87s
#      0     0 1309.28101    0   90 1308.00000 1309.28101  0.10%     -   92s
#      0     0 1309.28101    0   98 1308.00000 1309.28101  0.10%     -   93s
#      0     0 1309.27517    0  125 1308.00000 1309.27517  0.10%     -  103s
#      0     0 1309.26957    0  131 1308.00000 1309.26957  0.10%     -  105s
#      0     0 1309.26957    0  132 1308.00000 1309.26957  0.10%     -  106s
#      0     0 1309.26952    0  128 1308.00000 1309.26952  0.10%     -  110s
#      0     0 1309.25410    0  117 1308.00000 1309.25410  0.10%     -  112s
#      0     0 1309.25405    0  115 1308.00000 1309.25405  0.10%     -  113s
#      0     0 1309.25390    0  120 1308.00000 1309.25390  0.10%     -  117s
#      0     0 1309.25390    0  116 1308.00000 1309.25390  0.10%     -  119s
#      0     0 1309.25344    0  116 1308.00000 1309.25344  0.10%     -  122s
#      0     0 1309.25344    0  104 1308.00000 1309.25344  0.10%     -  124s
#      0     0 1309.25344    0  110 1308.00000 1309.25344  0.10%     -  126s
#      0     0 1309.25344    0  111 1308.00000 1309.25344  0.10%     -  128s
#      0     0 1309.25344    0  121 1308.00000 1309.25344  0.10%     -  132s
#      0     0 1309.25344    0   97 1308.00000 1309.25344  0.10%     -  137s
#      0     0 1309.25344    0  136 1308.00000 1309.25344  0.10%     -  165s
#      0     0 1309.25344    0  138 1308.00000 1309.25344  0.10%     -  170s
#      0     0 1309.25344    0  101 1308.00000 1309.25344  0.10%     -  173s
#      0     0 1309.25344    0  105 1308.00000 1309.25344  0.10%     -  174s
#      0     0 1309.25344    0  105 1308.00000 1309.25344  0.10%     -  175s
#      0     0 1309.25344    0   98 1308.00000 1309.25344  0.10%     -  180s
#      0     0 1309.25344    0   93 1308.00000 1309.25344  0.10%     -  181s
#      0     0 1309.25344    0   82 1308.00000 1309.25344  0.10%     -  184s
#      0     0 1309.25344    0   88 1308.00000 1309.25344  0.10%     -  186s
#      0     0 1309.25344    0   94 1308.00000 1309.25344  0.10%     -  190s
# H    0     0                    1309.0000000 1309.25344  0.02%     -  192s
#      0     0 1309.25344    0   94 1309.00000 1309.25344  0.02%     -  192s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 9
#   Implied bound: 1
#   MIR: 50
#   StrongCG: 1
#   GUB cover: 4
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (35191 simplex iterations) in 192.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1309 1308 1307 ... 1258
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.309000000000e+03, best bound 1.309000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4.5x4

# %%
datafile="4x2000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x2e301752
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1237.0000000
# Presolve removed 46 rows and 40 columns (presolve time = 7s) ...
# Presolve removed 46 rows and 40 columns (presolve time = 11s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 31s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 35s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 40s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 50s) ...
# Sparsify removed 2561741 nonzeros (32%)
# Presolve removed 62 rows and 7817 columns (presolve time = 55s) ...
# Presolve added 0 rows and 107 columns
# Presolve removed 62 rows and 0 columns
# Presolve time: 55.36s
# Presolved: 9938 rows, 8107 columns, 5370407 nonzeros
# Variable types: 147 continuous, 7960 integer (7960 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9900000e+03   1.540729e+06   0.000000e+00     60s
#      192    1.6076928e+03   7.870308e+05   0.000000e+00     61s
#     1472    1.3028205e+03   1.442249e+04   0.000000e+00     65s
#     2548    1.3016350e+03   0.000000e+00   0.000000e+00     66s
#
# Root relaxation: objective 1.301635e+03, 2548 iterations, 7.29 seconds
# Total elapsed time = 71.75s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1301.63502    0  201 1237.00000 1301.63502  5.23%     -   75s
# H    0     0                    1297.0000000 1301.63502  0.36%     -   76s
# H    0     0                    1299.0000000 1301.63502  0.20%     -   77s
# H    0     0                    1300.0000000 1301.63502  0.13%     -   78s
#      0     0 1301.61024    0  247 1300.00000 1301.61024  0.12%     -   87s
#      0     0 1301.53239    0  207 1300.00000 1301.53239  0.12%     -   94s
#      0     0 1301.53204    0  205 1300.00000 1301.53204  0.12%     -   96s
#      0     0 1301.53193    0  208 1300.00000 1301.53193  0.12%     -   98s
#      0     0 1301.52960    0  189 1300.00000 1301.52960  0.12%     -  107s
#      0     0 1301.47117    0  169 1300.00000 1301.47117  0.11%     -  111s
#      0     0 1301.47078    0  165 1300.00000 1301.47078  0.11%     -  113s
#      0     0 1301.47078    0  161 1300.00000 1301.47078  0.11%     -  114s
#      0     0 1301.36602    0  180 1300.00000 1301.36602  0.11%     -  118s
#      0     0 1301.36564    0  162 1300.00000 1301.36564  0.11%     -  120s
#      0     0 1301.36563    0  170 1300.00000 1301.36563  0.11%     -  121s
#      0     0 1301.36214    0  160 1300.00000 1301.36214  0.10%     -  126s
#      0     0 1301.36115    0  136 1300.00000 1301.36115  0.10%     -  128s
#      0     0 1301.36115    0  147 1300.00000 1301.36115  0.10%     -  129s
#      0     0 1301.35477    0  150 1300.00000 1301.35477  0.10%     -  134s
#      0     0 1301.35329    0  149 1300.00000 1301.35329  0.10%     -  136s
#      0     0 1301.35329    0  151 1300.00000 1301.35329  0.10%     -  137s
#      0     0 1301.30440    0  139 1300.00000 1301.30440  0.10%     -  142s
#      0     0 1301.30440    0  156 1300.00000 1301.30440  0.10%     -  143s
#      0     0 1301.28954    0  150 1300.00000 1301.28954  0.10%     -  147s
#      0     0 1301.27737    0  141 1300.00000 1301.27737  0.10%     -  149s
#      0     0 1301.27737    0  147 1300.00000 1301.27737  0.10%     -  150s
#      0     0 1301.27737    0  136 1300.00000 1301.27737  0.10%     -  154s
#      0     0 1301.27737    0  136 1300.00000 1301.27737  0.10%     -  155s
#      0     0 1301.27736    0  131 1300.00000 1301.27736  0.10%     -  158s
#      0     0 1301.27736    0  136 1300.00000 1301.27736  0.10%     -  159s
#      0     0 1301.25276    0  138 1300.00000 1301.25276  0.10%     -  162s
#      0     0 1301.24900    0  133 1300.00000 1301.24900  0.10%     -  164s
#      0     0 1301.24900    0  122 1300.00000 1301.24900  0.10%     -  165s
#      0     0 1301.24713    0  130 1300.00000 1301.24713  0.10%     -  169s
#      0     0 1301.24712    0  126 1300.00000 1301.24712  0.10%     -  171s
#      0     0 1301.24712    0  120 1300.00000 1301.24712  0.10%     -  174s
#      0     0 1301.24712    0  127 1300.00000 1301.24712  0.10%     -  175s
#      0     0 1301.24712    0  128 1300.00000 1301.24712  0.10%     -  178s
#      0     0 1301.24712    0  125 1300.00000 1301.24712  0.10%     -  180s
#      0     0 1301.24666    0  119 1300.00000 1301.24666  0.10%     -  186s
#      0     0 1301.24666    0  119 1300.00000 1301.24666  0.10%     -  189s
#      0     0 1301.24666    0  212 1300.00000 1301.24666  0.10%     -  209s
#      0     0 1301.24666    0  196 1300.00000 1301.24666  0.10%     -  213s
#      0     0 1301.24666    0  159 1300.00000 1301.24666  0.10%     -  214s
#      0     0 1301.24646    0  156 1300.00000 1301.24646  0.10%     -  215s
#      0     0 1301.24646    0  155 1300.00000 1301.24646  0.10%     -  216s
#      0     0 1301.24483    0  178 1300.00000 1301.24483  0.10%     -  218s
#      0     0 1301.24483    0  160 1300.00000 1301.24483  0.10%     -  219s
#      0     0 1301.24483    0  176 1300.00000 1301.24483  0.10%     -  222s
#      0     0 1301.24483    0  160 1300.00000 1301.24483  0.10%     -  223s
#      0     0 1301.24482    0  159 1300.00000 1301.24482  0.10%     -  225s
#      0     0 1301.24482    0  158 1300.00000 1301.24482  0.10%     -  226s
#      0     0 1301.24481    0  164 1300.00000 1301.24481  0.10%     -  229s
#      0     0 1301.24481    0  154 1300.00000 1301.24481  0.10%     -  230s
#      0     0 1301.24481    0  161 1300.00000 1301.24481  0.10%     -  232s
#      0     0 1301.24481    0  165 1300.00000 1301.24481  0.10%     -  233s
#      0     0 1301.24481    0  138 1300.00000 1301.24481  0.10%     -  236s
#      0     0 1301.24481    0  148 1300.00000 1301.24481  0.10%     -  238s
#      0     0 1301.24467    0  162 1300.00000 1301.24467  0.10%     -  240s
#      0     0 1301.24467    0  166 1300.00000 1301.24467  0.10%     -  241s
#      0     0 1301.24437    0  162 1300.00000 1301.24437  0.10%     -  243s
#      0     0 1301.24437    0  136 1300.00000 1301.24437  0.10%     -  248s
#      0     2 1301.24437    0  135 1300.00000 1301.24437  0.10%     -  253s
#      3     8 1301.23680    2  134 1300.00000 1301.23680  0.10%   367  255s
#     37    43 1301.22039    8  112 1300.00000 1301.22039  0.09%  43.5  260s
#     64    96 1301.18853   12  113 1300.00000 1301.21771  0.09%  29.5  265s
#     99   183 1301.18130   18  107 1300.00000 1301.21771  0.09%  21.9  270s
#    186   361 1301.17558   26   98 1300.00000 1301.21771  0.09%  15.6  278s
#    364   687 1301.18086   43  123 1300.00000 1301.21771  0.09%  11.4  292s
#    692  1158 1301.17405  131  117 1300.00000 1301.21771  0.09%   8.9  308s
#   1180  1552 1301.16809  203  118 1300.00000 1301.21771  0.09%   7.2  322s
#   1625  1899 1301.16168  295  102 1300.00000 1301.21771  0.09%   6.8  338s
#   1998  2035 1301.14256  386  119 1300.00000 1301.21771  0.09%   6.6  350s
#   2161  2128 1301.12654  446  117 1300.00000 1301.21771  0.09%   6.9  365s
#   2268  2588 1301.12395  453  109 1300.00000 1301.21771  0.09%   7.2  384s
#   2736  2983 1301.11259  525  112 1300.00000 1301.21771  0.09%   7.3  403s
#   3163  3354 1301.10100  601  101 1300.00000 1301.21771  0.09%   7.1  422s
#   3599  3901 1301.09014  668  113 1300.00000 1301.21771  0.09%   7.2  445s
#   4224  4439 1301.02381  732  107 1300.00000 1301.21598  0.09%   7.4  470s
#   4922  4440 1301.17431   98  119 1300.00000 1301.21328  0.09%   7.5  557s
#   4924  4441 1301.10657  185  202 1300.00000 1301.21328  0.09%   7.5  593s
#   4925  4442 1301.00007   95  204 1300.00000 1301.21328  0.09%   7.5  598s
#   4927  4443 1301.16498  251  154 1300.00000 1301.21328  0.09%   7.5  601s
#   4929  4445 1301.12195  218  163 1300.00000 1301.21328  0.09%   7.5  608s
#   4930  4445 1301.16795   77  159 1300.00000 1301.21328  0.09%   7.5  634s
#   4931  4446 1301.14631  346  144 1300.00000 1301.21328  0.09%   7.5  636s
#   4932  4447 1301.02712  539  128 1300.00000 1301.21328  0.09%   7.5  641s
#   4933  4447 1301.02001  298  132 1300.00000 1301.21328  0.09%   7.5  657s
#   4934  4448 1301.09901  244  120 1300.00000 1301.21328  0.09%   7.5  661s
#   4935  4449 1301.09878   87  136 1300.00000 1301.21328  0.09%   7.5  667s
#   4936  4449 1301.00128   30  123 1300.00000 1301.21328  0.09%   7.5  687s
#   4937  4450 1301.02247  187  124 1300.00000 1301.21328  0.09%   7.5  690s
#   4938  4451 1301.02192  176  122 1300.00000 1301.20510  0.09%   7.5  695s
#   4939  4451 1301.10605  284  112 1300.00000 1301.20510  0.09%   7.5  712s
#   4940  4452 1301.15075   29  110 1300.00000 1301.20127  0.09%   7.5  717s
#   4941  4453 1301.07311  403  109 1300.00000 1301.19484  0.09%   7.5  723s
#   4942  4453 1301.13438  227  114 1300.00000 1301.19484  0.09%   7.5  743s
#   4943  4454 1301.10467  556  108 1300.00000 1301.18986  0.09%   7.5  747s
#   4944  4455 1301.02427  176  106 1300.00000 1301.18979  0.09%   7.5  767s
#   4945  4455 1301.10740  274  107 1300.00000 1301.18979  0.09%   7.5  774s
#   4946  4456 1301.10724   55  127 1300.00000 1301.18979  0.09%   7.5  804s
#   4947  4457 1301.03898   40  120 1300.00000 1301.18979  0.09%   7.5  808s
#   4948  4457 1301.03653  202  108 1300.00000 1301.18979  0.09%   7.5  826s
#   4950  4459 1301.13092  441  113 1300.00000 1301.18979  0.09%   7.5  839s
#   4951  4459 1301.16278   76   79 1300.00000 1301.18979  0.09%   7.5  855s
#   4952  4460 1301.11195  317  103 1300.00000 1301.18979  0.09%   7.5  867s
#   4953  4461 1301.04252  400   93 1300.00000 1301.18979  0.09%   7.5  884s
#   4954  4461 1301.02978  228  104 1300.00000 1301.18979  0.09%   7.5  897s
#   4955  4462 1301.13536  424   95 1300.00000 1301.18979  0.09%   7.5  916s
#   4957  4463 1301.11462  239   95 1300.00000 1301.18979  0.09%   7.5  954s
#   4958  4467 1301.18973   10   84 1300.00000 1301.18973  0.09%  12.0  966s
#   4964  4475 1301.17566   12   96 1300.00000 1301.18449  0.09%  12.1  974s
#   4970  4479 1301.17558   13   98 1300.00000 1301.18375  0.09%  12.2  975s
#   4994  4499 1301.17558   15   94 1300.00000 1301.17558  0.09%  12.2  980s
#   5024  4510 1301.05332   17   91 1300.00000 1301.17558  0.09%  12.2  986s
#   5030  4551 1301.05332   18   91 1300.00000 1301.17558  0.09%  12.2  990s
#   5122  4658 1301.02692   26   72 1300.00000 1301.17558  0.09%  12.2 1004s
#   5223  4825 1301.02647   36   75 1300.00000 1301.17558  0.09%  12.2 1020s
#   5424  5077 1301.02228   50   82 1300.00000 1301.17558  0.09%  12.2 1049s
#   5761  5450 1301.03805   23   86 1300.00000 1301.17469  0.09%  13.1 1080s
#   6285  5457 1301.02192   43   79 1300.00000 1301.17469  0.09%  13.1 1099s
#   6466  5705 1301.01606   90   76 1300.00000 1301.17469  0.09%  12.8 1127s
#   6775  6146 1301.01461  149   73 1300.00000 1301.17469  0.09%  12.5 1162s
#   7417  6536 1301.13049  110   65 1300.00000 1301.17391  0.09%  12.3 1198s
#   8122  7144 1301.14645   31   78 1300.00000 1301.16816  0.09%  12.0 1233s
#   9011  7512 1301.13586   89   62 1300.00000 1301.16816  0.09%  11.6 1261s
#   9808  7951 1300.99874  225   86 1300.00000 1301.16113  0.09%  11.4 1286s
#  10632  8367 1301.02594  183   71 1300.00000 1301.15899  0.09%  11.1 1318s
#  11407  8792 1301.10477   61  104 1300.00000 1301.15892  0.09%  11.0 1343s
#  12169  8995 1301.01172  144  109 1300.00000 1301.15892  0.09%  10.8 1369s
#  12745  9669 1300.99923  220   84 1300.00000 1301.15768  0.09%  10.7 1506s
#  13678  9480 1301.02513  217   63 1300.00000 1301.15768  0.09%  10.4 1515s
#  13808 10106 1301.00196  237   89 1300.00000 1301.15767  0.09%  10.4 1531s
#  14566 10571 infeasible  113      1300.00000 1301.15589  0.09%  10.3 1547s
#  15398 10477 1301.12969   66   84 1300.00000 1301.15478  0.09%  10.2 1557s
#  15605 11228 1301.11981  104   98 1300.00000 1301.15478  0.09%  10.2 1575s
#  16540 11611 1301.13755   43   74 1300.00000 1301.15453  0.09%  10.1 1592s
#  17316 11818 1301.06824  181  120 1300.00000 1301.15453  0.09%  10.1 1607s
#  17891 12333 1301.05513  248  118 1300.00000 1301.15453  0.09%  10.1 1627s
#  18770 12804 1301.02316  321  118 1300.00000 1301.15312  0.09%  10.1 1648s
#  19513 13563 1301.09750   47  101 1300.00000 1301.15127  0.09%  10.2 1672s
#  20302 14327 1301.07617  112   86 1300.00000 1301.15127  0.09%  10.5 1694s
#  21108 15098 1301.02891  176   91 1300.00000 1301.15127  0.09%  10.7 1717s
#  22049 16011 1301.13625   62  104 1300.00000 1301.14948  0.09%  10.9 1738s
#  22988 17114 1301.10914  224   73 1300.00000 1301.14948  0.09%  11.0 1758s
#  24145 17977 1301.10287  380   71 1300.00000 1301.14948  0.09%  10.9 1775s
#  25072 18763 1301.09978  445   74 1300.00000 1301.14948  0.09%  11.0 1794s
#  25882 18764 1301.12475   56  119 1300.00000 1301.14948  0.09%  11.1 2283s
#  25884 18765 1301.14645   33  191 1300.00000 1301.14948  0.09%  11.1 2308s
#  25885 18766 1301.01200  238  157 1300.00000 1301.14948  0.09%  11.1 2311s
#  25889 18769 1301.02584  469  131 1300.00000 1301.14948  0.09%  11.1 2329s
#  25890 18769 1301.13979   65  126 1300.00000 1301.14948  0.09%  11.1 2330s
#  25893 18771 1301.09796  135  127 1300.00000 1301.14948  0.09%  11.1 2361s
#  25895 18773 1301.03695  150  125 1300.00000 1301.14948  0.09%  11.1 2401s
#  25897 18774 1301.07786  175  130 1300.00000 1301.14948  0.09%  11.1 2431s
#  25899 18775 1301.04666  134  120 1300.00000 1301.14948  0.09%  11.1 2471s
#  25901 18777 1301.13868   76  111 1300.00000 1301.14948  0.09%  11.1 2512s
#  25902 18777 1301.12981  105  123 1300.00000 1301.14948  0.09%  11.1 2515s
#  25903 18778 1301.12979   66  123 1300.00000 1301.14948  0.09%  11.1 2539s
#  25904 18779 1301.03846   32  113 1300.00000 1301.14948  0.09%  11.1 2542s
#  25905 18779 1301.11348  110  120 1300.00000 1301.14948  0.09%  11.1 2580s
#  25907 18781 1301.09204   63  128 1300.00000 1301.14948  0.09%  11.1 2624s
#  25908 18781 1301.00196  235  118 1300.00000 1301.14948  0.09%  11.1 2669s
#  25909 18782 1300.99921  273  113 1300.00000 1301.14948  0.09%  11.1 2708s
#  25910 18783 1301.02344  246  127 1300.00000 1301.14948  0.09%  11.1 2712s
#  25911 18783 1301.10204   69  110 1300.00000 1301.14948  0.09%  11.1 2754s
#  25912 18784 1301.04188  134  124 1300.00000 1301.14948  0.09%  11.1 2755s
#  25913 18785 1301.07848   60  118 1300.00000 1301.14948  0.09%  11.1 2785s
#  25915 18786 1301.02692   26  114 1300.00000 1301.14948  0.09%  11.1 2807s
#  25916 18787 1301.01640   19  103 1300.00000 1301.14948  0.09%  11.1 2850s
#  25917 18787 1301.02089  156  113 1300.00000 1301.14948  0.09%  11.1 2877s
#  25918 18788 1301.07153  260  116 1300.00000 1301.14948  0.09%  11.1 2906s
#  25919 18789 1301.12327   46  121 1300.00000 1301.14948  0.09%  11.1 2930s
#  25920 18789 1301.06387  167  129 1300.00000 1301.14948  0.09%  11.1 2959s
#  25921 18790 1301.01532  218  131 1300.00000 1301.14948  0.09%  11.1 2981s
#  25923 18791 1301.00000  703  116 1300.00000 1301.14948  0.09%  11.1 3005s
#  25925 18793 1301.13014   64  114 1300.00000 1301.14948  0.09%  11.1 3027s
#  25926 18793 1301.07325  160  125 1300.00000 1301.14948  0.09%  11.1 3033s
#  25927 18794 1301.05191   19  107 1300.00000 1301.14948  0.09%  11.1 3058s
#  25928 18795 1301.00300  204  111 1300.00000 1301.14948  0.09%  11.1 3060s
#  25929 18795 1301.13324   64  100 1300.00000 1301.14948  0.09%  11.1 3080s
#  25930 18796 1301.10434  207  121 1300.00000 1301.14948  0.09%  11.1 3088s
#  25931 18797 1301.00559  231  118 1300.00000 1301.14948  0.09%  11.1 3112s
#  25932 18797 1301.13401   47  125 1300.00000 1301.14948  0.09%  11.1 3115s
#  25933 18798 1301.10711  115  124 1300.00000 1301.14948  0.09%  11.1 3144s
#  25934 18799 1301.00318   82  117 1300.00000 1301.14948  0.09%  11.1 3146s
#  25935 18799 1301.03779   52  125 1300.00000 1301.14948  0.09%  11.1 3167s
#  25937 18801 1301.00000  609  116 1300.00000 1301.14948  0.09%  11.1 3189s
#  25938 18801 1301.00926  213  111 1300.00000 1301.14948  0.09%  11.1 3191s
#  25939 18802 1301.11298   97  111 1300.00000 1301.14948  0.09%  11.1 3215s
#  25941 18803 1300.99877  251  125 1300.00000 1301.14948  0.09%  11.1 3248s
#  25942 18804 1301.11277   85  127 1300.00000 1301.14948  0.09%  11.1 3250s
#  25943 18805 1301.10886  195  116 1300.00000 1301.14948  0.09%  11.1 3283s
#  25944 18805 1301.00574  174  106 1300.00000 1301.14948  0.09%  11.1 3286s
#  25945 18806 1301.00645   48  119 1300.00000 1301.14948  0.09%  11.1 3318s
#  25946 18807 1301.13409   64  112 1300.00000 1301.14948  0.09%  11.1 3322s
#  25947 18807 1301.13466   89  109 1300.00000 1301.14948  0.09%  11.1 3343s
#  25948 18808 1301.05006  158  102 1300.00000 1301.14948  0.09%  11.1 3346s
#  25949 18809 1301.04065  145  101 1300.00000 1301.14948  0.09%  11.1 3368s
#  25950 18809 1301.14294   20  103 1300.00000 1301.14948  0.09%  11.1 3399s
#  25951 18810 1301.08784  138  119 1300.00000 1301.14948  0.09%  11.1 3419s
#  25952 18811 1301.05127  147  113 1300.00000 1301.14948  0.09%  11.1 3421s
#  25953 18811 1301.00000  320  126 1300.00000 1301.14948  0.09%  11.1 3445s
#  25954 18812 1301.03399  142  120 1300.00000 1301.14948  0.09%  11.1 3473s
#  25955 18813 1301.00000  893  106 1300.00000 1301.14948  0.09%  11.1 3495s
#  25957 18814 1301.04185  425  118 1300.00000 1301.14948  0.09%  11.1 3520s
#  25958 18815 1301.14294   34  129 1300.00000 1301.14948  0.09%  11.1 3525s
#  25959 18815 1301.00464  215  125 1300.00000 1301.14948  0.09%  11.1 3556s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 7
#   MIR: 131
#   StrongCG: 1
#   Flow cover: 156
#   GUB cover: 5
#   Zero half: 7
#   RLT: 2
#
# Explored 25959 nodes (349796 simplex iterations) in 3600.47 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1300 1299 1297 1237
#
# Time limit reached
# Best objective 1.300000000000e+03, best bound 1.301000000000e+03, gap 0.0769%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x4.5x5

# %%
datafile="4x2000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x6fdf8364
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1230.0000000
# Presolve removed 34 rows and 24 columns (presolve time = 5s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 20s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 25s) ...
# Sparsify removed 2508423 nonzeros (31%)
# Presolve added 0 rows and 113 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 25.90s
# Presolved: 9962 rows, 8113 columns, 5455589 nonzeros
# Variable types: 137 continuous, 7976 integer (7976 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9940000e+03   1.602303e+06   0.000000e+00     28s
#     1497    1.4673221e+03   5.319538e+05   0.000000e+00     30s
#     4903    1.2906721e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 1.290672e+03, 4903 iterations, 5.65 seconds
# Total elapsed time = 36.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1290.67209    0  390 1230.00000 1290.67209  4.93%     -   40s
# H    0     0                    1286.0000000 1290.67209  0.36%     -   41s
# H    0     0                    1287.0000000 1290.67209  0.29%     -   41s
# H    0     0                    1288.0000000 1290.67209  0.21%     -   42s
#      0     0 1290.66540    0  375 1288.00000 1290.66540  0.21%     -   49s
# H    0     0                    1289.0000000 1290.66540  0.13%     -   55s
#      0     0 1290.62715    0  318 1289.00000 1290.62715  0.13%     -   56s
#      0     0 1290.45221    0  308 1289.00000 1290.45221  0.11%     -   57s
#      0     0 1290.45221    0  303 1289.00000 1290.45221  0.11%     -   58s
#      0     0 1290.41570    0  341 1289.00000 1290.41570  0.11%     -   65s
#      0     0 1290.40974    0  347 1289.00000 1290.40974  0.11%     -   67s
#      0     0 1290.40974    0  350 1289.00000 1290.40974  0.11%     -   69s
#      0     0 1290.33228    0  319 1289.00000 1290.33228  0.10%     -   77s
#      0     0 1290.33140    0  322 1289.00000 1290.33140  0.10%     -   79s
#      0     0 1290.33115    0  320 1289.00000 1290.33115  0.10%     -   81s
#      0     0 1290.33102    0  314 1289.00000 1290.33102  0.10%     -   82s
#      0     0 1290.07102    0  274 1289.00000 1290.07102  0.08%     -   88s
#      0     0 1290.07102    0  278 1289.00000 1290.07102  0.08%     -   90s
#      0     0 1290.06912    0  251 1289.00000 1290.06912  0.08%     -   98s
#      0     0 1290.06912    0  340 1289.00000 1290.06912  0.08%     -  112s
#      0     0 1290.06912    0  322 1289.00000 1290.06912  0.08%     -  117s
#      0     0 1290.06912    0  318 1289.00000 1290.06912  0.08%     -  118s
#      0     0 1290.06912    0  295 1289.00000 1290.06912  0.08%     -  118s
#      0     0 1290.06912    0  283 1289.00000 1290.06912  0.08%     -  119s
#      0     0 1290.06912    0  281 1289.00000 1290.06912  0.08%     -  119s
#      0     0 1290.06912    0  285 1289.00000 1290.06912  0.08%     -  120s
#      0     0 1290.06912    0  270 1289.00000 1290.06912  0.08%     -  123s
#      0     0 1290.06639    0  278 1289.00000 1290.06639  0.08%     -  124s
#      0     0 1290.06603    0  270 1289.00000 1290.06603  0.08%     -  124s
#      0     0 1290.06601    0  282 1289.00000 1290.06601  0.08%     -  125s
#      0     0 1290.06599    0  270 1289.00000 1290.06599  0.08%     -  129s
#      0     0 1290.06559    0  268 1289.00000 1290.06559  0.08%     -  130s
#      0     0 1290.06515    0  267 1289.00000 1290.06515  0.08%     -  130s
#      0     0 1290.06515    0  280 1289.00000 1290.06515  0.08%     -  131s
#      0     0 1290.06229    0  259 1289.00000 1290.06229  0.08%     -  134s
#      0     0 1290.05996    0  257 1289.00000 1290.05996  0.08%     -  135s
#      0     0 1290.05993    0  259 1289.00000 1290.05993  0.08%     -  136s
#      0     0 1290.05993    0  241 1289.00000 1290.05993  0.08%     -  139s
#      0     0 1290.05983    0  255 1289.00000 1290.05983  0.08%     -  140s
#      0     0 1290.05983    0  254 1289.00000 1290.05983  0.08%     -  142s
#      0     0 1290.05983    0  267 1289.00000 1290.05983  0.08%     -  143s
#      0     0 1290.05983    0  270 1289.00000 1290.05983  0.08%     -  146s
#      0     0 1290.05983    0  251 1289.00000 1290.05983  0.08%     -  150s
#      0     2 1290.05983    0  231 1289.00000 1290.05983  0.08%     -  158s
#      3     8 1290.05821    2  252 1289.00000 1290.05821  0.08%   399  160s
#     37    44 1290.05190    7  245 1289.00000 1290.05416  0.08%  90.2  165s
#     58    87 1290.05046   10  244 1289.00000 1290.05416  0.08%  62.6  171s
#     86   208 1290.04419   15  227 1289.00000 1290.05416  0.08%  48.8  176s
#    207   478 1290.03565   34  220 1289.00000 1290.05416  0.08%  31.3  187s
#    478   745 1290.03138   68  203 1289.00000 1290.05416  0.08%  19.0  199s
#    746  1131 1290.02908  104  207 1289.00000 1290.05416  0.08%  14.7  211s
#   1132  1489 1290.01683  183  199 1289.00000 1290.05416  0.08%  11.0  225s
#   1588  1879 1290.00242   54  211 1289.00000 1290.05416  0.08%  11.0  243s
#   2093  2495 1290.02979   44  285 1289.00000 1290.05413  0.08%  11.6  267s
#   2789  2496 1290.03327   23  251 1289.00000 1290.05413  0.08%  11.0  384s
#   2791  2497 1290.00209   25  330 1289.00000 1290.05413  0.08%  11.0  420s
#   2794  2499 1290.01531   95  249 1289.00000 1290.05413  0.08%  11.0  425s
#   2796  2501 1290.00679  180  251 1289.00000 1290.05413  0.08%  11.0  441s
#   2798  2502 1290.03327   19  229 1289.00000 1290.03473  0.08%  11.0  445s
#   2800  2503 1290.02470   92  217 1289.00000 1290.03384  0.08%  10.9  466s
#   2803  2505 1290.03206   18  209 1289.00000 1290.03206  0.08%  10.9  471s
#   2804  2506 1290.01256  143  202 1289.00000 1290.03206  0.08%  10.9  484s
#   2805  2507 1290.01515   83  221 1289.00000 1290.03201  0.08%  10.9  486s
#   2806  2507 1290.00289   41  212 1289.00000 1290.03201  0.08%  10.9  497s
#   2807  2508 1290.03191   21  231 1289.00000 1290.03191  0.08%  10.9  500s
#   2808  2509 1290.02860   52  206 1289.00000 1290.03191  0.08%  10.9  515s
#   2810  2510 1290.03191   73  184 1289.00000 1290.03191  0.08%  10.9  530s
#   2812  2511 1290.01531   93  202 1289.00000 1290.03191  0.08%  10.9  548s
#   2813  2512 1290.00134  171  186 1289.00000 1290.03191  0.08%  10.9  550s
#   2814  2513 1290.01132  107  184 1289.00000 1290.03191  0.08%  10.9  564s
#   2815  2513 1290.00596  129  180 1289.00000 1290.03191  0.08%  10.9  581s
#   2816  2514 1290.02179  158  197 1289.00000 1290.03191  0.08%  10.9  598s
#   2817  2515 1290.01279  106  184 1289.00000 1290.03191  0.08%  10.9  628s
#   2818  2515 1290.00283  138  184 1289.00000 1290.03191  0.08%  10.9  637s
#   2819  2516 1290.02092  178  184 1289.00000 1290.03191  0.08%  10.9  661s
#   2820  2520 1290.03191   15  179 1289.00000 1290.03191  0.08%  24.4  686s
#   2826  2526 1290.03123   17  164 1289.00000 1290.03123  0.08%  24.9  690s
#   2850  2538 infeasible   19      1289.00000 1290.02839  0.08%  25.5  696s
#   2868  2541 1290.02839   21  193 1289.00000 1290.02839  0.08%  25.5  700s
#   2907  2580 1290.02077   23  204 1289.00000 1290.02839  0.08%  25.5  707s
#   2938  2644 1290.02789   24  184 1289.00000 1290.02839  0.08%  25.4  716s
#   3044  2685 1290.02263   35  180 1289.00000 1290.02789  0.08%  25.3  733s
#   3148  2863 1290.02773   22  188 1289.00000 1290.02785  0.08%  27.7  757s
#   3453  3205 1290.02753   27  189 1289.00000 1290.02777  0.08%  29.4  791s
#   4023  3373     cutoff   58      1289.00000 1290.02773  0.08%  32.2  811s
#   4532  3432 1290.02767   31  168 1289.00000 1290.02773  0.08%  32.0  827s
#   4982  3432     cutoff   48      1289.00000 1290.02773  0.08%  36.3  841s
#   5206  3518 1290.02268   38  173 1289.00000 1290.02773  0.08%  37.5  854s
#   5419  3751 1290.00688   31  243 1289.00000 1290.02773  0.08%  37.7  872s
#   5884  3723 1290.01369   43  143 1289.00000 1290.02773  0.08%  43.2  890s
#   6106  3901 1290.00801   33  180 1289.00000 1290.02773  0.08%  51.2  916s
#   6517  4071 1290.02753   34  176 1289.00000 1290.02773  0.08%  55.5  949s
#   7015  4224 1290.02066   45  169 1289.00000 1290.02773  0.08%  59.7  994s
#   7586  4293 1290.02591   37  178 1289.00000 1290.02773  0.08%  62.8 1040s
#   8054  4339 1290.02746   32  184 1289.00000 1290.02773  0.08%  66.2 1072s
#   8392  4647 1290.02746   36  179 1289.00000 1290.02773  0.08%  67.2 1112s
#   9091  4845 1290.01606   46  159 1289.00000 1290.02771  0.08%  68.3 1154s
#   9784  4901 1290.01455   34  175 1289.00000 1290.02771  0.08%  68.2 1202s
#  10374  4845 1290.00345   40  191 1289.00000 1290.02767  0.08%  71.2 1244s
#  10731  5132 1290.01115   40  165 1289.00000 1290.02767  0.08%  74.2 1287s
#  11290  5524 1290.01881   31  183 1289.00000 1290.02753  0.08%  77.1 1330s
#  11961  5768 1290.01820   45  155 1289.00000 1290.02753  0.08%  78.5 1397s
#  12408  6170 1290.01842   45  167 1289.00000 1290.02753  0.08%  79.9 1464s
#  13181  6323 1290.00909   42  184 1289.00000 1290.02746  0.08%  81.8 1632s
#  13509  7108 1290.01820   38  153 1289.00000 1290.02746  0.08%  82.3 1775s
#  15271  7365     cutoff   39      1289.00000 1290.02746  0.08%  88.7 1848s
#  15837  7846     cutoff   47      1289.00000 1290.02746  0.08%  89.9 1933s
#  16930  7945 1290.02746   39  177 1289.00000 1290.02746  0.08%  92.0 1985s
#  17116  8521 1290.00925   41  176 1289.00000 1290.02746  0.08%  92.3 2035s
#  18323  8840     cutoff   47      1289.00000 1290.02745  0.08%  93.3 2084s
#  19237  9323 1290.00699   40  165 1289.00000 1290.02742  0.08%  96.4 2132s
#  20345  9792 1290.00699   47  157 1289.00000 1290.02734  0.08%  98.2 2180s
#  21433 10245 1290.00650   38  271 1289.00000 1290.02725  0.08%   100 2229s
#  22597 10601     cutoff   48      1289.00000 1290.02720  0.08%   101 2274s
#  23624 10872 1290.00415   37  212 1289.00000 1290.02698  0.08%   103 2317s
#  24351 11223     cutoff   46      1289.00000 1290.02698  0.08%   104 2366s
#  25351 11491     cutoff   46      1289.00000 1290.02690  0.08%   106 2411s
#  26345 11492 1290.02356   39  251 1289.00000 1290.02679  0.08%   107 2864s
#  26347 11493 1290.01379   38  362 1289.00000 1290.02679  0.08%   107 2889s
#  26348 11494 1290.00006   42  289 1289.00000 1290.02679  0.08%   107 2890s
#  26351 11496 1290.01483   34  206 1289.00000 1290.02679  0.08%   107 2900s
#  26353 11497 1290.01025   31  303 1289.00000 1290.02679  0.08%   107 2926s
#  26355 11499 1290.00699   41  233 1289.00000 1290.02679  0.08%   107 2955s
#  26357 11500 1290.01092   44  199 1289.00000 1290.02679  0.08%   107 2978s
#  26359 11501 1290.02267   40  236 1289.00000 1290.02679  0.08%   107 2982s
#  26360 11502 1290.01066   45  211 1289.00000 1290.02679  0.08%   107 3011s
#  26363 11504 1290.02120   28  209 1289.00000 1290.02679  0.08%   107 3045s
#  26365 11505 1290.00572   42  178 1289.00000 1290.02679  0.08%   107 3067s
#  26367 11507 1290.00699   47  168 1289.00000 1290.02679  0.08%   107 3098s
#  26369 11508 1290.02259   41  175 1289.00000 1290.02679  0.08%   107 3130s
#  26371 11509 1290.00327   38  161 1289.00000 1290.02679  0.08%   107 3147s
#  26373 11511 1290.00340   44  153 1289.00000 1290.02540  0.08%   107 3150s
#  26374 11511 1290.02259   40  157 1289.00000 1290.02540  0.08%   107 3175s
#  26375 11512 1290.00487   39  150 1289.00000 1290.02540  0.08%   107 3214s
#  26376 11513 1290.00628   47  147 1289.00000 1290.02540  0.08%   107 3233s
#  26377 11513 1290.02386   39  162 1289.00000 1290.02540  0.08%   107 3235s
#  26378 11514 1290.00591   38  139 1289.00000 1290.02540  0.08%   107 3253s
#  26379 11515 1290.01337   40  126 1289.00000 1290.02540  0.08%   107 3275s
#  26380 11515 1290.01695   46  133 1289.00000 1290.02540  0.08%   107 3293s
#  26381 11516 1290.02177   39  160 1289.00000 1290.02177  0.08%   107 3315s
#  26382 11517 1290.00622   42  138 1289.00000 1290.02176  0.08%   107 3328s
#  26384 11518 1290.01820   40  137 1289.00000 1290.02176  0.08%   107 3342s
#  26386 11519 1290.00900   41  134 1289.00000 1290.02176  0.08%   107 3357s
#  26387 11520 1290.00699   46  137 1289.00000 1290.02176  0.08%   107 3375s
#  26388 11521 1290.02176   37  144 1289.00000 1290.02176  0.08%   107 3390s
#  26389 11521 1290.02176   36  148 1289.00000 1290.02176  0.08%   107 3410s
#  26390 11522 1290.01567   42  134 1289.00000 1290.02176  0.08%   107 3425s
#  26391 11523 1290.02176   34  146 1289.00000 1290.02176  0.08%   107 3443s
#  26392 11523 1290.02171   40  179 1289.00000 1290.02171  0.08%   107 3457s
#  26393 11524 1290.00372   39  159 1289.00000 1290.02171  0.08%   107 3480s
#  26394 11525 1290.00900   42  158 1289.00000 1290.02171  0.08%   107 3495s
#  26396 11526 1290.00345   42  155 1289.00000 1290.02171  0.08%   107 3510s
#  26397 11527 1290.02171   31  148 1289.00000 1290.02171  0.08%   107 3529s
#  26398 11527 1290.02171   37  134 1289.00000 1290.02171  0.08%   107 3543s
#  26399 11528 1289.99923   46  134 1289.00000 1290.02171  0.08%   107 3560s
#  26401 11529 1290.01781   39  190 1289.00000 1290.02135  0.08%   107 3575s
#  26402 11530 1290.01781   40  161 1289.00000 1290.02135  0.08%   107 3594s
#
# Cutting planes:
#   Gomory: 21
#   Cover: 2
#   MIR: 185
#   StrongCG: 1
#   Flow cover: 176
#   GUB cover: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 26402 nodes (2883938 simplex iterations) in 3600.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1289 1288 1287 ... 1230
#
# Time limit reached
# Best objective 1.289000000000e+03, best bound 1.290000000000e+03, gap 0.0776%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x5x1

# %%
datafile="4x2000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x20110bfc
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1151.0000000
# Presolve removed 62 rows and 40 columns (presolve time = 5s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 14s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 20s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 25s) ...
# Sparsify removed 2606799 nonzeros (33%)
# Presolve added 0 rows and 99 columns
# Presolve removed 62 rows and 0 columns
# Presolve time: 26.13s
# Presolved: 9938 rows, 8099 columns, 5325313 nonzeros
# Variable types: 139 continuous, 7960 integer (7960 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9900000e+03   1.584617e+06   0.000000e+00     28s
#     1421    1.2191469e+03   2.459390e+04   0.000000e+00     30s
#     2562    1.2164785e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.216479e+03, 2562 iterations, 2.91 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1216.47853    0  144 1151.00000 1216.47853  5.69%     -   35s
# H    0     0                    1213.0000000 1216.47853  0.29%     -   35s
#      0     0 1216.47853    0  173 1213.00000 1216.47853  0.29%     -   39s
# H    0     0                    1215.0000000 1216.47853  0.12%     -   43s
#      0     0 1216.39050    0  140 1215.00000 1216.39050  0.11%     -   44s
#      0     0 1216.39050    0  142 1215.00000 1216.39050  0.11%     -   45s
#      0     0 1216.22965    0  133 1215.00000 1216.22965  0.10%     -   51s
#      0     0 1216.19406    0  118 1215.00000 1216.19406  0.10%     -   53s
#      0     0 1216.19406    0  126 1215.00000 1216.19406  0.10%     -   54s
#      0     0     cutoff    0      1215.00000 1215.00000  0.00%     -   57s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 23
#   Implied bound: 13
#   Clique: 1
#   MIR: 333
#   StrongCG: 11
#   Mod-K: 2
#   RLT: 12
#   Relax-and-lift: 2
#
# Explored 1 nodes (12815 simplex iterations) in 57.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1215 1213 1151
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.215000000000e+03, best bound 1.215000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x5x2

# %%
datafile="4x2000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xf7591aa9
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1176.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 25s) ...
# Sparsify removed 2555575 nonzeros (32%)
# Presolve added 0 rows and 125 columns
# Presolve removed 29 rows and 0 columns
# Presolve time: 26.19s
# Presolved: 9971 rows, 8125 columns, 5416429 nonzeros
# Variable types: 145 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.541234e+06   0.000000e+00     28s
#     1050    1.2763899e+03   5.752054e+04   0.000000e+00     31s
#     2636    1.2281437e+03   0.000000e+00   0.000000e+00     32s
#
# Root relaxation: objective 1.228144e+03, 2636 iterations, 3.60 seconds
# Total elapsed time = 35.64s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1228.14368    0  160 1176.00000 1228.14368  4.43%     -   39s
# H    0     0                    1225.0000000 1228.14368  0.26%     -   40s
# H    0     0                    1226.0000000 1228.14368  0.17%     -   40s
# H    0     0                    1227.0000000 1228.14368  0.09%     -   41s
#      0     0 1228.13024    0   85 1227.00000 1228.13024  0.09%     -   56s
#      0     0 1228.13024    0  148 1227.00000 1228.13024  0.09%     -   77s
#      0     0 1228.13024    0  149 1227.00000 1228.13024  0.09%     -   81s
#      0     0 1228.13024    0  134 1227.00000 1228.13024  0.09%     -   83s
#      0     0 1228.13024    0  134 1227.00000 1228.13024  0.09%     -   84s
#      0     0 1228.13024    0  119 1227.00000 1228.13024  0.09%     -   87s
#      0     0 1228.13024    0  116 1227.00000 1228.13024  0.09%     -   88s
#      0     0 1228.13024    0  113 1227.00000 1228.13024  0.09%     -   92s
#      0     0 1228.13024    0  112 1227.00000 1228.13024  0.09%     -   93s
#      0     0 1228.13024    0   92 1227.00000 1228.13024  0.09%     -   99s
#      0     0 1228.13024    0   95 1227.00000 1228.13024  0.09%     -  100s
#      0     0 1228.13024    0   97 1227.00000 1228.13024  0.09%     -  105s
#      0     0 1228.11537    0   95 1227.00000 1228.11537  0.09%     -  106s
#      0     0 1228.08342    0   90 1227.00000 1228.08342  0.09%     -  107s
#      0     0 1228.08342    0   94 1227.00000 1228.08342  0.09%     -  107s
#      0     0     cutoff    0      1227.00000 1227.00000  0.00%     -  109s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 230
#
# Explored 1 nodes (26016 simplex iterations) in 109.96 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1227 1226 1225 1176
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.227000000000e+03, best bound 1.227000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x5x3

# %%
datafile="4x2000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x54c28f09
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1171.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 5s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 10s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 15s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 20s) ...
# Sparsify removed 2653536 nonzeros (33%)
# Presolve added 0 rows and 120 columns
# Presolve removed 39 rows and 0 columns
# Presolve time: 22.10s
# Presolved: 9961 rows, 8120 columns, 5302544 nonzeros
# Variable types: 148 continuous, 7972 integer (7972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.549445e+06   0.000000e+00     24s
#      719    1.5223982e+03   3.671790e+05   0.000000e+00     25s
#     5494    1.2299261e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 1.229927e+03, 5494 iterations, 6.43 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1229.92706    0  243 1171.00000 1229.92706  5.03%     -   34s
# H    0     0                    1226.0000000 1229.92706  0.32%     -   34s
# H    0     0                    1227.0000000 1229.92706  0.24%     -   35s
#      0     0 1229.87170    0  211 1227.00000 1229.87170  0.23%     -   40s
# H    0     0                    1228.0000000 1229.87170  0.15%     -   43s
#      0     0 1229.37338    0  191 1228.00000 1229.37338  0.11%     -   44s
#      0     0 1229.37209    0  187 1228.00000 1229.37209  0.11%     -   45s
#      0     0 1229.37022    0  184 1228.00000 1229.37022  0.11%     -   46s
#      0     0 1229.37022    0  185 1228.00000 1229.37022  0.11%     -   47s
#      0     0 1229.35368    0  158 1228.00000 1229.35368  0.11%     -   52s
#      0     0 1229.35306    0  150 1228.00000 1229.35306  0.11%     -   54s
#      0     0 1229.35110    0  152 1228.00000 1229.35110  0.11%     -   56s
#      0     0 1229.35110    0  149 1228.00000 1229.35110  0.11%     -   57s
#      0     0 1229.34540    0  127 1228.00000 1229.34540  0.11%     -   61s
#      0     0 1229.34522    0  132 1228.00000 1229.34522  0.11%     -   63s
#      0     0 1229.34508    0  140 1228.00000 1229.34508  0.11%     -   64s
#      0     0 1229.33744    0  136 1228.00000 1229.33744  0.11%     -   68s
#      0     0 1229.33740    0  112 1228.00000 1229.33740  0.11%     -   70s
#      0     0 1229.33740    0  130 1228.00000 1229.33740  0.11%     -   74s
#      0     0 1229.33740    0  133 1228.00000 1229.33740  0.11%     -   75s
#      0     0 1229.33740    0  117 1228.00000 1229.33740  0.11%     -   79s
#      0     0 1229.33740    0  124 1228.00000 1229.33740  0.11%     -   80s
#      0     0 1229.33740    0  105 1228.00000 1229.33740  0.11%     -   86s
#      0     0 1229.33740    0  118 1228.00000 1229.33740  0.11%     -   88s
#      0     0 1229.33740    0  119 1228.00000 1229.33740  0.11%     -   93s
#      0     0 1229.33740    0  117 1228.00000 1229.33740  0.11%     -   95s
#      0     0 1229.33668    0  115 1228.00000 1229.33668  0.11%     -  101s
#      0     0 1229.33651    0  112 1228.00000 1229.33651  0.11%     -  102s
#      0     0 1229.33651    0  120 1228.00000 1229.33651  0.11%     -  103s
#      0     0 1229.33651    0  145 1228.00000 1229.33651  0.11%     -  107s
#      0     0 1229.33651    0  112 1228.00000 1229.33651  0.11%     -  110s
#      0     0 1229.33651    0  257 1228.00000 1229.33651  0.11%     -  133s
#      0     0 1229.33651    0  177 1228.00000 1229.33651  0.11%     -  137s
#      0     0 1229.33622    0  158 1228.00000 1229.33622  0.11%     -  140s
#      0     0 1229.33622    0  156 1228.00000 1229.33622  0.11%     -  140s
#      0     0 1229.33622    0  150 1228.00000 1229.33622  0.11%     -  143s
#      0     0 1229.33621    0  136 1228.00000 1229.33621  0.11%     -  144s
#      0     0 1229.33555    0  156 1228.00000 1229.33555  0.11%     -  147s
#      0     0 1229.33493    0  155 1228.00000 1229.33493  0.11%     -  148s
#      0     0 1229.33490    0  158 1228.00000 1229.33490  0.11%     -  149s
#      0     0 1229.33460    0  155 1228.00000 1229.33460  0.11%     -  151s
#      0     0 1229.33425    0  163 1228.00000 1229.33425  0.11%     -  152s
#      0     0 1229.33425    0  161 1228.00000 1229.33425  0.11%     -  153s
#      0     0 1229.33373    0  152 1228.00000 1229.33373  0.11%     -  155s
#      0     0 1229.33365    0  161 1228.00000 1229.33365  0.11%     -  157s
#      0     0 1229.33341    0  146 1228.00000 1229.33341  0.11%     -  159s
#      0     0 1229.33341    0  160 1228.00000 1229.33341  0.11%     -  160s
#      0     0 1229.33341    0  140 1228.00000 1229.33341  0.11%     -  162s
#      0     0 1229.33341    0  128 1228.00000 1229.33341  0.11%     -  166s
#      0     2 1229.33341    0  125 1228.00000 1229.33341  0.11%     -  171s
#     13    20 1229.33161    4  136 1228.00000 1229.33161  0.11%   122  175s
#     31    38 1229.33161    7  131 1228.00000 1229.33161  0.11%  57.6  180s
#     77   209 1229.32039   13  122 1228.00000 1229.33161  0.11%  29.9  190s
#    208   561 1229.31096   32  116 1228.00000 1229.33161  0.11%  16.9  202s
#    560   715 1229.15682   73  119 1228.00000 1229.33161  0.11%  12.8  213s
#    714  1065 1229.18245   96  102 1228.00000 1229.33161  0.11%  11.6  228s
#   1064  1460 1229.11471  138   83 1228.00000 1229.33161  0.11%  10.0  243s
#   1493  1809 1229.11351  199   93 1228.00000 1229.33161  0.11%   9.2  257s
# H 1886   524                    1229.0000000 1229.33161  0.03%   8.6  270s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 29
#   Implied bound: 7
#   MIR: 105
#   StrongCG: 5
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 2082 nodes (56291 simplex iterations) in 270.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1229 1228 1227 ... 1171
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.229000000000e+03, best bound 1.229000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x5x4

# %%
datafile="4x2000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0x98f26ab3
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1185.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 5s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 10s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 20s) ...
# Sparsify removed 2473704 nonzeros (31%)
# Presolve added 0 rows and 116 columns
# Presolve removed 33 rows and 0 columns
# Presolve time: 21.19s
# Presolved: 9967 rows, 8116 columns, 5498316 nonzeros
# Variable types: 136 continuous, 7980 integer (7980 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9950000e+03   1.612609e+06   0.000000e+00     23s
#     1378    1.4963161e+03   3.922436e+05   0.000000e+00     26s
#     5043    1.2418659e+03   0.000000e+00   0.000000e+00     29s
#
# Root relaxation: objective 1.241866e+03, 5043 iterations, 5.98 seconds
# Total elapsed time = 30.44s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1241.86592    0  246 1185.00000 1241.86592  4.80%     -   35s
# H    0     0                    1238.0000000 1241.86592  0.31%     -   36s
# H    0     0                    1239.0000000 1241.86592  0.23%     -   36s
#      0     0 1241.86026    0  267 1239.00000 1241.86026  0.23%     -   41s
# H    0     0                    1240.0000000 1241.86026  0.15%     -   46s
#      0     0 1241.84594    0  262 1240.00000 1241.84594  0.15%     -   47s
#      0     0 1241.73828    0  249 1240.00000 1241.73828  0.14%     -   48s
#      0     0 1241.73828    0  247 1240.00000 1241.73828  0.14%     -   49s
#      0     0 1241.72565    0  239 1240.00000 1241.72565  0.14%     -   54s
#      0     0 1241.72232    0  199 1240.00000 1241.72232  0.14%     -   57s
#      0     0 1241.67476    0  198 1240.00000 1241.67476  0.14%     -   58s
#      0     0 1241.67476    0  204 1240.00000 1241.67476  0.14%     -   59s
#      0     0 1241.67024    0  188 1240.00000 1241.67024  0.13%     -   65s
#      0     0 1241.49092    0  166 1240.00000 1241.49092  0.12%     -   67s
#      0     0 1241.49092    0  169 1240.00000 1241.49092  0.12%     -   68s
#      0     0 1241.49092    0  180 1240.00000 1241.49092  0.12%     -   72s
#      0     0 1241.44721    0  190 1240.00000 1241.44721  0.12%     -   74s
#      0     0 1241.44721    0  186 1240.00000 1241.44721  0.12%     -   75s
#      0     0 1241.44632    0  169 1240.00000 1241.44632  0.12%     -   80s
#      0     0 1241.44350    0  173 1240.00000 1241.44350  0.12%     -   82s
#      0     0 1241.44350    0  164 1240.00000 1241.44350  0.12%     -   83s
#      0     0 1241.43717    0  142 1240.00000 1241.43717  0.12%     -   87s
#      0     0 1241.43717    0  151 1240.00000 1241.43717  0.12%     -   89s
#      0     0 1241.43717    0  136 1240.00000 1241.43717  0.12%     -   93s
#      0     0 1241.43140    0  130 1240.00000 1241.43140  0.12%     -   95s
#      0     0 1241.43140    0  141 1240.00000 1241.43140  0.12%     -   96s
#      0     0 1241.42915    0  119 1240.00000 1241.42915  0.12%     -  101s
#      0     0 1241.42309    0  128 1240.00000 1241.42309  0.11%     -  103s
#      0     0 1241.42309    0  131 1240.00000 1241.42309  0.11%     -  104s
#      0     0 1241.42275    0  149 1240.00000 1241.42275  0.11%     -  109s
# H    0     0                    1241.0000000 1241.42275  0.03%     -  111s
#      0     0 1241.42275    0  149 1241.00000 1241.42275  0.03%     -  111s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 68
#
# Explored 1 nodes (16304 simplex iterations) in 111.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1241 1240 1239 ... 1185
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.241000000000e+03, best bound 1.241000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x2000x5x5

# %%
datafile="4x2000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 2000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 10000 rows, 8000 columns and 8012000 nonzeros
# Model fingerprint: 0xae50d490
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1163.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 5s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 10s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 15s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 20s) ...
# Sparsify removed 2575426 nonzeros (32%)
# Presolve added 0 rows and 110 columns
# Presolve removed 47 rows and 0 columns
# Presolve time: 21.41s
# Presolved: 9953 rows, 8110 columns, 5380618 nonzeros
# Variable types: 138 continuous, 7972 integer (7972 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9930000e+03   1.576907e+06   0.000000e+00     23s
#     1108    1.5232052e+03   4.894787e+05   0.000000e+00     25s
#     4587    1.2240942e+03   0.000000e+00   0.000000e+00     28s
#
# Root relaxation: objective 1.224094e+03, 4587 iterations, 5.28 seconds
# Total elapsed time = 30.86s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1224.09419    0  185 1163.00000 1224.09419  5.25%     -   32s
# H    0     0                    1221.0000007 1224.09419  0.25%     -   32s
#      0     0 1224.09296    0  172 1221.00000 1224.09296  0.25%     -   38s
# H    0     0                    1223.0000000 1224.09296  0.09%     -   40s
#      0     0 1224.06539    0  167 1223.00000 1224.06539  0.09%     -   41s
#      0     0 1224.06438    0  158 1223.00000 1224.06438  0.09%     -   42s
#      0     0 1224.06438    0  160 1223.00000 1224.06438  0.09%     -   43s
#      0     0 1224.02629    0   90 1223.00000 1224.02629  0.08%     -   51s
#      0     0 1224.02629    0  167 1223.00000 1224.02629  0.08%     -   63s
#      0     0 1224.02629    0  123 1223.00000 1224.02629  0.08%     -   65s
#      0     0 1224.02629    0  123 1223.00000 1224.02629  0.08%     -   66s
#      0     0 1224.02629    0  117 1223.00000 1224.02629  0.08%     -   67s
#      0     0 1224.02576    0  120 1223.00000 1224.02576  0.08%     -   68s
#      0     0 1224.00277    0  111 1223.00000 1224.00277  0.08%     -   69s
#      0     0 1224.00277    0  110 1223.00000 1224.00277  0.08%     -   70s
#      0     0     cutoff    0      1223.00000 1223.00000  0.00%     -   71s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 1
#   MIR: 164
#   RLT: 6
#
# Explored 1 nodes (20221 simplex iterations) in 71.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 1223 1221 1163
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.223000000000e+03, best bound 1.223000000000e+03, gap 0.0000%

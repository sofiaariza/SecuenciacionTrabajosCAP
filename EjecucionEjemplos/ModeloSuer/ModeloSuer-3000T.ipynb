# %% [markdown]
# # Modelo de programación lineal Süer et. al.

# %%
import pandas as pd

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x1.5x1

# %%
datafile="2x3000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-06-11
# Using license file C:\Users\elPatan03\gurobi.lic
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xdd7358c9
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3000.0000000
# Presolve removed 6 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1129451 nonzeros (13%)
# Presolve removed 46 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 46 rows and 0 columns
# Presolve time: 25.39s
# Presolved: 8954 rows, 6039 columns, 7879331 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   1.803001e+06   0.000000e+00     28s
#
# Root relaxation: cutoff, 0 iterations, 0.50 seconds
#
# Explored 0 nodes (0 simplex iterations) in 28.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+03, best bound 3.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x1.5x2

# %%
datafile="2x3000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xcf368753
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3000.0000000
# Presolve removed 104 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 104 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 104 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 104 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1486737 nonzeros (17%)
# Presolve removed 167 rows and 5853 columns (presolve time = 25s) ...
# Presolve added 0 rows and 43 columns
# Presolve removed 167 rows and 0 columns
# Presolve time: 25.45s
# Presolved: 8833 rows, 6043 columns, 7519222 nonzeros
# Variable types: 43 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   1.653180e+06   0.000000e+00     28s
#
# Root relaxation: cutoff, 0 iterations, 0.48 seconds
#
# Explored 0 nodes (0 simplex iterations) in 28.14 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+03, best bound 3.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x1.5x3

# %%
datafile="2x3000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xd5ac6054
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3000.0000000
# Presolve removed 18 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1151891 nonzeros (13%)
# Presolve removed 101 rows and 5939 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 101 rows and 0 columns
# Presolve time: 25.26s
# Presolved: 8899 rows, 6039 columns, 7856313 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   1.686248e+06   0.000000e+00     28s
#
# Root relaxation: cutoff, 0 iterations, 0.50 seconds
#
# Explored 0 nodes (0 simplex iterations) in 28.04 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+03, best bound 3.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x1.5x4

# %%
datafile="2x3000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x4785ee8c
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3000.0000000
# Presolve removed 30 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 30 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 30 rows and 0 columns (presolve time = 25s) ...
# Sparsify removed 1212848 nonzeros (13%)
# Presolve added 0 rows and 42 columns
# Presolve removed 94 rows and 0 columns
# Presolve time: 29.73s
# Presolved: 8906 rows, 6042 columns, 7795546 nonzeros
# Variable types: 40 continuous, 6002 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   1.688050e+06   0.000000e+00     32s
#
# Root relaxation: cutoff, 0 iterations, 0.50 seconds
#
# Explored 0 nodes (0 simplex iterations) in 32.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+03, best bound 3.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x1.5x5

# %%
datafile="2x3000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xc92e99dd
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2997.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1129571 nonzeros (13%)
# Presolve removed 40 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 40 rows and 0 columns
# Presolve time: 25.33s
# Presolved: 8960 rows, 6039 columns, 7879265 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   1.640999e+06   0.000000e+00     28s
#      643    2.9981144e+03   0.000000e+00   0.000000e+00     29s
#
# Root relaxation: objective 2.998114e+03, 643 iterations, 1.94 seconds
# Total elapsed time = 30.24s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2998.11444    0    6 2997.00000 2998.11444  0.04%     -   31s
#      0     0 2998.09542    0   13 2997.00000 2998.09542  0.04%     -   37s
#      0     0 2998.09542    0   15 2997.00000 2998.09542  0.04%     -   39s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 4
#   MIR: 12
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (741 simplex iterations) in 43.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.997000000000e+03, best bound 2.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2x1

# %%
datafile="2x3000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x05ad9259
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2955.0000000
# Presolve removed 12 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 14 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 14 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 14 rows and 4 columns (presolve time = 25s) ...
# Sparsify removed 1139951 nonzeros (13%)
# Presolve removed 49 rows and 5943 columns (presolve time = 30s) ...
# Presolve added 0 rows and 35 columns
# Presolve removed 49 rows and 0 columns
# Presolve time: 30.10s
# Presolved: 8951 rows, 6035 columns, 7856845 nonzeros
# Variable types: 39 continuous, 5996 integer (5996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   2.552719e+06   0.000000e+00     33s
#      899    2.9641742e+03   0.000000e+00   0.000000e+00     35s
#
# Root relaxation: objective 2.964174e+03, 899 iterations, 2.16 seconds
# Total elapsed time = 36.16s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2964.17418    0   50 2955.00000 2964.17418  0.31%     -   38s
# H    0     0                    2962.0000000 2964.17418  0.07%     -   38s
#      0     0 2964.15356    0   42 2962.00000 2964.15356  0.07%     -   44s
# H    0     0                    2963.0000000 2964.15356  0.04%     -   46s
#      0     0 2964.13082    0   46 2963.00000 2964.13082  0.04%     -   47s
#      0     0 2964.12840    0   40 2963.00000 2964.12840  0.04%     -   48s
#      0     0 2964.12808    0   41 2963.00000 2964.12808  0.04%     -   49s
#      0     0 2964.12808    0   43 2963.00000 2964.12808  0.04%     -   51s
#      0     0 2964.00962    0   32 2963.00000 2964.00962  0.03%     -   56s
#      0     0 2964.00906    0   33 2963.00000 2964.00906  0.03%     -   59s
#      0     0 2964.00856    0   34 2963.00000 2964.00856  0.03%     -   61s
#      0     0 2964.00846    0   33 2963.00000 2964.00846  0.03%     -   62s
#      0     0 2964.00673    0   32 2963.00000 2964.00673  0.03%     -   68s
#      0     0 2964.00673    0   34 2963.00000 2964.00673  0.03%     -   71s
#      0     0 2964.00606    0   38 2963.00000 2964.00606  0.03%     -   77s
#      0     0 2964.00559    0   41 2963.00000 2964.00559  0.03%     -   79s
#      0     0 2964.00559    0   41 2963.00000 2964.00559  0.03%     -   80s
#      0     0 2964.00559    0   40 2963.00000 2964.00559  0.03%     -   86s
#      0     0 2964.00483    0   40 2963.00000 2964.00483  0.03%     -   88s
#      0     0 2964.00483    0   42 2963.00000 2964.00483  0.03%     -   90s
#      0     0 2964.00440    0   47 2963.00000 2964.00440  0.03%     -   94s
#      0     0 2964.00440    0   47 2963.00000 2964.00440  0.03%     -   97s
#      0     0 2963.99882    0   39 2963.00000 2963.99882  0.03%     -  102s
#      0     0 2963.99882    0   24 2963.00000 2963.99882  0.03%     -  108s
#      0     2 2963.99882    0   23 2963.00000 2963.99882  0.03%     -  120s
#      2     3 2963.99882    1   24 2963.00000 2963.99882  0.03%  19.5  261s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 4
#   MIR: 5
#   Flow cover: 22
#   RLT: 1
#
# Explored 4 nodes (4406 simplex iterations) in 262.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2963 2962 2955
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.963000000000e+03, best bound 2.963000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2x2

# %%
datafile="2x3000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x8668de6c
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2962.0000000
# Presolve removed 13 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 13 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1145869 nonzeros (13%)
# Presolve removed 33 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 33 rows and 0 columns
# Presolve time: 25.66s
# Presolved: 8967 rows, 6037 columns, 7857052 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   2.569750e+06   0.000000e+00     28s
#      888    2.9703264e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 2.970326e+03, 888 iterations, 2.07 seconds
# Total elapsed time = 31.79s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2970.32636    0   33 2962.00000 2970.32636  0.28%     -   34s
# H    0     0                    2967.0000000 2970.32636  0.11%     -   35s
# H    0     0                    2969.0000000 2970.32636  0.04%     -   35s
#      0     0 2970.32358    0   31 2969.00000 2970.32358  0.04%     -   40s
# H    0     0                    2970.0000000 2970.32358  0.01%     -   42s
#      0     0 2970.32358    0   31 2970.00000 2970.32358  0.01%     -   42s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 8
#
# Explored 1 nodes (1171 simplex iterations) in 42.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2970 2969 2967 2962
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.970000000000e+03, best bound 2.970000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2x3

# %%
datafile="2x3000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x89e01b7f
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2986.0000000
# Presolve removed 10 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1146317 nonzeros (13%)
# Presolve removed 93 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 93 rows and 0 columns
# Presolve time: 25.17s
# Presolved: 8907 rows, 6039 columns, 7861926 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   2.500087e+06   0.000000e+00     28s
#      739    2.9899954e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 2.989995e+03, 739 iterations, 2.08 seconds
# Total elapsed time = 31.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2989.99544    0   15 2986.00000 2989.99544  0.13%     -   33s
# H    0     0                    2989.0000000 2989.99544  0.03%     -   33s
#      0     0 2989.99544    0   15 2989.00000 2989.99544  0.03%     -   33s
#
# Explored 1 nodes (814 simplex iterations) in 33.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2989 2986
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.989000000000e+03, best bound 2.989000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2x4

# %%
datafile="2x3000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x8bd0293e
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2976.0000000
# Presolve removed 9 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1140321 nonzeros (13%)
# Presolve removed 32 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 32 rows and 0 columns
# Presolve time: 25.68s
# Presolved: 8968 rows, 6037 columns, 7862601 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   2.586636e+06   0.000000e+00     28s
#      850    2.9818864e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 2.981886e+03, 850 iterations, 2.01 seconds
# Total elapsed time = 31.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2981.88639    0   25 2976.00000 2981.88639  0.20%     -   33s
# H    0     0                    2979.0000000 2981.88639  0.10%     -   33s
# H    0     0                    2980.0000000 2981.88639  0.06%     -   33s
#      0     0 2981.00000    0   20 2980.00000 2981.00000  0.03%     -   39s
# H    0     0                    2981.0000000 2981.00000  0.00%     -   41s
#      0     0 2981.00000    0   20 2981.00000 2981.00000  0.00%     -   41s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 4
#   StrongCG: 1
#
# Explored 1 nodes (1082 simplex iterations) in 41.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2981 2980 2979 2976
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.981000000000e+03, best bound 2.981000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2x5

# %%
datafile="2x3000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x39ef8a6c
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2987.0000000
# Presolve removed 20 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 20 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 20 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 20 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1146291 nonzeros (13%)
# Presolve removed 38 rows and 5941 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 38 rows and 0 columns
# Presolve time: 25.23s
# Presolved: 8962 rows, 6039 columns, 7862555 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   2.611684e+06   0.000000e+00     28s
#      890    2.9898509e+03   0.000000e+00   0.000000e+00     30s
#
# Root relaxation: objective 2.989851e+03, 890 iterations, 2.09 seconds
# Total elapsed time = 31.45s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2989.85093    0   66 2987.00000 2989.85093  0.10%     -   33s
# H    0     0                    2988.0000000 2989.85093  0.06%     -   34s
#      0     0 2989.84772    0   57 2988.00000 2989.84772  0.06%     -   40s
# H    0     0                    2989.0000000 2989.84772  0.03%     -   43s
#      0     0 2989.84772    0   57 2989.00000 2989.84772  0.03%     -   43s
#
# Cutting planes:
#   Gomory: 8
#   MIR: 4
#
# Explored 1 nodes (1515 simplex iterations) in 43.17 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2989 2988 2987
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.989000000000e+03, best bound 2.989000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2.5x1

# %%
datafile="2x3000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x3547c3ba
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2586.0000000
# Presolve removed 16 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 1155960 nonzeros (13%)
# Presolve removed 32 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 32 columns
# Presolve removed 32 rows and 0 columns
# Presolve time: 25.71s
# Presolved: 8968 rows, 6032 columns, 7828964 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.060429e+06   0.000000e+00     28s
#      535    2.6963090e+03   3.037141e+05   0.000000e+00     31s
#     2347    2.6665258e+03   0.000000e+00   0.000000e+00     35s
#
# Root relaxation: objective 2.666526e+03, 2347 iterations, 7.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2666.52581    0   91 2586.00000 2666.52581  3.11%     -   39s
# H    0     0                    2660.0000000 2666.52581  0.25%     -   39s
# H    0     0                    2665.0000000 2666.52581  0.06%     -   40s
# H    0     0                    2666.0000000 2666.52581  0.02%     -   41s
#      0     0 2666.52581    0   91 2666.00000 2666.52581  0.02%     -   41s
#
# Explored 1 nodes (2463 simplex iterations) in 41.32 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2666 2665 2660 2586
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.666000000000e+03, best bound 2.666000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2.5x2

# %%
datafile="2x3000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x4fd17b6e
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2590.0000000
# Presolve removed 12 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 11s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 20s) ...
# Sparsify removed 1128791 nonzeros (13%)
# Presolve removed 27 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 35 columns
# Presolve removed 27 rows and 0 columns
# Presolve time: 25.71s
# Presolved: 8973 rows, 6035 columns, 7868149 nonzeros
# Variable types: 39 continuous, 5996 integer (5996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   3.072655e+06   0.000000e+00     28s
#     1275    2.6634908e+03   9.365274e+03   0.000000e+00     30s
#     1764    2.6628228e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 2.662823e+03, 1764 iterations, 2.54 seconds
# Total elapsed time = 35.72s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2662.82282    0   28 2590.00000 2662.82282  2.81%     -   36s
# H    0     0                    2660.0000000 2662.82282  0.11%     -   36s
# H    0     0                    2661.0000000 2662.82282  0.07%     -   37s
#      0     0 2662.66632    0   30 2661.00000 2662.66632  0.06%     -   43s
# H    0     0                    2662.0000000 2662.66632  0.03%     -   45s
#      0     0 2662.66632    0   30 2662.00000 2662.66632  0.03%     -   45s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 8
#
# Explored 1 nodes (2614 simplex iterations) in 45.66 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2662 2661 2660 2590
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.662000000000e+03, best bound 2.662000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2.5x3

# %%
datafile="2x3000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x295617fd
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2604.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 11s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 20s) ...
# Sparsify removed 1134373 nonzeros (13%)
# Presolve removed 14 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 35 columns
# Presolve removed 14 rows and 0 columns
# Presolve time: 25.79s
# Presolved: 8986 rows, 6035 columns, 7862611 nonzeros
# Variable types: 39 continuous, 5996 integer (5996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   3.036807e+06   0.000000e+00     29s
#      557    2.7052845e+03   1.452755e+05   0.000000e+00     31s
#     2201    2.6624832e+03   0.000000e+00   0.000000e+00     34s
#
# Root relaxation: objective 2.662483e+03, 2201 iterations, 5.96 seconds
# Total elapsed time = 35.79s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2662.48324    0   74 2604.00000 2662.48324  2.25%     -   39s
# H    0     0                    2659.0000000 2662.48324  0.13%     -   39s
# H    0     0                    2661.0000000 2662.48324  0.06%     -   40s
# H    0     0                    2662.0000000 2662.48324  0.02%     -   41s
#      0     0 2662.48324    0   74 2662.00000 2662.48324  0.02%     -   41s
#
# Explored 1 nodes (2303 simplex iterations) in 41.79 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2662 2661 2659 2604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.662000000000e+03, best bound 2.662000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2.5x4

# %%
datafile="2x3000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x5f0eae4d
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2592.0000000
# Presolve removed 6 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1129571 nonzeros (13%)
# Presolve removed 24 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 24 rows and 0 columns
# Presolve time: 25.27s
# Presolved: 8976 rows, 6039 columns, 7879357 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   3.021390e+06   0.000000e+00     28s
#      963    2.6725764e+03   1.361045e+04   0.000000e+00     30s
#     1737    2.6676705e+03   0.000000e+00   0.000000e+00     32s
#
# Root relaxation: objective 2.667670e+03, 1737 iterations, 4.46 seconds
# Total elapsed time = 35.91s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2667.67046    0   35 2592.00000 2667.67046  2.92%     -   37s
# H    0     0                    2665.0000000 2667.67046  0.10%     -   38s
# H    0     0                    2666.0000000 2667.67046  0.06%     -   38s
#      0     0 2667.66770    0   38 2666.00000 2667.66770  0.06%     -   45s
# H    0     0                    2667.0000000 2667.66770  0.03%     -   47s
#      0     0 2667.66770    0   38 2667.00000 2667.66770  0.03%     -   47s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 1
#   MIR: 8
#   RLT: 1
#
# Explored 1 nodes (2019 simplex iterations) in 47.88 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2667 2666 2665 2592
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.667000000000e+03, best bound 2.667000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x2.5x5

# %%
datafile="2x3000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x36b2a305
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2583.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1129181 nonzeros (13%)
# Presolve removed 39 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 39 rows and 0 columns
# Presolve time: 25.80s
# Presolved: 8961 rows, 6037 columns, 7873699 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.178717e+06   0.000000e+00     29s
#      727    2.6705776e+03   3.251107e+04   0.000000e+00     30s
#     1935    2.6601968e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 2.660197e+03, 1935 iterations, 4.64 seconds
# Total elapsed time = 35.99s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2660.19685    0   87 2583.00000 2660.19685  2.99%     -   37s
# H    0     0                    2657.0000000 2660.19685  0.12%     -   37s
#      0     0 2660.02141    0   92 2657.00000 2660.02141  0.11%     -   44s
# H    0     0                    2658.0000000 2660.02141  0.08%     -   45s
# H    0     0                    2659.0000000 2660.02141  0.04%     -   46s
#      0     0     cutoff    0      2659.00000 2659.00000  0.00%     -   47s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 3
#   MIR: 27
#
# Explored 1 nodes (2100 simplex iterations) in 47.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2659 2658 2657 2583
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.659000000000e+03, best bound 2.659000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3x1

# %%
datafile="2x3000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x26ebf1cd
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2311.0000000
# Presolve removed 5 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1134765 nonzeros (13%)
# Presolve removed 7 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 7 rows and 0 columns
# Presolve time: 25.65s
# Presolved: 8993 rows, 6037 columns, 7868219 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.416991e+06   0.000000e+00     28s
#     1713    2.4236494e+03   2.374866e+04   0.000000e+00     30s
#     2098    2.4215975e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 2.421598e+03, 2098 iterations, 2.58 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2421.59752    0   59 2311.00000 2421.59752  4.79%     -   34s
# H    0     0                    2415.0000000 2421.59752  0.27%     -   35s
# H    0     0                    2418.0000000 2421.59752  0.15%     -   35s
# H    0     0                    2420.0000000 2421.59752  0.07%     -   36s
#      0     0 2421.30503    0   58 2420.00000 2421.30503  0.05%     -   42s
# H    0     0                    2421.0000000 2421.30503  0.01%     -   44s
#      0     0 2421.30503    0   58 2421.00000 2421.30503  0.01%     -   44s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 26
#   StrongCG: 2
#
# Explored 1 nodes (3343 simplex iterations) in 44.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2421 2420 2418 ... 2311
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.421000000000e+03, best bound 2.421000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3x2

# %%
datafile="2x3000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xe689186f
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2301.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 25s) ...
# Sparsify removed 1167496 nonzeros (13%)
# Presolve added 0 rows and 34 columns
# Presolve removed 41 rows and 0 columns
# Presolve time: 29.97s
# Presolved: 8959 rows, 6034 columns, 7823406 nonzeros
# Variable types: 40 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.450602e+06   0.000000e+00     33s
#     2193    2.4177097e+03   0.000000e+00   0.000000e+00     35s
#
# Root relaxation: objective 2.417710e+03, 2193 iterations, 2.50 seconds
# Total elapsed time = 35.87s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2417.70968    0   52 2301.00000 2417.70968  5.07%     -   37s
# H    0     0                    2416.0000000 2417.70968  0.07%     -   38s
#      0     0 2417.49907    0   53 2416.00000 2417.49907  0.06%     -   43s
# H    0     0                    2417.0000000 2417.49907  0.02%     -   46s
#      0     0 2417.49907    0   53 2417.00000 2417.49907  0.02%     -   46s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 2
#   MIR: 10
#
# Explored 1 nodes (2420 simplex iterations) in 46.19 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2417 2416 2301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.417000000000e+03, best bound 2.417000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3x3

# %%
datafile="2x3000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x89961fbf
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2322.0000000
# Presolve removed 11 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 11s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 20s) ...
# Sparsify removed 1128401 nonzeros (13%)
# Presolve removed 19 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 33 columns
# Presolve removed 19 rows and 0 columns
# Presolve time: 25.67s
# Presolved: 8981 rows, 6033 columns, 7862579 nonzeros
# Variable types: 39 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.410059e+06   0.000000e+00     28s
#      516    2.4870327e+03   9.467067e+04   0.000000e+00     30s
#     2131    2.4298316e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 2.429832e+03, 2131 iterations, 5.19 seconds
# Total elapsed time = 36.03s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2429.83156    0   69 2322.00000 2429.83156  4.64%     -   38s
# H    0     0                    2428.0000000 2429.83156  0.08%     -   39s
# H    0     0                    2429.0000000 2429.83156  0.03%     -   40s
#      0     0 2429.83156    0   69 2429.00000 2429.83156  0.03%     -   40s
#
# Explored 1 nodes (2246 simplex iterations) in 40.30 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2429 2428 2322
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.429000000000e+03, best bound 2.429000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3x4

# %%
datafile="2x3000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xfc2edc59
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2316.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 25s) ...
# Sparsify removed 1155960 nonzeros (13%)
# Presolve added 0 rows and 32 columns
# Presolve removed 28 rows and 0 columns
# Presolve time: 29.98s
# Presolved: 8972 rows, 6032 columns, 7829008 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.345772e+06   0.000000e+00     33s
#     2069    2.4218844e+03   0.000000e+00   0.000000e+00     35s
#
# Root relaxation: objective 2.421884e+03, 2069 iterations, 2.67 seconds
# Total elapsed time = 36.40s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2421.88437    0   65 2316.00000 2421.88437  4.57%     -   40s
# H    0     0                    2417.0000000 2421.88437  0.20%     -   40s
# H    0     0                    2420.0000000 2421.88437  0.08%     -   41s
#      0     0 2421.40651    0   65 2420.00000 2421.40651  0.06%     -   47s
# H    0     0                    2421.0000000 2421.40651  0.02%     -   50s
#      0     0 2421.40651    0   65 2421.00000 2421.40651  0.02%     -   50s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 3
#   MIR: 21
#   GUB cover: 1
#
# Explored 1 nodes (2836 simplex iterations) in 50.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2421 2420 2417 2316
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.421000000000e+03, best bound 2.421000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3x5

# %%
datafile="2x3000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xe6cebd76
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2322.0000000
# Presolve removed 11 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 11 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 11 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 11 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1129181 nonzeros (13%)
# Presolve removed 23 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 23 rows and 0 columns
# Presolve time: 25.58s
# Presolved: 8977 rows, 6037 columns, 7873763 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.410811e+06   0.000000e+00     28s
#      569    2.4726573e+03   2.142331e+05   0.000000e+00     30s
#     2251    2.4263218e+03   0.000000e+00   0.000000e+00     33s
#
# Root relaxation: objective 2.426322e+03, 2251 iterations, 4.79 seconds
# Total elapsed time = 35.44s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2426.32177    0   85 2322.00000 2426.32177  4.49%     -   36s
# H    0     0                    2425.0000000 2426.32177  0.05%     -   37s
#      0     0 2426.08068    0   74 2425.00000 2426.08068  0.04%     -   44s
#      0     0 2426.08017    0   70 2425.00000 2426.08017  0.04%     -   47s
#      0     0 2426.00501    0   63 2425.00000 2426.00501  0.04%     -   53s
#      0     0 2426.00501    0   61 2425.00000 2426.00501  0.04%     -   55s
#      0     0     cutoff    0      2425.00000 2425.00000  0.00%     -   60s
#
# Cutting planes:
#   Gomory: 12
#   MIR: 47
#   StrongCG: 2
#
# Explored 1 nodes (2470 simplex iterations) in 60.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2425 2322
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.425000000000e+03, best bound 2.425000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3.5x1

# %%
datafile="2x3000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x42844e23
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2108.0000000
# Presolve removed 6 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1135157 nonzeros (13%)
# Presolve removed 15 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 15 rows and 0 columns
# Presolve time: 25.22s
# Presolved: 8985 rows, 6039 columns, 7873799 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   3.636469e+06   0.000000e+00     28s
#      904    2.3032546e+03   1.462843e+05   0.000000e+00     30s
#     2129    2.2406283e+03   4.903795e+04   0.000000e+00     35s
#     2790    2.2347795e+03   0.000000e+00   0.000000e+00     36s
#
# Root relaxation: objective 2.234779e+03, 2790 iterations, 8.99 seconds
# Total elapsed time = 40.25s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2234.77950    0   54 2108.00000 2234.77950  6.01%     -   40s
# H    0     0                    2229.0000000 2234.77950  0.26%     -   41s
# H    0     0                    2232.0000000 2234.77950  0.12%     -   41s
# H    0     0                    2233.0000000 2234.77950  0.08%     -   42s
#      0     0 2234.74859    0   60 2233.00000 2234.74859  0.08%     -   47s
# H    0     0                    2234.0000000 2234.74859  0.03%     -   50s
#      0     0 2234.74859    0   60 2234.00000 2234.74859  0.03%     -   50s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 3
#   MIR: 14
#   RLT: 1
#
# Explored 1 nodes (2923 simplex iterations) in 50.25 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2234 2233 2232 ... 2108
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.234000000000e+03, best bound 2.234000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3.5x2

# %%
datafile="2x3000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x469ab77d
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2100.0000000
# Presolve removed 20 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 25s) ...
# Sparsify removed 1188508 nonzeros (13%)
# Presolve added 0 rows and 28 columns
# Presolve removed 20 rows and 0 columns
# Presolve time: 29.80s
# Presolved: 8980 rows, 6028 columns, 7784496 nonzeros
# Variable types: 40 continuous, 5988 integer (5988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   3.601332e+06   0.000000e+00     33s
#     2897    2.2277814e+03   0.000000e+00   0.000000e+00     35s
#
# Root relaxation: objective 2.227781e+03, 2897 iterations, 2.69 seconds
# Total elapsed time = 35.84s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2227.78141    0   94 2100.00000 2227.78141  6.08%     -   36s
# H    0     0                    2223.0000000 2227.78141  0.22%     -   36s
# H    0     0                    2226.0000000 2227.78141  0.08%     -   37s
#      0     0 2227.70358    0   98 2226.00000 2227.70358  0.08%     -   43s
# H    0     0                    2227.0000000 2227.70358  0.03%     -   46s
#      0     0 2227.70358    0   98 2227.00000 2227.70358  0.03%     -   46s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 2
#   Implied bound: 1
#   MIR: 26
#   GUB cover: 2
#   RLT: 3
#
# Explored 1 nodes (3269 simplex iterations) in 46.33 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2227 2226 2223 2100
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.227000000000e+03, best bound 2.227000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3.5x3

# %%
datafile="2x3000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x963134a2
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2114.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 25s) ...
# Sparsify removed 1134373 nonzeros (13%)
# Presolve added 0 rows and 35 columns
# Presolve removed 18 rows and 0 columns
# Presolve time: 29.91s
# Presolved: 8982 rows, 6035 columns, 7862593 nonzeros
# Variable types: 39 continuous, 5996 integer (5996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   3.630248e+06   0.000000e+00     33s
#      939    2.3016369e+03   6.381696e+04   0.000000e+00     35s
#     3006    2.2433307e+03   0.000000e+00   0.000000e+00     39s
#
# Root relaxation: objective 2.243331e+03, 3006 iterations, 7.17 seconds
# Total elapsed time = 40.83s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2243.33066    0   80 2114.00000 2243.33066  6.12%     -   42s
# H    0     0                    2235.0000000 2243.33066  0.37%     -   43s
# H    0     0                    2242.0000000 2243.33066  0.06%     -   43s
#      0     0 2243.16266    0   91 2242.00000 2243.16266  0.05%     -   50s
#      0     0 2243.10360    0   83 2242.00000 2243.10360  0.05%     -   54s
#      0     0 2243.09018    0   78 2242.00000 2243.09018  0.05%     -   56s
#      0     0 2243.08247    0   73 2242.00000 2243.08247  0.05%     -   61s
#      0     0 2243.08244    0   71 2242.00000 2243.08244  0.05%     -   64s
#      0     0 2243.08244    0   64 2242.00000 2243.08244  0.05%     -   69s
#      0     0 2243.08244    0   59 2242.00000 2243.08244  0.05%     -   72s
#      0     0 2243.08244    0   73 2242.00000 2243.08244  0.05%     -   77s
#      0     0 2243.08244    0   71 2242.00000 2243.08244  0.05%     -   79s
#      0     0 2243.08244    0   57 2242.00000 2243.08244  0.05%     -   87s
#      0     0 2243.08232    0   61 2242.00000 2243.08232  0.05%     -   89s
#      0     0 2243.08232    0   58 2242.00000 2243.08232  0.05%     -   97s
#      0     0 2243.08232    0   57 2242.00000 2243.08232  0.05%     -  100s
#      0     0 2243.08232    0   58 2242.00000 2243.08232  0.05%     -  105s
#      0     0 2243.08232    0   68 2242.00000 2243.08232  0.05%     -  107s
#      0     0 2243.08230    0   54 2242.00000 2243.08230  0.05%     -  113s
#      0     0 2243.08230    0   56 2242.00000 2243.08230  0.05%     -  115s
#      0     0 2243.08230    0   69 2242.00000 2243.08230  0.05%     -  120s
#      0     0 2243.08230    0   45 2242.00000 2243.08230  0.05%     -  127s
#      0     0 2243.08230    0   39 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.08230    0   38 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.08230    0   30 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.08230    0   30 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.08230    0   33 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.08230    0   34 2242.00000 2243.08230  0.05%     -  194s
#      0     0 2243.06446    0   33 2242.00000 2243.06446  0.05%     -  194s
#      0     0 2243.05987    0   30 2242.00000 2243.05987  0.05%     -  194s
#      0     0 2243.05987    0   31 2242.00000 2243.05987  0.05%     -  194s
#      0     0 2243.05987    0   37 2242.00000 2243.05987  0.05%     -  194s
#      0     0 2243.05987    0   35 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   32 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   38 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   21 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   28 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   23 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   33 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   17 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   20 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   21 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   26 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   23 2242.00000 2243.05987  0.05%     -  195s
#      0     0 2243.05987    0   22 2242.00000 2243.05987  0.05%     -  195s
#      0     2 2243.05987    0   21 2242.00000 2243.05987  0.05%     -  195s
#
# Cutting planes:
#   Learned: 4
#   Gomory: 5
#   Cover: 7
#   MIR: 3
#   StrongCG: 2
#   Flow cover: 5
#   Inf proof: 1
#
# Explored 2390 nodes (19425 simplex iterations) in 198.46 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2242 2235 2114
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.242000000000e+03, best bound 2.242000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3.5x4

# %%
datafile="2x3000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x2ec76731
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2118.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 1155960 nonzeros (13%)
# Presolve removed 26 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 32 columns
# Presolve removed 26 rows and 0 columns
# Presolve time: 25.71s
# Presolved: 8974 rows, 6032 columns, 7829012 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.635407e+06   0.000000e+00     28s
#      494    2.3608136e+03   4.205281e+05   0.000000e+00     30s
#     2365    2.2321972e+03   0.000000e+00   0.000000e+00     34s
#
# Root relaxation: objective 2.232197e+03, 2365 iterations, 5.67 seconds
# Total elapsed time = 35.92s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2232.19723    0   64 2118.00000 2232.19723  5.39%     -   36s
# H    0     0                    2226.0000000 2232.19723  0.28%     -   37s
# H    0     0                    2230.0000000 2232.19723  0.10%     -   37s
# H    0     0                    2231.0000000 2232.19723  0.05%     -   38s
#      0     0     cutoff    0      2231.00000 2231.00000  0.00%     -   43s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 6
#   MIR: 77
#   GUB cover: 1
#   RLT: 5
#
# Explored 1 nodes (3016 simplex iterations) in 43.26 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2231 2230 2226 2118
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.231000000000e+03, best bound 2.231000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x3.5x5

# %%
datafile="2x3000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x9d853f9e
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2101.0000000
# Presolve removed 11 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 15 rows and 6 columns (presolve time = 25s) ...
# Sparsify removed 1133959 nonzeros (13%)
# Presolve added 0 rows and 33 columns
# Presolve removed 23 rows and 0 columns
# Presolve time: 29.92s
# Presolved: 8977 rows, 6033 columns, 7856951 nonzeros
# Variable types: 39 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.638379e+06   0.000000e+00     33s
#      985    2.2664368e+03   4.055165e+04   0.000000e+00     35s
#     2373    2.2264799e+03   0.000000e+00   0.000000e+00     37s
#
# Root relaxation: objective 2.226480e+03, 2373 iterations, 5.12 seconds
# Total elapsed time = 41.17s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2226.47988    0   80 2101.00000 2226.47988  5.97%     -   42s
# H    0     0                    2222.0000000 2226.47988  0.20%     -   42s
# H    0     0                    2226.0000000 2226.47988  0.02%     -   43s
#      0     0 2226.47988    0   80 2226.00000 2226.47988  0.02%     -   43s
#
# Explored 1 nodes (2583 simplex iterations) in 43.33 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2226 2222 2101
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.226000000000e+03, best bound 2.226000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4x1

# %%
datafile="2x3000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x8d6ccd6f
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1946.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 25s) ...
# Sparsify removed 1161528 nonzeros (13%)
# Presolve added 0 rows and 32 columns
# Presolve removed 20 rows and 0 columns
# Presolve time: 29.93s
# Presolved: 8980 rows, 6032 columns, 7823442 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.873852e+06   0.000000e+00     33s
#     1011    2.1571877e+03   1.907088e+04   0.000000e+00     35s
#     2355    2.0763961e+03   1.807159e+05   0.000000e+00     40s
#     2957    2.0716237e+03   0.000000e+00   0.000000e+00     41s
#
# Root relaxation: objective 2.071624e+03, 2957 iterations, 9.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.62367    0   74 1946.00000 2071.62367  6.46%     -   44s
# H    0     0                    2064.0000000 2071.62367  0.37%     -   44s
# H    0     0                    2069.0000000 2071.62367  0.13%     -   45s
#      0     0 2071.39452    0   78 2069.00000 2071.39452  0.12%     -   51s
# H    0     0                    2070.0000000 2071.39452  0.07%     -   55s
#      0     0 2071.37539    0   66 2070.00000 2071.37539  0.07%     -   56s
#      0     0 2071.37525    0   71 2070.00000 2071.37525  0.07%     -   58s
#      0     0 2071.31132    0   45 2070.00000 2071.31132  0.06%     -   64s
#      0     0 2071.26564    0   44 2070.00000 2071.26564  0.06%     -   66s
#      0     0 2071.26564    0   46 2070.00000 2071.26564  0.06%     -   68s
#      0     0 2071.26443    0   50 2070.00000 2071.26443  0.06%     -   73s
#      0     0 2071.26443    0   50 2070.00000 2071.26443  0.06%     -   77s
#      0     0 2071.26443    0   53 2070.00000 2071.26443  0.06%     -   82s
#      0     0 2071.26443    0   51 2070.00000 2071.26443  0.06%     -   84s
#      0     0 2071.26443    0   44 2070.00000 2071.26443  0.06%     -   91s
#      0     0 2071.26443    0   40 2070.00000 2071.26443  0.06%     -   93s
#      0     0 2071.26443    0   50 2070.00000 2071.26443  0.06%     -  100s
#      0     0 2071.26443    0   48 2070.00000 2071.26443  0.06%     -  102s
#      0     0 2071.26443    0   33 2070.00000 2071.26443  0.06%     -  110s
#      0     0 2071.26443    0   33 2070.00000 2071.26443  0.06%     -  112s
#      0     0 2071.26443    0   32 2070.00000 2071.26443  0.06%     -  119s
#      0     0 2071.26443    0   32 2070.00000 2071.26443  0.06%     -  121s
#      0     0 2071.26443    0   31 2070.00000 2071.26443  0.06%     -  128s
#      0     0 2071.26443    0   40 2070.00000 2071.26443  0.06%     -  131s
#      0     0 2071.26443    0   28 2070.00000 2071.26443  0.06%     -  138s
#      0     0 2071.26443    0   37 2070.00000 2071.26443  0.06%     -  141s
#      0     0 2071.26443    0   43 2070.00000 2071.26443  0.06%     -  147s
#      0     0 2071.26443    0   32 2070.00000 2071.26443  0.06%     -  151s
#      0     0 2071.26443    0   46 2070.00000 2071.26443  0.06%     -  189s
#      0     0 2071.26443    0   36 2070.00000 2071.26443  0.06%     -  193s
#      0     0 2071.26443    0   42 2070.00000 2071.26443  0.06%     -  195s
#      0     0 2071.26443    0   38 2070.00000 2071.26443  0.06%     -  196s
#      0     0 2071.26443    0   38 2070.00000 2071.26443  0.06%     -  197s
#      0     0 2071.12219    0   31 2070.00000 2071.12219  0.05%     -  201s
#      0     0 2071.12219    0   30 2070.00000 2071.12219  0.05%     -  203s
#      0     0 2071.12219    0   26 2070.00000 2071.12219  0.05%     -  207s
#      0     0 2071.12219    0   25 2070.00000 2071.12219  0.05%     -  208s
#      0     0 2071.12219    0   22 2070.00000 2071.12219  0.05%     -  213s
#      0     0 2071.12219    0   25 2070.00000 2071.12219  0.05%     -  215s
#      0     0 2071.12219    0   20 2070.00000 2071.12219  0.05%     -  221s
#      0     0 2071.12219    0   19 2070.00000 2071.12219  0.05%     -  222s
#      0     0 2071.12219    0   20 2070.00000 2071.12219  0.05%     -  227s
#      0     0 2071.12219    0   20 2070.00000 2071.12219  0.05%     -  229s
#      0     0 2071.12219    0   21 2070.00000 2071.12219  0.05%     -  233s
#      0     0 2071.12219    0   23 2070.00000 2071.12219  0.05%     -  235s
#      0     0 2071.12219    0   19 2070.00000 2071.12219  0.05%     -  241s
#      0     0 2071.12219    0   20 2070.00000 2071.12219  0.05%     -  243s
#      0     0 2071.12219    0   18 2070.00000 2071.12219  0.05%     -  248s
# H    0     0                    2071.0000000 2071.12219  0.01%     -  248s
#      0     0 2071.12219    0   18 2071.00000 2071.12219  0.01%     -  248s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 7
#   MIR: 10
#   GUB cover: 1
#
# Explored 1 nodes (8606 simplex iterations) in 248.95 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2071 2070 2069 ... 1946
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071000000000e+03, best bound 2.071000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4x2

# %%
datafile="2x3000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xc19eb196
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1934.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 5s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 11s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 20s) ...
# Sparsify removed 1184580 nonzeros (13%)
# Presolve removed 16 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 36 columns
# Presolve removed 16 rows and 0 columns
# Presolve time: 25.72s
# Presolved: 8984 rows, 6036 columns, 7812394 nonzeros
# Variable types: 40 continuous, 5996 integer (5996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   3.834223e+06   0.000000e+00     28s
#      512    2.2025259e+03   6.119299e+05   0.000000e+00     30s
#     2920    2.0706080e+03   0.000000e+00   0.000000e+00     34s
#
# Root relaxation: objective 2.070608e+03, 2920 iterations, 6.29 seconds
# Total elapsed time = 35.82s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2070.60797    0  100 1934.00000 2070.60797  7.06%     -   38s
# H    0     0                    2065.0000000 2070.60797  0.27%     -   39s
# H    0     0                    2068.0000000 2070.60797  0.13%     -   40s
# H    0     0                    2069.0000000 2070.60797  0.08%     -   40s
#      0     0 2070.30508    0   77 2069.00000 2070.30508  0.06%     -   46s
#      0     0 2070.30002    0   78 2069.00000 2070.30002  0.06%     -   51s
#      0     0 2070.29766    0   72 2069.00000 2070.29766  0.06%     -   53s
#      0     0 2070.16862    0   61 2069.00000 2070.16862  0.06%     -   58s
#      0     0 2070.16818    0   64 2069.00000 2070.16818  0.06%     -   61s
#      0     0 2070.16818    0   64 2069.00000 2070.16818  0.06%     -   62s
#      0     0 2070.16716    0   65 2069.00000 2070.16716  0.06%     -   67s
# H    0     0                    2070.0000000 2070.16716  0.01%     -   70s
#      0     0 2070.16716    0   65 2070.00000 2070.16716  0.01%     -   70s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 2
#   MIR: 29
#
# Explored 1 nodes (3309 simplex iterations) in 70.32 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2070 2069 2068 ... 1934
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.070000000000e+03, best bound 2.070000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4x3

# %%
datafile="2x3000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xa11b3335
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1938.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 25s) ...
# Sparsify removed 1145921 nonzeros (13%)
# Presolve added 0 rows and 37 columns
# Presolve removed 17 rows and 0 columns
# Presolve time: 29.88s
# Presolved: 8983 rows, 6037 columns, 7857033 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.831132e+06   0.000000e+00     33s
#      940    2.1494821e+03   7.944617e+05   0.000000e+00     35s
#     2591    2.0640637e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: objective 2.064064e+03, 2591 iterations, 8.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2064.06366    0   74 1938.00000 2064.06366  6.50%     -   42s
# H    0     0                    2062.0000000 2064.06366  0.10%     -   42s
#      0     0 2063.76405    0   79 2062.00000 2063.76405  0.09%     -   49s
# H    0     0                    2063.0000000 2063.76405  0.04%     -   51s
#      0     0 2063.76405    0   79 2063.00000 2063.76405  0.04%     -   51s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 20
#
# Explored 1 nodes (2750 simplex iterations) in 51.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2063 2062 1938
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.063000000000e+03, best bound 2.063000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4x4

# %%
datafile="2x3000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xf96d0835
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1951.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 11s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 20s) ...
# Sparsify removed 1155160 nonzeros (13%)
# Presolve removed 28 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 28 columns
# Presolve removed 28 rows and 0 columns
# Presolve time: 25.71s
# Presolved: 8972 rows, 6028 columns, 7817834 nonzeros
# Variable types: 40 continuous, 5988 integer (5988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   3.766331e+06   0.000000e+00     28s
#     1029    2.1370530e+03   8.889122e+04   0.000000e+00     30s
#     2613    2.0814695e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 2.081470e+03, 2613 iterations, 3.29 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2081.46950    0   64 1951.00000 2081.46950  6.69%     -   34s
# H    0     0                    2079.0000000 2081.46950  0.12%     -   34s
# H    0     0                    2081.0000000 2081.46950  0.02%     -   35s
#      0     0 2081.46950    0   64 2081.00000 2081.46950  0.02%     -   35s
#
# Explored 1 nodes (2824 simplex iterations) in 35.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2081 2079 1951
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.081000000000e+03, best bound 2.081000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4x5

# %%
datafile="2x3000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x0a631a70
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 1971.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1145893 nonzeros (13%)
# Presolve removed 21 rows and 5941 columns (presolve time = 26s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 21 rows and 0 columns
# Presolve time: 25.65s
# Presolved: 8979 rows, 6039 columns, 7857053 nonzeros
# Variable types: 41 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.795417e+06   0.000000e+00     28s
#      706    2.1938418e+03   1.084717e+05   0.000000e+00     30s
#     2228    2.0998669e+03   1.779946e+04   0.000000e+00     35s
#     2543    2.0988155e+03   0.000000e+00   0.000000e+00     36s
#
# Root relaxation: objective 2.098816e+03, 2543 iterations, 8.06 seconds
# Total elapsed time = 40.37s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2098.81555    0  111 1971.00000 2098.81555  6.48%     -   40s
# H    0     0                    2091.0000000 2098.81555  0.37%     -   41s
# H    0     0                    2097.0000000 2098.81555  0.09%     -   42s
#      0     0 2098.60517    0   79 2097.00000 2098.60517  0.08%     -   48s
# H    0     0                    2098.0000000 2098.60517  0.03%     -   50s
#      0     0 2098.60517    0   79 2098.00000 2098.60517  0.03%     -   50s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 3
#   Implied bound: 1
#   Clique: 2
#   MIR: 18
#
# Explored 1 nodes (3665 simplex iterations) in 50.48 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2098 2097 2091 1971
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.098000000000e+03, best bound 2.098000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4.5x1

# %%
datafile="2x3000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xc7b0fd98
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1817.0000000
# Presolve removed 17 rows and 10 columns (presolve time = 5s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 15s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 20s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 25s) ...
# Sparsify removed 1194464 nonzeros (13%)
# Presolve added 0 rows and 30 columns
# Presolve removed 25 rows and 0 columns
# Presolve time: 29.92s
# Presolved: 8975 rows, 6030 columns, 7784524 nonzeros
# Variable types: 40 continuous, 5990 integer (5990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   4.000555e+06   0.000000e+00     33s
#      951    2.0725886e+03   4.092131e+05   0.000000e+00     35s
#     3368    1.9493855e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: objective 1.949385e+03, 3368 iterations, 7.45 seconds
# Total elapsed time = 40.95s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1949.38547    0   87 1817.00000 1949.38547  7.29%     -   42s
# H    0     0                    1942.0000000 1949.38547  0.38%     -   43s
# H    0     0                    1948.0000000 1949.38547  0.07%     -   43s
#      0     0 1949.23588    0   88 1948.00000 1949.23588  0.06%     -   49s
#      0     0 1949.22991    0   74 1948.00000 1949.22991  0.06%     -   53s
#      0     0 1949.22973    0   84 1948.00000 1949.22973  0.06%     -   55s
#      0     0 1949.21925    0   79 1948.00000 1949.21925  0.06%     -   61s
#      0     0 1949.21845    0   77 1948.00000 1949.21845  0.06%     -   63s
#      0     0 1949.21845    0   77 1948.00000 1949.21845  0.06%     -   64s
#      0     0 1949.21751    0   84 1948.00000 1949.21751  0.06%     -   69s
#      0     0 1949.21751    0   82 1948.00000 1949.21751  0.06%     -   73s
#      0     0 1949.21717    0   58 1948.00000 1949.21717  0.06%     -   81s
#      0     0 1949.21717    0   50 1948.00000 1949.21717  0.06%     -  108s
#      0     0 1949.21420    0   49 1948.00000 1949.21420  0.06%     -  113s
#      0     0 1949.21420    0   52 1948.00000 1949.21420  0.06%     -  114s
#      0     0 1949.20040    0   39 1948.00000 1949.20040  0.06%     -  118s
#      0     0 1949.20005    0   40 1948.00000 1949.20005  0.06%     -  119s
#      0     0 1949.20005    0   43 1948.00000 1949.20005  0.06%     -  120s
#      0     0 1949.19673    0   44 1948.00000 1949.19673  0.06%     -  124s
#      0     0 1949.19673    0   44 1948.00000 1949.19673  0.06%     -  125s
#      0     0 1949.16708    0   39 1948.00000 1949.16708  0.06%     -  127s
#      0     0 1949.16708    0   38 1948.00000 1949.16708  0.06%     -  129s
#      0     0 1949.16708    0   35 1948.00000 1949.16708  0.06%     -  131s
#      0     0 1949.16708    0   39 1948.00000 1949.16708  0.06%     -  132s
#      0     0 1949.16708    0   22 1948.00000 1949.16708  0.06%     -  137s
#      0     0 1949.16708    0   27 1948.00000 1949.16708  0.06%     -  138s
#      0     0 1949.16708    0   22 1948.00000 1949.16708  0.06%     -  143s
#      0     0 1949.16647    0   23 1948.00000 1949.16647  0.06%     -  145s
#      0     0 1949.16647    0   26 1948.00000 1949.16647  0.06%     -  145s
#      0     0 1949.16647    0   23 1948.00000 1949.16647  0.06%     -  150s
#      0     0 1949.16647    0   27 1948.00000 1949.16647  0.06%     -  151s
#      0     0 1949.16647    0   31 1948.00000 1949.16647  0.06%     -  154s
#      0     0 1949.16647    0   32 1948.00000 1949.16647  0.06%     -  155s
#      0     0 1949.16647    0   25 1948.00000 1949.16647  0.06%     -  159s
#      0     0 1949.16647    0   25 1948.00000 1949.16647  0.06%     -  162s
#      0     2 1949.16647    0   18 1948.00000 1949.16647  0.06%     -  170s
# H   33    38                    1949.0000000 1949.13364  0.01%   7.8  173s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 5
#   MIR: 29
#   GUB cover: 2
#   RLT: 3
#
# Explored 37 nodes (7099 simplex iterations) in 174.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1949 1948 1942 1817
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.949000000000e+03, best bound 1.949000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4.5x2

# %%
datafile="2x3000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xc2abbdcc
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1820.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 25s) ...
# Sparsify removed 1189746 nonzeros (13%)
# Presolve added 0 rows and 34 columns
# Presolve removed 15 rows and 0 columns
# Presolve time: 29.97s
# Presolved: 8985 rows, 6034 columns, 7801242 nonzeros
# Variable types: 40 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.919363e+06   0.000000e+00     33s
#     1074    2.0379437e+03   5.615339e+05   0.000000e+00     35s
#     2993    1.9446900e+03   0.000000e+00   0.000000e+00     39s
#
# Root relaxation: objective 1.944690e+03, 2993 iterations, 6.39 seconds
# Total elapsed time = 40.07s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1944.68997    0  119 1820.00000 1944.68997  6.85%     -   43s
# H    0     0                    1938.0000000 1944.68997  0.35%     -   43s
# H    0     0                    1943.0000000 1944.68997  0.09%     -   44s
#      0     0 1944.61767    0  101 1943.00000 1944.61767  0.08%     -   50s
#      0     0 1944.61712    0   96 1943.00000 1944.61712  0.08%     -   56s
#      0     0 1944.61712    0   96 1943.00000 1944.61712  0.08%     -   57s
#      0     0 1944.57730    0   91 1943.00000 1944.57730  0.08%     -   62s
# H    0     0                    1944.0000000 1944.57730  0.03%     -   64s
#      0     0 1944.57730    0   91 1944.00000 1944.57730  0.03%     -   64s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 3
#   MIR: 26
#   GUB cover: 1
#
# Explored 1 nodes (3296 simplex iterations) in 64.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1944 1943 1938 1820
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.944000000000e+03, best bound 1.944000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4.5x3

# %%
datafile="2x3000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x20de8ef8
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1838.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 4 rows and 0 columns (presolve time = 20s) ...
# Sparsify removed 1129571 nonzeros (13%)
# Presolve removed 10 rows and 5943 columns (presolve time = 25s) ...
# Presolve added 0 rows and 39 columns
# Presolve removed 10 rows and 0 columns
# Presolve time: 25.23s
# Presolved: 8990 rows, 6039 columns, 7879409 nonzeros
# Variable types: 39 continuous, 6000 integer (6000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   3.840450e+06   0.000000e+00     28s
#     1434    2.0262599e+03   1.557183e+05   0.000000e+00     30s
#     3097    1.9781233e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.978123e+03, 3097 iterations, 3.63 seconds
# Total elapsed time = 35.02s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1978.12335    0   90 1838.00000 1978.12335  7.62%     -   36s
# H    0     0                    1977.0000000 1978.12335  0.06%     -   37s
#      0     0     cutoff    0      1977.00000 1977.00000  0.00%     -   41s
#
# Cutting planes:
#   Gomory: 21
#   Implied bound: 1
#   MIR: 75
#   RLT: 4
#
# Explored 1 nodes (3730 simplex iterations) in 41.74 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 1977 1838
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.977000000000e+03, best bound 1.977000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4.5x4

# %%
datafile="2x3000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x643aec4a
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1810.0000000
# Presolve removed 16 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 1167092 nonzeros (13%)
# Presolve removed 22 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 32 columns
# Presolve removed 22 rows and 0 columns
# Presolve time: 25.66s
# Presolved: 8978 rows, 6032 columns, 7817894 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.023181e+06   0.000000e+00     28s
#      647    2.0940669e+03   1.099177e+05   0.000000e+00     30s
#     1969    1.9861452e+03   4.523499e+05   0.000000e+00     36s
#     3127    1.9438861e+03   0.000000e+00   0.000000e+00     39s
#
# Root relaxation: objective 1.943886e+03, 3127 iterations, 11.15 seconds
# Total elapsed time = 40.42s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1943.88612    0   74 1810.00000 1943.88612  7.40%     -   43s
# H    0     0                    1941.0000000 1943.88612  0.15%     -   43s
# H    0     0                    1942.0000000 1943.88612  0.10%     -   44s
# H    0     0                    1943.0000000 1943.88612  0.05%     -   45s
#      0     0 1943.88612    0   74 1943.00000 1943.88612  0.05%     -   45s
#
# Explored 1 nodes (3234 simplex iterations) in 45.10 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1943 1942 1941 1810
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.943000000000e+03, best bound 1.943000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x4.5x5

# %%
datafile="2x3000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x543b31c6
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 1819.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 20s) ...
# Sparsify removed 1155960 nonzeros (13%)
# Presolve removed 20 rows and 5942 columns (presolve time = 26s) ...
# Presolve added 0 rows and 32 columns
# Presolve removed 20 rows and 0 columns
# Presolve time: 25.62s
# Presolved: 8980 rows, 6032 columns, 7829024 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.985006e+06   0.000000e+00     28s
#     1240    2.0241373e+03   1.000294e+06   0.000000e+00     30s
#     2921    1.9491580e+03   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 1.949158e+03, 2921 iterations, 2.94 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1949.15800    0  100 1819.00000 1949.15800  7.16%     -   33s
# H    0     0                    1942.0000000 1949.15800  0.37%     -   33s
# H    0     0                    1947.0000000 1949.15800  0.11%     -   34s
#      0     0 1949.12155    0   86 1947.00000 1949.12155  0.11%     -   42s
# H    0     0                    1948.0000000 1949.12155  0.06%     -   44s
#      0     0 1949.02813    0   79 1948.00000 1949.02813  0.05%     -   46s
#      0     0 1949.02813    0   81 1948.00000 1949.02813  0.05%     -   47s
#      0     0     cutoff    0      1948.00000 1948.00000  0.00%     -   51s
#
# Cutting planes:
#   Gomory: 23
#   MIR: 52
#
# Explored 1 nodes (3130 simplex iterations) in 52.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1948 1947 1942 1819
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.948000000000e+03, best bound 1.948000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x5x1

# %%
datafile="2x3000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x4b4b68d1
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1700.0000000
# Presolve removed 11 rows and 6 columns (presolve time = 5s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 11s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 11 rows and 6 columns (presolve time = 20s) ...
# Sparsify removed 1133981 nonzeros (13%)
# Presolve removed 11 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 33 columns
# Presolve removed 11 rows and 0 columns
# Presolve time: 25.62s
# Presolved: 8989 rows, 6033 columns, 7857015 nonzeros
# Variable types: 39 continuous, 5994 integer (5994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   4.090305e+06   0.000000e+00     28s
#      721    2.0163510e+03   2.636588e+05   0.000000e+00     30s
#     1951    1.9012023e+03   9.685655e+05   0.000000e+00     36s
#     3437    1.8377237e+03   5.125680e+04   0.000000e+00     40s
#     4123    1.8352353e+03   0.000000e+00   0.000000e+00     42s
#
# Root relaxation: objective 1.835235e+03, 4123 iterations, 14.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1835.23527    0   72 1700.00000 1835.23527  7.96%     -   45s
# H    0     0                    1833.0000000 1835.23527  0.12%     -   45s
# H    0     0                    1834.0000000 1835.23527  0.07%     -   46s
#      0     0 1835.15189    0   50 1834.00000 1835.15189  0.06%     -   54s
#      0     0 1835.15189    0   41 1834.00000 1835.15189  0.06%     -  101s
#      0     0 1835.15189    0   40 1834.00000 1835.15189  0.06%     -  101s
#      0     0 1835.09245    0   39 1834.00000 1835.09245  0.06%     -  101s
#      0     0 1835.09244    0   37 1834.00000 1835.09244  0.06%     -  101s
#      0     0 1835.07989    0   33 1834.00000 1835.07989  0.06%     -  101s
#      0     0 1835.07630    0   33 1834.00000 1835.07630  0.06%     -  101s
#      0     0 1835.07630    0   34 1834.00000 1835.07630  0.06%     -  101s
#      0     0 1835.07630    0   24 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   22 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   24 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   23 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   11 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   12 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   12 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   10 1834.00000 1835.07630  0.06%     -  102s
#      0     0 1835.07630    0   10 1834.00000 1835.07630  0.06%     -  102s
#      0     2 1835.07630    0   10 1834.00000 1835.07630  0.06%     -  102s
# H 1484    16                    1835.0000000 1835.04814  0.00%   1.7  103s
#
# Explored 1485 nodes (10560 simplex iterations) in 103.99 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1835 1834 1833 1700
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.835000000000e+03, best bound 1.835000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x5x2

# %%
datafile="2x3000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xdb14858f
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1715.0000000
# Presolve removed 16 rows and 12 columns (presolve time = 5s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 20 rows and 12 columns (presolve time = 25s) ...
# Sparsify removed 1155160 nonzeros (13%)
# Presolve added 0 rows and 28 columns
# Presolve removed 20 rows and 0 columns
# Presolve time: 29.78s
# Presolved: 8980 rows, 6028 columns, 7817854 nonzeros
# Variable types: 40 continuous, 5988 integer (5988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   4.087817e+06   0.000000e+00     33s
#     1084    1.9553398e+03   2.658283e+05   0.000000e+00     36s
#     2146    1.9064365e+03   1.606835e+04   0.000000e+00     40s
#     3223    1.8476306e+03   0.000000e+00   0.000000e+00     43s
#
# Root relaxation: objective 1.847631e+03, 3223 iterations, 10.78 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1847.63061    0   24 1715.00000 1847.63061  7.73%     -   45s
# H    0     0                    1844.0000000 1847.63061  0.20%     -   45s
# H    0     0                    1846.0000000 1847.63061  0.09%     -   46s
# H    0     0                    1847.0000000 1847.63061  0.03%     -   47s
#      0     0 1847.63061    0   24 1847.00000 1847.63061  0.03%     -   47s
#
# Explored 1 nodes (3257 simplex iterations) in 47.54 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1847 1846 1844 1715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.847000000000e+03, best bound 1.847000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x5x3

# %%
datafile="2x3000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xddab44be
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1731.0000000
# Presolve removed 5 rows and 2 columns (presolve time = 5s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 11s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 20s) ...
# Sparsify removed 1129181 nonzeros (13%)
# Presolve removed 7 rows and 5943 columns (presolve time = 26s) ...
# Presolve added 0 rows and 37 columns
# Presolve removed 7 rows and 0 columns
# Presolve time: 25.63s
# Presolved: 8993 rows, 6037 columns, 7873807 nonzeros
# Variable types: 39 continuous, 5998 integer (5998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   4.116436e+06   0.000000e+00     28s
#      744    2.0192894e+03   2.959129e+05   0.000000e+00     30s
#     2539    1.8701039e+03   4.159956e+05   0.000000e+00     35s
#     3487    1.8575196e+03   0.000000e+00   0.000000e+00     37s
#
# Root relaxation: objective 1.857520e+03, 3487 iterations, 9.62 seconds
# Total elapsed time = 40.29s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1857.51964    0   60 1731.00000 1857.51964  7.31%     -   40s
# H    0     0                    1854.0000000 1857.51964  0.19%     -   41s
# H    0     0                    1856.0000000 1857.51964  0.08%     -   42s
#      0     0 1857.49750    0   50 1856.00000 1857.49750  0.08%     -   49s
# H    0     0                    1857.0000000 1857.49750  0.03%     -   51s
#      0     0 1857.49750    0   50 1857.00000 1857.49750  0.03%     -   51s
#
# Cutting planes:
#   Gomory: 10
#   Cover: 3
#   MIR: 14
#   StrongCG: 4
#   RLT: 1
#
# Explored 1 nodes (3633 simplex iterations) in 51.14 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1857 1856 1854 1731
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.857000000000e+03, best bound 1.857000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x5x4

# %%
datafile="2x3000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0xfb458a45
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1730.0000000
# Presolve removed 12 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 15s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 25s) ...
# Sparsify removed 1167092 nonzeros (13%)
# Presolve added 0 rows and 32 columns
# Presolve removed 12 rows and 0 columns
# Presolve time: 29.90s
# Presolved: 8988 rows, 6032 columns, 7817910 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.023564e+06   0.000000e+00     33s
#     1154    2.0140288e+03   7.269786e+05   0.000000e+00     35s
#     3698    1.8539359e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: objective 1.853936e+03, 3698 iterations, 7.91 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1853.93590    0   71 1730.00000 1853.93590  7.16%     -   43s
# H    0     0                    1848.0000000 1853.93590  0.32%     -   44s
# H    0     0                    1852.0000000 1853.93590  0.10%     -   44s
#      0     0 1853.75347    0   57 1852.00000 1853.75347  0.09%     -   51s
# H    0     0                    1853.0000000 1853.75347  0.04%     -   53s
#      0     0 1853.75347    0   57 1853.00000 1853.75347  0.04%     -   53s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 1
#   MIR: 12
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (4133 simplex iterations) in 53.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1853 1852 1848 1730
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.853000000000e+03, best bound 1.853000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x3000x5x5

# %%
datafile="2x3000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 9000 rows, 6000 columns and 9009000 nonzeros
# Model fingerprint: 0x029bda1c
# Variable types: 0 continuous, 6000 integer (6000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 1699.0000000
# Presolve removed 12 rows and 8 columns (presolve time = 5s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 19s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 30s) ...
# Sparsify removed 1167092 nonzeros (13%)
# Presolve added 0 rows and 32 columns
# Presolve removed 16 rows and 0 columns
# Presolve time: 34.25s
# Presolved: 8984 rows, 6032 columns, 7817896 nonzeros
# Variable types: 40 continuous, 5992 integer (5992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.104987e+06   0.000000e+00     37s
#     1329    1.9402439e+03   8.981231e+04   0.000000e+00     40s
#     3382    1.8307464e+03   0.000000e+00   0.000000e+00     43s
#
# Root relaxation: objective 1.830746e+03, 3382 iterations, 6.90 seconds
# Total elapsed time = 45.65s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1830.74641    0  117 1699.00000 1830.74641  7.75%     -   48s
# H    0     0                    1820.0000000 1830.74641  0.59%     -   49s
# H    0     0                    1828.0000000 1830.74641  0.15%     -   50s
# H    0     0                    1829.0000000 1830.74641  0.10%     -   51s
#      0     0 1830.54962    0  105 1829.00000 1830.54962  0.08%     -   56s
# H    0     0                    1830.0000000 1830.54962  0.03%     -   60s
#      0     0 1830.54962    0  105 1830.00000 1830.54962  0.03%     -   60s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 2
#   Implied bound: 2
#   MIR: 26
#   StrongCG: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (3760 simplex iterations) in 60.68 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1830 1829 1828 ... 1699
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.830000000000e+03, best bound 1.830000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x1.5x1

# %%
datafile="3x3000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x45d0f0d0
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2999.0000000
# Presolve removed 7 rows and 3 columns (presolve time = 6s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 13s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 23s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 25s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 30s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 35s) ...
# Presolve removed 13 rows and 3 columns (presolve time = 40s) ...
# Presolve removed 13 rows and 3 columns
# Presolve time: 42.76s
# Presolved: 11987 rows, 8997 columns, 13504473 nonzeros
# Variable types: 0 continuous, 8997 integer (8997 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   3.339843e+06   0.000000e+00     45s
#
# Root relaxation: cutoff, 0 iterations, 0.90 seconds
#
# Explored 0 nodes (0 simplex iterations) in 45.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.999000000000e+03, best bound 2.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x1.5x2

# %%
datafile="3x3000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x90fdecfe
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2997.0000000
# Presolve removed 24 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 16s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 36s) ...
# Presolve removed 24 rows and 9 columns
# Presolve time: 36.13s
# Presolved: 11976 rows, 8991 columns, 13486470 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.291083e+06   0.000000e+00     39s
#
# Root relaxation: cutoff, 0 iterations, 0.90 seconds
#
# Explored 0 nodes (0 simplex iterations) in 38.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.997000000000e+03, best bound 2.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x1.5x3

# %%
datafile="3x3000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x40f0c93b
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2996.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 17s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 36s) ...
# Presolve removed 18 rows and 9 columns
# Presolve time: 36.39s
# Presolved: 11982 rows, 8991 columns, 13486488 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.252353e+06   0.000000e+00     39s
#      682    2.9963170e+03   1.054028e+01   0.000000e+00     40s
#
# Root relaxation: cutoff, 725 iterations, 2.50 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2996.00000 2996.00000  0.00%     -   40s
#
# Explored 0 nodes (725 simplex iterations) in 40.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.996000000000e+03, best bound 2.996000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x1.5x4

# %%
datafile="3x3000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xa2d4f9d9
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2994.0000000
# Presolve removed 32 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 17s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 20s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 36s) ...
# Presolve removed 32 rows and 15 columns
# Presolve time: 36.07s
# Presolved: 11968 rows, 8985 columns, 13468476 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   3.281751e+06   0.000000e+00     38s
#      768    2.9946712e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: cutoff, 768 iterations, 2.65 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2994.00000 2994.00000  0.00%     -   40s
#
# Explored 0 nodes (768 simplex iterations) in 40.33 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.994000000000e+03, best bound 2.994000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x1.5x5

# %%
datafile="3x3000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x2d9a12f0
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3000.0000000
# Presolve removed 9 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 16s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 36s) ...
# Presolve removed 9 rows and 0 columns
# Presolve time: 35.62s
# Presolved: 11991 rows, 9000 columns, 13513473 nonzeros
# Variable types: 0 continuous, 9000 integer (9000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0000000e+03   3.349807e+06   0.000000e+00     38s
#
# Root relaxation: cutoff, 0 iterations, 0.89 seconds
#
# Explored 0 nodes (0 simplex iterations) in 38.11 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+03, best bound 3.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2x1

# %%
datafile="3x3000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xb6cf0a86
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2976.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 16s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 20s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 36s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 36.03s
# Presolved: 11974 rows, 8985 columns, 13468500 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   3.879986e+06   0.000000e+00     38s
#     1038    2.9805927e+03   8.654960e+00   0.000000e+00     40s
#     1110    2.9805939e+03   0.000000e+00   0.000000e+00     40s
#
# Root relaxation: objective 2.980594e+03, 1110 iterations, 2.94 seconds
# Total elapsed time = 45.83s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2980.59387    0   47 2976.00000 2980.59387  0.15%     -   49s
# H    0     0                    2979.0000000 2980.59387  0.05%     -   50s
#      0     0 2980.58667    0   37 2979.00000 2980.58667  0.05%     -   60s
#      0     0 2980.48013    0   38 2979.00000 2980.48013  0.05%     -   70s
#      0     0 2980.48013    0   41 2979.00000 2980.48013  0.05%     -   72s
#      0     0 2980.31776    0   40 2979.00000 2980.31776  0.04%     -   81s
#      0     0 2980.16348    0   32 2979.00000 2980.16348  0.04%     -   86s
#      0     0 2980.16348    0   32 2979.00000 2980.16348  0.04%     -   89s
#      0     0 2980.16348    0   30 2979.00000 2980.16348  0.04%     -   99s
#      0     0 2980.16348    0   32 2979.00000 2980.16348  0.04%     -  103s
#      0     0 2980.16348    0   39 2979.00000 2980.16348  0.04%     -  113s
#      0     0 2980.13990    0   35 2979.00000 2980.13990  0.04%     -  116s
#      0     0 2980.13990    0   31 2979.00000 2980.13990  0.04%     -  119s
#      0     0 2980.02180    0   21 2979.00000 2980.02180  0.03%     -  133s
#      0     0 2980.02180    0   26 2979.00000 2980.02180  0.03%     -  137s
#      0     0 2980.02180    0   29 2979.00000 2980.02180  0.03%     -  147s
#      0     0 2980.02178    0   30 2979.00000 2980.02178  0.03%     -  151s
#      0     0 2980.02178    0   22 2979.00000 2980.02178  0.03%     -  165s
#      0     0 2980.02061    0   20 2979.00000 2980.02061  0.03%     -  169s
#      0     0 2980.02061    0   31 2979.00000 2980.02061  0.03%     -  179s
#      0     0 2980.02061    0   33 2979.00000 2980.02061  0.03%     -  183s
#      0     0 2980.02061    0   30 2979.00000 2980.02061  0.03%     -  190s
#      0     0 2980.02061    0   28 2979.00000 2980.02061  0.03%     -  192s
#      0     0 2980.02061    0   25 2979.00000 2980.02061  0.03%     -  202s
#      0     0 2980.02061    0   20 2979.00000 2980.02061  0.03%     -  210s
#      0     2 2980.02061    0   20 2979.00000 2980.02061  0.03%     -  222s
#      3     6 infeasible    2      2979.00000 2980.01937  0.03%   478  227s
#      7    12 2980.01937    3   24 2979.00000 2980.01937  0.03%   210  231s
#     19    24 2980.01927    4   24 2979.00000 2980.01937  0.03%  83.4  236s
#     31    36 2980.01927    6   22 2979.00000 2980.01937  0.03%  54.0  245s
#     43    48 2980.01927    5   29 2979.00000 2980.01937  0.03%  40.2  252s
#     49    75 2980.01927    7   20 2979.00000 2980.01937  0.03%  35.6  256s
#     76   164 2980.01927    8   20 2979.00000 2980.01937  0.03%  24.3  265s
#    174   317 2980.01927   20   20 2979.00000 2980.01937  0.03%  12.5  283s
#    354   558 2980.01927   37   20 2979.00000 2980.01937  0.03%   7.8  319s
#    634   918 2980.01846   72   20 2979.00000 2980.01937  0.03%   5.6  357s
#   1022  1221 2980.01822  112   20 2979.00000 2980.01937  0.03%   4.6  400s
#   1436  1479 2980.00484  154   18 2979.00000 2980.01937  0.03%   4.1  445s
#   1865  1480 2980.01846   13   20 2979.00000 2980.01937  0.03%   3.9  603s
#   1867  1481 2980.00541   33   27 2979.00000 2980.01937  0.03%   3.9  775s
#   1868  1482 2980.01881   35   28 2979.00000 2980.01881  0.03%   3.9  804s
#   1869  1483 2980.01552   46   35 2979.00000 2980.01552  0.03%   3.9  829s
#   1870  1483 2979.99758  182   31 2979.00000 2980.01552  0.03%   3.9  852s
#   1872  1485 2980.00484  155   22 2979.00000 2980.00959  0.03%   3.9  877s
#   1873  1485 2980.00959  157   16 2979.00000 2980.00959  0.03%   3.9  909s
#   1874  1486 2979.99903   74   25 2979.00000 2980.00959  0.03%   3.9  930s
#   1875  1487 2980.00959   71   21 2979.00000 2980.00959  0.03%   3.9  943s
#   1876  1487 2980.00287  190   14 2979.00000 2980.00959  0.03%   3.9  962s
#   1877  1488 2980.00813  119   16 2979.00000 2980.00959  0.03%   3.8  988s
#   1878  1489 2980.00959   34   26 2979.00000 2980.00959  0.03%   3.8 1014s
#   1879  1489 2980.00959   75   25 2979.00000 2980.00959  0.03%   3.8 1043s
#   1880  1490 2980.00959   34   16 2979.00000 2980.00959  0.03%   3.8 1070s
#   1881  1491 2979.99874  135   12 2979.00000 2980.00959  0.03%   3.8 1093s
#   1882  1491 2979.99758  159    9 2979.00000 2980.00959  0.03%   3.8 1117s
#   1883  1492 2980.00484  140   14 2979.00000 2980.00959  0.03%   3.8 1149s
#   1884  1493 2980.00959   33   15 2979.00000 2980.00959  0.03%   3.8 1179s
#   1885  1493 2980.00959   88   19 2979.00000 2980.00959  0.03%   3.8 1215s
#   1886  1494 2980.00484  162   15 2979.00000 2980.00959  0.03%   3.8 1245s
#   1887  1495 2980.00959   10   19 2979.00000 2980.00959  0.03%   3.8 1275s
#   1888  1495 2980.00777   83   11 2979.00000 2980.00959  0.03%   3.8 1290s
#   1890  1498 2980.00484  153   20 2979.00000 2980.00959  0.03%   9.6 1461s
#   1892  1499 2980.00959   40   41 2979.00000 2980.00959  0.03%   9.6 1638s
#   1893  1500 2980.00813  107   24 2979.00000 2980.00959  0.03%   9.6 1691s
#   1894  1501 2980.00959  130   19 2979.00000 2980.00959  0.03%   9.6 1700s
#   1895  1501 2980.00959    6   21 2979.00000 2980.00959  0.03%   9.6 1716s
#   1896  1502 2980.00959   65   24 2979.00000 2980.00959  0.03%   9.6 1752s
#   1897  1503 2980.00959   16   24 2979.00000 2980.00959  0.03%   9.6 1782s
#   1898  1503 2980.00109  166   16 2979.00000 2980.00959  0.03%   9.6 1824s
#   1899  1504 2980.00959   28   23 2979.00000 2980.00959  0.03%   9.6 1857s
#   1900  1505 2980.00959  150   15 2979.00000 2980.00959  0.03%   9.6 1902s
#   1901  1505 2980.00484  175   19 2979.00000 2980.00959  0.03%   9.6 1915s
#   1902  1506 2980.00959  107   13 2979.00000 2980.00959  0.03%   9.6 1957s
#   1903  1507 2980.00959   45   17 2979.00000 2980.00959  0.03%   9.6 1972s
#   1904  1507 2980.00959  170   20 2979.00000 2980.00959  0.03%   9.6 2002s
#   1905  1508 2980.00959  113   27 2979.00000 2980.00959  0.03%   9.6 2033s
#   1906  1509 2979.99758  196   15 2979.00000 2980.00959  0.03%   9.6 2071s
#   1907  1509 2980.00959  132   21 2979.00000 2980.00959  0.03%   9.5 2097s
#   1908  1510 2980.00777   92   17 2979.00000 2980.00959  0.03%   9.5 2137s
#   1909  1511 2980.00777   84   22 2979.00000 2980.00959  0.03%   9.5 2150s
#   1910  1511 2980.00959   65   20 2979.00000 2980.00959  0.03%   9.5 2184s
#   1911  1512 2980.00082   50   27 2979.00000 2980.00959  0.03%   9.5 2210s
#   1912  1513 2980.00959   39   19 2979.00000 2980.00959  0.03%   9.5 2236s
#   1913  1513 2980.00959   43   19 2979.00000 2980.00959  0.03%   9.5 2251s
#   1914  1514 2979.99758  197   19 2979.00000 2980.00959  0.03%   9.5 2346s
#   1915  1517 2980.00959   22   15 2979.00000 2980.00959  0.03%  12.0 2360s
#   1923  1513 2980.00959   26   12 2979.00000 2980.00959  0.03%  12.0 2365s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 3
#   MIR: 4
#   StrongCG: 2
#   Flow cover: 2
#   RLT: 1
#
# Explored 1926 nodes (46218 simplex iterations) in 2366.85 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2979 2976
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.979000000000e+03, best bound 2.979000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2x2

# %%
datafile="3x3000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xf47d30b8
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2971.0000000
# Presolve removed 19 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 25s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 19 rows and 12 columns
# Presolve time: 42.68s
# Presolved: 11981 rows, 8988 columns, 13477497 nonzeros
# Variable types: 0 continuous, 8988 integer (8988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   3.856645e+06   0.000000e+00     45s
#     1078    2.9762111e+03   0.000000e+00   0.000000e+00     48s
#
# Root relaxation: objective 2.976211e+03, 1078 iterations, 3.41 seconds
# Total elapsed time = 51.67s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2976.21110    0   44 2971.00000 2976.21110  0.18%     -   55s
# H    0     0                    2975.0000000 2976.21110  0.04%     -   57s
#      0     0 2976.20548    0   57 2975.00000 2976.20548  0.04%     -  116s
#      0     0 2976.19348    0   56 2975.00000 2976.19348  0.04%     -  125s
#      0     0 2976.19348    0   56 2975.00000 2976.19348  0.04%     -  127s
#      0     0 2976.09112    0   51 2975.00000 2976.09112  0.04%     -  137s
#      0     0 2976.01378    0   44 2975.00000 2976.01378  0.03%     -  143s
#
# Cutting planes:
#   Gomory: 15
#   MIR: 8
#
# Explored 1 nodes (4528 simplex iterations) in 146.50 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2975 2971
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.975000000000e+03, best bound 2.975000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2x3

# %%
datafile="3x3000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x5d324b59
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2980.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 27s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 40s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 50.08s
# Presolved: 11974 rows, 8985 columns, 13468494 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   3.893152e+06   0.000000e+00     53s
#     1287    2.9824387e+03   0.000000e+00   0.000000e+00     55s
#
# Root relaxation: objective 2.982440e+03, 1287 iterations, 3.60 seconds
# Total elapsed time = 60.57s
# Total elapsed time = 67.34s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2982.43992    0   96 2980.00000 2982.43992  0.08%     -   70s
#      0     0 2982.20643    0   93 2980.00000 2982.20643  0.07%     -  133s
#      0     0 2982.20204    0   90 2980.00000 2982.20204  0.07%     -  140s
#      0     0 2982.20153    0   93 2980.00000 2982.20153  0.07%     -  143s
#      0     0 2982.17719    0   81 2980.00000 2982.17719  0.07%     -  154s
#      0     0 2982.17719    0   78 2980.00000 2982.17719  0.07%     -  160s
#      0     0 2982.16885    0   64 2980.00000 2982.16885  0.07%     -  171s
#      0     0 2982.16756    0   70 2980.00000 2982.16756  0.07%     -  178s
#      0     0 2982.16756    0   70 2980.00000 2982.16756  0.07%     -  181s
#      0     0 2982.15194    0   61 2980.00000 2982.15194  0.07%     -  192s
#      0     0 2982.15194    0   58 2980.00000 2982.15194  0.07%     -  198s
#      0     0 2982.15194    0   59 2980.00000 2982.15194  0.07%     -  208s
#      0     0 2982.15194    0   60 2980.00000 2982.15194  0.07%     -  215s
#      0     0 2982.13716    0   48 2980.00000 2982.13716  0.07%     -  235s
#      0     0 2982.04738    0   49 2980.00000 2982.04738  0.07%     -  241s
#      0     0 2982.04738    0   41 2980.00000 2982.04738  0.07%     -  245s
#      0     0 2982.04738    0   42 2980.00000 2982.04738  0.07%     -  255s
# H    0     0                    2981.0000000 2982.04738  0.04%     -  258s
#      0     0 2982.04738    0   49 2981.00000 2982.04738  0.04%     -  262s
#      0     0 2982.04738    0   46 2981.00000 2982.04738  0.04%     -  272s
#      0     0 2982.04738    0   49 2981.00000 2982.04738  0.04%     -  279s
#      0     0 2982.04738    0   45 2981.00000 2982.04738  0.04%     -  299s
#      0     0 2982.04738    0   46 2981.00000 2982.04738  0.04%     -  313s
#      0     0 2982.04738    0   45 2981.00000 2982.04738  0.04%     -  334s
#      0     0 2982.04738    0   45 2981.00000 2982.04738  0.04%     -  342s
#      0     2 2982.04738    0   45 2981.00000 2982.04738  0.04%     -  364s
#      1     2 infeasible    1      2981.00000 2982.04738  0.04%  1315  367s
#      3     4 2982.04738    2   53 2981.00000 2982.04738  0.04%   445  372s
#      5     8 2982.04738    3   51 2981.00000 2982.04738  0.04%   272  376s
#      9    14 2982.04738    4   56 2981.00000 2982.04738  0.04%   159  380s
#     21    26 2982.04738    6   54 2981.00000 2982.04738  0.04%  77.4  386s
#     27    32 2982.04738    7   55 2981.00000 2982.04738  0.04%  61.4  396s
#     44    52 2982.04738    9   51 2981.00000 2982.04738  0.04%  39.8  404s
#     53    82 2982.04738   11   53 2981.00000 2982.04738  0.04%  34.0  413s
#     84    92 2982.04738   13   49 2981.00000 2982.04738  0.04%  23.2  436s
#     94   174 2982.04738   14   49 2981.00000 2982.04738  0.04%  21.1  474s
#    184   503 2982.04607   21   47 2981.00000 2982.04738  0.04%  12.6  530s
#    538   603 2982.04314   54   45 2981.00000 2982.04738  0.04%   7.6  608s
#    650   922 2982.04241   54   41 2981.00000 2982.04738  0.04%   7.1  711s
#    991  1452 2982.02881  101   27 2981.00000 2982.04738  0.04%   6.2  773s
#   1558  1832 2982.02307  162   34 2981.00000 2982.04738  0.04%   5.6  836s
#   1962  2374 2982.00834  198   37 2981.00000 2982.04738  0.04%   5.4  916s
#   2568  2711 2982.03132  151   53 2981.00000 2982.04738  0.04%   5.2  983s
#   2973  3416 2982.04551   53   39 2981.00000 2982.04738  0.04%   5.1 1057s
#   3878  3663 2982.03557  224   51 2981.00000 2982.04738  0.04%   5.0 1108s
#   4249  3664 2982.04399   97   45 2981.00000 2982.04738  0.04%   4.9 1369s
#   4251  3665 2982.00044  296   90 2981.00000 2982.04738  0.04%   4.9 1598s
#   4252  3666 2982.02653  113   52 2981.00000 2982.04738  0.04%   4.9 1768s
#   4253  3667 2982.03942   98   59 2981.00000 2982.04738  0.04%   4.9 1770s
#   4255  3668 2982.02995  125   60 2981.00000 2982.04738  0.04%   4.9 1917s
#   4256  3669 2982.04103  125   52 2981.00000 2982.04738  0.04%   4.9 1948s
#   4257  3669 2982.04408   46   46 2981.00000 2982.04738  0.04%   4.9 1974s
#   4258  3670 2982.00821  263   30 2981.00000 2982.03160  0.03%   4.9 2024s
#   4259  3671 2982.02235  148   36 2981.00000 2982.03160  0.03%   4.9 2058s
#   4260  3671 2982.01662   81   38 2981.00000 2982.01662  0.03%   4.9 2103s
#   4261  3672 2982.01655   47   40 2981.00000 2982.01655  0.03%   4.9 2137s
#   4262  3673 2982.01539  118   32 2981.00000 2982.01539  0.03%   4.9 2171s
#   4263  3673 2982.00637  310   38 2981.00000 2982.01539  0.03%   4.9 2199s
#   4264  3674 2982.00941  176   30 2981.00000 2982.01539  0.03%   4.9 2261s
#   4265  3675 2982.01539  304   33 2981.00000 2982.01539  0.03%   4.9 2307s
#   4266  3675 2982.00913   82   37 2981.00000 2982.00913  0.03%   4.9 2338s
#   4267  3676 2982.00913  102   48 2981.00000 2982.00913  0.03%   4.9 2374s
#   4268  3677 2982.00913   84   36 2981.00000 2982.00913  0.03%   4.9 2420s
#   4269  3677 2982.00913   50   45 2981.00000 2982.00913  0.03%   4.9 2450s
#   4270  3678 2982.00913   53   33 2981.00000 2982.00913  0.03%   4.9 2488s
#   4271  3679 2982.00913  153   44 2981.00000 2982.00913  0.03%   4.9 2521s
#   4272  3679 2982.00913  108   29 2981.00000 2982.00913  0.03%   4.9 2563s
#   4273  3680 2982.00124  260   51 2981.00000 2982.00913  0.03%   4.9 2589s
#   4274  3681 2982.00833  157   47 2981.00000 2982.00913  0.03%   4.9 2624s
#   4275  3681 2982.00649  282   46 2981.00000 2982.00913  0.03%   4.9 2649s
#   4276  3682 2982.00913   88   35 2981.00000 2982.00913  0.03%   4.9 2690s
#   4277  3683 2982.00913   95   40 2981.00000 2982.00913  0.03%   4.9 2718s
#   4278  3683 2982.00913  249   36 2981.00000 2982.00913  0.03%   4.9 2759s
#   4279  3684 2982.00913  114   46 2981.00000 2982.00913  0.03%   4.9 2785s
#   4280  3685 2982.00913  131   43 2981.00000 2982.00913  0.03%   4.9 2821s
#   4281  3685 2982.00913  152   41 2981.00000 2982.00913  0.03%   4.9 2836s
#   4283  3688 2982.00913  119   45 2981.00000 2982.00913  0.03%   9.7 3080s
#   4285  3689 2982.00000  105   66 2981.00000 2982.00000  0.03%   9.7 3293s
#   4286  3690 2982.00000   10   47 2981.00000 2982.00000  0.03%   9.7 3445s
#   4287  3691 2982.00000  176   42 2981.00000 2982.00000  0.03%   9.7 3458s
#   4288  3691 2982.00000  273   40 2981.00000 2982.00000  0.03%   9.7 3481s
#   4289  3692 2982.00000  134   49 2981.00000 2982.00000  0.03%   9.7 3500s
#   4290  3693 2982.00000  227   44 2981.00000 2982.00000  0.03%   9.7 3524s
#   4291  3693 2982.00000  192   50 2981.00000 2982.00000  0.03%   9.7 3539s
#   4292  3694 2982.00000  118   46 2981.00000 2982.00000  0.03%   9.7 3567s
#   4293  3695 2982.00000  241   52 2981.00000 2982.00000  0.03%   9.6 3592s
#
# Cutting planes:
#   Gomory: 19
#   Cover: 20
#   MIR: 28
#   StrongCG: 21
#   Flow cover: 37
#   GUB cover: 2
#   RLT: 2
#
# Explored 4293 nodes (71157 simplex iterations) in 3603.00 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2981 2980
#
# Time limit reached
# Best objective 2.981000000000e+03, best bound 2.982000000000e+03, gap 0.0335%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2x4

# %%
datafile="3x3000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x100a986f
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2977.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 16s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 46s) ...
# Presolve removed 18 rows and 9 columns
# Presolve time: 45.58s
# Presolved: 11982 rows, 8991 columns, 13486485 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   3.876512e+06   0.000000e+00     48s
#     1163    2.9821936e+03   0.000000e+00   0.000000e+00     50s
#
# Root relaxation: objective 2.982195e+03, 1163 iterations, 3.22 seconds
# Total elapsed time = 55.09s
# Total elapsed time = 61.70s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2982.19479    0   78 2977.00000 2982.19479  0.17%     -   64s
# H    0     0                    2981.0000000 2982.19479  0.04%     -   66s
#      0     0 2982.19479    0   68 2981.00000 2982.19479  0.04%     -  125s
#      0     0 2982.19479    0   75 2981.00000 2982.19479  0.04%     -  133s
#      0     0 2982.19478    0   58 2981.00000 2982.19478  0.04%     -  153s
#      0     0 2982.19478    0   56 2981.00000 2982.19478  0.04%     -  158s
#      0     0 2982.19478    0   52 2981.00000 2982.19478  0.04%     -  167s
# H    0     0                    2982.0000000 2982.19478  0.01%     -  174s
#      0     0 2982.19478    0   52 2982.00000 2982.19478  0.01%     -  174s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 5
#   MIR: 12
#   RLT: 2
#
# Explored 1 nodes (9011 simplex iterations) in 174.29 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2982 2981 2977
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.982000000000e+03, best bound 2.982000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2x5

# %%
datafile="3x3000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x33188a1d
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2977.0000000
# Presolve removed 23 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 17s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 29s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 40s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 52.51s
# Presolved: 11974 rows, 8985 columns, 13468491 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   3.915673e+06   0.000000e+00     55s
#     1300    2.9799518e+03   0.000000e+00   0.000000e+00     58s
#
# Root relaxation: objective 2.979952e+03, 1300 iterations, 3.79 seconds
# Total elapsed time = 62.18s
# Total elapsed time = 66.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2979.95180    0   89 2977.00000 2979.95180  0.10%     -   68s
# H    0     0                    2979.0000000 2979.95180  0.03%     -   70s
#      0     0 2979.95180    0   89 2979.00000 2979.95180  0.03%     -   70s
#
# Explored 1 nodes (5132 simplex iterations) in 71.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2979 2977
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.979000000000e+03, best bound 2.979000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2.5x1

# %%
datafile="3x3000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x073c111c
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2610.0000000
# Presolve removed 15 rows and 9 columns (presolve time = 7s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 11s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 15 rows and 9 columns
# Presolve time: 40.07s
# Presolved: 11985 rows, 8991 columns, 13486500 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   4.232702e+06   0.000000e+00     43s
#      464    2.6757008e+03   2.702868e+05   0.000000e+00     46s
#     1778    2.6683934e+03   0.000000e+00   0.000000e+00     48s
#
# Root relaxation: objective 2.668393e+03, 1778 iterations, 6.53 seconds
# Total elapsed time = 53.16s
# Total elapsed time = 56.35s
# Total elapsed time = 60.23s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2668.39343    0  165 2610.00000 2668.39343  2.24%     -   68s
# H    0     0                    2664.0000000 2668.39343  0.16%     -   68s
# H    0     0                    2667.0000000 2668.39343  0.05%     -   70s
#      0     0 2668.36467    0  150 2667.00000 2668.36467  0.05%     -   82s
#      0     0 2668.35928    0  153 2667.00000 2668.35928  0.05%     -   93s
#      0     0 2668.35928    0  152 2667.00000 2668.35928  0.05%     -   96s
#      0     0 2668.34968    0  141 2667.00000 2668.34968  0.05%     -  107s
#      0     0 2668.34887    0  142 2667.00000 2668.34887  0.05%     -  113s
#      0     0 2668.34885    0  139 2667.00000 2668.34885  0.05%     -  115s
#      0     0 2668.34794    0  141 2667.00000 2668.34794  0.05%     -  126s
#      0     0 2668.34794    0  139 2667.00000 2668.34794  0.05%     -  130s
#      0     0 2668.34589    0  141 2667.00000 2668.34589  0.05%     -  142s
#      0     0 2668.34347    0  135 2667.00000 2668.34347  0.05%     -  146s
#      0     0 2668.34347    0  139 2667.00000 2668.34347  0.05%     -  149s
#      0     0 2668.33335    0  134 2667.00000 2668.33335  0.05%     -  160s
#      0     0 2668.33335    0  127 2667.00000 2668.33335  0.05%     -  164s
#      0     0 2668.33334    0  127 2667.00000 2668.33334  0.05%     -  172s
#      0     0 2668.33327    0  136 2667.00000 2668.33327  0.05%     -  177s
#      0     0 2668.32902    0  115 2667.00000 2668.32902  0.05%     -  188s
#      0     0 2668.32902    0  111 2667.00000 2668.32902  0.05%     -  196s
#      0     0 2668.32729    0  116 2667.00000 2668.32729  0.05%     -  205s
#      0     0 2668.32729    0  100 2667.00000 2668.32729  0.05%     -  209s
#      0     0 2668.32729    0  110 2667.00000 2668.32729  0.05%     -  220s
#      0     0 2668.32729    0  111 2667.00000 2668.32729  0.05%     -  224s
#      0     0 2668.32729    0   88 2667.00000 2668.32729  0.05%     -  245s
#      0     0 2668.32729    0  103 2667.00000 2668.32729  0.05%     -  250s
#      0     0 2668.32729    0  103 2667.00000 2668.32729  0.05%     -  276s
#      0     0 2668.32729    0   81 2667.00000 2668.32729  0.05%     -  297s
#      0     2 2668.32729    0   79 2667.00000 2668.32729  0.05%     -  315s
#      3     8 2668.21293    2   78 2667.00000 2668.32729  0.05%   196  320s
#      7    12     cutoff    3      2667.00000 2668.31923  0.05%  98.3  325s
#     19    24 2668.31338    5   72 2667.00000 2668.31923  0.05%  56.6  333s
#     25    30 2668.30949    6   72 2667.00000 2668.31923  0.05%  47.0  335s
#     31    36 2668.30949    7   68 2667.00000 2668.31923  0.05%  39.0  340s
# H   33    36                    2667.9999999 2668.31923  0.01%  36.7  340s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 93
#   Clique: 2
#   MIR: 48
#
# Explored 37 nodes (21704 simplex iterations) in 341.57 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2668 2667 2664 2610
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.667999999975e+03, best bound 2.668000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2.5x2

# %%
datafile="3x3000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x3e4765a3
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2613.0000000
# Presolve removed 15 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 17s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 15 rows and 9 columns
# Presolve time: 37.18s
# Presolved: 11985 rows, 8991 columns, 13486488 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   4.239471e+06   0.000000e+00     40s
#      133    2.9970000e+03   2.215992e+06   0.000000e+00     41s
#     1574    2.6718606e+03   0.000000e+00   0.000000e+00     44s
#
# Root relaxation: objective 2.671861e+03, 1574 iterations, 5.75 seconds
# Total elapsed time = 49.43s
# Total elapsed time = 52.56s
# Total elapsed time = 56.20s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2671.86065    0   45 2613.00000 2671.86065  2.25%     -   57s
# H    0     0                    2669.0000000 2671.86065  0.11%     -   58s
# H    0     0                    2670.0000000 2671.86065  0.07%     -   59s
# H    0     0                    2671.0000000 2671.86065  0.03%     -   61s
#      0     0 2671.86065    0   45 2671.00000 2671.86065  0.03%     -   61s
#
# Explored 1 nodes (6627 simplex iterations) in 61.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2671 2670 2669 2613
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.671000000000e+03, best bound 2.671000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2.5x3

# %%
datafile="3x3000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x96c587ca
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2601.0000000
# Presolve removed 29 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 17s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 20s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 29 rows and 15 columns
# Presolve time: 37.31s
# Presolved: 11971 rows, 8985 columns, 13468491 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   4.272164e+06   0.000000e+00     40s
#      136    2.9950000e+03   1.948834e+06   0.000000e+00     41s
#     1681    2.6662399e+03   0.000000e+00   0.000000e+00     44s
#
# Root relaxation: objective 2.666240e+03, 1681 iterations, 5.26 seconds
# Total elapsed time = 48.57s
# Total elapsed time = 51.61s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2666.23994    0  121 2601.00000 2666.23994  2.51%     -   55s
# H    0     0                    2663.0000000 2666.23994  0.12%     -   56s
# H    0     0                    2664.0000000 2666.23994  0.08%     -   57s
# H    0     0                    2665.0000000 2666.23994  0.05%     -   58s
#      0     0 2666.18568    0  109 2665.00000 2666.18568  0.04%     -   68s
#      0     0 2666.11249    0  103 2665.00000 2666.11249  0.04%     -   75s
#      0     0 2666.11249    0  103 2665.00000 2666.11249  0.04%     -   77s
#      0     0 2666.10323    0   96 2665.00000 2666.10323  0.04%     -   89s
#      0     0 2666.04463    0   97 2665.00000 2666.04463  0.04%     -   94s
#      0     0 2666.04463    0   95 2665.00000 2666.04463  0.04%     -   96s
#      0     0 2666.04323    0   87 2665.00000 2666.04323  0.04%     -  107s
#      0     0 2666.04323    0   89 2665.00000 2666.04323  0.04%     -  112s
#      0     0 2666.04308    0   83 2665.00000 2666.04308  0.04%     -  122s
#      0     0 2666.04308    0   76 2665.00000 2666.04308  0.04%     -  126s
#      0     0 2666.04197    0   77 2665.00000 2666.04197  0.04%     -  136s
#      0     0 2666.04197    0   77 2665.00000 2666.04197  0.04%     -  141s
#      0     0 2666.04197    0   78 2665.00000 2666.04197  0.04%     -  148s
#      0     0 2666.04197    0   79 2665.00000 2666.04197  0.04%     -  152s
#      0     0 2666.04197    0   67 2665.00000 2666.04197  0.04%     -  167s
#      0     0 2666.02770    0   69 2665.00000 2666.02770  0.04%     -  174s
#      0     0 2666.02770    0   71 2665.00000 2666.02770  0.04%     -  176s
#      0     0     cutoff    0      2665.00000 2665.00000  0.00%     -  181s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 20
#   MIR: 54
#   StrongCG: 16
#   RLT: 1
#
# Explored 1 nodes (7630 simplex iterations) in 181.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2665 2664 2663 2601
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.665000000000e+03, best bound 2.665000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2.5x4

# %%
datafile="3x3000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x0180f5d8
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2603.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 17s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 25s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 37.05s
# Presolved: 11978 rows, 8988 columns, 13477494 nonzeros
# Variable types: 0 continuous, 8988 integer (8988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.289641e+06   0.000000e+00     39s
#      129    2.9960000e+03   1.768064e+06   0.000000e+00     40s
#     1773    2.6661634e+03   0.000000e+00   0.000000e+00     44s
#
# Root relaxation: objective 2.666163e+03, 1773 iterations, 5.20 seconds
# Total elapsed time = 48.41s
# Total elapsed time = 51.53s
# Total elapsed time = 55.75s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2666.16338    0  146 2603.00000 2666.16338  2.43%     -   56s
# H    0     0                    2663.0000000 2666.16338  0.12%     -   57s
# H    0     0                    2664.0000000 2666.16338  0.08%     -   59s
#      0     0 2665.92314    0  127 2664.00000 2665.92314  0.07%     -   69s
# H    0     0                    2665.0000000 2665.92314  0.03%     -   79s
#      0     0 2665.92314    0  127 2665.00000 2665.92314  0.03%     -   79s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 5
#   MIR: 44
#
# Explored 1 nodes (5768 simplex iterations) in 79.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2665 2664 2663 2603
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.665000000000e+03, best bound 2.665000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x2.5x5

# %%
datafile="3x3000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x80ca7457
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2604.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 17s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 14 rows and 6 columns
# Presolve time: 37.09s
# Presolved: 11986 rows, 8994 columns, 13495488 nonzeros
# Variable types: 0 continuous, 8994 integer (8994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   4.334524e+06   0.000000e+00     39s
#      134    2.9980000e+03   2.341586e+06   0.000000e+00     40s
#     1650    2.6641531e+03   0.000000e+00   0.000000e+00     44s
#
# Root relaxation: objective 2.664153e+03, 1650 iterations, 5.47 seconds
# Total elapsed time = 48.76s
# Total elapsed time = 51.07s
# Total elapsed time = 57.33s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2664.15311    0  145 2604.00000 2664.15311  2.31%     -   59s
# H    0     0                    2661.0000000 2664.15311  0.12%     -   59s
# H    0     0                    2662.0000000 2664.15311  0.08%     -   61s
# H    0     0                    2663.0000000 2664.15311  0.04%     -   62s
#      0     0     cutoff    0      2663.00000 2663.00000  0.00%     -   72s
#
# Cutting planes:
#   Gomory: 36
#   Cover: 34
#   MIR: 157
#   StrongCG: 10
#   RLT: 2
#
# Explored 1 nodes (6700 simplex iterations) in 72.68 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2663 2662 2661 2604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.663000000000e+03, best bound 2.663000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3x1

# %%
datafile="3x3000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xb51632c9
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2323.0000000
# Presolve removed 17 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 17s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 17 rows and 6 columns
# Presolve time: 37.35s
# Presolved: 11983 rows, 8994 columns, 13495473 nonzeros
# Variable types: 0 continuous, 8994 integer (8994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   4.585273e+06   0.000000e+00     40s
#      146    2.9980000e+03   2.186738e+06   0.000000e+00     41s
#     1144    2.4189989e+03   1.397034e+04   0.000000e+00     45s
#     1841    2.4184656e+03   0.000000e+00   0.000000e+00     46s
#
# Root relaxation: objective 2.418466e+03, 1841 iterations, 7.09 seconds
# Total elapsed time = 52.59s
# Total elapsed time = 55.37s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2418.46558    0  120 2323.00000 2418.46558  4.11%     -   57s
# H    0     0                    2411.0000000 2418.46558  0.31%     -   57s
# H    0     0                    2416.0000000 2418.46558  0.10%     -   58s
# H    0     0                    2417.0000000 2418.46558  0.06%     -   61s
#      0     0 2418.45899    0  131 2417.00000 2418.45899  0.06%     -   70s
#      0     0 2418.39979    0  124 2417.00000 2418.39979  0.06%     -   81s
#      0     0 2418.39214    0  121 2417.00000 2418.39214  0.06%     -   84s
#      0     0 2418.39214    0  121 2417.00000 2418.39214  0.06%     -   86s
#      0     0 2418.05125    0   98 2417.00000 2418.05125  0.04%     -   97s
#      0     0 2418.03977    0   89 2417.00000 2418.03977  0.04%     -  102s
#      0     0 2418.03973    0   91 2417.00000 2418.03973  0.04%     -  105s
#      0     0 2418.03973    0   97 2417.00000 2418.03973  0.04%     -  114s
#      0     0 2418.03970    0   96 2417.00000 2418.03970  0.04%     -  117s
#      0     0 infeasible    0      2417.00000 2417.00000  0.00%     -  126s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 15
#   MIR: 78
#   StrongCG: 7
#   RLT: 1
#
# Explored 1 nodes (5751 simplex iterations) in 126.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2417 2416 2411 2323
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.417000000000e+03, best bound 2.417000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3x2

# %%
datafile="3x3000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x7a17bc54
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2335.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 17s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 25s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 37.02s
# Presolved: 11978 rows, 8988 columns, 13477497 nonzeros
# Variable types: 0 continuous, 8988 integer (8988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.579335e+06   0.000000e+00     39s
#      156    2.6230610e+03   4.929633e+05   0.000000e+00     40s
#     2067    2.4232347e+03   0.000000e+00   0.000000e+00     45s
#
# Root relaxation: objective 2.423237e+03, 2067 iterations, 6.77 seconds
# Total elapsed time = 50.93s
# Total elapsed time = 56.93s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2423.23743    0   62 2335.00000 2423.23743  3.78%     -   59s
# H    0     0                    2418.0000000 2423.23743  0.22%     -   59s
# H    0     0                    2420.0000000 2423.23743  0.13%     -   60s
# H    0     0                    2421.0000000 2423.23743  0.09%     -   61s
# H    0     0                    2422.0000000 2423.23743  0.05%     -   63s
#      0     0 2423.23703    0   63 2422.00000 2423.23703  0.05%     -   71s
#      0     0 2423.18007    0   53 2422.00000 2423.18007  0.05%     -   79s
#      0     0 2423.18006    0   47 2422.00000 2423.18006  0.05%     -   82s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 10
#   MIR: 97
#   StrongCG: 27
#
# Explored 1 nodes (6915 simplex iterations) in 89.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2422 2421 2420 ... 2335
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.422000000000e+03, best bound 2.422000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3x3

# %%
datafile="3x3000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x9546d970
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2329.0000000
# Presolve removed 8 rows and 6 columns (presolve time = 6s) ...
# Presolve removed 8 rows and 6 columns (presolve time = 17s) ...
# Presolve removed 8 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 8 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 8 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 8 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 8 rows and 6 columns
# Presolve time: 37.24s
# Presolved: 11992 rows, 8994 columns, 13495503 nonzeros
# Variable types: 0 continuous, 8994 integer (8994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   4.512267e+06   0.000000e+00     40s
#      147    2.9980000e+03   2.702198e+06   0.000000e+00     41s
#     1809    2.4241451e+03   0.000000e+00   0.000000e+00     45s
#
# Root relaxation: objective 2.424145e+03, 1809 iterations, 6.20 seconds
# Total elapsed time = 48.92s
# Total elapsed time = 52.08s
# Total elapsed time = 55.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2424.14505    0   76 2329.00000 2424.14505  4.09%     -   57s
# H    0     0                    2420.0000000 2424.14505  0.17%     -   57s
# H    0     0                    2422.0000000 2424.14505  0.09%     -   59s
# H    0     0                    2423.0000000 2424.14505  0.05%     -   61s
#      0     0 2424.07218    0   92 2423.00000 2424.07218  0.04%     -  105s
#      0     0 2424.06608    0   91 2423.00000 2424.06608  0.04%     -  114s
#      0     0 2424.06608    0   85 2423.00000 2424.06608  0.04%     -  117s
#      0     0 2424.06608    0   89 2423.00000 2424.06608  0.04%     -  125s
#      0     0 2424.01638    0   87 2423.00000 2424.01638  0.04%     -  131s
#      0     0 2424.01447    0   74 2423.00000 2424.01447  0.04%     -  135s
#      0     0 2424.01447    0   76 2423.00000 2424.01447  0.04%     -  138s
#      0     0 2424.01447    0   81 2423.00000 2424.01447  0.04%     -  145s
#      0     0 2424.01447    0   82 2423.00000 2424.01447  0.04%     -  151s
#      0     0 2424.01447    0   79 2423.00000 2424.01447  0.04%     -  159s
#      0     0 2424.01447    0   75 2423.00000 2424.01447  0.04%     -  164s
#      0     0 2424.01447    0   57 2423.00000 2424.01447  0.04%     -  182s
#      0     0 2424.01447    0   64 2423.00000 2424.01447  0.04%     -  188s
#      0     0 2424.01447    0   50 2423.00000 2424.01447  0.04%     -  205s
#      0     0 2424.01447    0   61 2423.00000 2424.01447  0.04%     -  210s
#      0     0 2424.01447    0   67 2423.00000 2424.01447  0.04%     -  222s
#      0     0 2424.01375    0   66 2423.00000 2424.01375  0.04%     -  227s
#      0     0 2424.00616    0   64 2423.00000 2424.00616  0.04%     -  231s
#      0     0 2424.00616    0   70 2423.00000 2424.00616  0.04%     -  233s
#      0     0 2424.00616    0   57 2423.00000 2424.00616  0.04%     -  252s
#      0     0 2424.00616    0   68 2423.00000 2424.00616  0.04%     -  257s
#      0     0 2424.00616    0   70 2423.00000 2424.00616  0.04%     -  264s
#      0     0 2424.00616    0   73 2423.00000 2424.00616  0.04%     -  270s
#      0     0 2424.00616    0   62 2423.00000 2424.00616  0.04%     -  309s
#      0     0 2424.00616    0   82 2423.00000 2424.00616  0.04%     -  315s
#      0     0 2424.00616    0   66 2423.00000 2424.00616  0.04%     -  327s
#      0     0 2424.00616    0   66 2423.00000 2424.00616  0.04%     -  334s
#      0     0 2424.00616    0   88 2423.00000 2424.00616  0.04%     -  385s
#      0     0 2424.00616    0   77 2423.00000 2424.00616  0.04%     -  417s
#      0     0 2424.00616    0   83 2423.00000 2424.00616  0.04%     -  422s
#      0     0 2424.00616    0   82 2423.00000 2424.00616  0.04%     -  423s
#      0     0 2424.00157    0   74 2423.00000 2424.00157  0.04%     -  425s
#      0     0 2424.00157    0   62 2423.00000 2424.00157  0.04%     -  431s
#      0     0 2424.00157    0   62 2423.00000 2424.00157  0.04%     -  434s
#      0     0 2424.00157    0   62 2423.00000 2424.00157  0.04%     -  439s
#      0     0 2424.00157    0   65 2423.00000 2424.00157  0.04%     -  442s
#      0     0 2424.00157    0   53 2423.00000 2424.00157  0.04%     -  451s
#      0     0 2424.00157    0   63 2423.00000 2424.00157  0.04%     -  455s
#      0     0 2424.00157    0   51 2423.00000 2424.00157  0.04%     -  466s
#      0     0 2424.00157    0   63 2423.00000 2424.00157  0.04%     -  469s
#      0     0 2424.00157    0   49 2423.00000 2424.00157  0.04%     -  478s
#      0     0     cutoff    0      2423.00000 2423.00000  0.00%     -  480s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 4
#   MIR: 42
#   RLT: 1
#
# Explored 1 nodes (34475 simplex iterations) in 480.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2423 2422 2422 ... 2329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.423000000000e+03, best bound 2.423000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3x4

# %%
datafile="3x3000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xee96d214
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2338.0000000
# Presolve removed 25 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 17s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 25s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 25 rows and 12 columns
# Presolve time: 37.18s
# Presolved: 11975 rows, 8988 columns, 13477482 nonzeros
# Variable types: 0 continuous, 8988 integer (8988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.542019e+06   0.000000e+00     40s
#      131    2.9960000e+03   2.951409e+06   0.000000e+00     41s
#     1661    2.4265182e+03   0.000000e+00   0.000000e+00     45s
#
# Root relaxation: objective 2.426518e+03, 1661 iterations, 6.59 seconds
# Total elapsed time = 51.52s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2426.51819    0   81 2338.00000 2426.51819  3.79%     -   55s
# H    0     0                    2417.0000000 2426.51819  0.39%     -   55s
# H    0     0                    2423.0000000 2426.51819  0.15%     -   55s
# H    0     0                    2424.0000000 2426.51819  0.10%     -   58s
#      0     0 2426.34203    0   91 2424.00000 2426.34203  0.10%     -   67s
# H    0     0                    2425.0000000 2426.34203  0.06%     -   75s
#      0     0 2426.33667    0   89 2425.00000 2426.33667  0.06%     -   77s
#      0     0 2426.25701    0   81 2425.00000 2426.25701  0.05%     -   81s
#      0     0 2426.25701    0   76 2425.00000 2426.25701  0.05%     -   83s
#      0     0 2426.15457    0   65 2425.00000 2426.15457  0.05%     -   94s
#      0     0 2426.15437    0   75 2425.00000 2426.15437  0.05%     -   99s
#      0     0 2426.03143    0   66 2425.00000 2426.03143  0.04%     -  110s
#      0     0 2426.03143    0   63 2425.00000 2426.03143  0.04%     -  115s
#      0     0 2426.03143    0   64 2425.00000 2426.03143  0.04%     -  124s
#      0     0 2426.03143    0   64 2425.00000 2426.03143  0.04%     -  129s
#      0     0     cutoff    0      2425.00000 2425.00000  0.00%     -  137s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 9
#   MIR: 51
#   StrongCG: 2
#   RLT: 3
#
# Explored 1 nodes (6674 simplex iterations) in 137.48 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2425 2424 2423 ... 2338
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.425000000000e+03, best bound 2.425000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3x5

# %%
datafile="3x3000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x5183a840
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2329.0000000
# Presolve removed 24 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 19s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 24 rows and 9 columns
# Presolve time: 39.19s
# Presolved: 11976 rows, 8991 columns, 13486464 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   4.508411e+06   0.000000e+00     42s
#      864    2.4248413e+03   4.743630e+04   0.000000e+00     46s
#     1876    2.4239989e+03   0.000000e+00   0.000000e+00     47s
#
# Root relaxation: objective 2.423999e+03, 1876 iterations, 6.59 seconds
# Total elapsed time = 51.05s
# Total elapsed time = 56.58s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2423.99887    0  134 2329.00000 2423.99887  4.08%     -   61s
# H    0     0                    2415.0000000 2423.99887  0.37%     -   62s
# H    0     0                    2420.0000000 2423.99887  0.17%     -   62s
# H    0     0                    2421.0000000 2423.99887  0.12%     -   63s
# H    0     0                    2423.0000000 2423.99887  0.04%     -   65s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 9
#   MIR: 33
#   StrongCG: 2
#
# Explored 1 nodes (6393 simplex iterations) in 72.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2423 2421 2420 ... 2329
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.423000000000e+03, best bound 2.423000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3.5x1

# %%
datafile="3x3000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x2d6829df
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2128.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 18s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 20s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 25s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 30s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 34 rows and 21 columns
# Presolve time: 38.35s
# Presolved: 11966 rows, 8979 columns, 13450521 nonzeros
# Variable types: 0 continuous, 8979 integer (8979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9930000e+03   4.708676e+06   0.000000e+00     41s
#      656    2.2526383e+03   5.409180e+05   0.000000e+00     45s
#     2002    2.2310275e+03   0.000000e+00   0.000000e+00     48s
#
# Root relaxation: objective 2.231028e+03, 2002 iterations, 8.05 seconds
# Total elapsed time = 51.54s
# Total elapsed time = 57.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2231.02752    0  173 2128.00000 2231.02752  4.84%     -   58s
# H    0     0                    2223.0000000 2231.02752  0.36%     -   59s
# H    0     0                    2229.0000000 2231.02752  0.09%     -   61s
# H    0     0                    2230.0000000 2231.02752  0.05%     -   62s
#      0     0     cutoff    0      2230.00000 2230.00000  0.00%     -   97s
#
# Cutting planes:
#   Gomory: 28
#   Cover: 4
#   MIR: 97
#   StrongCG: 6
#
# Explored 1 nodes (5019 simplex iterations) in 97.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2230 2229 2223 2128
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.230000000000e+03, best bound 2.230000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3.5x2

# %%
datafile="3x3000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xda68b894
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2122.0000000
# Presolve removed 24 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 18 columns (presolve time = 17s) ...
# Presolve removed 24 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 24 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 24 rows and 18 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 24 rows and 18 columns
# Presolve time: 37.23s
# Presolved: 11976 rows, 8982 columns, 13459530 nonzeros
# Variable types: 0 continuous, 8982 integer (8982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   4.713365e+06   0.000000e+00     40s
#      140    2.9940000e+03   3.011125e+06   0.000000e+00     41s
#     1196    2.2208693e+03   3.361371e+04   0.000000e+00     46s
#     2286    2.2201176e+03   0.000000e+00   0.000000e+00     47s
#
# Root relaxation: objective 2.220118e+03, 2286 iterations, 8.67 seconds
# Total elapsed time = 50.98s
# Total elapsed time = 56.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2220.11764    0  179 2122.00000 2220.11764  4.62%     -   59s
# H    0     0                    2209.0000000 2220.11764  0.50%     -   59s
# H    0     0                    2216.0000000 2220.11764  0.19%     -   59s
# H    0     0                    2217.0000000 2220.11764  0.14%     -   61s
# H    0     0                    2219.0000000 2220.11764  0.05%     -   65s
#      0     0 2220.06996    0  179 2219.00000 2220.06996  0.05%     -  106s
#      0     0 2220.06551    0  171 2219.00000 2220.06551  0.05%     -  114s
#      0     0 2220.01498    0  166 2219.00000 2220.01498  0.05%     -  117s
#      0     0 2220.01498    0  168 2219.00000 2220.01498  0.05%     -  120s
#
# Cutting planes:
#   Gomory: 29
#   Cover: 12
#   MIR: 208
#   StrongCG: 9
#   GUB cover: 3
#   RLT: 1
#
# Explored 1 nodes (5463 simplex iterations) in 127.47 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2219 2217 2216 ... 2122
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.219000000000e+03, best bound 2.219000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3.5x3

# %%
datafile="3x3000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xe52a5957
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2130.0000000
# Presolve removed 42 rows and 27 columns (presolve time = 6s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 13s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 15s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 24s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 25s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 30s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 35s) ...
# Presolve removed 45 rows and 27 columns (presolve time = 40s) ...
# Presolve removed 45 rows and 27 columns
# Presolve time: 44.13s
# Presolved: 11955 rows, 8973 columns, 13432551 nonzeros
# Variable types: 0 continuous, 8973 integer (8973 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9910000e+03   4.745691e+06   0.000000e+00     47s
#      663    2.2566606e+03   1.845903e+05   0.000000e+00     51s
#     2167    2.2278233e+03   0.000000e+00   0.000000e+00     53s
#
# Root relaxation: objective 2.227823e+03, 2167 iterations, 7.89 seconds
# Total elapsed time = 57.34s
# Total elapsed time = 60.12s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2227.82327    0  196 2130.00000 2227.82327  4.59%     -   62s
# H    0     0                    2225.0000000 2227.82327  0.13%     -   62s
# H    0     0                    2226.0000000 2227.82327  0.08%     -   65s
#      0     0 2227.71880    0  172 2226.00000 2227.71880  0.08%     -  113s
#      0     0 2227.52773    0  146 2226.00000 2227.52773  0.07%     -  126s
#      0     0 2227.52773    0  144 2226.00000 2227.52773  0.07%     -  128s
#      0     0 2227.51850    0  139 2226.00000 2227.51850  0.07%     -  139s
#      0     0 2227.51850    0  135 2226.00000 2227.51850  0.07%     -  145s
#      0     0 2227.51645    0  140 2226.00000 2227.51645  0.07%     -  156s
# H    0     0                    2227.0000000 2227.51645  0.02%     -  162s
#      0     0 2227.51645    0  140 2227.00000 2227.51645  0.02%     -  162s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 11
#   MIR: 40
#   StrongCG: 4
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (6298 simplex iterations) in 163.13 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2227 2226 2225 2130
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.227000000000e+03, best bound 2.227000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3.5x4

# %%
datafile="3x3000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x4d5a7fbb
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2119.0000000
# Presolve removed 29 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 17s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 20s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 29 rows and 15 columns
# Presolve time: 38.50s
# Presolved: 11971 rows, 8985 columns, 13468485 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   4.676872e+06   0.000000e+00     41s
#      660    2.2667013e+03   5.399815e+05   0.000000e+00     45s
#     2076    2.2271195e+03   0.000000e+00   0.000000e+00     48s
#
# Root relaxation: objective 2.227119e+03, 2076 iterations, 8.07 seconds
# Total elapsed time = 51.87s
# Total elapsed time = 57.79s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2227.11946    0  130 2119.00000 2227.11946  5.10%     -   59s
# H    0     0                    2221.0000000 2227.11946  0.28%     -   60s
# H    0     0                    2224.0000000 2227.11946  0.14%     -   62s
# H    0     0                    2225.0000000 2227.11946  0.10%     -   65s
#      0     0 2227.11946    0  124 2225.00000 2227.11946  0.10%     -  114s
# H    0     0                    2226.0000000 2227.11946  0.05%     -  123s
#      0     0     cutoff    0      2226.00000 2226.00000  0.00%     -  124s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 48
#   MIR: 106
#   StrongCG: 62
#   GUB cover: 5
#   RLT: 3
#
# Explored 1 nodes (4542 simplex iterations) in 124.32 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2226 2225 2224 ... 2119
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.226000000000e+03, best bound 2.226000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x3.5x5

# %%
datafile="3x3000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x9555ff34
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2134.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 17s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 30s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 37.15s
# Presolved: 11970 rows, 8982 columns, 13459512 nonzeros
# Variable types: 0 continuous, 8982 integer (8982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   4.709115e+06   0.000000e+00     40s
#      135    2.9940000e+03   2.812618e+06   0.000000e+00     41s
#     1103    2.2342938e+03   1.666866e+04   0.000000e+00     45s
#     1986    2.2330991e+03   0.000000e+00   0.000000e+00     46s
#
# Root relaxation: objective 2.233099e+03, 1986 iterations, 7.70 seconds
# Total elapsed time = 50.15s
# Total elapsed time = 55.70s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2233.09912    0  134 2134.00000 2233.09912  4.64%     -   59s
# H    0     0                    2228.0000000 2233.09912  0.23%     -   59s
# H    0     0                    2230.0000000 2233.09912  0.14%     -   61s
# H    0     0                    2231.0000000 2233.09912  0.09%     -   65s
#      0     0 2232.96139    0  142 2231.00000 2232.96139  0.09%     -   75s
#      0     0 2232.94546    0  140 2231.00000 2232.94546  0.09%     -   88s
#      0     0 2232.69282    0  121 2231.00000 2232.69282  0.08%     -   99s
#      0     0 2232.68777    0  120 2231.00000 2232.68777  0.08%     -  102s
#      0     0 2232.68777    0  120 2231.00000 2232.68777  0.08%     -  105s
#      0     0 2232.60449    0  124 2231.00000 2232.60449  0.07%     -  116s
#      0     0 2232.60443    0  116 2231.00000 2232.60443  0.07%     -  120s
#      0     0 2232.59101    0  125 2231.00000 2232.59101  0.07%     -  131s
#      0     0 2232.58962    0  122 2231.00000 2232.58962  0.07%     -  134s
#      0     0 2232.58962    0  125 2231.00000 2232.58962  0.07%     -  137s
#      0     0 2232.58837    0  106 2231.00000 2232.58837  0.07%     -  147s
#      0     0 2232.58490    0  101 2231.00000 2232.58490  0.07%     -  150s
#      0     0 2232.58441    0  112 2231.00000 2232.58441  0.07%     -  153s
#      0     0 2232.58441    0  114 2231.00000 2232.58441  0.07%     -  155s
#      0     0 2232.57384    0   89 2231.00000 2232.57384  0.07%     -  167s
#      0     0 2232.57384    0   81 2231.00000 2232.57384  0.07%     -  171s
#      0     0 2232.57384    0   95 2231.00000 2232.57384  0.07%     -  178s
# H    0     0                    2232.0000000 2232.57384  0.03%     -  183s
#      0     0 2232.57384    0   95 2232.00000 2232.57384  0.03%     -  183s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 2
#   MIR: 39
#
# Explored 1 nodes (8445 simplex iterations) in 183.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2232 2231 2230 ... 2134
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.232000000000e+03, best bound 2.232000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4x1

# %%
datafile="3x3000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x2b60d675
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1958.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 6s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 17s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 20s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 30s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 37.20s
# Presolved: 11974 rows, 8985 columns, 13468503 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   4.898986e+06   0.000000e+00     40s
#      143    2.9950000e+03   3.434452e+06   0.000000e+00     41s
#     1659    2.0747891e+03   2.562501e+03   0.000000e+00     45s
#     2236    2.0744453e+03   0.000000e+00   0.000000e+00     46s
#
# Root relaxation: objective 2.074445e+03, 2236 iterations, 7.14 seconds
# Total elapsed time = 51.42s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2074.44528    0  155 1958.00000 2074.44528  5.95%     -   53s
# H    0     0                    2061.0000000 2074.44528  0.65%     -   54s
# H    0     0                    2072.0000000 2074.44528  0.12%     -   54s
# H    0     0                    2073.0000000 2074.44528  0.07%     -   56s
#      0     0 2074.42901    0  134 2073.00000 2074.42901  0.07%     -  107s
# H    0     0                    2074.0000000 2074.42901  0.02%     -  117s
#      0     0 2074.42901    0  134 2074.00000 2074.42901  0.02%     -  117s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 3
#   MIR: 25
#   StrongCG: 1
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (5108 simplex iterations) in 117.96 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2074 2073 2072 ... 1958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.074000000000e+03, best bound 2.074000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4x2

# %%
datafile="3x3000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xbae49413
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1962.0000000
# Presolve removed 31 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 16s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 26s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 30s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 40s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 45s) ...
# Presolve removed 34 rows and 21 columns
# Presolve time: 47.43s
# Presolved: 11966 rows, 8979 columns, 13450527 nonzeros
# Variable types: 0 continuous, 8979 integer (8979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9930000e+03   4.924656e+06   0.000000e+00     50s
#      131    2.9930000e+03   3.355296e+06   0.000000e+00     51s
#     1011    2.0786476e+03   9.423969e+04   0.000000e+00     56s
#     2183    2.0716073e+03   0.000000e+00   0.000000e+00     58s
#
# Root relaxation: objective 2.071607e+03, 2183 iterations, 8.74 seconds
# Total elapsed time = 60.84s
# Total elapsed time = 65.97s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2071.60728    0  122 1962.00000 2071.60728  5.59%     -   67s
# H    0     0                    2063.0000000 2071.60728  0.42%     -   68s
# H    0     0                    2067.0000000 2071.60728  0.22%     -   68s
# H    0     0                    2069.0000000 2071.60728  0.13%     -   70s
# H    0     0                    2070.0000000 2071.60728  0.08%     -   72s
#      0     0 2071.52410    0  112 2070.00000 2071.52410  0.07%     -  116s
#      0     0 2071.45558    0  133 2070.00000 2071.45558  0.07%     -  128s
#      0     0 2071.35726    0  127 2070.00000 2071.35726  0.07%     -  132s
#      0     0 2071.35726    0  127 2070.00000 2071.35726  0.07%     -  134s
#      0     0 2071.20930    0  104 2070.00000 2071.20930  0.06%     -  144s
#      0     0 2071.20325    0   84 2070.00000 2071.20325  0.06%     -  151s
#      0     0 2071.20325    0   77 2070.00000 2071.20325  0.06%     -  154s
#      0     0 2071.20325    0   80 2070.00000 2071.20325  0.06%     -  162s
#      0     0 2071.12513    0   78 2070.00000 2071.12513  0.05%     -  168s
#      0     0 infeasible    0      2070.00000 2070.00000  0.00%     -  170s
#
# Cutting planes:
#   Gomory: 10
#   MIR: 43
#   StrongCG: 2
#   RLT: 2
#
# Explored 1 nodes (5191 simplex iterations) in 170.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2070 2069 2067 ... 1962
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.070000000000e+03, best bound 2.070000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4x3

# %%
datafile="3x3000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x759fac1f
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1964.0000000
# Presolve removed 49 rows and 30 columns (presolve time = 6s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 14s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 16s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 25s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 25s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 30s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 35s) ...
# Presolve removed 49 rows and 30 columns (presolve time = 40s) ...
# Presolve removed 49 rows and 30 columns
# Presolve time: 44.92s
# Presolved: 11951 rows, 8970 columns, 13423575 nonzeros
# Variable types: 0 continuous, 8970 integer (8970 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9900000e+03   4.884876e+06   0.000000e+00     47s
#      375    2.1693376e+03   8.105663e+05   0.000000e+00     50s
#     2166    2.0807259e+03   0.000000e+00   0.000000e+00     55s
#
# Root relaxation: objective 2.080729e+03, 2166 iterations, 8.80 seconds
# Total elapsed time = 60.97s
# Total elapsed time = 65.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2080.72896    0  133 1964.00000 2080.72896  5.94%     -   66s
# H    0     0                    2066.0000000 2080.72896  0.71%     -   66s
# H    0     0                    2078.0000000 2080.72896  0.13%     -   67s
#      0     0 2080.68283    0  143 2078.00000 2080.68283  0.13%     -  117s
# H    0     0                    2079.0000000 2080.68283  0.08%     -  128s
#      0     0 2080.68095    0  142 2079.00000 2080.68095  0.08%     -  130s
#      0     0 2080.68095    0  144 2079.00000 2080.68095  0.08%     -  132s
#      0     0 2080.50651    0  124 2079.00000 2080.50651  0.07%     -  144s
#      0     0 2080.49508    0  109 2079.00000 2080.49508  0.07%     -  150s
#      0     0 2080.49450    0  115 2079.00000 2080.49450  0.07%     -  153s
#      0     0 2080.49431    0  116 2079.00000 2080.49431  0.07%     -  155s
#      0     0 2080.42282    0   91 2079.00000 2080.42282  0.07%     -  168s
#      0     0 2080.42282    0   93 2079.00000 2080.42282  0.07%     -  171s
#      0     0 2080.42282    0  107 2079.00000 2080.42282  0.07%     -  181s
#      0     0 2080.41792    0  108 2079.00000 2080.41792  0.07%     -  186s
#      0     0 2080.41792    0   98 2079.00000 2080.41792  0.07%     -  189s
#      0     0 2080.41792    0   94 2079.00000 2080.41792  0.07%     -  203s
#      0     0 2080.41142    0   93 2079.00000 2080.41142  0.07%     -  213s
#      0     0 2080.41142    0   91 2079.00000 2080.41142  0.07%     -  216s
#      0     0 2080.41142    0   89 2079.00000 2080.41142  0.07%     -  226s
#      0     0 2080.41142    0   82 2079.00000 2080.41142  0.07%     -  230s
#      0     0 2080.41142    0   98 2079.00000 2080.41142  0.07%     -  240s
#      0     0 2080.41142    0   88 2079.00000 2080.41142  0.07%     -  244s
#      0     0 2080.40644    0   68 2079.00000 2080.40644  0.07%     -  263s
#      0     0 2080.40471    0   73 2079.00000 2080.40471  0.07%     -  269s
#      0     0 2080.40471    0   83 2079.00000 2080.40471  0.07%     -  272s
#      0     0 2080.39639    0   85 2079.00000 2080.39639  0.07%     -  282s
#      0     0 2080.39639    0   92 2079.00000 2080.39639  0.07%     -  288s
#      0     0 2080.39639    0   89 2079.00000 2080.39639  0.07%     -  335s
#      0     0 2080.39639    0   99 2079.00000 2080.39639  0.07%     -  342s
#      0     0 2080.39639    0   89 2079.00000 2080.39639  0.07%     -  360s
#      0     0 2080.39639    0   96 2079.00000 2080.39639  0.07%     -  368s
#      0     0 2080.39639    0   81 2079.00000 2080.39639  0.07%     -  384s
#      0     0 2080.39639    0   79 2079.00000 2080.39639  0.07%     -  390s
#      0     2 2080.39639    0   78 2079.00000 2080.39639  0.07%     -  403s
#      1     2 infeasible    1      2079.00000 2080.39639  0.07%   462  405s
#      5     8 2080.39639    3   88 2079.00000 2080.39639  0.07%   115  410s
#      9    14 2080.39639    4   85 2079.00000 2080.39639  0.07%  80.0  421s
#     21    26 2080.39639    5   93 2079.00000 2080.39639  0.07%  46.3  426s
#     27    32 2080.39639    6   91 2079.00000 2080.39639  0.07%  39.8  438s
# H   29    32                    2080.0000000 2080.39639  0.02%  37.2  438s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 51
#   MIR: 73
#   StrongCG: 4
#   GUB cover: 5
#   RLT: 1
#
# Explored 33 nodes (15634 simplex iterations) in 438.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2080 2079 2078 ... 1964
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.080000000000e+03, best bound 2.080000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4x4

# %%
datafile="3x3000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x26e67f42
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1970.0000000
# Presolve removed 16 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 16 rows and 12 columns (presolve time = 17s) ...
# Presolve removed 16 rows and 12 columns (presolve time = 20s) ...
# Presolve removed 16 rows and 12 columns (presolve time = 25s) ...
# Presolve removed 16 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 16 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 16 rows and 12 columns
# Presolve time: 37.48s
# Presolved: 11984 rows, 8988 columns, 13477521 nonzeros
# Variable types: 0 continuous, 8988 integer (8988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   4.912212e+06   0.000000e+00     40s
#      145    2.3048502e+03   5.264548e+05   0.000000e+00     41s
#     1103    2.0849244e+03   2.026016e+05   0.000000e+00     46s
#     2103    2.0740516e+03   0.000000e+00   0.000000e+00     48s
#
# Root relaxation: objective 2.074052e+03, 2103 iterations, 8.65 seconds
# Total elapsed time = 51.37s
# Total elapsed time = 56.05s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2074.05159    0   86 1970.00000 2074.05159  5.28%     -   59s
# H    0     0                    2068.0000000 2074.05159  0.29%     -   59s
# H    0     0                    2071.0000000 2074.05159  0.15%     -   60s
# H    0     0                    2072.0000000 2074.05159  0.10%     -   61s
# H    0     0                    2073.0000000 2074.05159  0.05%     -   64s
#      0     0 2074.01756    0   45 2073.00000 2074.01756  0.05%     -   78s
#      0     0 2074.01756    0   70 2073.00000 2074.01756  0.05%     -  113s
#      0     0 2074.00416    0   59 2073.00000 2074.00416  0.05%     -  135s
#      0     0     cutoff    0      2073.00000 2073.00000  0.00%     -  137s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 4
#   MIR: 25
#   StrongCG: 2
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (10924 simplex iterations) in 137.99 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2073 2072 2071 ... 1970
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.073000000000e+03, best bound 2.073000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4x5

# %%
datafile="3x3000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xa92df7dc
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1962.0000000
# Presolve removed 31 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 16s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 28s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 30s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 40s) ...
# Presolve removed 31 rows and 21 columns (presolve time = 45s) ...
# Presolve removed 31 rows and 21 columns
# Presolve time: 48.22s
# Presolved: 11969 rows, 8979 columns, 13450539 nonzeros
# Variable types: 0 continuous, 8979 integer (8979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9930000e+03   4.837796e+06   0.000000e+00     51s
#      654    2.1984087e+03   1.463301e+05   0.000000e+00     56s
#     2316    2.0696540e+03   0.000000e+00   0.000000e+00     59s
#
# Root relaxation: objective 2.069654e+03, 2316 iterations, 9.19 seconds
# Total elapsed time = 62.52s
# Total elapsed time = 66.90s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2069.65401    0  177 1962.00000 2069.65401  5.49%     -   68s
# H    0     0                    2059.0000000 2069.65401  0.52%     -   68s
# H    0     0                    2066.0000000 2069.65401  0.18%     -   70s
# H    0     0                    2067.0000000 2069.65401  0.13%     -   71s
# H    0     0                    2068.0000000 2069.65401  0.08%     -   72s
#      0     0 2069.60534    0  202 2068.00000 2069.60534  0.08%     -  118s
#      0     0 2069.51776    0  180 2068.00000 2069.51776  0.07%     -  132s
#      0     0 2069.47252    0  172 2068.00000 2069.47252  0.07%     -  135s
#      0     0 2069.47252    0  169 2068.00000 2069.47252  0.07%     -  138s
#      0     0 2069.39739    0  155 2068.00000 2069.39739  0.07%     -  149s
#      0     0 2069.37074    0  136 2068.00000 2069.37074  0.07%     -  156s
#      0     0 2069.37074    0  138 2068.00000 2069.37074  0.07%     -  158s
#      0     0 2069.25725    0  111 2068.00000 2069.25725  0.06%     -  169s
#      0     0 2069.24941    0  110 2068.00000 2069.24941  0.06%     -  173s
#      0     0 2069.24941    0  114 2068.00000 2069.24941  0.06%     -  176s
#      0     0 2069.24425    0  106 2068.00000 2069.24425  0.06%     -  186s
#      0     0 2069.23905    0  125 2068.00000 2069.23905  0.06%     -  191s
#      0     0 2069.23879    0  127 2068.00000 2069.23879  0.06%     -  193s
#      0     0 2069.23879    0  128 2068.00000 2069.23879  0.06%     -  196s
#      0     0 2069.23879    0  130 2068.00000 2069.23879  0.06%     -  205s
#      0     0 2069.23879    0  120 2068.00000 2069.23879  0.06%     -  214s
#      0     0 2069.23879    0  114 2068.00000 2069.23879  0.06%     -  223s
#      0     0 2069.23879    0  114 2068.00000 2069.23879  0.06%     -  227s
#      0     0 2069.23773    0  116 2068.00000 2069.23773  0.06%     -  240s
#      0     0 2069.23773    0  121 2068.00000 2069.23773  0.06%     -  243s
#      0     0 2069.23763    0  131 2068.00000 2069.23763  0.06%     -  252s
#      0     0 2069.23760    0  137 2068.00000 2069.23760  0.06%     -  256s
#      0     0 2069.23612    0  123 2068.00000 2069.23612  0.06%     -  267s
#      0     0 2069.23589    0  123 2068.00000 2069.23589  0.06%     -  270s
#      0     0 2069.23286    0  112 2068.00000 2069.23286  0.06%     -  280s
#      0     0 2069.23286    0   97 2068.00000 2069.23286  0.06%     -  293s
#      0     0 2069.23286    0  195 2068.00000 2069.23286  0.06%     -  340s
#      0     0 2069.23286    0  184 2068.00000 2069.23286  0.06%     -  376s
#      0     0 2069.23286    0  134 2068.00000 2069.23286  0.06%     -  382s
#      0     0 2069.23255    0  132 2068.00000 2069.23255  0.06%     -  384s
#      0     0 2069.18242    0  132 2068.00000 2069.18242  0.06%     -  392s
#      0     0 2069.18242    0  123 2068.00000 2069.18242  0.06%     -  396s
#      0     0 2069.18221    0  120 2068.00000 2069.18221  0.06%     -  401s
#      0     0 2069.18221    0  116 2068.00000 2069.18221  0.06%     -  406s
#      0     0 2069.18221    0  109 2068.00000 2069.18221  0.06%     -  411s
#      0     0 2069.18221    0  110 2068.00000 2069.18221  0.06%     -  414s
#      0     0 2069.18221    0  108 2068.00000 2069.18221  0.06%     -  422s
#      0     0 2069.18221    0  106 2068.00000 2069.18221  0.06%     -  426s
#      0     0 2069.18221    0  105 2068.00000 2069.18221  0.06%     -  434s
#      0     0 2069.18221    0   96 2068.00000 2069.18221  0.06%     -  438s
#      0     0 2069.18221    0   88 2068.00000 2069.18221  0.06%     -  450s
#      0     0 2069.18221    0   98 2068.00000 2069.18221  0.06%     -  454s
#      0     0 2069.18221    0  107 2068.00000 2069.18221  0.06%     -  463s
#      0     0 2069.18221    0  103 2068.00000 2069.18221  0.06%     -  467s
#      0     0 2069.18221    0   88 2068.00000 2069.18221  0.06%     -  477s
#      0     0 2069.18221    0   88 2068.00000 2069.18221  0.06%     -  485s
#      0     2 2069.18221    0   88 2068.00000 2069.18221  0.06%     -  501s
#      7    11 2069.15155    3   82 2068.00000 2069.15155  0.06%   110  505s
#     31    23 2069.12544    6   80 2068.00000 2069.15155  0.06%  30.1  512s
#     57    40     cutoff    9      2068.00000 2069.15155  0.06%  18.5  515s
#    104   106 2069.04086   14   68 2068.00000 2069.15155  0.06%  12.2  523s
#    136   159 2069.02828   18   64 2068.00000 2069.15155  0.06%  10.2  529s
#    191   276 2069.02350   26   53 2068.00000 2069.15155  0.06%   8.1  540s
#    308   508 2069.02350   40   62 2068.00000 2069.15155  0.06%   6.5  563s
#    573   838 2069.02005   89   60 2068.00000 2069.13513  0.05%   4.8  596s
#   1035  1066 2069.01306   40   58 2068.00000 2069.12235  0.05%   4.2  626s
#   1269  1067 2069.01187   40   97 2068.00000 2069.12235  0.05%   4.3  876s
#   1293  1083 2069.02810   58   68 2068.00000 2069.07905  0.05%   4.2  880s
#   2632  1914 2069.03271  111   47 2068.00000 2069.03809  0.05%  15.7  885s
#   7269  3923 2069.02816  209   79 2068.00000 2069.03797  0.05%   7.4  890s
#  12837  6821 2069.03185  101   97 2068.00000 2069.03796  0.05%   5.6  896s
#  12858  6838 2069.03796   23   52 2068.00000 2069.03796  0.05%   6.7  900s
#  14655  8327 2069.03157  169   38 2068.00000 2069.03781  0.05%   6.5  905s
#  22262 11061 2069.03271  143   45 2068.00000 2069.03732  0.05%   5.3  910s
#  29776 14161 2068.99919  242   48 2068.00000 2069.03732  0.05%   4.7  915s
#  38027 18759 2069.02874  212   47 2068.00000 2069.03732  0.05%   4.3  920s
#  38938 18776 2069.00259  138   71 2068.00000 2069.03732  0.05%   4.3  925s
#  39208 19276 2069.02461   51   41 2068.00000 2069.03732  0.05%   4.8  930s
#  40388 20045 2069.03238  142   44 2068.00000 2069.03732  0.05%   4.8  935s
#  42640 21853 2069.00464  179   47 2068.00000 2069.03732  0.05%   4.7  940s
#  45403 22929 2069.01252   93   57 2068.00000 2069.03732  0.05%   4.6  945s
#  51089 25796 2069.03732   41   48 2068.00000 2069.03732  0.05%   4.6  950s
#  52759 25240 2069.02009  159   97 2068.00000 2069.03732  0.05%   4.5  970s
#  52773 25249 2069.00407   80   70 2068.00000 2069.03713  0.05%   4.5  975s
#  52778 25253 2069.00115  139   65 2068.00000 2069.03561  0.05%   4.5  980s
#  52784 25257 2069.01178   67   61 2068.00000 2069.03561  0.05%   4.5  985s
#  52855 25320 2069.03542   51   41 2068.00000 2069.03559  0.05%   5.0  990s
#  54152 26439 2069.03187   89   48 2068.00000 2069.03552  0.05%   5.1  996s
#  56183 26950 2069.03331   60   50 2068.00000 2069.03400  0.05%   5.2 1000s
#  57432 28167 2069.03161  126   80 2068.00000 2069.03400  0.05%   5.3 1005s
#  60435 30125 2069.02808  252   77 2068.00000 2069.03400  0.05%   5.3 1010s
#  63817 31840 2069.02962  193   71 2068.00000 2069.03400  0.05%   5.3 1016s
#  67357 34147 2069.03331   53   56 2068.00000 2069.03331  0.05%   5.3 1020s
#  72406 36676 2069.03273   62   51 2068.00000 2069.03331  0.05%   5.4 1025s
#  77539 38817 2069.03331   70   52 2068.00000 2069.03331  0.05%   5.7 1030s
#  82563 42023 2069.03329   60   63 2068.00000 2069.03331  0.05%   6.0 1035s
#  87926 44392 2069.03324   70   61 2068.00000 2069.03331  0.05%   6.1 1040s
#  92311 46767     cutoff  123      2068.00000 2069.03331  0.05%   6.1 1045s
#  96584 49421 2069.02839  221   52 2068.00000 2069.03331  0.05%   6.1 1050s
#  101320 52113 2069.03039  172   72 2068.00000 2069.03331  0.05%   6.1 1055s
#  106464 54456 2069.02957  196   56 2068.00000 2069.03331  0.05%   6.2 1060s
#  110836 56931 2069.03214  126   50 2068.00000 2069.03331  0.05%   6.2 1065s
#  115182 59479 2069.03331   71   61 2068.00000 2069.03331  0.05%   6.2 1070s
#  117974 61015 2069.02999  171   66 2068.00000 2069.03331  0.05%   6.2 1075s
#  120151 62016 2069.02747  246   74 2068.00000 2069.03331  0.05%   6.3 1080s
#  123622 63788 2069.02367  210   61 2068.00000 2069.03331  0.05%   6.4 1085s
#  127979 66532 2069.02858  235   60 2068.00000 2069.03331  0.05%   6.4 1091s
#  131363 69536 2069.02968  200   56 2068.00000 2069.03331  0.05%   6.3 1095s
#  135274 73134 2069.02984  201   56 2068.00000 2069.03331  0.05%   6.3 1100s
#  138828 76520 2069.03077  169   52 2068.00000 2069.03331  0.05%   6.3 1105s
#  142814 80351 2069.03083  145   43 2068.00000 2069.03331  0.05%   6.3 1110s
#  147643 84890 2069.02958  190   59 2068.00000 2069.03331  0.05%   6.2 1115s
#  151147 88474 2069.03043  161   55 2068.00000 2069.03331  0.05%   6.2 1120s
#  155885 92253 2069.02942  207   77 2068.00000 2069.03331  0.05%   6.2 1125s
#  159206 96296 2069.03134  131   67 2068.00000 2069.03331  0.05%   6.2 1130s
#  163660 100446 2069.03058  150   60 2068.00000 2069.03331  0.05%   6.2 1135s
#  166449 103030 2069.03319   69   57 2068.00000 2069.03331  0.05%   6.2 1140s
#  171095 107630 2069.03217  112   55 2068.00000 2069.03331  0.05%   6.2 1145s
#  174874 111036 2069.03331   65   69 2068.00000 2069.03331  0.05%   6.2 1150s
#  179244 115299 2069.03320   78   77 2068.00000 2069.03331  0.05%   6.2 1155s
#  183935 119895 2069.02268  264   75 2068.00000 2069.03331  0.05%   6.2 1161s
#  187711 123537 2069.02719  235   75 2068.00000 2069.03331  0.05%   6.2 1166s
#  190567 126250 2069.02929  205   57 2068.00000 2069.03331  0.05%   6.2 1170s
#  194279 129589 2069.03029  160   55 2068.00000 2069.03331  0.05%   6.1 1175s
#  197901 133009 2069.03221  113   51 2068.00000 2069.03331  0.05%   6.1 1180s
#  202609 137610 2069.03214  121   51 2068.00000 2069.03331  0.05%   6.1 1185s
#  206219 140897 2069.02719  258   72 2068.00000 2069.03331  0.05%   6.1 1190s
#  209827 144573 2069.02775  233   70 2068.00000 2069.03331  0.05%   6.1 1196s
#  213609 148297 2069.02758  217   58 2068.00000 2069.03331  0.05%   6.1 1200s
#  217422 152016 2069.02891  224   67 2068.00000 2069.03331  0.05%   6.1 1205s
#  221742 156132 2069.02958  207   61 2068.00000 2069.03331  0.05%   6.1 1210s
#  224725 158968 2069.03064  150   51 2068.00000 2069.03331  0.05%   6.1 1215s
#  229540 163606 2069.03061  162   49 2068.00000 2069.03331  0.05%   6.1 1220s
#  233379 167244 2069.03232   98   49 2068.00000 2069.03331  0.05%   6.1 1225s
#  236930 170690 2069.02180  235   54 2068.00000 2069.03331  0.05%   6.1 1230s
#  239872 173567 2069.02891  197   58 2068.00000 2069.03331  0.05%   6.1 1235s
#  243739 176576 2069.02958  179   57 2068.00000 2069.03331  0.05%   6.1 1240s
#  246886 180342 2069.03136  135   73 2068.00000 2069.03331  0.05%   6.0 1245s
#  250851 184114 2069.03214  119   43 2068.00000 2069.03331  0.05%   6.0 1250s
#  254819 187507 2069.03228  110   49 2068.00000 2069.03331  0.05%   6.0 1255s
#  258196 191065 2069.02807  232   75 2068.00000 2069.03331  0.05%   6.0 1260s
#  261886 194742 2069.02922  196   47 2068.00000 2069.03331  0.05%   6.0 1265s
#  265620 198355 2069.02987  186   66 2068.00000 2069.03331  0.05%   6.0 1270s
#  269316 201843 2069.02967  130   49 2068.00000 2069.03331  0.05%   6.0 1275s
#  273048 205358 2069.03315   68   35 2068.00000 2069.03331  0.05%   6.0 1280s
#  274863 211988 2069.02991  167   53 2068.00000 2069.03331  0.05%   6.0 1290s
#  283682 215513 2069.02977  182   67 2068.00000 2069.03331  0.05%   6.0 1295s
#  287384 219344 2069.03054  159   76 2068.00000 2069.03331  0.05%   6.0 1300s
#  292020 223325 2069.02182  248   60 2068.00000 2069.03331  0.05%   6.0 1306s
#  295687 227188 2069.02808  229   57 2068.00000 2069.03331  0.05%   6.0 1310s
#  299431 230808 2069.02905  203   60 2068.00000 2069.03331  0.05%   6.0 1315s
#  303397 234674 2069.02908  209   55 2068.00000 2069.03331  0.05%   6.0 1320s
#  307198 238188 2069.02977  188   48 2068.00000 2069.03331  0.05%   6.0 1325s
#  310591 241591 2069.03156  136   49 2068.00000 2069.03331  0.05%   6.0 1331s
#  313691 243597 2069.02148  260   77 2068.00000 2069.03331  0.05%   5.9 1336s
#  313697 249371 2069.02148  261   75 2068.00000 2069.03331  0.05%   5.9 1344s
#  319703 250456 2069.03070  148   61 2068.00000 2069.03331  0.05%   5.9 1346s
#  321913 252440 2069.02791  237   64 2068.00000 2069.03331  0.05%   5.9 1350s
#  325954 256363 2069.02866  213   56 2068.00000 2069.03331  0.05%   5.9 1355s
#  329980 260166 2069.02904  201   60 2068.00000 2069.03331  0.05%   5.9 1361s
#  333421 263531 2069.02922  201   43 2068.00000 2069.03331  0.05%   5.9 1365s
#  335363 265097 2069.03190  124   51 2068.00000 2069.03331  0.05%   5.9 1370s
#  339033 268809 2069.03224  113   47 2068.00000 2069.03331  0.05%   5.9 1376s
#  341916 271263 2069.02872  219   56 2068.00000 2069.03331  0.05%   5.9 1380s
#  345496 275236 2069.02927  195   54 2068.00000 2069.03331  0.05%   5.9 1385s
#  348124 277654 2069.03134  130   61 2068.00000 2069.03331  0.05%   5.9 1390s
#  350945 280239 2069.02624  260   66 2068.00000 2069.03331  0.05%   5.9 1396s
#  353864 283116 2069.02892  208   53 2068.00000 2069.03331  0.05%   5.9 1400s
#  357438 286645 2069.02910  198   55 2068.00000 2069.03331  0.05%   5.9 1405s
#  361218 290028 2069.02945  203   69 2068.00000 2069.03331  0.05%   5.9 1411s
#  364901 293435 2069.02992  184   56 2068.00000 2069.03331  0.05%   5.9 1416s
#  367526 296191 2069.03242  108   61 2068.00000 2069.03331  0.05%   5.9 1420s
#  371946 300568 2069.01383  263   66 2068.00000 2069.03331  0.05%   5.9 1426s
#  375802 303929 2069.03315   69   47 2068.00000 2069.03331  0.05%   5.9 1431s
#  378252 306784 2069.02894  219   58 2068.00000 2069.03331  0.05%   5.9 1435s
#  381863 310215 2069.02970  188   47 2068.00000 2069.03331  0.05%   5.9 1440s
#  385680 313505 2069.03014  161   56 2068.00000 2069.03331  0.05%   5.9 1446s
#  386926 315018 2069.02795  216   56 2068.00000 2069.03331  0.05%   5.9 1450s
#  390844 318833 2069.02938  208   63 2068.00000 2069.03331  0.05%   5.9 1456s
#  393586 321417 2069.03133  127   80 2068.00000 2069.03331  0.05%   5.9 1460s
#  397269 324897 2069.03331   73   63 2068.00000 2069.03331  0.05%   5.9 1466s
#  400177 327577 2069.02812  222   63 2068.00000 2069.03331  0.05%   5.9 1470s
#  402891 330329 2069.03054  160   60 2068.00000 2069.03331  0.05%   5.9 1475s
#  405907 333257 2069.03269   98   71 2068.00000 2069.03331  0.05%   5.8 1480s
#  408763 336076 2069.02897  214   79 2068.00000 2069.03331  0.05%   5.8 1485s
#  412396 339535 2069.03046  140   65 2068.00000 2069.03331  0.05%   5.9 1490s
#  415142 342096 2069.02727  246   73 2068.00000 2069.03331  0.05%   5.8 1495s
#  418094 344876 2069.03020  170   58 2068.00000 2069.03331  0.05%   5.8 1500s
#  420625 346875 2069.02635  256   75 2068.00000 2069.03331  0.05%   5.8 1505s
#  422946 349531 2069.03148  132   63 2068.00000 2069.03331  0.05%   5.8 1511s
#  424857 351529 2069.02904  211   62 2068.00000 2069.03331  0.05%   5.8 1515s
#  427845 354317 2069.03120  155   54 2068.00000 2069.03331  0.05%   5.8 1520s
#  429518 356087 2069.02896  227   65 2068.00000 2069.03331  0.05%   5.8 1526s
#  432500 358739 2069.03072  155   65 2068.00000 2069.03331  0.05%   5.8 1531s
#  435214 361278 2069.03317   79   55 2068.00000 2069.03331  0.05%   5.8 1535s
#  438925 364904 2069.02751  249   57 2068.00000 2069.03331  0.05%   5.8 1541s
#  441563 367525 2069.02991  181   75 2068.00000 2069.03331  0.05%   5.8 1545s
#  444273 370419 2069.03315   83   51 2068.00000 2069.03331  0.05%   5.8 1550s
#  447359 373322 2069.03117  155   64 2068.00000 2069.03331  0.05%   5.8 1555s
#  450372 376145 2069.02909  225   74 2068.00000 2069.03331  0.05%   5.8 1561s
#  451444 376966 2069.02794  257   59 2068.00000 2069.03331  0.05%   5.8 1566s
#  454242 379839 2069.03106  148   50 2068.00000 2069.03331  0.05%   5.8 1571s
#  457020 382588 2069.02792  258   51 2068.00000 2069.03331  0.05%   5.8 1576s
#  459450 384857 2069.02981  166   66 2068.00000 2069.03331  0.05%   5.8 1580s
#  462601 387985 2069.03317   82   40 2068.00000 2069.03331  0.05%   5.8 1585s
#  465683 389865 2069.02827  232   46 2068.00000 2069.03331  0.05%   5.8 1590s
#  468355 393464 2069.03042  167   57 2068.00000 2069.03331  0.05%   5.8 1596s
#  470265 395220 2069.02795  253   60 2068.00000 2069.03331  0.05%   5.8 1600s
#  473965 398810 2069.02884  212   65 2068.00000 2069.03331  0.05%   5.8 1605s
#  476802 401592 2069.03156  126   36 2068.00000 2069.03331  0.05%   5.8 1611s
#  479725 404142 2069.03331   74   66 2068.00000 2069.03331  0.05%   5.8 1616s
#  482515 406973 2069.02948  215   73 2068.00000 2069.03331  0.05%   5.8 1620s
#  485427 409839 2069.03216  119   73 2068.00000 2069.03331  0.05%   5.8 1625s
#  488255 412445 2069.02780  239   66 2068.00000 2069.03331  0.05%   5.8 1630s
#  492131 415974 2069.02807  226   48 2068.00000 2069.03331  0.05%   5.8 1636s
#  494893 418688 2069.03221  125   49 2068.00000 2069.03331  0.05%   5.8 1641s
#  497515 421579 2069.02999  183   66 2068.00000 2069.03331  0.05%   5.8 1646s
#  500344 424116 2069.02790  252   64 2068.00000 2069.03331  0.05%   5.8 1651s
#  501314 424925 2069.02147  276   65 2068.00000 2069.03331  0.05%   5.8 1655s
#  504044 427591 2069.02982  188   55 2068.00000 2069.03331  0.05%   5.8 1660s
#  506861 430258 2069.03271   90   39 2068.00000 2069.03331  0.05%   5.8 1665s
#  509701 433096 2069.02826  227   46 2068.00000 2069.03331  0.05%   5.8 1670s
#  513428 436568 2069.03070  146   67 2068.00000 2069.03331  0.05%   5.8 1676s
#  516106 438935 2069.02906  215   79 2068.00000 2069.03331  0.05%   5.8 1681s
#  518695 441668 2069.03225  105   61 2068.00000 2069.03331  0.05%   5.8 1686s
#  521443 444275 2069.02740  214   65 2068.00000 2069.03331  0.05%   5.8 1691s
#  524217 446952 2069.03029  179   66 2068.00000 2069.03331  0.05%   5.8 1696s
#  526790 449458 2069.02789  263   61 2068.00000 2069.03331  0.05%   5.8 1701s
#  529503 452050 2069.03217  121   68 2068.00000 2069.03331  0.05%   5.8 1705s
#  532342 454817 2069.03016  179   64 2068.00000 2069.03331  0.05%   5.8 1711s
#  535081 457428 2069.02749  256   64 2068.00000 2069.03331  0.05%   5.8 1716s
#  536705 459173 2069.03214  129   43 2068.00000 2069.03331  0.05%   5.8 1720s
#  539830 462118 2069.02739  260   61 2068.00000 2069.03331  0.05%   5.8 1726s
#  541614 462872 2069.03101  144   51 2068.00000 2069.03331  0.05%   5.8 1730s
#  543560 465638 2069.02827  222   51 2068.00000 2069.03331  0.05%   5.8 1736s
#  545466 467400 2069.03216  132   48 2068.00000 2069.03331  0.05%   5.8 1740s
#  548392 470191 2069.02771  255   68 2068.00000 2069.03331  0.05%   5.8 1746s
#  550424 472236 2069.03085  149   57 2068.00000 2069.03331  0.05%   5.8 1751s
#  552293 473738 2069.02809  239   61 2068.00000 2069.03331  0.05%   5.8 1755s
#  554914 476514 2069.03030  176   69 2068.00000 2069.03331  0.05%   5.8 1761s
#  556706 478176 2069.02778  248   65 2068.00000 2069.03331  0.05%   5.8 1765s
#  559547 480886 2069.03056  167   62 2068.00000 2069.03331  0.05%   5.8 1771s
#  561165 482530 2069.02855  233   65 2068.00000 2069.03331  0.05%   5.8 1775s
#  563757 484893 2069.03217  111   67 2068.00000 2069.03331  0.05%   5.8 1781s
#  565622 486918 2069.03098  147   71 2068.00000 2069.03331  0.05%   5.8 1785s
#  568448 489675 2069.02933  210   76 2068.00000 2069.03331  0.05%   5.8 1791s
#  570526 490628 2069.02782  260   77 2068.00000 2069.03331  0.05%   5.8 1797s
#  571272 492322 2069.03307   80   47 2068.00000 2069.03331  0.05%   5.8 1801s
#  573337 494077 2069.02938  192   56 2068.00000 2069.03331  0.05%   5.8 1805s
#  574143 499837 2069.02713  216   65 2068.00000 2069.03331  0.05%   5.8 1817s
#  580149 500315 2069.03232   94   36 2068.00000 2069.03331  0.05%   5.8 1821s
#  581667 502230 2069.03045  151   42 2068.00000 2069.03331  0.05%   5.8 1825s
#  584584 504971 2069.03214  121   50 2068.00000 2069.03331  0.05%   5.8 1831s
#  585949 506241 2069.02946  194   72 2068.00000 2069.03331  0.05%   5.8 1835s
#  588688 508980 2069.03319   85   77 2068.00000 2069.03331  0.05%   5.8 1842s
#  590692 510620 2069.03026  177   81 2068.00000 2069.03331  0.05%   5.8 1846s
#  592406 512536 2069.02826  243   75 2068.00000 2069.03331  0.05%   5.8 1850s
#  594258 514275 2069.03072  145   62 2068.00000 2069.03331  0.05%   5.8 1855s
#  597304 516945 2069.02148  262   54 2068.00000 2069.03331  0.05%   5.8 1861s
#  598920 518677 2069.03174  143   74 2068.00000 2069.03331  0.05%   5.8 1865s
#  601708 521545 2069.02866  239   71 2068.00000 2069.03331  0.05%   5.8 1871s
#  603782 523017 2069.03164  132   54 2068.00000 2069.03331  0.05%   5.8 1875s
#  606459 525808 2069.02794  242   60 2068.00000 2069.03331  0.05%   5.8 1881s
#  609060 528116 2069.03014  181   82 2068.00000 2069.03331  0.05%   5.8 1886s
#  610712 530014 2069.02791  253   80 2068.00000 2069.03331  0.05%   5.8 1890s
#  612640 531764 2069.03096  150   53 2068.00000 2069.03331  0.05%   5.8 1897s
#  614617 533513 2069.02824  233   57 2068.00000 2069.03331  0.05%   5.8 1901s
#  616431 535263 2069.03216  145   52 2068.00000 2069.03331  0.05%   5.8 1906s
#  618071 536822 2069.02977  214   63 2068.00000 2069.03331  0.05%   5.8 1910s
#  620586 539384 2069.03225  107   77 2068.00000 2069.03331  0.05%   5.8 1918s
#  621628 540293 2069.03228  103   36 2068.00000 2069.03331  0.05%   5.8 1920s
#  623435 542045 2069.02991  167   58 2068.00000 2069.03331  0.05%   5.8 1925s
#  625368 543940 2069.02831  226   71 2068.00000 2069.03331  0.05%   5.8 1930s
#  628154 546572 2069.03056  153   50 2068.00000 2069.03331  0.05%   5.8 1936s
#  629164 547150 2069.02958  196   52 2068.00000 2069.03331  0.05%   5.8 1940s
#  630751 549073 2069.02182  257   51 2068.00000 2069.03331  0.05%   5.8 1945s
#  632797 550881 2069.03024  168   83 2068.00000 2069.03331  0.05%   5.8 1951s
#  634744 552776 2069.02771  244   85 2068.00000 2069.03331  0.05%   5.8 1956s
#  636658 554595 2069.03054  157   70 2068.00000 2069.03331  0.05%   5.8 1961s
#  638652 556615 2069.02834  248   70 2068.00000 2069.03331  0.05%   5.8 1965s
#  641359 559042 2069.03148  154   53 2068.00000 2069.03331  0.05%   5.8 1971s
#  643170 560771 2069.02938  226   53 2068.00000 2069.03331  0.05%   5.8 1975s
#  644954 562543 2069.03270  102   50 2068.00000 2069.03331  0.05%   5.8 1980s
#  647690 565073 2069.02926  225   70 2068.00000 2069.03331  0.05%   5.8 1986s
#  649615 566038 2069.02624  289   68 2068.00000 2069.03331  0.05%   5.8 1992s
#  649621 566817 2069.02624  288   68 2068.00000 2069.03331  0.05%   5.8 1995s
#  651476 568683 2069.03246  101   42 2068.00000 2069.03331  0.05%   5.8 2002s
#  652455 569362 2069.03216  130   43 2068.00000 2069.03331  0.05%   5.8 2005s
#  654269 571530 2069.03070  163   51 2068.00000 2069.03331  0.05%   5.8 2012s
#  655317 572250 2069.03019  186   52 2068.00000 2069.03331  0.05%   5.8 2015s
#  657022 574028 2069.02923  220   56 2068.00000 2069.03331  0.05%   5.8 2020s
#  658952 575890 2069.02180  269   50 2068.00000 2069.03331  0.05%   5.8 2025s
#  661698 578600 2069.02924  214   56 2068.00000 2069.03331  0.05%   5.8 2032s
#  663273 579931 2069.03270   92   41 2068.00000 2069.03331  0.05%   5.8 2037s
#  664184 580691 2069.03164  143   46 2068.00000 2069.03331  0.05%   5.8 2040s
#  666226 582828 2069.02923  225   54 2068.00000 2069.03331  0.05%   5.8 2045s
#  668262 584815 2069.03232  108   60 2068.00000 2069.03331  0.05%   5.8 2050s
#  670007 586467 2069.03015  184   59 2068.00000 2069.03331  0.05%   5.8 2056s
#  672064 588389 2069.02780  257   57 2068.00000 2069.03331  0.05%   5.8 2062s
#  673045 589320 2069.03224  113   37 2068.00000 2069.03331  0.05%   5.7 2065s
#  675055 591084 2069.02926  200   50 2068.00000 2069.03331  0.05%   5.7 2070s
#  676865 592980 2069.03315   65   72 2068.00000 2069.03331  0.05%   5.7 2077s
#  678509 593921 2069.02182  247   55 2068.00000 2069.03331  0.05%   5.7 2080s
#  680539 596533 2069.02904  241   71 2068.00000 2069.03331  0.05%   5.7 2087s
#  682543 598215 2069.03224  115   52 2068.00000 2069.03331  0.05%   5.7 2092s
#  683359 599188 2069.03097  154   62 2068.00000 2069.03331  0.05%   5.7 2096s
#  685379 600985 2069.02872  243   72 2068.00000 2069.03331  0.05%   5.7 2101s
#  687160 602778 2069.03112   91   42 2068.00000 2069.03331  0.05%   5.7 2105s
#  689003 604485 2069.03007  133   40 2068.00000 2069.03331  0.05%   5.7 2113s
#  689914 605483 2069.02903  152   38 2068.00000 2069.03331  0.05%   5.7 2117s
#  690968 606281 2069.02836  179   42 2068.00000 2069.03331  0.05%   5.7 2120s
#  692807 608207 2069.02719  221   52 2068.00000 2069.03331  0.05%   5.7 2125s
#  694582 609876 2069.01986  260   48 2068.00000 2069.03331  0.05%   5.7 2130s
#  696549 610748 2069.03019  145   57 2068.00000 2069.03331  0.05%   5.7 2136s
#  697423 612494 2069.02901  187   57 2068.00000 2069.03331  0.05%   5.7 2140s
#  699364 614219 2069.03323   57   58 2068.00000 2069.03331  0.05%   5.7 2146s
#  700193 615155 2069.03214  116   43 2068.00000 2069.03331  0.05%   5.7 2151s
#  702170 616872 2069.02970  204   56 2068.00000 2069.03331  0.05%   5.7 2156s
#  702999 617879 2069.02904  226   58 2068.00000 2069.03331  0.05%   5.7 2160s
#  705003 619426 2069.03217  128   45 2068.00000 2069.03331  0.05%   5.7 2165s
#  706647 621249 2069.03014  189   52 2068.00000 2069.03331  0.05%   5.7 2171s
#  708609 622868 2069.02771  249   47 2068.00000 2069.03331  0.05%   5.7 2176s
#  709341 623692 2069.03251   97   44 2068.00000 2069.03331  0.05%   5.7 2180s
#  711234 625374 2069.02992  181   63 2068.00000 2069.03331  0.05%   5.7 2187s
#  712024 626332 2069.02910  215   67 2068.00000 2069.03331  0.05%   5.7 2191s
#  713928 627965 2069.03320   68   70 2068.00000 2069.03331  0.05%   5.7 2196s
#  714764 628883 2069.03214  115   58 2068.00000 2069.03331  0.05%   5.7 2200s
#  716740 630667 2069.02938  200   66 2068.00000 2069.03331  0.05%   5.7 2207s
#  717549 631587 2069.02833  225   69 2068.00000 2069.03331  0.05%   5.7 2210s
#  719489 633314 2069.03217  125   42 2068.00000 2069.03331  0.05%   5.7 2217s
#  720332 634279 2069.03063  151   63 2068.00000 2069.03331  0.05%   5.7 2220s
#  722289 635851 2069.02872  229   68 2068.00000 2069.03331  0.05%   5.7 2225s
#  723972 637640 2069.03224  123   46 2068.00000 2069.03331  0.05%   5.7 2231s
#  725724 639459 2069.02977  181   50 2068.00000 2069.03331  0.05%   5.7 2236s
#  727692 641105 2069.02726  256   56 2068.00000 2069.03331  0.05%   5.7 2241s
#  729550 642965 2069.03165  138   56 2068.00000 2069.03331  0.05%   5.7 2247s
#  730457 643787 2069.03024  178   79 2068.00000 2069.03331  0.05%   5.7 2250s
#  732046 645319 2069.02873  234   79 2068.00000 2069.03331  0.05%   5.7 2255s
#  733884 647127 2069.03221  119   53 2068.00000 2069.03331  0.05%   5.7 2262s
#  734831 648094 2069.03039  166   61 2068.00000 2069.03331  0.05%   5.7 2265s
#  736706 649730 2069.02807  230   66 2068.00000 2069.03331  0.05%   5.7 2271s
#  738632 651614 2069.03156  133   34 2068.00000 2069.03331  0.05%   5.7 2277s
#  739602 652317 2069.02953  176   62 2068.00000 2069.03331  0.05%   5.7 2280s
#  741367 654268 2069.02784  238   55 2068.00000 2069.03331  0.05%   5.7 2287s
#  742423 654274 2069.03315   64   49 2068.00000 2069.03331  0.05%   5.7 2290s
#  742753 654814 2069.02977  194   53 2068.00000 2069.03331  0.05%   5.7 2295s
#  744084 656937 2069.03054  147   50 2068.00000 2069.03331  0.05%   5.7 2302s
#  745244 657832 2069.02906  203   53 2068.00000 2069.03331  0.05%   5.7 2305s
#  746171 658779 2069.02756  241   58 2068.00000 2069.03331  0.05%   5.7 2310s
#  747514 660156 2069.03165  128   41 2068.00000 2069.03331  0.05%   5.7 2316s
#  748728 660977 2069.02809  231   53 2068.00000 2069.03331  0.05%   5.7 2320s
#  750412 662835 2069.03323   71   56 2068.00000 2069.03331  0.05%   5.7 2327s
#  751448 663809 2069.03216  135   45 2068.00000 2069.03331  0.05%   5.7 2331s
#  753326 665670 2069.02926  211   60 2068.00000 2069.03331  0.05%   5.7 2338s
#  754359 666492 2069.02791  247   70 2068.00000 2069.03331  0.05%   5.7 2342s
#  755326 667331 2069.03315   79   44 2068.00000 2069.03331  0.05%   5.7 2345s
#  757267 669228 2069.03221  123   53 2068.00000 2069.03331  0.05%   5.7 2353s
#  758133 669257 2069.03164  141   49 2068.00000 2069.03331  0.05%   5.7 2359s
#  758162 670091 2069.03164  142   49 2068.00000 2069.03331  0.05%   5.7 2362s
#  759030 670945 2069.03095  155   44 2068.00000 2069.03331  0.05%   5.7 2365s
#  760937 672972 2069.03014  196   44 2068.00000 2069.03331  0.05%   5.7 2373s
#  761951 673766 2069.02941  215   47 2068.00000 2069.03331  0.05%   5.7 2376s
#  763741 675544 2069.02787  258   49 2068.00000 2069.03331  0.05%   5.7 2383s
#  764766 676279 2069.03246  103   58 2068.00000 2069.03331  0.05%   5.7 2386s
#  765533 677208 2069.03103  136   50 2068.00000 2069.03331  0.05%   5.7 2391s
#  767458 678717 2069.02865  212   55 2068.00000 2069.03331  0.05%   5.7 2398s
#  768062 680181 2069.02778  237   52 2068.00000 2069.03331  0.05%   5.7 2404s
#  769629 681214 2069.03097  138   59 2068.00000 2069.03331  0.05%   5.7 2408s
#  770704 682164 2069.02946  197   52 2068.00000 2069.03331  0.05%   5.7 2412s
#  771708 683087 2069.02807  226   60 2068.00000 2069.03331  0.05%   5.7 2416s
#  773005 684062 2069.02146  264   61 2068.00000 2069.03331  0.05%   5.7 2420s
#  774588 685894 2069.02959  199   58 2068.00000 2069.03331  0.05%   5.7 2426s
#  775610 686596 2069.02823  233   58 2068.00000 2069.03331  0.05%   5.7 2430s
#  777411 688507 2069.03214  134   49 2068.00000 2069.03331  0.05%   5.7 2437s
#  778362 688513 2069.03031  173   60 2068.00000 2069.03331  0.05%   5.7 2440s
#  779162 690330 2069.02941  207   57 2068.00000 2069.03331  0.05%   5.7 2446s
#  780245 691339 2069.02809  242   67 2068.00000 2069.03331  0.05%   5.7 2450s
#  782028 693032 2069.03133  143   76 2068.00000 2069.03331  0.05%   5.7 2456s
#  784054 694862 2069.02872  229   74 2068.00000 2069.03331  0.05%   5.7 2462s
#  785000 695661 2069.02746  259   77 2068.00000 2069.03331  0.05%   5.7 2466s
#  786811 697373 2069.03072  149   65 2068.00000 2069.03331  0.05%   5.7 2473s
#  787641 698342 2069.02989  183   76 2068.00000 2069.03331  0.05%   5.7 2476s
#  788614 699207 2069.02891  225   68 2068.00000 2069.03331  0.05%   5.7 2480s
#  790206 700684 2069.03293   88   54 2068.00000 2069.03331  0.05%   5.7 2487s
#  791140 701697 2069.03148  136   55 2068.00000 2069.03331  0.05%   5.7 2491s
#  792172 702686 2069.03008  182   61 2068.00000 2069.03331  0.05%   5.7 2495s
#  794272 704423 2069.02180  250   61 2068.00000 2069.03331  0.05%   5.7 2502s
#  795087 705286 2069.03315   84   47 2068.00000 2069.03331  0.05%   5.7 2506s
#  796912 706971 2069.03023  188   61 2068.00000 2069.03331  0.05%   5.7 2513s
#  797695 707923 2069.02958  214   62 2068.00000 2069.03331  0.05%   5.7 2516s
#  798716 708852 2069.02827  253   56 2068.00000 2069.03331  0.05%   5.7 2520s
#  800514 710513 2069.03217  124   58 2068.00000 2069.03331  0.05%   5.7 2526s
#  801467 711476 2069.03021  169   63 2068.00000 2069.03331  0.05%   5.7 2530s
#  803303 713206 2069.02833  240   81 2068.00000 2069.03331  0.05%   5.7 2537s
#  804282 714050 2069.01413  278   73 2068.00000 2069.03331  0.05%   5.7 2540s
#  806039 715822 2069.03097  153   64 2068.00000 2069.03331  0.05%   5.7 2547s
#  807108 716755 2069.02946  209   73 2068.00000 2069.03331  0.05%   5.7 2551s
#  808859 718333 2069.02739  271   73 2068.00000 2069.03331  0.05%   5.7 2557s
#  809735 719143 2069.03228  100   38 2068.00000 2069.03331  0.05%   5.7 2560s
#  811472 720687 2069.02982  177   43 2068.00000 2069.03331  0.05%   5.7 2566s
#  812185 721643 2069.02909  202   51 2068.00000 2069.03331  0.05%   5.7 2570s
#  813629 722557 2069.02864  212   51 2068.00000 2069.03331  0.05%   5.7 2575s
#  815256 724536 2069.03232   92   47 2068.00000 2069.03331  0.05%   5.7 2583s
#  816243 725270 2069.03085  141   42 2068.00000 2069.03331  0.05%   5.7 2586s
#  817014 725276 2069.03014  167   54 2068.00000 2069.03331  0.05%   5.7 2590s
#  818025 727003 2069.02864  208   54 2068.00000 2069.03331  0.05%   5.7 2598s
#  818860 727926 2069.02771  238   52 2068.00000 2069.03331  0.05%   5.7 2602s
#  819828 728917 2069.03323   76   69 2068.00000 2069.03331  0.05%   5.7 2607s
#  820855 729789 2069.03214  134   48 2068.00000 2069.03331  0.05%   5.7 2611s
#  822414 730737 2069.02839  219   73 2068.00000 2069.03331  0.05%   5.7 2615s
#  823743 732473 2069.02822  244   58 2068.00000 2069.03331  0.05%   5.7 2622s
#  824587 733475 2069.03315   73   37 2068.00000 2069.03331  0.05%   5.7 2627s
#  825589 734309 2069.03190  132   48 2068.00000 2069.03331  0.05%   5.7 2631s
#  826479 735222 2069.03031  168   39 2068.00000 2069.03331  0.05%   5.7 2635s
#  828084 736590 2069.02827  230   42 2068.00000 2069.03331  0.05%   5.7 2643s
#  829024 737494 2069.03325   77   75 2068.00000 2069.03331  0.05%   5.7 2647s
#  829928 738413 2069.03217  137   62 2068.00000 2069.03331  0.05%   5.7 2650s
#  831845 740282 2069.02946  216   73 2068.00000 2069.03331  0.05%   5.7 2658s
#  832814 740970 2069.02832  251   77 2068.00000 2069.03331  0.05%   5.7 2663s
#  833602 741997 2069.02739  277   72 2068.00000 2069.03331  0.05%   5.7 2668s
#  834653 742980 2069.03217  122   54 2068.00000 2069.03331  0.05%   5.7 2674s
#  835674 743947 2069.03035  162   60 2068.00000 2069.03331  0.05%   5.7 2679s
#  836320 743947 2069.02802  243   54 2068.00000 2069.03331  0.05%   5.7 2680s
#  837657 745660 2069.02793  236   57 2068.00000 2069.03331  0.05%   5.7 2689s
#  838633 746274 2069.03232  113   52 2068.00000 2069.03331  0.05%   5.7 2694s
#  839277 747248 2069.03134  150   68 2068.00000 2069.03331  0.05%   5.7 2698s
#  840251 748161 2069.03021  191   70 2068.00000 2069.03331  0.05%   5.7 2703s
#  841196 749060 2069.02926  220   61 2068.00000 2069.03331  0.05%   5.7 2708s
#  842173 749909 2069.02796  249   68 2068.00000 2069.03331  0.05%   5.7 2713s
#  843135 750893 2069.03315   72   48 2068.00000 2069.03331  0.05%   5.7 2718s
#  844125 751774 2069.03148  134   46 2068.00000 2069.03331  0.05%   5.7 2722s
#  845006 752870 2069.03014  182   44 2068.00000 2069.03331  0.05%   5.7 2728s
#  846140 753557 2069.02864  219   51 2068.00000 2069.03331  0.05%   5.7 2732s
#  846929 754407 2069.02180  250   49 2068.00000 2069.03331  0.05%   5.7 2738s
#  847861 755256 2069.03221  120   55 2068.00000 2069.03331  0.05%   5.7 2742s
#  848710 756036 2069.03062  158   54 2068.00000 2069.03331  0.05%   5.7 2746s
#  849490 756970 2069.02958  198   59 2068.00000 2069.03331  0.05%   5.7 2750s
#  851421 758557 2069.01448  258   56 2068.00000 2069.03331  0.05%   5.7 2758s
#  852232 759442 2069.03216  118   43 2068.00000 2069.03331  0.05%   5.7 2761s
#  853117 760474 2069.03020  166   58 2068.00000 2069.03331  0.05%   5.7 2765s
#  854968 762222 2069.02831  231   70 2068.00000 2069.03331  0.05%   5.7 2773s
#  855991 762225 2069.02739  264   73 2068.00000 2069.03331  0.05%   5.7 2777s
#  855997 762819 2069.02739  265   71 2068.00000 2069.03331  0.05%   5.7 2780s
#  857621 764422 2069.03096  148   59 2068.00000 2069.03331  0.05%   5.7 2788s
#  858302 765937 2069.03020  173   61 2068.00000 2069.03331  0.05%   5.7 2794s
#  859877 766825 2069.02810  228   53 2068.00000 2069.03331  0.05%   5.7 2799s
#  860943 767737 2069.02616  107   57 2068.00000 2069.03331  0.05%   5.7 2803s
#  861886 768788 2069.02085  165   66 2068.00000 2069.03331  0.05%   5.7 2807s
#  862955 769793 2069.01654  210   71 2068.00000 2069.03331  0.05%   5.7 2811s
#  863983 770714 2069.03217  126   51 2068.00000 2069.03331  0.05%   5.7 2815s
#  865901 772168 2069.02947  202   65 2068.00000 2069.03331  0.05%   5.7 2823s
#  866526 773001 2069.02891  224   61 2068.00000 2069.03331  0.05%   5.7 2826s
#  867373 773901 2069.02740  255   69 2068.00000 2069.03331  0.05%   5.7 2830s
#  869309 775595 2069.03133  138   66 2068.00000 2069.03331  0.05%   5.7 2838s
#  870124 776577 2069.03013  173   69 2068.00000 2069.03331  0.05%   5.7 2842s
#  871137 777552 2069.02906  216   68 2068.00000 2069.03331  0.05%   5.7 2847s
#  872112 778324 2069.02789  244   73 2068.00000 2069.03331  0.05%   5.7 2850s
#  873923 780137 2069.03102  139   45 2068.00000 2069.03331  0.05%   5.7 2859s
#  874877 780857 2069.03020  182   48 2068.00000 2069.03331  0.05%   5.7 2862s
#  875637 781832 2069.02942  208   53 2068.00000 2069.03331  0.05%   5.7 2866s
#  876619 782671 2069.02828  234   51 2068.00000 2069.03331  0.05%   5.7 2871s
#  878441 784356 2069.03214  134   53 2068.00000 2069.03331  0.05%   5.7 2879s
#  879306 785089 2069.03061  167   47 2068.00000 2069.03331  0.05%   5.7 2882s
#  880090 786015 2069.02958  208   47 2068.00000 2069.03331  0.05%   5.7 2887s
#  881036 786706 2069.02864  229   47 2068.00000 2069.03331  0.05%   5.7 2890s
#  881771 787669 2069.02778  253   47 2068.00000 2069.03331  0.05%   5.7 2895s
#  883829 789559 2069.03046  162   51 2068.00000 2069.03331  0.05%   5.7 2904s
#  884826 790439 2069.02939  207   51 2068.00000 2069.03331  0.05%   5.7 2908s
#  885731 791064 2069.02824  237   47 2068.00000 2069.03331  0.05%   5.7 2912s
#  886393 792039 2069.03325   70   75 2068.00000 2069.03331  0.05%   5.7 2916s
#  887410 792882 2069.03217  137   46 2068.00000 2069.03331  0.05%   5.7 2920s
#  889248 794788 2069.02926  210   77 2068.00000 2069.03331  0.05%   5.7 2928s
#  890264 795707 2069.02790  237   81 2068.00000 2069.03331  0.05%   5.7 2933s
#  891216 796450 2069.03300   81   48 2068.00000 2069.03331  0.05%   5.7 2937s
#  891977 797372 2069.03216  127   38 2068.00000 2069.03331  0.05%   5.7 2942s
#  892968 798257 2069.03029  171   64 2068.00000 2069.03331  0.05%   5.7 2946s
#  893971 799213 2069.02926  212   62 2068.00000 2069.03331  0.05%   5.7 2950s
#  894927 800163 2069.02777  248   62 2068.00000 2069.03331  0.05%   5.7 2955s
#  895913 801037 2069.03293   94   46 2068.00000 2069.03331  0.05%   5.7 2960s
#  896821 802079 2069.03214  135   43 2068.00000 2069.03331  0.05%   5.7 2966s
#  897941 803004 2069.03014  185   49 2068.00000 2069.03331  0.05%   5.7 2971s
#  899375 803658 2069.02149  268   79 2068.00000 2069.03331  0.05%   5.7 2975s
#  899582 804667 2069.02827  234   47 2068.00000 2069.03331  0.05%   5.7 2982s
#  900640 805633 2069.03247   98   42 2068.00000 2069.03331  0.05%   5.7 2987s
#  901650 806504 2069.03071  154   68 2068.00000 2069.03331  0.05%   5.7 2991s
#  902573 807225 2069.02947  195   63 2068.00000 2069.03331  0.05%   5.7 2995s
#  903312 808204 2069.02893  227   62 2068.00000 2069.03331  0.05%   5.7 3000s
#  905291 809934 2069.02734  123   52 2068.00000 2069.03331  0.05%   5.7 3008s
#  906159 810807 2069.03224  111   58 2068.00000 2069.03331  0.05%   5.7 3012s
#  907121 811487 2069.03118  149   81 2068.00000 2069.03331  0.05%   5.7 3015s
#  907810 812580 2069.03000  184   78 2068.00000 2069.03331  0.05%   5.7 3020s
#  909976 814407 2069.02771  252   94 2068.00000 2069.03331  0.05%   5.7 3028s
#  910887 815131 2069.03270  106   57 2068.00000 2069.03331  0.05%   5.7 3032s
#  911715 816010 2069.03214  143   47 2068.00000 2069.03331  0.05%   5.7 3036s
#  912594 816947 2069.03029  177   66 2068.00000 2069.03331  0.05%   5.7 3040s
#  914245 818568 2069.02872  235   78 2068.00000 2069.03331  0.05%   5.7 3048s
#  915215 819522 2069.02746  267   71 2068.00000 2069.03331  0.05%   5.7 3053s
#  916315 820393 2069.03243  108   52 2068.00000 2069.03331  0.05%   5.7 3057s
#  917224 821385 2069.03098  149   72 2068.00000 2069.03331  0.05%   5.7 3062s
#  918216 822336 2069.02988  191   71 2068.00000 2069.03331  0.05%   5.7 3066s
#  919204 823118 2069.02893  224   71 2068.00000 2069.03331  0.05%   5.7 3071s
#  920033 824022 2069.02771  251   73 2068.00000 2069.03331  0.05%   5.7 3076s
#  921034 824709 2069.03300   94   60 2068.00000 2069.03331  0.05%   5.7 3081s
#  921759 825609 2069.03243  115   56 2068.00000 2069.03331  0.05%   5.7 3085s
#  922679 826604 2069.03072  158   73 2068.00000 2069.03331  0.05%   5.7 3091s
#  923706 827504 2069.02938  200   63 2068.00000 2069.03331  0.05%   5.7 3096s
#  924606 828444 2069.02872  227   77 2068.00000 2069.03331  0.05%   5.7 3101s
#  925635 829256 2069.02746  261   79 2068.00000 2069.03331  0.05%   5.7 3106s
#  926503 830110 2069.03232  107   56 2068.00000 2069.03331  0.05%   5.7 3110s
#  928234 831886 2069.03015  186   54 2068.00000 2069.03331  0.05%   5.7 3119s
#  929201 832849 2069.02923  217   62 2068.00000 2069.03331  0.05%   5.7 3123s
#  930248 833603 2069.02780  256   66 2068.00000 2069.03331  0.05%   5.7 3127s
#  931053 834482 2069.03041  103   46 2068.00000 2069.03331  0.05%   5.7 3132s
#  931971 835326 2069.02903  141   50 2068.00000 2069.03331  0.05%   5.7 3137s
#  932847 835840 2069.02807  181   54 2068.00000 2069.03331  0.05%   5.7 3141s
#  933365 836738 2069.02756  200   58 2068.00000 2069.03331  0.05%   5.7 3146s
#  934328 837611 2069.02635  222   56 2068.00000 2069.03331  0.05%   5.7 3151s
#  935291 838395 2069.03307   79   50 2068.00000 2069.03331  0.05%   5.7 3157s
#  936112 839383 2069.03217  124   57 2068.00000 2069.03331  0.05%   5.7 3163s
#  937149 840163 2069.03052  158   60 2068.00000 2069.03331  0.05%   5.7 3168s
#  938003 841096 2069.02969  193   52 2068.00000 2069.03331  0.05%   5.7 3174s
#  938946 841959 2069.02865  220   62 2068.00000 2069.03331  0.05%   5.7 3180s
#  939846 842897 2069.02787  243   62 2068.00000 2069.03331  0.05%   5.7 3185s
#  940894 843884 2069.03097   93   46 2068.00000 2069.03331  0.05%   5.7 3191s
#  941912 844674 2069.02919  142   45 2068.00000 2069.03331  0.05%   5.7 3197s
#  942724 844679 2069.02830  178   42 2068.00000 2069.03331  0.05%   5.7 3202s
#  942730 845622 2069.02830  177   45 2068.00000 2069.03331  0.05%   5.7 3207s
#  943706 846399 2069.02737  209   44 2068.00000 2069.03331  0.05%   5.7 3212s
#  944534 847274 2069.02635  231   43 2068.00000 2069.03331  0.05%   5.7 3218s
#  945508 848197 2069.03307   66   59 2068.00000 2069.03331  0.05%   5.7 3224s
#  946468 849047 2069.03164  123   57 2068.00000 2069.03331  0.05%   5.7 3229s
#  947355 849053 2069.03023  163   67 2068.00000 2069.03331  0.05%   5.7 3258s
#  947361 854813 2069.03023  162   67 2068.00000 2069.03331  0.05%   5.7 3295s
#  953367 855945 2069.02872  215   69 2068.00000 2069.03331  0.05%   5.7 3304s
#  954670 856182 2069.03323   76   61 2068.00000 2069.03331  0.05%   5.7 3309s
#  954907 857351 2069.03320   77   53 2068.00000 2069.03331  0.05%   5.7 3314s
#  956076 858592 2069.03072  156   62 2068.00000 2069.03331  0.05%   5.7 3321s
#  957366 859795 2069.02947  210   64 2068.00000 2069.03331  0.05%   5.7 3328s
#  958626 860740 2069.02778  258   70 2068.00000 2069.03331  0.05%   5.7 3335s
#  959705 861807 2069.03251  109   42 2068.00000 2069.03331  0.05%   5.7 3340s
#  960772 862907 2069.03085  164   47 2068.00000 2069.03331  0.05%   5.7 3347s
#  961922 863785 2069.02957  213   49 2068.00000 2069.03331  0.05%   5.7 3353s
#  962821 864609 2069.02904  234   51 2068.00000 2069.03331  0.05%   5.7 3359s
#  963708 865372 2069.02180  269   50 2068.00000 2069.03331  0.05%   5.7 3364s
#  964539 866183 2069.03217  112   60 2068.00000 2069.03331  0.05%   5.7 3369s
#  965350 867139 2069.03070  152   47 2068.00000 2069.03331  0.05%   5.7 3375s
#  966358 867978 2069.02957  193   45 2068.00000 2069.03331  0.05%   5.7 3380s
#  967223 868809 2069.02822  228   47 2068.00000 2069.03331  0.05%   5.7 3386s
#  968145 869625 2069.03307   74   44 2068.00000 2069.03331  0.05%   5.7 3391s
#  969011 870423 2069.03217  126   51 2068.00000 2069.03331  0.05%   5.7 3396s
#  969809 871311 2069.03055  167   56 2068.00000 2069.03331  0.05%   5.7 3401s
#  970729 872154 2069.02958  205   57 2068.00000 2069.03331  0.05%   5.7 3407s
#  971630 873049 2069.02839  232   62 2068.00000 2069.03331  0.05%   5.7 3413s
#  972583 873053 2069.01444  265   60 2068.00000 2069.03331  0.05%   5.7 3417s
#  972589 873811 2069.01444  266   64 2068.00000 2069.03331  0.05%   5.7 3422s
#  973486 874790 2069.03217  112   44 2068.00000 2069.03331  0.05%   5.7 3428s
#  974465 875814 2069.03020  158   53 2068.00000 2069.03331  0.05%   5.7 3433s
#  975529 876713 2069.02898  205   58 2068.00000 2069.03331  0.05%   5.7 3439s
#  976323 876713 2069.02664  244   56 2068.00000 2069.03331  0.05%   5.7 3440s
#  976470 877596 2069.02777  233   59 2068.00000 2069.03331  0.05%   5.7 3445s
#  977407 878456 2069.03251   97   52 2068.00000 2069.03331  0.05%   5.7 3450s
#  979046 880156 2069.03010  179   66 2068.00000 2069.03331  0.05%   5.7 3459s
#  980043 881105 2069.02925  217   64 2068.00000 2069.03331  0.05%   5.7 3464s
#  981054 882025 2069.02667  247   72 2068.00000 2069.03331  0.05%   5.7 3469s
#  982041 882843 2069.03323   79   67 2068.00000 2069.03331  0.05%   5.7 3476s
#  982966 883495 2069.03217  141   56 2068.00000 2069.03331  0.05%   5.7 3481s
#  983618 884430 2069.03072  166   69 2068.00000 2069.03331  0.05%   5.7 3487s
#  984561 885382 2069.02992  208   70 2068.00000 2069.03331  0.05%   5.7 3495s
#  985539 886268 2069.02926  230   64 2068.00000 2069.03331  0.05%   5.7 3502s
#  986466 887181 2069.02808  260   79 2068.00000 2069.03331  0.05%   5.7 3509s
#  987521 887906 2069.03315   75   53 2068.00000 2069.03331  0.05%   5.7 3515s
#  988246 888846 2069.03270   96   43 2068.00000 2069.03331  0.05%   5.7 3524s
#  989217 889834 2069.03228  123   53 2068.00000 2069.03331  0.05%   5.7 3533s
#  990224 890676 2069.03190  149   67 2068.00000 2069.03331  0.05%   5.7 3540s
#  991080 891443 2069.03101  163   60 2068.00000 2069.03331  0.05%   5.7 3546s
#  991849 892400 2069.03055  184   61 2068.00000 2069.03331  0.05%   5.7 3553s
#  992852 893376 2069.02977  206   51 2068.00000 2069.03331  0.05%   5.7 3559s
#  993364 893376 2069.00253  216   48 2068.00000 2069.03331  0.05%   5.7 3560s
#  994535 894981 2069.02839  241   54 2068.00000 2069.03331  0.05%   5.7 3571s
#  995601 895833 2069.02778  264   56 2068.00000 2069.03331  0.05%   5.7 3576s
#  996494 896762 2069.03045  104   34 2068.00000 2069.03331  0.05%   5.7 3582s
#  997483 897665 2069.02912  151   42 2068.00000 2069.03331  0.05%   5.7 3588s
#  998431 898586 2069.02794  196   42 2068.00000 2069.03331  0.05%   5.7 3594s
#  999404 899160 2069.02737  219   45 2068.00000 2069.03331  0.05%   5.7 3600s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 1
#   MIR: 73
#   Flow cover: 96
#
# Explored 1000033 nodes (5667575 simplex iterations) in 3601.54 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2068 2067 2066 ... 1962
#
# Time limit reached
# Best objective 2.068000000000e+03, best bound 2.069000000000e+03, gap 0.0484%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4.5x1

# %%
datafile="3x3000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x7ba16f4c
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1833.0000000
# Presolve removed 36 rows and 27 columns (presolve time = 9s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 13s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 24s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 25s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 30s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 35s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 40s) ...
# Presolve removed 36 rows and 27 columns (presolve time = 46s) ...
# Presolve removed 36 rows and 27 columns
# Presolve time: 46.13s
# Presolved: 11964 rows, 8973 columns, 13432599 nonzeros
# Variable types: 0 continuous, 8973 integer (8973 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9910000e+03   5.025972e+06   0.000000e+00     49s
#      452    2.0486769e+03   1.583482e+06   0.000000e+00     52s
#     1012    1.9636382e+03   9.766277e+05   0.000000e+00     56s
#     2358    1.9452852e+03   0.000000e+00   0.000000e+00     58s
#
# Root relaxation: objective 1.945285e+03, 2358 iterations, 10.48 seconds
# Total elapsed time = 61.65s
# Total elapsed time = 65.23s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1945.28521    0  180 1833.00000 1945.28521  6.13%     -   66s
# H    0     0                    1932.0000000 1945.28521  0.69%     -   66s
# H    0     0                    1941.0000000 1945.28521  0.22%     -   66s
# H    0     0                    1942.0000000 1945.28521  0.17%     -   69s
# H    0     0                    1943.0000000 1945.28521  0.12%     -   70s
#      0     0 1944.51664    0  162 1943.00000 1944.51664  0.08%     -   82s
#      0     0 1944.51276    0  179 1943.00000 1944.51276  0.08%     -   92s
#      0     0 1944.51202    0  169 1943.00000 1944.51202  0.08%     -   95s
#      0     0 1944.51202    0  169 1943.00000 1944.51202  0.08%     -   97s
#      0     0 1944.46123    0  130 1943.00000 1944.46123  0.08%     -  108s
#      0     0 1944.44484    0  128 1943.00000 1944.44484  0.07%     -  114s
#      0     0 1944.44109    0  120 1943.00000 1944.44109  0.07%     -  117s
#      0     0 1944.43526    0  123 1943.00000 1944.43526  0.07%     -  120s
#      0     0 1944.40061    0  117 1943.00000 1944.40061  0.07%     -  132s
#      0     0 1944.36966    0  105 1943.00000 1944.36966  0.07%     -  136s
#      0     0 1944.36949    0  114 1943.00000 1944.36949  0.07%     -  139s
#      0     0 1944.35628    0  111 1943.00000 1944.35628  0.07%     -  150s
#      0     0 1944.35628    0  110 1943.00000 1944.35628  0.07%     -  153s
#      0     0 1944.35628    0  113 1943.00000 1944.35628  0.07%     -  164s
#      0     0 1944.35586    0  111 1943.00000 1944.35586  0.07%     -  169s
#      0     0 1944.35249    0  103 1943.00000 1944.35249  0.07%     -  173s
#      0     0 1944.35249    0  120 1943.00000 1944.35249  0.07%     -  176s
#      0     0 1944.34346    0   78 1943.00000 1944.34346  0.07%     -  201s
#      0     0 1944.34346    0   88 1943.00000 1944.34346  0.07%     -  205s
#      0     0 1944.27524    0  102 1943.00000 1944.27524  0.07%     -  215s
#      0     0 1944.27524    0  108 1943.00000 1944.27524  0.07%     -  222s
#      0     0 1944.27524    0  102 1943.00000 1944.27524  0.07%     -  232s
#      0     0 1944.27524    0  113 1943.00000 1944.27524  0.07%     -  236s
#      0     0 1944.27524    0   79 1943.00000 1944.27524  0.07%     -  256s
#      0     0 1944.27511    0   91 1943.00000 1944.27511  0.07%     -  260s
#      0     0 1944.27511    0   74 1943.00000 1944.27511  0.07%     -  276s
#      0     0 1944.27511    0   79 1943.00000 1944.27511  0.07%     -  280s
#      0     0 1944.27511    0   86 1943.00000 1944.27511  0.07%     -  286s
#      0     0 1944.27511    0   61 1943.00000 1944.27511  0.07%     -  295s
#      0     0 1944.27511    0  179 1943.00000 1944.27511  0.07%     -  346s
#      0     0 1944.27511    0  113 1943.00000 1944.27511  0.07%     -  380s
#      0     0 1944.27511    0   99 1943.00000 1944.27511  0.07%     -  384s
#      0     0 1944.27511    0   89 1943.00000 1944.27511  0.07%     -  386s
#      0     0 1944.27511    0   92 1943.00000 1944.27511  0.07%     -  388s
#      0     0 1944.27511    0   92 1943.00000 1944.27511  0.07%     -  390s
#      0     0 1944.27511    0   99 1943.00000 1944.27511  0.07%     -  422s
#      0     0 1944.27511    0   91 1943.00000 1944.27511  0.07%     -  427s
#      0     0 1944.27511    0   93 1943.00000 1944.27511  0.07%     -  434s
#      0     0 1944.27511    0  100 1943.00000 1944.27511  0.07%     -  439s
#      0     0 1944.27511    0   73 1943.00000 1944.27511  0.07%     -  452s
#      0     0 1944.27511    0   79 1943.00000 1944.27511  0.07%     -  456s
#      0     0 1944.27511    0   76 1943.00000 1944.27511  0.07%     -  471s
#      0     0 1944.27511    0   85 1943.00000 1944.27511  0.07%     -  475s
#      0     0 1944.27511    0   92 1943.00000 1944.27511  0.07%     -  485s
#      0     0 1944.27511    0  104 1943.00000 1944.27511  0.07%     -  489s
#      0     0 1944.27511    0   89 1943.00000 1944.27511  0.07%     -  502s
#      0     0 1944.27511    0  107 1943.00000 1944.27511  0.07%     -  507s
#      0     0 1944.27511    0   91 1943.00000 1944.27511  0.07%     -  518s
#      0     0 1944.27511    0   79 1943.00000 1944.27511  0.07%     -  526s
#      0     2 1944.27511    0   79 1943.00000 1944.27511  0.07%     -  544s
#      1     5 1944.27234    1   82 1943.00000 1944.27234  0.07%   975  546s
#      7    14 1944.26465    3   88 1943.00000 1944.27230  0.07%   173  551s
#     25    32 1944.26384    6   93 1943.00000 1944.26465  0.07%  68.3  555s
#     31    38 1944.26384    7   93 1943.00000 1944.26465  0.07%  55.9  560s
#     63    70 1944.26111   12   93 1943.00000 1944.26465  0.07%  29.7  571s
#     69   100 1944.26111   13   93 1943.00000 1944.26465  0.07%  27.6  579s
#     99   167 1944.25921   18   93 1943.00000 1944.26465  0.07%  20.5  590s
#    166   409 1944.25812   25   93 1943.00000 1944.26465  0.07%  14.2  621s
#    417   836 1944.24048   70   86 1943.00000 1944.26465  0.07%   9.4  677s
#    850  1021 1944.20528  130  113 1943.00000 1944.26465  0.07%   7.1  789s
#   1048  1309 1944.19436  163  111 1943.00000 1944.26465  0.07%   6.5  837s
#   1500  1913 1944.06736   48  102 1943.00000 1944.26465  0.07%   6.0  898s
#   2210  2409     cutoff  103      1943.00000 1944.26465  0.07%   5.9  948s
#   2773  2410 1944.18091   13   61 1943.00000 1944.26465  0.07%   6.1 1265s
#   2799  2427 1944.12586   29   58 1943.00000 1944.12586  0.06%   6.0 1270s
#   2822  2444 1944.07455  157   87 1943.00000 1944.11263  0.06%  12.9 1275s
#   2841  2456 1944.08846   42   57 1943.00000 1944.11255  0.06%  12.8 1280s
#   4199  3303 1944.03726  114   50 1943.00000 1944.10564  0.06%  23.0 1285s
#   6677  4554 1944.07481  289   39 1943.00000 1944.10202  0.06%  17.1 1290s
#  10205  6658 1944.08274   33   78 1943.00000 1944.09959  0.06%  12.8 1295s
#  15748  9763 1944.02548   92   51 1943.00000 1944.09782  0.06%  10.8 1300s
#  19959 10850 1944.07656   30   69 1943.00000 1944.08541  0.06%  11.5 1305s
#  23288 11732 1944.00890   43   72 1943.00000 1944.08156  0.06%  14.0 1310s
#  25879 11580 1944.02094   42   63 1943.00000 1944.07582  0.06%  15.3 1315s
#  28699 10460     cutoff  141      1943.00000 1944.06519  0.05%  16.4 1320s
#  32119  9024     cutoff   42      1943.00000 1944.05073  0.05%  17.8 1326s
#  34728  7088 1944.01321   63   64 1943.00000 1944.03789  0.05%  18.3 1330s
#  37817  4515     cutoff   45      1943.00000 1944.02244  0.05%  18.8 1335s
#  41592  1097     cutoff   39      1943.00000 1944.00835  0.05%  19.2 1341s
# Cutting planes:
#   Gomory: 60
#   Cover: 53
#   Implied bound: 4
#   MIR: 168
#   StrongCG: 14
#   Flow cover: 198
#   GUB cover: 7
#   Zero half: 15
#   RLT: 6
#   Relax-and-lift: 3
#
# Explored 44092 nodes (856268 simplex iterations) in 1344.14 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1943 1942 1941 ... 1833
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.943000000000e+03, best bound 1.943000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4.5x2

# %%
datafile="3x3000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xe33f2cb7
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1837.0000000
# Presolve removed 45 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 13s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 23s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 25s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 30s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 35s) ...
# Presolve removed 48 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 48 rows and 36 columns
# Presolve time: 42.74s
# Presolved: 11952 rows, 8964 columns, 13405677 nonzeros
# Variable types: 0 continuous, 8964 integer (8964 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9880000e+03   4.994063e+06   0.000000e+00     45s
#      971    1.9926861e+03   5.820118e+04   0.000000e+00     51s
#     2469    1.9522395e+03   0.000000e+00   0.000000e+00     53s
#
# Root relaxation: objective 1.952240e+03, 2469 iterations, 9.10 seconds
# Total elapsed time = 56.40s
# Total elapsed time = 60.43s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1952.23952    0  205 1837.00000 1952.23952  6.27%     -   63s
# H    0     0                    1949.0000000 1952.23952  0.17%     -   64s
# H    0     0                    1950.0000000 1952.23952  0.11%     -   66s
#      0     0 1952.21838    0  233 1950.00000 1952.21838  0.11%     -  113s
# H    0     0                    1951.0000000 1952.21838  0.06%     -  124s
#      0     0 1952.21122    0  224 1951.00000 1952.21122  0.06%     -  127s
#      0     0 1952.21122    0  223 1951.00000 1952.21122  0.06%     -  129s
#      0     0 1952.18298    0  184 1951.00000 1952.18298  0.06%     -  148s
#      0     0 1952.18298    0  211 1951.00000 1952.18298  0.06%     -  180s
#      0     0 1952.18298    0  199 1951.00000 1952.18298  0.06%     -  209s
#      0     0 1952.18298    0  173 1951.00000 1952.18298  0.06%     -  213s
#      0     0 1952.18056    0  168 1951.00000 1952.18056  0.06%     -  216s
#      0     0 1952.18053    0  169 1951.00000 1952.18053  0.06%     -  217s
#      0     0 1952.17776    0  160 1951.00000 1952.17776  0.06%     -  225s
#      0     0 1952.17751    0  174 1951.00000 1952.17751  0.06%     -  231s
#      0     0 1952.17751    0  168 1951.00000 1952.17751  0.06%     -  232s
#      0     0 1952.17718    0  179 1951.00000 1952.17718  0.06%     -  240s
#      0     0 1952.17709    0  182 1951.00000 1952.17709  0.06%     -  243s
#      0     0 1952.17401    0  165 1951.00000 1952.17401  0.06%     -  251s
#      0     0 1952.17355    0  164 1951.00000 1952.17355  0.06%     -  253s
#      0     0 1952.17355    0  156 1951.00000 1952.17355  0.06%     -  255s
#      0     0 1952.17355    0  160 1951.00000 1952.17355  0.06%     -  262s
#      0     0 1952.17355    0  160 1951.00000 1952.17355  0.06%     -  265s
#      0     0 1952.17355    0  161 1951.00000 1952.17355  0.06%     -  272s
#      0     0 1952.17355    0  154 1951.00000 1952.17355  0.06%     -  274s
#      0     0 1952.17340    0  144 1951.00000 1952.17340  0.06%     -  284s
#      0     0 1952.17340    0  142 1951.00000 1952.17340  0.06%     -  290s
#      0     2 1952.17340    0  142 1951.00000 1952.17340  0.06%     -  304s
#      1     5 1952.15489    1  143 1951.00000 1952.15489  0.06%   178  305s
#     13    17 1952.13546    4  160 1951.00000 1952.13638  0.06%  72.6  310s
#     31    30 1952.12890    5  158 1951.00000 1952.13638  0.06%  74.0  318s
#     56    57 1952.12484    7  156 1951.00000 1952.13638  0.06%  46.8  320s
#     83   132 1952.11885   13  142 1951.00000 1952.13638  0.06%  34.3  325s
#    142   208 1952.11763   20  138 1951.00000 1952.13638  0.06%  22.8  333s
#    245   409 1952.08873   33  137 1951.00000 1952.13638  0.06%  16.6  348s
#    520   642 1952.02324   25  102 1951.00000 1952.13638  0.06%  13.0  367s
#    835   979 1952.00971   65  101 1951.00000 1952.13546  0.06%  12.2  391s
#   1297   980 1952.00768   46  184 1951.00000 1952.12983  0.06%  12.3  587s
#   1309   988 1952.03988   14  126 1951.00000 1952.03988  0.05%  12.1  590s
#   1329  1002 1952.02036   28  156 1951.00000 1952.02036  0.05%  32.4  595s
#   1355  1023 1952.00681   28   34 1951.00000 1952.00681  0.05%  44.6  600s
#   2119  1826 1952.00550   39   45 1951.00000 1952.00681  0.05%  31.4  606s
#   4240  2594 1952.00435   52   50 1951.00000 1952.00681  0.05%  19.9  610s
#   6776  4411 1952.00496   40   40 1951.00000 1952.00650  0.05%  15.8  615s
#  10545  7244 1952.00500   45   47 1951.00000 1952.00631  0.05%  13.1  620s
#  13610 11028 1951.99937   60   70 1951.00000 1952.00631  0.05%  12.2  631s
#  18273 12296 1952.00435   39   49 1951.00000 1952.00631  0.05%  11.4  635s
#  22283 14939     cutoff   59      1951.00000 1952.00600  0.05%  11.0  640s
#  26307 17022 1952.00385   58  184 1951.00000 1952.00600  0.05%  10.6  665s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 6
#   Implied bound: 2
#   MIR: 47
#   StrongCG: 2
#   Flow cover: 82
#   GUB cover: 3
#   RLT: 2
#
# Explored 26312 nodes (293323 simplex iterations) in 666.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1951 1950 1949 1837
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.951000000000e+03, best bound 1.951000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4.5x3

# %%
datafile="3x3000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x25361e2f
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1849.0000000
# Presolve removed 15 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 13s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 24s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 18 rows and 9 columns
# Presolve time: 44.71s
# Presolved: 11982 rows, 8991 columns, 13486488 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   5.014649e+06   0.000000e+00     47s
#      748    1.9876504e+03   1.154372e+06   0.000000e+00     51s
#     2272    1.9480351e+03   0.000000e+00   0.000000e+00     55s
#
# Root relaxation: objective 1.948035e+03, 2272 iterations, 8.70 seconds
# Total elapsed time = 58.10s
# Total elapsed time = 60.38s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1948.03514    0  121 1849.00000 1948.03514  5.36%     -   63s
# H    0     0                    1938.0000000 1948.03514  0.52%     -   64s
# H    0     0                    1945.0000000 1948.03514  0.16%     -   64s
# H    0     0                    1946.0000000 1948.03514  0.10%     -   66s
#      0     0 1947.94984    0  115 1946.00000 1947.94984  0.10%     -  113s
# H    0     0                    1947.0000000 1947.94984  0.05%     -  123s
#      0     0 1947.94984    0  115 1947.00000 1947.94984  0.05%     -  123s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 6
#   MIR: 16
#   StrongCG: 2
#   GUB cover: 3
#   RLT: 1
#
# Explored 1 nodes (4406 simplex iterations) in 123.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1947 1946 1945 ... 1849
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.947000000000e+03, best bound 1.947000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4.5x4

# %%
datafile="3x3000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x204c4476
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1829.0000000
# Presolve removed 28 rows and 21 columns (presolve time = 6s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 15s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 24s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 25s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 30s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 40s) ...
# Presolve removed 28 rows and 21 columns (presolve time = 45s) ...
# Presolve removed 28 rows and 21 columns
# Presolve time: 45.40s
# Presolved: 11972 rows, 8979 columns, 13450566 nonzeros
# Variable types: 0 continuous, 8979 integer (8979 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9930000e+03   5.030272e+06   0.000000e+00     48s
#      387    2.0846965e+03   1.041768e+06   0.000000e+00     51s
#     1425    1.9428696e+03   1.064838e+04   0.000000e+00     56s
#     2454    1.9411798e+03   0.000000e+00   0.000000e+00     57s
#
# Root relaxation: objective 1.941180e+03, 2454 iterations, 10.47 seconds
# Total elapsed time = 60.53s
# Total elapsed time = 65.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1941.17979    0  182 1829.00000 1941.17979  6.13%     -   66s
# H    0     0                    1935.0000000 1941.17979  0.32%     -   67s
# H    0     0                    1938.0000000 1941.17979  0.16%     -   69s
#      0     0 1940.29162    0  174 1938.00000 1940.29162  0.12%     -   81s
# H    0     0                    1939.0000000 1940.29162  0.07%     -   89s
#      0     0 1940.27680    0  151 1939.00000 1940.27680  0.07%     -   91s
#      0     0 1940.27680    0  148 1939.00000 1940.27680  0.07%     -   94s
#      0     0 1940.26525    0  127 1939.00000 1940.26525  0.07%     -  105s
#      0     0 1940.26525    0  132 1939.00000 1940.26525  0.07%     -  109s
#      0     0 1940.26388    0  137 1939.00000 1940.26388  0.07%     -  120s
#      0     0 1940.26388    0  133 1939.00000 1940.26388  0.07%     -  125s
#      0     0 1940.16530    0  118 1939.00000 1940.16530  0.06%     -  137s
#      0     0 1940.16407    0  113 1939.00000 1940.16407  0.06%     -  142s
#      0     0 1940.16407    0  112 1939.00000 1940.16407  0.06%     -  145s
#      0     0 1940.16264    0   97 1939.00000 1940.16264  0.06%     -  171s
#      0     0 1940.16264    0  192 1939.00000 1940.16264  0.06%     -  215s
#      0     0 1940.16264    0  179 1939.00000 1940.16264  0.06%     -  243s
#      0     0 1940.16264    0  170 1939.00000 1940.16264  0.06%     -  248s
#      0     0 1940.16264    0  153 1939.00000 1940.16264  0.06%     -  250s
#      0     0 1940.16264    0  159 1939.00000 1940.16264  0.06%     -  251s
#      0     0 1940.10553    0  149 1939.00000 1940.10553  0.06%     -  278s
#      0     0 1940.10520    0  140 1939.00000 1940.10520  0.06%     -  282s
#      0     0 1940.10520    0  140 1939.00000 1940.10520  0.06%     -  283s
#      0     0 1940.10502    0  146 1939.00000 1940.10502  0.06%     -  289s
#      0     0 1940.10502    0  144 1939.00000 1940.10502  0.06%     -  292s
#      0     0 1940.10502    0  143 1939.00000 1940.10502  0.06%     -  297s
#      0     0 1940.10429    0  144 1939.00000 1940.10429  0.06%     -  300s
#      0     0 1940.10429    0  147 1939.00000 1940.10429  0.06%     -  302s
#      0     0 1940.10429    0  108 1939.00000 1940.10429  0.06%     -  312s
#      0     0 1940.10424    0  110 1939.00000 1940.10424  0.06%     -  316s
#      0     0 1940.10424    0  113 1939.00000 1940.10424  0.06%     -  321s
#      0     0 1940.10424    0  116 1939.00000 1940.10424  0.06%     -  324s
#      0     0 1940.10424    0  120 1939.00000 1940.10424  0.06%     -  328s
#      0     0 1940.10424    0  125 1939.00000 1940.10424  0.06%     -  331s
#      0     0 1940.10423    0  122 1939.00000 1940.10423  0.06%     -  339s
#      0     0 1940.10423    0  102 1939.00000 1940.10423  0.06%     -  350s
#      0     2 1940.10423    0  101 1939.00000 1940.10423  0.06%     -  367s
#      3     8 1940.10087    2  105 1939.00000 1940.10087  0.06%  65.7  371s
#     13    20 1940.09727    4  103 1939.00000 1940.09727  0.06%  36.8  376s
#     31    38 1940.09606    7  101 1939.00000 1940.09606  0.06%  19.5  382s
#     43    64 1940.09606    9   98 1939.00000 1940.09606  0.06%  15.0  386s
#     63   103 1940.09337   12   96 1939.00000 1940.09404  0.06%  11.1  391s
#    102   183 1940.09149   17   94 1939.00000 1940.09404  0.06%   8.2  418s
#    182   378 1940.08612   27  100 1939.00000 1940.09404  0.06%   6.4  446s
#    399   730 1940.07240   51  107 1939.00000 1940.09384  0.06%   4.9  497s
#    772  1195 1940.04768   50   83 1939.00000 1940.09384  0.06%   5.1  543s
#   1316  1329 1940.08209   24  102 1939.00000 1940.09187  0.06%   4.8  585s
#   1465  1330 1940.07319   92   97 1939.00000 1940.09187  0.06%   5.0  769s
# H 1466  1264                    1940.0000000 1940.09187  0.00%   5.0  861s
#
# Cutting planes:
#   Gomory: 100
#   Cover: 4
#   MIR: 32
#   StrongCG: 7
#   Flow cover: 31
#   GUB cover: 2
#
# Explored 1466 nodes (32769 simplex iterations) in 862.17 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1940 1939 1938 ... 1829
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.940000000000e+03, best bound 1.940000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x4.5x5

# %%
datafile="3x3000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xd5877ce9
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 1862.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 18s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 20s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 30s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 39.10s
# Presolved: 11970 rows, 8982 columns, 13459518 nonzeros
# Variable types: 0 continuous, 8982 integer (8982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   4.936213e+06   0.000000e+00     42s
#     1007    1.9816835e+03   1.840253e+05   0.000000e+00     46s
#     2238    1.9608703e+03   0.000000e+00   0.000000e+00     49s
#
# Root relaxation: objective 1.960870e+03, 2238 iterations, 7.93 seconds
# Total elapsed time = 51.85s
# Total elapsed time = 56.06s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1960.87034    0   74 1862.00000 1960.87034  5.31%     -   57s
# H    0     0                    1954.0000000 1960.87034  0.35%     -   57s
# H    0     0                    1958.0000000 1960.87034  0.15%     -   58s
# H    0     0                    1959.0000000 1960.87034  0.10%     -   60s
#      0     0 1960.83762    0   73 1959.00000 1960.83762  0.09%     -   73s
# H    0     0                    1960.0000000 1960.83762  0.04%     -   84s
#      0     0 1960.83762    0   73 1960.00000 1960.83762  0.04%     -   84s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 64
#   MIR: 64
#   StrongCG: 39
#   RLT: 2
#
# Explored 1 nodes (4531 simplex iterations) in 84.27 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1960 1959 1958 ... 1862
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.960000000000e+03, best bound 1.960000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x5x1

# %%
datafile="3x3000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x9b3939e1
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1745.0000000
# Presolve removed 21 rows and 9 columns (presolve time = 6s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 18s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 20s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 25s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 9 columns
# Presolve time: 38.78s
# Presolved: 11979 rows, 8991 columns, 13486476 nonzeros
# Variable types: 0 continuous, 8991 integer (8991 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9970000e+03   5.015037e+06   0.000000e+00     41s
#      655    1.9299589e+03   2.983598e+05   0.000000e+00     46s
#     2451    1.8387879e+03   0.000000e+00   0.000000e+00     50s
#
# Root relaxation: objective 1.838788e+03, 2451 iterations, 9.76 seconds
# Total elapsed time = 55.42s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1838.78794    0  167 1745.00000 1838.78794  5.37%     -   60s
# H    0     0                    1836.0000000 1838.78794  0.15%     -   60s
# H    0     0                    1837.0000000 1838.78794  0.10%     -   64s
#      0     0 1838.78467    0  202 1837.00000 1838.78467  0.10%     -   75s
# H    0     0                    1838.0000000 1838.78467  0.04%     -   85s
#      0     0 1838.78467    0  202 1838.00000 1838.78467  0.04%     -   85s
#
# Cutting planes:
#   Gomory: 8
#   MIR: 33
#
# Explored 1 nodes (5173 simplex iterations) in 85.24 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1838 1837 1836 1745
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.838000000000e+03, best bound 1.838000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x5x2

# %%
datafile="3x3000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xb997396f
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1730.0000000
# Presolve removed 43 rows and 30 columns (presolve time = 6s) ...
# Presolve removed 43 rows and 30 columns (presolve time = 18s) ...
# Presolve removed 43 rows and 30 columns (presolve time = 20s) ...
# Presolve removed 43 rows and 30 columns (presolve time = 25s) ...
# Presolve removed 43 rows and 30 columns (presolve time = 30s) ...
# Presolve removed 43 rows and 30 columns (presolve time = 35s) ...
# Presolve removed 43 rows and 30 columns
# Presolve time: 39.14s
# Presolved: 11957 rows, 8970 columns, 13423599 nonzeros
# Variable types: 0 continuous, 8970 integer (8970 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9900000e+03   5.123328e+06   0.000000e+00     42s
#      651    1.9504471e+03   7.251897e+05   0.000000e+00     46s
#     1789    1.8395257e+03   1.402846e+04   0.000000e+00     50s
#     2284    1.8392199e+03   0.000000e+00   0.000000e+00     51s
#
# Root relaxation: objective 1.839220e+03, 2284 iterations, 10.18 seconds
# Total elapsed time = 55.69s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1839.21992    0   53 1730.00000 1839.21992  6.31%     -   59s
# H    0     0                    1835.0000000 1839.21992  0.23%     -   59s
# H    0     0                    1837.0000000 1839.21992  0.12%     -   61s
# H    0     0                    1838.0000000 1839.21992  0.07%     -   63s
#      0     0 1839.21665    0   42 1838.00000 1839.21665  0.07%     -  102s
#      0     0 1839.21665    0   59 1838.00000 1839.21665  0.07%     -  137s
#      0     0 1839.21570    0   59 1838.00000 1839.21570  0.07%     -  162s
#      0     0 1839.17071    0   59 1838.00000 1839.17071  0.06%     -  168s
#      0     0 1839.17069    0   59 1838.00000 1839.17069  0.06%     -  169s
#      0     0 1839.08466    0   51 1838.00000 1839.08466  0.06%     -  175s
#      0     0 1839.00096    0   50 1838.00000 1839.00096  0.05%     -  177s
#      0     0 1839.00096    0   50 1838.00000 1839.00096  0.05%     -  178s
#      0     0 1839.00085    0   41 1838.00000 1839.00085  0.05%     -  183s
#      0     0 1839.00085    0   39 1838.00000 1839.00085  0.05%     -  186s
#      0     0 1839.00085    0   45 1838.00000 1839.00085  0.05%     -  190s
#      0     0 1839.00085    0   42 1838.00000 1839.00085  0.05%     -  193s
#      0     0 1839.00085    0   34 1838.00000 1839.00085  0.05%     -  200s
#      0     0 1839.00085    0   35 1838.00000 1839.00085  0.05%     -  202s
#      0     0 1839.00085    0   33 1838.00000 1839.00085  0.05%     -  208s
#      0     0 1839.00085    0   31 1838.00000 1839.00085  0.05%     -  210s
#      0     0 1839.00085    0   30 1838.00000 1839.00085  0.05%     -  217s
#      0     0 1839.00085    0   31 1838.00000 1839.00085  0.05%     -  221s
#      0     0 1839.00085    0   32 1838.00000 1839.00085  0.05%     -  226s
#      0     0 1839.00085    0   35 1838.00000 1839.00085  0.05%     -  228s
#      0     0 1839.00085    0   33 1838.00000 1839.00085  0.05%     -  234s
#      0     0 1839.00085    0   33 1838.00000 1839.00085  0.05%     -  236s
#      0     0 1839.00085    0   29 1838.00000 1839.00085  0.05%     -  242s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1
#   MIR: 8
#   RLT: 2
#
# Explored 1 nodes (17928 simplex iterations) in 244.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1838 1837 1835 ... 1730
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.838000000000e+03, best bound 1.838000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x5x3

# %%
datafile="3x3000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0xcffaeb93
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1746.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 6s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 16s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 25s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 30s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 40s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 46s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 45.87s
# Presolved: 11970 rows, 8982 columns, 13459503 nonzeros
# Variable types: 0 continuous, 8982 integer (8982 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9940000e+03   5.153444e+06   0.000000e+00     48s
#      384    2.0000106e+03   1.118777e+06   0.000000e+00     51s
#     1254    1.8599239e+03   2.508245e+05   0.000000e+00     56s
#     2271    1.8473467e+03   0.000000e+00   0.000000e+00     57s
#
# Root relaxation: objective 1.847347e+03, 2271 iterations, 9.95 seconds
# Total elapsed time = 60.16s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1847.34675    0  120 1746.00000 1847.34675  5.80%     -   65s
# H    0     0                    1831.0000000 1847.34675  0.89%     -   65s
# H    0     0                    1844.0000000 1847.34675  0.18%     -   65s
# H    0     0                    1846.0000000 1847.34675  0.07%     -   68s
#      0     0 1847.33200    0  131 1846.00000 1847.33200  0.07%     -  106s
#      0     0 1847.30561    0  113 1846.00000 1847.30561  0.07%     -  114s
#      0     0 1847.30470    0  108 1846.00000 1847.30470  0.07%     -  116s
#      0     0 1847.30470    0  108 1846.00000 1847.30470  0.07%     -  118s
#      0     0 1847.20457    0  107 1846.00000 1847.20457  0.07%     -  129s
#      0     0 1847.20349    0  107 1846.00000 1847.20349  0.07%     -  134s
#      0     0 1847.20349    0  107 1846.00000 1847.20349  0.07%     -  136s
#      0     0 1847.18357    0   84 1846.00000 1847.18357  0.06%     -  154s
#      0     0 1847.18357    0  130 1846.00000 1847.18357  0.06%     -  191s
#      0     0 1847.18357    0  112 1846.00000 1847.18357  0.06%     -  214s
#      0     0 1847.18357    0   97 1846.00000 1847.18357  0.06%     -  219s
#      0     0 1847.18357    0   97 1846.00000 1847.18357  0.06%     -  220s
#      0     0 1847.15950    0   78 1846.00000 1847.15950  0.06%     -  226s
#      0     0 1847.14214    0   84 1846.00000 1847.14214  0.06%     -  229s
#      0     0 1847.10233    0   86 1846.00000 1847.10233  0.06%     -  231s
#      0     0 1847.10233    0   88 1846.00000 1847.10233  0.06%     -  232s
#      0     0     cutoff    0      1846.00000 1846.00000  0.00%     -  237s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 21
#   MIR: 95
#   StrongCG: 23
#   GUB cover: 1
#   Mod-K: 1
#   RLT: 1
#
# Explored 1 nodes (15701 simplex iterations) in 237.31 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1846 1844 1831 1746
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.846000000000e+03, best bound 1.846000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x5x4

# %%
datafile="3x3000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x76037a86
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1748.0000000
# Presolve removed 57 rows and 45 columns (presolve time = 6s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 13s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 15s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 25s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 25s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 30s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 35s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 40s) ...
# Presolve removed 60 rows and 45 columns (presolve time = 45s) ...
# Presolve removed 60 rows and 45 columns
# Presolve time: 45.44s
# Presolved: 11940 rows, 8955 columns, 13378785 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9850000e+03   5.017979e+06   0.000000e+00     48s
#      485    1.9879963e+03   2.922020e+06   0.000000e+00     51s
#     1095    1.8895241e+03   2.046722e+05   0.000000e+00     55s
#     2527    1.8567446e+03   0.000000e+00   0.000000e+00     58s
#
# Root relaxation: objective 1.856745e+03, 2527 iterations, 11.03 seconds
# Total elapsed time = 61.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1856.74456    0  160 1748.00000 1856.74456  6.22%     -   65s
# H    0     0                    1841.0000000 1856.74456  0.86%     -   66s
# H    0     0                    1853.0000000 1856.74456  0.20%     -   66s
# H    0     0                    1854.0000000 1856.74456  0.15%     -   69s
#      0     0 1856.70102    0  170 1854.00000 1856.70102  0.15%     -  111s
# H    0     0                    1855.0000000 1856.70102  0.09%     -  121s
#      0     0 1856.53430    0  173 1855.00000 1856.53430  0.08%     -  124s
#      0     0 1856.53430    0  172 1855.00000 1856.53430  0.08%     -  126s
#      0     0 1856.37326    0  139 1855.00000 1856.37326  0.07%     -  137s
#      0     0 1856.37298    0  135 1855.00000 1856.37298  0.07%     -  143s
#      0     0 1856.37298    0  134 1855.00000 1856.37298  0.07%     -  146s
#      0     0 1856.35296    0  122 1855.00000 1856.35296  0.07%     -  156s
#      0     0 1856.35285    0  125 1855.00000 1856.35285  0.07%     -  164s
#      0     0 1856.35273    0  130 1855.00000 1856.35273  0.07%     -  174s
#      0     0 1856.35244    0  136 1855.00000 1856.35244  0.07%     -  180s
#      0     0 1856.35244    0  125 1855.00000 1856.35244  0.07%     -  182s
#      0     0 1856.33862    0  105 1855.00000 1856.33862  0.07%     -  192s
#      0     0 1856.33862    0  107 1855.00000 1856.33862  0.07%     -  196s
#      0     0 1856.33862    0  114 1855.00000 1856.33862  0.07%     -  205s
#      0     0 1856.33862    0  105 1855.00000 1856.33862  0.07%     -  209s
#      0     0 1856.33862    0  107 1855.00000 1856.33862  0.07%     -  222s
#      0     0 1856.33862    0  108 1855.00000 1856.33862  0.07%     -  225s
#      0     0 1856.33862    0  108 1855.00000 1856.33862  0.07%     -  238s
#      0     0 1856.33862    0  104 1855.00000 1856.33862  0.07%     -  241s
#      0     0 1856.33862    0   88 1855.00000 1856.33862  0.07%     -  259s
#      0     0 1856.33862    0   90 1855.00000 1856.33862  0.07%     -  265s
#      0     0 1856.33862    0   94 1855.00000 1856.33862  0.07%     -  309s
#      0     0 1856.33862    0   90 1855.00000 1856.33862  0.07%     -  315s
#      0     0 1856.33862    0  164 1855.00000 1856.33862  0.07%     -  362s
#      0     0 1856.33862    0  146 1855.00000 1856.33862  0.07%     -  394s
#      0     0 1856.33862    0  127 1855.00000 1856.33862  0.07%     -  399s
#      0     0 1856.33862    0  117 1855.00000 1856.33862  0.07%     -  401s
#      0     0 1856.33862    0  120 1855.00000 1856.33862  0.07%     -  403s
#      0     0 1856.33854    0  119 1855.00000 1856.33854  0.07%     -  410s
#      0     0 1856.33854    0  115 1855.00000 1856.33854  0.07%     -  413s
#      0     0 1856.33854    0  108 1855.00000 1856.33854  0.07%     -  420s
#      0     0 1856.33854    0  114 1855.00000 1856.33854  0.07%     -  423s
#      0     0 1856.33854    0   93 1855.00000 1856.33854  0.07%     -  436s
#      0     0 1856.33854    0   99 1855.00000 1856.33854  0.07%     -  439s
#      0     0 1856.33854    0  102 1855.00000 1856.33854  0.07%     -  449s
#      0     0 1856.33854    0   98 1855.00000 1856.33854  0.07%     -  453s
#      0     0 1856.33854    0  119 1855.00000 1856.33854  0.07%     -  463s
#      0     0 1856.33854    0  110 1855.00000 1856.33854  0.07%     -  467s
#      0     0 1856.33854    0   93 1855.00000 1856.33854  0.07%     -  478s
#      0     0 1856.33854    0   94 1855.00000 1856.33854  0.07%     -  481s
#      0     0 1856.33854    0  105 1855.00000 1856.33854  0.07%     -  491s
#      0     0 1856.33854    0  101 1855.00000 1856.33854  0.07%     -  499s
#      0     2 1856.33854    0   95 1855.00000 1856.33854  0.07%     -  518s
#      1     5 1856.33036    1   92 1855.00000 1856.33036  0.07%   312  521s
#      3     7 1856.30231    2   99 1855.00000 1856.32860  0.07%   129  525s
#     13    17 1856.16257    4  115 1855.00000 1856.32860  0.07%  62.9  531s
#     31    32 1856.25045    6  115 1855.00000 1856.32860  0.07%  42.1  537s
#     55    49 1856.15536    9  107 1855.00000 1856.32860  0.07%  31.0  540s
#     62    64 1856.15278   10  106 1855.00000 1856.32860  0.07%  28.6  545s
#     82   105 1856.15245   13  100 1855.00000 1856.32860  0.07%  23.6  550s
#    127   145 1856.14903   20   98 1855.00000 1856.32860  0.07%  19.3  557s
#    186   187 infeasible   26      1855.00000 1856.32860  0.07%  17.1  567s
#    241   257 infeasible    6      1855.00000 1856.32860  0.07%  15.0  577s
#    339   343 1856.08888   17   95 1855.00000 1856.32860  0.07%  13.7  588s
#    437   364 1856.07234   32   92 1855.00000 1856.32860  0.07%  11.8  597s
#    481   404 1856.06697   32   97 1855.00000 1856.32860  0.07%  11.2  609s
#    558   473 1856.04857   41  105 1855.00000 1856.32860  0.07%  10.6  621s
#    681   599 1856.09291   15  105 1855.00000 1856.32833  0.07%  11.3  635s
#    839   690 1856.08225   34   78 1855.00000 1856.32833  0.07%  10.2  647s
#    956   792 1856.05305   46   66 1855.00000 1856.32833  0.07%  10.0  659s
#   1090   899 1856.04358   56   49 1855.00000 1856.32833  0.07%   9.7  671s
#   1211   960 1856.02990   71   49 1855.00000 1856.32833  0.07%   9.2  682s
#   1334   961 1856.02881   42   90 1855.00000 1856.32833  0.07%   9.1  857s
#   1336   962 1856.16037   14  155 1855.00000 1856.32833  0.07%   9.1  991s
#   1337   963 1856.04215   36  107 1855.00000 1856.32833  0.07%   9.0  996s
#   1339   964 1856.04880   29  105 1855.00000 1856.30671  0.07%   9.0 1001s
#   1341   966 1856.06063   24  107 1855.00000 1856.29859  0.07%   9.0 1026s
#   1342   966 1856.05946   17  109 1855.00000 1856.25851  0.07%   9.0 1031s
#   1344   968 1856.04699   39   95 1855.00000 1856.22063  0.07%   9.0 1035s
#   1345   968 1856.05784   41  111 1855.00000 1856.22063  0.07%   9.0 1058s
#   1346   969 1856.02175   55  117 1855.00000 1856.22063  0.07%   9.0 1062s
#   1347   970 1856.09291   16  117 1855.00000 1856.22028  0.07%   9.0 1067s
#   1348   970 1856.05842   41  110 1855.00000 1856.21894  0.07%   9.0 1070s
#   1349   971 1856.02745   40  108 1855.00000 1856.21894  0.07%   9.0 1088s
#   1350   972 1856.05260   37  104 1855.00000 1856.21894  0.07%   9.0 1091s
#   1351   972 1856.20678   10  105 1855.00000 1856.21894  0.07%   9.0 1111s
#   1352   973 1856.04693   38  104 1855.00000 1856.21894  0.07%   8.9 1116s
#   1353   974 1856.04150   47  113 1855.00000 1856.21894  0.07%   8.9 1142s
#   1354   974 1856.04161   33  108 1855.00000 1856.21894  0.07%   8.9 1171s
#   1355   975 1856.04752   23  118 1855.00000 1856.21849  0.07%   8.9 1175s
#   1357   976 1856.05201    9  121 1855.00000 1856.21617  0.07%   8.9 1203s
#   1358   977 1856.04651   37   95 1855.00000 1856.15297  0.06%   8.9 1230s
#   1360   978 1856.00818   47   93 1855.00000 1856.14893  0.06%   8.9 1235s
#   1362   980 1856.05952   28  104 1855.00000 1856.14574  0.06%   8.9 1240s
#   1364   981 1856.09531   12  112 1855.00000 1856.14054  0.06%   8.9 1258s
#   1365   982 1856.05305   44  185 1855.00000 1856.13526  0.06%   8.9 1266s
#   1366   982 1856.00190   10  186 1855.00000 1856.13526  0.06%   8.9 1285s
#   1367   983 1856.03116   55  145 1855.00000 1856.13098  0.06%   8.8 1291s
#   1368   984 1856.06349   21  137 1855.00000 1856.13098  0.06%   8.8 1304s
#   1369   984 1856.03505   37  138 1855.00000 1856.13098  0.06%   8.8 1308s
#   1370   985 1856.08342   16  142 1855.00000 1856.13098  0.06%   8.8 1322s
#   1371   986 1856.05305   41  139 1855.00000 1856.13098  0.06%   8.8 1326s
#   1372   986 1856.04992   36  131 1855.00000 1856.13097  0.06%   8.8 1343s
#   1373   987 1856.07327   26  120 1855.00000 1856.13097  0.06%   8.8 1347s
#   1374   988 1856.05305   45  120 1855.00000 1856.13097  0.06%   8.8 1363s
#   1375   988 1856.07539   24  111 1855.00000 1856.13097  0.06%   8.8 1368s
#   1376   989 1856.08091   18  117 1855.00000 1856.13097  0.06%   8.8 1382s
#   1377   990 1856.03862   79  121 1855.00000 1856.10824  0.06%   8.8 1389s
#   1378   990 1856.03162   51  128 1855.00000 1856.10824  0.06%   8.8 1403s
#   1379   991 1856.08256   31  113 1855.00000 1856.10821  0.06%   8.8 1408s
#   1380   992 1856.05920   36  116 1855.00000 1856.10818  0.06%   8.8 1425s
#   1382   993 1856.08080   12   95 1855.00000 1856.09365  0.06%   8.8 1432s
#   1383   994 1856.01399    7  116 1855.00000 1856.09365  0.06%   8.7 1447s
#   1384   994 1856.03307   90  124 1855.00000 1856.09365  0.06%   8.7 1450s
#   1385   995 1856.06735   24  119 1855.00000 1856.09365  0.06%   8.7 1464s
#   1386   996 1856.04109   46  123 1855.00000 1856.09365  0.06%   8.7 1467s
#   1387   996 1856.05456   17  112 1855.00000 1856.09365  0.06%   8.7 1483s
#   1388   997 1856.01465   55  109 1855.00000 1856.09365  0.06%   8.7 1506s
#   1389   998 1856.03827   38   99 1855.00000 1856.09358  0.06%   8.7 1522s
#   1390   998 1856.04590   39  107 1855.00000 1856.09358  0.06%   8.7 1547s
#   1391   999 1856.09358    7  109 1855.00000 1856.09358  0.06%   8.7 1563s
#   1392  1000 1856.07112   19  105 1855.00000 1856.09358  0.06%   8.7 1568s
#   1393  1000 1856.03322   87  121 1855.00000 1856.09358  0.06%   8.7 1585s
#   1395  1002 1856.02311   48  103 1855.00000 1856.09358  0.06%   8.7 1600s
#   1397  1004 1856.03270   53   90 1855.00000 1856.09358  0.06%  21.2 1784s
#   1399  1005 1856.05227   31  123 1855.00000 1856.09358  0.06%  21.2 1785s
#   1435  1022 1856.04503   32   51 1855.00000 1856.04503  0.06%  37.9 1790s
#   2864  2113 1856.02198   79   48 1855.00000 1856.03653  0.06%  23.9 1795s
#   4585  3130 1856.01695   79   50 1855.00000 1856.03431  0.06%  17.6 1800s
#   7619  5415 1856.01136   65   52 1855.00000 1856.02857  0.06%  13.6 1805s
#  10219  7421 1856.01990   66   56 1855.00000 1856.02729  0.06%  12.1 1811s
# H10872   351                    1856.0000000 1856.02729  0.00%  12.1 1814s
#
# Cutting planes:
#   Gomory: 31
#   Cover: 1
#   Implied bound: 1
#   MIR: 34
#   StrongCG: 1
#   Flow cover: 53
#   GUB cover: 4
#   Zero half: 1
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 10876 nodes (144015 simplex iterations) in 1814.48 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1856 1855 1854 ... 1748
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.856000000000e+03, best bound 1.856000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x3000x5x5

# %%
datafile="3x3000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 9000 columns and 13513500 nonzeros
# Model fingerprint: 0x78c40797
# Variable types: 0 continuous, 9000 integer (9000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1725.0000000
# Presolve removed 29 rows and 15 columns (presolve time = 7s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 16s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 23s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 25s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 61s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 75s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 80s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 85s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 90s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 95s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 100s) ...
# Presolve removed 29 rows and 15 columns (presolve time = 107s) ...
# Presolve removed 29 rows and 15 columns
# Presolve time: 106.81s
# Presolved: 11971 rows, 8985 columns, 13468488 nonzeros
# Variable types: 0 continuous, 8985 integer (8985 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   5.051359e+06   0.000000e+00    110s
#      384    1.9814200e+03   1.405919e+06   0.000000e+00    116s
#      964    1.8798352e+03   1.152606e+05   0.000000e+00    124s
#     1364    1.8452362e+03   1.846767e+05   0.000000e+00    127s
#     2357    1.8370699e+03   0.000000e+00   0.000000e+00    130s
#
# Root relaxation: objective 1.837070e+03, 2357 iterations, 21.13 seconds
# Total elapsed time = 136.77s
# Total elapsed time = 141.78s
# Total elapsed time = 145.45s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1837.06991    0  143 1725.00000 1837.06991  6.50%     -  147s
# H    0     0                    1824.0000000 1837.06991  0.72%     -  148s
# H    0     0                    1835.0000000 1837.06991  0.11%     -  148s
#      0     0 1836.75325    0  143 1835.00000 1836.75325  0.10%     -  205s
# H    0     0                    1836.0000000 1836.75325  0.04%     -  223s
#      0     0 1836.75325    0  143 1836.00000 1836.75325  0.04%     -  223s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 8
#   MIR: 38
#   StrongCG: 2
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (5564 simplex iterations) in 223.44 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1836 1835 1824 1725
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.836000000000e+03, best bound 1.836000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x1.5x1

# %%
datafile="4x3000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x4ed68fac
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2999.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 9 rows and 4 columns (presolve time = 13s) ...
# Presolve removed 9 rows and 4 columns (presolve time = 31s) ...
# Presolve removed 9 rows and 4 columns (presolve time = 49s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 73s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 88s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 122s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 125s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 130s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 135s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 140s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 145s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 150s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 155s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 160s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 165s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 170s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 175s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 182s) ...
# Presolve removed 13 rows and 4 columns
# Presolve time: 182.01s
# Presolved: 14987 rows, 11996 columns, 18005976 nonzeros
# Variable types: 0 continuous, 11996 integer (11996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   0.000000e+00   5.671500e+03    197s
# Concurrent spin time: 0.35s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 2999 iterations, 13.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2999.00000 2999.00000  0.00%     -  198s
#
# Explored 0 nodes (2999 simplex iterations) in 198.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.999000000000e+03, best bound 2.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x1.5x2

# %%
datafile="4x3000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xae707ee7
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2999.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 13s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 31s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 48s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 82s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 85s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 95s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 100s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 105s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 110s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 115s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 120s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 125s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 130s) ...
# Presolve removed 13 rows and 4 columns (presolve time = 139s) ...
# Presolve removed 13 rows and 4 columns
# Presolve time: 138.98s
# Presolved: 14987 rows, 11996 columns, 18005984 nonzeros
# Variable types: 0 continuous, 11996 integer (11996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9990000e+03   0.000000e+00   5.699250e+03    154s
# Concurrent spin time: 0.35s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 2999 iterations, 13.20 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2999.00000 2999.00000  0.00%     -  155s
#
# Explored 0 nodes (2999 simplex iterations) in 155.70 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.999000000000e+03, best bound 2.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x1.5x3

# %%
datafile="4x3000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xfe19fdb8
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2998.0000000
# Presolve removed 4 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 13s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 31s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 49s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 72s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 87s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 90s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 121s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 125s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 130s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 135s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 140s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 145s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 150s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 155s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 160s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 165s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 170s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 175s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 186s) ...
# Presolve removed 18 rows and 8 columns
# Presolve time: 186.15s
# Presolved: 14982 rows, 11992 columns, 17993980 nonzeros
# Variable types: 0 continuous, 11992 integer (11992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9980000e+03   0.000000e+00   5.675250e+03    201s
# Concurrent spin time: 0.19s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 2998 iterations, 13.85 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2998.00000 2998.00000  0.00%     -  203s
#
# Explored 0 nodes (2998 simplex iterations) in 203.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.998000000000e+03, best bound 2.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x1.5x4

# %%
datafile="4x3000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x256054eb
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2996.0000000
# Presolve removed 24 rows and 16 columns (presolve time = 9s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 13s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 26s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 35s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 40s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 45s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 50s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 55s) ...
# Presolve removed 24 rows and 16 columns
# Presolve time: 55.05s
# Presolved: 14976 rows, 11984 columns, 17969984 nonzeros
# Variable types: 0 continuous, 11984 integer (11984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9950000e+03   0.000000e+00   5.684500e+03     63s
# Concurrent spin time: 0.67s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 2998 iterations, 6.84 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2996.00000 2996.00000  0.00%     -   63s
#
# Explored 0 nodes (2998 simplex iterations) in 64.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 2996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.996000000000e+03, best bound 2.996000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x1.5x5

# %%
datafile="4x3000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x06e58bd9
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2996.0000000
# Presolve removed 8 rows and 0 columns (presolve time = 8s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 11s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 19s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 22s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 8 rows and 0 columns
# Presolve time: 63.94s
# Presolved: 14992 rows, 12000 columns, 18017968 nonzeros
# Variable types: 0 continuous, 12000 integer (12000 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9960000e+03   0.000000e+00   5.629750e+03     71s
#     3419    2.9982110e+03   0.000000e+00   0.000000e+00     72s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.998211e+03, 3419 iterations, 6.53 seconds
# Total elapsed time = 75.18s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2998.21101    0   34 2996.00000 2998.21101  0.07%     -   80s
# H    0     0                    2997.0000000 2998.21101  0.04%     -   80s
#      0     0     cutoff    0      2997.00000 2997.00000  0.00%     -  151s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 23
#   MIR: 43
#   StrongCG: 69
#   GUB cover: 8
#   Mod-K: 1
#   RLT: 1
#
# Explored 1 nodes (7115 simplex iterations) in 151.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2997 2996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.997000000000e+03, best bound 2.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2x1

# %%
datafile="4x3000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x90a6ffff
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2976.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 8s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 11s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 18s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 34s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 35s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 60s) ...
# Presolve removed 33 rows and 20 columns
# Presolve time: 60.30s
# Presolved: 14967 rows, 11980 columns, 17958004 nonzeros
# Variable types: 0 continuous, 11980 integer (11980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9770000e+03   0.000000e+00   5.640500e+03     67s
#     3331    2.9807965e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.980797e+03, 3331 iterations, 6.01 seconds
# Total elapsed time = 75.80s
# Total elapsed time = 80.96s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2980.79654    0   80 2976.00000 2980.79654  0.16%     -   84s
# H    0     0                    2978.0000000 2980.79654  0.09%     -   86s
#      0     0 2980.79654    0   87 2978.00000 2980.79654  0.09%     -  147s
# H    0     0                    2979.0000000 2980.79654  0.06%     -  158s
#      0     0 2980.59519    0   93 2979.00000 2980.59519  0.05%     -  160s
#      0     0 2980.59491    0   93 2979.00000 2980.59491  0.05%     -  164s
#      0     0 2980.47763    0   84 2979.00000 2980.47763  0.05%     -  184s
#      0     0 2980.47763    0   89 2979.00000 2980.47763  0.05%     -  191s
#      0     0 2980.37072    0   95 2979.00000 2980.37072  0.05%     -  205s
#      0     0 2980.37072    0   88 2979.00000 2980.37072  0.05%     -  217s
#      0     0 2980.33389    0   81 2979.00000 2980.33389  0.04%     -  230s
#      0     0 2980.32466    0   87 2979.00000 2980.32466  0.04%     -  238s
#      0     0 2980.32447    0   75 2979.00000 2980.32447  0.04%     -  241s
#      0     0 2980.24396    0   73 2979.00000 2980.24396  0.04%     -  254s
#      0     0 2980.22693    0   53 2979.00000 2980.22693  0.04%     -  262s
#      0     0 2980.22693    0   58 2979.00000 2980.22693  0.04%     -  266s
#      0     0 2980.22693    0   76 2979.00000 2980.22693  0.04%     -  279s
#      0     0 2980.22693    0   62 2979.00000 2980.22693  0.04%     -  286s
#      0     0 2980.22693    0   66 2979.00000 2980.22693  0.04%     -  298s
#      0     0 2980.19077    0   66 2979.00000 2980.19077  0.04%     -  310s
#      0     0 2980.19022    0   76 2979.00000 2980.19022  0.04%     -  314s
#      0     0 2980.19022    0   73 2979.00000 2980.19022  0.04%     -  317s
#      0     0 2980.19022    0   56 2979.00000 2980.19022  0.04%     -  342s
#      0     0 2980.18386    0   57 2979.00000 2980.18386  0.04%     -  351s
#      0     0 2980.18386    0   50 2979.00000 2980.18386  0.04%     -  355s
#      0     0 2980.18386    0   61 2979.00000 2980.18386  0.04%     -  367s
#      0     0 2980.18386    0   67 2979.00000 2980.18386  0.04%     -  381s
#      0     0 2980.18386    0   65 2979.00000 2980.18386  0.04%     -  394s
#      0     0 2980.18386    0   63 2979.00000 2980.18386  0.04%     -  400s
#      0     0 2980.18386    0   50 2979.00000 2980.18386  0.04%     -  425s
#      0     0 2980.18386    0   60 2979.00000 2980.18386  0.04%     -  432s
#      0     0 2980.18386    0   54 2979.00000 2980.18386  0.04%     -  453s
#      0     0 2980.18386    0   73 2979.00000 2980.18386  0.04%     -  461s
#      0     0 2980.18386    0   54 2979.00000 2980.18386  0.04%     -  538s
#      0     0 2980.18386    0   54 2979.00000 2980.18386  0.04%     -  548s
#      0     2 2980.18386    0   53 2979.00000 2980.18386  0.04%     -  598s
#      1     2 infeasible    1      2979.00000 2980.18386  0.04%  4253  601s
#      5     4 2980.08342    3   50 2979.00000 2980.08342  0.04%   867  606s
#      7     8 2980.08342    4   52 2979.00000 2980.08342  0.04%   626  610s
#     11    14 2980.08173    5   63 2979.00000 2980.08342  0.04%   412  615s
#     17    20 2980.07565    6   54 2979.00000 2980.08342  0.04%   280  620s
#     29    32 2980.07565    7   54 2979.00000 2980.08342  0.04%   172  628s
#     35    39 2980.07565    8   54 2979.00000 2980.08342  0.04%   143  631s
#     49    69 2980.07565   10   50 2979.00000 2980.08342  0.04%   104  639s
#     72   120 2980.02166   14   55 2979.00000 2980.08342  0.04%  73.3  653s
#    133   217 2979.99730   19   46 2979.00000 2980.08342  0.04%  42.8  680s
#    242   374 2979.99730   35   46 2979.00000 2980.08004  0.04%  26.1  723s
#    424   712 2980.05566   14   35 2979.00000 2980.08004  0.04%  17.8  830s
#    828  1039 2980.01482   70   27 2979.00000 2980.08004  0.04%  11.9  956s
#   1203  1395 2979.99953  112   29 2979.00000 2980.08004  0.04%   9.7 1115s
#   1621  1396 2980.05566   20   54 2979.00000 2980.08004  0.04%   8.6 1387s
#   1623  1397 2980.05566  132   96 2979.00000 2980.08004  0.04%   8.6 1880s
#   1624  1398 2980.02866   83   63 2979.00000 2980.08004  0.04%   8.6 1976s
#   1625  1399 2980.05593   26   54 2979.00000 2980.08004  0.04%   8.5 1980s
#   1626  1399 2980.07565   13   58 2979.00000 2980.08004  0.04%   8.5 2047s
#   1627  1400 2980.06798   47   52 2979.00000 2980.08004  0.04%   8.5 2144s
#   1628  1401 2980.06798   47   52 2979.00000 2980.08004  0.04%   8.5 2220s
#   1629  1401 2980.04210  179   47 2979.00000 2980.08004  0.04%   8.5 2337s
#   1630  1402 2980.05566   59   46 2979.00000 2980.08004  0.04%   8.5 2398s
#   1631  1403 2979.99953  147   37 2979.00000 2980.08004  0.04%   8.5 2509s
#   1632  1403 2980.02141   66   52 2979.00000 2980.05566  0.04%   8.5 2514s
#   1633  1404 2979.99953  109   53 2979.00000 2980.05566  0.04%   8.5 2558s
#   1634  1405 2980.05566   19   41 2979.00000 2980.05566  0.04%   8.5 2651s
#   1635  1405 2980.05566   33   39 2979.00000 2980.05566  0.04%   8.5 2688s
#   1636  1406 2980.00606   37   37 2979.00000 2980.05566  0.04%   8.5 2774s
#   1637  1407 2980.05566   15   31 2979.00000 2980.05566  0.04%   8.5 2820s
#   1638  1407 2980.05033   51   27 2979.00000 2980.05566  0.04%   8.5 2889s
#   1639  1408 2979.99953  115   40 2979.00000 2980.05566  0.04%   8.5 2928s
#   1640  1409 2980.05566   34   27 2979.00000 2980.05566  0.04%   8.5 2960s
#   1641  1409 2980.05566   77   27 2979.00000 2980.05566  0.04%   8.5 2987s
#   1642  1410 2980.05566   16   27 2979.00000 2980.05566  0.04%   8.5 3045s
#   1643  1411 2980.05566   14   39 2979.00000 2980.05566  0.04%   8.5 3083s
#   1644  1411 2980.04910   90   38 2979.00000 2980.05566  0.04%   8.4 3145s
#   1645  1412 2980.05566   13   46 2979.00000 2980.05566  0.04%   8.4 3181s
#   1646  1413 2980.05566   13   36 2979.00000 2980.05566  0.04%   8.4 3244s
#   1647  1413 2980.04210  126   34 2979.00000 2980.05566  0.04%   8.4 3266s
#   1648  1414 2980.05566   28   34 2979.00000 2980.05566  0.04%   8.4 3320s
#   1649  1418 2980.05566   15   32 2979.00000 2980.05566  0.04%  46.4 3347s
#   1651  1419 infeasible   16      2979.00000 2980.05566  0.04%  46.3 3355s
#   1655  1424 2980.05566   17   33 2979.00000 2980.05566  0.04%  46.2 3365s
#   1661  1428 2980.05566   18   32 2979.00000 2980.05566  0.04%  46.1 3370s
#   1673  1436 2980.05566   20   28 2979.00000 2980.05566  0.04%  45.9 3378s
#   1679  1440 2980.05566   21   27 2979.00000 2980.05566  0.04%  45.7 3405s
#   1685  1446 2980.05566   22   28 2979.00000 2980.05566  0.04%  45.6 3410s
#   1694  1451 2980.05566   23   29 2979.00000 2980.05566  0.04%  45.4 3416s
#   1702  1455 2980.05566   25   31 2979.00000 2980.05566  0.04%  45.2 3421s
#   1709  1467 2980.05566   24   33 2979.00000 2980.05566  0.04%  45.1 3438s
#   1723  1526 2980.05566   26   32 2979.00000 2980.05566  0.04%  44.8 3463s
#   1787  1575 2980.05566   32   30 2979.00000 2980.05566  0.04%  43.5 3509s
#   1862  1693 2980.05566   35   37 2979.00000 2980.05566  0.04%  42.0 3593s
#   2026  1661 2980.05559   67   34 2979.00000 2980.05566  0.04%  39.2 3600s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 5
#   MIR: 5
#   Flow cover: 2
#
# Explored 2049 nodes (121718 simplex iterations) in 3603.03 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2979 2978 2976
#
# Time limit reached
# Best objective 2.979000000000e+03, best bound 2.980000000000e+03, gap 0.0336%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2x2

# %%
datafile="4x3000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xe98c6c72
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2988.0000000
# Presolve removed 8 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 23s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 8 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 8 rows and 0 columns
# Presolve time: 49.71s
# Presolved: 14992 rows, 12000 columns, 18017988 nonzeros
# Variable types: 0 continuous, 12000 integer (12000 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9880000e+03   0.000000e+00   5.678500e+03     56s
#     3386    2.9921235e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.992123e+03, 3386 iterations, 6.01 seconds
# Total elapsed time = 65.25s
# Total elapsed time = 73.07s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2992.12348    0  131 2988.00000 2992.12348  0.14%     -   76s
# H    0     0                    2990.0000000 2992.12348  0.07%     -   79s
#      0     0 2992.11928    0  112 2990.00000 2992.11928  0.07%     -   94s
#      0     0 2991.46037    0  121 2990.00000 2991.46037  0.05%     -  110s
#      0     0 2991.45940    0  135 2990.00000 2991.45940  0.05%     -  114s
#      0     0 2991.45940    0  135 2990.00000 2991.45940  0.05%     -  117s
#      0     0 2991.45655    0  134 2990.00000 2991.45655  0.05%     -  132s
#      0     0 2991.45655    0  129 2990.00000 2991.45655  0.05%     -  140s
#      0     0 2991.45655    0  123 2990.00000 2991.45655  0.05%     -  155s
#      0     0 2991.45655    0  107 2990.00000 2991.45655  0.05%     -  170s
#      0     0 2991.45655    0   77 2990.00000 2991.45655  0.05%     -  210s
#      0     0 2991.45655    0  103 2990.00000 2991.45655  0.05%     -  218s
#      0     0 2991.45650    0   90 2990.00000 2991.45650  0.05%     -  248s
#      0     0 2991.45531    0   87 2990.00000 2991.45531  0.05%     -  255s
#      0     0 2991.45531    0   94 2990.00000 2991.45531  0.05%     -  258s
#      0     0 2991.45531    0   99 2990.00000 2991.45531  0.05%     -  272s
#      0     0 2991.45531    0  123 2990.00000 2991.45531  0.05%     -  284s
#      0     0 2991.45531    0  127 2990.00000 2991.45531  0.05%     -  295s
#      0     0 2991.44925    0  127 2990.00000 2991.44925  0.05%     -  308s
#      0     0 2991.40438    0  127 2990.00000 2991.40438  0.05%     -  312s
#      0     0 2991.40438    0  123 2990.00000 2991.40438  0.05%     -  315s
#      0     0 2991.36031    0   85 2990.00000 2991.36031  0.05%     -  349s
#      0     0 2991.36031    0   88 2990.00000 2991.36031  0.05%     -  357s
#      0     0 2991.36031    0   95 2990.00000 2991.36031  0.05%     -  370s
#      0     0 2991.36031    0  101 2990.00000 2991.36031  0.05%     -  382s
#      0     0 2991.36031    0   95 2990.00000 2991.36031  0.05%     -  408s
#      0     0 2991.36031    0  106 2990.00000 2991.36031  0.05%     -  416s
#      0     0 2991.36031    0   93 2990.00000 2991.36031  0.05%     -  443s
#      0     0 2991.36031    0   76 2990.00000 2991.36031  0.05%     -  456s
#      0     2 2991.36031    0   76 2990.00000 2991.36031  0.05%     -  499s
#      1     4 2991.22408    1   81 2990.00000 2991.36031  0.05%  2327  502s
#      3     6 infeasible    2      2990.00000 2991.35928  0.05%   780  507s
#      7    12 2991.35826    3   98 2990.00000 2991.35826  0.05%   362  513s
#     13    18 2991.35826    4  106 2990.00000 2991.35826  0.05%   217  519s
#     19    24 2991.35826    4  109 2990.00000 2991.35826  0.05%   160  522s
#     25    30 2991.35826    5  113 2990.00000 2991.35826  0.05%   130  526s
#     31    36 2991.35826    5  113 2990.00000 2991.35826  0.05%   107  537s
#     37    44 2991.35826    6  110 2990.00000 2991.35826  0.05%  90.7  541s
#     53   100 2991.34668    8  100 2990.00000 2991.35826  0.05%  66.2  558s
#    101   172 2991.34326   13   99 2990.00000 2991.35826  0.05%  38.6  578s
#    173   291 2991.34326   19  102 2990.00000 2991.35826  0.05%  26.0  668s
# H  291   291                    2991.0000000 2991.35826  0.01%  18.8  668s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 49
#   MIR: 104
#   StrongCG: 2
#   RLT: 1
#
# Explored 292 nodes (51752 simplex iterations) in 669.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2991 2990 2988
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.991000000000e+03, best bound 2.991000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2x3

# %%
datafile="4x3000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xb8ae63b6
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2982.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 12s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 24s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 25s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 30s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 35s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 40s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 51s) ...
# Presolve removed 39 rows and 28 columns
# Presolve time: 51.28s
# Presolved: 14961 rows, 11972 columns, 17934052 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9810000e+03   0.000000e+00   5.661250e+03     59s
#     3636    2.9846691e+03   2.113968e-03   0.000000e+00     60s
#     3638    2.9846691e+03   0.000000e+00   0.000000e+00     60s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.984669e+03, 3638 iterations, 7.11 seconds
# Total elapsed time = 68.84s
# Total elapsed time = 72.65s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2984.66912    0  111 2982.00000 2984.66912  0.09%     -   75s
#      0     0 2984.66912    0  131 2982.00000 2984.66912  0.09%     -  142s
# H    0     0                    2983.0000000 2984.66912  0.06%     -  147s
#      0     0 2984.66912    0  127 2983.00000 2984.66912  0.06%     -  159s
#      0     0 2984.42755    0   68 2983.00000 2984.42755  0.05%     -  195s
#      0     0 2984.42755    0   67 2983.00000 2984.42755  0.05%     -  201s
#      0     0 2984.42755    0   74 2983.00000 2984.42755  0.05%     -  215s
#      0     0 2984.42755    0   84 2983.00000 2984.42755  0.05%     -  225s
#      0     0 2984.42755    0   64 2983.00000 2984.42755  0.05%     -  250s
#      0     0 2984.42755    0   79 2983.00000 2984.42755  0.05%     -  258s
#      0     0 2984.42755    0   67 2983.00000 2984.42755  0.05%     -  287s
#      0     0 2984.42755    0   73 2983.00000 2984.42755  0.05%     -  301s
#      0     0 2984.42755    0   56 2983.00000 2984.42755  0.05%     -  325s
#      0     0 2984.42755    0   71 2983.00000 2984.42755  0.05%     -  333s
#      0     0 2984.31376    0   64 2983.00000 2984.31376  0.04%     -  360s
#      0     0 2984.20875    0   63 2983.00000 2984.20875  0.04%     -  372s
#      0     0 2984.20875    0   63 2983.00000 2984.20875  0.04%     -  375s
#      0     0 2984.20875    0   64 2983.00000 2984.20875  0.04%     -  389s
#      0     0 2984.20875    0   67 2983.00000 2984.20875  0.04%     -  397s
#      0     0 2984.20875    0   67 2983.00000 2984.20875  0.04%     -  411s
#      0     0 2984.20875    0   69 2983.00000 2984.20875  0.04%     -  422s
#      0     0 2984.20875    0   55 2983.00000 2984.20875  0.04%     -  445s
#      0     0 2984.20875    0   58 2983.00000 2984.20875  0.04%     -  453s
#      0     0 2984.20875    0   53 2983.00000 2984.20875  0.04%     -  524s
#      0     0 2984.20875    0   66 2983.00000 2984.20875  0.04%     -  535s
#      0     0 2984.20875    0   56 2983.00000 2984.20875  0.04%     -  556s
#      0     0 2984.20875    0   56 2983.00000 2984.20875  0.04%     -  566s
#      0     2 2984.20875    0   52 2983.00000 2984.20875  0.04%     -  621s
#      3     4 2984.16780    2   55 2983.00000 2984.20875  0.04%  1030  627s
#      5     6     cutoff    3      2983.00000 2984.20875  0.04%   634  631s
#      9    12 2984.20875    4   62 2983.00000 2984.20875  0.04%   359  638s
#     15    14     cutoff    5      2983.00000 2984.20875  0.04%   229  644s
#     21    16     cutoff    5      2983.00000 2984.20875  0.04%   187  648s
#     27    22 2984.10983    6   66 2983.00000 2984.20875  0.04%   150  659s
#     33    28 2984.10983    7   63 2983.00000 2984.20875  0.04%   126  664s
#     39    36 2984.10983    8   59 2983.00000 2984.20875  0.04%   110  667s
#     47    44 2984.10983   10   57 2983.00000 2984.20875  0.04%  93.0  670s
#     63    58 2984.10983   13   57 2983.00000 2984.20875  0.04%  72.6  680s
#     69   127 2984.10983   14   52 2983.00000 2984.20875  0.04%  67.2  696s
#    140   140     cutoff   31      2983.00000 2984.20875  0.04%  37.7  718s
#    155   319 2984.00230   32   38 2983.00000 2984.20875  0.04%  34.5  758s
#    375   559 2984.00230   63   34 2983.00000 2984.20875  0.04%  18.2  825s
#    684   803 2984.00230  107   36 2983.00000 2984.20875  0.04%  13.3  895s
#    991   915 2984.00230  134   38 2983.00000 2984.20875  0.04%  11.6  961s
#   1129  1304 2984.00230  147   38 2983.00000 2984.20875  0.04%  11.1 1059s
#   1633  1305 2984.00230  114   56 2983.00000 2984.20875  0.04%   9.5 1338s
#   1635  1306 2984.04539   76  126 2983.00000 2984.20875  0.04%   9.5 1691s
#   1636  1307 2984.00230   44   69 2983.00000 2984.13271  0.04%   9.5 1768s
#   1637  1308 2984.00667   88   68 2983.00000 2984.13271  0.04%   9.5 1771s
#   1639  1309 2984.09238   17   66 2983.00000 2984.13271  0.04%   9.4 1835s
#   1640  1310 2984.04644  154   61 2983.00000 2984.13271  0.04%   9.4 1904s
#   1641  1310 2984.10202   19   78 2983.00000 2984.13271  0.04%   9.4 1911s
#   1643  1312 2984.04797  193   69 2983.00000 2984.12890  0.04%   9.4 1979s
#   1644  1312 2984.00230   56   57 2983.00000 2984.12890  0.04%   9.4 2032s
#   1645  1313 2984.09855   51   69 2983.00000 2984.12890  0.04%   9.4 2106s
#   1646  1314 2984.10983   43   62 2983.00000 2984.12890  0.04%   9.4 2138s
#   1647  1314 2984.00230   92   61 2983.00000 2984.12890  0.04%   9.4 2172s
#   1648  1315 2984.06563   51   43 2983.00000 2984.06563  0.04%   9.4 2219s
#   1649  1316 2984.06563   15   58 2983.00000 2984.06563  0.04%   9.4 2242s
#   1650  1316 2984.05813  114   52 2983.00000 2984.06563  0.04%   9.4 2283s
#   1651  1317 2984.03526   65   55 2983.00000 2984.06563  0.04%   9.4 2316s
#   1652  1318 2984.06563   18   52 2983.00000 2984.06563  0.04%   9.4 2351s
#   1653  1318 2984.06563   35   50 2983.00000 2984.06563  0.04%   9.4 2394s
#   1654  1319 2984.06563   41   44 2983.00000 2984.06563  0.04%   9.4 2448s
#   1655  1320 2984.00230  117   45 2983.00000 2984.06563  0.04%   9.4 2488s
#   1656  1320 2984.05811   64   47 2983.00000 2984.06563  0.04%   9.4 2542s
#   1657  1321 2984.06563   26   64 2983.00000 2984.06563  0.04%   9.3 2570s
#   1658  1322 2984.00667  100   53 2983.00000 2984.06563  0.04%   9.3 2603s
#   1659  1322 2984.06563   11   53 2983.00000 2984.06563  0.04%   9.3 2621s
#   1661  1325 2984.04539  108   56 2983.00000 2984.06563  0.04%  32.5 2891s
#   1663  1326 2983.99704  113  121 2983.00000 2984.06563  0.04%  32.4 3223s
#   1664  1327 2984.00230   88   63 2983.00000 2984.06563  0.04%  32.4 3511s
#   1665  1328 2984.06068   27   55 2983.00000 2984.06068  0.04%  32.4 3531s
#   1666  1328 2984.05352   89   58 2983.00000 2984.06068  0.04%  32.4 3570s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 21
#   MIR: 24
#   StrongCG: 5
#   Flow cover: 64
#   GUB cover: 1
#   RLT: 3
#
# Explored 1666 nodes (137376 simplex iterations) in 3601.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2983 2982
#
# Time limit reached
# Best objective 2.983000000000e+03, best bound 2.984000000000e+03, gap 0.0335%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2x4

# %%
datafile="4x3000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x7549485f
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2992.0000000
# Presolve removed 19 rows and 12 columns (presolve time = 8s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 11s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 18s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 21s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 33s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 23 rows and 12 columns
# Presolve time: 59.18s
# Presolved: 14977 rows, 11988 columns, 17981984 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9920000e+03   0.000000e+00   5.678250e+03     66s
#     3343    2.9942260e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.994226e+03, 3343 iterations, 5.89 seconds
# Total elapsed time = 75.66s
# Total elapsed time = 81.70s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2994.22603    0   96 2992.00000 2994.22603  0.07%     -   84s
#      0     0 2994.21452    0   87 2992.00000 2994.21452  0.07%     -  149s
# H    0     0                    2993.0000000 2994.21452  0.04%     -  160s
#      0     0 2994.20187    0   97 2993.00000 2994.20187  0.04%     -  162s
#      0     0 2994.20187    0   93 2993.00000 2994.20187  0.04%     -  166s
#      0     0 2994.20187    0   99 2993.00000 2994.20187  0.04%     -  179s
#      0     0 infeasible    0      2993.00000 2993.00000  0.00%     -  186s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 12
#   MIR: 166
#   StrongCG: 1
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (10943 simplex iterations) in 186.79 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 2993 2992
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.993000000000e+03, best bound 2.993000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2x5

# %%
datafile="4x3000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xed8e3323
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2963.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 8s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 11s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 18s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 20s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 33s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 35s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 58.98s
# Presolved: 14963 rows, 11980 columns, 17957972 nonzeros
# Variable types: 0 continuous, 11980 integer (11980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9620000e+03   0.000000e+00   5.671500e+03     65s
#     3616    2.9699207e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.969921e+03, 3616 iterations, 5.86 seconds
# Total elapsed time = 73.23s
# Total elapsed time = 76.93s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2969.92068    0  108 2963.00000 2969.92068  0.23%     -   81s
# H    0     0                    2968.0000000 2969.92068  0.06%     -   83s
#      0     0 2969.84825    0   97 2968.00000 2969.84825  0.06%     -  146s
# H    0     0                    2969.0000000 2969.84825  0.03%     -  159s
#      0     0 2969.84825    0   97 2969.00000 2969.84825  0.03%     -  159s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 8
#   MIR: 90
#   StrongCG: 1
#   GUB cover: 8
#
# Explored 1 nodes (13168 simplex iterations) in 159.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2969 2968 2963
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.969000000000e+03, best bound 2.969000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2.5x1

# %%
datafile="4x3000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x1a4d3188
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2609.0000000
# Presolve removed 51 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 11s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 18s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 20s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 32s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 35s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 40s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 51 rows and 28 columns
# Presolve time: 58.77s
# Presolved: 14949 rows, 11972 columns, 17934004 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6090000e+03   0.000000e+00   5.799000e+03     65s
#     4352    2.6626225e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.662622e+03, 4352 iterations, 6.74 seconds
# Total elapsed time = 74.44s
# Total elapsed time = 78.47s
# Total elapsed time = 83.57s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2662.62246    0  126 2609.00000 2662.62246  2.06%     -   86s
# H    0     0                    2659.0000000 2662.62246  0.14%     -   87s
# H    0     0                    2661.0000000 2662.62246  0.06%     -   90s
#      0     0 2662.62231    0  142 2661.00000 2662.62231  0.06%     -  145s
#      0     0 2662.61663    0  137 2661.00000 2662.61663  0.06%     -  160s
#      0     0 2662.61663    0  140 2661.00000 2662.61663  0.06%     -  164s
#      0     0 2662.57171    0  127 2661.00000 2662.57171  0.06%     -  177s
#      0     0 2662.51931    0  125 2661.00000 2662.51931  0.06%     -  192s
#      0     0 2662.51931    0  125 2661.00000 2662.51931  0.06%     -  195s
#      0     0 2662.41452    0  116 2661.00000 2662.41452  0.05%     -  209s
#      0     0 2662.41452    0  119 2661.00000 2662.41452  0.05%     -  221s
#      0     0 2662.41452    0  141 2661.00000 2662.41452  0.05%     -  234s
#      0     0 2662.41452    0  133 2661.00000 2662.41452  0.05%     -  241s
#      0     0 2662.41452    0  101 2661.00000 2662.41452  0.05%     -  271s
#      0     0 2662.41452    0  116 2661.00000 2662.41452  0.05%     -  285s
#      0     0 2662.36301    0   90 2661.00000 2662.36301  0.05%     -  310s
#      0     0 2662.36301    0   85 2661.00000 2662.36301  0.05%     -  317s
#      0     0 2662.36301    0   94 2661.00000 2662.36301  0.05%     -  330s
#      0     0 2662.36301    0   87 2661.00000 2662.36301  0.05%     -  340s
#      0     0 2662.36301    0   71 2661.00000 2662.36301  0.05%     -  362s
#      0     0 2662.36301    0   76 2661.00000 2662.36301  0.05%     -  369s
#      0     0 2662.36301    0   73 2661.00000 2662.36301  0.05%     -  438s
#      0     0 2662.36301    0   92 2661.00000 2662.36301  0.05%     -  447s
#      0     0 2662.36301    0   84 2661.00000 2662.36301  0.05%     -  470s
#      0     0 2662.36301    0   84 2661.00000 2662.36301  0.05%     -  480s
# H    0     0                    2662.0000000 2662.36301  0.01%     -  500s
#      0     0 2662.36301    0   84 2662.00000 2662.36301  0.01%     -  500s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 17
#   MIR: 27
#   StrongCG: 1
#
# Explored 1 nodes (52547 simplex iterations) in 500.99 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2662 2661 2659 2609
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.662000000000e+03, best bound 2.662000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2.5x2

# %%
datafile="4x3000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xb5b36c84
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2607.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 8s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 11s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 18s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 33s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 35s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 59.06s
# Presolved: 14963 rows, 11980 columns, 17957980 nonzeros
# Variable types: 0 continuous, 11980 integer (11980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6070000e+03   0.000000e+00   5.793250e+03     65s
#     4662    2.6661990e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.666199e+03, 4662 iterations, 6.80 seconds
# Total elapsed time = 75.22s
# Total elapsed time = 83.86s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2666.19904    0  291 2607.00000 2666.19904  2.27%     -   86s
# H    0     0                    2664.0000000 2666.19904  0.08%     -   86s
#      0     0 2666.18780    0  288 2664.00000 2666.18780  0.08%     -  147s
#      0     0 2666.02624    0  270 2664.00000 2666.02624  0.08%     -  167s
#      0     0 2665.95183    0  263 2664.00000 2665.95183  0.07%     -  171s
#      0     0 2665.95183    0  263 2664.00000 2665.95183  0.07%     -  174s
#      0     0 2665.93427    0  250 2664.00000 2665.93427  0.07%     -  188s
#      0     0 2665.90990    0  226 2664.00000 2665.90990  0.07%     -  196s
#      0     0 2665.90935    0  226 2664.00000 2665.90935  0.07%     -  199s
#      0     0 2665.90935    0  221 2664.00000 2665.90935  0.07%     -  202s
#      0     0 2665.90277    0  226 2664.00000 2665.90277  0.07%     -  216s
#      0     0 2665.90090    0  213 2664.00000 2665.90090  0.07%     -  231s
#      0     0 2665.90090    0  210 2664.00000 2665.90090  0.07%     -  235s
#      0     0 2665.89666    0  180 2664.00000 2665.89666  0.07%     -  249s
#      0     0 2665.89645    0  179 2664.00000 2665.89645  0.07%     -  257s
#      0     0 2665.89645    0  177 2664.00000 2665.89645  0.07%     -  270s
#      0     0 2665.89622    0  177 2664.00000 2665.89622  0.07%     -  282s
#      0     0 2665.89622    0  194 2664.00000 2665.89622  0.07%     -  295s
#      0     0 2665.89622    0  190 2664.00000 2665.89622  0.07%     -  304s
#      0     0 2665.89622    0  174 2664.00000 2665.89622  0.07%     -  317s
#      0     0 2665.89512    0  179 2664.00000 2665.89512  0.07%     -  324s
#      0     0 2665.89512    0  182 2664.00000 2665.89512  0.07%     -  328s
#      0     0 2665.89512    0  162 2664.00000 2665.89512  0.07%     -  358s
#      0     0 2665.89512    0  157 2664.00000 2665.89512  0.07%     -  366s
#      0     0 2665.89512    0  166 2664.00000 2665.89512  0.07%     -  380s
#      0     0 2665.89512    0  146 2664.00000 2665.89512  0.07%     -  407s
#      0     2 2665.89512    0  140 2664.00000 2665.89512  0.07%     -  470s
#      3     8 2665.72491    2  157 2664.00000 2665.89496  0.07%  1131  478s
#      7    14 2665.23712    3  174 2664.00000 2665.89486  0.07%   563  485s
#     13    20 2665.04921    4  187 2664.00000 2665.89486  0.07%   361  491s
#     19    26 2665.23712    4  177 2664.00000 2665.81026  0.07%   276  495s
#     31    38 2665.23712    5  173 2664.00000 2665.81026  0.07%   178  503s
#     37    46 2665.23712    6  174 2664.00000 2665.81026  0.07%   152  506s
#     45    70 2665.23642    6  169 2664.00000 2665.81026  0.07%   126  512s
#     69   113 2665.16652    7  166 2664.00000 2665.81026  0.07%  86.6  527s
#    116   221 2665.16324    9  156 2664.00000 2665.81026  0.07%  55.8  554s
#    226   426 2665.01279   20  150 2664.00000 2665.81026  0.07%  34.6  603s
#    437   735     cutoff   44      2664.00000 2665.81026  0.07%  22.1  692s
#    750  1047 2665.73270   36  151 2664.00000 2665.81026  0.07%  16.0  773s
# H 1013   645                    2665.0000000 2665.81026  0.03%  13.6  773s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 84
#   MIR: 182
#   StrongCG: 9
#   RLT: 1
#
# Explored 1062 nodes (40459 simplex iterations) in 774.37 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2665 2664 2607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.665000000000e+03, best bound 2.665000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2.5x3

# %%
datafile="4x3000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xd98b5aad
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2603.0000000
# Presolve removed 18 rows and 8 columns (presolve time = 8s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 18s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 33s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 8 columns
# Presolve time: 58.92s
# Presolved: 14978 rows, 11992 columns, 17993960 nonzeros
# Variable types: 0 continuous, 11992 integer (11992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6030000e+03   0.000000e+00   5.729750e+03     65s
#     4840    2.6618150e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.661815e+03, 4840 iterations, 6.84 seconds
# Total elapsed time = 74.35s
# Total elapsed time = 78.95s
# Total elapsed time = 80.76s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2661.81503    0  257 2603.00000 2661.81503  2.26%     -   83s
# H    0     0                    2658.0000000 2661.81503  0.14%     -   83s
# H    0     0                    2659.0000000 2661.81503  0.11%     -   85s
# H    0     0                    2660.0000000 2661.81503  0.07%     -   93s
#      0     0 2661.81034    0  292 2660.00000 2661.81034  0.07%     -  150s
#      0     0 2661.77416    0  309 2660.00000 2661.77416  0.07%     -  168s
#      0     0 2661.77416    0  310 2660.00000 2661.77416  0.07%     -  171s
#      0     0 2661.63895    0  252 2660.00000 2661.63895  0.06%     -  186s
#      0     0 2661.61312    0  251 2660.00000 2661.61312  0.06%     -  204s
#      0     0 2661.59565    0  253 2660.00000 2661.59565  0.06%     -  208s
#      0     0 2661.51849    0  242 2660.00000 2661.51849  0.06%     -  212s
#      0     0 2661.51849    0  238 2660.00000 2661.51849  0.06%     -  216s
#      0     0 2661.51008    0  226 2660.00000 2661.51008  0.06%     -  231s
#      0     0 2661.51008    0  225 2660.00000 2661.51008  0.06%     -  241s
#      0     0 2661.50927    0  226 2660.00000 2661.50927  0.06%     -  255s
#      0     0 2661.50777    0  220 2660.00000 2661.50777  0.06%     -  262s
#      0     0 2661.41558    0  212 2660.00000 2661.41558  0.05%     -  266s
#      0     0 2661.41558    0  220 2660.00000 2661.41558  0.05%     -  270s
#      0     0 2661.35718    0  255 2660.00000 2661.35718  0.05%     -  286s
#      0     0 2661.35526    0  236 2660.00000 2661.35526  0.05%     -  304s
#      0     0 2661.35526    0  237 2660.00000 2661.35526  0.05%     -  308s
#      0     0 2661.35449    0  212 2660.00000 2661.35449  0.05%     -  324s
#      0     0 2661.35449    0  207 2660.00000 2661.35449  0.05%     -  331s
#      0     0 2661.35169    0  200 2660.00000 2661.35169  0.05%     -  346s
#      0     0 2661.35169    0  197 2660.00000 2661.35169  0.05%     -  353s
#      0     0 2661.35000    0  188 2660.00000 2661.35000  0.05%     -  368s
#      0     0 2661.35000    0  197 2660.00000 2661.35000  0.05%     -  375s
#      0     0 2661.23183    0  180 2660.00000 2661.23183  0.05%     -  389s
#      0     0 2661.23183    0  167 2660.00000 2661.23183  0.05%     -  404s
#      0     0 2661.23183    0  175 2660.00000 2661.23183  0.05%     -  463s
#      0     0 2661.23183    0  173 2660.00000 2661.23183  0.05%     -  470s
#      0     0 2661.23183    0  142 2660.00000 2661.23183  0.05%     -  498s
#      0     0 2661.23183    0  154 2660.00000 2661.23183  0.05%     -  513s
#      0     0 2661.23183    0  136 2660.00000 2661.23183  0.05%     -  539s
#      0     0 2661.23183    0  162 2660.00000 2661.23183  0.05%     -  547s
#      0     0 2661.23183    0  134 2660.00000 2661.23183  0.05%     -  570s
#      0     0 2661.23183    0  132 2660.00000 2661.23183  0.05%     -  581s
#      0     2 2661.23183    0  128 2660.00000 2661.23183  0.05%     -  684s
#      1     2 infeasible    1      2660.00000 2661.23183  0.05%  1865  687s
#      3     4 2661.23183    2  140 2660.00000 2661.23183  0.05%   661  691s
#      5     8 2661.23183    3  145 2660.00000 2661.23183  0.05%   431  696s
#      9    14 2661.23183    4  144 2660.00000 2661.23183  0.05%   262  702s
#     15    20 2661.23183    5  144 2660.00000 2661.23183  0.05%   176  708s
#     21    24 2661.23183    6  141 2660.00000 2661.23183  0.05%   135  713s
#     27    30 2661.23183    7  137 2660.00000 2661.23183  0.05%   111  724s
#     33    36 2661.23183    8  136 2660.00000 2661.23183  0.05%  93.8  727s
#     39    44 2661.23183    8  132 2660.00000 2661.23183  0.05%  81.0  730s
#     47    66 2661.23183    9  130 2660.00000 2661.23183  0.05%  69.3  738s
#     69    72 2661.23183   11  135 2660.00000 2661.23183  0.05%  50.6  764s
#     75   152 2661.23183   12  132 2660.00000 2661.23183  0.05%  47.5  788s
#    155   330 2661.23003   23  127 2660.00000 2661.23183  0.05%  28.2  834s
#    288   330 2661.23003   34  147 2660.00000 2661.23183  0.05%  19.8  835s
#    333   489 2661.23003   41  131 2660.00000 2661.23183  0.05%  18.2  933s
#    492  1182 2661.21570   75  128 2660.00000 2661.23183  0.05%  15.3 1086s
#   1191  1629 2661.08544  162   92 2660.00000 2661.23183  0.05%  10.5 1182s
#   1647  2062 2661.06495  210  100 2660.00000 2661.23183  0.05%   9.2 1278s
#   2104  2482 2661.06495  254  104 2660.00000 2661.23183  0.05%   8.7 1385s
#   2555  2847 2661.04545  302   96 2660.00000 2661.23183  0.05%   8.4 1470s
#   2939  3000 2661.04203  351  105 2660.00000 2661.23183  0.05%   8.1 1539s
#   3094  3438 2661.04142  371   95 2660.00000 2661.23183  0.05%   8.1 1638s
#   3540  3854 2661.03895  424  100 2660.00000 2661.23183  0.05%   7.8 1737s
#   3992  4340 2661.00884  475   89 2660.00000 2661.23183  0.05%   7.6 1844s
#   4513  4955 2661.00524  534   83 2660.00000 2661.23183  0.05%   7.5 1965s
#   5184  5562 2661.00019  613   87 2660.00000 2661.23183  0.05%   7.3 2089s
#   5849  6180 2660.99746  700   87 2660.00000 2661.23183  0.05%   7.2 2222s
#   6526  6181 2661.12151  654  132 2660.00000 2661.23183  0.05%   7.2 2711s
#   6528  6182 2661.12049  206  243 2660.00000 2661.23183  0.05%   7.2 3047s
#   6529  6183 2661.12147  671  151 2660.00000 2661.23183  0.05%   7.2 3337s
#   6530  6184 2661.10156  800  155 2660.00000 2661.23183  0.05%   7.2 3349s
#   6531  6184 2661.09975   83  146 2660.00000 2661.20475  0.05%   7.2 3353s
#   6532  6185 2661.09404   85  132 2660.00000 2661.20437  0.05%   7.2 3356s
#   6533  6186 2661.20437   11  134 2660.00000 2661.20437  0.05%   7.2 3517s
#
# Cutting planes:
#   Gomory: 37
#   Cover: 57
#   MIR: 135
#   StrongCG: 92
#   Flow cover: 115
#   GUB cover: 16
#   RLT: 9
#
# Explored 6533 nodes (94150 simplex iterations) in 3601.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2660 2659 2658 2603
#
# Time limit reached
# Best objective 2.660000000000e+03, best bound 2.661000000000e+03, gap 0.0376%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2.5x4

# %%
datafile="4x3000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xfbc34d35
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2601.0000000
# Presolve removed 60 rows and 32 columns (presolve time = 8s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 11s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 23s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 25s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 30s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 35s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 60 rows and 32 columns
# Presolve time: 49.21s
# Presolved: 14940 rows, 11968 columns, 17922016 nonzeros
# Variable types: 0 continuous, 11968 integer (11968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6010000e+03   0.000000e+00   5.810750e+03     56s
#     4905    2.6583877e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.658388e+03, 4905 iterations, 6.78 seconds
# Total elapsed time = 65.13s
# Total elapsed time = 70.05s
# Total elapsed time = 75.97s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2658.38773    0  197 2601.00000 2658.38773  2.21%     -   77s
# H    0     0                    2655.0000000 2658.38773  0.13%     -   77s
# H    0     0                    2656.0000000 2658.38773  0.09%     -   79s
# H    0     0                    2657.0000000 2658.38773  0.05%     -   84s
#      0     0 2658.28511    0  210 2657.00000 2658.28511  0.05%     -   98s
#      0     0 infeasible    0      2657.00000 2657.00000  0.00%     -  108s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 5
#   MIR: 101
#   StrongCG: 1
#   RLT: 3
#
# Explored 1 nodes (16302 simplex iterations) in 108.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2657 2656 2655 2601
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.657000000000e+03, best bound 2.657000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x2.5x5

# %%
datafile="4x3000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xc4046c01
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2614.0000000
# Presolve removed 47 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 11s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 18s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 21s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 33s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 35s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 40s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 47 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 47 rows and 28 columns
# Presolve time: 59.00s
# Presolved: 14953 rows, 11972 columns, 17934012 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6130000e+03   0.000000e+00   5.793750e+03     65s
#     5210    2.6655964e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.665596e+03, 5210 iterations, 7.49 seconds
# Total elapsed time = 76.06s
# Total elapsed time = 80.93s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2665.59640    0  323 2614.00000 2665.59640  1.97%     -   86s
# H    0     0                    2662.0000000 2665.59640  0.14%     -   86s
# H    0     0                    2663.0000000 2665.59640  0.10%     -   96s
#      0     0 2665.59233    0  337 2663.00000 2665.59233  0.10%     -  156s
#      0     0 2665.57731    0  324 2663.00000 2665.57731  0.10%     -  177s
#      0     0 2665.54723    0  314 2663.00000 2665.54723  0.10%     -  181s
#      0     0 2665.54723    0  316 2663.00000 2665.54723  0.10%     -  184s
#      0     0 2665.48048    0  297 2663.00000 2665.48048  0.09%     -  200s
#      0     0 2665.47649    0  280 2663.00000 2665.47649  0.09%     -  207s
#      0     0 2665.47649    0  283 2663.00000 2665.47649  0.09%     -  210s
#      0     0 2665.46901    0  270 2663.00000 2665.46901  0.09%     -  226s
#      0     0 2665.46901    0  265 2663.00000 2665.46901  0.09%     -  242s
#      0     0 2665.15748    0  246 2663.00000 2665.15748  0.08%     -  259s
#      0     0 2665.15744    0  232 2663.00000 2665.15744  0.08%     -  278s
#      0     0 2665.04308    0  219 2663.00000 2665.04308  0.08%     -  293s
#      0     0 2665.04308    0  209 2663.00000 2665.04308  0.08%     -  299s
#      0     0 2665.04178    0  203 2663.00000 2665.04178  0.08%     -  314s
#      0     0 2665.04178    0  200 2663.00000 2665.04178  0.08%     -  320s
#      0     0 2665.04106    0  197 2663.00000 2665.04106  0.08%     -  334s
# H    0     0                    2664.0000000 2665.04106  0.04%     -  343s
#      0     0 2665.04104    0  179 2664.00000 2665.04104  0.04%     -  346s
#      0     0 2665.04104    0  189 2664.00000 2665.04104  0.04%     -  360s
#      0     0 2665.03841    0  183 2664.00000 2665.03841  0.04%     -  369s
#      0     0 2665.03295    0  188 2664.00000 2665.03295  0.04%     -  374s
#      0     0 2665.03295    0  191 2664.00000 2665.03295  0.04%     -  378s
#      0     0 2665.03295    0  194 2664.00000 2665.03295  0.04%     -  392s
#      0     0 2665.03292    0  187 2664.00000 2665.03292  0.04%     -  400s
#      0     0 2665.03285    0  196 2664.00000 2665.03285  0.04%     -  454s
#      0     0 2665.03285    0  198 2664.00000 2665.03285  0.04%     -  459s
#      0     0 2665.03282    0  199 2664.00000 2665.03282  0.04%     -  472s
#      0     0 2665.03282    0  194 2664.00000 2665.03282  0.04%     -  483s
#      0     0 2665.03282    0  190 2664.00000 2665.03282  0.04%     -  497s
#      0     0 2665.03282    0  154 2664.00000 2665.03282  0.04%     -  519s
#      0     2 2665.03282    0  154 2664.00000 2665.03282  0.04%     -  560s
#      3     4 2665.03282    2  162 2664.00000 2665.03282  0.04%  1032  567s
#      5     8 2665.03282    3  157 2664.00000 2665.03282  0.04%   671  572s
#      9    14 2665.03226    4  166 2664.00000 2665.03282  0.04%   426  580s
#     15    20 2665.03226    5  166 2664.00000 2665.03282  0.04%   294  585s
#     27    32 2665.03226    6  166 2664.00000 2665.03282  0.04%   187  599s
#     33    39 2665.03226    6  165 2664.00000 2665.03282  0.04%   154  602s
#     40    46 2665.03176    7  161 2664.00000 2665.03282  0.04%   135  605s
#     47    72 2665.03160    8  161 2664.00000 2665.03282  0.04%   117  611s
#     73    85 2665.02706   11  149 2664.00000 2665.03282  0.04%  80.3  628s
#     86   200 2665.02706   11  149 2664.00000 2665.03282  0.04%  69.4  676s
#    201   379 2665.02706   25  155 2664.00000 2665.03282  0.04%  36.6  737s
#    382   758 2665.02706   45  148 2664.00000 2665.03226  0.04%  23.8  880s
#    813  1157 2665.01689   50  168 2664.00000 2665.03226  0.04%  16.0  994s
#   1265  1766 2664.99772  117  155 2664.00000 2665.03226  0.04%  13.9 1133s
#   1948  1767 2665.02160  104  154 2664.00000 2665.03226  0.04%  12.4 1399s
#   1950  1768 2665.00819  193  293 2664.00000 2665.03226  0.04%  12.4 1631s
#   1951  1769 2665.03226    7  243 2664.00000 2665.03226  0.04%  12.4 1806s
#   1952  1770 2665.03200   56  209 2664.00000 2665.03226  0.04%  12.4 1813s
#   1953  1770 2665.02630   73  208 2664.00000 2665.03226  0.04%  12.4 1816s
#   1954  1771 2665.00943   22  202 2664.00000 2665.03226  0.04%  12.3 1821s
#   1955  1772 2665.03226   40  204 2664.00000 2665.03226  0.04%  12.3 1825s
#   1956  1772 2665.03226   15  200 2664.00000 2665.03226  0.04%  12.3 1976s
#   1957  1773 2665.01262  126  169 2664.00000 2665.03226  0.04%  12.3 2058s
#   1958  1774 2665.02795   48  159 2664.00000 2665.03159  0.04%  12.3 2065s
#   1959  1774 2665.02473  108  163 2664.00000 2665.03159  0.04%  12.3 2099s
#   1960  1775 2665.02473  125  158 2664.00000 2665.03159  0.04%  12.3 2166s
#   1961  1776 2665.00549  207  153 2664.00000 2665.03159  0.04%  12.3 2192s
#   1962  1776 2665.02626   56  161 2664.00000 2665.03159  0.04%  12.3 2245s
#   1963  1777 2665.01733   95  177 2664.00000 2665.03159  0.04%  12.3 2284s
#   1964  1778 2665.01262  105  153 2664.00000 2665.03159  0.04%  12.3 2362s
#   1965  1778 2665.02706   30  161 2664.00000 2665.03159  0.04%  12.3 2402s
#   1966  1779 2665.02482   47  173 2664.00000 2665.03093  0.04%  12.3 2455s
#   1968  1780 2665.02706   40  164 2664.00000 2665.03025  0.04%  12.3 2497s
#   1969  1781 2664.99938   48  157 2664.00000 2665.03025  0.04%  12.3 2557s
#   1970  1782 2665.02160  134  179 2664.00000 2665.03025  0.04%  12.2 2606s
#   1971  1782 2665.01262  149  157 2664.00000 2665.03025  0.04%  12.2 2667s
#   1972  1783 2665.01262   95  191 2664.00000 2665.03025  0.04%  12.2 2713s
#   1973  1784 2665.02160  155  175 2664.00000 2665.03025  0.04%  12.2 2767s
#   1974  1784 2665.03025   10  173 2664.00000 2665.03025  0.04%  12.2 2800s
#   1975  1785 2665.00819  184  146 2664.00000 2665.03025  0.04%  12.2 2881s
#   1976  1786 2665.02473  106  180 2664.00000 2665.03025  0.04%  12.2 2923s
#   1977  1786 2665.03025   31  146 2664.00000 2665.03025  0.04%  12.2 3000s
#   1978  1787 2664.99820  101  146 2664.00000 2665.03025  0.04%  12.2 3019s
#   1979  1788 2665.03025   59  146 2664.00000 2665.03025  0.04%  12.2 3067s
#   1980  1789 2664.99953   13  139 2664.00000 2664.99953  0.04%  29.4 3092s
#   1982  1789 2664.99772   14  138 2664.00000 2664.99953  0.04%  29.4 3095s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 4
#   MIR: 25
#   Flow cover: 25
#   RLT: 1
#
# Explored 1986 nodes (106541 simplex iterations) in 3099.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2664 2663 2662 2614
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.664000000000e+03, best bound 2.664000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3x1

# %%
datafile="4x3000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xf6e3a693
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2337.0000000
# Presolve removed 24 rows and 16 columns (presolve time = 8s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 11s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 23s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 25s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 35s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 40s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 45s) ...
# Presolve removed 24 rows and 16 columns
# Presolve time: 49.74s
# Presolved: 14976 rows, 11984 columns, 17970008 nonzeros
# Variable types: 0 continuous, 11984 integer (11984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3370000e+03   0.000000e+00   5.923500e+03     56s
#     4863    2.4219891e+03   0.000000e+00   0.000000e+00     59s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.421989e+03, 4863 iterations, 6.94 seconds
# Total elapsed time = 64.97s
# Total elapsed time = 68.79s
# Total elapsed time = 72.78s
# Total elapsed time = 76.61s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2421.98911    0  204 2337.00000 2421.98911  3.64%     -   78s
# H    0     0                    2418.0000000 2421.98911  0.16%     -   79s
# H    0     0                    2419.0000000 2421.98911  0.12%     -   82s
# H    0     0                    2420.0000000 2421.98911  0.08%     -   84s
#      0     0 2421.97187    0  214 2420.00000 2421.97187  0.08%     -   95s
#      0     0 2421.89695    0  207 2420.00000 2421.89695  0.08%     -  113s
#      0     0 2421.89695    0  204 2420.00000 2421.89695  0.08%     -  116s
#      0     0 2421.59829    0  167 2420.00000 2421.59829  0.07%     -  127s
#      0     0 2421.47506    0  151 2420.00000 2421.47506  0.06%     -  135s
#      0     0 2421.47506    0  157 2420.00000 2421.47506  0.06%     -  139s
#      0     0 2421.32412    0  303 2420.00000 2421.32412  0.05%     -  155s
#      0     0 2421.26511    0  280 2420.00000 2421.26511  0.05%     -  163s
#      0     0 2421.26241    0  256 2420.00000 2421.26241  0.05%     -  166s
#      0     0 2421.26241    0  256 2420.00000 2421.26241  0.05%     -  169s
#      0     0 2421.26241    0  234 2420.00000 2421.26241  0.05%     -  186s
#      0     0 2421.26218    0  235 2420.00000 2421.26218  0.05%     -  193s
#      0     0 2421.26196    0  231 2420.00000 2421.26196  0.05%     -  210s
#      0     0 2421.26116    0  220 2420.00000 2421.26116  0.05%     -  218s
#      0     0 2421.26116    0  221 2420.00000 2421.26116  0.05%     -  222s
#      0     0 2421.26057    0  211 2420.00000 2421.26057  0.05%     -  238s
#      0     0 2421.25909    0  193 2420.00000 2421.25909  0.05%     -  245s
#      0     0 2421.25909    0  180 2420.00000 2421.25909  0.05%     -  248s
#      0     0 2421.25909    0  158 2420.00000 2421.25909  0.05%     -  264s
#      0     0 2421.25909    0  151 2420.00000 2421.25909  0.05%     -  272s
#      0     0 2421.25900    0  173 2420.00000 2421.25900  0.05%     -  287s
#      0     0 2421.25896    0  161 2420.00000 2421.25896  0.05%     -  296s
#      0     0 2421.25847    0  159 2420.00000 2421.25847  0.05%     -  310s
#      0     0 2421.25847    0  142 2420.00000 2421.25847  0.05%     -  319s
#      0     0 2421.25847    0  157 2420.00000 2421.25847  0.05%     -  334s
#      0     0 2421.25847    0  105 2420.00000 2421.25847  0.05%     -  356s
#      0     2 2421.25847    0  105 2420.00000 2421.25847  0.05%     -  404s
#      1     2 infeasible    1      2420.00000 2421.25847  0.05%  2556  408s
#      3     4 2421.25847    2  107 2420.00000 2421.25847  0.05%   876  411s
#      5     8 2421.25847    3  119 2420.00000 2421.25847  0.05%   549  416s
#      9    14 2421.25847    4  108 2420.00000 2421.25847  0.05%   327  422s
#     15    20 2421.25847    5  114 2420.00000 2421.25847  0.05%   213  427s
#     21    26 2421.25847    6  114 2420.00000 2421.25847  0.05%   163  431s
#     27    32 2421.25847    7  114 2420.00000 2421.25847  0.05%   129  442s
#     33    40 2421.25847    8  112 2420.00000 2421.25847  0.05%   108  445s
#     50    73 2421.25847   10  114 2420.00000 2421.25847  0.05%  75.5  455s
#     74    79 2421.25847   11  114 2420.00000 2421.25847  0.05%  54.4  497s
#     80   191 2421.25847   12  116 2420.00000 2421.25847  0.05%  51.1  521s
#    192   434 2421.24841   25  118 2420.00000 2421.25847  0.05%  26.2  572s
#    435   696 2421.10764   50   97 2420.00000 2421.25847  0.05%  15.5  639s
#    697  1104 2421.10008   85   79 2420.00000 2421.25847  0.05%  11.9  732s
#   1108  1495 2420.99840  134   83 2420.00000 2421.25847  0.05%   9.8  840s
#   1540  1675 2421.24948   68  112 2420.00000 2421.25847  0.05%   9.2  929s
#   1720  2023 2421.24730  107  112 2420.00000 2421.25847  0.05%   8.9 1020s
#   2072  2518 2421.24577  174  113 2420.00000 2421.25847  0.05%   8.5 1126s
#   2596  2903 2421.24494  269  101 2420.00000 2421.25847  0.05%   8.1 1213s
#   3012  3138 2421.23729  346   94 2420.00000 2421.25847  0.05%   7.9 1287s
#   3271  3597 2421.21918  386   83 2420.00000 2421.25847  0.05%   7.9 1384s
#   3784  3907 2421.12323  488   44 2420.00000 2421.25847  0.05%   7.8 1479s
#   4133  3908 2421.21943  379  105 2420.00000 2421.25847  0.05%   7.8 1842s
#   4135  3909 2421.09843  341  208 2420.00000 2421.25847  0.05%   7.8 2111s
#   4136  3910 2421.21162   95  158 2420.00000 2421.23663  0.05%   7.8 2357s
#   4137  3911 2421.23663  102  119 2420.00000 2421.23663  0.05%   7.8 2361s
#   4138  3911 2421.10698  406  111 2420.00000 2421.23663  0.05%   7.8 2557s
#   4139  3912 2421.20222  343  128 2420.00000 2421.23663  0.05%   7.8 2688s
#   4140  3913 2421.23663  149  139 2420.00000 2421.23663  0.05%   7.8 2814s
#   4141  3913 2421.23663   76  119 2420.00000 2421.23663  0.05%   7.8 2982s
#   4142  3914 2421.17214  180  115 2420.00000 2421.23663  0.05%   7.8 3128s
#   4143  3915 2421.23663   22  117 2420.00000 2421.23663  0.05%   7.8 3183s
#   4144  3915 2421.18752  211  130 2420.00000 2421.23663  0.05%   7.8 3225s
#   4145  3916 2421.22536  118  131 2420.00000 2421.23663  0.05%   7.8 3291s
#   4146  3917 2421.23663  105  118 2420.00000 2421.23663  0.05%   7.8 3333s
#   4147  3917 2421.15425  307  117 2420.00000 2421.23663  0.05%   7.8 3391s
#   4148  3918 2420.99768  189  118 2420.00000 2421.23663  0.05%   7.8 3418s
#   4149  3919 2421.12323  480  124 2420.00000 2421.23663  0.05%   7.8 3465s
#   4150  3919 2421.10717  362  121 2420.00000 2421.23663  0.05%   7.8 3504s
#   4151  3920 2421.23032   34  118 2420.00000 2421.23032  0.05%   7.8 3547s
#   4152  3921 2421.22156   58  110 2420.00000 2421.22156  0.05%   7.8 3550s
#   4153  3921 2421.18752  197  110 2420.00000 2421.22156  0.05%   7.8 3585s
#
# Cutting planes:
#   Gomory: 34
#   Cover: 42
#   Clique: 1
#   MIR: 134
#   StrongCG: 46
#   Flow cover: 129
#   GUB cover: 1
#   Zero half: 13
#   RLT: 4
#
# Explored 4153 nodes (75345 simplex iterations) in 3601.79 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2420 2419 2418 2337
#
# Time limit reached
# Best objective 2.420000000000e+03, best bound 2.421000000000e+03, gap 0.0413%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3x2

# %%
datafile="4x3000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xfed5e977
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2344.0000000
# Presolve removed 54 rows and 40 columns (presolve time = 8s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 11s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 18s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 20s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 32s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 35s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 40s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 50s) ...
# Presolve removed 66 rows and 40 columns (presolve time = 55s) ...
# Presolve removed 66 rows and 40 columns
# Presolve time: 58.40s
# Presolved: 14934 rows, 11960 columns, 17898080 nonzeros
# Variable types: 0 continuous, 11960 integer (11960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3500000e+03   0.000000e+00   5.880500e+03     65s
#     1462    2.3587559e+03   0.000000e+00   5.672630e+02     65s
#     4532    2.4221985e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.422198e+03, 4532 iterations, 6.61 seconds
# Total elapsed time = 73.30s
# Total elapsed time = 77.00s
# Total elapsed time = 80.52s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2422.19849    0  140 2344.00000 2422.19849  3.34%     -   83s
# H    0     0                    2419.0000000 2422.19849  0.13%     -   83s
# H    0     0                    2420.0000002 2422.19849  0.09%     -   87s
#      0     0 2421.68787    0  158 2420.00000 2421.68787  0.07%     -  141s
# H    0     0                    2421.0000000 2421.68787  0.03%     -  151s
#      0     0 2421.68787    0  158 2421.00000 2421.68787  0.03%     -  151s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 68
#   MIR: 121
#   StrongCG: 114
#   GUB cover: 7
#   RLT: 3
#
# Explored 1 nodes (12121 simplex iterations) in 151.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2421 2420 2419 2344
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.421000000000e+03, best bound 2.421000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3x3

# %%
datafile="4x3000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x48c0e3a9
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2345.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 8s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 11s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 24s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 25s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 30s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 35s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 51s) ...
# Presolve removed 29 rows and 20 columns
# Presolve time: 50.57s
# Presolved: 14971 rows, 11980 columns, 17958016 nonzeros
# Variable types: 0 continuous, 11980 integer (11980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3440000e+03   0.000000e+00   5.919750e+03     57s
#     4894    2.4233675e+03   0.000000e+00   0.000000e+00     60s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.423367e+03, 4894 iterations, 7.23 seconds
# Total elapsed time = 66.35s
# Total elapsed time = 70.34s
# Total elapsed time = 77.78s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2423.36746    0  197 2345.00000 2423.36746  3.34%     -   79s
# H    0     0                    2420.0000000 2423.36746  0.14%     -   80s
# H    0     0                    2422.0000000 2423.36746  0.06%     -   89s
#      0     0 2423.32939    0  226 2422.00000 2423.32939  0.05%     -  144s
#      0     0 2423.14962    0  221 2422.00000 2423.14962  0.05%     -  156s
#      0     0 2423.14962    0  221 2422.00000 2423.14962  0.05%     -  160s
#      0     0 2423.02218    0  212 2422.00000 2423.02218  0.04%     -  177s
#      0     0 2423.02178    0  207 2422.00000 2423.02178  0.04%     -  183s
#      0     0 2423.02091    0  203 2422.00000 2423.02091  0.04%     -  187s
#      0     0 2423.02067    0  208 2422.00000 2423.02067  0.04%     -  192s
#      0     0     cutoff    0      2422.00000 2422.00000  0.00%     -  205s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 26
#   MIR: 259
#   StrongCG: 8
#   RLT: 4
#
# Explored 1 nodes (16938 simplex iterations) in 206.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2422 2420 2345
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.422000000000e+03, best bound 2.422000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3x4

# %%
datafile="4x3000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xb428ffba
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2335.0000000
# Presolve removed 48 rows and 32 columns (presolve time = 8s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 11s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 18s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 21s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 33s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 35s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 50s) ...
# Presolve removed 52 rows and 32 columns (presolve time = 55s) ...
# Presolve removed 52 rows and 32 columns
# Presolve time: 58.88s
# Presolved: 14948 rows, 11968 columns, 17922036 nonzeros
# Variable types: 0 continuous, 11968 integer (11968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3350000e+03   0.000000e+00   5.915250e+03     65s
#     4855    2.4198001e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.419800e+03, 4855 iterations, 6.86 seconds
# Total elapsed time = 74.26s
# Total elapsed time = 78.16s
# Total elapsed time = 82.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2419.80010    0  229 2335.00000 2419.80010  3.63%     -   85s
# H    0     0                    2414.0000000 2419.80010  0.24%     -   86s
# H    0     0                    2416.0000000 2419.80010  0.16%     -   88s
# H    0     0                    2418.0000000 2419.80010  0.07%     -   91s
#      0     0 2419.79286    0  240 2418.00000 2419.79286  0.07%     -  145s
#      0     0 2419.74488    0  214 2418.00000 2419.74488  0.07%     -  162s
#      0     0 2419.70450    0  213 2418.00000 2419.70450  0.07%     -  165s
#      0     0 2419.70450    0  210 2418.00000 2419.70450  0.07%     -  169s
#      0     0 2419.40705    0  178 2418.00000 2419.40705  0.06%     -  183s
#      0     0 2419.40111    0  170 2418.00000 2419.40111  0.06%     -  191s
#      0     0 2419.40111    0  158 2418.00000 2419.40111  0.06%     -  195s
#      0     0 2419.25195    0  156 2418.00000 2419.25195  0.05%     -  210s
#      0     0 2419.25195    0  139 2418.00000 2419.25195  0.05%     -  224s
#      0     0 2419.24879    0  144 2418.00000 2419.24879  0.05%     -  238s
#      0     0 2419.24088    0  132 2418.00000 2419.24088  0.05%     -  248s
#      0     0 2419.24088    0  139 2418.00000 2419.24088  0.05%     -  251s
#      0     0 2419.24088    0  137 2418.00000 2419.24088  0.05%     -  265s
#      0     0 2419.20007    0  134 2418.00000 2419.20007  0.05%     -  279s
#      0     0 2419.20006    0  137 2418.00000 2419.20006  0.05%     -  283s
#      0     0 2419.19625    0  132 2418.00000 2419.19625  0.05%     -  297s
#      0     0 2419.19625    0  132 2418.00000 2419.19625  0.05%     -  304s
#      0     0 2419.19449    0  130 2418.00000 2419.19449  0.05%     -  318s
#      0     0 2419.19274    0  128 2418.00000 2419.19274  0.05%     -  331s
#      0     0 2419.19274    0  118 2418.00000 2419.19274  0.05%     -  335s
#      0     0 2419.19274    0  127 2418.00000 2419.19274  0.05%     -  348s
#      0     0 2419.19274    0  132 2418.00000 2419.19274  0.05%     -  356s
#      0     0 2419.19274    0  124 2418.00000 2419.19274  0.05%     -  409s
#      0     0 2419.19274    0  115 2418.00000 2419.19274  0.05%     -  419s
#      0     0 2419.19274    0  107 2418.00000 2419.19274  0.05%     -  450s
#      0     0 2419.19274    0  110 2418.00000 2419.19274  0.05%     -  459s
#      0     0 2419.19274    0  126 2418.00000 2419.19274  0.05%     -  480s
#      0     0 2419.19274    0  112 2418.00000 2419.19274  0.05%     -  497s
#      0     2 2419.19274    0   99 2418.00000 2419.19274  0.05%     -  544s
#      1     4 2419.15943    1  117 2418.00000 2419.19274  0.05%  1724  547s
#      3     8 2419.15656    2  121 2418.00000 2419.19274  0.05%   597  552s
#      7    12 infeasible    3      2418.00000 2419.19274  0.05%   284  558s
#     13    18 2419.19274    4  126 2418.00000 2419.19274  0.05%   182  565s
#     19    24 2419.19274    5  133 2418.00000 2419.19274  0.05%   143  572s
#     25    30 2419.19274    6  129 2418.00000 2419.19274  0.05%   117  576s
#     31    36 2419.19274    7  126 2418.00000 2419.19274  0.05%  99.3  592s
#     37    43 2419.19274    8  128 2418.00000 2419.19274  0.05%  85.5  595s
#     44    75 2419.19274   10  129 2418.00000 2419.19274  0.05%  73.6  604s
#     76    93 2419.09502   17  122 2418.00000 2419.19274  0.05%  47.0  617s
#     94   223 2419.09502   18  126 2418.00000 2419.19274  0.05%  39.6  660s
#    224   533 2419.08836   43  121 2418.00000 2419.19274  0.05%  21.5  733s
#    538   930 2419.08591   91  122 2418.00000 2419.19274  0.05%  13.2  829s
#    949  1108 2419.08016  148  115 2418.00000 2419.19274  0.05%  10.7  895s
#   1128  1610 2419.07888  184  117 2418.00000 2419.19274  0.05%   9.9  993s
#   1643  1939 2419.07680  263  104 2418.00000 2419.19274  0.05%   8.7 1081s
#   2049  2413 2419.06276  314  106 2418.00000 2419.19274  0.05%   8.2 1168s
#   2526  2414 2419.00631  158  112 2418.00000 2419.19274  0.05%   7.8 1467s
#   2528  2415 2419.01324   73  217 2418.00000 2419.19274  0.05%   7.8 1737s
#   2529  2416 2419.07611  154  160 2418.00000 2419.19274  0.05%   7.8 1992s
#   2530  2417 2419.09710  141  143 2418.00000 2419.19274  0.05%   7.8 1996s
#   2532  2418 2419.08386   86  146 2418.00000 2419.15146  0.05%   7.8 2184s
#   2533  2419 2419.01869   97   97 2418.00000 2419.11009  0.05%   7.8 2285s
#   2534  2419 2419.05356  353  118 2418.00000 2419.06225  0.04%   7.8 2390s
#   2535  2420 2419.00057  154  107 2418.00000 2419.06225  0.04%   7.8 2467s
#   2536  2421 2419.04121   35  116 2418.00000 2419.04121  0.04%   7.8 2471s
#   2537  2421 2419.04121   38  106 2418.00000 2419.04121  0.04%   7.8 2536s
#   2538  2422 2419.04121   78  118 2418.00000 2419.04121  0.04%   7.7 2607s
#   2539  2423 2419.04121   31  121 2418.00000 2419.04121  0.04%   7.7 2622s
#   2540  2423 2419.04121   27  120 2418.00000 2419.04121  0.04%   7.7 2691s
#   2541  2424 2419.04121  303  128 2418.00000 2419.04121  0.04%   7.7 2752s
#   2542  2425 2419.04121  175  112 2418.00000 2419.04121  0.04%   7.7 2805s
#   2543  2425 2419.03710   78  135 2418.00000 2419.04121  0.04%   7.7 2861s
#   2544  2426 2419.03532   83  119 2418.00000 2419.04121  0.04%   7.7 2919s
#   2545  2427 2419.00408   85  107 2418.00000 2419.04121  0.04%   7.7 2962s
#   2546  2427 2419.03320  111  118 2418.00000 2419.04121  0.04%   7.7 3028s
#   2547  2428 2419.04121   34  118 2418.00000 2419.04121  0.04%   7.7 3076s
#   2548  2429 2419.04121  106  100 2418.00000 2419.04121  0.04%   7.7 3154s
#   2549  2429 2419.04121  332  121 2418.00000 2419.04121  0.04%   7.7 3211s
#   2550  2430 2419.04121   47  114 2418.00000 2419.04121  0.04%   7.7 3269s
#   2551  2431 2419.04121   68  112 2418.00000 2419.04121  0.04%   7.7 3289s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 3
#   MIR: 12
#   StrongCG: 4
#   Flow cover: 18
#
# Explored 2552 nodes (82820 simplex iterations) in 3602.20 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2418 2416 2414 2335
#
# Time limit reached
# Best objective 2.418000000000e+03, best bound 2.419000000000e+03, gap 0.0414%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3x5

# %%
datafile="4x3000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x5fb47f61
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2334.0000000
# Presolve removed 22 rows and 8 columns (presolve time = 8s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 24s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 8 columns
# Presolve time: 50.49s
# Presolved: 14978 rows, 11992 columns, 17993968 nonzeros
# Variable types: 0 continuous, 11992 integer (11992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3400000e+03   0.000000e+00   5.851500e+03     57s
#     4236    2.4146512e+03   0.000000e+00   0.000000e+00     59s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.414651e+03, 4236 iterations, 6.65 seconds
# Total elapsed time = 65.21s
# Total elapsed time = 70.45s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2414.65119    0  164 2334.00000 2414.65119  3.46%     -   73s
# H    0     0                    2410.0000000 2414.65119  0.19%     -   73s
# H    0     0                    2412.0000000 2414.65119  0.11%     -   78s
#      0     0 2414.59978    0  184 2412.00000 2414.59978  0.11%     -   91s
#      0     0 2414.59859    0  173 2412.00000 2414.59859  0.11%     -  108s
#      0     0 2414.59756    0  174 2412.00000 2414.59756  0.11%     -  112s
#      0     0 2414.59756    0  176 2412.00000 2414.59756  0.11%     -  115s
#      0     0 2414.16468    0  156 2412.00000 2414.16468  0.09%     -  129s
#      0     0 2414.16249    0  146 2412.00000 2414.16249  0.09%     -  138s
#      0     0 2414.16199    0  145 2412.00000 2414.16199  0.09%     -  141s
#      0     0 2414.16004    0  134 2412.00000 2414.16004  0.09%     -  145s
#      0     0 2414.15999    0  133 2412.00000 2414.15999  0.09%     -  148s
#      0     0 2414.09000    0  121 2412.00000 2414.09000  0.09%     -  161s
# H    0     0                    2413.0000000 2414.09000  0.05%     -  171s
#      0     0 2414.09000    0  121 2413.00000 2414.09000  0.05%     -  171s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 10
#   MIR: 54
#   StrongCG: 3
#   RLT: 3
#
# Explored 1 nodes (11143 simplex iterations) in 171.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2413 2412 2410 2334
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.413000000000e+03, best bound 2.413000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3.5x1

# %%
datafile="4x3000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x3346203d
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2138.0000000
# Presolve removed 37 rows and 20 columns (presolve time = 8s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 11s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 23s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 25s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 30s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 35s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 49.36s
# Presolved: 14963 rows, 11980 columns, 17957992 nonzeros
# Variable types: 0 continuous, 11980 integer (11980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1380000e+03   0.000000e+00   5.998000e+03     56s
#     3963    2.2234223e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.223422e+03, 3963 iterations, 6.46 seconds
# Total elapsed time = 63.63s
# Total elapsed time = 67.03s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2223.42227    0  125 2138.00000 2223.42227  4.00%     -   69s
# H    0     0                    2216.0000000 2223.42227  0.33%     -   69s
# H    0     0                    2221.0000000 2223.42227  0.11%     -   72s
# H    0     0                    2222.0000000 2223.42227  0.06%     -   75s
#      0     0 2223.42216    0  140 2222.00000 2223.42216  0.06%     -   86s
#      0     0 2223.38743    0  149 2222.00000 2223.38743  0.06%     -  105s
#      0     0 2223.38645    0  149 2222.00000 2223.38645  0.06%     -  108s
#      0     0 2223.38645    0  148 2222.00000 2223.38645  0.06%     -  111s
#      0     0 2223.36997    0  125 2222.00000 2223.36997  0.06%     -  123s
#      0     0 2223.20195    0  110 2222.00000 2223.20195  0.05%     -  141s
#      0     0 2223.20195    0  111 2222.00000 2223.20195  0.05%     -  145s
#      0     0 2223.20195    0  109 2222.00000 2223.20195  0.05%     -  156s
#      0     0 2223.18408    0  108 2222.00000 2223.18408  0.05%     -  161s
#      0     0 2223.18408    0  110 2222.00000 2223.18408  0.05%     -  165s
#      0     0 2223.18408    0   99 2222.00000 2223.18408  0.05%     -  176s
#      0     0 2223.18408    0   97 2222.00000 2223.18408  0.05%     -  182s
#      0     0 2223.18408    0   93 2222.00000 2223.18408  0.05%     -  189s
#      0     0 2223.18408    0   95 2222.00000 2223.18408  0.05%     -  195s
#      0     0 2223.18408    0   78 2222.00000 2223.18408  0.05%     -  220s
#      0     0 2223.03333    0   80 2222.00000 2223.03333  0.05%     -  228s
#      0     0 2223.03333    0   88 2222.00000 2223.03333  0.05%     -  231s
#      0     0 2223.03333    0   73 2222.00000 2223.03333  0.05%     -  250s
#      0     0 2223.03333    0  140 2222.00000 2223.03333  0.05%     -  294s
#      0     0 2223.03333    0  157 2222.00000 2223.03333  0.05%     -  303s
#      0     0 2223.03333    0   99 2222.00000 2223.03333  0.05%     -  308s
#      0     0 2223.03333    0   98 2222.00000 2223.03333  0.05%     -  310s
#      0     0 2223.02414    0   71 2222.00000 2223.02414  0.05%     -  323s
#      0     0 2223.02414    0   74 2222.00000 2223.02414  0.05%     -  326s
#      0     0 2223.02414    0   66 2222.00000 2223.02414  0.05%     -  336s
#      0     0 2223.02414    0   55 2222.00000 2223.02414  0.05%     -  342s
#      0     0 2223.02414    0   39 2222.00000 2223.02414  0.05%     -  358s
#      0     0 2223.02414    0   39 2222.00000 2223.02414  0.05%     -  361s
#      0     0 2223.02414    0   49 2222.00000 2223.02414  0.05%     -  371s
#      0     0 2223.02414    0   50 2222.00000 2223.02414  0.05%     -  374s
#      0     0 2223.02414    0   43 2222.00000 2223.02414  0.05%     -  385s
#      0     0 2223.02414    0   46 2222.00000 2223.02414  0.05%     -  388s
#      0     0 2223.02414    0   44 2222.00000 2223.02414  0.05%     -  402s
#      0     0 2223.02414    0   61 2222.00000 2223.02414  0.05%     -  407s
#      0     0 2223.02414    0   42 2222.00000 2223.02414  0.05%     -  425s
#      0     0 2223.02414    0   42 2222.00000 2223.02414  0.05%     -  432s
#      0     2 2223.02414    0   42 2222.00000 2223.02414  0.05%     -  448s
#      3     6 2223.02139    2   48 2222.00000 2223.02139  0.05%   279  451s
#     10    11 2223.02043    3   52 2222.00000 2223.02139  0.05%  98.6  455s
#     24    28 2223.01336    6   55 2222.00000 2223.02043  0.05%  52.2  461s
#     30    34 2223.01336    7   50 2222.00000 2223.01816  0.05%  44.5  466s
#     50    65 2223.01336    9   56 2222.00000 2223.01816  0.05%  30.1  473s
#     69   112 2223.01304   12   45 2222.00000 2223.01816  0.05%  23.6  482s
#    117   182 2223.01234   17   45 2222.00000 2223.01816  0.05%  16.6  499s
#    206   367 2223.01104   26   56 2222.00000 2223.01816  0.05%  12.2  528s
#    438   557 2223.00852   49   51 2222.00000 2223.01816  0.05%   9.0  573s
#    739  1101 2223.00547   69   55 2222.00000 2223.01460  0.05%   7.9  640s
#   1447  1102 2223.01329    7   73 2222.00000 2223.01336  0.05%   6.9  798s
#   1449  1103 2223.01323   13  146 2222.00000 2223.01336  0.05%   6.8  846s
#   1450  1104 2223.00897   54   85 2222.00000 2223.01336  0.05%   6.8  851s
#   1452  1105 2223.01137    9   68 2222.00000 2223.01336  0.05%   6.8  856s
#   1453  1106 2223.01137   16   78 2222.00000 2223.01336  0.05%   6.8  873s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 16
#   MIR: 58
#   StrongCG: 22
#   Flow cover: 54
#   GUB cover: 1
#   Zero half: 2
#   RLT: 2
#
# Explored 1453 nodes (65199 simplex iterations) in 874.98 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2222 2221 2216 ... 2138
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.222000000000e+03, best bound 2.222000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3.5x2

# %%
datafile="4x3000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x0a0b86d1
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2160.0000000
# Presolve removed 38 rows and 24 columns (presolve time = 8s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 11s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 23s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 25s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 30s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 35s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 40s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 45s) ...
# Presolve removed 38 rows and 24 columns
# Presolve time: 49.79s
# Presolved: 14962 rows, 11976 columns, 17946028 nonzeros
# Variable types: 0 continuous, 11976 integer (11976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1600000e+03   0.000000e+00   6.048500e+03     56s
#     4502    2.2450328e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.245033e+03, 4502 iterations, 6.77 seconds
# Total elapsed time = 64.62s
# Total elapsed time = 68.47s
# Total elapsed time = 72.29s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2245.03282    0  193 2160.00000 2245.03282  3.94%     -   75s
# H    0     0                    2241.0000000 2245.03282  0.18%     -   75s
# H    0     0                    2243.0000000 2245.03282  0.09%     -   78s
#      0     0 2245.00729    0  200 2243.00000 2245.00729  0.09%     -  101s
# H    0     0                    2244.0000000 2245.00729  0.04%     -  117s
#      0     0 2245.00729    0  200 2244.00000 2245.00729  0.04%     -  117s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 4
#   MIR: 21
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (13029 simplex iterations) in 117.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2244 2243 2241 2160
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.244000000000e+03, best bound 2.244000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3.5x3

# %%
datafile="4x3000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x85972450
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2141.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 8s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 23s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 14 rows and 8 columns
# Presolve time: 49.87s
# Presolved: 14986 rows, 11992 columns, 17993984 nonzeros
# Variable types: 0 continuous, 11992 integer (11992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1410000e+03   0.000000e+00   6.023750e+03     56s
#     4710    2.2313066e+03   0.000000e+00   0.000000e+00     59s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.231307e+03, 4710 iterations, 7.02 seconds
# Total elapsed time = 64.81s
# Total elapsed time = 68.55s
# Total elapsed time = 71.58s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2231.30662    0  249 2141.00000 2231.30662  4.22%     -   74s
# H    0     0                    2228.0000000 2231.30662  0.15%     -   75s
# H    0     0                    2229.0000000 2231.30662  0.10%     -   82s
#      0     0 2231.28470    0  234 2229.00000 2231.28470  0.10%     -  136s
# H    0     0                    2230.0000000 2231.28470  0.06%     -  149s
#      0     0 2231.24216    0  215 2230.00000 2231.24216  0.06%     -  152s
#      0     0 2231.23967    0  208 2230.00000 2231.23967  0.06%     -  157s
#      0     0 2231.23967    0  210 2230.00000 2231.23967  0.06%     -  161s
#      0     0 2231.14709    0  189 2230.00000 2231.14709  0.05%     -  177s
#      0     0 2231.14351    0  175 2230.00000 2231.14351  0.05%     -  185s
#      0     0 2231.14351    0  173 2230.00000 2231.14351  0.05%     -  189s
#      0     0 2231.13943    0  174 2230.00000 2231.13943  0.05%     -  204s
#      0     0 2231.13465    0  179 2230.00000 2231.13465  0.05%     -  214s
#      0     0 2231.13465    0  177 2230.00000 2231.13465  0.05%     -  217s
#      0     0     cutoff    0      2230.00000 2230.00000  0.00%     -  230s
#
# Cutting planes:
#   Gomory: 23
#   Cover: 98
#   MIR: 395
#   StrongCG: 41
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (13016 simplex iterations) in 231.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2230 2229 2228 2141
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.230000000000e+03, best bound 2.230000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3.5x4

# %%
datafile="4x3000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x0fd1ca85
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2136.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 11s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 18s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 21s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 27s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 30s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 42s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 60s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 65s) ...
# Presolve removed 43 rows and 28 columns
# Presolve time: 68.25s
# Presolved: 14957 rows, 11972 columns, 17934024 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1320000e+03   0.000000e+00   6.013750e+03     75s
#     2004    2.1728946e+03   0.000000e+00   3.914796e+02     75s
#     4979    2.2242379e+03   0.000000e+00   0.000000e+00     77s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.224238e+03, 4979 iterations, 6.82 seconds
# Total elapsed time = 82.98s
# Total elapsed time = 86.79s
# Total elapsed time = 90.47s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2224.23790    0  237 2136.00000 2224.23790  4.13%     -   93s
# H    0     0                    2213.0000000 2224.23790  0.51%     -   93s
# H    0     0                    2221.0000000 2224.23790  0.15%     -   93s
# H    0     0                    2222.0000000 2224.23790  0.10%     -   96s
# H    0     0                    2223.0000000 2224.23790  0.06%     -   98s
#      0     0 2224.23749    0  264 2223.00000 2224.23749  0.06%     -  146s
#      0     0 2224.20869    0  234 2223.00000 2224.20869  0.05%     -  162s
#      0     0 2224.20831    0  235 2223.00000 2224.20831  0.05%     -  166s
#      0     0 2224.20760    0  234 2223.00000 2224.20760  0.05%     -  171s
#      0     0 2224.20760    0  231 2223.00000 2224.20760  0.05%     -  174s
#      0     0 2224.17849    0  175 2223.00000 2224.17849  0.05%     -  188s
#      0     0 2224.11083    0  145 2223.00000 2224.11083  0.05%     -  196s
#      0     0 2224.11083    0  144 2223.00000 2224.11083  0.05%     -  200s
#      0     0 2224.10705    0  157 2223.00000 2224.10705  0.05%     -  214s
#      0     0 2224.10660    0  142 2223.00000 2224.10660  0.05%     -  223s
#      0     0 2224.10660    0  143 2223.00000 2224.10660  0.05%     -  226s
#      0     0 2224.10202    0  143 2223.00000 2224.10202  0.05%     -  240s
#      0     0 2224.10185    0  129 2223.00000 2224.10185  0.05%     -  248s
#      0     0 2224.09980    0  126 2223.00000 2224.09980  0.05%     -  260s
#      0     0 2224.09980    0  122 2223.00000 2224.09980  0.05%     -  267s
#      0     0 2224.09980    0  131 2223.00000 2224.09980  0.05%     -  278s
#      0     0 2224.09980    0  118 2223.00000 2224.09980  0.05%     -  287s
#      0     0 2224.09980    0   87 2223.00000 2224.09980  0.05%     -  318s
#      0     0 2224.09980    0   99 2223.00000 2224.09980  0.05%     -  328s
#      0     0 2224.09980    0  106 2223.00000 2224.09980  0.05%     -  383s
#      0     0 2224.09980    0   98 2223.00000 2224.09980  0.05%     -  389s
#      0     0 2224.09713    0   77 2223.00000 2224.09713  0.05%     -  411s
#      0     0 2224.09713    0   79 2223.00000 2224.09713  0.05%     -  422s
#      0     0 2224.09713    0   90 2223.00000 2224.09713  0.05%     -  433s
#      0     0 2224.09713    0   90 2223.00000 2224.09713  0.05%     -  443s
#      0     0 2224.09713    0  272 2223.00000 2224.09713  0.05%     -  534s
#      0     0 2224.09713    0  200 2223.00000 2224.09713  0.05%     -  571s
#      0     0 2224.09713    0  139 2223.00000 2224.09713  0.05%     -  577s
#      0     0 2224.09713    0  133 2223.00000 2224.09713  0.05%     -  579s
#      0     0 2224.09713    0  133 2223.00000 2224.09713  0.05%     -  581s
#      0     0 2224.09713    0  125 2223.00000 2224.09713  0.05%     -  589s
#      0     0 2224.09713    0  133 2223.00000 2224.09713  0.05%     -  592s
#      0     0 2224.09713    0  134 2223.00000 2224.09713  0.05%     -  601s
#      0     0 2224.09713    0  129 2223.00000 2224.09713  0.05%     -  605s
#      0     0 2224.09713    0   99 2223.00000 2224.09713  0.05%     -  630s
#      0     0 2224.09713    0  101 2223.00000 2224.09713  0.05%     -  635s
#      0     0 2224.09713    0   89 2223.00000 2224.09713  0.05%     -  655s
#      0     0 2224.09713    0   88 2223.00000 2224.09713  0.05%     -  661s
#      0     0 2224.09713    0   96 2223.00000 2224.09713  0.05%     -  673s
#      0     0 2224.09713    0   90 2223.00000 2224.09713  0.05%     -  677s
#      0     0 2224.09713    0   87 2223.00000 2224.09713  0.05%     -  692s
#      0     0 2224.09713    0   88 2223.00000 2224.09713  0.05%     -  698s
#      0     0 2224.09713    0   94 2223.00000 2224.09713  0.05%     -  709s
#      0     0 2224.09713    0   91 2223.00000 2224.09713  0.05%     -  712s
#      0     0 2224.09713    0   88 2223.00000 2224.09713  0.05%     -  723s
#      0     0 2224.09713    0   84 2223.00000 2224.09713  0.05%     -  733s
#      0     2 2224.09713    0   84 2223.00000 2224.09713  0.05%     -  759s
#      1     5 2224.09713    1   81 2223.00000 2224.09713  0.05%  1354  761s
#      7     6 2224.09092    3   79 2223.00000 2224.09092  0.05%   201  765s
#     13    11 2224.09092    4   88 2223.00000 2224.09092  0.05%   114  770s
#     19    13 2224.08027    5   83 2223.00000 2224.09092  0.05%  89.7  777s
#     31    18 2224.06067    6   82 2223.00000 2224.09092  0.05%  60.0  782s
#     45    14 2224.06067    8   79 2223.00000 2224.08953  0.05%  44.4  786s
#     58    20     cutoff    8      2223.00000 2224.08027  0.05%  38.4  792s
#     64    25 2224.01206    7  110 2223.00000 2224.08027  0.05%  38.7  796s
#     82    39 2224.01193    9   98 2223.00000 2224.08027  0.05%  33.1  801s
#    105    64 2224.00826   12   91 2223.00000 2224.08027  0.05%  27.6  810s
#    138    92 2224.00826   14  100 2223.00000 2224.08027  0.05%  22.8  820s
#    193   171 2224.00826   23   87 2223.00000 2224.08027  0.05%  17.5  837s
#    293   227 2224.00757   47   91 2223.00000 2224.08027  0.05%  12.9  865s
#    466   623 2224.00500   82   92 2223.00000 2224.06593  0.05%   8.8  920s
#    969   943 2224.05573   39   80 2223.00000 2224.05573  0.05%   7.7  972s
#   1290   944 2224.05573   54   90 2223.00000 2224.05573  0.05%   7.8 1221s
#   1292   945 2224.03139   41  270 2223.00000 2224.05573  0.05%   7.7 1342s
#   1293   946 2224.05385   22  203 2223.00000 2224.05573  0.05%   7.7 1347s
#   1294   947 2224.04074   35  168 2223.00000 2224.05573  0.05%   7.7 1350s
#   1296   948 2224.05573   17  133 2223.00000 2224.05573  0.05%   7.7 1355s
#   1297   949 2224.05385   28  131 2223.00000 2224.05573  0.05%   7.7 1426s
#   1298   949 2224.05385   46  133 2223.00000 2224.05573  0.05%   7.7 1431s
#   1299   950 2224.04074   35  138 2223.00000 2224.05573  0.05%   7.7 1456s
#   1300   951 2224.04969   78  123 2223.00000 2224.05573  0.05%   7.7 1461s
#   1301   951 2224.05385   46  115 2223.00000 2224.05573  0.05%   7.7 1488s
#   1302   952 2224.05573   48  103 2223.00000 2224.05573  0.05%   7.7 1531s
#   1303   953 2224.04132   77  100 2223.00000 2224.05573  0.05%   7.7 1549s
#   1304   953 2224.05385   34   90 2223.00000 2224.05573  0.05%   7.7 1590s
#   1305   954 2224.05385   39   96 2223.00000 2224.05573  0.05%   7.7 1615s
#   1306   955 2224.00310   58   99 2223.00000 2224.05573  0.05%   7.7 1658s
#   1307   955 2224.05307   70   93 2223.00000 2224.05573  0.05%   7.7 1685s
#   1308   956 2224.02037   47   94 2223.00000 2224.05573  0.05%   7.6 1695s
#   1309   957 2224.05385   34  105 2223.00000 2224.05573  0.05%   7.6 1703s
#   1310   957 2224.05385   41  102 2223.00000 2224.05573  0.05%   7.6 1737s
#   1311   958 2224.01193   10   98 2223.00000 2224.05573  0.05%   7.6 1744s
#   1312   959 2224.05573   33   97 2223.00000 2224.05573  0.05%   7.6 1780s
#   1313   959 2224.05385   58   87 2223.00000 2224.05573  0.05%   7.6 1787s
#   1314   960 2224.05385   41   94 2223.00000 2224.05573  0.05%   7.6 1815s
#   1315   961 2224.05385   36   79 2223.00000 2224.05573  0.05%   7.6 1874s
#   1316   961 2223.99954   65   87 2223.00000 2224.05573  0.05%   7.6 1915s
#   1317   962 2224.00826   14   82 2223.00000 2224.05573  0.05%   7.6 1964s
#   1318   963 2224.00310   59   83 2223.00000 2224.05573  0.05%   7.6 2011s
#   1319   963 2224.05366   19   81 2223.00000 2224.05573  0.05%   7.6 2060s
#   1320   964 2224.05385   16   88 2223.00000 2224.05573  0.05%   7.6 2093s
#   1321   965 2224.01962   50   85 2223.00000 2224.05573  0.05%   7.6 2149s
#   1322   965 2224.05385   21   93 2223.00000 2224.05573  0.05%   7.6 2200s
#   1323   966 2224.04895   23   92 2223.00000 2224.05573  0.05%   7.6 2246s
#   1324   967 2224.04679   30   92 2223.00000 2224.05573  0.05%   7.6 2262s
#   1325   967 2224.00539   64   92 2223.00000 2224.05573  0.05%   7.6 2364s
#   1326   970 2224.05573   14   81 2223.00000 2224.05573  0.05%  49.5 2384s
#   1328   969 2224.05573   15   88 2223.00000 2224.05573  0.05%  49.4 2388s
#   1331   968 2224.05573   16   88 2223.00000 2224.05573  0.05%  49.3 2390s
#   1339   965 2224.05573   19   82 2223.00000 2224.05573  0.05%  49.1 2396s
#   1345   967 2224.05573   22   83 2223.00000 2224.05573  0.05%  48.9 2403s
#   1348   971 2224.05573   23   81 2223.00000 2224.05573  0.05%  48.8 2408s
#   1354   972 2224.05573   24   80 2223.00000 2224.05573  0.05%  48.6 2410s
#   1368   983 2224.05573   25   79 2223.00000 2224.05573  0.05%  48.1 2415s
#   1392   997     cutoff   26      2223.00000 2224.05573  0.05%  47.4 2421s
#   1401  1010 2224.05524   27   76 2223.00000 2224.05573  0.05%  47.2 2425s
#   1419  1041 2224.05524   29   81 2223.00000 2224.05573  0.05%  46.7 2433s
#   1456  1098 2224.05524   32   80 2223.00000 2224.05573  0.05%  45.7 2448s
#   1526  1235 2224.05524   38   75 2223.00000 2224.05573  0.05%  44.0 2481s
#   1688  1529 2224.05523   51   86 2223.00000 2224.05573  0.05%  40.6 2549s
#   2058  1869 2224.02037   80   88 2223.00000 2224.05573  0.05%  34.6 2627s
#   2600  2568 2224.00310  121   66 2223.00000 2224.05573  0.05%  29.0 2696s
#   3666  2842 2224.05224   78   67 2223.00000 2224.05573  0.05%  21.5 2745s
#   4417  3251 2224.04494  123   71 2223.00000 2224.05573  0.05%  18.4 2789s
#   5132  3840 2224.04494  107   67 2223.00000 2224.05524  0.05%  16.2 2834s
#   5831  4505 2224.04900  112   68 2223.00000 2224.05524  0.05%  14.6 2878s
#   6591  5109 2224.04194   88   67 2223.00000 2224.05524  0.05%  13.3 2923s
#   7324  5139 2224.05426   67   73 2223.00000 2224.05524  0.05%  12.2 2955s
#   7354  5872 2224.05426   68   71 2223.00000 2224.05524  0.05%  12.2 3001s
#   8210  6581 2224.05382   67   75 2223.00000 2224.05524  0.05%  11.2 3047s
#   9048  7364     cutoff  104      2223.00000 2224.05524  0.05%  10.4 3095s
#   9936  7705 2224.05139   81   73 2223.00000 2224.05524  0.05%   9.8 3146s
#  10359  8573 2224.05524   66   74 2223.00000 2224.05524  0.05%   9.6 3199s
#  11404  9186 2224.04937   66   62 2223.00000 2224.05524  0.05%   9.0 3252s
#  12095  9748 2224.05171  100   47 2223.00000 2224.05524  0.05%   8.7 3306s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 7
#   MIR: 19
#   StrongCG: 3
#   Flow cover: 20
#   RLT: 2
#
# Explored 12720 nodes (142093 simplex iterations) in 3600.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2223 2222 2221 ... 2136
#
# Time limit reached
# Best objective 2.223000000000e+03, best bound 2.224000000000e+03, gap 0.0450%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x3.5x5

# %%
datafile="4x3000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xd6444e28
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2135.0000000
# Presolve removed 49 rows and 36 columns (presolve time = 8s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 12s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 19s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 22s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 34s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 35s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 50s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 55s) ...
# Presolve removed 53 rows and 36 columns
# Presolve time: 59.73s
# Presolved: 14947 rows, 11964 columns, 17910072 nonzeros
# Variable types: 0 continuous, 11964 integer (11964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1360000e+03   0.000000e+00   5.958750e+03     66s
#     4291    2.2258417e+03   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.225842e+03, 4291 iterations, 6.78 seconds
# Total elapsed time = 74.25s
# Total elapsed time = 78.03s
# Total elapsed time = 81.67s
# Total elapsed time = 85.52s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2225.84174    0  254 2135.00000 2225.84174  4.25%     -   87s
# H    0     0                    2221.0000000 2225.84174  0.22%     -   88s
# H    0     0                    2222.0000000 2225.84174  0.17%     -   90s
# H    0     0                    2224.0000000 2225.84174  0.08%     -  100s
#      0     0 2225.80693    0  242 2224.00000 2225.80693  0.08%     -  154s
#      0     0 2225.79136    0  259 2224.00000 2225.79136  0.08%     -  171s
#      0     0 2225.79136    0  262 2224.00000 2225.79136  0.08%     -  175s
#      0     0 2225.57977    0  253 2224.00000 2225.57977  0.07%     -  192s
#      0     0 2225.57062    0  227 2224.00000 2225.57062  0.07%     -  199s
#      0     0 2225.57016    0  233 2224.00000 2225.57016  0.07%     -  203s
#      0     0 2225.57016    0  220 2224.00000 2225.57016  0.07%     -  206s
#      0     0 2225.54144    0  221 2224.00000 2225.54144  0.07%     -  224s
#      0     0 2225.53771    0  215 2224.00000 2225.53771  0.07%     -  238s
#      0     0 2225.53572    0  210 2224.00000 2225.53572  0.07%     -  242s
#      0     0 2225.53572    0  212 2224.00000 2225.53572  0.07%     -  246s
#      0     0 2225.51710    0  206 2224.00000 2225.51710  0.07%     -  263s
#      0     0 2225.51710    0  209 2224.00000 2225.51710  0.07%     -  270s
#      0     0 2225.51244    0  203 2224.00000 2225.51244  0.07%     -  286s
#      0     0 2225.50778    0  190 2224.00000 2225.50778  0.07%     -  297s
#      0     0 2225.50742    0  191 2224.00000 2225.50742  0.07%     -  300s
#      0     0 2225.50742    0  193 2224.00000 2225.50742  0.07%     -  304s
#      0     0 2225.50125    0  175 2224.00000 2225.50125  0.07%     -  320s
#      0     0 2225.50125    0  170 2224.00000 2225.50125  0.07%     -  327s
#      0     0 2225.50023    0  161 2224.00000 2225.50023  0.07%     -  342s
#      0     0 2225.50016    0  161 2224.00000 2225.50016  0.07%     -  357s
#      0     0 2225.49764    0  162 2224.00000 2225.49764  0.07%     -  411s
#      0     0 2225.49764    0  158 2224.00000 2225.49764  0.07%     -  419s
#      0     0 2225.49588    0  157 2224.00000 2225.49588  0.07%     -  434s
#      0     0 2225.49588    0  172 2224.00000 2225.49588  0.07%     -  444s
#      0     0 2225.45338    0  188 2224.00000 2225.45338  0.07%     -  459s
#      0     0 2225.38649    0  167 2224.00000 2225.38649  0.06%     -  468s
#      0     0 2225.38649    0  169 2224.00000 2225.38649  0.06%     -  472s
#      0     0 2225.38649    0  169 2224.00000 2225.38649  0.06%     -  487s
#      0     0 2225.38649    0  173 2224.00000 2225.38649  0.06%     -  498s
#      0     0 2225.38649    0  157 2224.00000 2225.38649  0.06%     -  513s
#      0     0 2225.38649    0  167 2224.00000 2225.38649  0.06%     -  521s
#      0     0 2225.38419    0  147 2224.00000 2225.38419  0.06%     -  557s
#      0     0 2225.38419    0  171 2224.00000 2225.38419  0.06%     -  565s
#      0     0 2225.38419    0  162 2224.00000 2225.38419  0.06%     -  579s
#      0     0 2225.38419    0  156 2224.00000 2225.38419  0.06%     -  588s
#      0     0 2225.38419    0  132 2224.00000 2225.38419  0.06%     -  619s
#      0     0 2225.38419    0  139 2224.00000 2225.38419  0.06%     -  629s
#      0     0 2225.38419    0  150 2224.00000 2225.38419  0.06%     -  651s
#      0     0 2225.38419    0  141 2224.00000 2225.38419  0.06%     -  661s
#      0     2 2225.38419    0  139 2224.00000 2225.38419  0.06%     -  692s
#      1     4 2225.34965    1  139 2224.00000 2225.38419  0.06%  2025  695s
#      3     8 2225.25295    2  122 2224.00000 2225.38419  0.06%   715  700s
#      7    12 infeasible    3      2224.00000 2225.38382  0.06%   353  706s
#     13    18 2225.38382    4  137 2224.00000 2225.38382  0.06%   239  712s
#     19    24 2225.38382    5  152 2224.00000 2225.38382  0.06%   247  717s
#     25    30 2225.38382    6  144 2224.00000 2225.38382  0.06%   209  720s
#     31    36 2225.38382    7  150 2224.00000 2225.38382  0.06%   178  741s
#     37    44 2225.38382    8  147 2224.00000 2225.38382  0.06%   152  745s
#     45    70 2225.38382    9  146 2224.00000 2225.38382  0.06%   129  753s
#     73    91 2225.38382   15  149 2224.00000 2225.38382  0.06%  86.2  764s
#     94   126 2225.38382   17  150 2224.00000 2225.38382  0.06%  70.9  788s
#    129   422 2225.38382   24  148 2224.00000 2225.38382  0.06%  54.8  862s
#    425   826 2225.36333   87  116 2224.00000 2225.38382  0.06%  25.3  963s
# H  493   733                    2225.0000000 2225.38382  0.02%  22.7  963s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 94
#   MIR: 265
#   StrongCG: 1
#   GUB cover: 2
#
# Explored 835 nodes (53408 simplex iterations) in 964.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2225 2224 2222 ... 2135
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.225000000000e+03, best bound 2.225000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4x1

# %%
datafile="4x3000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xadf95756
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1975.0000000
# Presolve removed 39 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 12s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 18s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 21s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 27s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 30s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 42s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 60s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 65s) ...
# Presolve removed 43 rows and 28 columns
# Presolve time: 68.41s
# Presolved: 14957 rows, 11972 columns, 17934036 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9780000e+03   0.000000e+00   6.012000e+03     75s
#     4111    2.0758664e+03   0.000000e+00   0.000000e+00     77s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.075866e+03, 4111 iterations, 6.90 seconds
# Total elapsed time = 82.67s
# Total elapsed time = 86.23s
# Total elapsed time = 90.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2075.86642    0  242 1975.00000 2075.86642  5.11%     -   91s
# H    0     0                    2073.0000000 2075.86642  0.14%     -   91s
# H    0     0                    2074.0000000 2075.86642  0.09%     -  100s
#      0     0 2075.86594    0  249 2074.00000 2075.86594  0.09%     -  150s
#      0     0 2075.80797    0  230 2074.00000 2075.80797  0.09%     -  168s
#      0     0 2075.79877    0  219 2074.00000 2075.79877  0.09%     -  172s
#      0     0 2075.79877    0  219 2074.00000 2075.79877  0.09%     -  175s
#      0     0 2075.78777    0  185 2074.00000 2075.78777  0.09%     -  189s
#      0     0 2075.71101    0  192 2074.00000 2075.71101  0.08%     -  199s
#      0     0 2075.70215    0  178 2074.00000 2075.70215  0.08%     -  202s
#      0     0 2075.69868    0  169 2074.00000 2075.69868  0.08%     -  206s
#      0     0 2075.69534    0  176 2074.00000 2075.69534  0.08%     -  209s
#      0     0 2075.67642    0  176 2074.00000 2075.67642  0.08%     -  223s
#      0     0 2075.67474    0  167 2074.00000 2075.67474  0.08%     -  239s
#      0     0 2075.67474    0  164 2074.00000 2075.67474  0.08%     -  243s
#      0     0 2075.66246    0  147 2074.00000 2075.66246  0.08%     -  255s
#      0     0 2075.66088    0  151 2074.00000 2075.66088  0.08%     -  266s
#      0     0 2075.66088    0  143 2074.00000 2075.66088  0.08%     -  270s
#      0     0 2075.65547    0  150 2074.00000 2075.65547  0.08%     -  282s
#      0     0 2075.64776    0  170 2074.00000 2075.64776  0.08%     -  296s
#      0     0 2075.62433    0  148 2074.00000 2075.62433  0.08%     -  300s
#      0     0 2075.62433    0  156 2074.00000 2075.62433  0.08%     -  303s
#      0     0 2075.61661    0  148 2074.00000 2075.61661  0.08%     -  316s
#      0     0 2075.61383    0  144 2074.00000 2075.61383  0.08%     -  325s
#      0     0 2075.61383    0  146 2074.00000 2075.61383  0.08%     -  328s
#      0     0 2075.59449    0  145 2074.00000 2075.59449  0.08%     -  378s
#      0     0 2075.59449    0  148 2074.00000 2075.59449  0.08%     -  391s
#      0     0 2075.54597    0  216 2074.00000 2075.54597  0.07%     -  405s
#      0     0 2075.53719    0  205 2074.00000 2075.53719  0.07%     -  414s
#      0     0 2075.53719    0  199 2074.00000 2075.53719  0.07%     -  418s
#      0     0 2075.51897    0  184 2074.00000 2075.51897  0.07%     -  431s
#      0     0 2075.49408    0  183 2074.00000 2075.49408  0.07%     -  445s
#      0     0 2075.49408    0  183 2074.00000 2075.49408  0.07%     -  448s
#      0     0 2075.49100    0  167 2074.00000 2075.49100  0.07%     -  462s
#      0     0 2075.49099    0  170 2074.00000 2075.49099  0.07%     -  478s
#      0     0 2075.49025    0  160 2074.00000 2075.49025  0.07%     -  491s
# H    0     0                    2075.0000000 2075.49025  0.02%     -  499s
#      0     0 2075.49025    0  160 2075.00000 2075.49025  0.02%     -  499s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 14
#   MIR: 70
#
# Explored 1 nodes (12773 simplex iterations) in 499.73 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2075 2074 2073 1975
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.075000000000e+03, best bound 2.075000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4x2

# %%
datafile="4x3000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xa0c1256b
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1986.0000000
# Presolve removed 52 rows and 48 columns (presolve time = 8s) ...
# Presolve removed 52 rows and 48 columns (presolve time = 11s) ...
# Presolve removed 60 rows and 48 columns (presolve time = 17s) ...
# Presolve removed 60 rows and 48 columns (presolve time = 20s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 27s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 30s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 41s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 45s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 50s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 55s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 60s) ...
# Presolve removed 72 rows and 48 columns (presolve time = 67s) ...
# Presolve removed 72 rows and 48 columns
# Presolve time: 67.40s
# Presolved: 14928 rows, 11952 columns, 17874176 nonzeros
# Variable types: 0 continuous, 11952 integer (11952 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9840000e+03   0.000000e+00   6.119250e+03     74s
#     3869    2.0762095e+03   0.000000e+00   5.528114e-01     75s
#     4035    2.0762824e+03   0.000000e+00   0.000000e+00     76s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.076282e+03, 4035 iterations, 6.43 seconds
# Total elapsed time = 81.12s
# Total elapsed time = 88.09s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2076.28239    0  209 1986.00000 2076.28239  4.55%     -   90s
# H    0     0                    2066.0000000 2076.28239  0.50%     -   90s
# H    0     0                    2072.0000000 2076.28239  0.21%     -   92s
# H    0     0                    2073.0000000 2076.28239  0.16%     -   93s
# H    0     0                    2074.0000000 2076.28239  0.11%     -   96s
#      0     0 2076.20755    0  204 2074.00000 2076.20755  0.11%     -  145s
# H    0     0                    2075.0000000 2076.20755  0.06%     -  161s
#      0     0     cutoff    0      2075.00000 2075.00000  0.00%     -  162s
#
# Cutting planes:
#   Gomory: 39
#   Cover: 5
#   MIR: 197
#   StrongCG: 2
#
# Explored 1 nodes (10845 simplex iterations) in 163.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2075 2074 2073 ... 1986
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.075000000000e+03, best bound 2.075000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4x3

# %%
datafile="4x3000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x5c954223
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1982.0000000
# Presolve removed 51 rows and 28 columns (presolve time = 9s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 12s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 24s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 25s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 30s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 35s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 40s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 51 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 51 rows and 28 columns
# Presolve time: 50.28s
# Presolved: 14949 rows, 11972 columns, 17934016 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9810000e+03   0.000000e+00   6.066000e+03     57s
#     3809    2.0748221e+03   0.000000e+00   0.000000e+00     59s
# Concurrent spin time: 0.06s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.074822e+03, 3809 iterations, 6.51 seconds
# Total elapsed time = 63.80s
# Total elapsed time = 66.59s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2074.82210    0  263 1982.00000 2074.82210  4.68%     -   69s
# H    0     0                    2071.0000000 2074.82210  0.18%     -   69s
# H    0     0                    2072.0000000 2074.82210  0.14%     -   80s
#      0     0 2074.74226    0  224 2072.00000 2074.74226  0.13%     -   94s
# H    0     0                    2073.0000000 2074.74226  0.08%     -  109s
#      0     0 2074.72669    0  225 2073.00000 2074.72669  0.08%     -  112s
#      0     0 2074.72669    0  228 2073.00000 2074.72669  0.08%     -  115s
#      0     0 2074.70842    0  190 2073.00000 2074.70842  0.08%     -  130s
#      0     0 2074.61119    0  172 2073.00000 2074.61119  0.08%     -  138s
#      0     0 2074.56582    0  168 2073.00000 2074.56582  0.08%     -  141s
#      0     0 2074.56582    0  168 2073.00000 2074.56582  0.08%     -  144s
#      0     0 2074.54385    0  173 2073.00000 2074.54385  0.07%     -  158s
#      0     0 2074.54385    0  172 2073.00000 2074.54385  0.07%     -  173s
#      0     0 2074.47220    0  178 2073.00000 2074.47220  0.07%     -  188s
#      0     0 2074.45967    0  161 2073.00000 2074.45967  0.07%     -  193s
#      0     0 2074.45778    0  166 2073.00000 2074.45778  0.07%     -  197s
#      0     0 2074.45778    0  152 2073.00000 2074.45778  0.07%     -  201s
#      0     0 2074.33096    0  145 2073.00000 2074.33096  0.06%     -  215s
#      0     0 2074.26564    0  130 2073.00000 2074.26564  0.06%     -  223s
#      0     0 2074.23597    0  131 2073.00000 2074.23597  0.06%     -  228s
#      0     0 2074.23597    0  131 2073.00000 2074.23597  0.06%     -  230s
#      0     0 2074.23597    0  145 2073.00000 2074.23597  0.06%     -  240s
#      0     0 2074.23597    0  136 2073.00000 2074.23597  0.06%     -  245s
#      0     0 2074.23416    0  136 2073.00000 2074.23416  0.06%     -  255s
#      0     0 2074.23415    0  130 2073.00000 2074.23415  0.06%     -  260s
#      0     0 2074.23008    0  137 2073.00000 2074.23008  0.06%     -  274s
#      0     0 2074.23008    0  143 2073.00000 2074.23008  0.06%     -  279s
#      0     0 2074.21637    0  138 2073.00000 2074.21637  0.06%     -  290s
#      0     0 2074.21636    0  142 2073.00000 2074.21636  0.06%     -  294s
#      0     0 2074.18765    0  129 2073.00000 2074.18765  0.06%     -  308s
#      0     0 2074.14007    0  126 2073.00000 2074.14007  0.05%     -  315s
#      0     0 2074.12509    0  125 2073.00000 2074.12509  0.05%     -  319s
#      0     0 2074.12509    0  123 2073.00000 2074.12509  0.05%     -  322s
#      0     0 2074.05651    0   87 2073.00000 2074.05651  0.05%     -  347s
#      0     0 2074.05651    0  276 2073.00000 2074.05651  0.05%     -  388s
#      0     0 2074.05651    0  215 2073.00000 2074.05651  0.05%     -  398s
#      0     0 2074.05651    0  149 2073.00000 2074.05651  0.05%     -  403s
#      0     0 2074.05651    0  146 2073.00000 2074.05651  0.05%     -  404s
#      0     0 2074.05651    0  139 2073.00000 2074.05651  0.05%     -  412s
#      0     0 2074.05651    0  130 2073.00000 2074.05651  0.05%     -  414s
#      0     0 2074.05651    0  132 2073.00000 2074.05651  0.05%     -  419s
#      0     0 2074.05651    0  121 2073.00000 2074.05651  0.05%     -  423s
#      0     0 2074.05651    0  118 2073.00000 2074.05651  0.05%     -  433s
#      0     0 2074.05651    0  127 2073.00000 2074.05651  0.05%     -  435s
#      0     0 2074.05651    0  103 2073.00000 2074.05651  0.05%     -  445s
#      0     0 2074.05651    0  113 2073.00000 2074.05651  0.05%     -  448s
#      0     0 2074.05651    0  115 2073.00000 2074.05651  0.05%     -  457s
#      0     0 2074.05651    0  120 2073.00000 2074.05651  0.05%     -  460s
#      0     0 2074.05651    0  102 2073.00000 2074.05651  0.05%     -  474s
#      0     0 2074.05651    0  103 2073.00000 2074.05651  0.05%     -  477s
#      0     0 2074.05651    0   92 2073.00000 2074.05651  0.05%     -  486s
#      0     0 2074.05651    0  102 2073.00000 2074.05651  0.05%     -  489s
#      0     0 2074.05651    0  113 2073.00000 2074.05651  0.05%     -  498s
#      0     0 2074.05651    0  112 2073.00000 2074.05651  0.05%     -  502s
#      0     0 2074.05651    0  104 2073.00000 2074.05651  0.05%     -  511s
#      0     0 2074.05651    0  104 2073.00000 2074.05651  0.05%     -  519s
#      0     2 2074.05651    0  103 2073.00000 2074.05651  0.05%     -  541s
#      3     8 2074.02696    2  101 2073.00000 2074.05651  0.05%   297  546s
#      7    14 2074.02696    3  107 2073.00000 2074.05651  0.05%   160  550s
#     19    26 2074.02696    5  114 2073.00000 2074.05651  0.05%  85.1  555s
#     31    38 2074.02641    6  140 2073.00000 2074.05651  0.05%  60.1  565s
#     51    73 2074.02641    8  141 2073.00000 2074.05651  0.05%  39.2  573s
#     72    79 2074.02641    9  147 2073.00000 2074.05651  0.05%  31.9  593s
#     78   182 2074.02641   10  140 2073.00000 2074.05651  0.05%  29.9  605s
#    181   382 2074.02419   26  120 2073.00000 2074.05651  0.05%  20.1  630s
#    388   615 2074.01743   56  133 2073.00000 2074.05651  0.05%  13.8  665s
#    715   763 2074.01280  111  124 2073.00000 2074.05651  0.05%   9.2  708s
#    910  1034 2074.01276  113  120 2073.00000 2074.05651  0.05%   7.9  766s
#   1366  1489 2074.05651    9  117 2073.00000 2074.05651  0.05%   7.4  829s
#   1822  1490 2074.05649    7   87 2073.00000 2074.05651  0.05%   9.2 1059s
#   1824  1491 2074.05649    5  213 2073.00000 2074.05651  0.05%   9.1 1106s
#   1825  1492 2074.05409   30  222 2073.00000 2074.05651  0.05%   9.1 1110s
#   1828  1494 2074.05531   15  158 2073.00000 2074.05651  0.05%   9.1 1137s
#   1829  1495 2074.05203   26  134 2073.00000 2074.05651  0.05%   9.1 1141s
#   1830  1495 2074.03361   44  125 2073.00000 2074.05651  0.05%   9.1 1162s
#   1831  1496 2074.05597   12  134 2073.00000 2074.05651  0.05%   9.1 1167s
#   1832  1497 2074.01533   70  143 2073.00000 2074.05651  0.05%   9.1 1196s
#   1833  1497 2074.05597   13  101 2073.00000 2074.05651  0.05%   9.1 1240s
#   1834  1498 2074.02639   50  113 2073.00000 2074.05651  0.05%   9.1 1267s
#   1835  1499 2074.04234   33  108 2073.00000 2074.05651  0.05%   9.1 1306s
#   1836  1499 2074.00089  128  111 2073.00000 2074.05651  0.05%   9.1 1337s
#   1837  1500 2074.04977   32   99 2073.00000 2074.05651  0.05%   9.1 1378s
#   1838  1501 2074.00085  122  119 2073.00000 2074.05651  0.05%   9.1 1408s
#   1839  1501 2074.02576   12  113 2073.00000 2074.05651  0.05%   9.1 1448s
#   1840  1502 2074.05597   20  111 2073.00000 2074.05651  0.05%   9.1 1482s
#   1841  1503 2074.05651    6  102 2073.00000 2074.05651  0.05%   9.1 1520s
#   1842  1503 2074.02140   14  105 2073.00000 2074.05651  0.05%   9.1 1541s
#   1843  1504 2074.02504   76  112 2073.00000 2074.05651  0.05%   9.1 1572s
#   1844  1505 2074.00995  154  119 2073.00000 2074.05651  0.05%   9.0 1595s
#   1845  1505 2074.05529   14   99 2073.00000 2074.05651  0.05%   9.0 1623s
#   1846  1506 2074.00806  158   99 2073.00000 2074.05651  0.05%   9.0 1633s
#   1847  1507 2074.03361   45   99 2073.00000 2074.05651  0.05%   9.0 1654s
#   1848  1510 2074.05651   10   97 2073.00000 2074.05651  0.05%  32.2 1667s
#   1850  1514 2074.05651   11  104 2073.00000 2074.05651  0.05%  32.2 1673s
#   1854  1518 2074.05651   12   97 2073.00000 2074.05651  0.05%  32.2 1679s
#   1860  1522 2074.05651   13   99 2073.00000 2074.05651  0.05%  32.1 1681s
#   1872  1530 2074.05651   14  104 2073.00000 2074.05651  0.05%  32.0 1686s
#   1878  1534 2074.05651   14   98 2073.00000 2074.05651  0.05%  31.9 1698s
#   1884  1540 2074.05651   15   96 2073.00000 2074.05651  0.05%  31.8 1701s
#   1900  1550 2074.05651   17  100 2073.00000 2074.05651  0.05%  31.7 1706s
#   1907  1567 2074.05651   18  104 2073.00000 2074.05651  0.05%  31.6 1721s
#   1926  1632 2074.05651   19   98 2073.00000 2074.05651  0.05%  31.4 1734s
#   1998  1659 2074.05651   25  100 2073.00000 2074.05651  0.05%  30.7 1765s
#   2049  1957 2074.05370   26   97 2073.00000 2074.05651  0.05%  30.2 1822s
#   2367  2321 2074.03339   57  148 2073.00000 2074.05651  0.05%  28.0 1892s
#   2837  2789 2074.04543   94  103 2073.00000 2074.05651  0.05%  25.6 1967s
#   3580  2709 2074.04277  151  108 2073.00000 2074.05651  0.05%  24.7 2024s
#   3766  3558 2074.04171  165  117 2073.00000 2074.05651  0.05%  24.5 2115s
#   4806  4129 2074.04053  164   91 2073.00000 2074.05651  0.05%  22.1 2184s
#   5763  4009 2074.03976  190  107 2073.00000 2074.05651  0.05%  19.4 2219s
#   5988  4564 2074.05146   55  113 2073.00000 2074.05651  0.05%  18.9 2278s
#   6637  5135 2074.05597   43  117 2073.00000 2074.05651  0.05%  17.6 2331s
#   7375  5808 2074.03751  203   82 2073.00000 2074.05651  0.05%  16.3 2385s
#   8087  6264 2074.04056  175   77 2073.00000 2074.05651  0.05%  15.3 2430s
#   8556  7063 2074.04448  134  101 2073.00000 2074.05651  0.05%  14.8 2485s
#   9454  7564 2074.04369  143  108 2073.00000 2074.05651  0.05%  13.8 2554s
#  10133  7669 2074.04513  125  115 2073.00000 2074.05651  0.05%  13.1 2607s
#  10349  8504 2074.04513  126  116 2073.00000 2074.05651  0.05%  12.8 2674s
#  11528  9635 2074.04558  106  108 2073.00000 2074.05651  0.05%  12.1 2740s
#  12746 10352 2074.04669   82   98 2073.00000 2074.05651  0.05%  11.4 2957s
#  13573 10359 2074.05065   63  141 2073.00000 2074.05651  0.05%  11.0 3062s
#  13580 11901 2074.05065   64  143 2073.00000 2074.05651  0.05%  11.0 3162s
#  15220 11907 2074.04448  115  120 2073.00000 2074.05651  0.05%  10.4 3263s
#  15226 12796 2074.04448  116  120 2073.00000 2074.05651  0.05%  10.4 3326s
#  16195 13625 2074.04593  115   76 2073.00000 2074.05651  0.05%  10.1 3398s
#  17082 14587 2074.05651   40   95 2073.00000 2074.05651  0.05%   9.8 3466s
#  18119 15517 2074.05651   39   91 2073.00000 2074.05651  0.05%   9.5 3530s
#  19094 16473 2074.03786  202   78 2073.00000 2074.05651  0.05%   9.3 3593s
#  20135 16575 2074.05651   37  101 2073.00000 2074.05651  0.05%   9.1 3600s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 6
#   MIR: 25
#   Flow cover: 15
#
# Explored 20237 nodes (199328 simplex iterations) in 3600.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2073 2072 2071 1982
#
# Time limit reached
# Best objective 2.073000000000e+03, best bound 2.074000000000e+03, gap 0.0482%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4x4

# %%
datafile="4x3000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xfc861bcd
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1995.0000000
# Presolve removed 28 rows and 32 columns (presolve time = 8s) ...
# Presolve removed 28 rows and 32 columns (presolve time = 11s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 17s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 20s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 32s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 35s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 50s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 55s) ...
# Presolve removed 48 rows and 32 columns
# Presolve time: 58.44s
# Presolved: 14952 rows, 11968 columns, 17922060 nonzeros
# Variable types: 0 continuous, 11968 integer (11968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9900000e+03   0.000000e+00   6.107750e+03     65s
#     1200    2.0060874e+03   0.000000e+00   7.781921e+02     65s
#     4233    2.0867761e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.086776e+03, 4233 iterations, 6.50 seconds
# Total elapsed time = 72.41s
# Total elapsed time = 75.91s
# Total elapsed time = 82.74s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2086.77613    0  278 1995.00000 2086.77613  4.60%     -   84s
# H    0     0                    2083.0000000 2086.77613  0.18%     -   85s
# H    0     0                    2084.0000000 2086.77613  0.13%     -   90s
#      0     0 2086.76246    0  282 2084.00000 2086.76246  0.13%     -  141s
# H    0     0                    2085.0000000 2086.76246  0.08%     -  159s
#      0     0 2086.74778    0  281 2085.00000 2086.74778  0.08%     -  161s
#      0     0 2086.74778    0  279 2085.00000 2086.74778  0.08%     -  165s
#      0     0 2086.67661    0  281 2085.00000 2086.67661  0.08%     -  182s
#      0     0 2086.55974    0  274 2085.00000 2086.55974  0.07%     -  191s
#      0     0 2086.55964    0  274 2085.00000 2086.55964  0.07%     -  194s
#      0     0 2086.53598    0  255 2085.00000 2086.53598  0.07%     -  212s
#      0     0 2086.53140    0  250 2085.00000 2086.53140  0.07%     -  229s
#      0     0 2086.53042    0  249 2085.00000 2086.53042  0.07%     -  233s
#      0     0 2086.53041    0  254 2085.00000 2086.53041  0.07%     -  236s
#      0     0 2086.52305    0  230 2085.00000 2086.52305  0.07%     -  253s
#      0     0 2086.52242    0  249 2085.00000 2086.52242  0.07%     -  261s
#      0     0 2086.52135    0  232 2085.00000 2086.52135  0.07%     -  265s
#      0     0 2086.52135    0  238 2085.00000 2086.52135  0.07%     -  269s
#      0     0 2086.51341    0  230 2085.00000 2086.51341  0.07%     -  285s
#      0     0 2086.51341    0  219 2085.00000 2086.51341  0.07%     -  292s
#      0     0 2086.45895    0  218 2085.00000 2086.45895  0.07%     -  309s
#      0     0 2086.45895    0  218 2085.00000 2086.45895  0.07%     -  318s
#      0     0 2086.36533    0  222 2085.00000 2086.36533  0.07%     -  334s
#      0     0 2086.36533    0  215 2085.00000 2086.36533  0.07%     -  348s
#      0     0 2086.36533    0  204 2085.00000 2086.36533  0.07%     -  399s
#      0     0 2086.36533    0  199 2085.00000 2086.36533  0.07%     -  407s
#      0     0 2086.36527    0  188 2085.00000 2086.36527  0.07%     -  436s
#      0     0 2086.36527    0  199 2085.00000 2086.36527  0.07%     -  448s
#      0     0 2086.36442    0  222 2085.00000 2086.36442  0.07%     -  464s
#      0     0 2086.36435    0  220 2085.00000 2086.36435  0.07%     -  474s
#      0     0 2086.36003    0  208 2085.00000 2086.36003  0.07%     -  491s
#      0     0 2086.36003    0  163 2085.00000 2086.36003  0.07%     -  508s
#      0     2 2086.36003    0  163 2085.00000 2086.36003  0.07%     -  549s
#      1     4 2086.32338    1  157 2085.00000 2086.36003  0.07%  1181  552s
#      3     8 2086.32198    2  160 2085.00000 2086.36003  0.07%   432  556s
#      7    13 2086.00356    3  165 2085.00000 2086.36003  0.07%   266  564s
#     13    17     cutoff    4      2085.00000 2086.36003  0.07%   289  570s
#     25    29 2086.35975    5  181 2085.00000 2086.35975  0.07%   191  580s
#     31    35 2086.35975    6  181 2085.00000 2086.35975  0.07%   162  593s
#     37    41 2086.35975    7  183 2085.00000 2086.35975  0.07%   143  597s
#     43    48 2086.35975    8  179 2085.00000 2086.35975  0.07%   126  601s
#     50    90 2086.35975    9  176 2085.00000 2086.35975  0.07%   110  614s
#     92    99 2086.35975   18  170 2085.00000 2086.35975  0.07%  66.1  638s
#    101   267 2086.35975   22  170 2085.00000 2086.35975  0.07%  62.3  677s
#    269   609 2086.35530   52  175 2085.00000 2086.35975  0.07%  33.2  752s
#    611   854 2086.34272  123  135 2085.00000 2086.35975  0.07%  19.3  822s
#    856  1354 2086.34272  124  138 2085.00000 2086.35975  0.07%  16.5  927s
#   1356  1488 2086.34171  220  134 2085.00000 2086.35975  0.07%  13.6  978s
#   1490  1998 2086.34171  257  134 2085.00000 2086.35975  0.07%  13.3 1079s
#   2006  2455 2086.34171  337  130 2085.00000 2086.35975  0.07%  11.7 1168s
#   2490  2655 2086.33105  424  116 2085.00000 2086.35975  0.07%  11.0 1229s
#   2691  3264 2086.27231  467  108 2085.00000 2086.35975  0.07%  11.4 1334s
#   3314  3783 2086.15253  574   52 2085.00000 2086.35975  0.07%  11.2 1426s
#   3872  4011 2086.15253  654   67 2085.00000 2086.35975  0.07%  10.7 1485s
#   4100  4368 2086.10635  708   57 2085.00000 2086.35975  0.07%  10.5 1643s
#   4462  4955 2086.10635  790   55 2085.00000 2086.35975  0.07%  10.3 1727s
#   5074  5458 2086.06798  884   40 2085.00000 2086.35975  0.07%   9.8 1843s
#   5690  6203 2086.32217  116  157 2085.00000 2086.35975  0.07%   9.8 1984s
#   6492  6204 2086.05386  274  163 2085.00000 2086.35975  0.07%   9.6 2434s
#   6494  6205 2086.20091  148  236 2085.00000 2086.35975  0.07%   9.6 2758s
#   6495  6206 2086.28683   57  209 2085.00000 2086.28683  0.06%   9.6 3062s
#   6496  6207 2086.28683   32  171 2085.00000 2086.28683  0.06%   9.6 3206s
#   6498  6208 2085.99897  524  165 2085.00000 2086.28644  0.06%   9.6 3356s
#   6499  6209 2086.00437  377  138 2085.00000 2086.28644  0.06%   9.6 3492s
#   6500  6209 2086.24440  169  167 2085.00000 2086.28027  0.06%   9.6 3497s
#   6501  6210 2086.12498  240  177 2085.00000 2086.28027  0.06%   9.6 3596s
#
# Cutting planes:
#   Gomory: 62
#   Cover: 97
#   MIR: 239
#   StrongCG: 74
#   Flow cover: 261
#   GUB cover: 50
#   RLT: 2
#
# Explored 6501 nodes (113219 simplex iterations) in 3641.26 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2085 2084 2083 1995
#
# Time limit reached
# Best objective 2.085000000000e+03, best bound 2.086000000000e+03, gap 0.0480%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4x5

# %%
datafile="4x3000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xb7582b1f
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1988.0000000
# Presolve removed 64 rows and 48 columns (presolve time = 8s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 11s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 18s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 21s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 33s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 35s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 40s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 45s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 50s) ...
# Presolve removed 68 rows and 48 columns (presolve time = 55s) ...
# Presolve removed 68 rows and 48 columns
# Presolve time: 59.01s
# Presolved: 14932 rows, 11952 columns, 17874196 nonzeros
# Variable types: 0 continuous, 11952 integer (11952 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9860000e+03   0.000000e+00   6.141500e+03     65s
#     4161    2.0765752e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.03s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.076575e+03, 4161 iterations, 6.52 seconds
# Total elapsed time = 72.43s
# Total elapsed time = 75.51s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2076.57524    0  144 1988.00000 2076.57524  4.46%     -   78s
# H    0     0                    2063.0000000 2076.57524  0.66%     -   78s
# H    0     0                    2073.0000000 2076.57524  0.17%     -   79s
# H    0     0                    2074.0000000 2076.57524  0.12%     -   81s
# H    0     0                    2075.0000000 2076.57524  0.08%     -   84s
#      0     0 2076.57500    0  162 2075.00000 2076.57500  0.08%     -  133s
# H    0     0                    2076.0000000 2076.57500  0.03%     -  144s
#      0     0 2076.57500    0  162 2076.00000 2076.57500  0.03%     -  144s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 3
#   MIR: 12
#   StrongCG: 1
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (9297 simplex iterations) in 144.26 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2076 2075 2074 ... 1988
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.076000000000e+03, best bound 2.076000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4.5x1

# %%
datafile="4x3000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x02f91aab
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1841.0000000
# Presolve removed 35 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 11s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 18s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 21s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 27s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 30s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 42s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 60s) ...
# Presolve removed 39 rows and 28 columns (presolve time = 65s) ...
# Presolve removed 39 rows and 28 columns
# Presolve time: 68.41s
# Presolved: 14961 rows, 11972 columns, 17934052 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8410000e+03   0.000000e+00   6.072750e+03     75s
#     1036    1.8523100e+03   0.000000e+00   7.039961e+02     75s
#     4067    1.9357962e+03   0.000000e+00   0.000000e+00     77s
# Concurrent spin time: 0.05s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.935796e+03, 4067 iterations, 6.46 seconds
# Total elapsed time = 81.54s
# Total elapsed time = 85.82s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1935.79622    0  154 1841.00000 1935.79622  5.15%     -   87s
# H    0     0                    1927.0000000 1935.79622  0.46%     -   88s
# H    0     0                    1931.0000000 1935.79622  0.25%     -   88s
# H    0     0                    1933.0000000 1935.79622  0.14%     -   90s
# H    0     0                    1934.0000000 1935.79622  0.09%     -   98s
#      0     0 1935.78207    0  120 1934.00000 1935.78207  0.09%     -  143s
#      0     0 1935.76941    0  139 1934.00000 1935.76941  0.09%     -  161s
#      0     0 1935.76902    0  132 1934.00000 1935.76902  0.09%     -  165s
#      0     0 1935.76884    0  128 1934.00000 1935.76884  0.09%     -  168s
#      0     0 1935.73700    0  108 1934.00000 1935.73700  0.09%     -  181s
#      0     0 1935.71980    0   85 1934.00000 1935.71980  0.09%     -  188s
#      0     0 1935.65037    0   81 1934.00000 1935.65037  0.09%     -  192s
#      0     0 1935.64998    0   85 1934.00000 1935.64998  0.09%     -  195s
#      0     0 1935.64998    0   85 1934.00000 1935.64998  0.09%     -  198s
#      0     0 1935.64677    0   86 1934.00000 1935.64677  0.09%     -  210s
#      0     0 1935.64256    0   86 1934.00000 1935.64256  0.08%     -  225s
#      0     0 1935.64256    0   93 1934.00000 1935.64256  0.08%     -  229s
#      0     0 1935.60109    0   83 1934.00000 1935.60109  0.08%     -  242s
#      0     0 1935.60109    0   98 1934.00000 1935.60109  0.08%     -  261s
#      0     0 1935.60109    0   99 1934.00000 1935.60109  0.08%     -  273s
#      0     0 1935.60109    0   89 1934.00000 1935.60109  0.08%     -  287s
#      0     0 1935.60109    0   76 1934.00000 1935.60109  0.08%     -  336s
#      0     0 1935.59979    0   98 1934.00000 1935.59979  0.08%     -  343s
#      0     0 1935.59979    0   89 1934.00000 1935.59979  0.08%     -  347s
#      0     0 1935.59979    0   82 1934.00000 1935.59979  0.08%     -  366s
#      0     0 1935.59977    0   88 1934.00000 1935.59977  0.08%     -  378s
#      0     0 1935.59977    0   86 1934.00000 1935.59977  0.08%     -  390s
#      0     0 1935.56152    0  105 1934.00000 1935.56152  0.08%     -  398s
#      0     0 1935.51609    0  113 1934.00000 1935.51609  0.08%     -  403s
#      0     0 1935.51609    0  113 1934.00000 1935.51609  0.08%     -  406s
#      0     0 1935.46075    0  110 1934.00000 1935.46075  0.08%     -  419s
#      0     0 1935.38358    0  105 1934.00000 1935.38358  0.07%     -  432s
#      0     0 1935.38358    0  109 1934.00000 1935.38358  0.07%     -  435s
#      0     0 1935.38358    0  105 1934.00000 1935.38358  0.07%     -  447s
#      0     0 1935.38358    0  110 1934.00000 1935.38358  0.07%     -  458s
#      0     0 1935.38352    0  107 1934.00000 1935.38352  0.07%     -  469s
#      0     0 1935.37488    0   93 1934.00000 1935.37488  0.07%     -  480s
#      0     0 1935.37488    0   93 1934.00000 1935.37488  0.07%     -  483s
#      0     0 1935.37488    0  100 1934.00000 1935.37488  0.07%     -  495s
#      0     0 1935.37488    0   99 1934.00000 1935.37488  0.07%     -  502s
#      0     0 1935.37488    0  102 1934.00000 1935.37488  0.07%     -  541s
#      0     0 1935.37488    0  102 1934.00000 1935.37488  0.07%     -  552s
#      0     0 1935.37488    0   89 1934.00000 1935.37488  0.07%     -  569s
#      0     0 1935.37488    0   97 1934.00000 1935.37488  0.07%     -  579s
#      0     0 1935.37488    0   82 1934.00000 1935.37488  0.07%     -  607s
#      0     0 1935.37488    0   82 1934.00000 1935.37488  0.07%     -  615s
#      0     0 1935.37488    0   91 1934.00000 1935.37488  0.07%     -  631s
#      0     0 1935.37488    0   89 1934.00000 1935.37488  0.07%     -  637s
#      0     2 1935.37488    0   89 1934.00000 1935.37488  0.07%     -  664s
#      1     4 1935.09349    1   96 1934.00000 1935.37488  0.07%  1445  667s
#      3     6 infeasible    2      1934.00000 1935.37154  0.07%   485  671s
#      7    12 1935.37119    3   97 1934.00000 1935.37119  0.07%   260  678s
#     13    18 1935.37119    4   85 1934.00000 1935.37119  0.07%   201  683s
#     19    24 1935.37004    5   82 1934.00000 1935.37119  0.07%   159  687s
#     25    30 1935.37119    5   87 1934.00000 1935.37119  0.07%   130  690s
#     31    36 1935.37119    6   90 1934.00000 1935.37119  0.07%   111  698s
#     37    43 1935.37119    6   85 1934.00000 1935.37119  0.07%  96.6  701s
#     44    51 1935.37119    7   84 1934.00000 1935.37119  0.07%  83.0  705s
#     60    74 1935.37119   10   79 1934.00000 1935.37119  0.07%  64.9  722s
#     75    89 1935.37119   11   86 1934.00000 1935.37119  0.07%  54.9  734s
# H   87    89                    1935.0000000 1935.37119  0.02%  49.8  734s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 528
#   MIR: 281
#   StrongCG: 80
#   RLT: 3
#
# Explored 94 nodes (38240 simplex iterations) in 734.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 1935 1934 1933 ... 1841
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.935000000000e+03, best bound 1.935000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4.5x2

# %%
datafile="4x3000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x25f77c55
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1862.0000000
# Presolve removed 37 rows and 36 columns (presolve time = 8s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 11s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 23s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 25s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 30s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 35s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 36 columns
# Presolve time: 49.43s
# Presolved: 14963 rows, 11964 columns, 17910184 nonzeros
# Variable types: 0 continuous, 11964 integer (11964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8620000e+03   0.000000e+00   6.157000e+03     56s
#     4070    1.9522733e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.952273e+03, 4070 iterations, 6.59 seconds
# Total elapsed time = 62.63s
# Total elapsed time = 65.19s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1952.27335    0  130 1862.00000 1952.27335  4.85%     -   68s
# H    0     0                    1948.0000000 1952.27335  0.22%     -   69s
# H    0     0                    1949.0000000 1952.27335  0.17%     -   73s
#      0     0 1952.21718    0  132 1949.00000 1952.21718  0.17%     -   85s
# H    0     0                    1951.0000000 1952.21718  0.06%     -   98s
#      0     0 infeasible    0      1951.00000 1951.00000  0.00%     -  100s
#
# Cutting planes:
#   Gomory: 21
#   Cover: 10
#   MIR: 59
#   StrongCG: 2
#
# Explored 1 nodes (9301 simplex iterations) in 100.22 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1951 1949 1948 1862
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.951000000000e+03, best bound 1.951000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4.5x3

# %%
datafile="4x3000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x945ec9d0
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1855.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 8s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 11s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 23s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 25s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 30s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 35s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 40s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 45s) ...
# Presolve removed 42 rows and 24 columns
# Presolve time: 49.42s
# Presolved: 14958 rows, 11976 columns, 17946012 nonzeros
# Variable types: 0 continuous, 11976 integer (11976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8550000e+03   0.000000e+00   6.156500e+03     56s
#     3477    1.9518117e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.951812e+03, 3477 iterations, 6.40 seconds
# Total elapsed time = 63.04s
# Total elapsed time = 65.74s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1951.81170    0  209 1855.00000 1951.81170  5.22%     -   71s
# H    0     0                    1948.0000000 1951.81170  0.20%     -   71s
# H    0     0                    1950.0000000 1951.81170  0.09%     -   75s
#      0     0 1951.81170    0  213 1950.00000 1951.81170  0.09%     -   89s
# H    0     0                    1951.0000000 1951.81170  0.04%     -  100s
#      0     0 1951.81170    0  213 1951.00000 1951.81170  0.04%     -  100s
#
# Cutting planes:
#   Cover: 4
#   MIR: 3
#   StrongCG: 4
#
# Explored 1 nodes (8977 simplex iterations) in 100.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1951 1950 1948 1855
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.951000000000e+03, best bound 1.951000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4.5x4

# %%
datafile="4x3000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x8df03600
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1869.0000000
# Presolve removed 62 rows and 40 columns (presolve time = 8s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 11s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 23s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 25s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 30s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 35s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 40s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 62 rows and 40 columns
# Presolve time: 49.64s
# Presolved: 14938 rows, 11960 columns, 17898116 nonzeros
# Variable types: 0 continuous, 11960 integer (11960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8690000e+03   0.000000e+00   6.156500e+03     56s
#     3540    1.9573720e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.957372e+03, 3540 iterations, 6.08 seconds
# Total elapsed time = 62.52s
# Total elapsed time = 65.78s
# Total elapsed time = 70.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1957.37195    0  162 1869.00000 1957.37195  4.73%     -   71s
# H    0     0                    1949.0000000 1957.37195  0.43%     -   71s
# H    0     0                    1954.0000000 1957.37195  0.17%     -   74s
# H    0     0                    1956.0000000 1957.37195  0.07%     -   76s
#      0     0 1957.37195    0  178 1956.00000 1957.37195  0.07%     -   87s
#      0     0 1957.31188    0  175 1956.00000 1957.31188  0.07%     -  100s
#      0     0 1957.31081    0  164 1956.00000 1957.31081  0.07%     -  105s
#      0     0 1957.31041    0  167 1956.00000 1957.31041  0.07%     -  110s
#      0     0 1957.31041    0  177 1956.00000 1957.31041  0.07%     -  114s
#      0     0 1957.30808    0  123 1956.00000 1957.30808  0.07%     -  138s
#      0     0 1957.18424    0  163 1956.00000 1957.18424  0.06%     -  148s
#      0     0 1957.18424    0  157 1956.00000 1957.18424  0.06%     -  151s
#      0     0 1957.18394    0  131 1956.00000 1957.18394  0.06%     -  180s
#      0     0 1957.18394    0  186 1956.00000 1957.18394  0.06%     -  234s
#      0     0 1957.18394    0  149 1956.00000 1957.18394  0.06%     -  242s
#      0     0 1957.18394    0  143 1956.00000 1957.18394  0.06%     -  248s
#      0     0 1957.18394    0  143 1956.00000 1957.18394  0.06%     -  250s
#      0     0 1957.18353    0  139 1956.00000 1957.18353  0.06%     -  253s
#      0     0 1957.18353    0  126 1956.00000 1957.18353  0.06%     -  254s
#      0     0 1957.16744    0  113 1956.00000 1957.16744  0.06%     -  263s
#      0     0 1957.12314    0  110 1956.00000 1957.12314  0.06%     -  267s
#      0     0 1957.12090    0  111 1956.00000 1957.12090  0.06%     -  269s
#      0     0 1957.12090    0  111 1956.00000 1957.12090  0.06%     -  271s
#      0     0 1957.11054    0  111 1956.00000 1957.11054  0.06%     -  279s
#      0     0 1957.02561    0  109 1956.00000 1957.02561  0.05%     -  284s
#      0     0 1957.02561    0  106 1956.00000 1957.02561  0.05%     -  286s
#      0     0 1957.02561    0  101 1956.00000 1957.02561  0.05%     -  291s
#      0     0 1956.99873    0   92 1956.00000 1956.99873  0.05%     -  295s
#      0     0     cutoff    0      1956.00000 1956.00000  0.00%     -  297s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 3
#   MIR: 44
#   StrongCG: 6
#   RLT: 3
#
# Explored 1 nodes (33382 simplex iterations) in 297.62 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1956 1954 1949 ... 1869
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.956000000000e+03, best bound 1.956000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x4.5x5

# %%
datafile="4x3000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0xb75e7fab
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 1843.0000000
# Presolve removed 24 rows and 16 columns (presolve time = 8s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 11s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 18s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 21s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 27s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 30s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 42s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 45s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 50s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 55s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 60s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 65s) ...
# Presolve removed 28 rows and 16 columns
# Presolve time: 68.49s
# Presolved: 14972 rows, 11984 columns, 17969984 nonzeros
# Variable types: 0 continuous, 11984 integer (11984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8430000e+03   0.000000e+00   6.084250e+03     75s
#      895    1.8498323e+03   0.000000e+00   9.962131e+02     75s
#     4053    1.9354342e+03   0.000000e+00   0.000000e+00     77s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.935434e+03, 4053 iterations, 6.53 seconds
# Total elapsed time = 81.84s
# Total elapsed time = 85.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1935.43422    0  309 1843.00000 1935.43422  5.02%     -   90s
# H    0     0                    1931.0000000 1935.43422  0.23%     -   91s
# H    0     0                    1932.0000000 1935.43422  0.18%     -   99s
#      0     0 1935.42599    0  322 1932.00000 1935.42599  0.18%     -  147s
# H    0     0                    1934.0000000 1935.42599  0.07%     -  162s
#      0     0 1935.40065    0  302 1934.00000 1935.40065  0.07%     -  166s
#      0     0 1935.38205    0  288 1934.00000 1935.38205  0.07%     -  171s
#      0     0 1935.38205    0  290 1934.00000 1935.38205  0.07%     -  174s
#      0     0 1935.34788    0  263 1934.00000 1935.34788  0.07%     -  189s
#      0     0 1935.19911    0  269 1934.00000 1935.19911  0.06%     -  199s
#      0     0 1935.19911    0  261 1934.00000 1935.19911  0.06%     -  202s
#      0     0 1935.19115    0  284 1934.00000 1935.19115  0.06%     -  217s
#      0     0 1935.19044    0  282 1934.00000 1935.19044  0.06%     -  227s
#      0     0 1935.19044    0  290 1934.00000 1935.19044  0.06%     -  230s
#      0     0 1935.18544    0  269 1934.00000 1935.18544  0.06%     -  246s
#      0     0 1935.18544    0  275 1934.00000 1935.18544  0.06%     -  253s
#      0     0 1935.17899    0  208 1934.00000 1935.17899  0.06%     -  284s
#      0     0 1935.17899    0  301 1934.00000 1935.17899  0.06%     -  333s
#      0     0 1935.17899    0  312 1934.00000 1935.17899  0.06%     -  364s
#      0     0 1935.17899    0  258 1934.00000 1935.17899  0.06%     -  371s
#      0     0 1935.17899    0  256 1934.00000 1935.17899  0.06%     -  373s
#      0     0 1935.17899    0  256 1934.00000 1935.17899  0.06%     -  375s
#      0     0 1935.17899    0  257 1934.00000 1935.17899  0.06%     -  377s
#      0     0 1935.17325    0  259 1934.00000 1935.17325  0.06%     -  387s
#      0     0 1935.16269    0  257 1934.00000 1935.16269  0.06%     -  395s
#      0     0 1935.16269    0  256 1934.00000 1935.16269  0.06%     -  397s
#      0     0 1935.15678    0  245 1934.00000 1935.15678  0.06%     -  407s
#      0     0 1935.15678    0  224 1934.00000 1935.15678  0.06%     -  411s
#      0     0 1935.15678    0  230 1934.00000 1935.15678  0.06%     -  420s
#      0     0 1935.14995    0  222 1934.00000 1935.14995  0.06%     -  423s
#      0     0 1935.14943    0  226 1934.00000 1935.14943  0.06%     -  425s
#      0     0 1935.14943    0  224 1934.00000 1935.14943  0.06%     -  428s
#      0     0 1935.14217    0  198 1934.00000 1935.14217  0.06%     -  437s
#      0     0 1935.12824    0  198 1934.00000 1935.12824  0.06%     -  442s
#      0     0 1935.12824    0  199 1934.00000 1935.12824  0.06%     -  444s
#      0     0 1935.12765    0  206 1934.00000 1935.12765  0.06%     -  451s
#      0     0 1935.12731    0  187 1934.00000 1935.12731  0.06%     -  454s
#      0     0 1935.12731    0  184 1934.00000 1935.12731  0.06%     -  456s
#      0     0 1935.12725    0  184 1934.00000 1935.12725  0.06%     -  465s
#      0     0 1935.12720    0  185 1934.00000 1935.12720  0.06%     -  469s
#      0     0 1935.12689    0  174 1934.00000 1935.12689  0.06%     -  477s
#      0     0 1935.12689    0  179 1934.00000 1935.12689  0.06%     -  480s
#      0     0 1935.12689    0  185 1934.00000 1935.12689  0.06%     -  488s
#      0     0 1935.12689    0  177 1934.00000 1935.12689  0.06%     -  492s
#      0     0 1935.12689    0  159 1934.00000 1935.12689  0.06%     -  507s
#      0     0 1935.12689    0  181 1934.00000 1935.12689  0.06%     -  511s
#      0     0 1935.12689    0  158 1934.00000 1935.12689  0.06%     -  525s
#      0     0 1935.12689    0  158 1934.00000 1935.12689  0.06%     -  534s
#      0     2 1935.12689    0  158 1934.00000 1935.12689  0.06%     -  548s
#      3     6 1935.10916    2  157 1934.00000 1935.10916  0.06%   181  551s
#     13    13 1935.09158    4  155 1934.00000 1935.09158  0.06%  49.7  555s
#     31    29 1935.07667    7  151 1934.00000 1935.09158  0.06%  27.5  572s
#     53    62 1935.07667   11  158 1934.00000 1935.09158  0.06%  18.2  578s
#     70   106 1935.07563   13  164 1934.00000 1935.09158  0.06%  15.4  584s
#    115   204 1935.07160   24  160 1934.00000 1935.09158  0.06%  12.6  599s
#    220   355 1935.02160   44  152 1934.00000 1935.09158  0.06%   9.8  628s
#    399   636 1935.01428   84  143 1934.00000 1935.09158  0.06%  10.4  675s
#    804   981     cutoff   44      1934.00000 1935.07667  0.06%   9.7  726s
#   1314   982 1935.02630  107  208 1934.00000 1935.07306  0.06%  14.1  929s
#   1316   983 1935.00418   32  257 1934.00000 1935.07306  0.06%  14.1 1023s
#   1317   984 1935.02394  117  260 1934.00000 1935.07306  0.06%  14.1 1030s
#   1318   985 1935.00922   67  220 1934.00000 1935.07306  0.06%  14.1 1037s
#   1320   986 1935.05834   44  197 1934.00000 1935.07306  0.06%  14.1 1042s
#   1321   987 1935.05528   33  192 1934.00000 1935.07306  0.06%  14.1 1102s
#   1322   987 1935.01199   63  215 1934.00000 1935.07306  0.06%  14.1 1108s
#   1323   988 1935.03501    8  217 1934.00000 1935.06608  0.06%  14.0 1114s
#   1324   989 1935.06193   18  236 1934.00000 1935.06519  0.06%  14.0 1116s
#   1325   989 1935.00756   15  228 1934.00000 1935.06519  0.06%  14.0 1173s
#   1326   990 1935.01345   10  203 1934.00000 1935.06515  0.06%  14.0 1179s
#   1327   991 1935.00114   13  206 1934.00000 1935.06512  0.06%  14.0 1232s
#   1328   991 1935.06455   15  194 1934.00000 1935.06510  0.06%  14.0 1243s
#   1329   992 1935.00338   28  186 1934.00000 1935.06324  0.05%  14.0 1251s
#   1330   993 1935.02416  111  195 1934.00000 1935.05985  0.05%  14.0 1256s
#   1331   993 1935.00299   20  211 1934.00000 1935.05918  0.05%  14.0 1260s
#   1332   994 1935.05848   31  214 1934.00000 1935.05918  0.05%  13.9 1307s
#   1333   995 1935.05019   15  201 1934.00000 1935.05918  0.05%  13.9 1311s
#   1334   995 1935.00545   20  186 1934.00000 1935.05751  0.05%  13.9 1324s
#   1335   996 1934.99966   20  199 1934.00000 1935.05751  0.05%  13.9 1355s
#   1337   997 1935.00304   27  330 1934.00000 1935.05734  0.05%  13.9 1388s
#   1338   998 1935.05528   33  265 1934.00000 1935.05734  0.05%  13.9 1392s
#   1339   999 1934.99871   46  315 1934.00000 1935.05728  0.05%  13.9 1422s
#   1340   999 1935.02590  108  259 1934.00000 1935.05727  0.05%  13.9 1425s
#   1341  1000 1935.00507   45  245 1934.00000 1935.05724  0.05%  13.9 1454s
#   1342  1001 1935.02394   48  243 1934.00000 1935.05723  0.05%  13.8 1459s
#   1343  1001 1934.99871   41  255 1934.00000 1935.05717  0.05%  13.8 1488s
#   1344  1002 1935.05716   17  234 1934.00000 1935.05716  0.05%  13.8 1495s
#   1345  1003 1935.05275   49  204 1934.00000 1935.05715  0.05%  13.8 1517s
#   1346  1003 1935.05662   18  165 1934.00000 1935.05662  0.05%  13.8 1534s
#   1347  1004 1934.99928   23  163 1934.00000 1935.05662  0.05%  13.8 1552s
#   1348  1005 1935.00891   27  163 1934.00000 1935.05662  0.05%  13.8 1591s
#   1349  1007 1935.05166   14  123 1934.00000 1935.05166  0.05%  29.9 1603s
#   1351  1008 1935.03201   15  142 1934.00000 1935.04784  0.05%  30.0 1605s
#   1361  1003 1935.02334   18  118 1934.00000 1935.02663  0.05%  29.9 1610s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 1
#   MIR: 27
#   Flow cover: 12
#
# Explored 1370 nodes (75372 simplex iterations) in 1613.31 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1934 1933 1932 ... 1843
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.934000000000e+03, best bound 1.934000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x5x1

# %%
datafile="4x3000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x21c8906b
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1759.0000000
# Presolve removed 35 rows and 28 columns (presolve time = 8s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 11s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 17s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 20s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 32s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 35s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 40s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 35 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 35 rows and 28 columns
# Presolve time: 58.56s
# Presolved: 14965 rows, 11972 columns, 17934104 nonzeros
# Variable types: 0 continuous, 11972 integer (11972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7620000e+03   0.000000e+00   6.177250e+03     65s
#     1181    1.7815306e+03   0.000000e+00   6.215795e+02     65s
#     3591    1.8457842e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.845784e+03, 3591 iterations, 6.22 seconds
# Total elapsed time = 71.26s
# Total elapsed time = 75.55s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1845.78424    0  146 1759.00000 1845.78424  4.93%     -   77s
# H    0     0                    1843.0000000 1845.78424  0.15%     -   77s
# H    0     0                    1844.0000000 1845.78424  0.10%     -   80s
#      0     0 1845.77551    0  158 1844.00000 1845.77551  0.10%     -  131s
# H    0     0                    1845.0000000 1845.77551  0.04%     -  144s
#      0     0 1845.77551    0  158 1845.00000 1845.77551  0.04%     -  144s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 13
#   Clique: 1
#   MIR: 31
#   StrongCG: 7
#   GUB cover: 4
#   RLT: 2
#
# Explored 1 nodes (9747 simplex iterations) in 144.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1845 1844 1843 1759
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.845000000000e+03, best bound 1.845000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x5x2

# %%
datafile="4x3000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x39fb473c
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1741.0000000
# Presolve removed 48 rows and 32 columns (presolve time = 8s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 11s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 23s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 25s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 30s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 35s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 48 rows and 32 columns
# Presolve time: 49.42s
# Presolved: 14952 rows, 11968 columns, 17922048 nonzeros
# Variable types: 0 continuous, 11968 integer (11968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7430000e+03   0.000000e+00   6.115000e+03     56s
#     3922    1.8318422e+03   0.000000e+00   0.000000e+00     58s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.831842e+03, 3922 iterations, 6.62 seconds
# Total elapsed time = 62.39s
# Total elapsed time = 65.28s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1831.84218    0  151 1741.00000 1831.84218  5.22%     -   68s
# H    0     0                    1828.0000000 1831.84218  0.21%     -   68s
# H    0     0                    1829.0000000 1831.84218  0.16%     -   71s
# H    0     0                    1830.0000000 1831.84218  0.10%     -   73s
#      0     0 1831.83460    0  163 1830.00000 1831.83460  0.10%     -  120s
# H    0     0                    1831.0000000 1831.83460  0.05%     -  131s
#      0     0 1831.83460    0  163 1831.00000 1831.83460  0.05%     -  131s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 3
#   MIR: 42
#   GUB cover: 4
#   RLT: 2
#
# Explored 1 nodes (11096 simplex iterations) in 131.98 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1831 1830 1829 ... 1741
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.831000000000e+03, best bound 1.831000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x5x3

# %%
datafile="4x3000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x5f1f523e
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1746.0000000
# Presolve removed 64 rows and 48 columns (presolve time = 8s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 11s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 18s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 21s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 33s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 35s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 40s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 45s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 50s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 55s) ...
# Presolve removed 64 rows and 48 columns
# Presolve time: 58.89s
# Presolved: 14936 rows, 11952 columns, 17874192 nonzeros
# Variable types: 0 continuous, 11952 integer (11952 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7530000e+03   0.000000e+00   6.138750e+03     65s
#     3830    1.8377286e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.837729e+03, 3830 iterations, 6.38 seconds
# Total elapsed time = 71.90s
# Total elapsed time = 75.03s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1837.72864    0  336 1746.00000 1837.72864  5.25%     -   79s
# H    0     0                    1834.0000000 1837.72864  0.20%     -   80s
# H    0     0                    1835.0000000 1837.72864  0.15%     -   91s
#      0     0 1837.71380    0  351 1835.00000 1837.71380  0.15%     -  141s
# H    0     0                    1836.0000000 1837.71380  0.09%     -  157s
#      0     0 1837.71166    0  354 1836.00000 1837.71166  0.09%     -  159s
#      0     0 1837.71166    0  354 1836.00000 1837.71166  0.09%     -  163s
#      0     0 1837.68084    0  301 1836.00000 1837.68084  0.09%     -  182s
#      0     0 1837.67919    0  297 1836.00000 1837.67919  0.09%     -  189s
#      0     0 1837.67919    0  295 1836.00000 1837.67919  0.09%     -  192s
#      0     0 1837.62189    0  265 1836.00000 1837.62189  0.09%     -  212s
#      0     0 1837.62184    0  256 1836.00000 1837.62184  0.09%     -  230s
#      0     0 1837.61964    0  260 1836.00000 1837.61964  0.09%     -  247s
#      0     0 1837.61964    0  248 1836.00000 1837.61964  0.09%     -  256s
#      0     0 1837.61385    0  253 1836.00000 1837.61385  0.09%     -  273s
#      0     0 1837.61385    0  254 1836.00000 1837.61385  0.09%     -  280s
#      0     0 1837.61385    0  260 1836.00000 1837.61385  0.09%     -  296s
#      0     0 1837.61385    0  249 1836.00000 1837.61385  0.09%     -  303s
#      0     0 1837.61385    0  202 1836.00000 1837.61385  0.09%     -  362s
#      0     0 1837.61385    0  203 1836.00000 1837.61385  0.09%     -  376s
#      0     0 1837.61385    0  219 1836.00000 1837.61385  0.09%     -  401s
#      0     0 1837.61380    0  225 1836.00000 1837.61380  0.09%     -  409s
#      0     0 1837.61340    0  233 1836.00000 1837.61340  0.09%     -  430s
#      0     0 1837.61292    0  234 1836.00000 1837.61292  0.09%     -  444s
#      0     0 1837.61292    0  239 1836.00000 1837.61292  0.09%     -  447s
#      0     0 1837.61292    0  240 1836.00000 1837.61292  0.09%     -  464s
#      0     0 1837.61292    0  187 1836.00000 1837.61292  0.09%     -  479s
#      0     2 1837.61292    0  187 1836.00000 1837.61292  0.09%     -  514s
#      1     4 1837.29879    1  184 1836.00000 1837.61292  0.09%  2249  517s
#      3     8 1837.25510    2  205 1836.00000 1837.61292  0.09%   792  522s
#      7    14 1837.09498    3  233 1836.00000 1837.61292  0.09%   416  528s
#     13    18     cutoff    4      1836.00000 1837.61292  0.09%   295  534s
#     19    24 1837.09482    4  229 1836.00000 1837.61292  0.09%   237  539s
#     25    30 1837.09482    5  226 1836.00000 1837.61292  0.09%   194  542s
#     31    36 1837.09482    5  223 1836.00000 1837.61292  0.09%   159  560s
#     43    48 1837.09482    7  231 1836.00000 1837.61292  0.09%   119  568s
#     49    55 1837.09482    7  224 1836.00000 1837.61292  0.09%   105  571s
#     56    85 1837.09482    8  222 1836.00000 1837.61292  0.09%  93.4  579s
#     86    91 1837.09415   12  230 1836.00000 1837.61292  0.09%  65.7  587s
#     92   157 1837.09415   13  230 1836.00000 1837.61292  0.09%  63.8  600s
#    158   169 1837.08994   24  205 1836.00000 1837.61292  0.09%  41.7  614s
#    170   320 1837.08994   26  207 1836.00000 1837.61292  0.09%  39.5  647s
#    321   418 1837.08716   38  188 1836.00000 1837.61292  0.09%  25.2  679s
#    421   730     cutoff   58      1836.00000 1837.61292  0.09%  21.2  746s
#    744  1210 1837.19278   45  205 1836.00000 1837.61292  0.09%  15.6  843s
#   1232  1367 1837.10997  143  190 1836.00000 1837.61292  0.09%  12.6  898s
#   1400  1817 1837.10890  170  189 1836.00000 1837.61292  0.09%  12.4  978s
#   1868  2301 1837.09659  230  170 1836.00000 1837.61292  0.09%  11.5 1083s
#   2460  2648 1837.03544  108  202 1836.00000 1837.61292  0.09%  11.0 1159s
#   2834  2649 1837.53420   57  187 1836.00000 1837.61292  0.09%  10.6 1429s
#   2836  2650 1837.16057   59  339 1836.00000 1837.61292  0.09%  10.6 1727s
#   2837  2651 1837.57922    6  306 1836.00000 1837.61292  0.09%  10.6 1980s
#   2838  2652 1837.22823   99  224 1836.00000 1837.58929  0.09%  10.6 1993s
#   2839  2652 1837.27215  126  215 1836.00000 1837.58823  0.09%  10.6 1997s
#   2840  2653 1837.22516  321  216 1836.00000 1837.58593  0.09%  10.6 2001s
#   2841  2654 1837.29792   35  217 1836.00000 1837.58593  0.09%  10.6 2206s
#   2842  2654 1837.56551   24  183 1836.00000 1837.56551  0.09%  10.6 2450s
#   2843  2655 1837.36314  103  182 1836.00000 1837.56390  0.09%  10.6 2467s
#   2844  2656 1836.99880  149  178 1836.00000 1837.56390  0.09%  10.6 2501s
#   2845  2656 1837.33567  107  201 1836.00000 1837.56390  0.09%  10.6 2554s
#   2846  2657 1837.56124   50  218 1836.00000 1837.56124  0.09%  10.6 2560s
#   2847  2658 1837.39757  129  204 1836.00000 1837.56124  0.09%  10.6 2588s
#   2848  2658 1837.52541   99  181 1836.00000 1837.54663  0.08%  10.6 2648s
#   2849  2659 1837.19820  142  190 1836.00000 1837.54594  0.08%  10.5 2658s
#   2850  2660 1837.50600   26  206 1836.00000 1837.50600  0.08%  10.5 2663s
#   2851  2660 1837.21241   22  211 1836.00000 1837.50600  0.08%  10.5 2701s
#   2852  2661 1837.22782   98  170 1836.00000 1837.50369  0.08%  10.5 2779s
#   2853  2662 1837.29704   16  181 1836.00000 1837.45997  0.08%  10.5 2787s
#   2854  2662 1837.34824  177  189 1836.00000 1837.45997  0.08%  10.5 2816s
#   2855  2663 1837.45997   75  180 1836.00000 1837.45997  0.08%  10.5 2884s
#   2856  2664 1837.45997   91  178 1836.00000 1837.45997  0.08%  10.5 2935s
#   2857  2664 1837.25312  244  196 1836.00000 1837.45997  0.08%  10.5 3007s
#   2858  2665 1837.05040   69  198 1836.00000 1837.45997  0.08%  10.5 3048s
#   2859  2666 1837.25032   43  163 1836.00000 1837.45010  0.08%  10.5 3143s
#   2860  2666 1837.23800  304  186 1836.00000 1837.43987  0.08%  10.5 3153s
#   2861  2667 1837.43807   22  183 1836.00000 1837.43807  0.08%  10.5 3158s
#   2862  2668 1837.43807   27  181 1836.00000 1837.43807  0.08%  10.5 3217s
#   2863  2668 1837.43807   30  163 1836.00000 1837.43807  0.08%  10.5 3302s
#   2864  2669 1837.43807   22  172 1836.00000 1837.43807  0.08%  10.5 3365s
#   2865  2670 1837.43807   49  161 1836.00000 1837.43807  0.08%  10.5 3453s
#   2866  2670 1837.25339   26  194 1836.00000 1837.43807  0.08%  10.5 3519s
#
# Cutting planes:
#   Gomory: 77
#   Cover: 81
#   MIR: 241
#   StrongCG: 40
#   Flow cover: 229
#   Zero half: 5
#   Mod-K: 1
#   RLT: 6
#
# Explored 2866 nodes (109019 simplex iterations) in 3601.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 1836 1835 1834 1746
#
# Time limit reached
# Best objective 1.836000000000e+03, best bound 1.837000000000e+03, gap 0.0545%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x5x4

# %%
datafile="4x3000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x07de3efc
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1756.0000000
# Presolve removed 26 rows and 24 columns (presolve time = 8s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 11s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 18s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 20s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 32s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 35s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 40s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 24 columns (presolve time = 55s) ...
# Presolve removed 26 rows and 24 columns
# Presolve time: 58.60s
# Presolved: 14974 rows, 11976 columns, 17946080 nonzeros
# Variable types: 0 continuous, 11976 integer (11976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7560000e+03   0.000000e+00   6.225000e+03     65s
#      757    1.7622416e+03   0.000000e+00   1.173509e+03     65s
#     3295    1.8405221e+03   0.000000e+00   0.000000e+00     67s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.840522e+03, 3295 iterations, 6.14 seconds
# Total elapsed time = 70.93s
# Total elapsed time = 76.50s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1840.52208    0  153 1756.00000 1840.52208  4.81%     -   79s
# H    0     0                    1830.0000000 1840.52208  0.57%     -   79s
# H    0     0                    1836.0000000 1840.52208  0.25%     -   80s
# H    0     0                    1837.0000000 1840.52208  0.19%     -   87s
#      0     0 1840.51698    0  147 1837.00000 1840.51698  0.19%     -  133s
# H    0     0                    1839.0000000 1840.51698  0.08%     -  144s
#      0     0 1840.17595    0  146 1839.00000 1840.17595  0.06%     -  148s
#      0     0 1840.17595    0  146 1839.00000 1840.17595  0.06%     -  151s
#      0     0 1840.05621    0   98 1839.00000 1840.05621  0.06%     -  175s
#      0     0 1840.05621    0  179 1839.00000 1840.05621  0.06%     -  211s
#      0     0 1840.05621    0  158 1839.00000 1840.05621  0.06%     -  229s
#      0     0 1840.05621    0  122 1839.00000 1840.05621  0.06%     -  232s
#      0     0 infeasible    0      1839.00000 1839.00000  0.00%     -  233s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 6
#   MIR: 62
#   StrongCG: 1
#   GUB cover: 4
#
# Explored 1 nodes (20551 simplex iterations) in 233.94 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 1839 1837 1836 ... 1756
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.839000000000e+03, best bound 1.839000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x3000x5x5

# %%
datafile="4x3000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 3000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 15000 rows, 12000 columns and 18018000 nonzeros
# Model fingerprint: 0x26c1bc5b
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+03]
# Found heuristic solution: objective 1754.0000000
# Presolve removed 67 rows and 44 columns (presolve time = 8s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 11s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 23s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 25s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 30s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 35s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 40s) ...
# Presolve removed 67 rows and 44 columns (presolve time = 45s) ...
# Presolve removed 67 rows and 44 columns
# Presolve time: 49.02s
# Presolved: 14933 rows, 11956 columns, 17886152 nonzeros
# Variable types: 0 continuous, 11956 integer (11956 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7540000e+03   0.000000e+00   6.148000e+03     55s
#     3846    1.8455224e+03   0.000000e+00   0.000000e+00     57s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.845522e+03, 3846 iterations, 6.44 seconds
# Total elapsed time = 62.26s
# Total elapsed time = 65.37s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1845.52236    0  195 1754.00000 1845.52236  5.22%     -   68s
# H    0     0                    1835.0000000 1845.52236  0.57%     -   68s
# H    0     0                    1840.0000000 1845.52236  0.30%     -   70s
# H    0     0                    1841.0000000 1845.52236  0.25%     -   71s
# H    0     0                    1842.0000000 1845.52236  0.19%     -   78s
#      0     0 1845.40317    0  209 1842.00000 1845.40317  0.18%     -   90s
# H    0     0                    1843.0000000 1845.40317  0.13%     -  106s
#      0     0 1845.13598    0  204 1843.00000 1845.13598  0.12%     -  108s
#      0     0 1845.13598    0  198 1843.00000 1845.13598  0.12%     -  111s
#      0     0 1844.70137    0  160 1843.00000 1844.70137  0.09%     -  125s
#      0     0 1844.70084    0  149 1843.00000 1844.70084  0.09%     -  133s
#      0     0 1844.70084    0  145 1843.00000 1844.70084  0.09%     -  136s
#      0     0 1844.46699    0  129 1843.00000 1844.46699  0.08%     -  152s
#      0     0 1844.46699    0  136 1843.00000 1844.46699  0.08%     -  162s
#      0     0 1844.36455    0  133 1843.00000 1844.36455  0.07%     -  177s
#      0     0 1844.36025    0  127 1843.00000 1844.36025  0.07%     -  185s
#      0     0 1844.36025    0  130 1843.00000 1844.36025  0.07%     -  188s
#      0     0 1844.32853    0  151 1843.00000 1844.32853  0.07%     -  201s
#      0     0 1844.31905    0  133 1843.00000 1844.31905  0.07%     -  207s
#      0     0 1844.31905    0  131 1843.00000 1844.31905  0.07%     -  211s
#      0     0 1844.31870    0  129 1843.00000 1844.31870  0.07%     -  222s
#      0     0 1844.31685    0  133 1843.00000 1844.31685  0.07%     -  234s
#      0     0 1844.31685    0  124 1843.00000 1844.31685  0.07%     -  237s
#      0     0 1844.31685    0  123 1843.00000 1844.31685  0.07%     -  249s
#      0     0 1844.31685    0  131 1843.00000 1844.31685  0.07%     -  261s
#      0     0 1844.31685    0  133 1843.00000 1844.31685  0.07%     -  272s
#      0     0 1844.31685    0  132 1843.00000 1844.31685  0.07%     -  278s
#      0     0 1844.31685    0  117 1843.00000 1844.31685  0.07%     -  301s
#      0     0 1844.31685    0  118 1843.00000 1844.31685  0.07%     -  307s
#      0     0 1844.31685    0  126 1843.00000 1844.31685  0.07%     -  324s
#      0     0 1844.31685    0  120 1843.00000 1844.31685  0.07%     -  335s
#      0     0 1844.31685    0  229 1843.00000 1844.31685  0.07%     -  395s
#      0     0 1844.31685    0  152 1843.00000 1844.31685  0.07%     -  412s
#      0     0 1844.31685    0  142 1843.00000 1844.31685  0.07%     -  418s
#      0     0 1844.31685    0  142 1843.00000 1844.31685  0.07%     -  421s
#      0     0 1844.31685    0  146 1843.00000 1844.31685  0.07%     -  423s
#      0     0 1844.31685    0  137 1843.00000 1844.31685  0.07%     -  429s
#      0     0 1844.31685    0  130 1843.00000 1844.31685  0.07%     -  432s
#      0     0 1844.31685    0  132 1843.00000 1844.31685  0.07%     -  439s
#      0     0 1844.31685    0  128 1843.00000 1844.31685  0.07%     -  444s
#      0     0 1844.31685    0  112 1843.00000 1844.31685  0.07%     -  462s
#      0     0 1844.31685    0  124 1843.00000 1844.31685  0.07%     -  466s
#      0     0 1844.31685    0   98 1843.00000 1844.31685  0.07%     -  482s
#      0     0 1844.31685    0  112 1843.00000 1844.31685  0.07%     -  487s
#      0     0 1844.31685    0  114 1843.00000 1844.31685  0.07%     -  497s
#      0     0 1844.31685    0  114 1843.00000 1844.31685  0.07%     -  500s
#      0     0 1844.31685    0  109 1843.00000 1844.31685  0.07%     -  511s
#      0     0 1844.31685    0  122 1843.00000 1844.31685  0.07%     -  515s
#      0     0 1844.31685    0  111 1843.00000 1844.31685  0.07%     -  527s
#      0     0 1844.31623    0  117 1843.00000 1844.31623  0.07%     -  530s
#      0     0 1844.31574    0  112 1843.00000 1844.31574  0.07%     -  533s
#      0     0 1844.31574    0  111 1843.00000 1844.31574  0.07%     -  535s
#      0     0 1844.31574    0  101 1843.00000 1844.31574  0.07%     -  546s
#      0     0 1844.31574    0  101 1843.00000 1844.31574  0.07%     -  555s
#      0     2 1844.31574    0  101 1843.00000 1844.31574  0.07%     -  569s
#      1     5 1844.31088    1   94 1843.00000 1844.31088  0.07%   648  571s
#      3     8 1844.30814    2  109 1843.00000 1844.30814  0.07%   237  575s
#      7    14 1844.30814    3  111 1843.00000 1844.30814  0.07%   143  580s
#     19    25 1844.05885    5  146 1843.00000 1844.30814  0.07%   128  587s
#     25    30 1844.30814    5  120 1843.00000 1844.30814  0.07%   113  590s
#     31    36 1844.30814    6  114 1843.00000 1844.30814  0.07%  99.4  598s
#     37    42 1844.30814    7  114 1843.00000 1844.30814  0.07%  84.8  601s
#     52    60 1844.30768    8  108 1843.00000 1844.30814  0.07%  66.2  605s
#     61    78 1844.30768    9  108 1843.00000 1844.30814  0.07%  58.0  623s
#     79   159 1844.30507   12  125 1843.00000 1844.30814  0.07%  47.6  643s
#    160   407 1844.29901   23   72 1843.00000 1844.30814  0.07%  29.3  688s
#    408   828 1844.28059   57   89 1843.00000 1844.30814  0.07%  18.7  751s
#    829  1074 1844.25789  109   81 1843.00000 1844.30814  0.07%  13.7  795s
#   1075  1435 1844.22479  151   85 1843.00000 1844.30814  0.07%  12.0  848s
#   1447  1579 1844.00026  217   75 1843.00000 1844.30814  0.07%  10.4  891s
#   1602  2070 1844.00026  218   76 1843.00000 1844.30814  0.07%   9.9  957s
#   2172  2633 1844.28025   78   99 1843.00000 1844.30814  0.07%   9.1 1015s
#   2763  3280 1844.08478  151   68 1843.00000 1844.30814  0.07%   8.4 1079s
#   3410  3901 1844.08300  303   71 1843.00000 1844.30814  0.07%   7.7 1137s
#   4031  4286 1844.08119  450   70 1843.00000 1844.30814  0.07%   7.0 1188s
#   4416  4688 1844.08061  525   75 1843.00000 1844.30814  0.07%   6.7 1238s
#   4818  5040 1844.07950  637   71 1843.00000 1844.30814  0.07%   6.4 1289s
#   5177  5569 1844.07880  717   75 1843.00000 1844.30814  0.07%   6.3 1342s
#   5773  5973 1844.07805  791   69 1843.00000 1844.30814  0.07%   6.2 1455s
#   6202  5974 1844.16639  277  120 1843.00000 1844.30814  0.07%   6.1 1812s
#   6204  5975 1844.12323  560  166 1843.00000 1844.30814  0.07%   6.1 1915s
#   6205  5976 1844.17008  218  140 1843.00000 1844.30814  0.07%   6.1 1922s
#   6206  5977 1844.04877  342  128 1843.00000 1844.30814  0.07%   6.1 1930s
#   6208  5978 1844.05984  331  143 1843.00000 1844.30814  0.07%   6.1 1935s
#   6210  5979 1844.04373  481  132 1843.00000 1844.30814  0.07%   6.1 1979s
#   6211  5980 1844.05114  161  135 1843.00000 1844.30814  0.07%   6.1 1984s
#   6212  5981 1844.03285  522  117 1843.00000 1844.30814  0.07%   6.1 1987s
#   6213  5981 1844.02796  446  107 1843.00000 1844.30814  0.07%   6.1 1990s
#   6214  5982 1844.23598   81  107 1843.00000 1844.30814  0.07%   6.1 2035s
#   6215  5983 1844.18315  242  115 1843.00000 1844.30814  0.07%   6.1 2041s
#   6216  5983 1844.15633  276  103 1843.00000 1844.28432  0.07%   6.1 2054s
#   6217  5984 1844.02599  201   97 1843.00000 1844.28432  0.07%   6.1 2112s
#   6218  5985 1844.28432   51  104 1843.00000 1844.28432  0.07%   6.1 2116s
#   6219  5985 1844.18661  218   96 1843.00000 1844.28432  0.07%   6.1 2133s
#   6220  5986 1844.18641  209   97 1843.00000 1844.28432  0.07%   6.1 2139s
#   6221  5987 1844.09174  160  101 1843.00000 1844.28432  0.07%   6.1 2182s
#   6222  5987 1844.03741  409   88 1843.00000 1844.28432  0.07%   6.1 2227s
#   6223  5988 1844.18767  233   97 1843.00000 1844.28432  0.07%   6.1 2289s
#   6224  5989 1844.01673  645   88 1843.00000 1844.28432  0.07%   6.1 2338s
#   6225  5989 1844.18726  237   96 1843.00000 1844.28432  0.07%   6.1 2376s
#   6226  5990 1844.23660   71  119 1843.00000 1844.28101  0.07%   6.1 2424s
#   6227  5991 1844.28101   35  137 1843.00000 1844.28101  0.07%   6.1 2459s
#   6228  5991 1844.17139  268  189 1843.00000 1844.28093  0.07%   6.1 2465s
#   6230  5993 1844.06622  482  162 1843.00000 1844.28069  0.07%   6.1 2496s
#   6231  5993 1844.26112   65  144 1843.00000 1844.28069  0.07%   6.1 2503s
#   6232  5994 1844.26498    8  122 1843.00000 1844.28069  0.07%   6.1 2526s
#   6233  5995 1844.04735  395  122 1843.00000 1844.28069  0.07%   6.1 2541s
#   6234  5998 1844.28069   12  120 1843.00000 1844.28069  0.07%   9.0 2554s
#   6235  5998 1844.28062   12  117 1843.00000 1844.28062  0.07%   9.0 2555s
#   6236  6002 1844.27887   13  104 1843.00000 1844.27887  0.07%   9.0 2561s
#   6246  6010 1844.27727   15  104 1843.00000 1844.27727  0.07%   9.1 2565s
#   6264  6022 1844.27727   16  101 1843.00000 1844.27727  0.07%   9.1 2584s
#   6270  6028 1844.27727   17  107 1843.00000 1844.27727  0.07%   9.1 2588s
#   6278  6035 1844.24108   17  104 1843.00000 1844.27727  0.07%   9.3 2590s
#   6297  6062 1844.26927   19  100 1843.00000 1844.27493  0.07%   9.5 2599s
#   6322  6125 1844.24108   21  103 1843.00000 1844.27493  0.07%   9.5 2613s
#   6393  6245 1844.24108   26  104 1843.00000 1844.27493  0.07%   9.5 2639s
#   6537  6408 1844.23851   37  102 1843.00000 1844.27493  0.07%   9.6 2687s
#   6748  6593 1844.23824   55   89 1843.00000 1844.27493  0.07%   9.7 2744s
#   7003  6630 1844.23701   79   94 1843.00000 1844.27493  0.07%   9.9 2865s
#   7125  7180 1844.23682   85   88 1843.00000 1844.27493  0.07%  10.0 2973s
#   7759  7462 1844.23094  121   98 1843.00000 1844.27493  0.07%  11.7 3051s
#   8283  7442 1844.22571  147   91 1843.00000 1844.27493  0.07%  13.0 3098s
#   8439  7828 1844.22544  159  102 1843.00000 1844.27493  0.07%  13.1 3176s
#   8933  8355 1844.22107  192   98 1843.00000 1844.27493  0.07%  14.6 3272s
#   9735  8774 1844.10941  261   99 1843.00000 1844.27493  0.07%  15.2 3350s
#  10468  9087     cutoff  336      1843.00000 1844.27493  0.07%  14.6 3424s
#  11079  9649 1844.23760   64  104 1843.00000 1844.26621  0.07%  14.3 3502s
#  11883 10111 1844.00607  309  142 1843.00000 1844.24108  0.07%  14.1 3580s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 9
#   MIR: 18
#   StrongCG: 5
#   Flow cover: 21
#   RLT: 1
#
# Explored 12661 nodes (218033 simplex iterations) in 3600.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 7: 1843 1842 1842 ... 1754
#
# Time limit reached
# Best objective 1.843000000000e+03, best bound 1.844000000000e+03, gap 0.0543%

# %% [markdown]
# # Modelo de programación lineal Süer et. al.

# %%
import pandas as pd

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x1.5x1

# %%
datafile="2x4000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-06-11
# Using license file C:\Users\elPatan03\gurobi.lic
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x54ddd82b
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 20 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 20 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 20 rows and 4 columns
# Presolve time: 49.94s
# Presolved: 11980 rows, 7996 columns, 15995916 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   3.449278e+06   0.000000e+00     53s
#
# Root relaxation: cutoff, 0 iterations, 1.04 seconds
#
# Explored 0 nodes (0 simplex iterations) in 52.75 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.998000000000e+03, best bound 3.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x1.5x2

# %%
datafile="2x4000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x8b775e71
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 4000.0000000
# Presolve removed 24 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 19s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 24 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 24 rows and 0 columns
# Presolve time: 49.10s
# Presolved: 11976 rows, 8000 columns, 16011844 nonzeros
# Variable types: 0 continuous, 8000 integer (8000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0000000e+03   3.482177e+06   0.000000e+00     52s
#
# Root relaxation: cutoff, 0 iterations, 1.04 seconds
#
# Explored 0 nodes (0 simplex iterations) in 51.92 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 4000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+03, best bound 4.000000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x1.5x3

# %%
datafile="2x4000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xc7110e7d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 3993.0000000
# Presolve removed 12 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 19s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 0 columns
# Presolve time: 49.15s
# Presolved: 11988 rows, 8000 columns, 16011948 nonzeros
# Variable types: 0 continuous, 8000 integer (8000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0000000e+03   3.511969e+06   0.000000e+00     52s
#      727    3.9960977e+03   3.558102e+03   0.000000e+00     55s
#      808    3.9960923e+03   0.000000e+00   0.000000e+00     56s
#
# Root relaxation: objective 3.996092e+03, 808 iterations, 4.81 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3996.09234    0   10 3993.00000 3996.09234  0.08%     -   59s
# H    0     0                    3994.0000000 3996.09234  0.05%     -   60s
#      0     0 3996.02866    0   13 3994.00000 3996.02866  0.05%     -   70s
# H    0     0                    3995.0000000 3996.02866  0.03%     -   74s
#      0     0 3996.02823    0   11 3995.00000 3996.02823  0.03%     -   76s
#      0     0     cutoff    0      3995.00000 3995.00000  0.00%     -   78s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 2
#   MIR: 1
#
# Explored 1 nodes (925 simplex iterations) in 79.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3995 3994 3993
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.995000000000e+03, best bound 3.995000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x1.5x4

# %%
datafile="2x4000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x72e41f4d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 3997.0000000
# Presolve removed 12 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 4 columns
# Presolve time: 49.88s
# Presolved: 11988 rows, 7996 columns, 15995982 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   3.424713e+06   0.000000e+00     53s
#      552    3.9978452e+03   0.000000e+00   0.000000e+00     55s
#
# Root relaxation: cutoff, 552 iterations, 3.81 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3997.00000 3997.00000  0.00%     -   55s
#
# Explored 0 nodes (552 simplex iterations) in 55.49 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3997
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.997000000000e+03, best bound 3.997000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x1.5x5

# %%
datafile="2x4000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x8834c76d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 3994.0000000
# Presolve removed 12 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 12 rows and 4 columns
# Presolve time: 50.17s
# Presolved: 11988 rows, 7996 columns, 15995980 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   3.512468e+06   0.000000e+00     53s
#      727    3.9950848e+03   1.238689e+05   0.000000e+00     56s
#      763    3.9950848e+03   0.000000e+00   0.000000e+00     57s
#
# Root relaxation: objective 3.995085e+03, 763 iterations, 4.86 seconds
# Total elapsed time = 60.00s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3995.08476    0    7 3994.00000 3995.08476  0.03%     -   61s
#      0     0     cutoff    0      3994.00000 3994.00000  0.00%     -   71s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   StrongCG: 1
#   RLT: 2
#
# Explored 1 nodes (821 simplex iterations) in 71.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.994000000000e+03, best bound 3.994000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2x1

# %%
datafile="2x4000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x92fb8701
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3947.0000000
# Presolve removed 20 rows and 8 columns (presolve time = 7s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 20 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 20 rows and 8 columns
# Presolve time: 49.97s
# Presolved: 11980 rows, 7992 columns, 15979972 nonzeros
# Variable types: 0 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9960000e+03   5.432722e+06   0.000000e+00     53s
#      488    3.9960000e+03   3.711029e+05   0.000000e+00     56s
#      949    3.9572031e+03   0.000000e+00   0.000000e+00     56s
#
# Root relaxation: objective 3.957203e+03, 949 iterations, 4.69 seconds
# Total elapsed time = 62.17s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3957.20311    0   43 3947.00000 3957.20311  0.26%     -   65s
# H    0     0                    3955.0000000 3957.20311  0.06%     -   65s
#      0     0 3957.20311    0   47 3955.00000 3957.20311  0.06%     -  188s
# H    0     0                    3956.0000000 3957.20311  0.03%     -  193s
#      0     0 3957.00000    0   41 3956.00000 3957.00000  0.03%     -  195s
#      0     0 3957.00000    0   35 3956.00000 3957.00000  0.03%     -  198s
#      0     0 3957.00000    0   15 3956.00000 3957.00000  0.03%     -  215s
#      0     0 3957.00000    0   15 3956.00000 3957.00000  0.03%     -  220s
#      0     0 3957.00000    0   14 3956.00000 3957.00000  0.03%     -  230s
# H    0     0                    3957.0000000 3957.00000  0.00%     -  235s
#      0     0 3957.00000    0   14 3957.00000 3957.00000  0.00%     -  235s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   MIR: 3
#   RLT: 1
#
# Explored 1 nodes (1866 simplex iterations) in 236.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3957 3956 3955 3947
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.957000000000e+03, best bound 3.957000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2x2

# %%
datafile="2x4000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x4b7bdf93
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3986.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 28s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 10 rows and 4 columns
# Presolve time: 57.66s
# Presolved: 11990 rows, 7996 columns, 15995990 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   5.163479e+06   0.000000e+00     60s
#      805    3.9902499e+03   0.000000e+00   0.000000e+00     64s
#
# Root relaxation: objective 3.990250e+03, 805 iterations, 4.81 seconds
# Total elapsed time = 67.47s
# Total elapsed time = 70.65s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3990.24986    0   50 3986.00000 3990.24986  0.11%     -   71s
# H    0     0                    3988.0000000 3990.24986  0.06%     -   72s
#      0     0 3990.24986    0   54 3988.00000 3990.24986  0.06%     -  195s
# H    0     0                    3989.0000000 3990.24986  0.03%     -  198s
#      0     0 3990.08272    0   37 3989.00000 3990.08272  0.03%     -  204s
#      0     0 3990.07600    0   37 3989.00000 3990.07600  0.03%     -  208s
#      0     0 3990.07600    0   37 3989.00000 3990.07600  0.03%     -  211s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 7
#   MIR: 14
#   StrongCG: 3
#
# Explored 1 nodes (1144 simplex iterations) in 219.29 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3989 3988 3986
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.989000000000e+03, best bound 3.989000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2x3

# %%
datafile="2x4000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x67fba327
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3964.0000000
# Presolve removed 17 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 17 rows and 6 columns
# Presolve time: 49.88s
# Presolved: 11983 rows, 7994 columns, 15987978 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   5.224089e+06   0.000000e+00     53s
#      527    3.9970000e+03   2.318465e+05   0.000000e+00     56s
#      960    3.9702311e+03   0.000000e+00   0.000000e+00     57s
#
# Root relaxation: objective 3.970231e+03, 960 iterations, 5.27 seconds
# Total elapsed time = 60.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3970.23106    0   49 3964.00000 3970.23106  0.16%     -   63s
# H    0     0                    3968.0000000 3970.23106  0.06%     -   63s
# H    0     0                    3969.0000000 3970.23106  0.03%     -   64s
#      0     0 3970.23106    0   53 3969.00000 3970.23106  0.03%     -   75s
#      0     0 3970.22949    0   44 3969.00000 3970.22949  0.03%     -   82s
#      0     0 3970.22949    0   38 3969.00000 3970.22949  0.03%     -   86s
#      0     0 3970.22614    0   22 3969.00000 3970.22614  0.03%     -  100s
#      0     0 3970.22531    0   26 3969.00000 3970.22531  0.03%     -  106s
#      0     0 3970.22531    0   26 3969.00000 3970.22531  0.03%     -  108s
#      0     0 3970.22501    0   30 3969.00000 3970.22501  0.03%     -  119s
# H    0     0                    3970.0000000 3970.22501  0.01%     -  124s
#      0     0 3970.22501    0   30 3970.00000 3970.22501  0.01%     -  124s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#   GUB cover: 1
#
# Explored 1 nodes (1315 simplex iterations) in 125.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3970 3969 3968 3964
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.970000000000e+03, best bound 3.970000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2x4

# %%
datafile="2x4000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x1c35f573
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3968.0000000
# Presolve removed 15 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 28s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 6 columns
# Presolve time: 57.61s
# Presolved: 11979 rows, 7994 columns, 15987948 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   5.219114e+06   0.000000e+00     60s
#      831    3.9740868e+03   0.000000e+00   0.000000e+00     65s
#
# Root relaxation: objective 3.974087e+03, 831 iterations, 5.30 seconds
# Total elapsed time = 68.31s
# Total elapsed time = 70.81s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3974.08676    0   11 3968.00000 3974.08676  0.15%     -   74s
# H    0     0                    3972.0000000 3974.08676  0.05%     -   74s
# H    0     0                    3973.0000000 3974.08676  0.03%     -   74s
# H    0     0                    3974.0000000 3974.08676  0.00%     -   75s
#      0     0 3974.08676    0   11 3974.00000 3974.08676  0.00%     -   75s
#
# Explored 1 nodes (976 simplex iterations) in 75.71 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3974 3973 3972 3968
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.974000000000e+03, best bound 3.974000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2x5

# %%
datafile="2x4000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x338db35d
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3971.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 7s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 20s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 25s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 10 columns
# Presolve time: 49.88s
# Presolved: 11979 rows, 7990 columns, 15971974 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   5.259452e+06   0.000000e+00     53s
#      500    3.9950000e+03   2.779577e+05   0.000000e+00     56s
#      792    3.9739874e+03   0.000000e+00   0.000000e+00     56s
#
# Root relaxation: objective 3.973987e+03, 792 iterations, 4.80 seconds
# Total elapsed time = 60.96s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3973.98740    0   23 3971.00000 3973.98740  0.08%     -   63s
# H    0     0                    3973.0000000 3973.98740  0.02%     -   63s
#      0     0 3973.98740    0   23 3973.00000 3973.98740  0.02%     -   63s
#
# Explored 1 nodes (918 simplex iterations) in 64.10 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 3973 3971
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.973000000000e+03, best bound 3.973000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2.5x1

# %%
datafile="2x4000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xb5006bff
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3458.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 13 rows and 6 columns
# Presolve time: 49.83s
# Presolved: 11987 rows, 7994 columns, 15987992 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   6.206002e+06   0.000000e+00     53s
#      510    3.5767074e+03   2.782769e+05   0.000000e+00     55s
#     1135    3.5593596e+03   7.227101e+04   0.000000e+00     60s
#     1845    3.5553389e+03   0.000000e+00   0.000000e+00     64s
#
# Root relaxation: objective 3.555339e+03, 1845 iterations, 12.79 seconds
# Total elapsed time = 68.02s
# Total elapsed time = 70.56s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3555.33888    0   57 3458.00000 3555.33888  2.81%     -   74s
# H    0     0                    3552.0000000 3555.33888  0.09%     -   74s
# H    0     0                    3554.0000000 3555.33888  0.04%     -   75s
#      0     0 3555.33719    0   53 3554.00000 3555.33719  0.04%     -  189s
# H    0     0                    3555.0000000 3555.33719  0.01%     -  194s
#      0     0 3555.33719    0   53 3555.00000 3555.33719  0.01%     -  194s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 4
#
# Explored 1 nodes (2022 simplex iterations) in 194.67 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3555 3554 3552 3458
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.555000000000e+03, best bound 3.555000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2.5x2

# %%
datafile="2x4000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xfae2811e
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3470.0000000
# Presolve removed 5 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 15s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 28s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 30s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 50s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 55s) ...
# Presolve removed 7 rows and 2 columns
# Presolve time: 57.71s
# Presolved: 11993 rows, 7998 columns, 16003986 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   6.213520e+06   0.000000e+00     60s
#      996    3.5691836e+03   6.236752e+04   0.000000e+00     65s
#     2097    3.5597347e+03   0.000000e+00   0.000000e+00     70s
#
# Root relaxation: objective 3.559735e+03, 2097 iterations, 10.20 seconds
# Total elapsed time = 72.65s
# Total elapsed time = 75.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3559.73469    0   55 3470.00000 3559.73469  2.59%     -   76s
# H    0     0                    3557.0000000 3559.73469  0.08%     -   76s
# H    0     0                    3558.0000000 3559.73469  0.05%     -   77s
#      0     0 3559.73263    0   63 3558.00000 3559.73263  0.05%     -  191s
# H    0     0                    3559.0000000 3559.73263  0.02%     -  196s
#      0     0 3559.73263    0   63 3559.00000 3559.73263  0.02%     -  196s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 5
#
# Explored 1 nodes (2245 simplex iterations) in 196.64 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3559 3558 3557 3470
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.559000000000e+03, best bound 3.559000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2.5x3

# %%
datafile="2x4000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xb5123ae5
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3463.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 8 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 8 rows and 4 columns
# Presolve time: 49.90s
# Presolved: 11992 rows, 7996 columns, 15995994 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   6.265336e+06   0.000000e+00     53s
#      470    3.5785631e+03   3.939288e+05   0.000000e+00     55s
#      896    3.5640883e+03   4.552565e+05   0.000000e+00     60s
#     1599    3.5583955e+03   0.000000e+00   0.000000e+00     63s
#
# Root relaxation: objective 3.558396e+03, 1599 iterations, 11.76 seconds
# Total elapsed time = 67.17s
# Total elapsed time = 70.25s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3558.39553    0  144 3463.00000 3558.39553  2.75%     -   75s
# H    0     0                    3555.0000000 3558.39553  0.10%     -   75s
#      0     0 3558.38359    0  139 3555.00000 3558.38359  0.10%     -  193s
# H    0     0                    3556.0000000 3558.38359  0.07%     -  196s
# H    0     0                    3557.0000000 3558.38359  0.04%     -  202s
#      0     0 3558.37134    0  139 3557.00000 3558.37134  0.04%     -  204s
#      0     0 3558.36939    0  128 3557.00000 3558.36939  0.04%     -  207s
#      0     0 3558.35126    0  125 3557.00000 3558.35126  0.04%     -  210s
#      0     0 3558.33668    0  135 3557.00000 3558.33668  0.04%     -  223s
#      0     0 3558.30942    0  128 3557.00000 3558.30942  0.04%     -  229s
#      0     0 3558.30924    0  130 3557.00000 3558.30924  0.04%     -  231s
#      0     0 3558.30770    0  125 3557.00000 3558.30770  0.04%     -  245s
#      0     0 3558.28718    0  106 3557.00000 3558.28718  0.04%     -  256s
#      0     0 3558.28712    0  108 3557.00000 3558.28712  0.04%     -  259s
#      0     0 3558.27700    0  106 3557.00000 3558.27700  0.04%     -  273s
#      0     0 3558.27647    0  116 3557.00000 3558.27647  0.04%     -  279s
#      0     0 3558.27641    0  114 3557.00000 3558.27641  0.04%     -  281s
#      0     0 3558.21479    0  106 3557.00000 3558.21479  0.03%     -  296s
#      0     0 3558.19492    0  118 3557.00000 3558.19492  0.03%     -  309s
#      0     0 3558.19492    0  118 3557.00000 3558.19492  0.03%     -  311s
#      0     0 3558.19199    0  100 3557.00000 3558.19199  0.03%     -  325s
#      0     0 3558.15042    0   98 3557.00000 3558.15042  0.03%     -  332s
#      0     0 3558.15042    0  102 3557.00000 3558.15042  0.03%     -  335s
#      0     0 3558.15041    0   93 3557.00000 3558.15041  0.03%     -  349s
#      0     0 3558.15039    0   96 3557.00000 3558.15039  0.03%     -  353s
#      0     0 3558.15031    0   94 3557.00000 3558.15031  0.03%     -  366s
#      0     0 3558.15031    0   98 3557.00000 3558.15031  0.03%     -  372s
#      0     0 3558.15022    0   93 3557.00000 3558.15022  0.03%     -  385s
#      0     0 3558.15022    0   99 3557.00000 3558.15022  0.03%     -  390s
#      0     0 3558.14839    0   95 3557.00000 3558.14839  0.03%     -  403s
#      0     0 3558.14839    0   95 3557.00000 3558.14839  0.03%     -  412s
#      0     2 3558.14839    0   66 3557.00000 3558.14839  0.03%     -  439s
#      1     4 3558.14644    1   60 3557.00000 3558.14812  0.03%  49.0  441s
#      7    12 infeasible    3      3557.00000 3558.14812  0.03%  19.9  449s
#     13    18 3558.14297    4   83 3557.00000 3558.14682  0.03%  16.2  451s
#     19    24 3558.13283    5   83 3557.00000 3558.14495  0.03%  15.8  472s
#     31    36 3558.12778    7   81 3557.00000 3558.14495  0.03%  12.6  484s
#     37    44 3558.12570    8   76 3557.00000 3558.14495  0.03%  11.6  485s
#     75    97 3558.11531   14   77 3557.00000 3558.14495  0.03%   8.2  496s
#     98   157 3558.05499   18   74 3557.00000 3558.14495  0.03%   7.1  509s
#    161   333 3558.01636   32   61 3557.00000 3558.14495  0.03%   6.4  538s
#    401   591 3557.99690   57   69 3557.00000 3558.14478  0.03%   5.0  591s
#    777   784 3558.05783   16   74 3557.00000 3558.14386  0.03%   4.8  641s
#   1043  1049 3557.99906   46   63 3557.00000 3558.14386  0.03%   4.9  699s
#   1450  1050 3558.05622   25   95 3557.00000 3558.14386  0.03%   4.9  961s
#   1452  1051 3558.07510   10  108 3557.00000 3558.14386  0.03%   4.9 1126s
#   1453  1052 3557.99787   52   64 3557.00000 3558.14386  0.03%   4.9 1177s
#   1454  1053 3558.14132    5   73 3557.00000 3558.14386  0.03%   4.9 1182s
#   1455  1053 3558.03914   43   71 3557.00000 3558.14386  0.03%   4.9 1223s
#   1456  1054 3558.02443   14   50 3557.00000 3558.13720  0.03%   4.9 1291s
#   1457  1055 3558.02574   15   69 3557.00000 3558.11259  0.03%   4.9 1295s
#   1458  1055 3558.03850   16   69 3557.00000 3558.11227  0.03%   4.9 1322s
#   1459  1056 3558.01134   43   54 3557.00000 3558.10036  0.03%   4.9 1373s
#   1460  1057 3557.99906   47   67 3557.00000 3558.09600  0.03%   4.9 1379s
#   1461  1057 3557.99958   32   67 3557.00000 3558.09600  0.03%   4.9 1413s
#   1462  1058 3558.01409   20   60 3557.00000 3558.09312  0.03%   4.9 1467s
#   1463  1059 3558.00005   22   88 3557.00000 3558.08737  0.03%   4.9 1473s
#   1464  1059 3558.00647   23   83 3557.00000 3558.08672  0.03%   4.9 1477s
#   1465  1060 3558.00309   16   78 3557.00000 3558.07778  0.03%   4.9 1481s
#   1467  1061 3558.05792   20   78 3557.00000 3558.07525  0.03%   4.9 1516s
#   1468  1062 3558.04574   22   67 3557.00000 3558.07525  0.03%   4.9 1569s
#   1469  1063 3558.04587   12   73 3557.00000 3558.07525  0.03%   4.9 1605s
#   1470  1063 3558.00188   47   63 3557.00000 3558.07525  0.03%   4.9 1654s
#   1471  1064 3558.01271   17   70 3557.00000 3558.07525  0.03%   4.9 1682s
#   1472  1065 3558.01282   41   66 3557.00000 3558.07525  0.03%   4.9 1727s
#   1473  1065 3557.99784   43   66 3557.00000 3558.07525  0.03%   4.9 1760s
#   1474  1066 3558.06802    8   53 3557.00000 3558.07525  0.03%   4.9 1812s
#   1475  1067 3558.00067   47   65 3557.00000 3558.07525  0.03%   4.9 1848s
#   1476  1067 3557.99905   37   55 3557.00000 3558.07525  0.03%   4.9 1900s
#   1477  1068 3557.99811   37   60 3557.00000 3558.07525  0.03%   4.9 1929s
#   1478  1069 3558.00186   21   63 3557.00000 3558.07525  0.03%   4.9 1969s
#   1479  1069 3558.00570   17   71 3557.00000 3558.07525  0.03%   4.8 2008s
#   1480  1070 3557.99877   45   56 3557.00000 3558.07525  0.03%   4.8 2057s
#   1481  1071 3558.00312   15   56 3557.00000 3558.07525  0.03%   4.8 2073s
#   1483  1073 3558.07525    8   95 3557.00000 3558.07525  0.03%  10.2 2380s
#   1485  1074 3557.99685   65   72 3557.00000 3558.07525  0.03%  10.2 2529s
#   1486  1075 3558.02766   21   42 3557.00000 3558.07525  0.03%  10.2 2570s
#   1488  1076 3558.03555   41   46 3557.00000 3558.07525  0.03%  10.1 2575s
#   1491  1078 3558.03850   15   47 3557.00000 3558.07525  0.03%  10.1 2581s
#   1492  1079 3558.07410   12   49 3557.00000 3558.07524  0.03%  10.1 2603s
#   1493  1080 3558.07479   15   51 3557.00000 3558.07479  0.03%  10.1 2637s
#   1494  1080 3558.07410   12   50 3557.00000 3558.07479  0.03%  10.1 2669s
#   1495  1081 3557.99877   45   42 3557.00000 3558.07479  0.03%  10.1 2708s
#   1496  1082 3558.07318    8   57 3557.00000 3558.07318  0.03%  10.1 2711s
#   1497  1082 3558.00302   18   62 3557.00000 3558.07314  0.03%  10.1 2732s
#   1498  1083 3557.99823   51   45 3557.00000 3558.07138  0.03%  10.1 2757s
#   1499  1084 3558.00172   31   48 3557.00000 3558.04829  0.03%  10.1 2762s
#   1500  1084 3557.99685   74   44 3557.00000 3558.04705  0.03%  10.1 2765s
#   1501  1085 3557.99991   28   45 3557.00000 3558.04705  0.03%  10.1 2785s
#   1502  1086 3558.04597   17   52 3557.00000 3558.04597  0.03%  10.0 2821s
#   1503  1086 3558.01509   24   55 3557.00000 3558.04548  0.03%  10.0 2825s
#   1504  1087 3558.04547   17   59 3557.00000 3558.04547  0.03%  10.0 2849s
#   1505  1088 3558.00188   45   36 3557.00000 3558.04448  0.03%  10.0 2894s
#   1506  1088 3558.00164   43   31 3557.00000 3558.00278  0.03%  10.0 2897s
#   1507  1089 3557.99913   32   29 3557.00000 3558.00211  0.03%  10.0 2945s
#
# Cutting planes:
#   Gomory: 27
#   Cover: 1
#   MIR: 15
#   StrongCG: 1
#   Flow cover: 16
#   RLT: 1
#
# Explored 1507 nodes (22391 simplex iterations) in 2964.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3557 3556 3555 3463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.557000000000e+03, best bound 3.557000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2.5x4

# %%
datafile="2x4000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x0e74b946
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3461.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 13 rows and 6 columns
# Presolve time: 49.81s
# Presolved: 11987 rows, 7994 columns, 15987992 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   6.388630e+06   0.000000e+00     53s
#      604    3.5687812e+03   1.398388e+05   0.000000e+00     56s
#     1976    3.5539488e+03   0.000000e+00   0.000000e+00     59s
#
# Root relaxation: objective 3.553949e+03, 1976 iterations, 7.36 seconds
# Total elapsed time = 62.62s
# Total elapsed time = 65.59s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3553.94882    0  128 3461.00000 3553.94882  2.69%     -   70s
# H    0     0                    3552.0000000 3553.94882  0.05%     -   70s
# H    0     0                    3553.0000000 3553.94882  0.03%     -   72s
#      0     0 3553.94882    0  128 3553.00000 3553.94882  0.03%     -   72s
#
# Explored 1 nodes (2817 simplex iterations) in 72.85 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3553 3552 3461
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.553000000000e+03, best bound 3.553000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x2.5x5

# %%
datafile="2x4000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x09f87262
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3464.0000000
# Presolve removed 10 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 19s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 10 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 10 rows and 0 columns
# Presolve time: 49.06s
# Presolved: 11990 rows, 8000 columns, 16011970 nonzeros
# Variable types: 0 continuous, 8000 integer (8000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0000000e+03   6.173789e+06   0.000000e+00     52s
#      548    3.5719016e+03   1.579123e+05   0.000000e+00     55s
#     1592    3.5544790e+03   2.098391e+03   0.000000e+00     61s
#     2420    3.5510345e+03   0.000000e+00   0.000000e+00     65s
#
# Root relaxation: objective 3.551035e+03, 2420 iterations, 13.90 seconds
# Total elapsed time = 68.18s
# Total elapsed time = 70.87s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3551.03451    0   31 3464.00000 3551.03451  2.51%     -   75s
# H    0     0                    3549.0000000 3551.03451  0.06%     -   75s
# H    0     0                    3550.0000000 3551.03451  0.03%     -   76s
#      0     0     cutoff    0      3550.00000 3550.00000  0.00%     -   86s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 2
#   MIR: 4
#   StrongCG: 2
#
# Explored 1 nodes (2929 simplex iterations) in 86.56 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3550 3549 3464
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.550000000000e+03, best bound 3.550000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3x1

# %%
datafile="2x4000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xcd189605
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3102.0000000
# Presolve removed 25 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 20s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 25 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 25 rows and 6 columns
# Presolve time: 49.80s
# Presolved: 11975 rows, 7994 columns, 15987928 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   6.964185e+06   0.000000e+00     53s
#      593    3.2892673e+03   4.965099e+05   0.000000e+00     56s
#     1611    3.2434827e+03   1.224768e+05   0.000000e+00     60s
#     2475    3.2316361e+03   0.000000e+00   0.000000e+00     63s
#
# Root relaxation: objective 3.231636e+03, 2475 iterations, 11.31 seconds
# Total elapsed time = 66.33s
# Total elapsed time = 72.19s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3231.63605    0   77 3102.00000 3231.63605  4.18%     -   74s
# H    0     0                    3226.0000000 3231.63605  0.17%     -   74s
# H    0     0                    3229.0000000 3231.63605  0.08%     -   74s
# H    0     0                    3231.0000000 3231.63605  0.02%     -   75s
#      0     0 3231.63605    0   77 3231.00000 3231.63605  0.02%     -   75s
#
# Explored 1 nodes (2679 simplex iterations) in 76.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3231 3229 3226 3102
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.231000000000e+03, best bound 3.231000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3x2

# %%
datafile="2x4000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xab3e4724
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3097.0000000
# Presolve removed 5 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 25s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 30s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 5 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 5 rows and 2 columns
# Presolve time: 49.92s
# Presolved: 11995 rows, 7998 columns, 16003994 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   6.900091e+06   0.000000e+00     53s
#      430    3.2988486e+03   2.394040e+05   0.000000e+00     55s
#     1285    3.2389700e+03   5.548775e+04   0.000000e+00     62s
#     1733    3.2362830e+03   0.000000e+00   0.000000e+00     65s
#
# Root relaxation: objective 3.236283e+03, 1733 iterations, 13.10 seconds
# Total elapsed time = 68.28s
# Total elapsed time = 70.48s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3236.28302    0   25 3097.00000 3236.28302  4.50%     -   72s
# H    0     0                    3233.0000000 3236.28302  0.10%     -   73s
# H    0     0                    3235.0000000 3236.28302  0.04%     -   74s
# H    0     0                    3236.0000000 3236.28302  0.01%     -   75s
#      0     0 3236.28302    0   25 3236.00000 3236.28302  0.01%     -   75s
#
# Explored 1 nodes (1861 simplex iterations) in 75.62 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3236 3235 3233 3097
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.236000000000e+03, best bound 3.236000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3x3

# %%
datafile="2x4000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x63c8ee30
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3089.0000000
# Presolve removed 8 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 23s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 36s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 60s) ...
# Presolve removed 12 rows and 4 columns (presolve time = 65s) ...
# Presolve removed 12 rows and 4 columns
# Presolve time: 65.35s
# Presolved: 11988 rows, 7996 columns, 15995976 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   7.006831e+06   0.000000e+00     68s
#      308    3.2994686e+03   2.172217e+05   0.000000e+00     70s
#     1583    3.2425991e+03   3.165779e+05   0.000000e+00     75s
#     2535    3.2286087e+03   0.000000e+00   0.000000e+00     78s
#
# Root relaxation: objective 3.228609e+03, 2535 iterations, 11.20 seconds
# Total elapsed time = 80.94s
# Total elapsed time = 85.84s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3228.60866    0   59 3089.00000 3228.60866  4.52%     -   87s
# H    0     0                    3224.0000000 3228.60866  0.14%     -   88s
# H    0     0                    3226.0000000 3228.60866  0.08%     -   88s
# H    0     0                    3228.0000000 3228.60866  0.02%     -   89s
#      0     0 3228.60866    0   59 3228.00000 3228.60866  0.02%     -   89s
#
# Explored 1 nodes (2596 simplex iterations) in 89.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3228 3226 3224 3089
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.228000000000e+03, best bound 3.228000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3x4

# %%
datafile="2x4000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xf0a6b378
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3098.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 25s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 30s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 7 rows and 2 columns
# Presolve time: 49.94s
# Presolved: 11993 rows, 7998 columns, 16003990 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   6.885416e+06   0.000000e+00     53s
#      386    3.3012369e+03   1.486186e+06   0.000000e+00     55s
#     1801    3.2329228e+03   9.460049e+04   0.000000e+00     61s
#     2137    3.2317676e+03   0.000000e+00   0.000000e+00     62s
#
# Root relaxation: objective 3.231768e+03, 2137 iterations, 10.01 seconds
# Total elapsed time = 65.02s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3231.76759    0   50 3098.00000 3231.76759  4.32%     -   70s
# H    0     0                    3227.0000000 3231.76759  0.15%     -   71s
# H    0     0                    3231.0000000 3231.76759  0.02%     -   71s
#      0     0 3231.76759    0   50 3231.00000 3231.76759  0.02%     -   71s
#
# Explored 1 nodes (3081 simplex iterations) in 71.33 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3231 3227 3098
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.231000000000e+03, best bound 3.231000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3x5

# %%
datafile="2x4000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x0a9c941e
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3084.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 7s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 20s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 25s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 10 columns
# Presolve time: 49.84s
# Presolved: 11979 rows, 7990 columns, 15971992 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   6.884742e+06   0.000000e+00     53s
#      612    3.2839392e+03   1.640247e+06   0.000000e+00     56s
#     1500    3.2428585e+03   1.583507e+05   0.000000e+00     60s
#     2401    3.2306391e+03   4.260663e+04   0.000000e+00     66s
#     3015    3.2292476e+03   0.000000e+00   0.000000e+00     69s
#
# Root relaxation: objective 3.229248e+03, 3015 iterations, 17.31 seconds
# Total elapsed time = 71.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3229.24760    0   38 3084.00000 3229.24760  4.71%     -   74s
# H    0     0                    3226.0000000 3229.24760  0.10%     -   75s
# H    0     0                    3228.0000000 3229.24760  0.04%     -   76s
#      0     0 3229.24753    0   38 3228.00000 3229.24753  0.04%     -  182s
# H    0     0                    3229.0000000 3229.24753  0.01%     -  188s
#      0     0 3229.24753    0   38 3229.00000 3229.24753  0.01%     -  188s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 3
#
# Explored 1 nodes (3246 simplex iterations) in 188.97 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3229 3228 3226 3084
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.229000000000e+03, best bound 3.229000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3.5x1

# %%
datafile="2x4000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x960f8a35
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2803.0000000
# Presolve removed 9 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 25s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 30s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 9 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 9 rows and 2 columns
# Presolve time: 49.88s
# Presolved: 11991 rows, 7998 columns, 16003984 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   7.501798e+06   0.000000e+00     53s
#      498    3.0774300e+03   4.001037e+05   0.000000e+00     56s
#     1374    3.0089574e+03   7.270178e+05   0.000000e+00     60s
#     1934    2.9768434e+03   8.269172e+05   0.000000e+00     65s
#     2782    2.9702174e+03   1.163285e+05   0.000000e+00     70s
#     3119    2.9692425e+03   0.000000e+00   0.000000e+00     72s
#
# Root relaxation: objective 2.969242e+03, 3119 iterations, 20.29 seconds
# Total elapsed time = 76.18s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2969.24246    0   37 2803.00000 2969.24246  5.93%     -   78s
# H    0     0                    2966.0000000 2969.24246  0.11%     -   78s
# H    0     0                    2968.0000000 2969.24246  0.04%     -   78s
#      0     0 2969.23937    0   39 2968.00000 2969.23937  0.04%     -   91s
# H    0     0                    2969.0000000 2969.23937  0.01%     -   95s
#      0     0 2969.23937    0   39 2969.00000 2969.23937  0.01%     -   95s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 7
#
# Explored 1 nodes (3325 simplex iterations) in 95.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2969 2968 2966 2803
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.969000000000e+03, best bound 2.969000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3.5x2

# %%
datafile="2x4000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x27c1a734
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2815.0000000
# Presolve removed 17 rows and 10 columns (presolve time = 7s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 10s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 17s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 28s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 50s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 55s) ...
# Presolve removed 17 rows and 10 columns
# Presolve time: 57.43s
# Presolved: 11983 rows, 7990 columns, 15972006 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   7.467330e+06   0.000000e+00     60s
#      708    3.0454818e+03   1.501428e+06   0.000000e+00     66s
#     1198    2.9932233e+03   4.194331e+05   0.000000e+00     72s
#     1588    2.9799162e+03   2.045158e+04   0.000000e+00     76s
#     2006    2.9774285e+03   0.000000e+00   0.000000e+00     77s
#
# Root relaxation: objective 2.977429e+03, 2006 iterations, 17.93 seconds
# Total elapsed time = 80.41s
# Total elapsed time = 85.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2977.42851    0   73 2815.00000 2977.42851  5.77%     -   87s
# H    0     0                    2972.0000000 2977.42851  0.18%     -   87s
# H    0     0                    2975.0000000 2977.42851  0.08%     -   87s
# H    0     0                    2976.0000000 2977.42851  0.05%     -   90s
#      0     0 2977.40939    0   57 2976.00000 2977.40939  0.05%     -  188s
# H    0     0                    2977.0000010 2977.40939  0.01%     -  195s
#      0     0 2977.40939    0   57 2977.00000 2977.40939  0.01%     -  195s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 4
#   MIR: 10
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (2198 simplex iterations) in 195.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2977 2976 2975 ... 2815
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.977000000776e+03, best bound 2.977000000776e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3.5x3

# %%
datafile="2x4000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x46e1b99a
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2795.0000000
# Presolve removed 2 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 19s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 2 rows and 0 columns
# Presolve time: 49.53s
# Presolved: 11998 rows, 8000 columns, 16011996 nonzeros
# Variable types: 0 continuous, 8000 integer (8000 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0000000e+03   7.601869e+06   0.000000e+00     52s
#      503    3.0743862e+03   8.400109e+05   0.000000e+00     55s
#     1253    3.0067440e+03   1.071699e+06   0.000000e+00     61s
#     1873    2.9832104e+03   3.654790e+05   0.000000e+00     66s
#     2742    2.9728064e+03   1.845974e+05   0.000000e+00     72s
#     3232    2.9673652e+03   0.000000e+00   0.000000e+00     74s
#
# Root relaxation: objective 2.967365e+03, 3232 iterations, 22.85 seconds
# Total elapsed time = 77.37s
# Total elapsed time = 82.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2967.36517    0   75 2795.00000 2967.36517  6.17%     -   85s
# H    0     0                    2961.0000000 2967.36517  0.21%     -   86s
# H    0     0                    2965.0000000 2967.36517  0.08%     -   87s
# H    0     0                    2966.0000000 2967.36517  0.05%     -   87s
#      0     0     cutoff    0      2966.00000 2966.00000  0.00%     -  189s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 31
#   MIR: 78
#   StrongCG: 28
#   GUB cover: 19
#   RLT: 1
#
# Explored 1 nodes (3456 simplex iterations) in 189.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2966 2965 2961 2795
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.966000000000e+03, best bound 2.966000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3.5x4

# %%
datafile="2x4000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x0c9e63ce
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2793.0000000
# Presolve removed 7 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 21s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 25s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 30s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 51s) ...
# Presolve removed 7 rows and 2 columns
# Presolve time: 51.04s
# Presolved: 11993 rows, 7998 columns, 16003980 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   7.620124e+06   0.000000e+00     54s
#      374    3.0852951e+03   8.346892e+04   0.000000e+00     56s
#     1074    3.0366642e+03   9.048618e+05   0.000000e+00     61s
#     1828    2.9787191e+03   1.090488e+05   0.000000e+00     65s
#     2468    2.9618740e+03   4.007529e+05   0.000000e+00     71s
#     3366    2.9607018e+03   6.109980e+03   0.000000e+00     76s
#     3586    2.9603763e+03   0.000000e+00   0.000000e+00     77s
#
# Root relaxation: objective 2.960376e+03, 3586 iterations, 24.45 seconds
# Total elapsed time = 80.58s
# Total elapsed time = 86.51s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2960.37632    0   75 2793.00000 2960.37632  5.99%     -   91s
# H    0     0                    2956.0000000 2960.37632  0.15%     -   92s
# H    0     0                    2959.0000000 2960.37632  0.05%     -   93s
#      0     0 2960.15179    0   55 2959.00000 2960.15179  0.04%     -  199s
# H    0     0                    2960.0000000 2960.15179  0.01%     -  203s
#      0     0 2960.15179    0   55 2960.00000 2960.15179  0.01%     -  203s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 53
#   RLT: 1
#
# Explored 1 nodes (3889 simplex iterations) in 203.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2960 2959 2956 2793
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.960000000000e+03, best bound 2.960000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x3.5x5

# %%
datafile="2x4000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xc822cef4
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2825.0000000
# Presolve removed 16 rows and 8 columns (presolve time = 8s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 16 rows and 8 columns (presolve time = 55s) ...
# Presolve removed 16 rows and 8 columns
# Presolve time: 58.29s
# Presolved: 11984 rows, 7992 columns, 15979988 nonzeros
# Variable types: 0 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9960000e+03   7.233058e+06   0.000000e+00     61s
#      574    3.0948508e+03   6.339658e+05   0.000000e+00     65s
#     1414    3.0182810e+03   5.237760e+04   0.000000e+00     72s
#     1854    3.0086584e+03   2.202120e+05   0.000000e+00     75s
#     2995    2.9880463e+03   0.000000e+00   0.000000e+00     80s
#
# Root relaxation: objective 2.988046e+03, 2995 iterations, 19.98 seconds
# Total elapsed time = 85.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2988.04625    0   73 2825.00000 2988.04625  5.77%     -   89s
# H    0     0                    2984.0000000 2988.04625  0.14%     -   89s
# H    0     0                    2986.0000000 2988.04625  0.07%     -   90s
# H    0     0                    2987.0000000 2988.04625  0.04%     -   91s
#      0     0 2988.01055    0   68 2987.00000 2988.01055  0.03%     -  179s
#      0     0 2988.01055    0   32 2987.00000 2988.01055  0.03%     -  240s
#      0     0     cutoff    0      2987.00000 2987.00000  0.00%     -  245s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 2
#   MIR: 25
#   StrongCG: 23
#
# Explored 1 nodes (4501 simplex iterations) in 246.14 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2987 2986 2984 ... 2825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.987000000000e+03, best bound 2.987000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4x1

# %%
datafile="2x4000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x0d0f348c
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2601.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 7s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 22s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 14 rows and 8 columns
# Presolve time: 54.58s
# Presolved: 11986 rows, 7992 columns, 15980000 nonzeros
# Variable types: 0 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9960000e+03   7.890668e+06   0.000000e+00     58s
#      332    2.9359994e+03   2.363234e+05   0.000000e+00     60s
#     1201    2.8485981e+03   6.700564e+05   0.000000e+00     66s
#     2188    2.7898580e+03   3.373388e+05   0.000000e+00     70s
#     3645    2.7712642e+03   0.000000e+00   0.000000e+00     75s
#
# Root relaxation: objective 2.771264e+03, 3645 iterations, 18.98 seconds
# Total elapsed time = 80.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2771.26423    0   46 2601.00000 2771.26423  6.55%     -   81s
# H    0     0                    2765.0000000 2771.26423  0.23%     -   81s
# H    0     0                    2768.0000000 2771.26423  0.12%     -   82s
# H    0     0                    2770.0000000 2771.26423  0.05%     -   83s
#      0     0 2771.01380    0   40 2770.00000 2771.01380  0.04%     -  170s
#      0     0 2771.01380    0   36 2770.00000 2771.01380  0.04%     -  176s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 6
#   MIR: 15
#   RLT: 1
#
# Explored 1 nodes (3751 simplex iterations) in 182.94 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2770 2768 2765 2601
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.770000000000e+03, best bound 2.770000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4x2

# %%
datafile="2x4000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x2a419019
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2600.0000000
# Presolve removed 25 rows and 14 columns (presolve time = 8s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 12s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 25s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 25s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 30s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 35s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 40s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 45s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 50s) ...
# Presolve removed 25 rows and 14 columns (presolve time = 55s) ...
# Presolve removed 25 rows and 14 columns
# Presolve time: 57.46s
# Presolved: 11975 rows, 7986 columns, 15956020 nonzeros
# Variable types: 0 continuous, 7986 integer (7986 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9930000e+03   7.880557e+06   0.000000e+00     60s
#      758    2.8976371e+03   1.587044e+06   0.000000e+00     65s
#     1659    2.8079442e+03   2.759911e+05   0.000000e+00     72s
#     2497    2.7746294e+03   6.657712e+04   0.000000e+00     76s
#     3067    2.7696637e+03   0.000000e+00   0.000000e+00     78s
#
# Root relaxation: objective 2.769664e+03, 3067 iterations, 18.85 seconds
# Total elapsed time = 81.48s
# Total elapsed time = 86.07s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2769.66374    0   85 2600.00000 2769.66374  6.53%     -   88s
# H    0     0                    2761.0000000 2769.66374  0.31%     -   89s
# H    0     0                    2768.0000000 2769.66374  0.06%     -   89s
# H    0     0                    2769.0000000 2769.66374  0.02%     -   91s
#      0     0 2769.66374    0   85 2769.00000 2769.66374  0.02%     -   91s
#
# Explored 1 nodes (3231 simplex iterations) in 91.35 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2769 2768 2761 2600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.769000000000e+03, best bound 2.769000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4x3

# %%
datafile="2x4000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x92ff5564
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2605.0000000
# Presolve removed 13 rows and 6 columns (presolve time = 8s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 11s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 23s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 25s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 30s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 62s) ...
# Presolve removed 13 rows and 6 columns
# Presolve time: 62.00s
# Presolved: 11987 rows, 7994 columns, 15987994 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   7.939146e+06   0.000000e+00     65s
#      950    2.8638705e+03   2.759882e+05   0.000000e+00     71s
#     2322    2.7891351e+03   9.559622e+04   0.000000e+00     75s
#     3315    2.7759534e+03   0.000000e+00   0.000000e+00     78s
#
# Root relaxation: objective 2.775953e+03, 3315 iterations, 14.20 seconds
# Total elapsed time = 80.51s
# Total elapsed time = 85.28s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2775.95338    0   41 2605.00000 2775.95338  6.56%     -   87s
# H    0     0                    2770.0000000 2775.95338  0.21%     -   87s
# H    0     0                    2773.0000000 2775.95338  0.11%     -   87s
# H    0     0                    2774.0000000 2775.95338  0.07%     -   89s
# H    0     0                    2775.0000000 2775.95338  0.03%     -   90s
#      0     0 2775.95338    0   41 2775.00000 2775.95338  0.03%     -   90s
#
# Explored 1 nodes (3802 simplex iterations) in 90.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2775 2774 2773 ... 2605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.775000000000e+03, best bound 2.775000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4x4

# %%
datafile="2x4000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x460468ed
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2586.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 11s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 23s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 10 rows and 4 columns
# Presolve time: 57.50s
# Presolved: 11990 rows, 7996 columns, 15995984 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   7.926518e+06   0.000000e+00     60s
#      780    2.8844725e+03   2.447637e+06   0.000000e+00     65s
#     1998    2.7827871e+03   3.568502e+04   0.000000e+00     70s
#     3351    2.7597200e+03   0.000000e+00   0.000000e+00     73s
#
# Root relaxation: objective 2.759720e+03, 3351 iterations, 14.05 seconds
# Total elapsed time = 77.15s
# Total elapsed time = 81.65s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2759.72000    0  147 2586.00000 2759.72000  6.72%     -   84s
# H    0     0                    2745.0000000 2759.72000  0.54%     -   84s
# H    0     0                    2755.0000000 2759.72000  0.17%     -   85s
# H    0     0                    2758.0000000 2759.72000  0.06%     -   86s
#      0     0 2759.68536    0  133 2758.00000 2759.68536  0.06%     -  189s
# H    0     0                    2759.0000000 2759.68536  0.02%     -  198s
#      0     0 2759.68536    0  133 2759.00000 2759.68536  0.02%     -  198s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 3
#   MIR: 30
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (4189 simplex iterations) in 199.01 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2759 2758 2755 ... 2586
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.759000000000e+03, best bound 2.759000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4x5

# %%
datafile="2x4000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x9a1f4c9c
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 2588.0000000
# Presolve removed 3 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 3 rows and 2 columns (presolve time = 10s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 16s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 20s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 32s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 35s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 40s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 45s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 50s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 55s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 60s) ...
# Presolve removed 7 rows and 2 columns (presolve time = 65s) ...
# Presolve removed 7 rows and 2 columns
# Presolve time: 65.22s
# Presolved: 11993 rows, 7998 columns, 16003986 nonzeros
# Variable types: 0 continuous, 7998 integer (7998 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   7.914640e+06   0.000000e+00     68s
#      373    2.9290492e+03   1.442015e+06   0.000000e+00     71s
#      946    2.8504686e+03   4.449261e+05   0.000000e+00     76s
#     1706    2.7814439e+03   4.876647e+05   0.000000e+00     82s
#     2585    2.7671706e+03   1.733153e+05   0.000000e+00     87s
#     3117    2.7643363e+03   0.000000e+00   0.000000e+00     90s
#
# Root relaxation: objective 2.764336e+03, 3117 iterations, 22.85 seconds
# Total elapsed time = 93.39s
# Total elapsed time = 95.61s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2764.33626    0   85 2588.00000 2764.33626  6.81%     -   99s
# H    0     0                    2757.0000000 2764.33626  0.27%     -  100s
# H    0     0                    2761.0000000 2764.33626  0.12%     -  100s
# H    0     0                    2763.0000000 2764.33626  0.05%     -  101s
#      0     0 2764.13971    0   72 2763.00000 2764.13971  0.04%     -  198s
#      0     0 2764.10004    0   59 2763.00000 2764.10004  0.04%     -  206s
#      0     0 2764.09882    0   62 2763.00000 2764.09882  0.04%     -  210s
#      0     0 2764.09882    0   64 2763.00000 2764.09882  0.04%     -  212s
#      0     0 2764.02646    0   49 2763.00000 2764.02646  0.04%     -  230s
#      0     0 2764.02646    0   48 2763.00000 2764.02646  0.04%     -  284s
#      0     0 2764.02113    0   28 2763.00000 2764.02113  0.04%     -  290s
#      0     0 2764.02113    0   26 2763.00000 2764.02113  0.04%     -  293s
#      0     0 2764.01016    0   30 2763.00000 2764.01016  0.04%     -  298s
#      0     0 2764.01016    0   28 2763.00000 2764.01016  0.04%     -  300s
#      0     0 2764.01016    0   21 2763.00000 2764.01016  0.04%     -  306s
#      0     0 2764.01013    0   23 2763.00000 2764.01013  0.04%     -  307s
#      0     0 2764.01013    0   19 2763.00000 2764.01013  0.04%     -  314s
#      0     0     cutoff    0      2763.00000 2763.00000  0.00%     -  317s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 4
#   MIR: 10
#   GUB cover: 5
#
# Explored 1 nodes (5223 simplex iterations) in 317.28 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2763 2761 2757 ... 2588
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.763000000000e+03, best bound 2.763000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4.5x1

# %%
datafile="2x4000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xd3b1681c
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2426.0000000
# Presolve removed 17 rows and 10 columns (presolve time = 8s) ...
# Presolve removed 17 rows and 10 columns (presolve time = 11s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 17s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 20s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 32s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 50s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 55s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 60s) ...
# Presolve removed 19 rows and 10 columns
# Presolve time: 64.35s
# Presolved: 11981 rows, 7990 columns, 15971990 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   8.104224e+06   0.000000e+00     67s
#      331    2.8014999e+03   1.827460e+06   0.000000e+00     70s
#     1608    2.6535532e+03   1.219762e+05   0.000000e+00     75s
#     3440    2.6062460e+03   1.143093e+03   0.000000e+00     80s
#     3508    2.6061918e+03   0.000000e+00   0.000000e+00     81s
#
# Root relaxation: objective 2.606192e+03, 3508 iterations, 14.61 seconds
# Total elapsed time = 85.76s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2606.19179    0   99 2426.00000 2606.19179  7.43%     -   88s
# H    0     0                    2596.0000000 2606.19179  0.39%     -   88s
# H    0     0                    2605.0000000 2606.19179  0.05%     -   89s
#      0     0     cutoff    0      2605.00000 2605.00000  0.00%     -  162s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 2
#   MIR: 147
#   StrongCG: 2
#   GUB cover: 2
#
# Explored 1 nodes (3814 simplex iterations) in 162.21 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2605 2596 2426
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.605000000000e+03, best bound 2.605000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4.5x2

# %%
datafile="2x4000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x522ebecd
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2393.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 8s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 12s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 27s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 30s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 62s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 62.48s
# Presolved: 11978 rows, 7988 columns, 15964010 nonzeros
# Variable types: 0 continuous, 7988 integer (7988 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9940000e+03   8.094949e+06   0.000000e+00     66s
#      841    2.7883187e+03   2.164805e+06   0.000000e+00     74s
#     1081    2.7412416e+03   3.137344e+06   0.000000e+00     77s
#     1331    2.7028153e+03   2.194820e+06   0.000000e+00     81s
#     1821    2.6297421e+03   1.480901e+06   0.000000e+00     86s
#     2591    2.5961956e+03   8.991545e+05   0.000000e+00     93s
#     3039    2.5939594e+03   4.282326e+05   0.000000e+00     95s
#     4124    2.5864840e+03   0.000000e+00   0.000000e+00    100s
#
# Root relaxation: objective 2.586484e+03, 4124 iterations, 35.74 seconds
# Total elapsed time = 105.44s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2586.48398    0   84 2393.00000 2586.48398  8.09%     -  106s
# H    0     0                    2578.0000000 2586.48398  0.33%     -  106s
# H    0     0                    2585.0000000 2586.48398  0.06%     -  107s
#      0     0 2586.40634    0   83 2585.00000 2586.40634  0.05%     -  122s
# H    0     0                    2586.0000000 2586.40634  0.02%     -  129s
#      0     0 2586.40634    0   83 2586.00000 2586.40634  0.02%     -  129s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 2
#   MIR: 13
#   StrongCG: 4
#   RLT: 1
#
# Explored 1 nodes (4271 simplex iterations) in 129.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2586 2585 2578 2393
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.586000000000e+03, best bound 2.586000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4.5x3

# %%
datafile="2x4000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x569997db
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2401.0000000
# Presolve removed 19 rows and 14 columns (presolve time = 9s) ...
# Presolve removed 19 rows and 14 columns (presolve time = 13s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 19s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 21s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 14 columns (presolve time = 72s) ...
# Presolve removed 21 rows and 14 columns
# Presolve time: 71.95s
# Presolved: 11979 rows, 7986 columns, 15956028 nonzeros
# Variable types: 0 continuous, 7986 integer (7986 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9930000e+03   8.159130e+06   0.000000e+00     75s
#      734    2.7613614e+03   6.220785e+05   0.000000e+00     80s
#     1621    2.6542785e+03   1.645014e+05   0.000000e+00     85s
#     2991    2.5917907e+03   1.135664e+05   0.000000e+00     90s
#     3611    2.5874882e+03   0.000000e+00   0.000000e+00     92s
#
# Root relaxation: objective 2.587488e+03, 3611 iterations, 18.25 seconds
# Total elapsed time = 95.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2587.48818    0   92 2401.00000 2587.48818  7.77%     -  100s
# H    0     0                    2576.0000000 2587.48818  0.45%     -  101s
# H    0     0                    2585.0000000 2587.48818  0.10%     -  101s
# H    0     0                    2587.0000000 2587.48818  0.02%     -  103s
#      0     0 2587.48818    0   92 2587.00000 2587.48818  0.02%     -  103s
#
# Explored 1 nodes (3779 simplex iterations) in 103.26 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2587 2585 2576 2401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.587000000000e+03, best bound 2.587000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4.5x4

# %%
datafile="2x4000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xf816040c
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2432.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 9s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 13s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 27s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 10 columns
# Presolve time: 62.96s
# Presolved: 11979 rows, 7990 columns, 15971996 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   8.156097e+06   0.000000e+00     66s
#      650    2.7413482e+03   1.440373e+06   0.000000e+00     72s
#     1000    2.7261341e+03   3.717190e+06   0.000000e+00     76s
#     1560    2.6734325e+03   1.938243e+06   0.000000e+00     82s
#     1880    2.6542289e+03   7.962025e+05   0.000000e+00     85s
#     2680    2.6154968e+03   4.921221e+05   0.000000e+00     91s
#     3557    2.6048734e+03   0.000000e+00   0.000000e+00     95s
#
# Root relaxation: objective 2.604873e+03, 3557 iterations, 30.15 seconds
# Total elapsed time = 100.34s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2604.87343    0   52 2432.00000 2604.87343  7.11%     -  101s
# H    0     0                    2599.0000000 2604.87343  0.23%     -  101s
# H    0     0                    2604.0000000 2604.87343  0.03%     -  101s
#      0     0 2604.87343    0   52 2604.00000 2604.87343  0.03%     -  101s
#
# Explored 1 nodes (3595 simplex iterations) in 102.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2604 2599 2432
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.604000000000e+03, best bound 2.604000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x4.5x5

# %%
datafile="2x4000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x0be741ca
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 2404.0000000
# Presolve removed 21 rows and 10 columns (presolve time = 8s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 11s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 23s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 25s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 10 columns (presolve time = 57s) ...
# Presolve removed 21 rows and 10 columns
# Presolve time: 56.80s
# Presolved: 11979 rows, 7990 columns, 15971992 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   8.199476e+06   0.000000e+00     60s
#      315    2.8016630e+03   2.367120e+05   0.000000e+00     62s
#      844    2.7436408e+03   2.571817e+06   0.000000e+00     65s
#     1692    2.6499134e+03   2.433650e+05   0.000000e+00     71s
#     2588    2.5872459e+03   3.627322e+05   0.000000e+00     75s
#     3753    2.5669564e+03   0.000000e+00   0.000000e+00     79s
#
# Root relaxation: objective 2.566956e+03, 3753 iterations, 20.02 seconds
# Total elapsed time = 82.35s
# Total elapsed time = 86.56s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2566.95639    0   86 2404.00000 2566.95639  6.78%     -   88s
# H    0     0                    2559.0000000 2566.95639  0.31%     -   89s
# H    0     0                    2565.0000000 2566.95639  0.08%     -   89s
# H    0     0                    2566.0000000 2566.95639  0.04%     -   92s
#      0     0 2566.95639    0   86 2566.00000 2566.95639  0.04%     -   92s
#
# Explored 1 nodes (4137 simplex iterations) in 93.16 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2566 2565 2559 2404
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.566000000000e+03, best bound 2.566000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x5x1

# %%
datafile="2x4000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xaa3c994a
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2281.0000000
# Presolve removed 14 rows and 8 columns (presolve time = 8s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 11s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 55s) ...
# Presolve removed 14 rows and 8 columns (presolve time = 60s) ...
# Presolve removed 14 rows and 8 columns
# Presolve time: 60.38s
# Presolved: 11986 rows, 7992 columns, 15979998 nonzeros
# Variable types: 0 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9960000e+03   8.336457e+06   0.000000e+00     64s
#      259    2.7108866e+03   2.144635e+05   0.000000e+00     67s
#     1001    2.5915525e+03   4.749035e+05   0.000000e+00     70s
#     2030    2.4877352e+03   1.088953e+05   0.000000e+00     75s
#     3614    2.4475671e+03   0.000000e+00   0.000000e+00     80s
#
# Root relaxation: objective 2.447567e+03, 3614 iterations, 17.18 seconds
# Total elapsed time = 81.77s
# Total elapsed time = 85.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2447.56705    0   60 2281.00000 2447.56705  7.30%     -   86s
# H    0     0                    2440.0000000 2447.56705  0.31%     -   86s
# H    0     0                    2446.0000000 2447.56705  0.06%     -   86s
#      0     0 2447.56375    0   65 2446.00000 2447.56375  0.06%     -  181s
# H    0     0                    2447.0000000 2447.56375  0.02%     -  186s
#      0     0 2447.56375    0   65 2447.00000 2447.56375  0.02%     -  186s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 11
#
# Explored 1 nodes (3723 simplex iterations) in 186.28 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2447 2446 2440 2281
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.447000000000e+03, best bound 2.447000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x5x2

# %%
datafile="2x4000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xe52ebe90
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2289.0000000
# Presolve removed 17 rows and 10 columns (presolve time = 7s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 15s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 28s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 30s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 35s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 40s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 45s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 50s) ...
# Presolve removed 19 rows and 10 columns (presolve time = 55s) ...
# Presolve removed 19 rows and 10 columns
# Presolve time: 58.59s
# Presolved: 11981 rows, 7990 columns, 15972000 nonzeros
# Variable types: 0 continuous, 7990 integer (7990 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   8.363297e+06   0.000000e+00     61s
#      570    2.6930106e+03   3.171059e+05   0.000000e+00     65s
#     1070    2.5739717e+03   2.771556e+06   0.000000e+00     70s
#     1970    2.4990805e+03   3.817058e+05   0.000000e+00     77s
#     2340    2.4820678e+03   1.665724e+05   0.000000e+00     80s
#     3422    2.4603640e+03   0.000000e+00   0.000000e+00     85s
#
# Root relaxation: objective 2.460364e+03, 3422 iterations, 25.01 seconds
# Total elapsed time = 91.97s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2460.36417    0   75 2289.00000 2460.36417  7.49%     -   95s
# H    0     0                    2448.0000000 2460.36417  0.51%     -   96s
# H    0     0                    2458.0000000 2460.36417  0.10%     -   96s
# H    0     0                    2459.0000000 2460.36417  0.06%     -   98s
#      0     0 2460.34490    0   71 2459.00000 2460.34490  0.05%     -  173s
# H    0     0                    2460.0000000 2460.34490  0.01%     -  180s
#      0     0 2460.34490    0   71 2460.00000 2460.34490  0.01%     -  180s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 22
#   GUB cover: 1
#
# Explored 1 nodes (4081 simplex iterations) in 181.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2460 2459 2458 ... 2289
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.460000000000e+03, best bound 2.460000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x5x3

# %%
datafile="2x4000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x580e612e
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2292.0000000
# Presolve removed 10 rows and 4 columns (presolve time = 7s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 20s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 25s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 30s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 35s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 40s) ...
# Presolve removed 10 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 10 rows and 4 columns
# Presolve time: 49.93s
# Presolved: 11990 rows, 7996 columns, 15995992 nonzeros
# Variable types: 0 continuous, 7996 integer (7996 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   8.404596e+06   0.000000e+00     53s
#      428    2.6996213e+03   5.598931e+05   0.000000e+00     56s
#     1646    2.5382161e+03   1.585408e+05   0.000000e+00     61s
#     3174    2.4668791e+03   4.720497e+04   0.000000e+00     65s
#     3683    2.4633812e+03   0.000000e+00   0.000000e+00     66s
#
# Root relaxation: objective 2.463381e+03, 3683 iterations, 14.69 seconds
# Total elapsed time = 70.72s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2463.38124    0   76 2292.00000 2463.38124  7.48%     -   72s
# H    0     0                    2455.0000000 2463.38124  0.34%     -   72s
# H    0     0                    2460.0000000 2463.38124  0.14%     -   72s
# H    0     0                    2462.0000000 2463.38124  0.06%     -   74s
#      0     0 2463.29610    0   77 2462.00000 2463.29610  0.05%     -   85s
# H    0     0                    2463.0000000 2463.29610  0.01%     -   92s
#      0     0 2463.29610    0   77 2463.00000 2463.29610  0.01%     -   92s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 6
#   MIR: 17
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (3858 simplex iterations) in 92.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2463 2462 2460 ... 2292
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.463000000000e+03, best bound 2.463000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x5x4

# %%
datafile="2x4000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0xf6003fb7
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2261.0000000
# Presolve removed 7 rows and 6 columns (presolve time = 7s) ...
# Presolve removed 7 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 9 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 23s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 26s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 37s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 60s) ...
# Presolve removed 13 rows and 6 columns (presolve time = 65s) ...
# Presolve removed 13 rows and 6 columns
# Presolve time: 67.91s
# Presolved: 11987 rows, 7994 columns, 15987982 nonzeros
# Variable types: 0 continuous, 7994 integer (7994 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9970000e+03   8.309180e+06   0.000000e+00     71s
#      820    2.6241002e+03   3.747808e+05   0.000000e+00     75s
#     2290    2.4669264e+03   1.093501e+05   0.000000e+00     80s
#     3507    2.4383993e+03   0.000000e+00   0.000000e+00     83s
#
# Root relaxation: objective 2.438399e+03, 3507 iterations, 13.35 seconds
# Total elapsed time = 85.53s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2438.39932    0   85 2261.00000 2438.39932  7.85%     -   90s
# H    0     0                    2427.0000000 2438.39932  0.47%     -   90s
# H    0     0                    2436.0000000 2438.39932  0.10%     -   91s
# H    0     0                    2437.0000000 2438.39932  0.06%     -   94s
#      0     0 2438.01464    0   63 2437.00000 2438.01464  0.04%     -  169s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 1
#   MIR: 34
#   StrongCG: 1
#   RLT: 1
#
# Explored 1 nodes (3952 simplex iterations) in 174.26 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2437 2436 2427 2261
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.437000000000e+03, best bound 2.437000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 2x4000x5x5

# %%
datafile="2x4000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=2
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 12000 rows, 8000 columns and 16012000 nonzeros
# Model fingerprint: 0x5d49a657
# Variable types: 0 continuous, 8000 integer (8000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2277.0000000
# Presolve removed 12 rows and 8 columns (presolve time = 7s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 10s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 20s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 25s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 35s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 8 columns
# Presolve time: 49.93s
# Presolved: 11988 rows, 7992 columns, 15980004 nonzeros
# Variable types: 0 continuous, 7992 integer (7992 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9960000e+03   8.458637e+06   0.000000e+00     53s
#      366    2.7021502e+03   1.755615e+06   0.000000e+00     56s
#     1827    2.5620079e+03   1.018087e+06   0.000000e+00     63s
#     2275    2.5180971e+03   9.642130e+05   0.000000e+00     65s
#     3619    2.4544795e+03   1.362655e+04   0.000000e+00     70s
#     4117    2.4496223e+03   0.000000e+00   0.000000e+00     71s
#
# Root relaxation: objective 2.449622e+03, 4117 iterations, 19.37 seconds
# Total elapsed time = 75.57s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2449.62234    0   95 2277.00000 2449.62234  7.58%     -   79s
# H    0     0                    2438.0000000 2449.62234  0.48%     -   79s
# H    0     0                    2447.0000000 2449.62234  0.11%     -   80s
# H    0     0                    2448.0000000 2449.62234  0.07%     -   81s
# H    0     0                    2449.0000000 2449.62234  0.03%     -   83s
#      0     0 2449.62234    0   95 2449.00000 2449.62234  0.03%     -   83s
#
# Explored 1 nodes (4219 simplex iterations) in 83.30 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2449 2448 2447 ... 2277
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.449000000000e+03, best bound 2.449000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x1.5x1

# %%
datafile="3x4000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x71cf6cd2
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3999.0000000
# Presolve removed 19 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 15s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 31s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 35s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 40s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 45s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 50s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 55s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 60s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 65s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 70s) ...
# Presolve removed 19 rows and 3 columns (presolve time = 76s) ...
# Presolve removed 19 rows and 3 columns
# Presolve time: 76.18s
# Presolved: 15981 rows, 11997 columns, 24005931 nonzeros
# Variable types: 0 continuous, 11997 integer (11997 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   0.000000e+00   5.043000e+03     85s
# Concurrent spin time: 0.43s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3999 iterations, 7.22 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3999.00000 3999.00000  0.00%     -   86s
#
# Explored 0 nodes (3999 simplex iterations) in 86.21 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.999000000000e+03, best bound 3.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x1.5x2

# %%
datafile="3x4000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x40150178
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 26 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 23s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 27s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 43s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 60s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 65s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 70s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 75s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 80s) ...
# Presolve removed 29 rows and 6 columns (presolve time = 85s) ...
# Presolve removed 29 rows and 6 columns
# Presolve time: 88.15s
# Presolved: 15971 rows, 11994 columns, 23993859 nonzeros
# Variable types: 0 continuous, 11994 integer (11994 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   0.000000e+00   4.978500e+03     96s
# Concurrent spin time: 0.53s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3998 iterations, 7.25 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3998.00000 3998.00000  0.00%     -   98s
#
# Explored 0 nodes (3998 simplex iterations) in 98.20 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.998000000000e+03, best bound 3.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x1.5x3

# %%
datafile="3x4000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x625b1a5c
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3995.0000000
# Presolve removed 25 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 31s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 25 rows and 12 columns (presolve time = 77s) ...
# Presolve removed 25 rows and 12 columns
# Presolve time: 76.86s
# Presolved: 15975 rows, 11988 columns, 23969988 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   0.000000e+00   5.056250e+03     85s
#     4034    3.9960000e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.996000e+03, 4034 iterations, 7.30 seconds
# Total elapsed time = 90.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3996.00000    0   17 3995.00000 3996.00000  0.03%     -   96s
#      0     0 3996.00000    0    8 3995.00000 3996.00000  0.03%     -  111s
#      0     0 3996.00000    0   15 3995.00000 3996.00000  0.03%     -  118s
#      0     0 3996.00000    0    9 3995.00000 3996.00000  0.03%     -  147s
#      0     0 3996.00000    0    7 3995.00000 3996.00000  0.03%     -  153s
#      0     0 3996.00000    0   10 3995.00000 3996.00000  0.03%     -  178s
#      0     0 3996.00000    0    8 3995.00000 3996.00000  0.03%     -  185s
#      0     0 3996.00000    0    9 3995.00000 3996.00000  0.03%     -  207s
#      0     0 3996.00000    0    9 3995.00000 3996.00000  0.03%     -  213s
#      0     0 3996.00000    0    4 3995.00000 3996.00000  0.03%     -  235s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  242s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  258s
#      0     0 3996.00000    0    8 3995.00000 3996.00000  0.03%     -  263s
#      0     0 3996.00000    0   10 3995.00000 3996.00000  0.03%     -  284s
#      0     0 3996.00000    0    7 3995.00000 3996.00000  0.03%     -  298s
#      0     2 3996.00000    0    7 3995.00000 3996.00000  0.03%     -  322s
#      2     3 3996.00000    1    7 3995.00000 3996.00000  0.03%   0.0  494s
#      4     4 3996.00000    1    7 3995.00000 3996.00000  0.03%   0.0  528s
#      5     5 3996.00000    1    7 3995.00000 3996.00000  0.03%   0.0  550s
#      6     6 3996.00000    1   14 3995.00000 3996.00000  0.03%   0.0  560s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 6
#   MIR: 3
#   StrongCG: 3
#   RLT: 1
#
# Explored 6 nodes (42417 simplex iterations) in 578.22 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.995000000000e+03, best bound 3.995000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x1.5x4

# %%
datafile="3x4000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x11ee2178
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3995.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 11s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 16s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 36s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 75s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 80s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 87s) ...
# Presolve removed 18 rows and 9 columns
# Presolve time: 86.64s
# Presolved: 15982 rows, 11991 columns, 23981976 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9950000e+03   0.000000e+00   5.038000e+03     97s
#     4172    3.9962231e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.996223e+03, 4172 iterations, 9.36 seconds
# Total elapsed time = 102.94s
# Total elapsed time = 105.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3996.22309    0   15 3995.00000 3996.22309  0.03%     -  109s
#      0     0 3996.22309    0   20 3995.00000 3996.22309  0.03%     -  260s
#      0     0 3996.00000    0    8 3995.00000 3996.00000  0.03%     -  269s
#      0     0 3996.00000    0    9 3995.00000 3996.00000  0.03%     -  273s
#      0     0 3996.00000    0   12 3995.00000 3996.00000  0.03%     -  296s
#      0     0 3996.00000    0    8 3995.00000 3996.00000  0.03%     -  303s
#      0     0 3996.00000    0   16 3995.00000 3996.00000  0.03%     -  320s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  355s
#      0     0 3996.00000    0   22 3995.00000 3996.00000  0.03%     -  365s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  398s
#      0     0 3996.00000    0   12 3995.00000 3996.00000  0.03%     -  407s
#      0     0 3996.00000    0    9 3995.00000 3996.00000  0.03%     -  433s
#      0     0 3996.00000    0   12 3995.00000 3996.00000  0.03%     -  441s
#      0     0 3996.00000    0    4 3995.00000 3996.00000  0.03%     -  465s
#      0     0 3996.00000    0   11 3995.00000 3996.00000  0.03%     -  473s
#      0     0 3996.00000    0    4 3995.00000 3996.00000  0.03%     -  499s
#      0     0 3996.00000    0   10 3995.00000 3996.00000  0.03%     -  506s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  531s
#      0     0 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  536s
#      0     2 3996.00000    0    6 3995.00000 3996.00000  0.03%     -  563s
#      1     2 infeasible    1      3995.00000 3996.00000  0.03%   1.0  567s
#      3     4 3996.00000    2    8 3995.00000 3996.00000  0.03%  11.3  574s
#      5     8 3996.00000    3   13 3995.00000 3996.00000  0.03%  14.4  579s
#      9     5     cutoff    4      3995.00000 3996.00000  0.03%  17.6  592s
#     15     0     cutoff    5      3995.00000 3996.00000  0.03%  14.2  596s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 19
#   MIR: 3
#   StrongCG: 1
#   GUB cover: 2
#   RLT: 1
#
# Explored 20 nodes (45874 simplex iterations) in 597.65 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.995000000000e+03, best bound 3.995000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x1.5x5

# %%
datafile="3x4000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xcc486e03
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 17 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 31s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 60s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 65s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 70s) ...
# Presolve removed 17 rows and 6 columns (presolve time = 76s) ...
# Presolve removed 17 rows and 6 columns
# Presolve time: 76.47s
# Presolved: 15983 rows, 11994 columns, 23993973 nonzeros
# Variable types: 0 continuous, 11994 integer (11994 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   0.000000e+00   5.001000e+03     85s
# Concurrent spin time: 0.23s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3998 iterations, 7.44 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3998.00000 3998.00000  0.00%     -   86s
#
# Explored 0 nodes (3998 simplex iterations) in 86.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.998000000000e+03, best bound 3.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2x1

# %%
datafile="3x4000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x57a1758b
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3971.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 23s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 27s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 44s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 75s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 80s) ...
# Presolve removed 28 rows and 12 columns (presolve time = 85s) ...
# Presolve removed 28 rows and 12 columns
# Presolve time: 88.57s
# Presolved: 15972 rows, 11988 columns, 23969967 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9710000e+03   0.000000e+00   4.999500e+03     97s
#     4462    3.9763717e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.976372e+03, 4462 iterations, 7.92 seconds
# Total elapsed time = 108.57s
# Total elapsed time = 113.57s
# Total elapsed time = 116.30s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3976.37173    0  125 3971.00000 3976.37173  0.14%     -  119s
# H    0     0                    3974.0000000 3976.37173  0.06%     -  122s
#      0     0 3976.37173    0  148 3974.00000 3976.37173  0.06%     -  254s
# H    0     0                    3975.0000000 3976.37173  0.03%     -  267s
#      0     0 3976.23411    0  145 3975.00000 3976.23411  0.03%     -  270s
#      0     0 3976.23411    0  143 3975.00000 3976.23411  0.03%     -  275s
#      0     0 3976.14339    0   84 3975.00000 3976.14339  0.03%     -  316s
#      0     0 3976.14097    0   78 3975.00000 3976.14097  0.03%     -  326s
#      0     0 3976.14097    0   81 3975.00000 3976.14097  0.03%     -  330s
#      0     0 3976.14097    0   97 3975.00000 3976.14097  0.03%     -  348s
#      0     0 3976.13787    0  111 3975.00000 3976.13787  0.03%     -  359s
#      0     0 3976.13784    0  102 3975.00000 3976.13784  0.03%     -  364s
#      0     0 3976.13784    0  107 3975.00000 3976.13784  0.03%     -  384s
#      0     0 3976.13732    0  102 3975.00000 3976.13732  0.03%     -  394s
#      0     0 3976.13732    0   94 3975.00000 3976.13732  0.03%     -  399s
#      0     0 3976.12256    0   88 3975.00000 3976.12256  0.03%     -  417s
#      0     0 3976.08723    0   93 3975.00000 3976.08723  0.03%     -  430s
#      0     0 3976.08723    0   92 3975.00000 3976.08723  0.03%     -  434s
#      0     0 3976.02474    0   86 3975.00000 3976.02474  0.03%     -  453s
#      0     0 3976.02474    0   89 3975.00000 3976.02474  0.03%     -  460s
#      0     0 3976.02474    0   82 3975.00000 3976.02474  0.03%     -  478s
#      0     0 3976.02474    0   79 3975.00000 3976.02474  0.03%     -  490s
#      0     0 3976.02474    0   61 3975.00000 3976.02474  0.03%     -  531s
#      0     0 3976.02474    0   66 3975.00000 3976.02474  0.03%     -  538s
#      0     0 3976.02474    0   62 3975.00000 3976.02474  0.03%     -  563s
#      0     0 3976.02474    0   72 3975.00000 3976.02474  0.03%     -  574s
#      0     0 3976.02474    0   58 3975.00000 3976.02474  0.03%     -  606s
#      0     0 3976.02474    0   52 3975.00000 3976.02474  0.03%     -  622s
#      0     2 3976.01618    0   49 3975.00000 3976.01618  0.03%     -  675s
#      3     4 3976.01618    2   47 3975.00000 3976.01618  0.03%   851  684s
#      5     8 3976.01618    3   51 3975.00000 3976.01618  0.03%   521  689s
#      7     8 3976.01618    3   56 3975.00000 3976.01618  0.03%   382  690s
#      9    14 3975.99901    4   54 3975.00000 3976.01618  0.03%   308  697s
#     15    20 3975.99901    5   51 3975.00000 3976.01618  0.03%   195  703s
#     21    26 3975.99901    6   48 3975.00000 3976.01618  0.03%   150  707s
#     27    32 3975.99901    7   50 3975.00000 3976.01618  0.03%   118  721s
#     41    45     cutoff    9      3975.00000 3976.01618  0.03%  80.6  727s
#     50    58 3975.99901    8   48 3975.00000 3976.01618  0.03%  67.2  734s
#     71    87 3975.99777   15   60 3975.00000 3976.01618  0.03%  49.7  742s
#    105   166 3975.99777   20   63 3975.00000 3976.01618  0.03%  35.6  770s
#    202   285 3975.99777   31   52 3975.00000 3976.01618  0.03%  21.8  827s
#    400   528 3976.00419   27   39 3975.00000 3976.01618  0.03%  14.0  907s
#    791   643 3975.99961   59   41 3975.00000 3976.01618  0.03%   9.9  979s
#    968   944 3975.99961   69   43 3975.00000 3976.01618  0.03%   9.4 1088s
#   1424   945 3976.00414   52   52 3975.00000 3976.01618  0.03%   8.3 1396s
#   1426   946 3976.00752   46   92 3975.00000 3976.01618  0.03%   8.3 1678s
#   1427   947 3975.99777   24   72 3975.00000 3976.01618  0.03%   8.3 1786s
#   1428   948 3975.99777   27   58 3975.00000 3976.01575  0.03%   8.2 1791s
#   1429   948 3975.99616   45   54 3975.00000 3976.01575  0.03%   8.2 1867s
#   1430   949 3976.01575   20   51 3975.00000 3976.01575  0.03%   8.2 1962s
#   1431   950 3976.01129   31   63 3975.00000 3976.01575  0.03%   8.2 2038s
#   1432   950 3976.00712   30   57 3975.00000 3976.01575  0.03%   8.2 2137s
#   1433   951 3975.99777   22   68 3975.00000 3976.01575  0.03%   8.2 2209s
#   1434   952 3975.99777   13   62 3975.00000 3976.01575  0.03%   8.2 2268s
#   1435   952 3976.00414   75   72 3975.00000 3976.01575  0.03%   8.2 2303s
#   1436   953 3975.99741   83   71 3975.00000 3976.01575  0.03%   8.2 2367s
#   1437   954 3976.00414   52   66 3975.00000 3976.01575  0.03%   8.2 2425s
#   1438   954 3976.01575    5   48 3975.00000 3976.01575  0.03%   8.2 2504s
#   1439   955 3975.99961   63   58 3975.00000 3976.01575  0.03%   8.2 2562s
#   1440   956 3976.01121   19   56 3975.00000 3976.01575  0.03%   8.2 2636s
#   1441   956 3976.00752   30   62 3975.00000 3976.01575  0.03%   8.2 2697s
#   1442   957 3975.99616   43   54 3975.00000 3976.01575  0.03%   8.2 2771s
#   1443   958 3976.00574   26   56 3975.00000 3976.01575  0.03%   8.2 2827s
#   1444   958 3975.99741   37   52 3975.00000 3976.01575  0.03%   8.2 2899s
#   1445   959 3976.01575   14   67 3975.00000 3976.01575  0.03%   8.1 2966s
#   1446   960 3975.99616   32   61 3975.00000 3976.01575  0.03%   8.1 3042s
#   1447   960 3976.00502   56   61 3975.00000 3976.01575  0.03%   8.1 3068s
#   1448   961 3975.99777   31   61 3975.00000 3976.01575  0.03%   8.1 3131s
#   1449   965 3976.01575   12   64 3975.00000 3976.01575  0.03%  10.6 3165s
#   1451   968 3976.01575   13   65 3975.00000 3976.01575  0.03%  10.6 3176s
#   1455   973 3976.01575   14   63 3975.00000 3976.01575  0.03%  10.6 3189s
#   1461   976 3976.01575   15   62 3975.00000 3976.01575  0.03%  10.6 3195s
#   1467   979 3976.01575   15   62 3975.00000 3976.01575  0.03%  10.6 3202s
#   1473   983 3976.01575   16   60 3975.00000 3976.01575  0.03%  10.6 3207s
#   1479   984 3976.00914   16   53 3975.00000 3976.01575  0.03%  10.6 3222s
#   1485   988 3976.01575   17   56 3975.00000 3976.01575  0.03%  10.6 3227s
#   1492   990 3976.01575   17   57 3975.00000 3976.01575  0.03%  10.5 3234s
#   1500   994 3976.01575   18   52 3975.00000 3976.01575  0.03%  10.5 3242s
#   1509  1001 3976.01197   18   55 3975.00000 3976.01575  0.03%  10.5 3267s
#   1524  1033 3976.01575   20   55 3975.00000 3976.01575  0.03%  10.5 3297s
#   1575  1038 3976.00870   24   53 3975.00000 3976.01575  0.03%  10.3 3347s
#   1627  1042 3976.01575   18   56 3975.00000 3976.01575  0.03%  10.3 3510s
#   1730  1068 3976.01575   21   53 3975.00000 3976.01575  0.03%  10.3 3600s
#
# Cutting planes:
#   Gomory: 8
#   MIR: 9
#   Flow cover: 12
#
# Explored 1934 nodes (74035 simplex iterations) in 3636.41 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3975 3974 3971
#
# Time limit reached
# Best objective 3.975000000000e+03, best bound 3.976000000000e+03, gap 0.0252%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2x2

# %%
datafile="3x4000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x3c1dfc93
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3953.0000000
# Presolve removed 16 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 15s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 31s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 35s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 40s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 45s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 50s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 55s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 60s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 65s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 70s) ...
# Presolve removed 16 rows and 3 columns (presolve time = 76s) ...
# Presolve removed 16 rows and 3 columns
# Presolve time: 75.92s
# Presolved: 15984 rows, 11997 columns, 24005961 nonzeros
# Variable types: 0 continuous, 11997 integer (11997 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9510000e+03   0.000000e+00   5.080750e+03     84s
#     4450    3.9589878e+03   0.000000e+00   1.003187e+01     85s
#     4918    3.9594956e+03   0.000000e+00   0.000000e+00     86s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.959496e+03, 4918 iterations, 8.02 seconds
# Total elapsed time = 96.03s
# Total elapsed time = 100.20s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3959.49558    0   88 3953.00000 3959.49558  0.16%     -  105s
# H    0     0                    3958.0000000 3959.49558  0.04%     -  105s
# H    0     0                    3959.0000000 3959.49558  0.01%     -  108s
#      0     0 3959.49558    0   88 3959.00000 3959.49558  0.01%     -  108s
#
# Explored 1 nodes (10692 simplex iterations) in 108.65 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3959 3958 3953
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.959000000000e+03, best bound 3.959000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2x3

# %%
datafile="3x4000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x669d4c32
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3983.0000000
# Presolve removed 3 rows and 0 columns (presolve time = 9s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 13s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 3 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 3 rows and 0 columns
# Presolve time: 74.98s
# Presolved: 15997 rows, 12000 columns, 24017997 nonzeros
# Variable types: 0 continuous, 12000 integer (12000 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9830000e+03   0.000000e+00   5.050250e+03     83s
#     4233    3.9875292e+03   0.000000e+00   0.000000e+00     86s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.987529e+03, 4233 iterations, 8.15 seconds
# Total elapsed time = 94.16s
# Total elapsed time = 98.24s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3987.52919    0   73 3983.00000 3987.52919  0.11%     -  101s
# H    0     0                    3986.0000000 3987.52919  0.04%     -  104s
#      0     0 3987.50694    0  103 3986.00000 3987.50694  0.04%     -  234s
#      0     0 3987.38310    0   84 3986.00000 3987.38310  0.03%     -  250s
#      0     0 3987.37772    0   83 3986.00000 3987.37772  0.03%     -  255s
#      0     0 3987.37772    0   93 3986.00000 3987.37772  0.03%     -  272s
#      0     0 3987.36689    0   92 3986.00000 3987.36689  0.03%     -  281s
#      0     0 3987.36446    0   92 3986.00000 3987.36446  0.03%     -  285s
#      0     0 3987.35969    0   83 3986.00000 3987.35969  0.03%     -  303s
#      0     0 3987.30698    0   79 3986.00000 3987.30698  0.03%     -  319s
#      0     0 3987.30698    0   82 3986.00000 3987.30698  0.03%     -  324s
#      0     0 3987.26490    0   78 3986.00000 3987.26490  0.03%     -  342s
#      0     0 3987.22724    0   77 3986.00000 3987.22724  0.03%     -  351s
#      0     0 3987.22724    0   84 3986.00000 3987.22724  0.03%     -  356s
#      0     0 3987.16781    0   79 3986.00000 3987.16781  0.03%     -  373s
# H    0     0                    3987.0000000 3987.16781  0.00%     -  385s
#      0     0 3987.16781    0   79 3987.00000 3987.16781  0.00%     -  385s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 4
#   MIR: 28
#
# Explored 1 nodes (8598 simplex iterations) in 385.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3987 3986 3983
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.987000000000e+03, best bound 3.987000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2x4

# %%
datafile="3x4000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xb7a301fa
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3952.0000000
# Presolve removed 10 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 15s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 31s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 35s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 40s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 45s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 50s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 55s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 60s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 65s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 70s) ...
# Presolve removed 10 rows and 3 columns (presolve time = 76s) ...
# Presolve removed 10 rows and 3 columns
# Presolve time: 75.78s
# Presolved: 15990 rows, 11997 columns, 24005985 nonzeros
# Variable types: 0 continuous, 11997 integer (11997 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9520000e+03   0.000000e+00   5.105500e+03     84s
#     4371    3.9621013e+03   0.000000e+00   3.135633e-01     85s
#     4461    3.9619180e+03   0.000000e+00   0.000000e+00     86s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.961918e+03, 4461 iterations, 7.97 seconds
# Total elapsed time = 92.52s
# Total elapsed time = 97.63s
# Total elapsed time = 101.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3961.91802    0   40 3952.00000 3961.91802  0.25%     -  105s
# H    0     0                    3960.0000000 3961.91802  0.05%     -  105s
# H    0     0                    3961.0000000 3961.91802  0.02%     -  108s
#      0     0 3961.91802    0   40 3961.00000 3961.91802  0.02%     -  108s
#
# Explored 1 nodes (11576 simplex iterations) in 108.43 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3961 3960 3952
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.961000000000e+03, best bound 3.961000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2x5

# %%
datafile="3x4000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xd384e120
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3966.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 23s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 26s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 43s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 55s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 60s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 75s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 80s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 88s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 87.70s
# Presolved: 15974 rows, 11985 columns, 23958000 nonzeros
# Variable types: 0 continuous, 11985 integer (11985 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9660000e+03   0.000000e+00   5.040500e+03     96s
#     4556    3.9706346e+03   0.000000e+00   0.000000e+00     98s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.970635e+03, 4556 iterations, 7.86 seconds
# Total elapsed time = 103.63s
# Total elapsed time = 108.84s
# Total elapsed time = 113.74s
# Total elapsed time = 115.36s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3970.63460    0   38 3966.00000 3970.63460  0.12%     -  117s
# H    0     0                    3969.0000000 3970.63460  0.04%     -  118s
# H    0     0                    3970.0000000 3970.63460  0.02%     -  120s
#      0     0 3970.63460    0   38 3970.00000 3970.63460  0.02%     -  120s
#
# Explored 1 nodes (10544 simplex iterations) in 120.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3970 3969 3966
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.970000000000e+03, best bound 3.970000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2.5x1

# %%
datafile="3x4000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xa36d62cb
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3472.0000000
# Presolve removed 42 rows and 27 columns (presolve time = 10s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 15s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 31s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 35s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 40s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 45s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 50s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 55s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 60s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 65s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 70s) ...
# Presolve removed 42 rows and 27 columns (presolve time = 76s) ...
# Presolve removed 42 rows and 27 columns
# Presolve time: 75.64s
# Presolved: 15958 rows, 11973 columns, 23910069 nonzeros
# Variable types: 0 continuous, 11973 integer (11973 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4720000e+03   0.000000e+00   5.272500e+03     84s
#     3241    3.5227773e+03   0.000000e+00   1.226615e+02     85s
#     5406    3.5565377e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.556538e+03, 5406 iterations, 9.07 seconds
# Total elapsed time = 96.16s
# Total elapsed time = 102.00s
# Total elapsed time = 108.04s
# Total elapsed time = 110.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3556.53767    0  123 3472.00000 3556.53767  2.43%     -  112s
# H    0     0                    3554.0000000 3556.53767  0.07%     -  112s
# H    0     0                    3555.0000000 3556.53767  0.04%     -  116s
#      0     0 3556.08085    0  105 3555.00000 3556.08085  0.03%     -  237s
#      0     0 3556.07510    0   95 3555.00000 3556.07510  0.03%     -  250s
#      0     0 3556.07506    0   97 3555.00000 3556.07506  0.03%     -  255s
#      0     0 3556.03783    0   85 3555.00000 3556.03783  0.03%     -  273s
#      0     0 3556.03783    0   82 3555.00000 3556.03783  0.03%     -  282s
#      0     0 3556.03287    0   63 3555.00000 3556.03287  0.03%     -  301s
#      0     0 3556.03287    0   69 3555.00000 3556.03287  0.03%     -  310s
#      0     0 3556.03287    0   75 3555.00000 3556.03287  0.03%     -  327s
#      0     0 3556.03287    0   78 3555.00000 3556.03287  0.03%     -  336s
#      0     0 3556.03287    0   71 3555.00000 3556.03287  0.03%     -  360s
#      0     0 3556.03287    0   69 3555.00000 3556.03287  0.03%     -  379s
#      0     0 3556.03287    0   40 3555.00000 3556.03287  0.03%     -  410s
#      0     0 infeasible    0      3555.00000 3555.00000  0.00%     -  419s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   MIR: 68
#   StrongCG: 4
#   RLT: 2
#
# Explored 1 nodes (27217 simplex iterations) in 420.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3555 3554 3472
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.555000000000e+03, best bound 3.555000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2.5x2

# %%
datafile="3x4000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xd38a94a1
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3475.0000000
# Presolve removed 6 rows and 0 columns (presolve time = 9s) ...
# Presolve removed 6 rows and 0 columns (presolve time = 13s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 22s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 42s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 75s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 80s) ...
# Presolve removed 9 rows and 0 columns (presolve time = 87s) ...
# Presolve removed 9 rows and 0 columns
# Presolve time: 86.78s
# Presolved: 15991 rows, 12000 columns, 24017970 nonzeros
# Variable types: 0 continuous, 12000 integer (12000 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4800000e+03   0.000000e+00   5.244500e+03     95s
#     5301    3.5586486e+03   0.000000e+00   0.000000e+00     98s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.558649e+03, 5301 iterations, 8.92 seconds
# Total elapsed time = 106.77s
# Total elapsed time = 112.00s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3558.64861    0   94 3475.00000 3558.64861  2.41%     -  115s
# H    0     0                    3556.0000000 3558.64861  0.07%     -  115s
#      0     0 3558.59482    0  113 3556.00000 3558.59482  0.07%     -  239s
# H    0     0                    3557.0000000 3558.59482  0.04%     -  245s
# H    0     0                    3558.0000000 3558.59482  0.02%     -  257s
#      0     0 3558.59482    0  113 3558.00000 3558.59482  0.02%     -  257s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 1
#   MIR: 9
#   GUB cover: 1
#
# Explored 1 nodes (13099 simplex iterations) in 257.36 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3558 3557 3556 3475
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.558000000000e+03, best bound 3.558000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2.5x3

# %%
datafile="3x4000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x2229f3fe
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3472.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 31s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 40s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 55s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 60s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 76s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 75.90s
# Presolved: 15974 rows, 11985 columns, 23958003 nonzeros
# Variable types: 0 continuous, 11985 integer (11985 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4720000e+03   0.000000e+00   5.203250e+03     84s
#     2175    3.4988273e+03   0.000000e+00   4.788678e+02     85s
#     5800    3.5543599e+03   0.000000e+00   0.000000e+00     88s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.554360e+03, 5800 iterations, 9.35 seconds
# Total elapsed time = 97.18s
# Total elapsed time = 104.06s
# Total elapsed time = 107.78s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3554.35994    0  157 3472.00000 3554.35994  2.37%     -  111s
# H    0     0                    3547.0000000 3554.35994  0.21%     -  112s
# H    0     0                    3550.0000000 3554.35994  0.12%     -  112s
# H    0     0                    3552.0000000 3554.35994  0.07%     -  115s
# H    0     0                    3553.0000000 3554.35994  0.04%     -  117s
#      0     0 3554.35002    0  154 3553.00000 3554.35002  0.04%     -  235s
#      0     0 3554.33567    0  166 3553.00000 3554.33567  0.04%     -  251s
#      0     0 3554.29630    0  170 3553.00000 3554.29630  0.04%     -  256s
#      0     0 3554.24888    0  128 3553.00000 3554.24888  0.04%     -  274s
#      0     0 3554.24888    0  145 3553.00000 3554.24888  0.04%     -  283s
#      0     0 3554.16674    0  134 3553.00000 3554.16674  0.03%     -  301s
#      0     0 3554.16629    0  133 3553.00000 3554.16629  0.03%     -  313s
#      0     0 3554.16614    0  123 3553.00000 3554.16614  0.03%     -  318s
#      0     0 3554.16614    0  123 3553.00000 3554.16614  0.03%     -  336s
#      0     0 3554.16614    0  113 3553.00000 3554.16614  0.03%     -  345s
#      0     0 3554.15635    0  132 3553.00000 3554.15635  0.03%     -  362s
#      0     0 3554.15509    0  132 3553.00000 3554.15509  0.03%     -  381s
#      0     0 3554.15509    0  126 3553.00000 3554.15509  0.03%     -  386s
#      0     0 3554.09788    0  108 3553.00000 3554.09788  0.03%     -  404s
#      0     0 3554.09788    0  112 3553.00000 3554.09788  0.03%     -  415s
#      0     0 3554.05541    0  108 3553.00000 3554.05541  0.03%     -  433s
#      0     0 3554.05525    0  109 3553.00000 3554.05525  0.03%     -  444s
#      0     0 3554.05343    0  102 3553.00000 3554.05343  0.03%     -  461s
#      0     0 3554.05343    0  109 3553.00000 3554.05343  0.03%     -  472s
#      0     0 3554.05343    0  121 3553.00000 3554.05343  0.03%     -  487s
#      0     0 3554.05313    0  118 3553.00000 3554.05313  0.03%     -  501s
#      0     0 3554.05313    0   90 3553.00000 3554.05313  0.03%     -  547s
#      0     0 3554.05313    0  103 3553.00000 3554.05313  0.03%     -  557s
#      0     0 3554.05313    0  116 3553.00000 3554.05313  0.03%     -  573s
#      0     0 3554.05313    0   94 3553.00000 3554.05313  0.03%     -  609s
#      0     2 3554.05313    0   87 3553.00000 3554.05313  0.03%     -  664s
#      1     2     cutoff    1      3553.00000 3554.04315  0.03%  3292  668s
#      3     2 3554.04315    2   88 3553.00000 3554.04315  0.03%  1099  671s
#      5     4 3554.04315    3   94 3553.00000 3554.04315  0.03%   663  675s
#      7     8 3554.04305    4   83 3553.00000 3554.04315  0.03%   481  681s
#     11     8 3554.02884    5   88 3553.00000 3554.04310  0.03%   314  688s
#     17     4     cutoff    6      3553.00000 3554.04310  0.03%   209  691s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 25
#   Clique: 1
#   MIR: 45
#   RLT: 1
#
# Explored 27 nodes (38306 simplex iterations) in 693.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3553 3552 3550 ... 3472
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.553000000000e+03, best bound 3.553000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2.5x4

# %%
datafile="3x4000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xc15ffc50
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3470.0000000
# Presolve removed 7 rows and 3 columns (presolve time = 10s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 15s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 31s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 35s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 40s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 45s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 50s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 55s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 60s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 65s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 70s) ...
# Presolve removed 7 rows and 3 columns (presolve time = 76s) ...
# Presolve removed 7 rows and 3 columns
# Presolve time: 75.95s
# Presolved: 15993 rows, 11997 columns, 24005994 nonzeros
# Variable types: 0 continuous, 11997 integer (11997 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4700000e+03   0.000000e+00   5.236500e+03     84s
#     1563    3.4770380e+03   0.000000e+00   4.415556e+02     85s
#     5351    3.5526019e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.552602e+03, 5351 iterations, 8.93 seconds
# Total elapsed time = 95.80s
# Total elapsed time = 100.91s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3552.60187    0  180 3470.00000 3552.60187  2.38%     -  106s
# H    0     0                    3550.0000000 3552.60187  0.07%     -  106s
#      0     0 3552.58730    0  197 3550.00000 3552.58730  0.07%     -  232s
# H    0     0                    3552.0000000 3552.58730  0.02%     -  244s
#      0     0 3552.58730    0  197 3552.00000 3552.58730  0.02%     -  244s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 42
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (12361 simplex iterations) in 244.65 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3552 3550 3470
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.552000000000e+03, best bound 3.552000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x2.5x5

# %%
datafile="3x4000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x13d7e096
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3470.0000000
# Presolve removed 14 rows and 6 columns (presolve time = 10s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 15s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 31s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 35s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 40s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 45s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 50s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 55s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 60s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 65s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 70s) ...
# Presolve removed 14 rows and 6 columns (presolve time = 76s) ...
# Presolve removed 14 rows and 6 columns
# Presolve time: 75.94s
# Presolved: 15986 rows, 11994 columns, 23993982 nonzeros
# Variable types: 0 continuous, 11994 integer (11994 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4700000e+03   0.000000e+00   5.272000e+03     84s
#     3274    3.5218913e+03   0.000000e+00   7.623159e+01     85s
#     5334    3.5532562e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.553256e+03, 5334 iterations, 8.85 seconds
# Total elapsed time = 96.24s
# Total elapsed time = 102.16s
# Total elapsed time = 107.70s
# Total elapsed time = 110.23s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3553.25619    0  107 3470.00000 3553.25619  2.40%     -  112s
# H    0     0                    3548.0000000 3553.25619  0.15%     -  112s
# H    0     0                    3550.0000000 3553.25619  0.09%     -  115s
# H    0     0                    3552.0000000 3553.25619  0.04%     -  120s
#      0     0 3553.06900    0   92 3552.00000 3553.06900  0.03%     -  206s
#      0     0 infeasible    0      3552.00000 3552.00000  0.00%     -  209s
#      0     0 infeasible    0      3552.00000 3552.00000  0.00%     -  209s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 5
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (16300 simplex iterations) in 209.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3552 3550 3548 3470
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.552000000000e+03, best bound 3.552000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3x1

# %%
datafile="3x4000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf60daf6d
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 3102.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 31s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 76s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 75.86s
# Presolved: 15978 rows, 11988 columns, 23969997 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1020000e+03   0.000000e+00   5.297000e+03     84s
#     2962    3.1683621e+03   0.000000e+00   2.382416e+02     85s
#     5424    3.2229157e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.222916e+03, 5424 iterations, 8.90 seconds
# Total elapsed time = 95.49s
# Total elapsed time = 100.75s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3222.91569    0  143 3102.00000 3222.91569  3.90%     -  104s
# H    0     0                    3213.0000000 3222.91569  0.31%     -  104s
# H    0     0                    3219.0000000 3222.91569  0.12%     -  104s
# H    0     0                    3220.0000000 3222.91569  0.09%     -  108s
# H    0     0                    3222.0000000 3222.91569  0.03%     -  109s
#      0     0 3222.91569    0  143 3222.00000 3222.91569  0.03%     -  109s
#
# Explored 1 nodes (11711 simplex iterations) in 109.67 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3222 3220 3219 ... 3102
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.222000000000e+03, best bound 3.222000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3x2

# %%
datafile="3x4000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf361a49f
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 3105.0000000
# Presolve removed 15 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 23s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 27s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 43s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 75s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 80s) ...
# Presolve removed 18 rows and 9 columns (presolve time = 85s) ...
# Presolve removed 18 rows and 9 columns
# Presolve time: 88.19s
# Presolved: 15982 rows, 11991 columns, 23981982 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1050000e+03   0.000000e+00   5.368750e+03     97s
#     5496    3.2283031e+03   0.000000e+00   0.000000e+00    100s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.228303e+03, 5496 iterations, 9.09 seconds
# Total elapsed time = 107.08s
# Total elapsed time = 111.87s
# Total elapsed time = 115.56s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3228.30307    0  124 3105.00000 3228.30307  3.97%     -  118s
# H    0     0                    3218.0000000 3228.30307  0.32%     -  119s
# H    0     0                    3224.0000000 3228.30307  0.13%     -  119s
# H    0     0                    3225.0000000 3228.30307  0.10%     -  122s
# H    0     0                    3227.0000000 3228.30307  0.04%     -  128s
#      0     0 3228.07105    0  133 3227.00000 3228.07105  0.03%     -  242s
#      0     0 infeasible    0      3227.00000 3227.00000  0.00%     -  245s
#      0     0 infeasible    0      3227.00000 3227.00000  0.00%     -  245s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 1
#   MIR: 22
#   StrongCG: 2
#   RLT: 1
#
# Explored 1 nodes (10687 simplex iterations) in 245.87 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3227 3225 3224 ... 3105
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.227000000000e+03, best bound 3.227000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3x3

# %%
datafile="3x4000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x56d65caf
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 3111.0000000
# Presolve removed 26 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 23s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 27s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 43s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 55s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 60s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 75s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 80s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 88s) ...
# Presolve removed 32 rows and 15 columns
# Presolve time: 88.02s
# Presolved: 15968 rows, 11985 columns, 23957964 nonzeros
# Variable types: 0 continuous, 11985 integer (11985 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1110000e+03   0.000000e+00   5.359000e+03     96s
#     5092    3.2275534e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.227553e+03, 5092 iterations, 8.72 seconds
# Total elapsed time = 106.78s
# Total elapsed time = 111.92s
# Total elapsed time = 117.21s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3227.55344    0   76 3111.00000 3227.55344  3.75%     -  121s
# H    0     0                    3220.0000000 3227.55344  0.23%     -  121s
# H    0     0                    3225.0000000 3227.55344  0.08%     -  122s
# H    0     0                    3226.0000000 3227.55344  0.05%     -  128s
#      0     0 3227.04550    0   62 3226.00000 3227.04550  0.03%     -  240s
#      0     0 3227.04550    0   70 3226.00000 3227.04550  0.03%     -  256s
#      0     0 3227.03393    0   51 3226.00000 3227.03393  0.03%     -  273s
#      0     0 3227.03393    0   51 3226.00000 3227.03393  0.03%     -  282s
#      0     0 infeasible    0      3226.00000 3226.00000  0.00%     -  295s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 7
#   MIR: 37
#   StrongCG: 13
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (14450 simplex iterations) in 296.06 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3226 3225 3220 3111
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.226000000000e+03, best bound 3.226000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3x4

# %%
datafile="3x4000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf93a8627
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3084.0000000
# Presolve removed 12 rows and 0 columns (presolve time = 9s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 13s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 50s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 55s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 60s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 65s) ...
# Presolve removed 12 rows and 0 columns (presolve time = 70s) ...
# Presolve removed 12 rows and 0 columns
# Presolve time: 74.79s
# Presolved: 15988 rows, 12000 columns, 24017970 nonzeros
# Variable types: 0 continuous, 12000 integer (12000 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0840000e+03   0.000000e+00   5.259000e+03     83s
#     5215    3.2083845e+03   0.000000e+00   3.742454e-01     85s
#     5405    3.2082858e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.208286e+03, 5405 iterations, 9.28 seconds
# Total elapsed time = 95.14s
# Total elapsed time = 100.54s
# Total elapsed time = 105.77s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3208.28576    0  213 3084.00000 3208.28576  4.03%     -  110s
# H    0     0                    3204.0000000 3208.28576  0.13%     -  110s
# H    0     0                    3206.0000000 3208.28576  0.07%     -  113s
#      0     0 3207.64199    0  197 3206.00000 3207.64199  0.05%     -  137s
# H    0     0                    3207.0000000 3207.64199  0.02%     -  149s
#      0     0 3207.64199    0  197 3207.00000 3207.64199  0.02%     -  149s
#
# Cutting planes:
#   Gomory: 19
#   Cover: 1
#   MIR: 34
#   StrongCG: 1
#   RLT: 1
#
# Explored 1 nodes (13649 simplex iterations) in 149.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3207 3206 3204 3084
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.207000000000e+03, best bound 3.207000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3x5

# %%
datafile="3x4000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x42b03c54
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+03]
# Found heuristic solution: objective 3111.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 23s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 27s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 43s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 75s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 80s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 88s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 87.92s
# Presolved: 15978 rows, 11988 columns, 23969988 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1040000e+03   0.000000e+00   5.397625e+03     96s
#     5527    3.2324460e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.232446e+03, 5527 iterations, 9.05 seconds
# Total elapsed time = 107.81s
# Total elapsed time = 112.74s
# Total elapsed time = 116.03s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3232.44603    0  107 3111.00000 3232.44603  3.90%     -  117s
# H    0     0                    3221.0000000 3232.44603  0.36%     -  118s
# H    0     0                    3229.0000000 3232.44603  0.11%     -  118s
# H    0     0                    3230.0000000 3232.44603  0.08%     -  123s
#      0     0 3231.79313    0  119 3230.00000 3231.79313  0.06%     -  235s
# H    0     0                    3231.0000000 3231.79313  0.02%     -  250s
#      0     0 3231.79313    0  119 3231.00000 3231.79313  0.02%     -  250s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 2
#   MIR: 22
#
# Explored 1 nodes (12049 simplex iterations) in 251.07 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3231 3230 3229 ... 3111
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.231000000000e+03, best bound 3.231000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3.5x1

# %%
datafile="3x4000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x5690d8f8
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2842.0000000
# Presolve removed 15 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 31s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 15 rows and 9 columns (presolve time = 76s) ...
# Presolve removed 15 rows and 9 columns
# Presolve time: 76.05s
# Presolved: 15985 rows, 11991 columns, 23981991 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8390000e+03   0.000000e+00   5.545750e+03     84s
#     3031    2.9226651e+03   0.000000e+00   1.971273e+02     85s
#     5377    2.9769902e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.976990e+03, 5377 iterations, 8.80 seconds
# Total elapsed time = 95.24s
# Total elapsed time = 104.64s
# Total elapsed time = 106.38s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2976.99021    0  121 2842.00000 2976.99021  4.75%     -  108s
# H    0     0                    2964.0000000 2976.99021  0.44%     -  108s
# H    0     0                    2974.0000000 2976.99021  0.10%     -  109s
# H    0     0                    2975.0000000 2976.99021  0.07%     -  120s
#      0     0 2976.94886    0  108 2975.00000 2976.94886  0.07%     -  228s
# H    0     0                    2976.0000000 2976.94886  0.03%     -  242s
#      0     0 2976.94886    0  108 2976.00000 2976.94886  0.03%     -  242s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   MIR: 41
#   StrongCG: 5
#   RLT: 1
#
# Explored 1 nodes (12067 simplex iterations) in 242.97 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2976 2975 2974 ... 2842
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.976000000000e+03, best bound 2.976000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3.5x2

# %%
datafile="3x4000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x7ece4bdd
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2852.0000000
# Presolve removed 21 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 23s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 26s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 43s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 75s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 80s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 88s) ...
# Presolve removed 21 rows and 9 columns
# Presolve time: 87.78s
# Presolved: 15979 rows, 11991 columns, 23981970 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8520000e+03   0.000000e+00   5.487000e+03     96s
#     5196    2.9810202e+03   0.000000e+00   0.000000e+00    100s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.981020e+03, 5196 iterations, 9.44 seconds
# Total elapsed time = 107.04s
# Total elapsed time = 111.63s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2981.02015    0  110 2852.00000 2981.02015  4.52%     -  116s
# H    0     0                    2972.0000000 2981.02015  0.30%     -  117s
# H    0     0                    2979.0000000 2981.02015  0.07%     -  119s
# H    0     0                    2980.0000000 2981.02015  0.03%     -  123s
#      0     0     cutoff    0      2980.00000 2980.00000  0.00%     -  200s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 1
#   MIR: 38
#   RLT: 3
#
# Explored 1 nodes (11271 simplex iterations) in 200.50 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2980 2979 2972 2852
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.980000000000e+03, best bound 2.980000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3.5x3

# %%
datafile="3x4000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x48334c42
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2833.0000000
# Presolve removed 36 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 23s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 27s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 43s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 75s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 80s) ...
# Presolve removed 39 rows and 18 columns (presolve time = 88s) ...
# Presolve removed 39 rows and 18 columns
# Presolve time: 88.03s
# Presolved: 15961 rows, 11982 columns, 23945967 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8330000e+03   0.000000e+00   5.526500e+03     96s
#     5375    2.9721654e+03   0.000000e+00   0.000000e+00    100s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.972165e+03, 5375 iterations, 9.15 seconds
# Total elapsed time = 107.17s
# Total elapsed time = 112.11s
# Total elapsed time = 116.67s
# Total elapsed time = 120.40s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2972.16544    0  254 2833.00000 2972.16544  4.91%     -  122s
# H    0     0                    2968.0000000 2972.16544  0.14%     -  123s
# H    0     0                    2969.0000000 2972.16544  0.11%     -  125s
# H    0     0                    2971.0000000 2972.16544  0.04%     -  128s
#      0     0 2972.15207    0  245 2971.00000 2972.15207  0.04%     -  225s
#      0     0     cutoff    0      2971.00000 2971.00000  0.00%     -  237s
#
# Cutting planes:
#   Gomory: 27
#   Cover: 2
#   MIR: 81
#   StrongCG: 13
#   GUB cover: 2
#
# Explored 1 nodes (13250 simplex iterations) in 237.47 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2971 2969 2968 2833
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.971000000000e+03, best bound 2.971000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3.5x4

# %%
datafile="3x4000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf134d88b
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2837.0000000
# Presolve removed 18 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 23s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 27s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 43s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 75s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 80s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 88s) ...
# Presolve removed 21 rows and 9 columns
# Presolve time: 88.00s
# Presolved: 15979 rows, 11991 columns, 23981964 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8300000e+03   0.000000e+00   5.460000e+03     96s
#     5204    2.9662854e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.966285e+03, 5204 iterations, 8.92 seconds
# Total elapsed time = 106.78s
# Total elapsed time = 111.74s
# Total elapsed time = 116.46s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2966.28535    0  246 2837.00000 2966.28535  4.56%     -  120s
# H    0     0                    2957.0000000 2966.28535  0.31%     -  120s
# H    0     0                    2963.0000000 2966.28535  0.11%     -  121s
# H    0     0                    2964.0000000 2966.28535  0.08%     -  123s
# H    0     0                    2965.0000000 2966.28535  0.04%     -  125s
#      0     0 2966.25860    0  267 2965.00000 2966.25860  0.04%     -  143s
#      0     0 2966.25101    0  271 2965.00000 2966.25101  0.04%     -  159s
#      0     0 2966.25033    0  268 2965.00000 2966.25033  0.04%     -  164s
#      0     0 2966.25033    0  268 2965.00000 2966.25033  0.04%     -  168s
#      0     0 2966.16707    0  242 2965.00000 2966.16707  0.04%     -  188s
#      0     0 2966.16490    0  230 2965.00000 2966.16490  0.04%     -  200s
#      0     0 2966.16388    0  224 2965.00000 2966.16388  0.04%     -  206s
#      0     0 2966.16388    0  224 2965.00000 2966.16388  0.04%     -  211s
#      0     0     cutoff    0      2965.00000 2965.00000  0.00%     -  228s
#
# Cutting planes:
#   Gomory: 29
#   Cover: 16
#   MIR: 234
#   StrongCG: 17
#   RLT: 1
#
# Explored 1 nodes (12431 simplex iterations) in 228.45 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2965 2964 2963 ... 2837
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.965000000000e+03, best bound 2.965000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x3.5x5

# %%
datafile="3x4000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x91dbbfd5
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 2830.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 31s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 40s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 76s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 76.10s
# Presolved: 15970 rows, 11982 columns, 23946012 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8270000e+03   0.000000e+00   5.414250e+03     84s
#     1568    2.8503392e+03   0.000000e+00   6.239725e+02     85s
#     5187    2.9625138e+03   0.000000e+00   0.000000e+00     88s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.962514e+03, 5187 iterations, 9.04 seconds
# Total elapsed time = 95.18s
# Total elapsed time = 103.38s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2962.51383    0  163 2830.00000 2962.51383  4.68%     -  106s
# H    0     0                    2948.0000000 2962.51383  0.49%     -  106s
# H    0     0                    2959.0000000 2962.51383  0.12%     -  107s
# H    0     0                    2960.0000000 2962.51383  0.08%     -  113s
#      0     0 2962.05954    0  141 2960.00000 2962.05954  0.07%     -  220s
# H    0     0                    2961.0000000 2962.05954  0.04%     -  230s
#      0     0 2962.05954    0  148 2961.00000 2962.05954  0.04%     -  233s
#      0     0 2962.05230    0  107 2961.00000 2962.05230  0.04%     -  272s
#      0     0 2962.05230    0  180 2961.00000 2962.05230  0.04%     -  335s
#      0     0 2962.05230    0  146 2961.00000 2962.05230  0.04%     -  401s
#      0     0 2962.05034    0  129 2961.00000 2962.05034  0.04%     -  409s
#      0     0 2962.04814    0  125 2961.00000 2962.04814  0.04%     -  412s
#      0     0 2962.04814    0  121 2961.00000 2962.04814  0.04%     -  415s
#      0     0 2962.04814    0  129 2961.00000 2962.04814  0.04%     -  425s
#      0     0     cutoff    0      2961.00000 2961.00000  0.00%     -  430s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 2
#   MIR: 73
#   StrongCG: 8
#   RLT: 1
#
# Explored 1 nodes (20629 simplex iterations) in 430.34 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2961 2960 2959 ... 2830
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.961000000000e+03, best bound 2.961000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4x1

# %%
datafile="3x4000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf844a35a
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2623.0000000
# Presolve removed 35 rows and 24 columns (presolve time = 10s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 23s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 26s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 43s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 45s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 50s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 55s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 60s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 35 rows and 24 columns (presolve time = 88s) ...
# Presolve removed 35 rows and 24 columns
# Presolve time: 87.59s
# Presolved: 15965 rows, 11976 columns, 23922051 nonzeros
# Variable types: 0 continuous, 11976 integer (11976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6260000e+03   0.000000e+00   5.598750e+03     96s
#     4754    2.7674049e+03   0.000000e+00   0.000000e+00     98s
# Concurrent spin time: 0.04s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.767405e+03, 4754 iterations, 8.44 seconds
# Total elapsed time = 104.95s
# Total elapsed time = 108.67s
# Total elapsed time = 111.72s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2767.40491    0  133 2623.00000 2767.40491  5.51%     -  114s
# H    0     0                    2751.0000000 2767.40491  0.60%     -  115s
# H    0     0                    2765.0000000 2767.40491  0.09%     -  115s
# H    0     0                    2766.0000000 2767.40491  0.05%     -  120s
#      0     0 2767.37841    0  132 2766.00000 2767.37841  0.05%     -  222s
#      0     0 2767.37841    0  128 2766.00000 2767.37841  0.05%     -  236s
#      0     0 2767.34844    0  122 2766.00000 2767.34844  0.05%     -  256s
#      0     0 2767.33195    0  102 2766.00000 2767.33195  0.05%     -  268s
#      0     0 2767.33195    0  104 2766.00000 2767.33195  0.05%     -  272s
#      0     0 2767.31701    0   99 2766.00000 2767.31701  0.05%     -  291s
#      0     0 2767.27395    0   93 2766.00000 2767.27395  0.05%     -  305s
#      0     0 2767.22674    0   90 2766.00000 2767.22674  0.04%     -  311s
#      0     0 2767.22674    0   90 2766.00000 2767.22674  0.04%     -  314s
#      0     0 2767.22482    0  102 2766.00000 2767.22482  0.04%     -  333s
#      0     0 2767.21537    0   95 2766.00000 2767.21537  0.04%     -  344s
#      0     0 2767.21537    0   96 2766.00000 2767.21537  0.04%     -  348s
#      0     0 2767.21537    0   85 2766.00000 2767.21537  0.04%     -  364s
#      0     0 2767.21537    0   82 2766.00000 2767.21537  0.04%     -  377s
#      0     0 2767.21516    0   69 2766.00000 2767.21516  0.04%     -  394s
#      0     0 2767.21516    0   76 2766.00000 2767.21516  0.04%     -  404s
#      0     0 2767.21330    0   67 2766.00000 2767.21330  0.04%     -  421s
#      0     0 2767.21330    0   72 2766.00000 2767.21330  0.04%     -  432s
#      0     0 2767.21330    0   77 2766.00000 2767.21330  0.04%     -  448s
#      0     0 2767.21330    0   79 2766.00000 2767.21330  0.04%     -  459s
#      0     0 2767.18246    0   61 2766.00000 2767.18246  0.04%     -  485s
#      0     0 2767.09932    0   67 2766.00000 2767.09932  0.04%     -  497s
#      0     0 2767.09932    0   65 2766.00000 2767.09932  0.04%     -  501s
#      0     0 2767.04411    0   53 2766.00000 2767.04411  0.04%     -  530s
#      0     0 2767.04411    0  136 2766.00000 2767.04411  0.04%     -  593s
#      0     0 2767.04411    0  114 2766.00000 2767.04411  0.04%     -  648s
#      0     0 2767.04411    0   92 2766.00000 2767.04411  0.04%     -  654s
#      0     0 2767.03811    0   82 2766.00000 2767.03811  0.04%     -  657s
#
# Cutting planes:
#   Gomory: 22
#   Cover: 7
#   MIR: 80
#   StrongCG: 3
#
# Explored 1 nodes (22239 simplex iterations) in 662.85 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2766 2765 2751 2623
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.766000000000e+03, best bound 2.766000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4x2

# %%
datafile="3x4000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xa8dc934a
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2614.0000000
# Presolve removed 33 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 31s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 40s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 76s) ...
# Presolve removed 33 rows and 18 columns
# Presolve time: 75.84s
# Presolved: 15967 rows, 11982 columns, 23946009 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6140000e+03   0.000000e+00   5.624250e+03     84s
#     3037    2.7226097e+03   0.000000e+00   2.429418e+02     85s
#     4719    2.7742201e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.774220e+03, 4719 iterations, 8.63 seconds
# Total elapsed time = 93.77s
# Total elapsed time = 97.47s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2774.22015    0   83 2614.00000 2774.22015  6.13%     -  100s
# H    0     0                    2768.0000000 2774.22015  0.22%     -  100s
# H    0     0                    2772.0000000 2774.22015  0.08%     -  102s
# H    0     0                    2773.0000000 2774.22015  0.04%     -  106s
#      0     0 2774.16392    0   80 2773.00000 2774.16392  0.04%     -  121s
#      0     0 2774.16392    0   78 2773.00000 2774.16392  0.04%     -  133s
#      0     0 infeasible    0      2773.00000 2773.00000  0.00%     -  146s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 25
#   MIR: 110
#   StrongCG: 23
#   RLT: 2
#
# Explored 1 nodes (8804 simplex iterations) in 147.02 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2773 2772 2768 2614
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.773000000000e+03, best bound 2.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4x3

# %%
datafile="3x4000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x79043dec
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2628.0000000
# Presolve removed 23 rows and 15 columns (presolve time = 10s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 23s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 27s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 43s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 55s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 60s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 75s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 80s) ...
# Presolve removed 26 rows and 15 columns (presolve time = 88s) ...
# Presolve removed 26 rows and 15 columns
# Presolve time: 87.99s
# Presolved: 15974 rows, 11985 columns, 23957997 nonzeros
# Variable types: 0 continuous, 11985 integer (11985 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6280000e+03   0.000000e+00   5.544000e+03     97s
#     4516    2.7682235e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.768223e+03, 4516 iterations, 8.90 seconds
# Total elapsed time = 106.48s
# Total elapsed time = 110.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2768.22349    0   93 2628.00000 2768.22349  5.34%     -  113s
# H    0     0                    2762.0000000 2768.22349  0.23%     -  114s
# H    0     0                    2766.0000000 2768.22349  0.08%     -  114s
# H    0     0                    2767.0000000 2768.22349  0.04%     -  121s
#      0     0     cutoff    0      2767.00000 2767.00000  0.00%     -  206s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 52
#   MIR: 132
#   StrongCG: 73
#   GUB cover: 36
#   RLT: 3
#
# Explored 1 nodes (9062 simplex iterations) in 206.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2767 2766 2762 2628
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.767000000000e+03, best bound 2.767000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4x4

# %%
datafile="3x4000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xd4577d74
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2619.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 23s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 27s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 43s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 75s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 80s) ...
# Presolve removed 33 rows and 18 columns (presolve time = 88s) ...
# Presolve removed 33 rows and 18 columns
# Presolve time: 87.89s
# Presolved: 15967 rows, 11982 columns, 23946003 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6280000e+03   0.000000e+00   5.588750e+03     96s
#     5189    2.7702216e+03   0.000000e+00   0.000000e+00    100s
# Concurrent spin time: 0.11s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.770222e+03, 5189 iterations, 9.68 seconds
# Total elapsed time = 106.60s
# Total elapsed time = 110.67s
# Total elapsed time = 118.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2770.22165    0  188 2619.00000 2770.22165  5.77%     -  120s
# H    0     0                    2754.0000000 2770.22165  0.59%     -  121s
# H    0     0                    2767.0000000 2770.22165  0.12%     -  121s
# H    0     0                    2768.0000000 2770.22165  0.08%     -  124s
# H    0     0                    2769.0000000 2770.22165  0.04%     -  131s
#      0     0 2770.20615    0  194 2769.00000 2770.20615  0.04%     -  220s
#      0     0 2770.19591    0  210 2769.00000 2770.19591  0.04%     -  238s
#      0     0 2770.18798    0  211 2769.00000 2770.18798  0.04%     -  244s
#      0     0 2770.18798    0  212 2769.00000 2770.18798  0.04%     -  249s
#      0     0 2769.99766    0  198 2769.00000 2769.99766  0.04%     -  267s
#      0     0 2769.99766    0  186 2769.00000 2769.99766  0.04%     -  273s
#      0     0     cutoff    0      2769.00000 2769.00000  0.00%     -  288s
#
# Cutting planes:
#   Gomory: 23
#   Cover: 2
#   MIR: 215
#   StrongCG: 3
#   RLT: 2
#
# Explored 1 nodes (10358 simplex iterations) in 289.19 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2769 2768 2767 ... 2619
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.769000000000e+03, best bound 2.769000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4x5

# %%
datafile="3x4000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x3957fbfe
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 2639.0000000
# Presolve removed 21 rows and 9 columns (presolve time = 10s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 15s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 31s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 35s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 40s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 70s) ...
# Presolve removed 21 rows and 9 columns (presolve time = 76s) ...
# Presolve removed 21 rows and 9 columns
# Presolve time: 75.87s
# Presolved: 15979 rows, 11991 columns, 23981982 nonzeros
# Variable types: 0 continuous, 11991 integer (11991 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6390000e+03   0.000000e+00   5.595500e+03     84s
#     3006    2.7329024e+03   0.000000e+00   1.850425e+02     85s
#     4908    2.7718572e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.771857e+03, 4908 iterations, 8.65 seconds
# Total elapsed time = 94.02s
# Total elapsed time = 98.17s
# Total elapsed time = 101.71s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2771.85719    0  141 2639.00000 2771.85719  5.03%     -  104s
# H    0     0                    2754.0000000 2771.85719  0.65%     -  105s
# H    0     0                    2769.0000000 2771.85719  0.10%     -  105s
# H    0     0                    2770.0000000 2771.85719  0.07%     -  108s
# H    0     0                    2771.0000000 2771.85719  0.03%     -  111s
#      0     0 2771.85719    0  141 2771.00000 2771.85719  0.03%     -  111s
#
# Explored 1 nodes (11237 simplex iterations) in 111.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2771 2770 2769 ... 2639
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.771000000000e+03, best bound 2.771000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4.5x1

# %%
datafile="3x4000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x5fabad0c
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2443.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 11s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 31s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 40s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 76s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 75.97s
# Presolved: 15970 rows, 11982 columns, 23946012 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4430000e+03   0.000000e+00   5.707000e+03     84s
#     1642    2.4738612e+03   0.000000e+00   6.574943e+02     85s
#     4871    2.5906935e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.590693e+03, 4871 iterations, 8.93 seconds
# Total elapsed time = 93.56s
# Total elapsed time = 97.37s
# Total elapsed time = 100.43s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2590.69345    0  114 2443.00000 2590.69345  6.05%     -  103s
# H    0     0                    2581.0000000 2590.69345  0.38%     -  104s
# H    0     0                    2585.0000000 2590.69345  0.22%     -  104s
# H    0     0                    2589.0000000 2590.69345  0.07%     -  107s
# H    0     0                    2590.0000000 2590.69345  0.03%     -  109s
#      0     0 2590.69345    0  114 2590.00000 2590.69345  0.03%     -  109s
#
# Explored 1 nodes (11113 simplex iterations) in 109.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2590 2589 2585 ... 2443
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.590000000000e+03, best bound 2.590000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4.5x2

# %%
datafile="3x4000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x548b795c
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2462.0000000
# Presolve removed 51 rows and 36 columns (presolve time = 10s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 23s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 27s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 43s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 50s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 55s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 60s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 54 rows and 36 columns (presolve time = 88s) ...
# Presolve removed 54 rows and 36 columns
# Presolve time: 87.71s
# Presolved: 15946 rows, 11964 columns, 23874147 nonzeros
# Variable types: 0 continuous, 11964 integer (11964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4660000e+03   0.000000e+00   5.650500e+03     96s
#     4439    2.6014662e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.601466e+03, 4439 iterations, 8.42 seconds
# Total elapsed time = 105.42s
# Total elapsed time = 113.81s
# Total elapsed time = 115.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2601.46624    0  151 2462.00000 2601.46624  5.66%     -  117s
# H    0     0                    2589.0000000 2601.46624  0.48%     -  117s
# H    0     0                    2597.0000000 2601.46624  0.17%     -  118s
# H    0     0                    2599.0000000 2601.46624  0.09%     -  121s
# H    0     0                    2600.0000000 2601.46624  0.06%     -  122s
#      0     0 2601.21744    0  164 2600.00000 2601.21744  0.05%     -  219s
#      0     0 2601.21474    0  158 2600.00000 2601.21474  0.05%     -  233s
#      0     0 2601.21474    0  157 2600.00000 2601.21474  0.05%     -  237s
#      0     0 2601.04477    0  149 2600.00000 2601.04477  0.04%     -  256s
#      0     0 2601.04399    0  145 2600.00000 2601.04399  0.04%     -  265s
#      0     0 2601.04399    0  142 2600.00000 2601.04399  0.04%     -  268s
#      0     0     cutoff    0      2600.00000 2600.00000  0.00%     -  282s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 9
#   MIR: 110
#   StrongCG: 8
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (11588 simplex iterations) in 282.29 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2600 2599 2597 ... 2462
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+03, best bound 2.600000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4.5x3

# %%
datafile="3x4000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xfb1b26a7
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2465.0000000
# Presolve removed 22 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 31s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 22 rows and 12 columns (presolve time = 76s) ...
# Presolve removed 22 rows and 12 columns
# Presolve time: 75.96s
# Presolved: 15978 rows, 11988 columns, 23969985 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4690000e+03   0.000000e+00   5.660000e+03     84s
#     2996    2.5804011e+03   0.000000e+00   6.305283e+01     85s
#     4742    2.6151189e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.615119e+03, 4742 iterations, 8.54 seconds
# Total elapsed time = 93.91s
# Total elapsed time = 98.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2615.11895    0   80 2465.00000 2615.11895  6.09%     -  100s
# H    0     0                    2606.0000000 2615.11895  0.35%     -  101s
# H    0     0                    2613.0000000 2615.11895  0.08%     -  101s
# H    0     0                    2614.0000004 2615.11895  0.04%     -  106s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 2
#   MIR: 73
#   StrongCG: 56
#   GUB cover: 2
#
# Explored 1 nodes (9941 simplex iterations) in 166.52 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2614 2613 2606 2465
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.614000000248e+03, best bound 2.614000000248e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4.5x4

# %%
datafile="3x4000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x9d83dca9
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2444.0000000
# Presolve removed 37 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 15s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 31s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 50s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 55s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 60s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 65s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 70s) ...
# Presolve removed 37 rows and 21 columns (presolve time = 76s) ...
# Presolve removed 37 rows and 21 columns
# Presolve time: 75.93s
# Presolved: 15963 rows, 11979 columns, 23934024 nonzeros
# Variable types: 0 continuous, 11979 integer (11979 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4500000e+03   0.000000e+00   5.631500e+03     84s
#     2396    2.5308456e+03   0.000000e+00   3.307724e+02     85s
#     4515    2.5887798e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.588780e+03, 4515 iterations, 8.62 seconds
# Total elapsed time = 93.44s
# Total elapsed time = 96.77s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2588.77983    0  152 2444.00000 2588.77983  5.92%     -  100s
# H    0     0                    2576.0000000 2588.77983  0.50%     -  101s
# H    0     0                    2586.0000000 2588.77983  0.11%     -  101s
# H    0     0                    2587.0000000 2588.77983  0.07%     -  107s
#      0     0 2588.67003    0  155 2587.00000 2588.67003  0.06%     -  122s
#      0     0 2588.66238    0  147 2587.00000 2588.66238  0.06%     -  142s
#      0     0 2588.66238    0  148 2587.00000 2588.66238  0.06%     -  146s
#      0     0 2588.49597    0  121 2587.00000 2588.49597  0.06%     -  165s
#      0     0 2588.49596    0  123 2587.00000 2588.49596  0.06%     -  175s
#      0     0 2588.32870    0  116 2587.00000 2588.32870  0.05%     -  195s
#      0     0 2588.32838    0  104 2587.00000 2588.32838  0.05%     -  208s
#      0     0 2588.32838    0  107 2587.00000 2588.32838  0.05%     -  213s
#      0     0 2588.31233    0  110 2587.00000 2588.31233  0.05%     -  231s
#      0     0 2588.31233    0   98 2587.00000 2588.31233  0.05%     -  240s
#      0     0 2588.31114    0  110 2587.00000 2588.31114  0.05%     -  257s
#      0     0 2588.31113    0  102 2587.00000 2588.31113  0.05%     -  263s
#      0     0 2588.26205    0  101 2587.00000 2588.26205  0.05%     -  279s
#      0     0 2588.26195    0   93 2587.00000 2588.26195  0.05%     -  288s
#      0     0 2588.26195    0  100 2587.00000 2588.26195  0.05%     -  303s
#      0     0 2588.26195    0   97 2587.00000 2588.26195  0.05%     -  314s
#      0     0 2588.26195    0   88 2587.00000 2588.26195  0.05%     -  329s
#      0     0 2588.26195    0  108 2587.00000 2588.26195  0.05%     -  339s
#      0     0 2588.26195    0   85 2587.00000 2588.26195  0.05%     -  370s
#      0     0 2588.26195    0   84 2587.00000 2588.26195  0.05%     -  381s
#      0     0 2588.26195    0   81 2587.00000 2588.26195  0.05%     -  410s
#      0     0 2588.26195    0   81 2587.00000 2588.26195  0.05%     -  419s
#      0     0 2588.26195    0  169 2587.00000 2588.26195  0.05%     -  498s
#      0     0 2588.26195    0  119 2587.00000 2588.26195  0.05%     -  514s
#      0     0 2588.26195    0  116 2587.00000 2588.26195  0.05%     -  524s
#      0     0 2588.26195    0  107 2587.00000 2588.26195  0.05%     -  527s
#      0     0 2588.24554    0  104 2587.00000 2588.24554  0.05%     -  531s
#      0     0 2588.24554    0  106 2587.00000 2588.24554  0.05%     -  534s
#      0     0 2588.24554    0  114 2587.00000 2588.24554  0.05%     -  545s
#      0     0 2588.24019    0  116 2587.00000 2588.24019  0.05%     -  552s
#      0     0 2588.24019    0  123 2587.00000 2588.24019  0.05%     -  555s
#      0     0 2588.24019    0  114 2587.00000 2588.24019  0.05%     -  568s
#      0     0 2588.24019    0  108 2587.00000 2588.24019  0.05%     -  577s
#      0     0 2588.24019    0  110 2587.00000 2588.24019  0.05%     -  589s
#      0     0 2588.24019    0  109 2587.00000 2588.24019  0.05%     -  596s
#      0     0 2588.24019    0   86 2587.00000 2588.24019  0.05%     -  623s
#      0     0 2588.24019    0   98 2587.00000 2588.24019  0.05%     -  631s
#      0     0 2588.24019    0   98 2587.00000 2588.24019  0.05%     -  647s
#      0     0 2588.24019    0  107 2587.00000 2588.24019  0.05%     -  654s
#      0     0 2588.24019    0   99 2587.00000 2588.24019  0.05%     -  673s
#      0     0 2588.24019    0   97 2587.00000 2588.24019  0.05%     -  679s
#      0     0 2588.23600    0   91 2587.00000 2588.23600  0.05%     -  706s
#      0     0 2588.23600    0   90 2587.00000 2588.23600  0.05%     -  718s
#      0     2 2588.23600    0   88 2587.00000 2588.23600  0.05%     -  784s
#      1     5 2588.23280    1   84 2587.00000 2588.23280  0.05%   887  787s
#      3     8 2588.18719    2   94 2587.00000 2588.22449  0.05%   318  791s
#      7    14 2588.17064    3   92 2587.00000 2588.22447  0.05%   157  796s
#     31    38 2588.15584    6   81 2587.00000 2588.22447  0.05%  43.1  802s
#     45    63 2588.14570    9   88 2587.00000 2588.22447  0.05%  31.8  807s
#     62    93 2588.13998   11   73 2587.00000 2588.22447  0.05%  25.2  812s
#     92   153 2588.13995   14   73 2587.00000 2588.22447  0.05%  18.7  822s
#    153   264 2588.13867   23   70 2587.00000 2588.22447  0.05%  12.8  843s
#    280   456 2588.10745   37   72 2587.00000 2588.22447  0.05%   9.0  884s
#    480   676 2588.10670   65   70 2587.00000 2588.22447  0.05%   7.2  928s
#    700   760 2588.10586  101   71 2587.00000 2588.22447  0.05%   6.3 1013s
#    784  1182 2588.10448  145   73 2587.00000 2588.22447  0.05%   6.0 1083s
#   1206  1319 2588.10304  194   75 2587.00000 2588.22447  0.05%   5.1 1140s
#   1343  1796 2588.10119  238   69 2587.00000 2588.22447  0.05%   5.0 1215s
#   1820  2118 2588.09930  293   73 2587.00000 2588.22447  0.05%   4.6 1281s
#   2196  2664 2588.08302  349   72 2587.00000 2588.22447  0.05%   4.5 1380s
#   2822  3460 2588.01526  434   40 2587.00000 2588.22447  0.05%   4.6 1481s
#   3713  4127 2588.01022  510   46 2587.00000 2588.22447  0.05%   4.5 1575s
#   4515  4128 2588.04953   31   81 2587.00000 2588.22447  0.05%   4.4 1943s
#   4517  4129 2588.03556   41  128 2587.00000 2588.22447  0.05%   4.4 2135s
#   4518  4130 2588.05731  437  122 2587.00000 2588.22447  0.05%   4.4 2144s
#   4519  4131 2588.03432   93  126 2587.00000 2588.22447  0.05%   4.4 2172s
#   4520  4131 2588.03017   44  109 2587.00000 2588.22447  0.05%   4.4 2178s
#   4521  4132 2588.03224  326  113 2587.00000 2588.22447  0.05%   4.4 2309s
#   4522  4133 2588.05571  333  111 2587.00000 2588.22447  0.05%   4.4 2321s
#   4523  4133 2588.14082   34  110 2587.00000 2588.22447  0.05%   4.4 2349s
#   4524  4134 2588.07989  121  112 2587.00000 2588.22447  0.05%   4.4 2466s
#   4525  4135 2588.08130  106   98 2587.00000 2588.22116  0.05%   4.4 2476s
#   4526  4135 2588.04522  339   99 2587.00000 2588.22116  0.05%   4.4 2613s
#   4527  4136 2587.99959  200  106 2587.00000 2588.21968  0.05%   4.4 2621s
#   4528  4137 2588.09688   72   86 2587.00000 2588.21968  0.05%   4.4 2685s
#   4529  4137 2588.01055  343   76 2587.00000 2588.21968  0.05%   4.4 2694s
#   4530  4138 2588.00732   35   88 2587.00000 2588.20987  0.05%   4.4 2704s
#   4531  4139 2588.07117   63   87 2587.00000 2588.20987  0.05%   4.4 2769s
#   4532  4139 2588.05538  341   76 2587.00000 2588.20987  0.05%   4.4 2857s
#   4533  4140 2588.09625  169   75 2587.00000 2588.20987  0.05%   4.4 2929s
#   4534  4141 2588.02851   66   80 2587.00000 2588.20987  0.05%   4.4 2939s
#   4535  4141 2588.01160  229   84 2587.00000 2588.20987  0.05%   4.4 3005s
#   4536  4142 2588.06104  286   69 2587.00000 2588.20987  0.05%   4.4 3085s
#   4537  4143 2588.16125   17   74 2587.00000 2588.20987  0.05%   4.4 3148s
#   4538  4143 2587.99910  364   73 2587.00000 2588.20987  0.05%   4.4 3219s
#   4539  4144 2588.08080  118   81 2587.00000 2588.20987  0.05%   4.4 3287s
#   4540  4145 2588.03044  158   64 2587.00000 2588.20987  0.05%   4.4 3383s
#   4541  4145 2588.11191   54   70 2587.00000 2588.20987  0.05%   4.4 3452s
#   4542  4146 2588.03679  108   63 2587.00000 2588.20987  0.05%   4.4 3541s
#
# Cutting planes:
#   Gomory: 29
#   Cover: 39
#   MIR: 88
#   StrongCG: 37
#   Flow cover: 78
#   GUB cover: 2
#   Zero half: 1
#   RLT: 3
#
# Explored 4542 nodes (70387 simplex iterations) in 3603.42 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2587 2586 2576 2444
#
# Time limit reached
# Best objective 2.587000000000e+03, best bound 2.588000000000e+03, gap 0.0387%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x4.5x5

# %%
datafile="3x4000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xd7d631d4
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2449.0000000
# Presolve removed 19 rows and 12 columns (presolve time = 10s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 15s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 31s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 35s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 40s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 76s) ...
# Presolve removed 19 rows and 12 columns
# Presolve time: 75.97s
# Presolved: 15981 rows, 11988 columns, 23970000 nonzeros
# Variable types: 0 continuous, 11988 integer (11988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4650000e+03   0.000000e+00   5.667500e+03     85s
#     1544    2.4917905e+03   0.000000e+00   3.120221e+02     85s
#     4454    2.6004502e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.600450e+03, 4454 iterations, 9.02 seconds
# Total elapsed time = 93.57s
# Total elapsed time = 96.88s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2600.45023    0   94 2449.00000 2600.45023  6.18%     -   99s
# H    0     0                    2593.0000000 2600.45023  0.29%     -  100s
# H    0     0                    2598.0000000 2600.45023  0.09%     -  100s
# H    0     0                    2599.0000000 2600.45023  0.06%     -  103s
#      0     0 2600.45001    0   96 2599.00000 2600.45001  0.06%     -  204s
# H    0     0                    2600.0000000 2600.45001  0.02%     -  218s
#      0     0 2600.45001    0   96 2600.00000 2600.45001  0.02%     -  218s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 2
#   MIR: 7
#   StrongCG: 2
#   RLT: 3
#
# Explored 1 nodes (8080 simplex iterations) in 218.32 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2600 2599 2598 ... 2449
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+03, best bound 2.600000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x5x1

# %%
datafile="3x4000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x3e1f17d3
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2327.0000000
# Presolve removed 39 rows and 27 columns (presolve time = 10s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 15s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 31s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 35s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 40s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 45s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 50s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 55s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 60s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 65s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 70s) ...
# Presolve removed 39 rows and 27 columns (presolve time = 76s) ...
# Presolve removed 39 rows and 27 columns
# Presolve time: 75.59s
# Presolved: 15961 rows, 11973 columns, 23910093 nonzeros
# Variable types: 0 continuous, 11973 integer (11973 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3270000e+03   0.000000e+00   5.730500e+03     84s
#     3079    2.4464798e+03   0.000000e+00   1.247598e+02     85s
#     4147    2.4637308e+03   0.000000e+00   0.000000e+00     86s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.463731e+03, 4147 iterations, 8.28 seconds
# Total elapsed time = 92.30s
# Total elapsed time = 95.93s
# Total elapsed time = 100.64s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2463.73080    0  182 2327.00000 2463.73080  5.88%     -  102s
# H    0     0                    2445.0000000 2463.73080  0.77%     -  102s
# H    0     0                    2460.0000000 2463.73080  0.15%     -  103s
# H    0     0                    2461.0000000 2463.73080  0.11%     -  108s
#      0     0 2463.70877    0  207 2461.00000 2463.70877  0.11%     -  125s
# H    0     0                    2463.0000000 2463.70877  0.03%     -  137s
#      0     0 2463.70877    0  207 2463.00000 2463.70877  0.03%     -  137s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 2
#   MIR: 60
#
# Explored 1 nodes (9221 simplex iterations) in 138.09 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2463 2461 2460 ... 2327
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.463000000000e+03, best bound 2.463000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x5x2

# %%
datafile="3x4000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xb4181847
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2330.0000000
# Presolve removed 32 rows and 15 columns (presolve time = 11s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 15s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 31s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 35s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 40s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 45s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 50s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 55s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 60s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 65s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 70s) ...
# Presolve removed 32 rows and 15 columns (presolve time = 76s) ...
# Presolve removed 32 rows and 15 columns
# Presolve time: 76.18s
# Presolved: 15968 rows, 11985 columns, 23957979 nonzeros
# Variable types: 0 continuous, 11985 integer (11985 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3300000e+03   0.000000e+00   5.749750e+03     84s
#     2263    2.3974400e+03   0.000000e+00   3.928618e+02     85s
#     4836    2.4636692e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.10s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.463669e+03, 4836 iterations, 8.68 seconds
# Total elapsed time = 93.59s
# Total elapsed time = 97.48s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2463.66922    0  145 2330.00000 2463.66922  5.74%     -  101s
# H    0     0                    2451.0000000 2463.66922  0.52%     -  101s
# H    0     0                    2461.0000000 2463.66922  0.11%     -  101s
# H    0     0                    2462.0000000 2463.66922  0.07%     -  105s
#      0     0 2463.63905    0  139 2462.00000 2463.63905  0.07%     -  125s
# H    0     0                    2463.0000000 2463.63905  0.03%     -  139s
#      0     0 2463.63905    0  139 2463.00000 2463.63905  0.03%     -  139s
#
# Cutting planes:
#   Gomory: 15
#   MIR: 27
#   RLT: 1
#
# Explored 1 nodes (10835 simplex iterations) in 139.91 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2463 2462 2461 ... 2330
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.463000000000e+03, best bound 2.463000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x5x3

# %%
datafile="3x4000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x2c33c101
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2318.0000000
# Presolve removed 63 rows and 45 columns (presolve time = 10s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 15s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 23s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 27s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 43s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 45s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 50s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 55s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 60s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 65s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 70s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 75s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 80s) ...
# Presolve removed 63 rows and 45 columns (presolve time = 88s) ...
# Presolve removed 63 rows and 45 columns
# Presolve time: 88.09s
# Presolved: 15937 rows, 11955 columns, 23838264 nonzeros
# Variable types: 0 continuous, 11955 integer (11955 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3110000e+03   0.000000e+00   5.728000e+03     96s
#     4671    2.4611194e+03   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.461119e+03, 4671 iterations, 8.40 seconds
# Total elapsed time = 104.80s
# Total elapsed time = 109.16s
# Total elapsed time = 112.68s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2461.11945    0  155 2318.00000 2461.11945  6.17%     -  116s
# H    0     0                    2446.0000000 2461.11945  0.62%     -  117s
# H    0     0                    2456.0000000 2461.11945  0.21%     -  117s
# H    0     0                    2458.0000000 2461.11945  0.13%     -  120s
# H    0     0                    2459.0000000 2461.11945  0.09%     -  126s
#      0     0 2460.82972    0  119 2459.00000 2460.82972  0.07%     -  221s
# H    0     0                    2460.0000000 2460.82972  0.03%     -  238s
#      0     0 2460.82972    0  119 2460.00000 2460.82972  0.03%     -  238s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 16
#   MIR: 37
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (11116 simplex iterations) in 238.40 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2460 2459 2458 ... 2318
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.460000000000e+03, best bound 2.460000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x5x4

# %%
datafile="3x4000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0xf0ee21a9
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2300.0000000
# Presolve removed 30 rows and 18 columns (presolve time = 10s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 15s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 31s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 35s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 40s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 45s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 50s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 55s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 60s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 65s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 70s) ...
# Presolve removed 30 rows and 18 columns (presolve time = 76s) ...
# Presolve removed 30 rows and 18 columns
# Presolve time: 75.79s
# Presolved: 15970 rows, 11982 columns, 23946009 nonzeros
# Variable types: 0 continuous, 11982 integer (11982 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3000000e+03   0.000000e+00   5.689250e+03     84s
#     2565    2.3996398e+03   0.000000e+00   2.397055e+02     85s
#     4213    2.4377562e+03   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 0.13s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.437756e+03, 4213 iterations, 8.57 seconds
# Total elapsed time = 92.83s
# Total elapsed time = 96.36s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2437.75618    0  107 2300.00000 2437.75618  5.99%     -  100s
# H    0     0                    2432.0000000 2437.75618  0.24%     -  100s
# H    0     0                    2434.0000000 2437.75618  0.15%     -  103s
# H    0     0                    2435.0000000 2437.75618  0.11%     -  104s
# H    0     0                    2436.0000000 2437.75618  0.07%     -  108s
#      0     0 2437.75618    0  111 2436.00000 2437.75618  0.07%     -  200s
#      0     0 2437.66015    0   99 2436.00000 2437.66015  0.07%     -  219s
#      0     0 2437.66003    0  100 2436.00000 2437.66003  0.07%     -  224s
#      0     0 2437.46495    0   81 2436.00000 2437.46495  0.06%     -  248s
#      0     0 2437.41756    0   83 2436.00000 2437.41756  0.06%     -  266s
#      0     0 2437.21118    0   83 2436.00000 2437.21118  0.05%     -  283s
#      0     0 2437.19704    0   89 2436.00000 2437.19704  0.05%     -  296s
#      0     0 2437.19704    0   91 2436.00000 2437.19704  0.05%     -  300s
#      0     0 2437.11674    0   81 2436.00000 2437.11674  0.05%     -  331s
#      0     0 2437.11674    0  107 2436.00000 2437.11674  0.05%     -  380s
#      0     0 2437.11674    0   85 2436.00000 2437.11674  0.05%     -  391s
#      0     0 2437.10824    0   73 2436.00000 2437.10824  0.05%     -  397s
#      0     0 2437.10824    0   68 2436.00000 2437.10824  0.05%     -  399s
#      0     0 2437.10824    0   69 2436.00000 2437.10824  0.05%     -  406s
#      0     0 2437.10824    0   70 2436.00000 2437.10824  0.05%     -  409s
#      0     0 2437.10778    0   77 2436.00000 2437.10778  0.05%     -  417s
#      0     0 2437.10778    0   76 2436.00000 2437.10778  0.05%     -  421s
#      0     0 2437.10778    0   78 2436.00000 2437.10778  0.05%     -  428s
#      0     0 2437.10274    0   71 2436.00000 2437.10274  0.05%     -  432s
#      0     0 2437.10274    0   73 2436.00000 2437.10274  0.05%     -  434s
#      0     0 2437.10274    0   48 2436.00000 2437.10274  0.05%     -  449s
#      0     0 2437.10274    0   54 2436.00000 2437.10274  0.05%     -  454s
#      0     0 2437.10274    0   64 2436.00000 2437.10274  0.05%     -  461s
#      0     0 2437.10274    0   56 2436.00000 2437.10274  0.05%     -  464s
#      0     0 2437.10274    0   58 2436.00000 2437.10274  0.05%     -  475s
#      0     0 2437.10274    0   56 2436.00000 2437.10274  0.05%     -  479s
#      0     0 2437.10274    0   46 2436.00000 2437.10274  0.05%     -  489s
#      0     0 2437.10274    0   40 2436.00000 2437.10274  0.05%     -  497s
#      0     2 2437.10274    0   40 2436.00000 2437.10274  0.05%     -  513s
#      1     5 2437.10274    1   39 2436.00000 2437.10274  0.05%   488  515s
#      7    14 2437.10251    3   59 2436.00000 2437.10274  0.05%  91.6  521s
#     13    20 2437.10251    4   48 2436.00000 2437.10274  0.05%  60.0  525s
#     19    26 2437.10227    5   48 2436.00000 2437.10274  0.05%  47.4  531s
#     31    38 2437.10141    7   52 2436.00000 2437.10274  0.05%  32.4  539s
#     37    44 2437.10141    8   50 2436.00000 2437.10274  0.05%  28.0  541s
#     43    75 2437.10112    9   42 2436.00000 2437.10274  0.05%  25.3  545s
#     74    95 2437.10105   11   35 2436.00000 2437.10274  0.05%  16.8  552s
#     94   179 2437.09908   13   40 2436.00000 2437.10274  0.05%  14.9  564s
#    178   340 2437.10099   21   45 2436.00000 2437.10274  0.05%  10.2  591s
#    339   697 2437.09652   41   48 2436.00000 2437.10274  0.05%   7.4  649s
#    696   953 2437.09155   96   39 2436.00000 2437.10274  0.05%   5.6  692s
#    952  1275 2437.08732  133   43 2436.00000 2437.10274  0.05%   5.1  739s
#   1274  1680 2437.08327  184   39 2436.00000 2437.10274  0.05%   4.7  790s
#   1679  1987 2437.07559  254   39 2436.00000 2437.10274  0.05%   4.5  840s
#   1986  2101 2437.07434  304   35 2436.00000 2437.10274  0.05%   4.0 1143s
#   2100  2351 2437.07404  323   35 2436.00000 2437.10274  0.05%   3.9 1200s
#   2350  2488 2437.07353  363   35 2436.00000 2437.10274  0.05%   3.6 1271s
#   2496  3308 2437.07267  407   35 2436.00000 2437.10274  0.05%   3.5 1364s
#   3428  3187 2437.00000  519   24 2436.00000 2437.10273  0.05%   3.6 1458s
#   4297  3044     cutoff   15      2436.00000 2437.10154  0.05%   6.6 1561s
#   4712  3044 2437.06365   15   45 2436.00000 2437.10154  0.05%   6.8 1566s
#   5031  3044 2437.10114   23   40 2436.00000 2437.10114  0.05%   7.0 1570s
#   5116  2881     cutoff   23      2436.00000 2437.10067  0.05%   7.0 1657s
#   5215  2881 2437.09334   60   38 2436.00000 2437.10067  0.05%   7.1 1660s
#   5609  2881     cutoff   22      2436.00000 2437.10050  0.05%   7.3 1670s
#   5707  2693     cutoff   62      2436.00000 2437.09342  0.04%   7.4 1763s
#   5738  2693 2437.09034   44   35 2436.00000 2437.09323  0.04%   7.4 1765s
#   5982  2693 2437.08836   58   39 2436.00000 2437.09299  0.04%   7.7 1774s
#   6008  2693 2437.09175   40   33 2436.00000 2437.09299  0.04%   7.7 1775s
#   6251  2458 2437.08626   85   38 2436.00000 2437.08770  0.04%   7.9 1909s
#   6464  2458 2437.08556   90   38 2436.00000 2437.08755  0.04%   8.1 1910s
#   6902  2239 2437.03932  122   42 2436.00000 2437.07754  0.04%   8.4 2031s
#   7558  1985     cutoff  156      2436.00000 2437.06826  0.04%   8.8 2168s
#   8335  1704     cutoff  188      2436.00000 2437.06127  0.04%   9.2 2309s
#   9136  1435 2437.04773  226   42 2436.00000 2437.05241  0.04%   9.5 2453s
#   9976  1168 2437.03043  253   51 2436.00000 2437.04042  0.04%   9.7 2592s
#  10868   887 2437.02595  306   47 2436.00000 2437.02680  0.04%  10.7 2734s
#  11811   603 2437.00430  371   43 2436.00000 2437.01585  0.04%  12.0 2875s
#  12780   266 2437.00207  376   46 2436.00000 2437.00997  0.04%  12.6 3015s
#  13210   266     cutoff  359      2436.00000 2437.00997  0.04%  13.3 3021s
#  13640   243 2437.00000  437   25 2436.00000 2437.00000  0.04%  14.2 3202s
#  13723   133     cutoff  438      2436.00000 2437.00000  0.04%  15.1 3311s
#  13775   133 2437.00000  476   29 2436.00000 2437.00000  0.04%  16.0 3315s
#  14055    77     cutoff  438      2436.00000 2437.00000  0.04%  20.9 3428s
#  14084    77 2437.00000  451   35 2436.00000 2437.00000  0.04%  21.2 3430s
#  14190    77 2437.00000  489   41 2436.00000 2437.00000  0.04%  22.3 3435s
#  14327    77 2437.00000  476   37 2436.00000 2437.00000  0.04%  23.2 3440s
#  14449     2 2437.00000  453   33 2436.00000 2437.00000  0.04%  24.0 3527s
#  14548     2 2437.00000  469   39 2436.00000 2437.00000  0.04%  24.6 3530s
#  14783     0     cutoff  420      2436.00000 2436.99849  0.04%  26.0 3536s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 4653
#   MIR: 109
#   StrongCG: 1
#
# Explored 14785 nodes (415438 simplex iterations) in 3537.21 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2436 2435 2434 ... 2300
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.436000000000e+03, best bound 2.436000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 3x4000x5x5

# %%
datafile="3x4000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=3
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 16000 rows, 12000 columns and 24018000 nonzeros
# Model fingerprint: 0x5f76de74
# Variable types: 0 continuous, 12000 integer (12000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2328.0000000
# Presolve removed 34 rows and 21 columns (presolve time = 10s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 15s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 31s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 35s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 40s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 45s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 50s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 55s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 60s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 65s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 70s) ...
# Presolve removed 34 rows and 21 columns (presolve time = 76s) ...
# Presolve removed 34 rows and 21 columns
# Presolve time: 75.68s
# Presolved: 15966 rows, 11979 columns, 23934033 nonzeros
# Variable types: 0 continuous, 11979 integer (11979 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3280000e+03   0.000000e+00   5.774500e+03     84s
#     3460    2.4625343e+03   0.000000e+00   4.143700e+01     85s
#     4267    2.4696281e+03   0.000000e+00   0.000000e+00     86s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.469628e+03, 4267 iterations, 8.29 seconds
# Total elapsed time = 92.17s
# Total elapsed time = 95.62s
# Total elapsed time = 100.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2469.62808    0  174 2328.00000 2469.62808  6.08%     -  101s
# H    0     0                    2455.0000000 2469.62808  0.60%     -  102s
# H    0     0                    2467.0000000 2469.62808  0.11%     -  102s
# H    0     0                    2468.0000000 2469.62808  0.07%     -  108s
#      0     0 2469.61985    0  199 2468.00000 2469.61985  0.07%     -  126s
#      0     0 2469.61299    0  191 2468.00000 2469.61299  0.07%     -  153s
#      0     0 2469.61298    0  198 2468.00000 2469.61298  0.07%     -  158s
#      0     0 2469.56921    0  177 2468.00000 2469.56921  0.06%     -  177s
#      0     0 2469.56921    0  162 2468.00000 2469.56921  0.06%     -  187s
#      0     0 2469.56716    0  138 2468.00000 2469.56716  0.06%     -  207s
#      0     0 2469.56568    0  137 2468.00000 2469.56568  0.06%     -  229s
#      0     0 2469.56450    0  136 2468.00000 2469.56450  0.06%     -  235s
#      0     0 2469.56450    0  140 2468.00000 2469.56450  0.06%     -  240s
#      0     0 2469.54850    0  141 2468.00000 2469.54850  0.06%     -  260s
#      0     0 2469.54783    0  122 2468.00000 2469.54783  0.06%     -  268s
#      0     0 2469.54783    0  133 2468.00000 2469.54783  0.06%     -  273s
#      0     0 2469.50417    0  127 2468.00000 2469.50417  0.06%     -  287s
#      0     0 2469.50372    0  133 2468.00000 2469.50372  0.06%     -  297s
#      0     0 2469.50372    0  127 2468.00000 2469.50372  0.06%     -  302s
#      0     0 2469.50306    0  122 2468.00000 2469.50306  0.06%     -  320s
#      0     0 2469.50306    0  128 2468.00000 2469.50306  0.06%     -  328s
#      0     0 2469.50306    0  121 2468.00000 2469.50306  0.06%     -  340s
#      0     0 2469.50306    0  125 2468.00000 2469.50306  0.06%     -  347s
#      0     0 2469.50306    0  104 2468.00000 2469.50306  0.06%     -  379s
#      0     0 2469.50306    0  115 2468.00000 2469.50306  0.06%     -  388s
#      0     0 2469.49297    0   97 2468.00000 2469.49297  0.06%     -  415s
# H    0     0                    2469.0000000 2469.49297  0.02%     -  423s
#      0     0 2469.49297    0   97 2469.00000 2469.49297  0.02%     -  423s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 35
#
# Explored 1 nodes (16597 simplex iterations) in 423.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2469 2468 2467 ... 2328
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.469000000000e+03, best bound 2.469000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x1.5x1

# %%
datafile="4x4000x1.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x1ee3a9c3
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 6 rows and 8 columns (presolve time = 6s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 14s) ...
# Presolve removed 18 rows and 8 columns (presolve time = 21s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 33s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 38s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 41s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 61s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 65s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 70s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 75s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 80s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 85s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 90s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 95s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 100s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 105s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 110s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 115s) ...
# Presolve removed 26 rows and 8 columns (presolve time = 122s) ...
# Presolve removed 26 rows and 8 columns
# Presolve time: 121.51s
# Presolved: 19974 rows, 15992 columns, 31991940 nonzeros
# Variable types: 0 continuous, 15992 integer (15992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   0.000000e+00   7.550250e+03    133s
# Concurrent spin time: 0.08s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3998 iterations, 10.46 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3998.00000 3998.00000  0.00%     -  135s
#
# Explored 0 nodes (3998 simplex iterations) in 135.72 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.998000000000e+03, best bound 3.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x1.5x2

# %%
datafile="4x4000x1.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x93b8705b
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3994.0000000
# Presolve removed 38 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 21s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 46s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 50s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 55s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 60s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 85s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 90s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 95s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 100s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 107s) ...
# Presolve removed 38 rows and 24 columns
# Presolve time: 107.31s
# Presolved: 19962 rows, 15976 columns, 31928020 nonzeros
# Variable types: 0 continuous, 15976 integer (15976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9940000e+03   0.000000e+00   7.499250e+03    120s
# Concurrent spin time: 1.39s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3994 iterations, 11.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3994.00000 3994.00000  0.00%     -  121s
#
# Explored 0 nodes (3994 simplex iterations) in 122.11 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.994000000000e+03, best bound 3.994000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x1.5x3

# %%
datafile="4x4000x1.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x119eda07
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 17 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 14s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 21s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 44s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 60s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 65s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 70s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 75s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 80s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 85s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 95s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 100s) ...
# Presolve removed 17 rows and 4 columns
# Presolve time: 104.46s
# Presolved: 19983 rows, 15996 columns, 32007972 nonzeros
# Variable types: 0 continuous, 15996 integer (15996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   0.000000e+00   7.620250e+03    116s
#     4086    3.9990000e+03   0.000000e+00   0.000000e+00    118s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.999000e+03, 4086 iterations, 10.42 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    3999.0000000 15996.0000   300%     -  119s
#      0     0          -    0      3999.00000 3999.00000  0.00%     -  124s
#
# Explored 0 nodes (8177 simplex iterations) in 125.20 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 2: 3999 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.999000000000e+03, best bound 3.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x1.5x4

# %%
datafile="4x4000x1.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x00c50d96
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3999.0000000
# Presolve removed 25 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 15s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 21s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 44s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 60s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 65s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 70s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 75s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 80s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 85s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 95s) ...
# Presolve removed 25 rows and 4 columns (presolve time = 100s) ...
# Presolve removed 25 rows and 4 columns
# Presolve time: 104.89s
# Presolved: 19975 rows, 15996 columns, 32007936 nonzeros
# Variable types: 0 continuous, 15996 integer (15996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9990000e+03   0.000000e+00   7.549500e+03    117s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3999 iterations, 10.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3999.00000 3999.00000  0.00%     -  118s
#
# Explored 0 nodes (3999 simplex iterations) in 118.83 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3999
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.999000000000e+03, best bound 3.999000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x1.5x5

# %%
datafile="4x4000x1.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xd2a58c7a
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3998.0000000
# Presolve removed 22 rows and 8 columns (presolve time = 6s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 14s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 21s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 44s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 45s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 50s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 55s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 60s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 65s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 70s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 75s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 80s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 85s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 90s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 95s) ...
# Presolve removed 22 rows and 8 columns (presolve time = 100s) ...
# Presolve removed 22 rows and 8 columns
# Presolve time: 104.97s
# Presolved: 19978 rows, 15992 columns, 31991972 nonzeros
# Variable types: 0 continuous, 15992 integer (15992 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9980000e+03   0.000000e+00   7.542750e+03    117s
# Concurrent spin time: 1.27s
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 3998 iterations, 10.80 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3998.00000 3998.00000  0.00%     -  119s
#
# Explored 0 nodes (3998 simplex iterations) in 119.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 1: 3998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.998000000000e+03, best bound 3.998000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2x1

# %%
datafile="4x4000x2x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x4b857bef
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3950.0000000
# Presolve removed 24 rows and 16 columns (presolve time = 6s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 14s) ...
# Presolve removed 24 rows and 16 columns (presolve time = 21s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 32s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 38s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 40s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 61s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 65s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 70s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 75s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 80s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 85s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 90s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 95s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 100s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 105s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 110s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 115s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 121s) ...
# Presolve removed 28 rows and 16 columns
# Presolve time: 121.01s
# Presolved: 19972 rows, 15984 columns, 31959984 nonzeros
# Variable types: 0 continuous, 15984 integer (15984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9500000e+03   0.000000e+00   7.602750e+03    133s
#     4589    3.9622771e+03   1.956024e+00   0.000000e+00    136s
#     4598    3.9622771e+03   0.000000e+00   0.000000e+00    136s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.962277e+03, 4598 iterations, 11.72 seconds
# Total elapsed time = 149.24s
# Total elapsed time = 157.21s
# Total elapsed time = 161.11s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3962.27707    0   56 3950.00000 3962.27707  0.31%     -  168s
# H    0     0                    3959.0000000 3962.27707  0.08%     -  169s
# H    0     0                    3960.0000000 3962.27707  0.06%     -  172s
#      0     0 3962.27707    0   60 3960.00000 3962.27707  0.06%     -  307s
# H    0     0                    3961.0000000 3962.27707  0.03%     -  316s
#      0     0 3962.27707    0   85 3961.00000 3962.27707  0.03%     -  330s
#      0     0 3962.27707    0   48 3961.00000 3962.27707  0.03%     -  382s
#      0     0 3962.22980    0   54 3961.00000 3962.22980  0.03%     -  395s
#      0     0 3962.22980    0   41 3961.00000 3962.22980  0.03%     -  437s
#      0     0 3962.06506    0   31 3961.00000 3962.06506  0.03%     -  460s
#      0     0 3962.06506    0   32 3961.00000 3962.06506  0.03%     -  482s
#      0     0 3962.06506    0   41 3961.00000 3962.06506  0.03%     -  495s
#      0     0 3962.06506    0   39 3961.00000 3962.06506  0.03%     -  517s
#      0     0 3962.06506    0   41 3961.00000 3962.06506  0.03%     -  537s
#      0     0 3962.06506    0   42 3961.00000 3962.06506  0.03%     -  570s
#      0     0 3962.06506    0   33 3961.00000 3962.06506  0.03%     -  583s
#      0     0 3962.06506    0   38 3961.00000 3962.06506  0.03%     -  617s
#      0     0 3962.06506    0   35 3961.00000 3962.06506  0.03%     -  634s
#      0     0 3962.06506    0   29 3961.00000 3962.06506  0.03%     -  671s
#      0     0 3962.06506    0   30 3961.00000 3962.06506  0.03%     -  684s
#      0     0 3962.06506    0   25 3961.00000 3962.06506  0.03%     -  726s
#      0     0 3962.06506    0   36 3961.00000 3962.06506  0.03%     -  740s
#      0     0 3962.06506    0   30 3961.00000 3962.06506  0.03%     -  780s
#      0     0 3962.06506    0   28 3961.00000 3962.06506  0.03%     -  798s
#      0     2 3962.06506    0   28 3961.00000 3962.06506  0.03%     -  871s
#      1     4 3962.03566    1   43 3961.00000 3962.06506  0.03%  3615  877s
#      3     6 infeasible    2      3961.00000 3962.06506  0.03%  1215  885s
#      7    12 3962.06506    3   40 3961.00000 3962.06506  0.03%   528  898s
#     13    18 3962.06506    4   35 3961.00000 3962.06506  0.03%   297  911s
#     19    24 3962.06506    5   34 3961.00000 3962.06506  0.03%   206  920s
#     25    30 3962.06506    6   35 3961.00000 3962.06506  0.03%   161  927s
#     31    36 3962.06506    7   35 3961.00000 3962.06506  0.03%   131  949s
# H   34    36                    3962.0000000 3962.06506  0.00%   120  949s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 35
#   MIR: 17
#   StrongCG: 47
#   RLT: 1
#
# Explored 37 nodes (78363 simplex iterations) in 951.53 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3962 3961 3960 ... 3950
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.962000000000e+03, best bound 3.962000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2x2

# %%
datafile="4x4000x2x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xac10a712
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3945.0000000
# Presolve removed 25 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 33s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 38s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 41s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 61s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 105s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 110s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 115s) ...
# Presolve removed 29 rows and 20 columns (presolve time = 121s) ...
# Presolve removed 29 rows and 20 columns
# Presolve time: 121.21s
# Presolved: 19971 rows, 15980 columns, 31944008 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9450000e+03   0.000000e+00   7.582500e+03    134s
#     5196    3.9547344e+03   6.784642e-05   0.000000e+00    136s
#     5197    3.9547344e+03   0.000000e+00   0.000000e+00    136s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.954734e+03, 5197 iterations, 11.80 seconds
# Total elapsed time = 149.43s
# Total elapsed time = 156.18s
# Total elapsed time = 162.71s
# Total elapsed time = 166.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3954.73438    0   97 3945.00000 3954.73438  0.25%     -  170s
# H    0     0                    3952.0000000 3954.73438  0.07%     -  170s
# H    0     0                    3953.0000000 3954.73438  0.04%     -  174s
#      0     0 3954.68446    0  115 3953.00000 3954.68446  0.04%     -  311s
# H    0     0                    3954.0000000 3954.68446  0.02%     -  336s
#      0     0 3954.68446    0  115 3954.00000 3954.68446  0.02%     -  336s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1
#   MIR: 22
#   StrongCG: 2
#   GUB cover: 4
#
# Explored 1 nodes (17695 simplex iterations) in 336.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3954 3953 3952 3945
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.954000000000e+03, best bound 3.954000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2x3

# %%
datafile="4x4000x2x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xb413c979
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3975.0000000
# Presolve removed 23 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 14s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 21s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 44s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 75s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 80s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 85s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 90s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 95s) ...
# Presolve removed 23 rows and 12 columns (presolve time = 104s) ...
# Presolve removed 23 rows and 12 columns
# Presolve time: 104.23s
# Presolved: 19977 rows, 15988 columns, 31975972 nonzeros
# Variable types: 0 continuous, 15988 integer (15988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9750000e+03   0.000000e+00   7.508500e+03    117s
#     4326    3.9807318e+03   0.000000e+00   0.000000e+00    119s
# Concurrent spin time: 0.10s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.980732e+03, 4326 iterations, 11.75 seconds
# Total elapsed time = 134.06s
# Total elapsed time = 141.79s
# Total elapsed time = 149.53s
# Total elapsed time = 153.12s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3980.73184    0   88 3975.00000 3980.73184  0.14%     -  155s
# H    0     0                    3978.0000000 3980.73184  0.07%     -  156s
# H    0     0                    3979.0000000 3980.73184  0.04%     -  160s
#      0     0 3980.72996    0   89 3979.00000 3980.72996  0.04%     -  297s
#      0     0 3980.72996    0   83 3979.00000 3980.72996  0.04%     -  322s
#      0     0 3980.72996    0   91 3979.00000 3980.72996  0.04%     -  345s
#      0     0 3980.63552    0   95 3979.00000 3980.63552  0.04%     -  358s
#      0     0 3980.63552    0   95 3979.00000 3980.63552  0.04%     -  365s
#      0     0 3980.50680    0   75 3979.00000 3980.50680  0.04%     -  415s
#      0     0 3980.50680    0   78 3979.00000 3980.50680  0.04%     -  440s
#      0     0 3980.50680    0   79 3979.00000 3980.50680  0.04%     -  463s
#      0     0 3980.50680    0   88 3979.00000 3980.50680  0.04%     -  478s
#      0     0 3980.50680    0   59 3979.00000 3980.50680  0.04%     -  538s
#      0     0 3980.50680    0   67 3979.00000 3980.50680  0.04%     -  557s
#      0     0 3980.50680    0   73 3979.00000 3980.50680  0.04%     -  592s
#      0     0 3980.50680    0   87 3979.00000 3980.50680  0.04%     -  606s
#      0     0 3980.50680    0   74 3979.00000 3980.50680  0.04%     -  647s
#      0     0 3980.50680    0   82 3979.00000 3980.50680  0.04%     -  664s
#      0     0 3980.50680    0   65 3979.00000 3980.50680  0.04%     -  711s
#      0     0 3980.50680    0   67 3979.00000 3980.50680  0.04%     -  725s
#      0     0 3980.50680    0   63 3979.00000 3980.50680  0.04%     -  774s
#      0     0 3980.50680    0   63 3979.00000 3980.50680  0.04%     -  793s
#      0     2 3980.50680    0   63 3979.00000 3980.50680  0.04%     -  882s
#      1     4 3980.30350    1   64 3979.00000 3980.50680  0.04%  3749  887s
#      3     8 3980.30349    2   71 3979.00000 3980.50680  0.04%  1275  895s
#      7    14 3980.26995    3   86 3979.00000 3980.50680  0.04%   574  908s
#     13    18     cutoff    4      3979.00000 3980.50664  0.04%   338  930s
#     19    24 3980.26995    4   92 3979.00000 3980.50535  0.04%   254  940s
#     25    30 3980.26995    5   92 3979.00000 3980.50535  0.04%   205  948s
#     31    36 3980.26995    6   92 3979.00000 3980.50535  0.04%   169  963s
#     37    43 3980.05641    7   87 3979.00000 3980.50535  0.04%   143  970s
#     44    50 3980.26995    7   93 3979.00000 3980.50535  0.04%   122  975s
#     51   100 3980.26995    8   91 3979.00000 3980.50535  0.04%   108 1031s
#    101   246 3980.01844   11   84 3979.00000 3980.50535  0.04%  59.2 1107s
#    249   435 3980.00484   30   53 3979.00000 3980.50535  0.04%  29.4 1219s
#    451   847 3980.50535    7   83 3979.00000 3980.50535  0.04%  19.6 1445s
#    865  1110 3980.00962   77   63 3979.00000 3980.50535  0.04%  14.2 1603s
#   1134  1561 3980.00962  119   65 3979.00000 3980.50535  0.04%  12.7 1829s
# H 1383   783                    3980.0000000 3980.50535  0.01%  11.8 1829s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 50
#   MIR: 76
#
# Explored 1629 nodes (100109 simplex iterations) in 1832.35 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3980 3979 3978 3975
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980000000000e+03, best bound 3.980000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2x4

# %%
datafile="4x4000x2x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x5eb0b50e
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3961.0000000
# Presolve removed 42 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 15s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 21s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 44s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 45s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 50s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 55s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 60s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 85s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 90s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 95s) ...
# Presolve removed 42 rows and 24 columns (presolve time = 104s) ...
# Presolve removed 42 rows and 24 columns
# Presolve time: 104.06s
# Presolved: 19958 rows, 15976 columns, 31928008 nonzeros
# Variable types: 0 continuous, 15976 integer (15976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9610000e+03   0.000000e+00   7.587000e+03    117s
#     4890    3.9695516e+03   0.000000e+00   0.000000e+00    119s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.969552e+03, 4890 iterations, 11.80 seconds
# Total elapsed time = 133.25s
# Total elapsed time = 140.90s
# Total elapsed time = 148.77s
# Total elapsed time = 152.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3969.55162    0   28 3961.00000 3969.55162  0.22%     -  156s
# H    0     0                    3967.0000000 3969.55162  0.06%     -  157s
# H    0     0                    3968.0000000 3969.55162  0.04%     -  161s
#      0     0 3969.55162    0   36 3968.00000 3969.55162  0.04%     -  183s
#      0     0 3969.55162    0   42 3968.00000 3969.55162  0.04%     -  201s
#      0     0 3969.55162    0   39 3968.00000 3969.55162  0.04%     -  244s
#      0     0 3969.55162    0   36 3968.00000 3969.55162  0.04%     -  258s
#      0     0 3969.55162    0   28 3968.00000 3969.55162  0.04%     -  304s
#      0     0 3969.47418    0   36 3968.00000 3969.47418  0.04%     -  340s
#      0     0 3969.47418    0   24 3968.00000 3969.47418  0.04%     -  383s
#      0     0 3969.31867    0   31 3968.00000 3969.31867  0.03%     -  397s
#      0     0 3969.31867    0   31 3968.00000 3969.31867  0.03%     -  403s
#      0     0 3969.31867    0   30 3968.00000 3969.31867  0.03%     -  425s
#      0     0 3969.31867    0   33 3968.00000 3969.31867  0.03%     -  436s
#      0     0 3969.31867    0   34 3968.00000 3969.31867  0.03%     -  456s
#      0     0 3969.31867    0   32 3968.00000 3969.31867  0.03%     -  471s
#      0     0 3969.31867    0   18 3968.00000 3969.31867  0.03%     -  520s
#      0     0 3969.31867    0   24 3968.00000 3969.31867  0.03%     -  548s
#      0     0 3969.31867    0   30 3968.00000 3969.31867  0.03%     -  583s
#      0     0 3969.31867    0   25 3968.00000 3969.31867  0.03%     -  596s
#      0     0 3969.31867    0   28 3968.00000 3969.31867  0.03%     -  625s
#      0     0 3969.31867    0   32 3968.00000 3969.31867  0.03%     -  634s
#      0     0 3969.31867    0   25 3968.00000 3969.31867  0.03%     -  678s
#      0     0 3969.31867    0   25 3968.00000 3969.31867  0.03%     -  698s
#      0     2 3969.31867    0   25 3968.00000 3969.31867  0.03%     -  828s
#      1     4 3969.31778    1   24 3968.00000 3969.31867  0.03%  5233  833s
#      3     8 3969.24869    2   20 3968.00000 3969.31867  0.03%  1751  842s
#      7    12     cutoff    3      3968.00000 3969.25378  0.03%   761  852s
#     13    18 3969.25378    4   25 3968.00000 3969.25378  0.03%   413  864s
#     19    23 3969.25378    5   28 3968.00000 3969.25378  0.03%   286  873s
#     25    29 3969.25378    6   26 3968.00000 3969.25378  0.03%   220  879s
#     31    32 3969.25378    7   27 3968.00000 3969.25378  0.03%   179  890s
#     38    37 3969.18572    8   20 3968.00000 3969.25378  0.03%   148  895s
#     44    55 3969.18572    9   20 3968.00000 3969.25378  0.03%   129  908s
#     68    63 3969.05118   14   19 3968.00000 3969.25378  0.03%  85.7  933s
#    114    75 3969.14552   19   19 3968.00000 3969.25378  0.03%  53.2  966s
#    176    79 3969.05118   26   17 3968.00000 3969.25378  0.03%  36.4  994s
#    199    79 3969.25378    7   32 3968.00000 3969.25378  0.03%  33.1  995s
#    200   123 3969.07979    9   13 3968.00000 3969.25378  0.03%  32.9 1044s
#    299   266 3969.03889   24   16 3968.00000 3969.25378  0.03%  23.7 1125s
#    503   449 3969.03889   56   14 3968.00000 3969.25378  0.03%  15.9 1258s
#    777   725 3969.03889   85   21 3968.00000 3969.25378  0.03%  11.6 1430s
#   1159  1026 3969.03889  129   19 3968.00000 3969.25378  0.03%   9.1 1607s
#   1526  1027 3969.03889   84   25 3968.00000 3969.25378  0.03%   7.9 1990s
#   1528  1028 3969.00000   22   74 3968.00000 3969.00000  0.03%   7.9 2748s
#   1529  1029 3969.00000   97   41 3968.00000 3969.00000  0.03%   7.9 3336s
#   1530  1030 3969.00000   22   37 3968.00000 3969.00000  0.03%   7.9 3383s
#   1531  1030 3969.00000  149   31 3968.00000 3969.00000  0.03%   7.9 3468s
#   1532  1031 3969.00000  125   42 3968.00000 3969.00000  0.03%   7.9 3529s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 10
#   MIR: 90
#   StrongCG: 20
#   Flow cover: 97
#   GUB cover: 2
#   RLT: 2
#
# Explored 1532 nodes (128356 simplex iterations) in 3607.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3968 3967 3961
#
# Time limit reached
# Best objective 3.968000000000e+03, best bound 3.969000000000e+03, gap 0.0252%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2x5

# %%
datafile="4x4000x2x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x0fe0381d
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Found heuristic solution: objective 3960.0000000
# Presolve removed 32 rows and 32 columns (presolve time = 6s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 21s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 25s) ...
# Presolve removed 44 rows and 32 columns (presolve time = 34s) ...
# Presolve removed 44 rows and 32 columns (presolve time = 39s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 51s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 56s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 79s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 80s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 85s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 90s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 95s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 100s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 105s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 110s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 115s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 120s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 125s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 130s) ...
# Presolve removed 48 rows and 32 columns (presolve time = 139s) ...
# Presolve removed 48 rows and 32 columns
# Presolve time: 139.20s
# Presolved: 19952 rows, 15968 columns, 31896052 nonzeros
# Variable types: 0 continuous, 15968 integer (15968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9590000e+03   0.000000e+00   7.533750e+03    152s
#     4656    3.9665699e+03   0.000000e+00   0.000000e+00    154s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.966570e+03, 4656 iterations, 11.82 seconds
# Total elapsed time = 169.29s
# Total elapsed time = 178.35s
# Total elapsed time = 188.35s
# Total elapsed time = 196.96s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3966.56994    0  190 3960.00000 3966.56994  0.17%     -  201s
# H    0     0                    3964.0000000 3966.56994  0.06%     -  206s
#      0     0 3966.55401    0  193 3964.00000 3966.55401  0.06%     -  342s
# H    0     0                    3965.0000000 3966.55401  0.04%     -  362s
#      0     0 3966.55325    0  188 3965.00000 3966.55325  0.04%     -  367s
#      0     0 3966.55325    0  179 3965.00000 3966.55325  0.04%     -  373s
#      0     0 3966.33102    0  163 3965.00000 3966.33102  0.03%     -  397s
#      0     0 3966.33092    0  160 3965.00000 3966.33092  0.03%     -  410s
#      0     0 3966.33092    0  154 3965.00000 3966.33092  0.03%     -  433s
#      0     0 3966.33092    0  145 3965.00000 3966.33092  0.03%     -  449s
#      0     0 3966.33092    0  159 3965.00000 3966.33092  0.03%     -  472s
#      0     0 3966.33086    0  163 3965.00000 3966.33086  0.03%     -  484s
#      0     0 3966.33086    0  157 3965.00000 3966.33086  0.03%     -  507s
#      0     0 3966.33082    0  149 3965.00000 3966.33082  0.03%     -  538s
#      0     0 3966.33066    0  138 3965.00000 3966.33066  0.03%     -  561s
#      0     0 3966.33066    0  143 3965.00000 3966.33066  0.03%     -  573s
#      0     0 3966.33066    0  145 3965.00000 3966.33066  0.03%     -  596s
#      0     0 3966.33062    0  160 3965.00000 3966.33062  0.03%     -  625s
#      0     0 3966.33062    0  159 3965.00000 3966.33062  0.03%     -  669s
#      0     0 3966.33062    0  154 3965.00000 3966.33062  0.03%     -  697s
#      0     2 3966.33062    0  154 3965.00000 3966.33062  0.03%     -  791s
#      1     4 3966.33037    1  153 3965.00000 3966.33062  0.03%  3776  797s
#      3     8 3966.29362    2  116 3965.00000 3966.33051  0.03%  1298  806s
#      7    12 infeasible    3      3965.00000 3966.33038  0.03%   610  819s
#     13    18 3966.33008    4  148 3965.00000 3966.33038  0.03%   356  840s
#     19    24 3966.33008    5  150 3965.00000 3966.33038  0.03%   266  855s
#     25    30 3966.33008    6  150 3965.00000 3966.33038  0.03%   209  866s
#     31    36 3966.33008    7  149 3965.00000 3966.33038  0.03%   171  917s
#     37    44 3966.33008    8  147 3965.00000 3966.33038  0.03%   145  921s
#     45    68 3966.33008    9  147 3965.00000 3966.33038  0.03%   121  933s
#     69    80 3966.33008   13  144 3965.00000 3966.33038  0.03%  82.2  962s
#     81   219 3966.33008   15  149 3965.00000 3966.33038  0.03%  71.8 1033s
#    220   516 3966.31980   46  155 3965.00000 3966.33038  0.03%  31.9 1176s
#    519   862 3966.28314   96  131 3965.00000 3966.33038  0.03%  18.1 1422s
#    870   929 3966.28121  153   91 3965.00000 3966.33038  0.03%  13.5 1556s
#    937  1318 3966.26798  179   75 3965.00000 3966.33038  0.03%  13.1 1771s
#   1328  1585 3966.22833  224   69 3965.00000 3966.33038  0.03%  11.3 1921s
#   1629  2066 3966.22159  279   58 3965.00000 3966.33038  0.03%  10.3 2150s
#   2114  2479 3966.05845  369   46 3965.00000 3966.33038  0.03%   9.4 2341s
#   2550  2904 3966.00633  455   44 3965.00000 3966.33038  0.03%   8.9 2532s
#   3014  3324 3966.00633  521   46 3965.00000 3966.33038  0.03%   8.3 2726s
#   3474  3784 3966.31823   74  105 3965.00000 3966.33017  0.03%   8.0 2933s
#   3952  4091 3965.99774  175   89 3965.00000 3966.33017  0.03%   7.8 3144s
#   4117  4091 3966.02683  388   63 3965.00000 3966.33017  0.03%   7.7 3145s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 84
#   MIR: 158
#   StrongCG: 2
#   RLT: 1
#
# Explored 4312 nodes (66184 simplex iterations) in 3602.08 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3965 3964 3960
#
# Time limit reached
# Best objective 3.965000000000e+03, best bound 3.966000000000e+03, gap 0.0252%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2.5x1

# %%
datafile="4x4000x2.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xf570b5f0
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 3479.0000000
# Presolve removed 37 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 16s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 23s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 26s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 47s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 60s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 105s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 109.84s
# Presolved: 19963 rows, 15980 columns, 31943996 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4790000e+03   0.000000e+00   7.771750e+03    122s
#     5635    3.5514755e+03   0.000000e+00   3.059812e-01    125s
#     5726    3.5511598e+03   0.000000e+00   0.000000e+00    126s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.551160e+03, 5726 iterations, 13.05 seconds
# Total elapsed time = 140.47s
# Total elapsed time = 149.87s
# Total elapsed time = 156.84s
# Total elapsed time = 164.22s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3551.15984    0   84 3479.00000 3551.15984  2.07%     -  168s
# H    0     0                    3545.0000000 3551.15984  0.17%     -  169s
# H    0     0                    3548.0000000 3551.15984  0.09%     -  171s
# H    0     0                    3549.0000000 3551.15984  0.06%     -  179s
#      0     0 3551.15984    0  101 3549.00000 3551.15984  0.06%     -  199s
# H    0     0                    3550.0000000 3551.15984  0.03%     -  218s
#      0     0 3551.14964    0  102 3550.00000 3551.14964  0.03%     -  223s
#      0     0 3551.14964    0  104 3550.00000 3551.14964  0.03%     -  230s
#
# Cutting planes:
#   Gomory: 34
#   Cover: 35
#   MIR: 165
#   StrongCG: 25
#
# Explored 1 nodes (22298 simplex iterations) in 248.74 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3550 3549 3548 ... 3479
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.550000000000e+03, best bound 3.550000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2.5x2

# %%
datafile="4x4000x2.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x019f2cf9
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 3478.0000000
# Presolve removed 60 rows and 32 columns (presolve time = 6s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 22s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 50s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 55s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 60s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 65s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 70s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 75s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 80s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 85s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 90s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 95s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 100s) ...
# Presolve removed 60 rows and 32 columns (presolve time = 106s) ...
# Presolve removed 60 rows and 32 columns
# Presolve time: 105.97s
# Presolved: 19940 rows, 15968 columns, 31896020 nonzeros
# Variable types: 0 continuous, 15968 integer (15968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4780000e+03   0.000000e+00   7.783000e+03    118s
#     5533    3.5561195e+03   0.000000e+00   1.536751e+00    120s
#     5800    3.5561587e+03   0.000000e+00   0.000000e+00    122s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.556159e+03, 5800 iterations, 12.45 seconds
# Total elapsed time = 132.95s
# Total elapsed time = 139.43s
# Total elapsed time = 147.07s
# Total elapsed time = 150.31s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3556.15872    0  172 3478.00000 3556.15872  2.25%     -  154s
# H    0     0                    3552.0000000 3556.15872  0.12%     -  155s
# H    0     0                    3553.0000000 3556.15872  0.09%     -  161s
#      0     0 3555.69997    0  159 3553.00000 3555.69997  0.08%     -  186s
# H    0     0                    3555.0000000 3555.69997  0.02%     -  210s
#      0     0 3555.69997    0  159 3555.00000 3555.69997  0.02%     -  210s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 5
#   MIR: 37
#   RLT: 2
#
# Explored 1 nodes (18412 simplex iterations) in 210.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3555 3553 3552 3478
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.555000000000e+03, best bound 3.555000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2.5x3

# %%
datafile="4x4000x2.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xe61b93c2
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 3484.0000000
# Presolve removed 13 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 14s) ...
# Presolve removed 17 rows and 4 columns (presolve time = 21s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 33s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 38s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 41s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 61s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 70s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 75s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 80s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 85s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 95s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 100s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 105s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 110s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 115s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 122s) ...
# Presolve removed 21 rows and 4 columns
# Presolve time: 122.32s
# Presolved: 19979 rows, 15996 columns, 32007920 nonzeros
# Variable types: 0 continuous, 15996 integer (15996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4840000e+03   0.000000e+00   7.836000e+03    135s
#      201    3.4859783e+03   0.000000e+00   3.495915e+03    135s
#     6084    3.5572714e+03   0.000000e+00   0.000000e+00    139s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.557271e+03, 6084 iterations, 13.21 seconds
# Total elapsed time = 152.43s
# Total elapsed time = 159.22s
# Total elapsed time = 161.07s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3557.27139    0  126 3484.00000 3557.27139  2.10%     -  163s
# H    0     0                    3551.0000000 3557.27139  0.18%     -  164s
# H    0     0                    3554.0000000 3557.27139  0.09%     -  167s
# H    0     0                    3556.0000000 3557.27139  0.04%     -  176s
#      0     0 3557.25723    0  105 3556.00000 3557.25723  0.04%     -  302s
#      0     0 infeasible    0      3556.00000 3556.00000  0.00%     -  307s
#      0     0 infeasible    0      3556.00000 3556.00000  0.00%     -  307s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 3
#   MIR: 6
#   StrongCG: 2
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (13525 simplex iterations) in 307.40 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3556 3554 3551 3484
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.556000000000e+03, best bound 3.556000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2.5x4

# %%
datafile="4x4000x2.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x6d4751f5
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 3481.0000000
# Presolve removed 26 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 21s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 33s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 38s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 41s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 61s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 85s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 90s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 95s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 100s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 105s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 110s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 115s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 122s) ...
# Presolve removed 38 rows and 24 columns
# Presolve time: 122.21s
# Presolved: 19962 rows, 15976 columns, 31928020 nonzeros
# Variable types: 0 continuous, 15976 integer (15976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4810000e+03   0.000000e+00   7.789250e+03    134s
#     3705    3.5373075e+03   0.000000e+00   1.735563e+02    135s
#     6347    3.5527289e+03   0.000000e+00   0.000000e+00    138s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.552729e+03, 6347 iterations, 12.64 seconds
# Total elapsed time = 152.20s
# Total elapsed time = 160.21s
# Total elapsed time = 166.84s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3552.72887    0  282 3481.00000 3552.72887  2.06%     -  172s
# H    0     0                    3549.0000000 3552.72887  0.11%     -  173s
# H    0     0                    3550.0000000 3552.72887  0.08%     -  176s
# H    0     0                    3551.0000000 3552.72887  0.05%     -  188s
#      0     0 3552.72536    0  322 3551.00000 3552.72536  0.05%     -  314s
#      0     0 3552.72003    0  322 3551.00000 3552.72003  0.05%     -  348s
#      0     0 3552.72003    0  316 3551.00000 3552.72003  0.05%     -  354s
#      0     0 3552.64802    0  291 3551.00000 3552.64802  0.05%     -  377s
#      0     0 3552.49500    0  253 3551.00000 3552.49500  0.04%     -  396s
#      0     0 3552.49500    0  254 3551.00000 3552.49500  0.04%     -  404s
#      0     0 3552.48057    0  232 3551.00000 3552.48057  0.04%     -  433s
#      0     0 3552.47604    0  210 3551.00000 3552.47604  0.04%     -  461s
#      0     0 3552.47604    0  214 3551.00000 3552.47604  0.04%     -  468s
#      0     0 3552.46424    0  205 3551.00000 3552.46424  0.04%     -  495s
#      0     0 3552.46424    0  203 3551.00000 3552.46424  0.04%     -  506s
#      0     0 3552.46326    0  215 3551.00000 3552.46326  0.04%     -  533s
#      0     0 3552.44936    0  205 3551.00000 3552.44936  0.04%     -  555s
#      0     0 3552.44936    0  200 3551.00000 3552.44936  0.04%     -  563s
#      0     0 3552.43895    0  193 3551.00000 3552.43895  0.04%     -  587s
#      0     0 3552.43345    0  203 3551.00000 3552.43345  0.04%     -  598s
#      0     0 3552.43345    0  202 3551.00000 3552.43345  0.04%     -  605s
#      0     0 3552.39501    0  191 3551.00000 3552.39501  0.04%     -  630s
#      0     0 3552.39501    0  177 3551.00000 3552.39501  0.04%     -  642s
#      0     0 3552.33267    0  178 3551.00000 3552.33267  0.04%     -  666s
#      0     0 3552.33267    0  171 3551.00000 3552.33267  0.04%     -  682s
#      0     0 3552.29578    0  164 3551.00000 3552.29578  0.04%     -  707s
#      0     0 3552.23783    0  155 3551.00000 3552.23783  0.03%     -  726s
#      0     0 3552.23783    0  140 3551.00000 3552.23783  0.03%     -  733s
#      0     0 3552.23783    0  148 3551.00000 3552.23783  0.03%     -  757s
#      0     0 3552.23783    0  147 3551.00000 3552.23783  0.03%     -  773s
#      0     0 3552.23783    0  151 3551.00000 3552.23783  0.03%     -  798s
#      0     0 3552.23783    0  156 3551.00000 3552.23783  0.03%     -  815s
#      0     0 3552.23783    0  123 3551.00000 3552.23783  0.03%     -  879s
#      0     0 3552.23783    0  122 3551.00000 3552.23783  0.03%     -  894s
#      0     0 3552.23783    0  139 3551.00000 3552.23783  0.03%     -  940s
#      0     0 3552.23783    0  142 3551.00000 3552.23783  0.03%     -  956s
#      0     0 3552.23783    0  151 3551.00000 3552.23783  0.03%     - 1109s
#      0     0 3552.23783    0  151 3551.00000 3552.23783  0.03%     - 1131s
#      0     2 3552.23783    0  151 3551.00000 3552.23783  0.03%     - 1239s
#      1     4 3552.06107    1  161 3551.00000 3552.23783  0.03%  1751 1244s
#      3     6     cutoff    2      3551.00000 3552.23783  0.03%   591 1253s
#      7    12 3552.23718    3  162 3551.00000 3552.23783  0.03%   307 1280s
#     13    18 3552.23718    4  156 3551.00000 3552.23718  0.03%   224 1306s
#     19    24 3552.23718    4  161 3551.00000 3552.23718  0.03%   174 1317s
#     25    30 3552.23718    5  156 3551.00000 3552.23718  0.03%   138 1324s
#     31    36 3552.23718    6  158 3551.00000 3552.23718  0.03%   113 1345s
#     37    44 3552.23718    6  156 3551.00000 3552.23718  0.03%  96.6 1351s
#     45    76 3552.23718    7  161 3551.00000 3552.23718  0.03%  80.9 1368s
#     77    88 3552.23718    8  155 3551.00000 3552.23718  0.03%  50.7 1457s
#     89   242 3552.23718   10  157 3551.00000 3552.23718  0.03%  45.5 1545s
#    243   557 3552.23557   26  133 3551.00000 3552.23718  0.03%  22.4 1716s
#    558   870 3552.22644   58  128 3551.00000 3552.23718  0.03%  14.0 1894s
#    873  1256 3552.22254   88  115 3551.00000 3552.23718  0.03%  11.3 2109s
# H 1264   651                    3552.0000000 3552.23718  0.01%   9.7 2292s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 213
#   MIR: 225
#   StrongCG: 7
#   GUB cover: 2
#   RLT: 1
#
# Explored 1592 nodes (60205 simplex iterations) in 2294.55 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3552 3551 3550 ... 3481
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.552000000000e+03, best bound 3.552000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x2.5x5

# %%
datafile="4x4000x2.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xb32b6d61
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Found heuristic solution: objective 3477.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 6s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 14s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 21s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 44s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 45s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 50s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 55s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 60s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 65s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 70s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 75s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 80s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 85s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 90s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 95s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 100s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 105s) ...
# Presolve removed 28 rows and 16 columns
# Presolve time: 105.13s
# Presolved: 19972 rows, 15984 columns, 31959988 nonzeros
# Variable types: 0 continuous, 15984 integer (15984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4770000e+03   0.000000e+00   7.740750e+03    118s
#     5696    3.5529709e+03   0.000000e+00   1.402631e+01    120s
#     6343    3.5532503e+03   0.000000e+00   0.000000e+00    122s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.553250e+03, 6343 iterations, 13.39 seconds
# Total elapsed time = 135.53s
# Total elapsed time = 142.87s
# Total elapsed time = 146.17s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3553.25025    0  169 3477.00000 3553.25025  2.19%     -  150s
# H    0     0                    3551.0000000 3553.25025  0.06%     -  151s
# H    0     0                    3552.0000000 3553.25025  0.04%     -  157s
#      0     0     cutoff    0      3552.00000 3552.00000  0.00%     -  176s
#
# Cutting planes:
#   Gomory: 28
#   Cover: 39
#   MIR: 225
#   StrongCG: 4
#   RLT: 3
#
# Explored 1 nodes (15639 simplex iterations) in 176.76 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 3552 3551 3477
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.552000000000e+03, best bound 3.552000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3x1

# %%
datafile="4x4000x3x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x6ccaa489
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 3121.0000000
# Presolve removed 46 rows and 40 columns (presolve time = 6s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 14s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 21s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 33s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 38s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 41s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 61s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 65s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 70s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 75s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 80s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 85s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 90s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 95s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 100s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 105s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 110s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 115s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 121s) ...
# Presolve removed 50 rows and 40 columns
# Presolve time: 121.48s
# Presolved: 19950 rows, 15960 columns, 31864144 nonzeros
# Variable types: 0 continuous, 15960 integer (15960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1210000e+03   0.000000e+00   7.879000e+03    133s
#     4998    3.2253670e+03   0.000000e+00   4.761373e+01    136s
#     5802    3.2293185e+03   0.000000e+00   0.000000e+00    137s
# Concurrent spin time: 0.09s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.229319e+03, 5802 iterations, 12.49 seconds
# Total elapsed time = 149.04s
# Total elapsed time = 156.28s
# Total elapsed time = 164.12s
# Total elapsed time = 167.13s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3229.31854    0  149 3121.00000 3229.31854  3.47%     -  169s
# H    0     0                    3221.0000000 3229.31854  0.26%     -  170s
# H    0     0                    3226.0000000 3229.31854  0.10%     -  173s
# H    0     0                    3227.0000000 3229.31854  0.07%     -  175s
# H    0     0                    3228.0000000 3229.31854  0.04%     -  178s
#      0     0 3229.29968    0  159 3228.00000 3229.29968  0.04%     -  294s
#      0     0 3229.26815    0  176 3228.00000 3229.26815  0.04%     -  314s
#      0     0 3229.26551    0  176 3228.00000 3229.26551  0.04%     -  321s
#      0     0 3229.26551    0  176 3228.00000 3229.26551  0.04%     -  326s
#      0     0 3229.20559    0  151 3228.00000 3229.20559  0.04%     -  351s
#      0     0 3229.20537    0  142 3228.00000 3229.20537  0.04%     -  368s
#      0     0 3229.20457    0  139 3228.00000 3229.20457  0.04%     -  392s
#      0     0 3229.20252    0  127 3228.00000 3229.20252  0.04%     -  410s
#      0     0 3229.20252    0  127 3228.00000 3229.20252  0.04%     -  417s
#      0     0 3229.20194    0  123 3228.00000 3229.20194  0.04%     -  439s
#      0     0 3229.17085    0  101 3228.00000 3229.17085  0.04%     -  455s
#      0     0 3229.13910    0  106 3228.00000 3229.13910  0.04%     -  464s
#      0     0 3229.13910    0  106 3228.00000 3229.13910  0.04%     -  470s
#      0     0     cutoff    0      3228.00000 3228.00000  0.00%     -  488s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 13
#   MIR: 172
#   StrongCG: 13
#   GUB cover: 2
#   RLT: 2
#
# Explored 1 nodes (19757 simplex iterations) in 488.57 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3228 3227 3226 ... 3121
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.228000000000e+03, best bound 3.228000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3x2

# %%
datafile="4x4000x3x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x40bfabdd
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 3124.0000000
# Presolve removed 56 rows and 32 columns (presolve time = 6s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 15s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 21s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 44s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 45s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 50s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 55s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 60s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 65s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 70s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 75s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 80s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 85s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 90s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 95s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 100s) ...
# Presolve removed 56 rows and 32 columns (presolve time = 105s) ...
# Presolve removed 56 rows and 32 columns
# Presolve time: 105.04s
# Presolved: 19944 rows, 15968 columns, 31896040 nonzeros
# Variable types: 0 continuous, 15968 integer (15968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1240000e+03   0.000000e+00   7.924250e+03    117s
#     5944    3.2283184e+03   2.081451e-01   0.000000e+00    121s
#     5946    3.2283184e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.228318e+03, 5946 iterations, 12.41 seconds
# Total elapsed time = 132.19s
# Total elapsed time = 138.73s
# Total elapsed time = 141.68s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3228.31837    0  171 3124.00000 3228.31837  3.34%     -  145s
# H    0     0                    3223.0000000 3228.31837  0.17%     -  146s
# H    0     0                    3224.0000000 3228.31837  0.13%     -  150s
# H    0     0                    3226.0000000 3228.31837  0.07%     -  163s
#      0     0 3228.25135    0  192 3226.00000 3228.25135  0.07%     -  186s
# H    0     0                    3227.0000000 3228.25135  0.04%     -  209s
#      0     0 3228.20635    0  184 3227.00000 3228.20635  0.04%     -  215s
#      0     0 3228.20635    0  184 3227.00000 3228.20635  0.04%     -  222s
#      0     0     cutoff    0      3227.00000 3227.00000  0.00%     -  247s
#
# Cutting planes:
#   Gomory: 61
#   Cover: 39
#   MIR: 345
#   StrongCG: 30
#   RLT: 3
#
# Explored 1 nodes (15273 simplex iterations) in 247.61 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3227 3226 3224 ... 3124
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.227000000000e+03, best bound 3.227000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3x3

# %%
datafile="4x4000x3x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xf8d3a59b
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 3115.0000000
# Presolve removed 45 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 44s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 50s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 55s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 60s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 45 rows and 36 columns (presolve time = 100s) ...
# Presolve removed 45 rows and 36 columns
# Presolve time: 104.52s
# Presolved: 19955 rows, 15964 columns, 31880112 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1080000e+03   0.000000e+00   7.889250e+03    117s
#     5585    3.2250572e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.225057e+03, 5585 iterations, 12.96 seconds
# Total elapsed time = 132.74s
# Total elapsed time = 140.00s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3225.05724    0  192 3115.00000 3225.05724  3.53%     -  146s
# H    0     0                    3221.0000000 3225.05724  0.13%     -  147s
# H    0     0                    3222.0000000 3225.05724  0.09%     -  151s
#      0     0 3224.90648    0  178 3222.00000 3224.90648  0.09%     -  288s
# H    0     0                    3223.0000000 3224.90648  0.06%     -  315s
#      0     0 3224.89372    0  172 3223.00000 3224.89372  0.06%     -  319s
#      0     0 3224.85712    0  167 3223.00000 3224.85712  0.06%     -  325s
#      0     0 3224.85661    0  169 3223.00000 3224.85661  0.06%     -  331s
#      0     0 3224.85661    0  171 3223.00000 3224.85661  0.06%     -  338s
#      0     0 3224.58924    0  160 3223.00000 3224.58924  0.05%     -  360s
#      0     0 3224.56245    0  162 3223.00000 3224.56245  0.05%     -  372s
#      0     0 3224.52869    0  155 3223.00000 3224.52869  0.05%     -  378s
#      0     0 3224.52865    0  154 3223.00000 3224.52865  0.05%     -  385s
#      0     0 3224.31331    0  168 3223.00000 3224.31331  0.04%     -  410s
#      0     0 3224.31121    0  155 3223.00000 3224.31121  0.04%     -  430s
#      0     0 3224.31111    0  157 3223.00000 3224.31111  0.04%     -  437s
#      0     0 3224.17490    0  139 3223.00000 3224.17490  0.04%     -  464s
#      0     0 3224.17137    0  140 3223.00000 3224.17137  0.04%     -  478s
#      0     0 3224.16774    0  132 3223.00000 3224.16774  0.04%     -  487s
#      0     0 3224.16570    0  129 3223.00000 3224.16570  0.04%     -  496s
#      0     0 3224.16508    0  127 3223.00000 3224.16508  0.04%     -  505s
#      0     0 3224.16508    0  124 3223.00000 3224.16508  0.04%     -  511s
#      0     0 3224.15546    0  121 3223.00000 3224.15546  0.04%     -  535s
#      0     0 3224.15546    0  115 3223.00000 3224.15546  0.04%     -  550s
#      0     0 3224.15075    0  151 3223.00000 3224.15075  0.04%     -  574s
#      0     0 3224.14442    0  144 3223.00000 3224.14442  0.04%     -  588s
#      0     0 3224.14270    0  141 3223.00000 3224.14270  0.04%     -  596s
#      0     0 3224.14270    0  130 3223.00000 3224.14270  0.04%     -  603s
#      0     0 3224.04200    0  139 3223.00000 3224.04200  0.03%     -  628s
#      0     0 3224.04200    0  144 3223.00000 3224.04200  0.03%     -  651s
#      0     0 3224.03449    0  132 3223.00000 3224.03449  0.03%     -  674s
#      0     0 3224.03406    0  127 3223.00000 3224.03406  0.03%     -  687s
#      0     0 3224.03406    0  123 3223.00000 3224.03406  0.03%     -  694s
#      0     0 infeasible    0      3223.00000 3223.00000  0.00%     -  714s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 10
#   Clique: 1
#   MIR: 277
#   StrongCG: 6
#   Mod-K: 1
#
# Explored 1 nodes (15707 simplex iterations) in 714.78 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3223 3222 3221 3115
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.223000000000e+03, best bound 3.223000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3x4

# %%
datafile="4x4000x3x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x9b02fdf4
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 3122.0000000
# Presolve removed 21 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 14s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 21s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 44s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 45s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 50s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 55s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 60s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 65s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 70s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 75s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 80s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 85s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 90s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 95s) ...
# Presolve removed 21 rows and 4 columns (presolve time = 100s) ...
# Presolve removed 21 rows and 4 columns
# Presolve time: 104.72s
# Presolved: 19979 rows, 15996 columns, 32007956 nonzeros
# Variable types: 0 continuous, 15996 integer (15996 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1220000e+03   0.000000e+00   7.949500e+03    116s
#     5851    3.2322916e+03   1.696983e+00   0.000000e+00    120s
#     5855    3.2322916e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.232292e+03, 5855 iterations, 12.32 seconds
# Total elapsed time = 132.28s
# Total elapsed time = 139.05s
# Total elapsed time = 142.08s
# Total elapsed time = 145.27s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3232.29156    0   51 3122.00000 3232.29156  3.53%     -  147s
# H    0     0                    3227.0000000 3232.29156  0.16%     -  148s
# H    0     0                    3230.0000000 3232.29156  0.07%     -  150s
# H    0     0                    3231.0000001 3232.29156  0.04%     -  155s
#      0     0 3232.29156    0   74 3231.00000 3232.29156  0.04%     -  174s
#      0     0 3232.28640    0   65 3231.00000 3232.28640  0.04%     -  195s
#      0     0 3232.28640    0   65 3231.00000 3232.28640  0.04%     -  200s
#      0     0 3232.25194    0   49 3231.00000 3232.25194  0.04%     -  240s
#      0     0 3232.19789    0   51 3231.00000 3232.19789  0.04%     -  260s
#      0     0 3232.18991    0   41 3231.00000 3232.18991  0.04%     -  283s
#      0     0 3232.08181    0   47 3231.00000 3232.08181  0.03%     -  300s
#      0     0 3232.08181    0   43 3231.00000 3232.08181  0.03%     -  319s
#      0     0 3232.07305    0   35 3231.00000 3232.07305  0.03%     -  334s
#      0     0 3232.07305    0   35 3231.00000 3232.07305  0.03%     -  341s
#      0     0 3232.07305    0   40 3231.00000 3232.07305  0.03%     -  359s
#      0     0 3232.07305    0   38 3231.00000 3232.07305  0.03%     -  372s
#      0     0 3232.07305    0   33 3231.00000 3232.07305  0.03%     -  385s
#      0     0 3232.07305    0   37 3231.00000 3232.07305  0.03%     -  400s
#      0     0 3232.07305    0   42 3231.00000 3232.07305  0.03%     -  423s
#      0     0 3232.07305    0   43 3231.00000 3232.07305  0.03%     -  438s
#      0     0 3232.07305    0   40 3231.00000 3232.07305  0.03%     -  469s
#      0     0 3232.07305    0   37 3231.00000 3232.07305  0.03%     -  482s
#      0     0 3232.07305    0   39 3231.00000 3232.07305  0.03%     -  512s
#      0     0 3232.07305    0   39 3231.00000 3232.07305  0.03%     -  527s
#      0     0 3232.07305    0   43 3231.00000 3232.07305  0.03%     -  552s
#      0     0 3232.07305    0   43 3231.00000 3232.07305  0.03%     -  572s
#      0     0 3232.07305    0   66 3231.00000 3232.07305  0.03%     -  712s
#      0     0 3232.07305    0   62 3231.00000 3232.07305  0.03%     -  732s
#      0     0 3232.07305    0   48 3231.00000 3232.07305  0.03%     -  746s
#      0     0 3232.07305    0   50 3231.00000 3232.07305  0.03%     -  750s
#      0     0 3232.02472    0   45 3231.00000 3232.02472  0.03%     -  767s
#      0     0 3232.02472    0   44 3231.00000 3232.02472  0.03%     -  775s
#      0     0 3232.02472    0   36 3231.00000 3232.02472  0.03%     -  786s
#      0     0 3232.02472    0   31 3231.00000 3232.02472  0.03%     -  796s
#      0     0 3232.02472    0   28 3231.00000 3232.02472  0.03%     -  818s
#      0     0 3232.02472    0   30 3231.00000 3232.02472  0.03%     -  826s
#      0     0 3232.02472    0   29 3231.00000 3232.02472  0.03%     -  846s
#      0     0 3232.02472    0   27 3231.00000 3232.02472  0.03%     -  857s
#      0     0 3232.02472    0   27 3231.00000 3232.02472  0.03%     -  882s
#      0     0 3232.02472    0   27 3231.00000 3232.02472  0.03%     -  910s
#      0     0 3232.02472    0   30 3231.00000 3232.02472  0.03%     -  921s
#      0     0 3232.02472    0   24 3231.00000 3232.02472  0.03%     -  940s
#      0     0 3232.02472    0   35 3231.00000 3232.02472  0.03%     -  949s
#      0     0 3232.02472    0   26 3231.00000 3232.02472  0.03%     -  977s
#      0     0 3232.02472    0   31 3231.00000 3232.02472  0.03%     -  988s
#      0     0 3232.02472    0   29 3231.00000 3232.02472  0.03%     - 1006s
#      0     0 3232.02472    0   29 3231.00000 3232.02472  0.03%     - 1026s
#      0     2 3232.02472    0   28 3231.00000 3232.02472  0.03%     - 1092s
#      1     5 3232.02472    1   28 3231.00000 3232.02472  0.03%  2075 1097s
#      3     8 3232.02472    2   28 3231.00000 3232.02472  0.03%   696 1102s
#      7    14 3232.02472    3   29 3231.00000 3232.02472  0.03%   302 1112s
#     13    20 3232.02470    4   37 3231.00000 3232.02470  0.03%   169 1120s
#     19    26 3232.02470    5   37 3231.00000 3232.02470  0.03%   121 1149s
#     25    32 3232.02457    6   37 3231.00000 3232.02457  0.03%  96.2 1154s
#     31    38 3232.02457    7   37 3231.00000 3232.02457  0.03%  78.0 1173s
#     37    46 3232.02448    8   37 3231.00000 3232.02448  0.03%  66.1 1178s
#     45    52 3232.02448    9   37 3231.00000 3232.02448  0.03%  55.3 1183s
#     51    70 3232.02443   10   37 3231.00000 3232.02443  0.03%  49.5 1194s
#     69   126 3232.02443   12   37 3231.00000 3232.02443  0.03%  38.7 1220s
#    128   277 3232.02419   17   37 3231.00000 3232.02419  0.03%  23.7 1283s
#    284   526 3232.00000   27   23 3231.00000 3232.01598  0.03%  13.6 1379s
#    533   853 3232.00000   65   14 3231.00000 3232.01598  0.03%  10.1 1538s
#    891   853 3232.01584   65   31 3231.00000 3232.01598  0.03%   8.1 1540s
#    969   768 3232.00000  121   16 3231.00000 3232.01598  0.03%   7.9 1660s
#   1081   768 3232.01598  110   36 3231.00000 3232.01598  0.03%  19.1 1665s
#   1218   694 3232.01598   11   46 3231.00000 3232.01598  0.03%  18.4 1808s
#   1245   694 3232.01598  103   33 3231.00000 3232.01598  0.03%  18.5 1810s
#   1471   541     cutoff   69      3231.00000 3232.01598  0.03%  18.2 2017s
#   1526   541 3232.01598  113   34 3231.00000 3232.01598  0.03%  18.3 2020s
#   1640   541 3232.01598   22   43 3231.00000 3232.01598  0.03%  18.3 2025s
#   1889   374     cutoff  128      3231.00000 3232.01598  0.03%  18.3 2240s
#   2240   220     cutoff   40      3231.00000 3232.01598  0.03%  19.3 2477s
#   2407   220     cutoff   27      3231.00000 3232.01598  0.03%  22.8 2481s
#   2483   180     cutoff   13      3231.00000 3232.00623  0.03%  22.9 2632s
#   2567   180     cutoff   80      3231.00000 3232.00623  0.03%  32.9 2636s
#   2735   109     cutoff  112      3231.00000 3232.00000  0.03%  53.8 2784s
#   2740   109 3232.00000   73   24 3231.00000 3232.00000  0.03%  54.2 2785s
#   2804   109 3232.00000  106   40 3231.00000 3232.00000  0.03%  58.8 2790s
#   2894   109     cutoff   69      3231.00000 3232.00000  0.03%  66.9 2797s
#   2919   109 3232.00000  101   38 3231.00000 3232.00000  0.03%  68.7 2800s
#   2971   109 3232.00000   92   39 3231.00000 3232.00000  0.03%  71.5 2805s
#   2978    78     cutoff   51      3231.00000 3232.00000  0.03%  72.9 2941s
#   3117    53     cutoff   78      3231.00000 3232.00000  0.03%  82.1 3056s
#   3260     9     cutoff   34      3231.00000 3232.00000  0.03%  96.3 3144s
#   3271     9 3232.00000   46   24 3231.00000 3232.00000  0.03%  98.0 3145s
#   3366     0 3232.00000   71   53 3231.00000 3232.00000  0.03%   107 3182s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 2183
#   MIR: 28
#   StrongCG: 1
#   RLT: 2
#
# Explored 3389 nodes (466420 simplex iterations) in 3188.59 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 3231 3230 3227 ... 3122
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.231000000000e+03, best bound 3.231000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3x5

# %%
datafile="4x4000x3x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x0abe88b7
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+03]
# Found heuristic solution: objective 3131.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 33s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 38s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 61s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 105s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 110s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 115s) ...
# Presolve removed 33 rows and 20 columns (presolve time = 122s) ...
# Presolve removed 33 rows and 20 columns
# Presolve time: 122.17s
# Presolved: 19967 rows, 15980 columns, 31944004 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1310000e+03   0.000000e+00   7.932250e+03    134s
#     4505    3.2214129e+03   0.000000e+00   8.099642e+01    136s
#     6485    3.2348103e+03   0.000000e+00   0.000000e+00    138s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 3.234810e+03, 6485 iterations, 12.65 seconds
# Total elapsed time = 150.47s
# Total elapsed time = 157.82s
# Total elapsed time = 165.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3234.81033    0  358 3131.00000 3234.81033  3.32%     -  169s
# H    0     0                    3230.0000000 3234.81033  0.15%     -  169s
# H    0     0                    3233.0000000 3234.81033  0.06%     -  174s
#      0     0 3234.80308    0  364 3233.00000 3234.80308  0.06%     -  308s
# H    0     0                    3234.0000000 3234.80308  0.02%     -  330s
#      0     0 3234.80308    0  364 3234.00000 3234.80308  0.02%     -  330s
#
# Cutting planes:
#   Gomory: 19
#   Cover: 3
#   MIR: 85
#   StrongCG: 3
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (17125 simplex iterations) in 330.86 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 3234 3233 3230 3131
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.234000000000e+03, best bound 3.234000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3.5x1

# %%
datafile="4x4000x3.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xa47ee995
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2839.0000000
# Presolve removed 27 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 14s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 21s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 44s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 75s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 80s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 85s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 90s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 95s) ...
# Presolve removed 27 rows and 12 columns (presolve time = 100s) ...
# Presolve removed 27 rows and 12 columns
# Presolve time: 104.59s
# Presolved: 19973 rows, 15988 columns, 31975972 nonzeros
# Variable types: 0 continuous, 15988 integer (15988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8400000e+03   0.000000e+00   7.893000e+03    117s
#     5802    2.9587269e+03   6.232872e-02   0.000000e+00    121s
#     5803    2.9587269e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.958727e+03, 5803 iterations, 12.80 seconds
# Total elapsed time = 131.93s
# Total elapsed time = 138.78s
# Total elapsed time = 145.08s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2958.72685    0  151 2839.00000 2958.72685  4.22%     -  148s
# H    0     0                    2949.0000000 2958.72685  0.33%     -  149s
# H    0     0                    2955.0000000 2958.72685  0.13%     -  150s
# H    0     0                    2956.0000000 2958.72685  0.09%     -  154s
# H    0     0                    2957.0000000 2958.72685  0.06%     -  161s
#      0     0 2958.71080    0  165 2957.00000 2958.71080  0.06%     -  181s
# H    0     0                    2958.0000000 2958.71080  0.02%     -  201s
#      0     0 2958.71080    0  165 2958.00000 2958.71080  0.02%     -  201s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 14
#   Clique: 1
#   MIR: 15
#   StrongCG: 7
#
# Explored 1 nodes (15370 simplex iterations) in 201.96 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2958 2957 2956 ... 2839
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.958000000000e+03, best bound 2.958000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3.5x2

# %%
datafile="4x4000x3.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xcbdb5a7e
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2845.0000000
# Presolve removed 29 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 33s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 38s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 61s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 105s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 110s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 115s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 122s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 122.06s
# Presolved: 19963 rows, 15980 columns, 31943972 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8410000e+03   0.000000e+00   7.938250e+03    134s
#     1358    2.8546645e+03   0.000000e+00   1.427052e+03    135s
#     6080    2.9627173e+03   0.000000e+00   0.000000e+00    139s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.962717e+03, 6080 iterations, 13.34 seconds
# Total elapsed time = 149.68s
# Total elapsed time = 156.24s
# Total elapsed time = 162.67s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2962.71730    0  284 2845.00000 2962.71730  4.14%     -  166s
# H    0     0                    2957.0000000 2962.71730  0.19%     -  167s
# H    0     0                    2959.0000000 2962.71730  0.13%     -  172s
# H    0     0                    2960.0000000 2962.71730  0.09%     -  192s
#      0     0 2962.71302    0  314 2960.00000 2962.71302  0.09%     -  306s
# H    0     0                    2961.0000000 2962.71302  0.06%     -  333s
#      0     0 2962.69339    0  300 2961.00000 2962.69339  0.06%     -  337s
#      0     0 2962.68829    0  290 2961.00000 2962.68829  0.06%     -  343s
#      0     0 2962.55661    0  256 2961.00000 2962.55661  0.05%     -  368s
#      0     0 2962.50917    0  259 2961.00000 2962.50917  0.05%     -  381s
#      0     0 2962.50917    0  263 2961.00000 2962.50917  0.05%     -  388s
#      0     0 2962.37172    0  257 2961.00000 2962.37172  0.05%     -  416s
#      0     0 2962.36816    0  251 2961.00000 2962.36816  0.05%     -  445s
#      0     0 2962.36340    0  249 2961.00000 2962.36340  0.05%     -  453s
#      0     0 2962.36340    0  246 2961.00000 2962.36340  0.05%     -  460s
#      0     0 2962.22791    0  231 2961.00000 2962.22791  0.04%     -  488s
#      0     0 2962.22791    0  238 2961.00000 2962.22791  0.04%     -  499s
#      0     0 2962.22768    0  230 2961.00000 2962.22768  0.04%     -  522s
#      0     0 2962.22715    0  229 2961.00000 2962.22715  0.04%     -  548s
#      0     0 2962.22715    0  225 2961.00000 2962.22715  0.04%     -  555s
#      0     0 2962.22644    0  230 2961.00000 2962.22644  0.04%     -  579s
#      0     0 2962.22641    0  220 2961.00000 2962.22641  0.04%     -  593s
#      0     0 2962.22528    0  221 2961.00000 2962.22528  0.04%     -  619s
#      0     0 2962.22528    0  228 2961.00000 2962.22528  0.04%     -  630s
#      0     0 2962.22528    0  221 2961.00000 2962.22528  0.04%     -  655s
#      0     0 2962.22528    0  216 2961.00000 2962.22528  0.04%     -  667s
#      0     0 2962.22517    0  185 2961.00000 2962.22517  0.04%     -  706s
#      0     0 2962.22475    0  189 2961.00000 2962.22475  0.04%     -  726s
#      0     0 2962.22475    0  197 2961.00000 2962.22475  0.04%     -  733s
#      0     0 2962.22421    0  208 2961.00000 2962.22421  0.04%     -  759s
#      0     0 2962.22421    0  183 2961.00000 2962.22421  0.04%     -  789s
#      0     2 2962.22421    0  175 2961.00000 2962.22421  0.04%     -  865s
#      1     4 2962.15859    1  193 2961.00000 2962.22421  0.04%  4213  871s
#      3     8 2962.03601    2  240 2961.00000 2962.22421  0.04%  1458  880s
#      7    14 2962.02698    3  249 2961.00000 2962.22421  0.04%   692  894s
#     13    20 2962.02432    4  253 2961.00000 2962.22421  0.04%   436  914s
#     19    24 infeasible    4      2961.00000 2962.22421  0.04%   356  924s
#     25    30 2962.02432    5  250 2961.00000 2962.22421  0.04%   285  932s
#     31    36 2962.02432    6  250 2961.00000 2962.22421  0.04%   240  953s
#     37    43 2962.02432    7  248 2961.00000 2962.22421  0.04%   203  960s
#     44    60 2962.02432    8  249 2961.00000 2962.22421  0.04%   173  977s
#     61    91 2962.02404   11  243 2961.00000 2962.22421  0.04%   129 1005s
#     92   235 2962.02403   14  237 2961.00000 2962.22421  0.04%  90.1 1159s
#    236   745 2962.01140   31  216 2961.00000 2962.22421  0.04%  41.8 1419s
#    755  1167 2962.22125   46  195 2961.00000 2962.22421  0.04%  18.0 1635s
#   1206  1569 2962.21589  130  185 2961.00000 2962.22421  0.04%  13.9 1842s
#   1610  1971 2962.21328  199  174 2961.00000 2962.22421  0.04%  12.2 2032s
#   2012  2351 2962.17252  286  151 2961.00000 2962.22421  0.04%  11.0 2215s
#   2404  2563 2962.16397  355  153 2961.00000 2962.22421  0.04%  10.4 2382s
#   2635  3046 2962.16210  443   95 2961.00000 2962.22421  0.04%   9.9 2619s
#   3182  3587 2962.12711  530   65 2961.00000 2962.22421  0.04%   9.7 2857s
#   3771  4138 2962.12667  624   61 2961.00000 2962.22421  0.04%   9.1 3090s
#   4379  4648 2962.11254  699   74 2961.00000 2962.22421  0.04%   8.7 3305s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 210
#   MIR: 266
#
# Explored 4928 nodes (71140 simplex iterations) in 3606.58 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2961 2960 2959 ... 2845
#
# Time limit reached
# Best objective 2.961000000000e+03, best bound 2.962000000000e+03, gap 0.0338%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3.5x3

# %%
datafile="4x4000x3.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x32f5eab5
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2851.0000000
# Presolve removed 43 rows and 28 columns (presolve time = 6s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 14s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 21s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 44s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 45s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 50s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 55s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 60s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 65s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 70s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 75s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 80s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 85s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 90s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 95s) ...
# Presolve removed 43 rows and 28 columns (presolve time = 100s) ...
# Presolve removed 43 rows and 28 columns
# Presolve time: 104.30s
# Presolved: 19957 rows, 15972 columns, 31912024 nonzeros
# Variable types: 0 continuous, 15972 integer (15972 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8510000e+03   0.000000e+00   8.049000e+03    116s
#     5580    2.9782763e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.04s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.978276e+03, 5580 iterations, 12.14 seconds
# Total elapsed time = 129.79s
# Total elapsed time = 135.29s
# Total elapsed time = 141.00s
# Total elapsed time = 145.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2978.27634    0   95 2851.00000 2978.27634  4.46%     -  148s
# H    0     0                    2964.0000000 2978.27634  0.48%     -  149s
# H    0     0                    2975.0000000 2978.27634  0.11%     -  149s
# H    0     0                    2976.0000000 2978.27634  0.08%     -  161s
#      0     0 2978.27447    0  100 2976.00000 2978.27447  0.08%     -  274s
# H    0     0                    2977.0000000 2978.27447  0.04%     -  296s
#      0     0 2978.20293    0   95 2977.00000 2978.20293  0.04%     -  302s
#      0     0 2978.14037    0   91 2977.00000 2978.14037  0.04%     -  310s
#
# Cutting planes:
#   Gomory: 53
#   Cover: 22
#   MIR: 162
#   StrongCG: 26
#   GUB cover: 1
#
# Explored 1 nodes (15841 simplex iterations) in 327.04 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2977 2976 2975 ... 2851
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.977000000000e+03, best bound 2.977000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3.5x4

# %%
datafile="4x4000x3.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x5fc5a51b
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2844.0000000
# Presolve removed 19 rows and 12 columns (presolve time = 6s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 14s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 21s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 44s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 45s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 50s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 55s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 60s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 65s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 70s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 75s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 80s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 85s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 90s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 95s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 100s) ...
# Presolve removed 19 rows and 12 columns (presolve time = 105s) ...
# Presolve removed 19 rows and 12 columns
# Presolve time: 105.04s
# Presolved: 19981 rows, 15988 columns, 31975992 nonzeros
# Variable types: 0 continuous, 15988 integer (15988 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8440000e+03   0.000000e+00   8.050750e+03    117s
#     6116    2.9681275e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.968128e+03, 6116 iterations, 12.69 seconds
# Total elapsed time = 131.57s
# Total elapsed time = 139.07s
# Total elapsed time = 141.95s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2968.12753    0  297 2844.00000 2968.12753  4.36%     -  145s
# H    0     0                    2965.0000000 2968.12753  0.11%     -  146s
# H    0     0                    2966.0000000 2968.12753  0.07%     -  153s
#      0     0 2968.11847    0  283 2966.00000 2968.11847  0.07%     -  270s
# H    0     0                    2967.0000000 2968.11847  0.04%     -  298s
#      0     0 2968.10276    0  263 2967.00000 2968.10276  0.04%     -  304s
#      0     0 2968.10266    0  273 2967.00000 2968.10266  0.04%     -  311s
#      0     0 2968.05900    0  245 2967.00000 2968.05900  0.04%     -  339s
#      0     0 2968.04625    0  243 2967.00000 2968.04625  0.04%     -  352s
#      0     0 2968.04625    0  243 2967.00000 2968.04625  0.04%     -  358s
#      0     0 2968.02520    0  170 2967.00000 2968.02520  0.03%     -  414s
#      0     0 2968.02520    0  288 2967.00000 2968.02520  0.03%     -  528s
#      0     0 2968.02520    0  258 2967.00000 2968.02520  0.03%     -  596s
#      0     0 2968.02520    0  216 2967.00000 2968.02520  0.03%     -  606s
#      0     0 2968.02520    0  218 2967.00000 2968.02520  0.03%     -  610s
#      0     0 2968.02520    0  213 2967.00000 2968.02520  0.03%     -  613s
#
# Cutting planes:
#   Gomory: 60
#   Cover: 21
#   MIR: 304
#   StrongCG: 11
#   GUB cover: 1
#
# Explored 1 nodes (32919 simplex iterations) in 626.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2967 2966 2965 2844
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.967000000000e+03, best bound 2.967000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x3.5x5

# %%
datafile="4x4000x3.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x90043b47
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+03]
# Found heuristic solution: objective 2865.0000000
# Presolve removed 28 rows and 16 columns (presolve time = 6s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 14s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 21s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 44s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 45s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 50s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 55s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 60s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 65s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 70s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 75s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 80s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 85s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 90s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 95s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 100s) ...
# Presolve removed 28 rows and 16 columns (presolve time = 105s) ...
# Presolve removed 28 rows and 16 columns
# Presolve time: 105.05s
# Presolved: 19972 rows, 15984 columns, 31959996 nonzeros
# Variable types: 0 continuous, 15984 integer (15984 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8650000e+03   0.000000e+00   8.074000e+03    117s
#     5796    2.9822844e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.982284e+03, 5796 iterations, 12.89 seconds
# Total elapsed time = 132.81s
# Total elapsed time = 140.16s
# Total elapsed time = 147.61s
# Total elapsed time = 150.39s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2982.28435    0  226 2865.00000 2982.28435  4.09%     -  152s
# H    0     0                    2979.0000000 2982.28435  0.11%     -  153s
# H    0     0                    2980.0000000 2982.28435  0.08%     -  162s
#      0     0 2982.22714    0  238 2980.00000 2982.22714  0.07%     -  184s
#      0     0 2982.21266    0  230 2980.00000 2982.21266  0.07%     -  215s
#      0     0 2982.20528    0  218 2980.00000 2982.20528  0.07%     -  220s
#      0     0 2982.20528    0  217 2980.00000 2982.20528  0.07%     -  226s
#      0     0 2982.07050    0  174 2980.00000 2982.07050  0.07%     -  250s
#      0     0 2982.05916    0  162 2980.00000 2982.05916  0.07%     -  266s
#      0     0 2982.05916    0  161 2980.00000 2982.05916  0.07%     -  273s
#      0     0 2982.03646    0  175 2980.00000 2982.03646  0.07%     -  298s
#      0     0 2982.03389    0  160 2980.00000 2982.03389  0.07%     -  321s
#      0     0 2982.03387    0  167 2980.00000 2982.03387  0.07%     -  328s
#      0     0 2982.01562    0  154 2980.00000 2982.01562  0.07%     -  353s
#      0     0 2982.01562    0  149 2980.00000 2982.01562  0.07%     -  369s
#      0     0 2982.01207    0  155 2980.00000 2982.01207  0.07%     -  393s
#      0     0 2982.01175    0  157 2980.00000 2982.01175  0.07%     -  403s
#      0     0 2981.90122    0  182 2980.00000 2981.90122  0.06%     -  422s
#      0     0 2981.89230    0  190 2980.00000 2981.89230  0.06%     -  432s
#      0     0 2981.89230    0  193 2980.00000 2981.89230  0.06%     -  439s
#      0     0 2981.81614    0  183 2980.00000 2981.81614  0.06%     -  464s
#      0     0 2981.81604    0  177 2980.00000 2981.81604  0.06%     -  475s
#      0     0 2981.81508    0  176 2980.00000 2981.81508  0.06%     -  495s
#      0     0 2981.81318    0  156 2980.00000 2981.81318  0.06%     -  506s
#      0     0 2981.81318    0  155 2980.00000 2981.81318  0.06%     -  513s
#      0     0 2981.80750    0  159 2980.00000 2981.80750  0.06%     -  537s
#      0     0 2981.80750    0  148 2980.00000 2981.80750  0.06%     -  559s
#      0     0 2981.80750    0  141 2980.00000 2981.80750  0.06%     -  577s
#      0     0 2981.80750    0  128 2980.00000 2981.80750  0.06%     -  590s
#      0     0 2981.80750    0  108 2980.00000 2981.80750  0.06%     -  630s
#      0     0 2981.80750    0  129 2980.00000 2981.80750  0.06%     -  642s
#      0     0 2981.80750    0  105 2980.00000 2981.80750  0.06%     -  689s
#      0     0 2981.80750    0  110 2980.00000 2981.80750  0.06%     -  706s
#      0     0 2981.78520    0  120 2980.00000 2981.78520  0.06%     -  742s
#      0     0 2981.71028    0  111 2980.00000 2981.71028  0.06%     -  763s
#      0     0 2981.71028    0  117 2980.00000 2981.71028  0.06%     -  770s
#      0     0 2981.63388    0  115 2980.00000 2981.63388  0.05%     -  792s
#      0     0 2981.63388    0  120 2980.00000 2981.63388  0.05%     -  803s
#      0     0 2981.63388    0  126 2980.00000 2981.63388  0.05%     -  827s
# H    0     0                    2981.0000000 2981.63388  0.02%     -  838s
#      0     0 2981.63388    0  126 2981.00000 2981.63388  0.02%     -  838s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 80
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (38119 simplex iterations) in 838.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2981 2980 2979 2865
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.981000000000e+03, best bound 2.981000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4x1

# %%
datafile="4x4000x4x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xded88c11
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2648.0000000
# Presolve removed 53 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 44s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 50s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 55s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 60s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 100s) ...
# Presolve removed 53 rows and 36 columns
# Presolve time: 104.54s
# Presolved: 19947 rows, 15964 columns, 31880096 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6480000e+03   0.000000e+00   8.134750e+03    116s
#     5109    2.7764001e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.776400e+03, 5109 iterations, 11.92 seconds
# Total elapsed time = 129.35s
# Total elapsed time = 135.31s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2776.40014    0  125 2648.00000 2776.40014  4.85%     -  140s
# H    0     0                    2762.0000000 2776.40014  0.52%     -  140s
# H    0     0                    2774.0000000 2776.40014  0.09%     -  141s
# H    0     0                    2775.0000000 2776.40014  0.05%     -  154s
#      0     0 2776.33466    0  122 2775.00000 2776.33466  0.05%     -  177s
#      0     0 2776.31404    0  125 2775.00000 2776.31404  0.05%     -  197s
#      0     0 2776.26823    0  123 2775.00000 2776.26823  0.05%     -  206s
#      0     0 2776.26823    0  122 2775.00000 2776.26823  0.05%     -  211s
#      0     0 2776.07534    0  118 2775.00000 2776.07534  0.04%     -  236s
#      0     0 2776.06989    0  121 2775.00000 2776.06989  0.04%     -  246s
#      0     0 2776.06989    0  119 2775.00000 2776.06989  0.04%     -  253s
#      0     0 2776.00839    0   97 2775.00000 2776.00839  0.04%     -  288s
#      0     0 2776.00839    0  115 2775.00000 2776.00839  0.04%     -  377s
#      0     0 2776.00839    0  122 2775.00000 2776.00839  0.04%     -  390s
#      0     0 2776.00839    0  118 2775.00000 2776.00839  0.04%     -  399s
#      0     0 2776.00839    0  113 2775.00000 2776.00839  0.04%     -  402s
#      0     0 2776.00839    0  111 2775.00000 2776.00839  0.04%     -  404s
#      0     0     cutoff    0      2775.00000 2775.00000  0.00%     -  431s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 7
#   MIR: 84
#   StrongCG: 13
#   GUB cover: 1
#   RLT: 3
#
# Explored 1 nodes (29041 simplex iterations) in 431.35 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2775 2774 2762 2648
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.775000000000e+03, best bound 2.775000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4x2

# %%
datafile="4x4000x4x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x0adfd079
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2645.0000000
# Presolve removed 37 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 15s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 44s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 60s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 37 rows and 20 columns (presolve time = 105s) ...
# Presolve removed 37 rows and 20 columns
# Presolve time: 105.16s
# Presolved: 19963 rows, 15980 columns, 31943996 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6410000e+03   0.000000e+00   8.120500e+03    117s
#     5297    2.7741864e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.774186e+03, 5297 iterations, 12.07 seconds
# Total elapsed time = 130.73s
# Total elapsed time = 137.15s
# Total elapsed time = 143.52s
# Total elapsed time = 149.74s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2774.18639    0  206 2645.00000 2774.18639  4.88%     -  153s
# H    0     0                    2770.0000000 2774.18639  0.15%     -  153s
# H    0     0                    2771.0000000 2774.18639  0.11%     -  158s
# H    0     0                    2772.0000000 2774.18639  0.08%     -  168s
#      0     0 2774.04159    0  202 2772.00000 2774.04159  0.07%     -  191s
#      0     0 2773.98738    0  214 2772.00000 2773.98738  0.07%     -  221s
#      0     0 2773.98738    0  211 2772.00000 2773.98738  0.07%     -  228s
#      0     0 2773.62656    0  164 2772.00000 2773.62656  0.06%     -  254s
#      0     0 2773.62624    0  152 2772.00000 2773.62624  0.06%     -  266s
#      0     0 2773.62624    0  156 2772.00000 2773.62624  0.06%     -  273s
#      0     0 2773.56539    0  166 2772.00000 2773.56539  0.06%     -  297s
# H    0     0                    2773.0000000 2773.56539  0.02%     -  317s
#      0     0 2773.56539    0  166 2773.00000 2773.56539  0.02%     -  317s
#
# Cutting planes:
#   Gomory: 13
#   Cover: 37
#   MIR: 94
#   StrongCG: 12
#   GUB cover: 3
#   RLT: 1
#
# Explored 1 nodes (15956 simplex iterations) in 317.38 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2773 2772 2771 ... 2645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.773000000000e+03, best bound 2.773000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4x3

# %%
datafile="4x4000x4x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x3716d65a
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2653.0000000
# Presolve removed 45 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 15s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 33s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 39s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 62s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 100s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 105s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 110s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 115s) ...
# Presolve removed 49 rows and 36 columns (presolve time = 122s) ...
# Presolve removed 49 rows and 36 columns
# Presolve time: 122.29s
# Presolved: 19951 rows, 15964 columns, 31880108 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6530000e+03   0.000000e+00   8.139750e+03    135s
#      689    2.6567277e+03   0.000000e+00   2.361287e+03    135s
#     5498    2.7840930e+03   0.000000e+00   0.000000e+00    138s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.784093e+03, 5498 iterations, 12.84 seconds
# Total elapsed time = 147.90s
# Total elapsed time = 153.73s
# Total elapsed time = 156.24s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2784.09302    0  131 2653.00000 2784.09302  4.94%     -  159s
# H    0     0                    2774.0000000 2784.09302  0.36%     -  160s
# H    0     0                    2782.0000000 2784.09302  0.08%     -  161s
#      0     0 2784.09302    0  134 2782.00000 2784.09302  0.08%     -  190s
# H    0     0                    2783.0000000 2784.09302  0.04%     -  209s
#      0     0 2784.05943    0  113 2783.00000 2784.05943  0.04%     -  215s
#      0     0 2784.05943    0  110 2783.00000 2784.05943  0.04%     -  221s
#      0     0 2784.05754    0   80 2783.00000 2784.05754  0.04%     -  262s
#      0     0 2784.05754    0  129 2783.00000 2784.05754  0.04%     -  344s
#      0     0 2784.05754    0  103 2783.00000 2784.05754  0.04%     -  401s
#      0     0 2784.05754    0   97 2783.00000 2784.05754  0.04%     -  414s
#      0     0 2784.04889    0   91 2783.00000 2784.04889  0.04%     -  417s
#      0     0 2784.04889    0   91 2783.00000 2784.04889  0.04%     -  420s
#      0     0 2784.03009    0   88 2783.00000 2784.03009  0.04%     -  432s
#      0     0     cutoff    0      2783.00000 2783.00000  0.00%     -  439s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 8
#   MIR: 25
#   StrongCG: 2
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (27131 simplex iterations) in 439.62 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2783 2782 2774 2653
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.783000000000e+03, best bound 2.783000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4x4

# %%
datafile="4x4000x4x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xe11612d8
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2660.0000000
# Presolve removed 50 rows and 40 columns (presolve time = 6s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 14s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 21s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 44s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 50s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 55s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 60s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 65s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 70s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 75s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 80s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 85s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 90s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 95s) ...
# Presolve removed 50 rows and 40 columns (presolve time = 100s) ...
# Presolve removed 50 rows and 40 columns
# Presolve time: 104.53s
# Presolved: 19950 rows, 15960 columns, 31864156 nonzeros
# Variable types: 0 continuous, 15960 integer (15960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6570000e+03   0.000000e+00   8.092000e+03    116s
#     5861    2.7794778e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.04s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.779478e+03, 5861 iterations, 12.22 seconds
# Total elapsed time = 130.83s
# Total elapsed time = 136.87s
# Total elapsed time = 140.72s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2779.47783    0  249 2660.00000 2779.47783  4.49%     -  143s
# H    0     0                    2774.0000000 2779.47783  0.20%     -  143s
# H    0     0                    2776.0000000 2779.47783  0.13%     -  148s
# H    0     0                    2778.0000000 2779.47783  0.05%     -  158s
#      0     0 2779.47015    0  257 2778.00000 2779.47015  0.05%     -  268s
#      0     0 2779.31807    0  240 2778.00000 2779.31807  0.05%     -  294s
#      0     0 2779.31807    0  237 2778.00000 2779.31807  0.05%     -  301s
#      0     0 2779.26578    0  208 2778.00000 2779.26578  0.05%     -  328s
#      0     0 2779.22267    0  194 2778.00000 2779.22267  0.04%     -  343s
#      0     0 2779.22267    0  197 2778.00000 2779.22267  0.04%     -  350s
#      0     0 2779.13940    0  298 2778.00000 2779.13940  0.04%     -  377s
#      0     0 2779.13940    0  303 2778.00000 2779.13940  0.04%     -  395s
#      0     0 2779.01184    0  250 2778.00000 2779.01184  0.04%     -  422s
#      0     0 2779.01184    0  248 2778.00000 2779.01184  0.04%     -  438s
#      0     0     cutoff    0      2778.00000 2778.00000  0.00%     -  459s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 33
#   MIR: 276
#   StrongCG: 6
#
# Explored 1 nodes (16417 simplex iterations) in 459.77 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2778 2776 2774 2660
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.778000000000e+03, best bound 2.778000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4x5

# %%
datafile="4x4000x4x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x879c9243
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2634.0000000
# Presolve removed 41 rows and 20 columns (presolve time = 6s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 14s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 21s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 44s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 45s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 50s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 55s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 60s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 65s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 70s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 75s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 80s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 85s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 90s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 95s) ...
# Presolve removed 41 rows and 20 columns (presolve time = 100s) ...
# Presolve removed 41 rows and 20 columns
# Presolve time: 104.51s
# Presolved: 19959 rows, 15980 columns, 31943980 nonzeros
# Variable types: 0 continuous, 15980 integer (15980 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6340000e+03   0.000000e+00   8.027000e+03    117s
#     5846    2.7570243e+03   0.000000e+00   1.059078e-01    120s
#     5936    2.7570203e+03   0.000000e+00   0.000000e+00    121s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.757020e+03, 5936 iterations, 13.56 seconds
# Total elapsed time = 131.42s
# Total elapsed time = 137.38s
# Total elapsed time = 141.21s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2757.02032    0  233 2634.00000 2757.02032  4.67%     -  143s
# H    0     0                    2754.0000000 2757.02032  0.11%     -  144s
# H    0     0                    2755.0000000 2757.02032  0.07%     -  161s
#      0     0 2757.02032    0  253 2755.00000 2757.02032  0.07%     -  183s
#      0     0 2756.98389    0  250 2755.00000 2756.98389  0.07%     -  218s
#      0     0 2756.98242    0  248 2755.00000 2756.98242  0.07%     -  225s
#      0     0 2756.98242    0  247 2755.00000 2756.98242  0.07%     -  232s
#      0     0 2756.97288    0  182 2755.00000 2756.97288  0.07%     -  292s
#      0     0 2756.79861    0  170 2755.00000 2756.79861  0.07%     -  305s
#      0     0 2756.79655    0  167 2755.00000 2756.79655  0.07%     -  311s
#      0     0 2756.79655    0  171 2755.00000 2756.79655  0.07%     -  316s
#      0     0 2756.79655    0  195 2755.00000 2756.79655  0.07%     -  340s
#      0     0 2756.79648    0  190 2755.00000 2756.79648  0.07%     -  365s
#      0     0 2756.79648    0  196 2755.00000 2756.79648  0.07%     -  389s
#      0     0 2756.79497    0  189 2755.00000 2756.79497  0.07%     -  412s
#      0     0 2756.79447    0  183 2755.00000 2756.79447  0.07%     -  419s
#      0     0 2756.79447    0  190 2755.00000 2756.79447  0.07%     -  425s
#      0     0 2756.79218    0  198 2755.00000 2756.79218  0.07%     -  449s
#      0     0 2756.79218    0  193 2755.00000 2756.79218  0.07%     -  462s
#      0     0 2756.79218    0  201 2755.00000 2756.79218  0.07%     -  486s
#      0     0 2756.74044    0  181 2755.00000 2756.74044  0.06%     -  496s
#      0     0 2756.74044    0  188 2755.00000 2756.74044  0.06%     -  503s
#      0     0 2756.74044    0  164 2755.00000 2756.74044  0.06%     -  544s
#      0     0 2756.74044    0  173 2755.00000 2756.74044  0.06%     -  567s
#      0     0 2756.74044    0  175 2755.00000 2756.74044  0.06%     -  590s
#      0     0 2756.74044    0  178 2755.00000 2756.74044  0.06%     -  600s
#      0     0 2756.73396    0  156 2755.00000 2756.73396  0.06%     -  642s
#      0     0 2756.72406    0  168 2755.00000 2756.72406  0.06%     -  653s
#      0     0 2756.66354    0  172 2755.00000 2756.66354  0.06%     -  660s
#      0     0 2756.65951    0  162 2755.00000 2756.65951  0.06%     -  667s
#      0     0 2756.65907    0  166 2755.00000 2756.65907  0.06%     -  674s
#      0     0 2756.65907    0  164 2755.00000 2756.65907  0.06%     -  681s
#      0     0 2756.65907    0  174 2755.00000 2756.65907  0.06%     -  704s
#      0     0 2756.65808    0  170 2755.00000 2756.65808  0.06%     -  728s
#      0     0 2756.65641    0  172 2755.00000 2756.65641  0.06%     -  736s
#      0     0 2756.65641    0  169 2755.00000 2756.65641  0.06%     -  742s
#      0     0 2756.64249    0  181 2755.00000 2756.64249  0.06%     -  766s
#      0     0 2756.60935    0  178 2755.00000 2756.60935  0.06%     -  783s
#      0     0 2756.59417    0  163 2755.00000 2756.59417  0.06%     -  790s
#      0     0 2756.59417    0  166 2755.00000 2756.59417  0.06%     -  796s
#      0     0 2756.56948    0  171 2755.00000 2756.56948  0.06%     -  820s
#      0     0 2756.56317    0  158 2755.00000 2756.56317  0.06%     -  830s
#      0     0 2756.56317    0  159 2755.00000 2756.56317  0.06%     -  837s
#      0     0 2756.50637    0  148 2755.00000 2756.50637  0.05%     -  861s
#      0     0 2756.50218    0  147 2755.00000 2756.50218  0.05%     -  878s
#      0     0 2756.50218    0  152 2755.00000 2756.50218  0.05%     -  884s
#      0     0 2756.50196    0  162 2755.00000 2756.50196  0.05%     -  908s
#      0     0 2756.49802    0  145 2755.00000 2756.49802  0.05%     -  917s
#      0     0 2756.49802    0  147 2755.00000 2756.49802  0.05%     -  924s
#      0     0 2756.48872    0  156 2755.00000 2756.48872  0.05%     -  950s
# H    0     0                    2756.0000000 2756.48872  0.02%     -  961s
#      0     0 2756.48872    0  156 2756.00000 2756.48872  0.02%     -  961s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   MIR: 69
#   RLT: 1
#
# Explored 1 nodes (36774 simplex iterations) in 961.94 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2756 2755 2754 2634
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.756000000000e+03, best bound 2.756000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4.5x1

# %%
datafile="4x4000x4.5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x99adc29d
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2472.0000000
# Presolve removed 56 rows and 48 columns (presolve time = 6s) ...
# Presolve removed 60 rows and 48 columns (presolve time = 14s) ...
# Presolve removed 60 rows and 48 columns (presolve time = 21s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 33s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 38s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 41s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 61s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 65s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 70s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 75s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 80s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 85s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 90s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 95s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 100s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 105s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 110s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 115s) ...
# Presolve removed 64 rows and 48 columns (presolve time = 122s) ...
# Presolve removed 64 rows and 48 columns
# Presolve time: 121.94s
# Presolved: 19936 rows, 15952 columns, 31832208 nonzeros
# Variable types: 0 continuous, 15952 integer (15952 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4720000e+03   0.000000e+00   8.149000e+03    134s
#     2792    2.5425391e+03   0.000000e+00   5.089149e+02    135s
#     5656    2.5952734e+03   0.000000e+00   0.000000e+00    138s
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.595273e+03, 5656 iterations, 12.84 seconds
# Total elapsed time = 147.38s
# Total elapsed time = 152.72s
# Total elapsed time = 157.93s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2595.27340    0  136 2472.00000 2595.27340  4.99%     -  162s
# H    0     0                    2583.0000000 2595.27340  0.48%     -  163s
# H    0     0                    2591.0000000 2595.27340  0.16%     -  163s
# H    0     0                    2592.0000000 2595.27340  0.13%     -  168s
# H    0     0                    2593.0000000 2595.27340  0.09%     -  174s
#      0     0 2595.27340    0  143 2593.00000 2595.27340  0.09%     -  276s
# H    0     0                    2594.0000000 2595.27340  0.05%     -  294s
#      0     0 2595.27052    0  151 2594.00000 2595.27052  0.05%     -  300s
#      0     0 2595.27052    0  153 2594.00000 2595.27052  0.05%     -  307s
#      0     0 2595.26521    0  114 2594.00000 2595.26521  0.05%     -  353s
#      0     0 2595.26521    0  112 2594.00000 2595.26521  0.05%     -  366s
#      0     0 2595.26521    0  132 2594.00000 2595.26521  0.05%     -  388s
#      0     0 2595.22023    0  129 2594.00000 2595.22023  0.05%     -  406s
#      0     0 2595.21959    0  132 2594.00000 2595.21959  0.05%     -  414s
#      0     0 2595.21958    0  133 2594.00000 2595.21958  0.05%     -  421s
#      0     0 2595.21418    0  110 2594.00000 2595.21418  0.05%     -  462s
#      0     0 2595.13810    0  256 2594.00000 2595.13810  0.04%     -  478s
#      0     0 2595.13014    0  247 2594.00000 2595.13014  0.04%     -  486s
#      0     0 2595.13014    0  252 2594.00000 2595.13014  0.04%     -  493s
#      0     0 2595.03519    0  136 2594.00000 2595.03519  0.04%     -  539s
#      0     0 2595.03519    0  153 2594.00000 2595.03519  0.04%     -  616s
#      0     0 2595.03519    0  149 2594.00000 2595.03519  0.04%     -  662s
#      0     0 2595.03519    0  135 2594.00000 2595.03519  0.04%     -  669s
#      0     0 2595.03519    0  131 2594.00000 2595.03519  0.04%     -  671s
#      0     0 2595.03519    0  131 2594.00000 2595.03519  0.04%     -  674s
#      0     0 2595.01814    0  135 2594.00000 2595.01814  0.04%     -  685s
#      0     0     cutoff    0      2594.00000 2594.00000  0.00%     -  688s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 8
#   MIR: 66
#   StrongCG: 11
#   RLT: 1
#
# Explored 1 nodes (42425 simplex iterations) in 688.51 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2594 2593 2592 ... 2472
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.594000000000e+03, best bound 2.594000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4.5x2

# %%
datafile="4x4000x4.5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x3a2ef950
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2485.0000000
# Presolve removed 30 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 21s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 33s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 38s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 41s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 61s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 85s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 90s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 95s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 100s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 105s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 110s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 115s) ...
# Presolve removed 34 rows and 24 columns (presolve time = 122s) ...
# Presolve removed 34 rows and 24 columns
# Presolve time: 122.06s
# Presolved: 19966 rows, 15976 columns, 31928028 nonzeros
# Variable types: 0 continuous, 15976 integer (15976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4820000e+03   0.000000e+00   8.176250e+03    134s
#     3637    2.5842873e+03   0.000000e+00   1.889800e+02    135s
#     5459    2.6059251e+03   0.000000e+00   0.000000e+00    137s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.605925e+03, 5459 iterations, 11.98 seconds
# Total elapsed time = 147.13s
# Total elapsed time = 153.08s
# Total elapsed time = 159.11s
# Total elapsed time = 161.40s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2605.92513    0  278 2485.00000 2605.92513  4.87%     -  163s
# H    0     0                    2600.0000000 2605.92513  0.23%     -  164s
# H    0     0                    2602.0000000 2605.92513  0.15%     -  169s
# H    0     0                    2603.0000000 2605.92513  0.11%     -  173s
#      0     0 2605.89207    0  282 2603.00000 2605.89207  0.11%     -  280s
# H    0     0                    2604.0000000 2605.89207  0.07%     -  314s
#      0     0 2605.46565    0  270 2604.00000 2605.46565  0.06%     -  320s
#      0     0 2605.46452    0  261 2604.00000 2605.46452  0.06%     -  328s
#      0     0 2605.46452    0  262 2604.00000 2605.46452  0.06%     -  335s
#      0     0 2605.45509    0  215 2604.00000 2605.45509  0.06%     -  364s
#      0     0 2605.45509    0  225 2604.00000 2605.45509  0.06%     -  379s
#      0     0 2605.45174    0  197 2604.00000 2605.45174  0.06%     -  408s
#      0     0 2605.45033    0  195 2604.00000 2605.45033  0.06%     -  438s
#      0     0 2605.45033    0  197 2604.00000 2605.45033  0.06%     -  445s
#      0     0 2605.44328    0  182 2604.00000 2605.44328  0.06%     -  474s
#      0     0 2605.44328    0  169 2604.00000 2605.44328  0.06%     -  487s
#      0     0 2605.43036    0  180 2604.00000 2605.43036  0.05%     -  515s
#      0     0 2605.43036    0  180 2604.00000 2605.43036  0.05%     -  528s
#      0     0 2605.43036    0  179 2604.00000 2605.43036  0.05%     -  553s
#      0     0 2605.43036    0  173 2604.00000 2605.43036  0.05%     -  567s
#      0     0 2605.43036    0  177 2604.00000 2605.43036  0.05%     -  611s
#      0     0 2605.43036    0  179 2604.00000 2605.43036  0.05%     -  634s
#      0     0 2605.43036    0  151 2604.00000 2605.43036  0.05%     -  672s
#      0     0 2605.43036    0  145 2604.00000 2605.43036  0.05%     -  688s
#      0     0 2605.43036    0  141 2604.00000 2605.43036  0.05%     -  726s
#      0     0 2605.43036    0  146 2604.00000 2605.43036  0.05%     -  738s
#      0     0 2605.43036    0  149 2604.00000 2605.43036  0.05%     -  854s
#      0     0 2605.43036    0  130 2604.00000 2605.43036  0.05%     -  878s
#      0     2 2605.43036    0  130 2604.00000 2605.43036  0.05%     -  951s
#      1     4 2605.00636    1  145 2604.00000 2605.43036  0.05%  2286  956s
#      3     6 infeasible    2      2604.00000 2605.43036  0.05%   765  965s
#      7    12 2605.42581    3  167 2604.00000 2605.43036  0.05%   392  980s
#     13    18 2605.42581    4  152 2604.00000 2605.42996  0.05%   273 1006s
#     19    24 2605.42581    5  152 2604.00000 2605.42996  0.05%   209 1032s
#     25    30 2605.42581    6  149 2604.00000 2605.42996  0.05%   170 1037s
#     31    36 2605.42581    7  154 2604.00000 2605.42996  0.05%   139 1065s
#     37    44 2605.42472    7  153 2604.00000 2605.42996  0.05%   119 1071s
#     45    51 2605.42581    6  155 2604.00000 2605.42996  0.05%   102 1078s
#     52    77 2605.42472    8  153 2604.00000 2605.42996  0.05%  91.8 1095s
#     78    92 2605.42581   10  153 2604.00000 2605.42996  0.05%  66.3 1130s
#     95   200 2605.37544   12  151 2604.00000 2605.42996  0.05%  56.8 1191s
#    206   320 2605.30042   26  144 2604.00000 2605.42996  0.05%  30.8 1279s
# H  248   320                    2605.0000000 2605.42996  0.02%  26.8 1279s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 366
#   MIR: 231
#   StrongCG: 4
#   Mod-K: 2
#   RLT: 1
#
# Explored 359 nodes (44953 simplex iterations) in 1282.18 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2605 2604 2603 ... 2485
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.605000000000e+03, best bound 2.605000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4.5x3

# %%
datafile="4x4000x4.5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xd4b8c988
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2488.0000000
# Presolve removed 29 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 33s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 39s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 62s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 100s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 105s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 110s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 115s) ...
# Presolve removed 37 rows and 36 columns (presolve time = 122s) ...
# Presolve removed 37 rows and 36 columns
# Presolve time: 122.11s
# Presolved: 19963 rows, 15964 columns, 31880180 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4880000e+03   0.000000e+00   8.259125e+03    134s
#     1745    2.5157283e+03   0.000000e+00   7.395087e+02    135s
#     5136    2.6089892e+03   0.000000e+00   0.000000e+00    138s
#     5136    2.6089892e+03   0.000000e+00   0.000000e+00    139s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.608989e+03, 5136 iterations, 14.11 seconds
# Total elapsed time = 149.75s
# Total elapsed time = 156.05s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2608.98917    0  318 2488.00000 2608.98917  4.86%     -  162s
# H    0     0                    2606.0000000 2608.98917  0.11%     -  162s
#      0     0 2608.95112    0  292 2606.00000 2608.95112  0.11%     -  283s
# H    0     0                    2607.0000000 2608.95112  0.07%     -  310s
#      0     0 2608.92160    0  265 2607.00000 2608.92160  0.07%     -  315s
#      0     0 2608.92160    0  267 2607.00000 2608.92160  0.07%     -  322s
#      0     0 2608.89289    0  285 2607.00000 2608.89289  0.07%     -  348s
#      0     0 2608.85753    0  282 2607.00000 2608.85753  0.07%     -  364s
#      0     0 2608.85655    0  281 2607.00000 2608.85655  0.07%     -  370s
#      0     0 2608.85645    0  288 2607.00000 2608.85645  0.07%     -  376s
#      0     0 2608.82287    0  283 2607.00000 2608.82287  0.07%     -  405s
#      0     0 2608.81441    0  277 2607.00000 2608.81441  0.07%     -  437s
#      0     0 2608.81433    0  277 2607.00000 2608.81433  0.07%     -  444s
#      0     0 2608.78899    0  258 2607.00000 2608.78899  0.07%     -  471s
#      0     0 2608.78122    0  263 2607.00000 2608.78122  0.07%     -  486s
#      0     0 2608.78120    0  257 2607.00000 2608.78120  0.07%     -  494s
#      0     0 2608.76200    0  249 2607.00000 2608.76200  0.07%     -  520s
#      0     0 2608.75833    0  240 2607.00000 2608.75833  0.07%     -  533s
#      0     0 2608.75833    0  252 2607.00000 2608.75833  0.07%     -  540s
#      0     0 2608.74588    0  238 2607.00000 2608.74588  0.07%     -  568s
#      0     0 2608.74588    0  240 2607.00000 2608.74588  0.07%     -  584s
#      0     0 2608.73255    0  211 2607.00000 2608.73255  0.07%     -  610s
#      0     0 2608.73255    0  223 2607.00000 2608.73255  0.07%     -  633s
#      0     0 2608.73200    0  206 2607.00000 2608.73200  0.07%     -  658s
#      0     0 2608.72462    0  203 2607.00000 2608.72462  0.07%     -  674s
#      0     0 2608.72462    0  213 2607.00000 2608.72462  0.07%     -  681s
#      0     0 2608.68402    0  206 2607.00000 2608.68402  0.06%     -  706s
#      0     0 2608.68402    0  206 2607.00000 2608.68402  0.06%     -  716s
#      0     0 2608.38726    0  205 2607.00000 2608.38726  0.05%     -  826s
#      0     0 2608.38617    0  192 2607.00000 2608.38617  0.05%     -  843s
#      0     0 2608.38617    0  217 2607.00000 2608.38617  0.05%     -  850s
#      0     0 2608.36053    0  216 2607.00000 2608.36053  0.05%     -  876s
#      0     0 2608.36053    0  214 2607.00000 2608.36053  0.05%     -  896s
#      0     0 2608.34168    0  196 2607.00000 2608.34168  0.05%     -  923s
#      0     0 2608.34168    0  179 2607.00000 2608.34168  0.05%     -  938s
#      0     0 2608.34168    0  189 2607.00000 2608.34168  0.05%     -  961s
#      0     0 2608.34085    0  192 2607.00000 2608.34085  0.05%     -  981s
#      0     0 2608.34085    0  192 2607.00000 2608.34085  0.05%     -  988s
#      0     0 2608.30723    0  176 2607.00000 2608.30723  0.05%     - 1033s
#      0     0 2608.30723    0  175 2607.00000 2608.30723  0.05%     - 1046s
#      0     0 2608.30723    0  199 2607.00000 2608.30723  0.05%     - 1070s
#      0     0 2608.30723    0  211 2607.00000 2608.30723  0.05%     - 1088s
#      0     0 2608.30723    0  165 2607.00000 2608.30723  0.05%     - 1136s
#      0     0 2608.30723    0  197 2607.00000 2608.30723  0.05%     - 1150s
#      0     0 2608.30723    0  198 2607.00000 2608.30723  0.05%     - 1184s
#      0     0 2608.30723    0  189 2607.00000 2608.30723  0.05%     - 1201s
#      0     0 2608.30723    0  308 2607.00000 2608.30723  0.05%     - 1328s
#      0     0 2608.30723    0  458 2607.00000 2608.30723  0.05%     - 1413s
#      0     0 2608.30341    0  405 2607.00000 2608.30341  0.05%     - 1428s
#      0     0 2608.30268    0  399 2607.00000 2608.30268  0.05%     - 1434s
#      0     0 2608.30267    0  396 2607.00000 2608.30267  0.05%     - 1438s
#      0     0 2608.30267    0  347 2607.00000 2608.30267  0.05%     - 1455s
#      0     0 2608.30267    0  329 2607.00000 2608.30267  0.05%     - 1465s
#      0     0 2608.30267    0  324 2607.00000 2608.30267  0.05%     - 1482s
#      0     0 2608.30267    0  324 2607.00000 2608.30267  0.05%     - 1494s
#      0     0 2608.30267    0  160 2607.00000 2608.30267  0.05%     - 1530s
#      0     0 2608.30267    0  173 2607.00000 2608.30267  0.05%     - 1541s
#      0     0 2608.30267    0  187 2607.00000 2608.30267  0.05%     - 1562s
#      0     0 2608.30267    0  195 2607.00000 2608.30267  0.05%     - 1573s
#      0     0 2608.30267    0  172 2607.00000 2608.30267  0.05%     - 1604s
#      0     0 2608.30267    0  178 2607.00000 2608.30267  0.05%     - 1616s
#      0     0 2608.30267    0  168 2607.00000 2608.30267  0.05%     - 1641s
#      0     0 2608.30267    0  181 2607.00000 2608.30267  0.05%     - 1652s
#      0     0 2608.30267    0  143 2607.00000 2608.30267  0.05%     - 1687s
#      0     0 2608.30267    0  178 2607.00000 2608.30267  0.05%     - 1700s
#      0     0 2608.30267    0  168 2607.00000 2608.30267  0.05%     - 1723s
#      0     0 2608.30267    0  168 2607.00000 2608.30267  0.05%     - 1738s
#      0     2 2608.30267    0  168 2607.00000 2608.30267  0.05%     - 1840s
#      1     5 2608.30267    1  171 2607.00000 2608.30267  0.05%   484 1845s
#      3     8 2608.24070    2  172 2607.00000 2608.26055  0.05%   172 1850s
#      7    14 2608.24070    3  168 2607.00000 2608.26055  0.05%  83.0 1857s
#     13    20 2608.22825    4  193 2607.00000 2608.26055  0.05%  59.1 1873s
#     19    26 2608.22796    5  172 2607.00000 2608.26055  0.05%  61.6 1879s
#     25    31 2608.22405    6  158 2607.00000 2608.26034  0.05%  50.8 1884s
#     31    37 2608.22405    7  157 2607.00000 2608.26034  0.05%  42.1 1894s
#     37    44 2608.22383    8  157 2607.00000 2608.26034  0.05%  38.8 1898s
#     44    62 2608.22383    9  157 2607.00000 2608.25946  0.05%  33.2 1908s
#     62   102 2608.22295   11  157 2607.00000 2608.25209  0.05%  24.8 1934s
#    110   194 2608.16162   15  156 2607.00000 2608.25209  0.05%  17.9 1975s
#    202   396 2608.16001   24  156 2607.00000 2608.25209  0.05%  12.0 2071s
#    446   817 2608.13388   44  141 2607.00000 2608.25209  0.05%  10.5 2231s
#    958  1140 2608.07249  110  156 2607.00000 2608.25209  0.05%  12.0 2358s
#   1371  1141 2608.03142   36  189 2607.00000 2608.25209  0.05%  13.2 2862s
#   1373  1142 2608.05950   40  310 2607.00000 2608.25209  0.05%  13.2 3299s
#   1374  1143 2608.22241   13  297 2607.00000 2608.25209  0.05%  13.2 3316s
#   1375  1144 2608.08428   21  245 2607.00000 2608.25209  0.05%  13.1 3352s
#   1376  1144 2608.22359    9  252 2607.00000 2608.25209  0.05%  13.1 3359s
#   1377  1145 2607.99950   68  262 2607.00000 2608.25209  0.05%  13.1 3365s
#
# Cutting planes:
#   Gomory: 113
#   Cover: 20
#   MIR: 246
#   StrongCG: 14
#   Flow cover: 218
#   GUB cover: 9
#   Zero half: 2
#   RLT: 1
#
# Explored 1377 nodes (102155 simplex iterations) in 3604.80 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 3: 2607 2606 2488
#
# Time limit reached
# Best objective 2.607000000000e+03, best bound 2.608000000000e+03, gap 0.0384%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4.5x4

# %%
datafile="4x4000x4.5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x02ab97fa
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2476.0000000
# Presolve removed 24 rows and 32 columns (presolve time = 6s) ...
# Presolve removed 32 rows and 32 columns (presolve time = 14s) ...
# Presolve removed 32 rows and 32 columns (presolve time = 21s) ...
# Presolve removed 32 rows and 32 columns (presolve time = 33s) ...
# Presolve removed 32 rows and 32 columns (presolve time = 38s) ...
# Presolve removed 36 rows and 32 columns (presolve time = 40s) ...
# Presolve removed 36 rows and 32 columns (presolve time = 50s) ...
# Presolve removed 36 rows and 32 columns (presolve time = 56s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 80s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 80s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 85s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 90s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 95s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 100s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 105s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 110s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 115s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 120s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 125s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 130s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 135s) ...
# Presolve removed 40 rows and 32 columns (presolve time = 140s) ...
# Presolve removed 40 rows and 32 columns
# Presolve time: 140.31s
# Presolved: 19960 rows, 15968 columns, 31896088 nonzeros
# Variable types: 0 continuous, 15968 integer (15968 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4750000e+03   0.000000e+00   8.130250e+03    152s
#     5142    2.5974126e+03   0.000000e+00   0.000000e+00    155s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.597413e+03, 5142 iterations, 11.78 seconds
# Total elapsed time = 164.84s
# Total elapsed time = 170.54s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2597.41260    0  112 2476.00000 2597.41260  4.90%     -  175s
# H    0     0                    2587.0000000 2597.41260  0.40%     -  176s
# H    0     0                    2594.0000000 2597.41260  0.13%     -  176s
# H    0     0                    2595.0000000 2597.41260  0.09%     -  184s
#      0     0 2597.24818    0   93 2595.00000 2597.24818  0.09%     -  286s
# H    0     0                    2596.0000000 2597.24818  0.05%     -  309s
#      0     0 2597.06099    0   92 2596.00000 2597.06099  0.04%     -  315s
#      0     0 2597.06099    0   97 2596.00000 2597.06099  0.04%     -  321s
#
# Cutting planes:
#   Gomory: 25
#   Cover: 42
#   MIR: 232
#   StrongCG: 38
#   GUB cover: 1
#
# Explored 1 nodes (13702 simplex iterations) in 335.54 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2596 2595 2594 ... 2476
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.596000000000e+03, best bound 2.596000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x4.5x5

# %%
datafile="4x4000x4.5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x53b66248
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Found heuristic solution: objective 2467.0000000
# Presolve removed 26 rows and 24 columns (presolve time = 6s) ...
# Presolve removed 30 rows and 24 columns (presolve time = 14s) ...
# Presolve removed 30 rows and 24 columns (presolve time = 21s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 33s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 38s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 40s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 61s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 65s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 70s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 75s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 80s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 85s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 90s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 95s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 100s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 105s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 110s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 115s) ...
# Presolve removed 38 rows and 24 columns (presolve time = 122s) ...
# Presolve removed 38 rows and 24 columns
# Presolve time: 121.90s
# Presolved: 19962 rows, 15976 columns, 31928012 nonzeros
# Variable types: 0 continuous, 15976 integer (15976 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4670000e+03   0.000000e+00   8.177000e+03    134s
#     2019    2.5105004e+03   0.000000e+00   6.310870e+02    135s
#     5393    2.5970188e+03   0.000000e+00   0.000000e+00    138s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.597019e+03, 5393 iterations, 12.70 seconds
# Total elapsed time = 147.52s
# Total elapsed time = 153.67s
# Total elapsed time = 159.54s
# Total elapsed time = 161.80s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2597.01881    0  361 2467.00000 2597.01881  5.27%     -  163s
# H    0     0                    2591.0000000 2597.01881  0.23%     -  164s
# H    0     0                    2593.0000000 2597.01881  0.15%     -  170s
# H    0     0                    2595.0000000 2597.01881  0.08%     -  177s
#      0     0 2596.29041    0  338 2595.00000 2596.29041  0.05%     -  285s
#      0     0 2596.28629    0  334 2595.00000 2596.28629  0.05%     -  312s
#      0     0 2596.28555    0  320 2595.00000 2596.28555  0.05%     -  321s
#      0     0 2596.28555    0  323 2595.00000 2596.28555  0.05%     -  328s
#      0     0 2596.27953    0  332 2595.00000 2596.27953  0.05%     -  355s
#      0     0 2596.27857    0  301 2595.00000 2596.27857  0.05%     -  377s
#      0     0 2596.27855    0  296 2595.00000 2596.27855  0.05%     -  384s
#      0     0 2596.27811    0  279 2595.00000 2596.27811  0.05%     -  410s
#      0     0 2596.27811    0  266 2595.00000 2596.27811  0.05%     -  435s
#      0     0 2596.27694    0  271 2595.00000 2596.27694  0.05%     -  462s
#      0     0 2596.27612    0  251 2595.00000 2596.27612  0.05%     -  477s
#      0     0 2596.27612    0  248 2595.00000 2596.27612  0.05%     -  484s
#      0     0 2596.27504    0  250 2595.00000 2596.27504  0.05%     -  509s
#      0     0 2596.27504    0  248 2595.00000 2596.27504  0.05%     -  530s
#      0     0 2596.27503    0  248 2595.00000 2596.27503  0.05%     -  553s
#      0     0 2596.27503    0  250 2595.00000 2596.27503  0.05%     -  570s
#      0     0 2596.27488    0  246 2595.00000 2596.27488  0.05%     -  593s
#      0     0 2596.27485    0  256 2595.00000 2596.27485  0.05%     -  613s
#      0     0 2596.27474    0  253 2595.00000 2596.27474  0.05%     -  636s
#      0     0 2596.27474    0  257 2595.00000 2596.27474  0.05%     -  650s
#      0     0 2596.27405    0  255 2595.00000 2596.27405  0.05%     -  675s
#      0     0 2596.27405    0  201 2595.00000 2596.27405  0.05%     -  707s
#      0     0 2596.27405    0  405 2595.00000 2596.27405  0.05%     -  833s
#      0     0 2596.27405    0  372 2595.00000 2596.27405  0.05%     -  920s
#      0     0 2596.27405    0  271 2595.00000 2596.27405  0.05%     -  937s
#      0     0 2596.27405    0  251 2595.00000 2596.27405  0.05%     -  942s
#      0     0 2596.27405    0  250 2595.00000 2596.27405  0.05%     -  945s
#      0     0 2596.27405    0  251 2595.00000 2596.27405  0.05%     -  964s
#      0     0 2596.27405    0  242 2595.00000 2596.27405  0.05%     -  972s
#      0     0 2596.27405    0  263 2595.00000 2596.27405  0.05%     -  991s
#      0     0 2596.27405    0  267 2595.00000 2596.27405  0.05%     - 1002s
#      0     0 2596.27405    0  207 2595.00000 2596.27405  0.05%     - 1041s
#      0     0 2596.27405    0  208 2595.00000 2596.27405  0.05%     - 1054s
#      0     0 2596.27405    0  187 2595.00000 2596.27405  0.05%     - 1082s
#      0     0 2596.27405    0  201 2595.00000 2596.27405  0.05%     - 1097s
#      0     0 2596.27405    0  203 2595.00000 2596.27405  0.05%     - 1126s
#      0     0 2596.27405    0  207 2595.00000 2596.27405  0.05%     - 1138s
#      0     0 2596.27405    0  194 2595.00000 2596.27405  0.05%     - 1170s
#      0     0 2596.27405    0  215 2595.00000 2596.27405  0.05%     - 1184s
#      0     0 2596.27405    0  223 2595.00000 2596.27405  0.05%     - 1210s
#      0     0 2596.27405    0  206 2595.00000 2596.27405  0.05%     - 1235s
#      0     2 2596.27405    0  206 2595.00000 2596.27405  0.05%     - 1376s
#      1     5 2596.27405    1  206 2595.00000 2596.27405  0.05%   976 1381s
#      3     8 2596.27405    2  223 2595.00000 2596.27405  0.05%   393 1388s
#      7    14 2596.27122    3  225 2595.00000 2596.27122  0.05%   261 1399s
#     13    20 2596.27122    4  222 2595.00000 2596.27122  0.05%   205 1408s
#     19    26 2596.27122    5  221 2595.00000 2596.27122  0.05%   149 1412s
#     25    32 2596.27111    6  225 2595.00000 2596.27111  0.05%   116 1416s
#     31    38 2596.27111    7  225 2595.00000 2596.27111  0.05%  95.6 1426s
#     37    46 2596.27111    8  225 2595.00000 2596.27111  0.05%  82.0 1431s
#     45    52 2596.27083    9  223 2595.00000 2596.27083  0.05%  69.2 1435s
#     51    71 2596.27083   10  225 2595.00000 2596.27083  0.05%  62.4 1445s
#     70   134 2596.27078   12  225 2595.00000 2596.27078  0.05%  48.4 1477s
#    133   250 2596.26936   17  224 2595.00000 2596.26936  0.05%  30.4 1536s
#    249   517 2596.26747   27  221 2595.00000 2596.26763  0.05%  20.3 1660s
#    516  1013 2596.25777   47  223 2595.00000 2596.26763  0.05%  14.6 1873s
#   1064  1017 2596.15666   78  216 2595.00000 2596.26763  0.05%  11.4 1979s
#   1071  1094 2596.02530   79  214 2595.00000 2596.26763  0.05%  11.6 2072s
#   1251  1504 2596.18170   11  207 2595.00000 2596.26763  0.05%  13.3 2283s
#   1807  1505 2596.03476   30  201 2595.00000 2596.26763  0.05%  12.5 2796s
#   1809  1506 2596.26558   33  398 2595.00000 2596.26763  0.05%  12.5 3026s
#   1810  1507 2596.26473   39  348 2595.00000 2596.26763  0.05%  12.5 3040s
#   1811  1508 2596.26747   38  297 2595.00000 2596.26763  0.05%  12.5 3064s
#   1812  1508 2596.22741   74  277 2595.00000 2596.26763  0.05%  12.5 3071s
#   1813  1509 2596.16491   43  266 2595.00000 2596.26763  0.05%  12.5 3078s
#   1814  1510 2596.22060   60  264 2595.00000 2596.26763  0.05%  12.5 3217s
#   1815  1510 2596.08472   35  257 2595.00000 2596.26763  0.05%  12.5 3231s
#   1816  1511 2596.09392   25  255 2595.00000 2596.26763  0.05%  12.5 3386s
#   1817  1512 2596.26725   38  221 2595.00000 2596.26763  0.05%  12.5 3401s
#   1818  1512 2596.05484   94  228 2595.00000 2596.26763  0.05%  12.5 3527s
#   1819  1513 2596.24603   48  237 2595.00000 2596.26763  0.05%  12.5 3537s
#
# Cutting planes:
#   Gomory: 67
#   Cover: 57
#   MIR: 206
#   StrongCG: 58
#   Flow cover: 236
#   GUB cover: 6
#
# Explored 1819 nodes (86003 simplex iterations) in 3604.63 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2595 2595 2593 ... 2467
#
# Time limit reached
# Best objective 2.595000000000e+03, best bound 2.596000000000e+03, gap 0.0385%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x5x1

# %%
datafile="4x4000x5x1.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xfa4e6057
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2350.0000000
# Presolve removed 39 rows and 44 columns (presolve time = 6s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 14s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 21s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 33s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 38s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 40s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 61s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 65s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 70s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 75s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 80s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 85s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 90s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 95s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 100s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 105s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 110s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 115s) ...
# Presolve removed 55 rows and 44 columns (presolve time = 122s) ...
# Presolve removed 55 rows and 44 columns
# Presolve time: 121.55s
# Presolved: 19945 rows, 15956 columns, 31848196 nonzeros
# Variable types: 0 continuous, 15956 integer (15956 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3520000e+03   0.000000e+00   8.288500e+03    133s
#     4751    2.4827608e+03   0.000000e+00   3.512836e+00    136s
#     5071    2.4832009e+03   0.000000e+00   0.000000e+00    137s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.483201e+03, 5071 iterations, 11.82 seconds
# Total elapsed time = 145.97s
# Total elapsed time = 151.52s
# Total elapsed time = 156.19s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2483.20085    0  105 2350.00000 2483.20085  5.67%     -  158s
# H    0     0                    2476.0000000 2483.20085  0.29%     -  158s
# H    0     0                    2479.0000000 2483.20085  0.17%     -  162s
# H    0     0                    2481.0000000 2483.20085  0.09%     -  173s
#      0     0 2483.18878    0   92 2481.00000 2483.18878  0.09%     -  272s
# H    0     0                    2482.0000000 2483.18878  0.05%     -  295s
#      0     0 2483.18340    0  106 2482.00000 2483.18340  0.05%     -  300s
#      0     0 2483.18340    0  103 2482.00000 2483.18340  0.05%     -  307s
#      0     0     cutoff    0      2482.00000 2482.00000  0.00%     -  323s
#
# Cutting planes:
#   Gomory: 22
#   Cover: 69
#   MIR: 241
#   StrongCG: 78
#   GUB cover: 4
#   RLT: 4
#
# Explored 1 nodes (14561 simplex iterations) in 323.82 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 5: 2482 2481 2479 ... 2350
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.482000000000e+03, best bound 2.482000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x5x2

# %%
datafile="4x4000x5x2.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xfff272c3
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2357.0000000
# Presolve removed 49 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 33s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 39s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 40s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 62s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 100s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 105s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 110s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 115s) ...
# Presolve removed 53 rows and 36 columns (presolve time = 123s) ...
# Presolve removed 53 rows and 36 columns
# Presolve time: 122.58s
# Presolved: 19947 rows, 15964 columns, 31880088 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3580000e+03   0.000000e+00   8.286750e+03    135s
#      244    2.3597322e+03   0.000000e+00   3.508367e+03    135s
#     5289    2.4740267e+03   0.000000e+00   0.000000e+00    139s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.474027e+03, 5289 iterations, 12.74 seconds
# Total elapsed time = 148.16s
# Total elapsed time = 152.99s
# Total elapsed time = 157.64s
# Total elapsed time = 162.10s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2474.02666    0  289 2357.00000 2474.02666  4.97%     -  164s
# H    0     0                    2470.0000000 2474.02666  0.16%     -  165s
# H    0     0                    2471.0000000 2474.02666  0.12%     -  170s
# H    0     0                    2472.0000000 2474.02666  0.08%     -  173s
#      0     0 2473.83074    0  291 2472.00000 2473.83074  0.07%     -  276s
#      0     0 2473.56844    0  268 2472.00000 2473.56844  0.06%     -  311s
#      0     0 2473.56752    0  279 2472.00000 2473.56752  0.06%     -  318s
#      0     0 2473.56752    0  284 2472.00000 2473.56752  0.06%     -  325s
#      0     0 2473.40694    0  241 2472.00000 2473.40694  0.06%     -  353s
#      0     0 2473.40218    0  233 2472.00000 2473.40218  0.06%     -  369s
#      0     0 2473.40215    0  236 2472.00000 2473.40215  0.06%     -  374s
#      0     0 2473.40120    0  226 2472.00000 2473.40120  0.06%     -  402s
#      0     0 2473.39942    0  227 2472.00000 2473.39942  0.06%     -  426s
#      0     0 2473.39939    0  224 2472.00000 2473.39939  0.06%     -  433s
#      0     0 2473.36777    0  189 2472.00000 2473.36777  0.06%     -  458s
#      0     0 2473.36632    0  183 2472.00000 2473.36632  0.06%     -  474s
#      0     0 2473.36582    0  184 2472.00000 2473.36582  0.06%     -  482s
#      0     0 2473.36582    0  183 2472.00000 2473.36582  0.06%     -  489s
#      0     0 2473.36582    0  176 2472.00000 2473.36582  0.06%     -  511s
#      0     0 2473.36582    0  179 2472.00000 2473.36582  0.06%     -  532s
#      0     0 2473.36574    0  197 2472.00000 2473.36574  0.06%     -  554s
#      0     0 2473.36465    0  186 2472.00000 2473.36465  0.06%     -  568s
#      0     0 2473.36465    0  176 2472.00000 2473.36465  0.06%     -  575s
#      0     0 2473.36465    0  181 2472.00000 2473.36465  0.06%     -  597s
#      0     0 2473.36465    0  158 2472.00000 2473.36465  0.06%     -  615s
#      0     0 2473.36465    0  175 2472.00000 2473.36465  0.06%     -  636s
#      0     0 2473.36465    0  166 2472.00000 2473.36465  0.06%     -  649s
#      0     0 2473.36265    0  153 2472.00000 2473.36265  0.06%     -  697s
#      0     0 2473.35643    0  154 2472.00000 2473.35643  0.05%     -  716s
#      0     0 2473.35359    0  149 2472.00000 2473.35359  0.05%     -  724s
#      0     0 2473.35358    0  161 2472.00000 2473.35358  0.05%     -  730s
#      0     0 2473.35354    0  176 2472.00000 2473.35354  0.05%     -  817s
#      0     0 2473.35354    0  171 2472.00000 2473.35354  0.05%     -  849s
#      0     0 2473.35350    0  187 2472.00000 2473.35350  0.05%     -  872s
#      0     0 2473.35340    0  187 2472.00000 2473.35340  0.05%     -  889s
#      0     0 2473.31964    0  184 2472.00000 2473.31964  0.05%     -  914s
#      0     0 2473.31964    0  178 2472.00000 2473.31964  0.05%     -  937s
#      0     0 2473.31959    0  172 2472.00000 2473.31959  0.05%     -  959s
#      0     0 2473.31959    0  175 2472.00000 2473.31959  0.05%     -  974s
#      0     0 2473.31920    0  178 2472.00000 2473.31920  0.05%     -  998s
#      0     0 2473.31900    0  176 2472.00000 2473.31900  0.05%     - 1009s
#      0     0 2473.31815    0  175 2472.00000 2473.31815  0.05%     - 1031s
#      0     0 2473.31815    0  139 2472.00000 2473.31815  0.05%     - 1068s
#      0     0 2473.31815    0  332 2472.00000 2473.31815  0.05%     - 1198s
#      0     0 2473.31815    0  226 2472.00000 2473.31815  0.05%     - 1278s
#      0     0 2473.31815    0  186 2472.00000 2473.31815  0.05%     - 1293s
#      0     0 2473.31815    0  188 2472.00000 2473.31815  0.05%     - 1297s
#      0     0 2473.31815    0  170 2472.00000 2473.31815  0.05%     - 1314s
#      0     0 2473.31815    0  177 2472.00000 2473.31815  0.05%     - 1327s
#      0     0 2473.31815    0  179 2472.00000 2473.31815  0.05%     - 1343s
#      0     0 2473.31815    0  174 2472.00000 2473.31815  0.05%     - 1354s
#      0     0 2473.31815    0  183 2472.00000 2473.31815  0.05%     - 1370s
#      0     0 2473.31815    0  182 2472.00000 2473.31815  0.05%     - 1379s
#      0     0 2473.31815    0  135 2472.00000 2473.31815  0.05%     - 1409s
#      0     0 2473.31815    0  163 2472.00000 2473.31815  0.05%     - 1424s
#      0     0 2473.31815    0  152 2472.00000 2473.31815  0.05%     - 1450s
#      0     0 2473.31815    0  159 2472.00000 2473.31815  0.05%     - 1456s
#      0     0 2473.31815    0  152 2472.00000 2473.31815  0.05%     - 1486s
#      0     0 2473.31815    0  150 2472.00000 2473.31815  0.05%     - 1497s
#      0     0 2473.31815    0  150 2472.00000 2473.31815  0.05%     - 1523s
#      0     0 2473.31815    0  148 2472.00000 2473.31815  0.05%     - 1542s
#      0     2 2473.31815    0  144 2472.00000 2473.31815  0.05%     - 1633s
#      1     5 2473.31815    1  144 2472.00000 2473.31815  0.05%  1259 1637s
#      3     8 2473.31815    2  142 2472.00000 2473.31815  0.05%   429 1643s
#      7    14 2473.31490    3  164 2472.00000 2473.31490  0.05%   206 1651s
#     13    20 2473.31490    4  162 2472.00000 2473.31490  0.05%   160 1660s
#     25    32 2473.31399    6  162 2472.00000 2473.31399  0.05%   116 1666s
#     31    40 2473.31056    7  159 2472.00000 2473.31308  0.05%  95.5 1670s
#     47    56 2473.30729   10  159 2472.00000 2473.31308  0.05%  67.8 1676s
#     55    76 2473.30729   11  156 2472.00000 2473.31308  0.05%  58.9 1683s
#     75   129 2473.30266   15  153 2472.00000 2473.31308  0.05%  45.7 1704s
#    128   240 2473.29543   21  154 2472.00000 2473.31308  0.05%  32.0 1749s
#    246   444 2473.22379   35  155 2472.00000 2473.31308  0.05%  21.8 1830s
#    455   758 2473.06770   76  156 2472.00000 2473.31308  0.05%  16.0 1955s
#    780   793 2473.04284  130  120 2472.00000 2473.31308  0.05%  12.7 2074s
#    816  1118 2473.04196  136  115 2472.00000 2473.31308  0.05%  12.5 2184s
#   1147  1522 2473.03247  182  117 2472.00000 2473.31308  0.05%  11.5 2314s
#   1571  1528 2473.02743  241  125 2472.00000 2473.31308  0.05%  10.8 2396s
#   1577  1971 2473.02579  242  133 2472.00000 2473.31308  0.05%  10.9 2541s
#   2036  2445 2473.01796  301  125 2472.00000 2473.31308  0.05%  10.5 2689s
#   2513  2952 2473.01202  352  122 2472.00000 2473.31308  0.05%  10.1 2843s
#   3041  3454 2473.00757  392  132 2472.00000 2473.31308  0.05%   9.7 3035s
#   3586  3981 2473.00176  440  114 2472.00000 2473.31308  0.05%   9.7 3207s
#   4155  4599 2473.06958   53  151 2472.00000 2473.31308  0.05%   9.6 3399s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 433
#   MIR: 201
#   GUB cover: 2
#
# Explored 4781 nodes (103924 simplex iterations) in 3600.93 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2472 2471 2470 2357
#
# Time limit reached
# Best objective 2.472000000000e+03, best bound 2.473000000000e+03, gap 0.0405%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x5x3

# %%
datafile="4x4000x5x3.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xcc0aa18c
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2337.0000000
# Presolve removed 62 rows and 40 columns (presolve time = 6s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 21s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 44s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 50s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 55s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 60s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 65s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 70s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 75s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 80s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 85s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 90s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 95s) ...
# Presolve removed 62 rows and 40 columns (presolve time = 100s) ...
# Presolve removed 62 rows and 40 columns
# Presolve time: 104.74s
# Presolved: 19938 rows, 15960 columns, 31864108 nonzeros
# Variable types: 0 continuous, 15960 integer (15960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3370000e+03   0.000000e+00   8.223750e+03    116s
#     5198    2.4613535e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.461354e+03, 5198 iterations, 11.88 seconds
# Total elapsed time = 129.01s
# Total elapsed time = 134.50s
# Total elapsed time = 139.47s
# Total elapsed time = 144.73s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2461.35350    0  225 2337.00000 2461.35350  5.32%     -  147s
# H    0     0                    2456.0000000 2461.35350  0.22%     -  148s
# H    0     0                    2459.0000000 2461.35350  0.10%     -  153s
# H    0     0                    2460.0000000 2461.35350  0.06%     -  158s
#      0     0 2461.33462    0  239 2460.00000 2461.33462  0.05%     -  182s
#      0     0 infeasible    0      2460.00000 2460.00000  0.00%     -  187s
#      0     0 infeasible    0      2460.00000 2460.00000  0.00%     -  187s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 1
#   MIR: 33
#   RLT: 1
#
# Explored 1 nodes (14653 simplex iterations) in 187.38 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2460 2459 2456 2337
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.460000000000e+03, best bound 2.460000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x5x4

# %%
datafile="4x4000x5x4.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0x05260a8f
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2323.0000000
# Presolve removed 54 rows and 40 columns (presolve time = 6s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 15s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 21s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 44s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 45s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 50s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 55s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 60s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 65s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 70s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 75s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 80s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 85s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 90s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 95s) ...
# Presolve removed 54 rows and 40 columns (presolve time = 100s) ...
# Presolve removed 54 rows and 40 columns
# Presolve time: 104.40s
# Presolved: 19946 rows, 15960 columns, 31864124 nonzeros
# Variable types: 0 continuous, 15960 integer (15960 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3230000e+03   0.000000e+00   8.157750e+03    117s
#     4651    2.4473837e+03   0.000000e+00   0.000000e+00    121s
#     4651    2.4473837e+03   0.000000e+00   0.000000e+00    122s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.447384e+03, 4651 iterations, 14.51 seconds
# Total elapsed time = 131.40s
# Total elapsed time = 136.98s
# Total elapsed time = 141.64s
# Total elapsed time = 146.02s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2447.38365    0  270 2323.00000 2447.38365  5.35%     -  149s
# H    0     0                    2431.0000000 2447.38365  0.67%     -  149s
# H    0     0                    2438.0000000 2447.38365  0.38%     -  153s
# H    0     0                    2444.0000000 2447.38365  0.14%     -  155s
# H    0     0                    2445.0000000 2447.38365  0.10%     -  159s
#      0     0 2447.12531    0  248 2445.00000 2447.12531  0.09%     -  259s
#      0     0 2447.11538    0  248 2445.00000 2447.11538  0.09%     -  292s
#      0     0 2447.11538    0  242 2445.00000 2447.11538  0.09%     -  299s
#      0     0 2446.67058    0  207 2445.00000 2446.67058  0.07%     -  324s
#      0     0 2446.66208    0  200 2445.00000 2446.66208  0.07%     -  338s
#      0     0 2446.66208    0  208 2445.00000 2446.66208  0.07%     -  345s
#      0     0 2446.66151    0  200 2445.00000 2446.66151  0.07%     -  369s
# H    0     0                    2446.0000000 2446.66151  0.03%     -  389s
#      0     0 2446.66151    0  200 2446.00000 2446.66151  0.03%     -  389s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 7
#   MIR: 99
#   StrongCG: 5
#   GUB cover: 1
#
# Explored 1 nodes (12262 simplex iterations) in 389.49 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 6: 2446 2445 2444 ... 2323
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.446000000000e+03, best bound 2.446000000000e+03, gap 0.0000%

# %% [markdown]
# ## Entrada de datos: Instancia 4x4000x5x5

# %%
datafile="4x4000x5x5.csv"
data=pd.DataFrame(pd.read_csv(datafile,sep=";"))

data["JOB"]="J"+data["JOB"].map(str)
dictJobs={i:[data.set_index('JOB').to_dict()["Deadline"][i],data.set_index('JOB').to_dict()["PT"][i]] for i in data.set_index('JOB').to_dict()["Deadline"].keys()}

dictJobs=dict(sorted(dictJobs.items(), key=lambda item: item[1]))
ordDict={}
cont=0

for i in dictJobs:
    ordDict[cont]=[i,dictJobs[i][0],dictJobs[i][1]]
    cont+=1
len(dictJobs)
# Out:
# 4000

# %%
p = []
d = []
for i in ordDict.keys():
    p.append(ordDict[i][2])
    d.append(ordDict[i][1])
    
jth=4
ith=len(ordDict)
N = range(ith)
M = range(jth)

indices=[(i,j) for i in N for j in M]

# Importar Gurobi
import gurobipy as grb

#Inicializar modelo
mdl = grb.Model("modelo")
    
x = mdl.addVars(indices, vtype=grb.GRB.BINARY, name='x')

mdl.Params.timeLimit=3600.0

mdl.setObjective(sum(x[(i,j)] for i in N for j in M))

mdl.addConstrs((sum(x[(i,j)] for j in M) <= 1 for i in N), name='A')

for k in N:
    for j in M:
        mdl.addConstr(sum(x[(i,j)]*p[i] for i in N if i<=k)<=d[k])

mdl.ModelSense = grb.GRB.MAXIMIZE
mdl.optimize()
# Out:
# Changed value of parameter timeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 6 logical processors, using up to 6 threads
# Optimize a model with 20000 rows, 16000 columns and 32024000 nonzeros
# Model fingerprint: 0xa1e7c262
# Variable types: 0 continuous, 16000 integer (16000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Found heuristic solution: objective 2344.0000000
# Presolve removed 57 rows and 36 columns (presolve time = 6s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 14s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 21s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 44s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 45s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 50s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 55s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 60s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 65s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 70s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 75s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 80s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 85s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 90s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 95s) ...
# Presolve removed 57 rows and 36 columns (presolve time = 104s) ...
# Presolve removed 57 rows and 36 columns
# Presolve time: 104.17s
# Presolved: 19943 rows, 15964 columns, 31880084 nonzeros
# Variable types: 0 continuous, 15964 integer (15964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3370000e+03   0.000000e+00   8.232000e+03    116s
#     4801    2.4585993e+03   0.000000e+00   0.000000e+00    120s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.458599e+03, 4801 iterations, 12.59 seconds
# Total elapsed time = 128.89s
# Total elapsed time = 134.35s
# Total elapsed time = 136.58s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2458.59926    0  155 2344.00000 2458.59926  4.89%     -  139s
# H    0     0                    2448.0000000 2458.59926  0.43%     -  140s
# H    0     0                    2456.0000000 2458.59926  0.11%     -  144s
# H    0     0                    2457.0000000 2458.59926  0.07%     -  151s
#      0     0 2458.57768    0  125 2457.00000 2458.57768  0.06%     -  173s
#      0     0 2458.50888    0  114 2457.00000 2458.50888  0.06%     -  197s
#      0     0 2458.50888    0  114 2457.00000 2458.50888  0.06%     -  202s
#      0     0 2458.30332    0   88 2457.00000 2458.30332  0.05%     -  225s
#      0     0 2458.30332    0   87 2457.00000 2458.30332  0.05%     -  238s
#      0     0 infeasible    0      2457.00000 2457.00000  0.00%     -  258s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 92
#   MIR: 149
#   StrongCG: 86
#   RLT: 5
#
# Explored 1 nodes (13327 simplex iterations) in 258.23 seconds
# Thread count was 6 (of 6 available processors)
#
# Solution count 4: 2457 2456 2448 2344
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.457000000000e+03, best bound 2.457000000000e+03, gap 0.0000%
